# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/ABIDE/")
# Out:
# Mounted at /content/drive

# %%
# !pip install torch==1.11.0 torchvision==0.12.0 torchaudio==0.11.0
# !pip install --no-index torch-scatter -f https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# !pip install --no-index torch-sparse -f https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# !pip install --no-index torch-cluster -f https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# !pip install --no-index torch-spline-conv -f https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# !pip install torch-geometric
import torch
print(torch.__version__)  
print(torch.version.cuda)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch==1.11.0
#   Downloading torch-1.11.0-cp38-cp38-manylinux1_x86_64.whl (750.6 MB)
#      |████████████████████████████████| 750.6 MB 18 kB/s
# Collecting torchvision==0.12.0
#   Downloading torchvision-0.12.0-cp38-cp38-manylinux1_x86_64.whl (21.0 MB)
#      |████████████████████████████████| 21.0 MB 1.3 MB/s
# Collecting torchaudio==0.11.0
#   Downloading torchaudio-0.11.0-cp38-cp38-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 66.0 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch==1.11.0) (4.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torchvision==0.12.0) (2.23.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision==0.12.0) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torchvision==0.12.0) (1.21.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision==0.12.0) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision==0.12.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision==0.12.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision==0.12.0) (2.10)
# Installing collected packages: torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.1+cu113
#     Uninstalling torchvision-0.13.1+cu113:
#       Successfully uninstalled torchvision-0.13.1+cu113
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 0.12.1+cu113
#     Uninstalling torchaudio-0.12.1+cu113:
#       Successfully uninstalled torchaudio-0.12.1+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.13.1 requires torch==1.12.1, but you have torch 1.11.0 which is incompatible.
# Successfully installed torch-1.11.0 torchaudio-0.11.0 torchvision-0.12.0
# Looking in links: https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# Collecting torch-scatter
#   Downloading https://data.pyg.org/whl/torch-1.11.0%2Bcu102/torch_scatter-2.0.9-cp38-cp38-linux_x86_64.whl (8.0 MB)
#      |████████████████████████████████| 8.0 MB 30.7 MB/s
# Installing collected packages: torch-scatter
# Successfully installed torch-scatter-2.0.9
# Looking in links: https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# Collecting torch-sparse
#   Downloading https://data.pyg.org/whl/torch-1.11.0%2Bcu102/torch_sparse-0.6.15-cp38-cp38-linux_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 28.3 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from torch-sparse) (1.7.3)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /usr/local/lib/python3.8/dist-packages (from scipy->torch-sparse) (1.21.6)
# Installing collected packages: torch-sparse
# Successfully installed torch-sparse-0.6.15
# Looking in links: https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# Collecting torch-cluster
#   Downloading https://data.pyg.org/whl/torch-1.11.0%2Bcu102/torch_cluster-1.6.0-cp38-cp38-linux_x86_64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 39.7 MB/s
# Installing collected packages: torch-cluster
# Successfully installed torch-cluster-1.6.0
# Looking in links: https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# Collecting torch-spline-conv
#   Downloading https://data.pyg.org/whl/torch-1.11.0%2Bcu102/torch_spline_conv-1.2.1-cp38-cp38-linux_x86_64.whl (672 kB)
#      |████████████████████████████████| 672 kB 49.7 MB/s
# Installing collected packages: torch-spline-conv
# Successfully installed torch-spline-conv-1.2.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch-geometric
#   Downloading torch_geometric-2.2.0.tar.gz (564 kB)
#      |████████████████████████████████| 564 kB 35.8 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from torch-geometric) (4.64.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torch-geometric) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from torch-geometric) (1.7.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from torch-geometric) (2.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torch-geometric) (2.23.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.8/dist-packages (from torch-geometric) (3.0.9)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from torch-geometric) (1.0.2)
# Collecting psutil>=5.8.0
#   Downloading psutil-5.9.4-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
#      |████████████████████████████████| 280 kB 79.0 MB/s
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->torch-geometric) (2.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torch-geometric) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torch-geometric) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->torch-geometric) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->torch-geometric) (3.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->torch-geometric) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->torch-geometric) (1.2.0)
# Building wheels for collected packages: torch-geometric
#   Building wheel for torch-geometric (setup.py) ... done
#   Created wheel for torch-geometric: filename=torch_geometric-2.2.0-py3-none-any.whl size=773302 sha256=558b6b9e182c4a43db3c932c45bfe2ba5eee2f175bb6e8d87382333c3e083f69
#   Stored in directory: /root/.cache/pip/wheels/59/a3/20/198928106d3169865ae73afcbd3d3d1796cf6b429b55c65378
# Successfully built torch-geometric
# Installing collected packages: psutil, torch-geometric
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
# Successfully installed psutil-5.9.4 torch-geometric-2.2.0
# 1.11.0+cu102
# 10.2

# %%
# load ComBat algorithm
# !python /content/drive/MyDrive/ABIDE/neuralCombat.py 
import sys
sys.path.append('/content/drive/MyDrive/ABIDE/')

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from neuralCombat import *
# from neuralCombat.py import neuralCombat
import pandas as pd
from sklearn import svm
import joblib
import openpyxl
from openpyxl import load_workbook
import os
import scipy.io as scio
import argparse
import numpy as np
import time
import torch
import torch.utils.data
import torch.nn as nn
import torch.optim as optim
from torch.utils.data.dataset import Dataset
from torch.autograd import Variable
from torchvision import datasets, transforms
from torchvision.utils import make_grid , save_image
import torchvision.utils as vutils
from os.path import join
from os import listdir
from torch.utils.data.dataloader import DataLoader
from torch.utils.data import DataLoader
from collections import OrderedDict
import nibabel as nib
import matplotlib.pyplot as plt
import cv2 as cv
from os import path
import shutil
import scipy.stats
import scipy.ndimage
import random
import torch.nn.init as init
import torch.nn.functional as F
import sys
import math
from functools import reduce
import operator
from scipy.interpolate import interp1d
from torch.optim import lr_scheduler
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import RidgeClassifier
from sklearn.feature_selection import RFE

def feature_selection(matrix, labels, train_ind, fnum):
    """
        matrix       : feature matrix (num_subjects x num_features)
        labels       : ground truth labels (num_subjects x 1)
        train_ind    : indices of the training samples
        fnum         : size of the feature vector after feature selection 

    return:
        x_data      : feature matrix of lower dimension (num_subjects x fnum)
    """

    estimator = RidgeClassifier()
    selector = RFE(estimator, n_features_to_select=fnum, step=100, verbose=1)

    featureX = matrix[train_ind, :]
    featureY = labels[train_ind]
    selector = selector.fit(featureX, featureY.ravel())

    return selector

def get_index(lst=None, item=''):
	return [i for i in range(len(lst)) if lst[i] == item]

def flatten_one(length, img):
	'''
	  In some situations, the dimension on z-axis of images are smaller than
	  the dimension of z-axis of patches, this function will be used to pad
	'''

	one_line = np.zeros((1, int(length)))
	position = 0
	for i in range(img.shape[0]):  # column
		for j in range(i + 1, img.shape[1]):  # row
			one_line[0, position] = img[j, i]
			position = position + 1
	return one_line


def get_ids(num_subjects=None,dir_path=''):
	"""
	return:
		subject_IDs    : list of all subject IDs
	"""
	subject_IDs = np.genfromtxt(os.path.join(dir_path, 'subject_IDs.txt'), dtype=str)

	if num_subjects is not None:
		subject_IDs = subject_IDs[:num_subjects]

	return subject_IDs

def save_model(net,path, name_net):

  # This fucntion is used to save a specific model

    path_net =  path + '/' + name_net + '.pth'
    torch.save(net.cpu().state_dict(), path_net)
    net.cuda()

def load_model(net, path, name_net):

  # This function is used to load a specific model we saved before

    path_net =  path + '/' + name_net + '.pth'
    net.load_state_dict(torch.load(path_net))

    return net

def initialize():
  set_seed


def set_seed(seed=0):
  random.seed(seed)
  np.random.seed(seed)
  torch.manual_seed(seed)
  torch.cuda.manual_seed(seed)
  torch.cuda.manual_seed_all(seed)
  torch.backends.cudnn.deterministic = True
  torch.backends.cudnn.benchmark = False

# initialize()

# %%
########################################### Load Data ###############################################
#####################################################################################################
#####################################################################################################
fMRI_atlas = 'CC200'  # AAL or CC200
combat = True    # True or False
scaler = True

if combat == False:
  save_combat = '/without_ComBat/'
else:
  save_combat = '/with_ComBat/'

save_path = '/content/drive/MyDrive/ABIDE/save_models/'+fMRI_atlas+ save_combat
root_path = '/content/dataset'
if os.path.exists(root_path):
  shutil.rmtree(root_path) 
shutil.copytree('/content/drive/MyDrive/ABIDE/' + fMRI_atlas + '/original/', root_path) 
label_dir = '/content/drive/MyDrive/ABIDE/phenotypic_image_quality'

k_fold = 5
new_number_features = 5000
number_samples = 871
useless_samples = ['51334']
if fMRI_atlas == 'AAL':
  image_size = [116, 116]
else:
  image_size = [200, 200]


age_name = 'ages.mat'
gender_name = 'genders.mat'
label_name = 'ABIDE_label_871.mat'
label = scio.loadmat(os.path.join(label_dir, label_name))
label = label['label'][0]
labels = np.zeros(number_samples - len(useless_samples))
site_name = 'sites.mat'
site = scio.loadmat(os.path.join(label_dir, site_name))
all_sites = site['sites']
for i in range(len(all_sites)):
	site = all_sites[i]
	all_sites[i] = site.replace(' ', '')
unique_sites = np.unique(all_sites)
sites = []
unique_sites = list(unique_sites)

age = scio.loadmat(os.path.join(label_dir, age_name))
age = age['ages']
ages = np.zeros((number_samples - len(useless_samples), 1))

gender = scio.loadmat(os.path.join(label_dir, gender_name))
gender = gender['genders']
genders = np.zeros((number_samples - len(useless_samples), 1))

subject_IDs = get_ids(number_samples,dir_path=label_dir)
subject_IDs = subject_IDs.tolist()
length = image_size[0] * (image_size[1]-1) / 2
fMRI_images = np.zeros((number_samples - len(useless_samples), int(length)))

EV_GCN_unique = list(unique_sites)
EV_GCN_site = np.zeros([number_samples - len(useless_samples)], dtype=np.int)
EV_GCN_age = np.zeros([number_samples - len(useless_samples)], dtype=np.float32)
EV_GCN_gender = np.zeros([number_samples - len(useless_samples)], dtype=np.int)

position = 0
print('constructing fMRI features')
for i in range(number_samples):
  subject_name = subject_IDs[i]
  print(subject_name)
  if subject_name in useless_samples:
    subject_index = get_index(lst=subject_IDs, item=subject_name)
    print('The index for sample ' + subject_name + ' is : ', subject_index)
  else:
    image_name = subject_name + '.mat'
    subject_index = get_index(lst=subject_IDs, item=subject_name)
    image = scio.loadmat(os.path.join(root_path, image_name))
    img = image['connectivity']

    idx = np.triu_indices_from(img, 1)
    fMRI_images[position, :] = img[idx]
    sites.append(all_sites[subject_index[0]])
    labels[position] = label[subject_index[0]]
    genders[position] = int(gender[subject_index[0]]) + 1
    ages[position] = float(age[subject_index[0]])
    
    position = position + 1

for i in range(number_samples - len(useless_samples)): 

  EV_GCN_site[i] = EV_GCN_unique.index(sites[i])
  EV_GCN_age[i] = ages[i]
  EV_GCN_gender[i] = genders[i]

phonetic_data = np.zeros([number_samples - len(useless_samples), 3], dtype=np.float32)
phonetic_data[:,0] = EV_GCN_site 
phonetic_data[:,1] = EV_GCN_gender 
phonetic_data[:,2] = EV_GCN_age

pd_dict = {}
pd_dict['SITE_ID'] = np.copy(phonetic_data[:,0])
pd_dict['SEX'] = np.copy(phonetic_data[:,1])
pd_dict['AGE_AT_SCAN'] = np.copy(phonetic_data[:,2]) 

if scaler == True:
	fMRI_images = StandardScaler().fit_transform(fMRI_images)
	print('Done')
# Out:
# <ipython-input-5-f202fb8b3ef0>:60: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   EV_GCN_site = np.zeros([number_samples - len(useless_samples)], dtype=np.int)
# <ipython-input-5-f202fb8b3ef0>:62: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   EV_GCN_gender = np.zeros([number_samples - len(useless_samples)], dtype=np.int)
# constructing fMRI features
# 50003
# 50004
# 50005
# 50006
# 50007
# 50008
# 50010
# 50011
# 50012
# 50013
# 50014
# 50015
# 50016
# 50020
# 50022
# 50023
# 50024
# 50025
# 50026
# 50027
# 50028
# 50030
# 50031
# 50032
# 50033
# 50034
# 50035
# 50036
# 50037
# 50038
# 50039
# 50040
# 50041
# 50042
# 50043
# 50044
# 50045
# 50046
# 50047
# 50048
# 50049
# 50050
# 50051
# 50052
# 50053
# 50054
# 50056
# 50057
# 50059
# 50060
# 50102
# 50103
# 50104
# 50105
# 50106
# 50107
# 50109
# 50111
# 50112
# 50113
# 50114
# 50115
# 50116
# 50117
# 50118
# 50119
# 50121
# 50123
# 50124
# 50125
# 50127
# 50128
# 50129
# 50130
# 50131
# 50132
# 50134
# 50135
# 50142
# 50143
# 50144
# 50145
# 50146
# 50147
# 50148
# 50149
# 50150
# 50152
# 50153
# 50156
# 50157
# 50158
# 50159
# 50160
# 50161
# 50162
# 50163
# 50164
# 50167
# 50168
# 50169
# 50170
# 50171
# 50182
# 50183
# 50184
# 50186
# 50187
# 50188
# 50189
# 50190
# 50193
# 50194
# 50195
# 50196
# 50198
# 50199
# 50200
# 50201
# 50202
# 50203
# 50204
# 50205
# 50206
# 50208
# 50210
# 50213
# 50214
# 50215
# 50217
# 50232
# 50233
# 50234
# 50236
# 50237
# 50239
# 50240
# 50241
# 50243
# 50245
# 50247
# 50248
# 50249
# 50250
# 50251
# 50252
# 50253
# 50254
# 50255
# 50257
# 50259
# 50260
# 50261
# 50262
# 50263
# 50264
# 50265
# 50266
# 50267
# 50268
# 50269
# 50270
# 50271
# 50272
# 50273
# 50274
# 50275
# 50276
# 50278
# 50282
# 50284
# 50285
# 50287
# 50289
# 50290
# 50291
# 50292
# 50293
# 50294
# 50295
# 50297
# 50298
# 50300
# 50301
# 50302
# 50304
# 50308
# 50310
# 50312
# 50314
# 50315
# 50318
# 50319
# 50320
# 50321
# 50324
# 50325
# 50327
# 50329
# 50330
# 50331
# 50332
# 50333
# 50334
# 50335
# 50336
# 50337
# 50338
# 50339
# 50340
# 50341
# 50342
# 50343
# 50344
# 50345
# 50346
# 50347
# 50348
# 50349
# 50350
# 50351
# 50352
# 50353
# 50354
# 50355
# 50356
# 50357
# 50358
# 50359
# 50360
# 50361
# 50362
# 50363
# 50364
# 50365
# 50366
# 50367
# 50368
# 50369
# 50370
# 50372
# 50373
# 50374
# 50375
# 50376
# 50377
# 50379
# 50380
# 50381
# 50382
# 50383
# 50385
# 50386
# 50387
# 50388
# 50390
# 50391
# 50397
# 50399
# 50402
# 50403
# 50404
# 50405
# 50406
# 50407
# 50408
# 50410
# 50411
# 50412
# 50413
# 50414
# 50415
# 50416
# 50417
# 50418
# 50419
# 50421
# 50422
# 50424
# 50425
# 50426
# 50427
# 50428
# 50433
# 50434
# 50435
# 50436
# 50437
# 50438
# 50439
# 50440
# 50441
# 50442
# 50443
# 50444
# 50445
# 50446
# 50447
# 50448
# 50449
# 50453
# 50463
# 50466
# 50467
# 50468
# 50469
# 50470
# 50477
# 50480
# 50481
# 50482
# 50483
# 50485
# 50486
# 50487
# 50488
# 50490
# 50491
# 50492
# 50493
# 50494
# 50496
# 50497
# 50498
# 50499
# 50500
# 50501
# 50502
# 50503
# 50504
# 50507
# 50509
# 50510
# 50514
# 50515
# 50516
# 50518
# 50519
# 50520
# 50521
# 50523
# 50524
# 50525
# 50526
# 50527
# 50528
# 50529
# 50530
# 50531
# 50532
# 50551
# 50552
# 50555
# 50557
# 50558
# 50561
# 50563
# 50565
# 50568
# 50569
# 50570
# 50571
# 50572
# 50573
# 50574
# 50575
# 50576
# 50577
# 50578
# 50601
# 50602
# 50603
# 50604
# 50606
# 50607
# 50608
# 50612
# 50613
# 50614
# 50615
# 50616
# 50619
# 50620
# 50621
# 50622
# 50623
# 50624
# 50625
# 50626
# 50627
# 50628
# 50642
# 50644
# 50647
# 50648
# 50649
# 50654
# 50656
# 50659
# 50664
# 50665
# 50669
# 50682
# 50683
# 50685
# 50686
# 50687
# 50688
# 50689
# 50690
# 50691
# 50692
# 50693
# 50694
# 50695
# 50696
# 50697
# 50698
# 50699
# 50700
# 50701
# 50702
# 50703
# 50704
# 50705
# 50706
# 50707
# 50708
# 50709
# 50711
# 50722
# 50723
# 50724
# 50725
# 50726
# 50728
# 50730
# 50731
# 50733
# 50735
# 50737
# 50738
# 50739
# 50740
# 50741
# 50742
# 50743
# 50744
# 50745
# 50748
# 50749
# 50750
# 50751
# 50752
# 50754
# 50755
# 50756
# 50757
# 50772
# 50773
# 50774
# 50775
# 50776
# 50777
# 50778
# 50780
# 50781
# 50782
# 50783
# 50786
# 50790
# 50791
# 50792
# 50796
# 50797
# 50798
# 50799
# 50800
# 50801
# 50803
# 50807
# 50812
# 50814
# 50816
# 50817
# 50818
# 50820
# 50821
# 50822
# 50823
# 50824
# 50952
# 50954
# 50955
# 50956
# 50957
# 50958
# 50959
# 50960
# 50961
# 50962
# 50964
# 50965
# 50966
# 50967
# 50968
# 50969
# 50970
# 50972
# 50973
# 50974
# 50976
# 50977
# 50978
# 50979
# 50981
# 50982
# 50983
# 50984
# 50985
# 50986
# 50987
# 50988
# 50989
# 50990
# 50991
# 50992
# 50993
# 50994
# 50995
# 50996
# 50997
# 50999
# 51000
# 51001
# 51002
# 51003
# 51006
# 51007
# 51008
# 51009
# 51010
# 51011
# 51012
# 51013
# 51014
# 51015
# 51016
# 51017
# 51018
# 51019
# 51020
# 51021
# 51023
# 51024
# 51025
# 51026
# 51027
# 51028
# 51029
# 51030
# 51032
# 51033
# 51034
# 51035
# 51036
# 51038
# 51039
# 51040
# 51041
# 51042
# 51044
# 51045
# 51046
# 51047
# 51048
# 51049
# 51050
# 51051
# 51052
# 51053
# 51054
# 51055
# 51056
# 51057
# 51058
# 51059
# 51060
# 51061
# 51062
# 51063
# 51064
# 51065
# 51066
# 51067
# 51068
# 51069
# 51070
# 51072
# 51073
# 51074
# 51075
# 51076
# 51077
# 51078
# 51079
# 51080
# 51081
# 51082
# 51083
# 51084
# 51085
# 51086
# 51087
# 51088
# 51089
# 51090
# 51091
# 51093
# 51094
# 51095
# 51096
# 51097
# 51098
# 51099
# 51100
# 51101
# 51102
# 51103
# 51104
# 51105
# 51106
# 51107
# 51109
# 51110
# 51111
# 51112
# 51113
# 51114
# 51116
# 51117
# 51118
# 51122
# 51123
# 51124
# 51126
# 51127
# 51128
# 51129
# 51130
# 51131
# 51132
# 51133
# 51134
# 51135
# 51136
# 51137
# 51138
# 51139
# 51140
# 51141
# 51142
# 51146
# 51147
# 51148
# 51149
# 51150
# 51151
# 51152
# 51153
# 51154
# 51155
# 51156
# 51159
# 51161
# 51162
# 51163
# 51164
# 51168
# 51169
# 51170
# 51171
# 51173
# 51177
# 51178
# 51179
# 51180
# 51181
# 51182
# 51183
# 51184
# 51185
# 51187
# 51188
# 51189
# 51192
# 51194
# 51197
# 51198
# 51201
# 51202
# 51203
# 51204
# 51205
# 51206
# 51207
# 51208
# 51210
# 51211
# 51212
# 51214
# 51215
# 51216
# 51217
# 51218
# 51219
# 51220
# 51221
# 51222
# 51223
# 51224
# 51225
# 51226
# 51228
# 51229
# 51230
# 51231
# 51234
# 51235
# 51236
# 51237
# 51239
# 51240
# 51241
# 51248
# 51249
# 51250
# 51251
# 51252
# 51253
# 51254
# 51255
# 51256
# 51257
# 51260
# 51261
# 51262
# 51264
# 51265
# 51266
# 51267
# 51268
# 51269
# 51271
# 51272
# 51273
# 51275
# 51276
# 51277
# 51278
# 51279
# 51280
# 51281
# 51291
# 51292
# 51293
# 51294
# 51295
# 51297
# 51298
# 51299
# 51300
# 51301
# 51302
# 51303
# 51304
# 51305
# 51306
# 51307
# 51308
# 51309
# 51311
# 51313
# 51315
# 51318
# 51319
# 51320
# 51321
# 51322
# 51323
# 51325
# 51326
# 51327
# 51328
# 51329
# 51330
# 51331
# 51332
# 51333
# 51334
# The index for sample 51334 is :  [799]
# 51335
# 51336
# 51338
# 51339
# 51340
# 51341
# 51342
# 51343
# 51344
# 51345
# 51346
# 51347
# 51349
# 51350
# 51351
# 51354
# 51356
# 51357
# 51359
# 51360
# 51361
# 51362
# 51363
# 51364
# 51365
# 51369
# 51370
# 51373
# 51461
# 51463
# 51464
# 51465
# 51473
# 51477
# 51479
# 51480
# 51481
# 51482
# 51484
# 51487
# 51488
# 51491
# 51493
# 51556
# 51557
# 51558
# 51559
# 51560
# 51562
# 51563
# 51564
# 51565
# 51566
# 51567
# 51568
# 51569
# 51570
# 51572
# 51573
# 51574
# 51576
# 51577
# 51578
# 51579
# 51580
# 51582
# 51583
# 51584
# 51585
# 51606
# 51607
# Done

# %%
############################################### Combat ###############################################################
############################################### Combat ###############################################################
############################################### Combat ###############################################################
if combat == True:
	batch = []
	for i in range(len(sites)):
		batch.append(get_index(lst=unique_sites, item=sites[i])[0]+1)

	combat_labels = []
	combat_genders = []
	combat_ages = []
	for i in range(len(labels)):
		combat_labels.append(labels[i] + 1)
		combat_genders.append(genders[i])
		combat_ages.append(ages[i])

	new_all_samples_feature = fMRI_images.T
	covars = {}
	covars['batch'] = batch
	covars['labels'] = combat_labels
	covars['genders'] = combat_genders
	covars['ages'] = combat_ages
	covars = pd.DataFrame(covars)

	# To specify names of the variables that are categorical:
	categorical_cols = ['labels', 'genders']
	# To specify the name of the variable that encodes for the scanner/batch covariate:
	batch_col = 'batch'
	continuous_cols = ['ages']
	# Harmonization step:
	new_all_samples_feature = neuroCombat(dat=new_all_samples_feature,
										  covars=covars,
										  batch_col=batch_col,
										  categorical_cols=categorical_cols,
											continuous_cols=continuous_cols)["data"]
	fMRI_images = new_all_samples_feature.T
# Out:
# [neuroCombat] Creating design matrix
# [neuroCombat] Standardizing data across features
# [neuroCombat] Fitting L/S model and finding priors
# [neuroCombat] Finding parametric adjustments
# [neuroCombat] Final adjustment of data

# %%
dist_train = {}
dist_validation = {}
dist_test = {}
for i in range(k_fold):
	dist_train[str(i + 1)] = []
	dist_validation[str(i + 1)] = []
	dist_test[str(i + 1)] = []

for each_site in unique_sites:
	index_site = get_index(sites, each_site)
	label = np.zeros((len(index_site)))
	for i in range(len(index_site)):
		index = index_site[i]
		label[i] = int(labels[int(index)])
	########################################### StratifiedKFold ####################################################
	sfolder = StratifiedKFold(n_splits=k_fold,random_state=0,shuffle=True)
	group = 0
	for train, validation in sfolder.split(index_site,label):
		for i in train:
			dist_train[str(group + 1)].append(index_site[i])
			name = 0
		for j in validation:
			dist_validation[str(group + 1)].append(index_site[j])
			name = 0
		group = group+1

	group = 0
	for train, validation in sfolder.split(index_site,label):
		if group == 0:
			for j in validation:
				dist_test[str(group + k_fold)].append(index_site[j])
				dist_train[str(group + k_fold)].remove(index_site[j])
		else:
			for j in validation:
				dist_test[str(group)].append(index_site[j])
				dist_train[str(group)].remove(index_site[j])
		group = group+1

# %%
import torch
import torch_geometric as tg
from torch.nn import Linear as Lin, Sequential as Seq
import torch.nn.functional as F
from torch import nn

############################################### PAE and EV-GCN ###############################################################
############################################### PAE and EV-GCN ###############################################################
############################################### PAE and EV-GCN ###############################################################
class PAE(torch.nn.Module):
    def __init__(self, input_dim, dropout=0.2):
        super(PAE, self).__init__()
        hidden=128
        self.parser =nn.Sequential(
                nn.Linear(input_dim, hidden, bias=True),
                nn.ReLU(inplace=True),
                nn.BatchNorm1d(hidden),
                nn.Dropout(dropout),
                nn.Linear(hidden, hidden, bias=True),
                )
        self.cos = nn.CosineSimilarity(dim=1, eps=1e-8)
        self.input_dim = input_dim
        self.model_init()
        self.relu = nn.ReLU(inplace=True)
        self.elu = nn.ReLU()

    def forward(self, x):
        x1 = x[:,0:self.input_dim]
        x2 = x[:,self.input_dim:]
        h1 = self.parser(x1)
        h2 = self.parser(x2)
        p = (self.cos(h1,h2) + 1)*0.5
        return p

    def model_init(self):
        for m in self.modules():
            if isinstance(m, Lin):
                torch.nn.init.kaiming_normal_(m.weight)
                m.weight.requires_grad = True
                if m.bias is not None:
                    m.bias.data.zero_()
                    m.bias.requires_grad = True


class EV_GCN(torch.nn.Module):
    def __init__(self, input_dim, num_classes, dropout, edgenet_input_dim, edge_dropout, hgc, lg):
        super(EV_GCN, self).__init__()
        K=2
        hidden = [hgc for i in range(lg)]
        self.dropout = dropout 
        self.edge_dropout = edge_dropout  
        bias = False 
        self.relu = torch.nn.ReLU(inplace=True) 
        self.lg = lg 
        self.gconv = nn.ModuleList()
        for i in range(lg): 
            in_channels = input_dim if i==0  else hidden[i-1]
            self.gconv.append(tg.nn.ChebConv(in_channels, hidden[i], K, normalization='sym', bias=bias)) 
        cls_input_dim = sum(hidden) 

        self.cls = nn.Sequential(
                torch.nn.Linear(cls_input_dim, 256),
                torch.nn.ReLU(inplace=True),
                nn.BatchNorm1d(256), 
                torch.nn.Linear(256, num_classes))

        self.edge_net = PAE(input_dim=edgenet_input_dim//2, dropout=dropout)
        self.model_init()
        self.softmax = nn.LogSoftmax(dim=1)

    def model_init(self):
        for m in self.modules():
            if isinstance(m, Lin):
                torch.nn.init.kaiming_normal_(m.weight)
                m.weight.requires_grad = True
                if m.bias is not None:
                    m.bias.data.zero_()
                    m.bias.requires_grad = True

    def forward(self, features, edge_index, edgenet_input, enforce_edropout=False): 
        if self.edge_dropout>0:  
            if enforce_edropout or self.training: 
                one_mask = torch.ones([edgenet_input.shape[0],1]).cuda() 
                self.drop_mask = F.dropout(one_mask, self.edge_dropout, True)
                self.bool_mask = torch.squeeze(self.drop_mask.type(torch.bool))
                edge_index = edge_index[:, self.bool_mask]
                edgenet_input = edgenet_input[self.bool_mask] 


        edge_weight = torch.squeeze(self.edge_net(edgenet_input))
        features = F.dropout(features, self.dropout, self.training)
        h = self.relu(self.gconv[0](features, edge_index, edge_weight)) 
        h0 = h
        for i in range(1, self.lg): 
            h = F.dropout(h, self.dropout, self.training)
            h= self.relu(self.gconv[i](h, edge_index, edge_weight)) 
            jk = torch.cat((h0, h), axis=1)
            h0 = jk
        logit = self.cls(jk)


        return self.softmax(logit), edge_weight

# %%
EV_GCN_labels = np.zeros((number_samples - len(useless_samples), 2))
for i in range(len(labels)):
    if labels[i] == 1:
        EV_GCN_labels[i,0] = 1
    else:
        EV_GCN_labels[i,1] = 1


all_subject_IDs = get_ids(number_samples,dir_path=label_dir)
all_subject_IDs = all_subject_IDs.tolist()
for i in useless_samples:
    subject_IDs.remove(i)

# %%
from scipy.spatial import distance

def create_affinity_graph_from_scores(scores, pd_dict):
    num_nodes = len(pd_dict[scores[0]]) 
    graph = np.zeros((num_nodes, num_nodes))

    for l in scores:
        label_dict = pd_dict[l]

        if l in ['AGE_AT_SCAN', 'FIQ']:
            for k in range(num_nodes):
                for j in range(k + 1, num_nodes):
                    try:
                        val = abs(float(label_dict[k]) - float(label_dict[j]))
                        if val < 2:
                            graph[k, j] += 1
                            graph[j, k] += 1
                    except ValueError:  # missing label
                        pass

        else:
            for k in range(num_nodes):
                for j in range(k + 1, num_nodes):
                    if label_dict[k] == label_dict[j]:
                        graph[k, j] += 1
                        graph[j, k] += 1

    return graph

def get_static_affinity_adj(features, pd_dict):
    pd_affinity = create_affinity_graph_from_scores(['SEX', 'SITE_ID'], pd_dict) 
    distv = distance.pdist(features, metric='correlation') 
    dist = distance.squareform(distv)  
    sigma = np.mean(dist)
    feature_sim = np.exp(- dist ** 2 / (2 * sigma ** 2))
    adj = pd_affinity * feature_sim  

    return adj




data = {}
for fold in range(1, k_fold+1):

  data[str(fold)] = []
  selector = feature_selection(fMRI_images, labels, dist_train[str(fold)], new_number_features)
  fold_data = selector.transform(fMRI_images)
  n = fold_data.shape[0]
  num_edge = n * n
  edge_index = np.zeros([2, num_edge], dtype=np.int64)
  edgenet_input = np.zeros([num_edge, 2*phonetic_data.shape[1]], dtype=np.float32) 
  aff_score = np.zeros(num_edge, dtype=np.float32)

  aff_adj = get_static_affinity_adj(fold_data, pd_dict)  

########################################################## Change #########################################################################
########################################################## Change #########################################################################
########################################################## Change #########################################################################
# !!! Must enter the entire the whole population graph instead of the upper triangle area, otherwise information leakage will occur

  flatten_ind = 0
  for i in range(n): 
    for j in range(n):
      edge_index[:, flatten_ind] = [i, j]
      edgenet_input[flatten_ind] = np.concatenate((phonetic_data[i], phonetic_data[j]))
      aff_score[flatten_ind] = aff_adj[i][j]
      flatten_ind += 1
########################################################## Change #########################################################################
########################################################## Change #########################################################################
########################################################## Change #########################################################################

  keep_ind = np.where(aff_score > 1.1)[0]
  edge_index = edge_index[:, keep_ind]
  edgenet_input = edgenet_input[keep_ind]
  edgenet_input = (edgenet_input- edgenet_input.mean(axis=0)) / edgenet_input.std(axis=0)

  data[str(fold)].append(fold_data)
  data[str(fold)].append(EV_GCN_labels)
  data[str(fold)].append(edge_index)
  data[str(fold)].append(edgenet_input)
# Out:
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.

# %%
############################################### Train, validaiton, test pipelines ###############################################################
############################################### Train, validaiton, test pipelines ###############################################################
############################################### Train, validaiton, test pipelines ###############################################################
def train_EV_GCN(args, model, all_data, fold_train_index, fold_validation_index, fold_test_index, scheduler):

    model.train()
    data = torch.from_numpy(all_data[0])
    data = Variable(data, requires_grad=True)
    data = data.float()

    target = torch.from_numpy(all_data[1])
    target = target.float().long()

    edge_index = torch.from_numpy(all_data[2])
    edge_index = Variable(edge_index, requires_grad=False)

    edgenet_input = torch.from_numpy(all_data[3])
    edgenet_input = Variable(edgenet_input, requires_grad=True)
    edgenet_input = edgenet_input.float()

    if args.cuda:
        data, target, edge_index, edgenet_input = data.cuda(), target.cuda(), edge_index.cuda(), edgenet_input.cuda()

    scheduler.zero_grad()
    out, _ = model(data, edge_index, edgenet_input)
    out = out[fold_train_index,:]
    target = target[fold_train_index, :]

    cross_loss = torch.nn.functional.nll_loss(out, torch.max(target, 1)[1]) # only train set will be included
    out = torch.max(out, 1)[1]
    target = torch.max(target, 1)[1]
    target = target.cpu().numpy()
    out = out.cpu().numpy()
    cross_loss.backward()
    scheduler.step()

    ############################## validation and test ################################################################################
    val_target, val_out, val_loss = validation_EV_GCN(args, model, all_data, fold_validation_index)
    test_target, test_out, test_out_prob, test_loss = test_EV_GCN(args, model, all_data, fold_test_index)

    return model, target, out, cross_loss.item(), val_target, val_out,val_loss, test_target, test_out, test_out_prob, test_loss

    
def validation_EV_GCN(args, model,all_data,  fold_validation_index):

    model.eval()
    data = torch.from_numpy(all_data[0])
    data = Variable(data, requires_grad=False)
    data = data.float()

    target = torch.from_numpy(all_data[1])
    target = target.float().long()

    edge_index = torch.from_numpy(all_data[2])
    edge_index = Variable(edge_index, requires_grad=False)

    edgenet_input = torch.from_numpy(all_data[3])
    edgenet_input = Variable(edgenet_input, requires_grad=False)
    edgenet_input = edgenet_input.float()

    if args.cuda:
        data, target, edge_index, edgenet_input = data.cuda(), target.cuda(), edge_index.cuda(), edgenet_input.cuda()

    out, _ = model(data, edge_index, edgenet_input)
    out = out[fold_validation_index, :]
    target = target[fold_validation_index, :]
    cross_loss = torch.nn.functional.nll_loss(out, torch.max(target, 1)[1])

    out = torch.max(out, 1)[1]
    target = torch.max(target, 1)[1]
    target = target.cpu().numpy()
    out = out.cpu().numpy()

    return target, out, cross_loss.item()


def test_EV_GCN(args, model, all_data,  fold_test_index):

    model.eval()

    data = torch.from_numpy(all_data[0])
    data = Variable(data, requires_grad=False)
    data = data.float()

    target = torch.from_numpy(all_data[1])
    target = target.float().long()

    edge_index = torch.from_numpy(all_data[2])
    edge_index = Variable(edge_index, requires_grad=False)

    edgenet_input = torch.from_numpy(all_data[3])
    edgenet_input = Variable(edgenet_input, requires_grad=False)
    edgenet_input = edgenet_input.float()

    if args.cuda:
        data, target, edge_index, edgenet_input = data.cuda(), target.cuda(), edge_index.cuda(), edgenet_input.cuda()

    out, _ = model(data, edge_index, edgenet_input)
    out = out[fold_test_index, :]
    target = target[fold_test_index, :]
    cross_loss = torch.nn.functional.nll_loss(out, torch.max(target, 1)[1])

    out_prob = torch.exp(out)
    out = torch.max(out, 1)[1]
    target = torch.max(target, 1)[1]
    target = target.cpu().numpy()
    out = out.cpu().numpy()
    out_prob = out_prob.cpu().detach().numpy()


    return target, out, out_prob, cross_loss.item()

# %%
########################################### Training setting ################################################
########################################### Training setting ################################################
########################################### Training setting ################################################
torch.cuda.empty_cache()
parser = argparse.ArgumentParser()
parser.add_argument('--ngpu', type=int, default=1)
parser.add_argument('--nEpochs', type=int, default=200)
parser.add_argument('--start-epoch', default=0, type=int, metavar='N',
                    help='manual epoch number (useful on restarts)')
parser.add_argument('--no-cuda', action='store_true')
parser.add_argument('--opt', type=str, default='adam')
parser.add_argument('--seed', type=int, default=1)
parser.add_argument('--input_dimension', type=int, default=new_number_features)

parser.add_argument('--hgc', type=int, default=16, help='hidden units of gconv layer')
parser.add_argument('--lg', type=int, default=4, help='number of gconv layers')
parser.add_argument('--lr', default=0.01, type=float, help='initial learning rate')
parser.add_argument('--wd', default=5e-5, type=float, help='weight decay')
parser.add_argument('--num_iter', default=300, type=int, help='number of epochs for training')
parser.add_argument('--edropout', type=float, default=0.3, help='edge dropout rate')
parser.add_argument('--dropout', default=0.2, type=float, help='ratio of dropout')
parser.add_argument('--num_classes', type=int, default=2, help='number of classes')

#
args, unknown = parser.parse_known_args()
args.cuda = not args.no_cuda and torch.cuda.is_available()
torch.manual_seed(args.seed)
if args.cuda:
    torch.cuda.manual_seed(args.seed)
    
gpu_ids = range(args.ngpu)
train = train_EV_GCN

# %%
########################################### Training ################################################
########################################### Training ################################################
########################################### Training ################################################
for fold in range(1, k_fold+1):
  model = EV_GCN(args.input_dimension, args.num_classes, args.dropout, edge_dropout=args.edropout, hgc=args.hgc, lg=args.lg, edgenet_input_dim=2*phonetic_data.shape[1])
  print('  + Number of params: {}'.format(
    sum([p.data.nelement() for p in model.parameters()])))
  model = nn.parallel.DataParallel(model, device_ids=gpu_ids)
  if args.cuda:
    model = model.cuda()
  optimizer = optim.Adam(model.parameters(), lr = args.lr)

  best_validation_accuracy = 0
  Train_accuracy_list =[]
  Train_loss_list = []
  Val_accuracy_list =[]
  Val_loss_list = []
  Test_accuracy_list =[]
  Test_loss_list = []

  for epoch in range(1, args.nEpochs + 1):

    model, train_target, train_out, train_loss, val_target, val_out, val_loss, test_target, test_out, test_prob, test_loss = train(args, model, data[str(fold)], dist_train[str(fold)], dist_validation[str(fold)], dist_test[str(fold)], optimizer)

    train_accuracy = metrics.accuracy_score(train_target, train_out)
    val_accuracy = metrics.accuracy_score(val_target, val_out)
    test_accuracy = metrics.accuracy_score(test_target, test_out)
    Train_accuracy_list.append(train_accuracy)
    Val_accuracy_list.append(val_accuracy)
    Test_accuracy_list.append(test_accuracy)
    Train_loss_list.append(train_loss)
    Val_loss_list.append(val_loss)
    Test_loss_list.append(test_loss)

    if val_accuracy >=best_validation_accuracy:
      best_epoch = epoch
      best_validation_accuracy = val_accuracy
      corresponding_val_out = val_out
      corresponding_test_accuracy = test_accuracy
      corresponding_test_out = test_out
      corresponding_test_prob = test_prob

      print('Save models')
      save_model(model, save_path, 'EV_GCN_'+str(fold))

    print('Train Epoch: ' + str(epoch) + ': train loss : {:.8f}\t train accuracy : {:.8f}\t val accuracy : {:.8f}\t test accuracy : {:.8f}\t'.format(
      train_loss, train_accuracy, val_accuracy, test_accuracy))
  
  if fold == 1:
    all_fold_val_label = val_target
    all_fold_val_out = corresponding_val_out
    all_fold_test_label = test_target
    all_fold_test_out = corresponding_test_out
    all_fold_test_prob = corresponding_test_prob
  else:
    all_fold_val_label = np.concatenate((all_fold_val_label, val_target),axis = 0)
    all_fold_val_out = np.concatenate((all_fold_val_out, corresponding_val_out),axis = 0)
    all_fold_test_label = np.concatenate((all_fold_test_label, test_target),axis = 0)
    all_fold_test_out = np.concatenate((all_fold_test_out, corresponding_test_out),axis = 0)
    all_fold_test_prob = np.concatenate((all_fold_test_prob, corresponding_test_prob),axis = 0)

  x_axis = list(range(1, len(Train_accuracy_list)+1))
  plt.figure(figsize=(10,6))
  plt.plot(x_axis, Train_loss_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_loss_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_loss_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()

  plt.figure(figsize=(10,6))
  plt.plot(x_axis, Train_accuracy_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_accuracy_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_accuracy_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()


  test_fpr, test_tpr, te_thresholds = roc_curve(test_target, corresponding_test_prob[:,1],pos_label=1)
  test_auc = auc(test_fpr, test_tpr)
  print('\n')
  print('In fold ',str(fold))
  print('The best validaiton accuracy is: ',best_validation_accuracy)
  print('Happened at epoch: ',best_epoch)
  print('The corresponding test accuracy', corresponding_test_accuracy)
  print('The corresponding test AUC is: ',test_auc)
  print('\n')


  plt.grid()
  plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
  plt.plot([0,1],[0,1],'g--')
  plt.legend()
  plt.xlabel("False Positive Rate")
  plt.ylabel("True Positive Rate")
  plt.title("Test AUC(ROC curve)")
  plt.grid(color='black', linestyle='-', linewidth=0.5)
  plt.show()

print('Finish 5-fold training')
# Out:
#   + Number of params: 196482
# Save models
# Train Epoch: 1: train loss : 1.08845234	 train accuracy : 0.51076321	 val accuracy : 0.50549451	 test accuracy : 0.45197740
# Save models
# Train Epoch: 2: train loss : 0.92386699	 train accuracy : 0.51076321	 val accuracy : 0.52747253	 test accuracy : 0.50282486
# Train Epoch: 3: train loss : 0.83094168	 train accuracy : 0.56164384	 val accuracy : 0.51098901	 test accuracy : 0.59322034
# Train Epoch: 4: train loss : 0.81287020	 train accuracy : 0.61056751	 val accuracy : 0.51098901	 test accuracy : 0.53672316
# Save models
# Train Epoch: 5: train loss : 0.69085354	 train accuracy : 0.64383562	 val accuracy : 0.59340659	 test accuracy : 0.51977401
# Train Epoch: 6: train loss : 0.68439215	 train accuracy : 0.66144814	 val accuracy : 0.57692308	 test accuracy : 0.55932203
# Train Epoch: 7: train loss : 0.61409158	 train accuracy : 0.69667319	 val accuracy : 0.49450549	 test accuracy : 0.50847458
# Train Epoch: 8: train loss : 0.57400221	 train accuracy : 0.75538160	 val accuracy : 0.53296703	 test accuracy : 0.58757062
# Save models
# Train Epoch: 9: train loss : 0.57940334	 train accuracy : 0.71428571	 val accuracy : 0.63736264	 test accuracy : 0.61581921
# Save models
# Train Epoch: 10: train loss : 0.54638720	 train accuracy : 0.72211350	 val accuracy : 0.67582418	 test accuracy : 0.61581921
# Save models
# Train Epoch: 11: train loss : 0.50119543	 train accuracy : 0.76320939	 val accuracy : 0.68131868	 test accuracy : 0.59322034
# Save models
# Train Epoch: 12: train loss : 0.47691447	 train accuracy : 0.76712329	 val accuracy : 0.70879121	 test accuracy : 0.63841808
# Save models
# Train Epoch: 13: train loss : 0.41009477	 train accuracy : 0.82191781	 val accuracy : 0.71978022	 test accuracy : 0.61581921
# Train Epoch: 14: train loss : 0.37513617	 train accuracy : 0.83953033	 val accuracy : 0.69780220	 test accuracy : 0.62146893
# Save models
# Train Epoch: 15: train loss : 0.34691986	 train accuracy : 0.84931507	 val accuracy : 0.71978022	 test accuracy : 0.62711864
# Save models
# Train Epoch: 16: train loss : 0.30067089	 train accuracy : 0.88062622	 val accuracy : 0.72527473	 test accuracy : 0.63276836
# Save models
# Train Epoch: 17: train loss : 0.29361263	 train accuracy : 0.87279843	 val accuracy : 0.73076923	 test accuracy : 0.65536723
# Save models
# Train Epoch: 18: train loss : 0.25098264	 train accuracy : 0.90998043	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 19: train loss : 0.22240470	 train accuracy : 0.90802348	 val accuracy : 0.72527473	 test accuracy : 0.67796610
# Train Epoch: 20: train loss : 0.18929987	 train accuracy : 0.92563601	 val accuracy : 0.72527473	 test accuracy : 0.66666667
# Train Epoch: 21: train loss : 0.17097937	 train accuracy : 0.94324853	 val accuracy : 0.69780220	 test accuracy : 0.64971751
# Train Epoch: 22: train loss : 0.14160037	 train accuracy : 0.95303327	 val accuracy : 0.70879121	 test accuracy : 0.64406780
# Train Epoch: 23: train loss : 0.11722555	 train accuracy : 0.96086106	 val accuracy : 0.68681319	 test accuracy : 0.68361582
# Train Epoch: 24: train loss : 0.11073776	 train accuracy : 0.96281800	 val accuracy : 0.68681319	 test accuracy : 0.67231638
# Train Epoch: 25: train loss : 0.08251098	 train accuracy : 0.97651663	 val accuracy : 0.70879121	 test accuracy : 0.66101695
# Train Epoch: 26: train loss : 0.06719383	 train accuracy : 0.98238748	 val accuracy : 0.69230769	 test accuracy : 0.67231638
# Train Epoch: 27: train loss : 0.05825680	 train accuracy : 0.98825832	 val accuracy : 0.67032967	 test accuracy : 0.67231638
# Train Epoch: 28: train loss : 0.03901116	 train accuracy : 0.99608611	 val accuracy : 0.67032967	 test accuracy : 0.66666667
# Train Epoch: 29: train loss : 0.03705469	 train accuracy : 0.99217221	 val accuracy : 0.67032967	 test accuracy : 0.67796610
# Train Epoch: 30: train loss : 0.03524795	 train accuracy : 0.99217221	 val accuracy : 0.68681319	 test accuracy : 0.67796610
# Train Epoch: 31: train loss : 0.02343137	 train accuracy : 0.99608611	 val accuracy : 0.70879121	 test accuracy : 0.67231638
# Train Epoch: 32: train loss : 0.01818327	 train accuracy : 0.99412916	 val accuracy : 0.71428571	 test accuracy : 0.67796610
# Train Epoch: 33: train loss : 0.02585469	 train accuracy : 0.99217221	 val accuracy : 0.72527473	 test accuracy : 0.66101695
# Train Epoch: 34: train loss : 0.00838033	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.67231638
# Train Epoch: 35: train loss : 0.00681084	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.66666667
# Train Epoch: 36: train loss : 0.02382326	 train accuracy : 0.99412916	 val accuracy : 0.71978022	 test accuracy : 0.67231638
# Train Epoch: 37: train loss : 0.00965875	 train accuracy : 0.99608611	 val accuracy : 0.71978022	 test accuracy : 0.68361582
# Save models
# Train Epoch: 38: train loss : 0.01320389	 train accuracy : 0.99804305	 val accuracy : 0.74175824	 test accuracy : 0.67231638
# Train Epoch: 39: train loss : 0.00929144	 train accuracy : 0.99804305	 val accuracy : 0.70879121	 test accuracy : 0.67231638
# Train Epoch: 40: train loss : 0.00788761	 train accuracy : 0.99608611	 val accuracy : 0.70329670	 test accuracy : 0.66101695
# Train Epoch: 41: train loss : 0.02055359	 train accuracy : 0.99217221	 val accuracy : 0.70879121	 test accuracy : 0.67231638
# Train Epoch: 42: train loss : 0.00327726	 train accuracy : 1.00000000	 val accuracy : 0.70329670	 test accuracy : 0.69491525
# Train Epoch: 43: train loss : 0.00147145	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.68926554
# Train Epoch: 44: train loss : 0.00375018	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.68926554
# Train Epoch: 45: train loss : 0.00444041	 train accuracy : 1.00000000	 val accuracy : 0.71428571	 test accuracy : 0.69491525
# Train Epoch: 46: train loss : 0.00389262	 train accuracy : 1.00000000	 val accuracy : 0.70329670	 test accuracy : 0.69491525
# Train Epoch: 47: train loss : 0.00492793	 train accuracy : 0.99804305	 val accuracy : 0.69230769	 test accuracy : 0.67231638
# Train Epoch: 48: train loss : 0.00582132	 train accuracy : 0.99804305	 val accuracy : 0.70329670	 test accuracy : 0.66666667
# Train Epoch: 49: train loss : 0.00231425	 train accuracy : 1.00000000	 val accuracy : 0.70879121	 test accuracy : 0.67231638
# Train Epoch: 50: train loss : 0.00373251	 train accuracy : 1.00000000	 val accuracy : 0.70879121	 test accuracy : 0.69491525
# Train Epoch: 51: train loss : 0.00078728	 train accuracy : 1.00000000	 val accuracy : 0.70879121	 test accuracy : 0.69491525
# Train Epoch: 52: train loss : 0.00078990	 train accuracy : 1.00000000	 val accuracy : 0.70879121	 test accuracy : 0.68926554
# Train Epoch: 53: train loss : 0.00152222	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.68926554
# Train Epoch: 54: train loss : 0.00413665	 train accuracy : 0.99804305	 val accuracy : 0.72527473	 test accuracy : 0.68926554
# Train Epoch: 55: train loss : 0.00108121	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.68926554
# Save models
# Train Epoch: 56: train loss : 0.00552796	 train accuracy : 0.99608611	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 57: train loss : 0.00054355	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.67796610
# Train Epoch: 58: train loss : 0.00049204	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.67796610
# Train Epoch: 59: train loss : 0.00057810	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.68926554
# Train Epoch: 60: train loss : 0.00049645	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.68926554
# Train Epoch: 61: train loss : 0.00427622	 train accuracy : 0.99804305	 val accuracy : 0.73626374	 test accuracy : 0.68926554
# Train Epoch: 62: train loss : 0.00097875	 train accuracy : 1.00000000	 val accuracy : 0.73626374	 test accuracy : 0.68926554
# Train Epoch: 63: train loss : 0.00107871	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.69491525
# Save models
# Train Epoch: 64: train loss : 0.00133616	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.68361582
# Train Epoch: 65: train loss : 0.00045510	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.68361582
# Train Epoch: 66: train loss : 0.00054423	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.67796610
# Train Epoch: 67: train loss : 0.00063651	 train accuracy : 1.00000000	 val accuracy : 0.71428571	 test accuracy : 0.67231638
# Train Epoch: 68: train loss : 0.00041403	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.67231638
# Train Epoch: 69: train loss : 0.00033750	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.66101695
# Train Epoch: 70: train loss : 0.00020458	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.66101695
# Train Epoch: 71: train loss : 0.00030765	 train accuracy : 1.00000000	 val accuracy : 0.70329670	 test accuracy : 0.65536723
# Train Epoch: 72: train loss : 0.00025156	 train accuracy : 1.00000000	 val accuracy : 0.70879121	 test accuracy : 0.65536723
# Train Epoch: 73: train loss : 0.00048073	 train accuracy : 1.00000000	 val accuracy : 0.70329670	 test accuracy : 0.64971751
# Train Epoch: 74: train loss : 0.00031369	 train accuracy : 1.00000000	 val accuracy : 0.70329670	 test accuracy : 0.64971751
# Train Epoch: 75: train loss : 0.00023420	 train accuracy : 1.00000000	 val accuracy : 0.70879121	 test accuracy : 0.66101695
# Train Epoch: 76: train loss : 0.00036435	 train accuracy : 1.00000000	 val accuracy : 0.70879121	 test accuracy : 0.66101695
# Train Epoch: 77: train loss : 0.00056346	 train accuracy : 1.00000000	 val accuracy : 0.70879121	 test accuracy : 0.64971751
# Train Epoch: 78: train loss : 0.00059440	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.65536723
# Train Epoch: 79: train loss : 0.00023699	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.65536723
# Train Epoch: 80: train loss : 0.00022637	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.65536723
# Train Epoch: 81: train loss : 0.00032454	 train accuracy : 1.00000000	 val accuracy : 0.73626374	 test accuracy : 0.65536723
# Train Epoch: 82: train loss : 0.00070812	 train accuracy : 1.00000000	 val accuracy : 0.73626374	 test accuracy : 0.66666667
# Train Epoch: 83: train loss : 0.00080938	 train accuracy : 1.00000000	 val accuracy : 0.73626374	 test accuracy : 0.65536723
# Train Epoch: 84: train loss : 0.00016447	 train accuracy : 1.00000000	 val accuracy : 0.73626374	 test accuracy : 0.65536723
# Train Epoch: 85: train loss : 0.00017995	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.66101695
# Save models
# Train Epoch: 86: train loss : 0.00023873	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.66666667
# Train Epoch: 87: train loss : 0.00016492	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67231638
# Train Epoch: 88: train loss : 0.00021562	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 89: train loss : 0.00020972	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 90: train loss : 0.00089384	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 91: train loss : 0.00021589	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 92: train loss : 0.00012516	 train accuracy : 1.00000000	 val accuracy : 0.73626374	 test accuracy : 0.67231638
# Train Epoch: 93: train loss : 0.00016314	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.67231638
# Save models
# Train Epoch: 94: train loss : 0.00018654	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Save models
# Train Epoch: 95: train loss : 0.00017788	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Save models
# Train Epoch: 96: train loss : 0.00014042	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Save models
# Train Epoch: 97: train loss : 0.00052430	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.65536723
# Save models
# Train Epoch: 98: train loss : 0.00014282	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.65536723
# Save models
# Train Epoch: 99: train loss : 0.00009108	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.66101695
# Save models
# Train Epoch: 100: train loss : 0.00011269	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.66101695
# Save models
# Train Epoch: 101: train loss : 0.00012841	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.66101695
# Save models
# Train Epoch: 102: train loss : 0.00016184	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.66101695
# Save models
# Train Epoch: 103: train loss : 0.00012188	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.66666667
# Train Epoch: 104: train loss : 0.00009634	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.66666667
# Train Epoch: 105: train loss : 0.00011000	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 106: train loss : 0.00016775	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Save models
# Train Epoch: 107: train loss : 0.00011643	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.67231638
# Save models
# Train Epoch: 108: train loss : 0.00010263	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.67231638
# Save models
# Train Epoch: 109: train loss : 0.00009238	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.67231638
# Save models
# Train Epoch: 110: train loss : 0.00009447	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.67231638
# Save models
# Train Epoch: 111: train loss : 0.00018262	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.67231638
# Save models
# Train Epoch: 112: train loss : 0.00009960	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.67231638
# Save models
# Train Epoch: 113: train loss : 0.00007814	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.67231638
# Save models
# Train Epoch: 114: train loss : 0.00009234	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.67231638
# Save models
# Train Epoch: 115: train loss : 0.00006942	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.67231638
# Save models
# Train Epoch: 116: train loss : 0.00007675	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.67231638
# Save models
# Train Epoch: 117: train loss : 0.00008738	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.67231638
# Train Epoch: 118: train loss : 0.00014992	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.67231638
# Train Epoch: 119: train loss : 0.00005349	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.67231638
# Train Epoch: 120: train loss : 0.00017503	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.67231638
# Train Epoch: 121: train loss : 0.00006561	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.67231638
# Train Epoch: 122: train loss : 0.00008968	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.67231638
# Train Epoch: 123: train loss : 0.00010227	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.67231638
# Train Epoch: 124: train loss : 0.00006574	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.67231638
# Train Epoch: 125: train loss : 0.00009132	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.67796610
# Train Epoch: 126: train loss : 0.00009463	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.67796610
# Train Epoch: 127: train loss : 0.00008098	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.67796610
# Train Epoch: 128: train loss : 0.00008192	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.67231638
# Save models
# Train Epoch: 129: train loss : 0.00006571	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.67231638
# Save models
# Train Epoch: 130: train loss : 0.00031889	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.67231638
# Save models
# Train Epoch: 131: train loss : 0.00008132	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.67231638
# Save models
# Train Epoch: 132: train loss : 0.00028438	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.67231638
# Save models
# Train Epoch: 133: train loss : 0.00008122	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.67231638
# Save models
# Train Epoch: 134: train loss : 0.00007284	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.67231638
# Save models
# Train Epoch: 135: train loss : 0.00008490	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.67231638
# Save models
# Train Epoch: 136: train loss : 0.00007217	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.66666667
# Save models
# Train Epoch: 137: train loss : 0.00007629	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.66666667
# Save models
# Train Epoch: 138: train loss : 0.00008825	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.66666667
# Save models
# Train Epoch: 139: train loss : 0.00006400	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.66666667
# Save models
# Train Epoch: 140: train loss : 0.00011428	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.66666667
# Save models
# Train Epoch: 141: train loss : 0.00011427	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.66666667
# Save models
# Train Epoch: 142: train loss : 0.00006762	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.66666667
# Save models
# Train Epoch: 143: train loss : 0.00005748	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.66666667
# Save models
# Train Epoch: 144: train loss : 0.00011055	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.66666667
# Train Epoch: 145: train loss : 0.00014008	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.67231638
# Train Epoch: 146: train loss : 0.00006937	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.67231638
# Train Epoch: 147: train loss : 0.00017869	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.67231638
# Train Epoch: 148: train loss : 0.00005642	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 149: train loss : 0.00004393	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 150: train loss : 0.00006144	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 151: train loss : 0.00006187	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.66666667
# Train Epoch: 152: train loss : 0.00031799	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.66666667
# Train Epoch: 153: train loss : 0.00005562	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 154: train loss : 0.00008498	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 155: train loss : 0.00008743	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 156: train loss : 0.00003813	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 157: train loss : 0.00004753	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 158: train loss : 0.00005755	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 159: train loss : 0.00009049	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 160: train loss : 0.00005261	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 161: train loss : 0.00004254	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 162: train loss : 0.00007215	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 163: train loss : 0.00006462	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 164: train loss : 0.00009445	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 165: train loss : 0.00007978	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 166: train loss : 0.00005258	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 167: train loss : 0.00003696	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 168: train loss : 0.00004154	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 169: train loss : 0.00004730	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 170: train loss : 0.00005419	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 171: train loss : 0.00006156	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 172: train loss : 0.00010766	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 173: train loss : 0.00017424	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 174: train loss : 0.00039141	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 175: train loss : 0.00008510	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 176: train loss : 0.00005236	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 177: train loss : 0.00006717	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67231638
# Train Epoch: 178: train loss : 0.00003502	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67796610
# Train Epoch: 179: train loss : 0.00003605	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67796610
# Train Epoch: 180: train loss : 0.00006104	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.67796610
# Train Epoch: 181: train loss : 0.00008992	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.67796610
# Train Epoch: 182: train loss : 0.00006552	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.67796610
# Train Epoch: 183: train loss : 0.00004558	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.67796610
# Train Epoch: 184: train loss : 0.00005318	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.67796610
# Train Epoch: 185: train loss : 0.00006704	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.67796610
# Train Epoch: 186: train loss : 0.00003631	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.67796610
# Train Epoch: 187: train loss : 0.00004602	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.67796610
# Train Epoch: 188: train loss : 0.00006764	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.67796610
# Train Epoch: 189: train loss : 0.00004179	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.67796610
# Train Epoch: 190: train loss : 0.00003920	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.67796610
# Train Epoch: 191: train loss : 0.00004338	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.67796610
# Train Epoch: 192: train loss : 0.00004870	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.67796610
# Train Epoch: 193: train loss : 0.00003181	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.67796610
# Train Epoch: 194: train loss : 0.00004025	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.67796610
# Train Epoch: 195: train loss : 0.00003422	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.67796610
# Train Epoch: 196: train loss : 0.00004054	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.67796610
# Train Epoch: 197: train loss : 0.00004874	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.67796610
# Train Epoch: 198: train loss : 0.00006996	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.67796610
# Train Epoch: 199: train loss : 0.00007457	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.67796610
# Train Epoch: 200: train loss : 0.00003140	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.67796610
# In fold  1
# The best validaiton accuracy is:  0.7582417582417582
# Happened at epoch:  144
# The corresponding test accuracy 0.6666666666666666
# The corresponding test AUC is:  0.7553069053708441
#   + Number of params: 196482
# Save models
# Train Epoch: 1: train loss : 0.96842229	 train accuracy : 0.50674374	 val accuracy : 0.44067797	 test accuracy : 0.51149425
# Save models
# Train Epoch: 2: train loss : 0.88569677	 train accuracy : 0.53564547	 val accuracy : 0.53107345	 test accuracy : 0.55747126
# Save models
# Train Epoch: 3: train loss : 0.74096537	 train accuracy : 0.60500963	 val accuracy : 0.61016949	 test accuracy : 0.51724138
# Save models
# Train Epoch: 4: train loss : 0.55179256	 train accuracy : 0.74181118	 val accuracy : 0.65536723	 test accuracy : 0.54022989
# Train Epoch: 5: train loss : 0.53901845	 train accuracy : 0.79190751	 val accuracy : 0.61581921	 test accuracy : 0.60344828
# Train Epoch: 6: train loss : 0.43039510	 train accuracy : 0.84200385	 val accuracy : 0.55367232	 test accuracy : 0.60344828
# Train Epoch: 7: train loss : 0.37772194	 train accuracy : 0.84971098	 val accuracy : 0.55932203	 test accuracy : 0.63218391
# Train Epoch: 8: train loss : 0.30086660	 train accuracy : 0.87090559	 val accuracy : 0.61016949	 test accuracy : 0.63793103
# Train Epoch: 9: train loss : 0.25027102	 train accuracy : 0.90558767	 val accuracy : 0.62711864	 test accuracy : 0.58620690
# Train Epoch: 10: train loss : 0.20844692	 train accuracy : 0.91522158	 val accuracy : 0.62146893	 test accuracy : 0.60919540
# Train Epoch: 11: train loss : 0.17949590	 train accuracy : 0.94026975	 val accuracy : 0.61016949	 test accuracy : 0.61494253
# Train Epoch: 12: train loss : 0.13853772	 train accuracy : 0.95568401	 val accuracy : 0.61581921	 test accuracy : 0.66666667
# Train Epoch: 13: train loss : 0.12735721	 train accuracy : 0.96339114	 val accuracy : 0.61016949	 test accuracy : 0.66666667
# Train Epoch: 14: train loss : 0.09657048	 train accuracy : 0.96146435	 val accuracy : 0.59322034	 test accuracy : 0.68390805
# Train Epoch: 15: train loss : 0.06278534	 train accuracy : 0.98458574	 val accuracy : 0.59887006	 test accuracy : 0.67241379
# Train Epoch: 16: train loss : 0.05113989	 train accuracy : 0.98265896	 val accuracy : 0.62711864	 test accuracy : 0.67241379
# Train Epoch: 17: train loss : 0.05216642	 train accuracy : 0.98843931	 val accuracy : 0.64971751	 test accuracy : 0.66666667
# Train Epoch: 18: train loss : 0.03103319	 train accuracy : 0.99421965	 val accuracy : 0.64971751	 test accuracy : 0.68390805
# Save models
# Train Epoch: 19: train loss : 0.01609167	 train accuracy : 0.99807322	 val accuracy : 0.65536723	 test accuracy : 0.67816092
# Save models
# Train Epoch: 20: train loss : 0.02187823	 train accuracy : 0.99421965	 val accuracy : 0.65536723	 test accuracy : 0.68390805
# Save models
# Train Epoch: 21: train loss : 0.01189341	 train accuracy : 0.99807322	 val accuracy : 0.65536723	 test accuracy : 0.68965517
# Train Epoch: 22: train loss : 0.01181573	 train accuracy : 0.99807322	 val accuracy : 0.64406780	 test accuracy : 0.68965517
# Train Epoch: 23: train loss : 0.00719726	 train accuracy : 1.00000000	 val accuracy : 0.64406780	 test accuracy : 0.68965517
# Train Epoch: 24: train loss : 0.00744037	 train accuracy : 1.00000000	 val accuracy : 0.63841808	 test accuracy : 0.68965517
# Train Epoch: 25: train loss : 0.00517940	 train accuracy : 1.00000000	 val accuracy : 0.63841808	 test accuracy : 0.69540230
# Train Epoch: 26: train loss : 0.00396982	 train accuracy : 1.00000000	 val accuracy : 0.63841808	 test accuracy : 0.69540230
# Train Epoch: 27: train loss : 0.00220578	 train accuracy : 1.00000000	 val accuracy : 0.64406780	 test accuracy : 0.68390805
# Train Epoch: 28: train loss : 0.00240898	 train accuracy : 1.00000000	 val accuracy : 0.64971751	 test accuracy : 0.67816092
# Train Epoch: 29: train loss : 0.00550712	 train accuracy : 0.99807322	 val accuracy : 0.64406780	 test accuracy : 0.67816092
# Train Epoch: 30: train loss : 0.00183916	 train accuracy : 1.00000000	 val accuracy : 0.64406780	 test accuracy : 0.67816092
# Train Epoch: 31: train loss : 0.00247082	 train accuracy : 1.00000000	 val accuracy : 0.63841808	 test accuracy : 0.67816092
# Train Epoch: 32: train loss : 0.00097760	 train accuracy : 1.00000000	 val accuracy : 0.63841808	 test accuracy : 0.67816092
# Train Epoch: 33: train loss : 0.00127032	 train accuracy : 1.00000000	 val accuracy : 0.63841808	 test accuracy : 0.67816092
# Train Epoch: 34: train loss : 0.00054256	 train accuracy : 1.00000000	 val accuracy : 0.63841808	 test accuracy : 0.67816092
# Train Epoch: 35: train loss : 0.00092052	 train accuracy : 1.00000000	 val accuracy : 0.63841808	 test accuracy : 0.67816092
# Train Epoch: 36: train loss : 0.00121120	 train accuracy : 1.00000000	 val accuracy : 0.63841808	 test accuracy : 0.67816092
# Train Epoch: 37: train loss : 0.00092855	 train accuracy : 1.00000000	 val accuracy : 0.63841808	 test accuracy : 0.67816092
# Train Epoch: 38: train loss : 0.00095710	 train accuracy : 1.00000000	 val accuracy : 0.63841808	 test accuracy : 0.68390805
# Train Epoch: 39: train loss : 0.00043722	 train accuracy : 1.00000000	 val accuracy : 0.63841808	 test accuracy : 0.68390805
# Train Epoch: 40: train loss : 0.00051656	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.67816092
# Train Epoch: 41: train loss : 0.00053564	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.68390805
# Train Epoch: 42: train loss : 0.00020448	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.68965517
# Train Epoch: 43: train loss : 0.00073188	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.69540230
# Train Epoch: 44: train loss : 0.00047004	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.70114943
# Train Epoch: 45: train loss : 0.00267711	 train accuracy : 0.99807322	 val accuracy : 0.62711864	 test accuracy : 0.70114943
# Train Epoch: 46: train loss : 0.00024893	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.70114943
# Train Epoch: 47: train loss : 0.00035437	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.69540230
# Train Epoch: 48: train loss : 0.00023186	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.68965517
# Train Epoch: 49: train loss : 0.00020290	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.68965517
# Train Epoch: 50: train loss : 0.00024332	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.68965517
# Train Epoch: 51: train loss : 0.00356243	 train accuracy : 0.99807322	 val accuracy : 0.62711864	 test accuracy : 0.68390805
# Train Epoch: 52: train loss : 0.00018750	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.68390805
# Train Epoch: 53: train loss : 0.00014254	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.68390805
# Train Epoch: 54: train loss : 0.00018757	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.68965517
# Train Epoch: 55: train loss : 0.00033264	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.68965517
# Train Epoch: 56: train loss : 0.00011258	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.68965517
# Train Epoch: 57: train loss : 0.00015677	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.68965517
# Train Epoch: 58: train loss : 0.00605939	 train accuracy : 0.99807322	 val accuracy : 0.63276836	 test accuracy : 0.67816092
# Train Epoch: 59: train loss : 0.00021933	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.68390805
# Train Epoch: 60: train loss : 0.00031765	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.67816092
# Train Epoch: 61: train loss : 0.00077971	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.67241379
# Train Epoch: 62: train loss : 0.00048690	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.67816092
# Train Epoch: 63: train loss : 0.00061657	 train accuracy : 1.00000000	 val accuracy : 0.63841808	 test accuracy : 0.67816092
# Train Epoch: 64: train loss : 0.00021829	 train accuracy : 1.00000000	 val accuracy : 0.63841808	 test accuracy : 0.67816092
# Train Epoch: 65: train loss : 0.00009875	 train accuracy : 1.00000000	 val accuracy : 0.63841808	 test accuracy : 0.67816092
# Train Epoch: 66: train loss : 0.00077123	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.67816092
# Train Epoch: 67: train loss : 0.00057967	 train accuracy : 1.00000000	 val accuracy : 0.63841808	 test accuracy : 0.67816092
# Train Epoch: 68: train loss : 0.00700740	 train accuracy : 0.99807322	 val accuracy : 0.63841808	 test accuracy : 0.67816092
# Train Epoch: 69: train loss : 0.00008224	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.68390805
# Train Epoch: 70: train loss : 0.00036421	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.68965517
# Train Epoch: 71: train loss : 0.00014002	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.69540230
# Train Epoch: 72: train loss : 0.00015324	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.69540230
# Train Epoch: 73: train loss : 0.00031757	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.70114943
# Train Epoch: 74: train loss : 0.00008900	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.70114943
# Train Epoch: 75: train loss : 0.00024603	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.70114943
# Train Epoch: 76: train loss : 0.00015829	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.70114943
# Train Epoch: 77: train loss : 0.00014712	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.70114943
# Train Epoch: 78: train loss : 0.00085729	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.70114943
# Train Epoch: 79: train loss : 0.00013881	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.69540230
# Train Epoch: 80: train loss : 0.00012846	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.69540230
# Train Epoch: 81: train loss : 0.00008772	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.69540230
# Train Epoch: 82: train loss : 0.00020419	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.69540230
# Train Epoch: 83: train loss : 0.00012478	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.69540230
# Train Epoch: 84: train loss : 0.00021113	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.69540230
# Train Epoch: 85: train loss : 0.00014823	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.69540230
# Train Epoch: 86: train loss : 0.00029203	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.69540230
# Train Epoch: 87: train loss : 0.00014435	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.69540230
# Train Epoch: 88: train loss : 0.00008693	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.69540230
# Train Epoch: 89: train loss : 0.00010506	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.69540230
# Train Epoch: 90: train loss : 0.00012501	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.70114943
# Train Epoch: 91: train loss : 0.00377259	 train accuracy : 0.99807322	 val accuracy : 0.61581921	 test accuracy : 0.68965517
# Train Epoch: 92: train loss : 0.00008645	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.68390805
# Train Epoch: 93: train loss : 0.00026386	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.68390805
# Train Epoch: 94: train loss : 0.00036669	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.66091954
# Train Epoch: 95: train loss : 0.00056289	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.66091954
# Train Epoch: 96: train loss : 0.00013095	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.66091954
# Train Epoch: 97: train loss : 0.00018045	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.66091954
# Train Epoch: 98: train loss : 0.00025857	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.66091954
# Train Epoch: 99: train loss : 0.00013671	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.65517241
# Train Epoch: 100: train loss : 0.00189335	 train accuracy : 0.99807322	 val accuracy : 0.61581921	 test accuracy : 0.66091954
# Train Epoch: 101: train loss : 0.00055304	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.66091954
# Train Epoch: 102: train loss : 0.00091321	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.66091954
# Train Epoch: 103: train loss : 0.00016266	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.67816092
# Train Epoch: 104: train loss : 0.00020442	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.68965517
# Train Epoch: 105: train loss : 0.00012770	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.68965517
# Train Epoch: 106: train loss : 0.00009269	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.68965517
# Train Epoch: 107: train loss : 0.00012546	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.69540230
# Train Epoch: 108: train loss : 0.00007823	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.70689655
# Train Epoch: 109: train loss : 0.00015357	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.70689655
# Train Epoch: 110: train loss : 0.00007326	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.70689655
# Train Epoch: 111: train loss : 0.00052442	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.71264368
# Train Epoch: 112: train loss : 0.00011544	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.71264368
# Train Epoch: 113: train loss : 0.00014110	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.71264368
# Train Epoch: 114: train loss : 0.00018995	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.70689655
# Train Epoch: 115: train loss : 0.00017351	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.70689655
# Train Epoch: 116: train loss : 0.00029897	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.70689655
# Train Epoch: 117: train loss : 0.00041182	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.70689655
# Train Epoch: 118: train loss : 0.00007547	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.70689655
# Train Epoch: 119: train loss : 0.00015382	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.70689655
# Train Epoch: 120: train loss : 0.00010215	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.71264368
# Train Epoch: 121: train loss : 0.00007267	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.70689655
# Train Epoch: 122: train loss : 0.00028439	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.70689655
# Train Epoch: 123: train loss : 0.00017834	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.70689655
# Train Epoch: 124: train loss : 0.00015683	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.70114943
# Train Epoch: 125: train loss : 0.00028419	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.70114943
# Train Epoch: 126: train loss : 0.00018152	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.70114943
# Train Epoch: 127: train loss : 0.00019221	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.70114943
# Train Epoch: 128: train loss : 0.00034166	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.70114943
# Train Epoch: 129: train loss : 0.00006236	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.70114943
# Train Epoch: 130: train loss : 0.00005620	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.70689655
# Train Epoch: 131: train loss : 0.00007025	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.70689655
# Train Epoch: 132: train loss : 0.00004196	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.70114943
# Train Epoch: 133: train loss : 0.00012685	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.69540230
# Train Epoch: 134: train loss : 0.00005130	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.69540230
# Train Epoch: 135: train loss : 0.00012438	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.69540230
# Train Epoch: 136: train loss : 0.00004014	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.69540230
# Train Epoch: 137: train loss : 0.00004543	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.69540230
# Train Epoch: 138: train loss : 0.00006194	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.69540230
# Train Epoch: 139: train loss : 0.00007493	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.68965517
# Train Epoch: 140: train loss : 0.00007536	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.68965517
# Train Epoch: 141: train loss : 0.00008236	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.68965517
# Train Epoch: 142: train loss : 0.00005191	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.68965517
# Train Epoch: 143: train loss : 0.00005770	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.68965517
# Train Epoch: 144: train loss : 0.00006335	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.68965517
# Train Epoch: 145: train loss : 0.00011074	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.68965517
# Train Epoch: 146: train loss : 0.00009389	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.68965517
# Train Epoch: 147: train loss : 0.00005681	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.68965517
# Train Epoch: 148: train loss : 0.00013752	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.68965517
# Train Epoch: 149: train loss : 0.00010098	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.68965517
# Train Epoch: 150: train loss : 0.00007053	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.68965517
# Train Epoch: 151: train loss : 0.00005049	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.68965517
# Train Epoch: 152: train loss : 0.00009621	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.68965517
# Train Epoch: 153: train loss : 0.00005192	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.68965517
# Train Epoch: 154: train loss : 0.00004910	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.68965517
# Train Epoch: 155: train loss : 0.00006186	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.68965517
# Train Epoch: 156: train loss : 0.00008107	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.68965517
# Train Epoch: 157: train loss : 0.00010727	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.68965517
# Train Epoch: 158: train loss : 0.00037522	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.68965517
# Train Epoch: 159: train loss : 0.00006981	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.68965517
# Train Epoch: 160: train loss : 0.00015039	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.69540230
# Train Epoch: 161: train loss : 0.00008647	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.70114943
# Train Epoch: 162: train loss : 0.00004282	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.70114943
# Train Epoch: 163: train loss : 0.00007468	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.70689655
# Train Epoch: 164: train loss : 0.00010356	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.70689655
# Train Epoch: 165: train loss : 0.00013869	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.70689655
# Train Epoch: 166: train loss : 0.00003598	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.70689655
# Train Epoch: 167: train loss : 0.00004239	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.70689655
# Train Epoch: 168: train loss : 0.00002913	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.70689655
# Train Epoch: 169: train loss : 0.00003417	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.70689655
# Train Epoch: 170: train loss : 0.00003703	 train accuracy : 1.00000000	 val accuracy : 0.62711864	 test accuracy : 0.70689655
# Train Epoch: 171: train loss : 0.00003460	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.70689655
# Train Epoch: 172: train loss : 0.00005454	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.70689655
# ...
# Train Epoch: 84: train loss : 0.00060873	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.66483516
# Train Epoch: 85: train loss : 0.00015818	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.67032967
# Train Epoch: 86: train loss : 0.00062379	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.64285714
# Train Epoch: 87: train loss : 0.00027784	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.65384615
# Train Epoch: 88: train loss : 0.00191585	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.64835165
# Train Epoch: 89: train loss : 0.00231335	 train accuracy : 0.99808061	 val accuracy : 0.68862275	 test accuracy : 0.64835165
# Train Epoch: 90: train loss : 0.00022017	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.65384615
# Train Epoch: 91: train loss : 0.00016335	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.66483516
# Save models
# Train Epoch: 92: train loss : 0.00034452	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.66483516
# Train Epoch: 93: train loss : 0.00012063	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.66483516
# Train Epoch: 94: train loss : 0.00011037	 train accuracy : 1.00000000	 val accuracy : 0.67065868	 test accuracy : 0.65934066
# Train Epoch: 95: train loss : 0.00009703	 train accuracy : 1.00000000	 val accuracy : 0.65868263	 test accuracy : 0.64835165
# Train Epoch: 96: train loss : 0.00029117	 train accuracy : 1.00000000	 val accuracy : 0.67065868	 test accuracy : 0.64835165
# Train Epoch: 97: train loss : 0.00017605	 train accuracy : 1.00000000	 val accuracy : 0.67065868	 test accuracy : 0.65934066
# Train Epoch: 98: train loss : 0.00013697	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.65934066
# Train Epoch: 99: train loss : 0.00059120	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.65934066
# Train Epoch: 100: train loss : 0.00034659	 train accuracy : 1.00000000	 val accuracy : 0.67065868	 test accuracy : 0.65934066
# Train Epoch: 101: train loss : 0.00020246	 train accuracy : 1.00000000	 val accuracy : 0.67065868	 test accuracy : 0.63736264
# Train Epoch: 102: train loss : 0.00012869	 train accuracy : 1.00000000	 val accuracy : 0.66467066	 test accuracy : 0.64285714
# Train Epoch: 103: train loss : 0.00034896	 train accuracy : 1.00000000	 val accuracy : 0.65868263	 test accuracy : 0.64835165
# Train Epoch: 104: train loss : 0.00009641	 train accuracy : 1.00000000	 val accuracy : 0.67065868	 test accuracy : 0.65384615
# Train Epoch: 105: train loss : 0.00016123	 train accuracy : 1.00000000	 val accuracy : 0.67065868	 test accuracy : 0.65934066
# Train Epoch: 106: train loss : 0.00075983	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.65934066
# Train Epoch: 107: train loss : 0.00007732	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.67032967
# Train Epoch: 108: train loss : 0.00007899	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.65934066
# Train Epoch: 109: train loss : 0.00013558	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.66483516
# Train Epoch: 110: train loss : 0.00006596	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.66483516
# Save models
# Train Epoch: 111: train loss : 0.00011128	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.66483516
# Save models
# Train Epoch: 112: train loss : 0.00005628	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.66483516
# Save models
# Train Epoch: 113: train loss : 0.00008603	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.66483516
# Save models
# Train Epoch: 114: train loss : 0.00012241	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65934066
# Save models
# Train Epoch: 115: train loss : 0.00008660	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65934066
# Save models
# Train Epoch: 116: train loss : 0.00015403	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65934066
# Save models
# Train Epoch: 117: train loss : 0.00010952	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65934066
# Save models
# Train Epoch: 118: train loss : 0.00018679	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.64835165
# Save models
# Train Epoch: 119: train loss : 0.00010109	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.64285714
# Save models
# Train Epoch: 120: train loss : 0.00010533	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.64285714
# Save models
# Train Epoch: 121: train loss : 0.00011952	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.64285714
# Save models
# Train Epoch: 122: train loss : 0.00011934	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.64285714
# Train Epoch: 123: train loss : 0.00033152	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.64285714
# Train Epoch: 124: train loss : 0.00008243	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.64285714
# Train Epoch: 125: train loss : 0.00014764	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.64285714
# Save models
# Train Epoch: 126: train loss : 0.00025864	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.64835165
# Save models
# Train Epoch: 127: train loss : 0.00009761	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.64835165
# Save models
# Train Epoch: 128: train loss : 0.00007359	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 129: train loss : 0.00009407	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 130: train loss : 0.00012045	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 131: train loss : 0.00007920	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 132: train loss : 0.00007344	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 133: train loss : 0.00006939	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 134: train loss : 0.00008965	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 135: train loss : 0.00008229	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 136: train loss : 0.00009902	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 137: train loss : 0.00007892	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65934066
# Save models
# Train Epoch: 138: train loss : 0.00006633	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65934066
# Save models
# Train Epoch: 139: train loss : 0.00010507	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.66483516
# Save models
# Train Epoch: 140: train loss : 0.00007262	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.66483516
# Save models
# Train Epoch: 141: train loss : 0.00005334	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.66483516
# Save models
# Train Epoch: 142: train loss : 0.00006901	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.66483516
# Save models
# Train Epoch: 143: train loss : 0.00022104	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.66483516
# Save models
# Train Epoch: 144: train loss : 0.00009272	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.66483516
# Save models
# Train Epoch: 145: train loss : 0.00011922	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65934066
# Save models
# Train Epoch: 146: train loss : 0.00005122	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65934066
# Save models
# Train Epoch: 147: train loss : 0.00008970	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65934066
# Save models
# Train Epoch: 148: train loss : 0.00006596	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65934066
# Save models
# Train Epoch: 149: train loss : 0.00005200	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 150: train loss : 0.00007605	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 151: train loss : 0.00006198	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 152: train loss : 0.00004548	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 153: train loss : 0.00008040	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 154: train loss : 0.00007536	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 155: train loss : 0.00018301	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 156: train loss : 0.00007156	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 157: train loss : 0.00004930	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 158: train loss : 0.00007529	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 159: train loss : 0.00005878	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 160: train loss : 0.00007990	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 161: train loss : 0.00004360	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 162: train loss : 0.00006246	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 163: train loss : 0.00004522	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 164: train loss : 0.00009678	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 165: train loss : 0.00011252	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 166: train loss : 0.00016446	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 167: train loss : 0.00007977	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 168: train loss : 0.00007274	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 169: train loss : 0.00004572	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 170: train loss : 0.00008464	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 171: train loss : 0.00007227	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 172: train loss : 0.00004552	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 173: train loss : 0.00007196	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 174: train loss : 0.00006509	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 175: train loss : 0.00005851	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 176: train loss : 0.00006096	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 177: train loss : 0.00004503	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 178: train loss : 0.00005235	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 179: train loss : 0.00005980	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 180: train loss : 0.00006480	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 181: train loss : 0.00004507	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 182: train loss : 0.00005970	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 183: train loss : 0.00004406	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Save models
# Train Epoch: 184: train loss : 0.00006711	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Train Epoch: 185: train loss : 0.00006872	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.65384615
# Train Epoch: 186: train loss : 0.00005642	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.65384615
# Train Epoch: 187: train loss : 0.00011895	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.65384615
# Train Epoch: 188: train loss : 0.00005280	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.65384615
# Train Epoch: 189: train loss : 0.00008873	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.65384615
# Train Epoch: 190: train loss : 0.00003438	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.65384615
# Train Epoch: 191: train loss : 0.00003109	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.65384615
# Train Epoch: 192: train loss : 0.00014505	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.65384615
# Train Epoch: 193: train loss : 0.00004087	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.65384615
# Train Epoch: 194: train loss : 0.00005089	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.64835165
# Train Epoch: 195: train loss : 0.00006990	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.64835165
# Train Epoch: 196: train loss : 0.00008600	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.64835165
# Train Epoch: 197: train loss : 0.00007246	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.64835165
# Train Epoch: 198: train loss : 0.00005073	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.64835165
# Train Epoch: 199: train loss : 0.00007329	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.64835165
# Train Epoch: 200: train loss : 0.00004240	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.65384615
# In fold  5
# The best validaiton accuracy is:  0.6946107784431138
# Happened at epoch:  184
# The corresponding test accuracy 0.6538461538461539
# The corresponding test AUC is:  0.7229893410852714
# Finish 5-fold training

# %%
val_accuracy = metrics.accuracy_score(all_fold_val_label, all_fold_val_out)
test_accuracy = metrics.accuracy_score(all_fold_test_label, all_fold_test_out)
test_fpr, test_tpr, te_thresholds = roc_curve(all_fold_test_label, all_fold_test_prob[:,1],pos_label=1)
test_auc = auc(test_fpr, test_tpr)
print('The best validation accuracy is ',val_accuracy)
print('The corresponding test accuracy is ',test_accuracy)
print('The corresponding test AUC is: ',test_auc)
plt.grid()
plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
plt.plot([0,1],[0,1],'g--')
plt.legend()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Test AUC(ROC curve)")
plt.grid(color='black', linestyle='-', linewidth=0.5)
plt.show()
# Out:
# The best validation accuracy is  0.7160919540229885
# The corresponding test accuracy is  0.664367816091954
# The corresponding test AUC is:  0.7236066758412549

# %%
torch.cuda.empty_cache()
torch.manual_seed(args.seed)
if args.cuda:
    torch.cuda.manual_seed(args.seed)
############################################### Max voting ###############################################################
############################################### Max voting ###############################################################
############################################### Max voting ###############################################################
dist_ensemble_val_label = {}
dist_ensemble_val_result = {}
dist_ensemble_test_label = {}
dist_ensemble_test_result = {}
dist_ensemble_test_prob = {}

for ensemble_fold in range(5):
  print('Ensemble ',ensemble_fold+1)
  save_ensemble_models_path = save_path + 'Max_voting/EV_GCN/'
  dist_train = {}
  dist_validation = {}
  dist_test = {}
  for i in range(k_fold):
    dist_train[str(i + 1)] = []
    dist_validation[str(i + 1)] = []
    dist_test[str(i + 1)] = []
  test_name = {}
  for i in range(len(unique_sites)):
    test_name[unique_sites[i]] = []
  for each_site in unique_sites:
    index_site = get_index(sites, each_site)
    label = np.zeros((len(index_site)))
    for i in range(len(index_site)):
      index = index_site[i]
      label[i] = int(labels[int(index)])
    test_name_list = test_name[each_site]
    ########################################### StratifiedKFold ####################################################
    sfolder = StratifiedKFold(n_splits=k_fold,random_state=0,shuffle=True)
    group = 0
    for train, validation in sfolder.split(index_site,label):
      if group == ensemble_fold:
        for j in validation:
          name = index_site[j]
          dist_test['1'].append(name)
          dist_test['2'].append(name)
          dist_test['3'].append(name)
          dist_test['4'].append(name)
          dist_test['5'].append(name)
          test_name_list.append(name)
      group = group + 1
    test_name[each_site] = test_name_list

  for each_site in unique_sites:
    if ensemble_fold == 0:

      index_site = get_index(sites, each_site)
      label = np.zeros((len(index_site)))
      for i in range(len(index_site)):
        index = index_site[i]
        label[i] = int(labels[int(index)])
      test_name_list = test_name[each_site]
      index_site_new = []
      label_new = np.zeros((len(index_site) - len(test_name_list)))
      position = 0
      for x in range(len(index_site)):
        sample_name = index_site[x]
        if sample_name in test_name_list:
          c=0
        else:
          index_site_new.append(sample_name)
          label_new[position] = label[x]
          position = position + 1
      if each_site == 'CMU':  # ONLY 4 AUTISM SAMPLES AND 4 TD SAMPLES, CAN NOT BE DEVIDED INTO 5 GROUPS
        group_autism_val = []
        group_autism_train = []
        group_TD_val = []
        group_TD_train = []
        autism_validation_number = len(label_new[label_new ==1])/4
        TD_validation_number = len(label_new[label_new ==0]) / 4
        for j in range(len(label_new)):
          if label_new[j] == 1:
            if len(group_autism_val)<autism_validation_number:
              group_autism_val.append(index_site_new[j])
            else:
              group_autism_train.append(index_site_new[j])
          else:
            if len(group_TD_val)<TD_validation_number:
              group_TD_val.append(index_site_new[j])
            else:
              group_TD_train.append(index_site_new[j])

        dist_validation['1'] = dist_validation['1'] + group_autism_val + group_TD_val
        dist_validation['2'] = dist_validation['2'] + group_autism_val + group_TD_val
        dist_validation['3'] = dist_validation['3'] + group_autism_val + group_TD_val
        dist_validation['4'] = dist_validation['4'] + group_autism_val + group_TD_val
        dist_validation['5'] = dist_validation['5'] + group_autism_val + group_TD_val
        dist_train['1'] = dist_train['1'] + group_autism_train + group_TD_train
        dist_train['2'] = dist_train['2'] + group_autism_train + group_TD_train
        dist_train['3'] = dist_train['3'] + group_autism_train + group_TD_train
        dist_train['4'] = dist_train['4'] + group_autism_train + group_TD_train
        dist_train['5'] = dist_train['5'] + group_autism_train + group_TD_train
      else:
        ########################################### StratifiedKFold ####################################################
        sfolder = StratifiedKFold(n_splits=k_fold, random_state=0, shuffle=True)
        group = 0
        for train, validation in sfolder.split(index_site_new, label_new):

          for i in train:
            name = index_site_new[i]
            dist_train[str(group + 1)].append(name)
          for j in validation:
            name = index_site_new[j]
            dist_validation[str(group + 1)].append(name)
          group = group + 1
    else:

      index_site = get_index(sites, each_site)
      label = np.zeros((len(index_site)))
      for i in range(len(index_site)):
        index = index_site[i]
        label[i] = int(labels[int(index)])
      test_name_list = test_name[each_site]
      index_site_new = []
      label_new = np.zeros((len(index_site) - len(test_name_list)))
      position = 0
      for x in range(len(index_site)):
        sample_name = index_site[x]
        if sample_name in test_name_list:
          c=0
        else:
          index_site_new.append(sample_name)
          label_new[position] = label[x]
          position = position + 1
      ########################################### StratifiedKFold ####################################################
      sfolder = StratifiedKFold(n_splits=k_fold,random_state=0,shuffle=True)
      group = 0
      for train, validation in sfolder.split(index_site_new,label_new):

        for i in train:
          name = index_site_new[i]
          dist_train[str(group + 1)].append(name)
        for j in validation:
          name = index_site_new[j]
          dist_validation[str(group + 1)].append(name)
        group = group+1
  
  
  data = {}

  for fold in range(1, k_fold+1):
    data[str(fold)] = []
    selector = feature_selection(fMRI_images, labels, dist_train[str(fold)], new_number_features)
    fold_data = selector.transform(fMRI_images)
    n = fold_data.shape[0]
    num_edge = n * n
    edge_index = np.zeros([2, num_edge], dtype=np.int64)
    edgenet_input = np.zeros([num_edge, 2*phonetic_data.shape[1]], dtype=np.float32)  
    aff_score = np.zeros(num_edge, dtype=np.float32)

    aff_adj = get_static_affinity_adj(fold_data, pd_dict)  

    flatten_ind = 0
    for i in range(n): 
      for j in range(n):
        edge_index[:, flatten_ind] = [i, j]
        edgenet_input[flatten_ind] = np.concatenate((phonetic_data[i], phonetic_data[j]))
        aff_score[flatten_ind] = aff_adj[i][j]
        flatten_ind += 1


    keep_ind = np.where(aff_score > 1.1)[0]
    edge_index = edge_index[:, keep_ind]
    edgenet_input = edgenet_input[keep_ind]
    edgenet_input = (edgenet_input- edgenet_input.mean(axis=0)) / edgenet_input.std(axis=0)

    data[str(fold)].append(fold_data)
    data[str(fold)].append(EV_GCN_labels)
    data[str(fold)].append(edge_index)
    data[str(fold)].append(edgenet_input)




  ############################################### Train ###############################################################
  ############################################### Train ###############################################################
  ############################################### Train ###############################################################

  model_1 = EV_GCN(args.input_dimension, args.num_classes, args.dropout, edge_dropout=args.edropout, hgc=args.hgc, lg=args.lg, edgenet_input_dim=2*phonetic_data.shape[1])
  model_2 = EV_GCN(args.input_dimension, args.num_classes, args.dropout, edge_dropout=args.edropout, hgc=args.hgc, lg=args.lg, edgenet_input_dim=2*phonetic_data.shape[1])
  model_3 = EV_GCN(args.input_dimension, args.num_classes, args.dropout, edge_dropout=args.edropout, hgc=args.hgc, lg=args.lg, edgenet_input_dim=2*phonetic_data.shape[1])
  model_4 = EV_GCN(args.input_dimension, args.num_classes, args.dropout, edge_dropout=args.edropout, hgc=args.hgc, lg=args.lg, edgenet_input_dim=2*phonetic_data.shape[1])
  model_5 = EV_GCN(args.input_dimension, args.num_classes, args.dropout, edge_dropout=args.edropout, hgc=args.hgc, lg=args.lg, edgenet_input_dim=2*phonetic_data.shape[1])

  gpu_ids = range(args.ngpu)
  model_1 = nn.parallel.DataParallel(model_1, device_ids=gpu_ids)
  model_2 = nn.parallel.DataParallel(model_2, device_ids=gpu_ids)
  model_3 = nn.parallel.DataParallel(model_3, device_ids=gpu_ids)
  model_4 = nn.parallel.DataParallel(model_4, device_ids=gpu_ids)
  model_5 = nn.parallel.DataParallel(model_5, device_ids=gpu_ids)
  train = train_EV_GCN

  print('  + Number of params: {}'.format(
      sum([p.data.nelement() for p in model_1.parameters()])))
  if args.cuda:
      model_1 = model_1.cuda()
      model_2 = model_2.cuda()
      model_3 = model_3.cuda()
      model_4 = model_4.cuda()
      model_5 = model_5.cuda()

  optimizer_1 = optim.Adam(model_1.parameters(), lr = args.lr, weight_decay=args.wd)
  optimizer_2 = optim.Adam(model_2.parameters(), lr = args.lr, weight_decay=args.wd)
  optimizer_3 = optim.Adam(model_3.parameters(), lr = args.lr, weight_decay=args.wd)
  optimizer_4 = optim.Adam(model_4.parameters(), lr = args.lr, weight_decay=args.wd)
  optimizer_5 = optim.Adam(model_5.parameters(), lr = args.lr, weight_decay=args.wd)

  Train_accuracy_list =[]
  Train_loss_list = []
  Val_accuracy_list =[]
  Val_loss_list = []
  Test_accuracy_list =[]
  Test_loss_list = []
  best_validation_accuracy = 0

  for epoch in range(1, args.nEpochs + 1):


    model_1, train_target_1, train_out_1, train_loss_1, val_target_1, val_out_1, val_loss_1, test_target_1, test_out_1, test_prob_1, test_loss_1 = train(args, model_1, data['1'], dist_train['1'], dist_validation['1'], dist_test['1'], optimizer_1)
    model_2, train_target_2, train_out_2, train_loss_2, val_target_2, val_out_2, val_loss_2, test_target_2, test_out_2, test_prob_2, test_loss_2 = train(args, model_2, data['2'], dist_train['2'], dist_validation['2'], dist_test['2'], optimizer_2)
    model_3, train_target_3, train_out_3, train_loss_3, val_target_3, val_out_3, val_loss_3, test_target_3, test_out_3, test_prob_3, test_loss_3 = train(args, model_3, data['3'], dist_train['3'], dist_validation['3'], dist_test['3'], optimizer_3)
    model_4, train_target_4, train_out_4, train_loss_4, val_target_4, val_out_4, val_loss_4, test_target_4, test_out_4, test_prob_4, test_loss_4 = train(args, model_4, data['4'], dist_train['4'], dist_validation['4'], dist_test['4'], optimizer_4)
    model_5, train_target_5, train_out_5, train_loss_5, val_target_5, val_out_5, val_loss_5, test_target_5, test_out_5, test_prob_5, test_loss_5 = train(args, model_5, data['5'], dist_train['5'], dist_validation['5'], dist_test['5'], optimizer_5)

    train_target_all = np.concatenate((train_target_1, train_target_2, train_target_3, train_target_4, train_target_5),axis = 0)
    train_out_all = np.concatenate((train_out_1, train_out_2, train_out_3, train_out_4, train_out_5),axis = 0)
    train_loss = (train_loss_1 + train_loss_2 + train_loss_3 + train_loss_4 + train_loss_5)/5
    val_target_all = np.concatenate((val_target_1, val_target_2, val_target_3, val_target_4, val_target_5),axis = 0)
    val_out_all = np.concatenate((val_out_1, val_out_2, val_out_3, val_out_4, val_out_5),axis = 0)
    val_loss = (val_loss_1 + val_loss_2 + val_loss_3 + val_loss_4 + val_loss_5)/5
    test_target_all = test_target_1 # test_target_1 = test_target_2 = test_target_3 = test_target_4 = test_target_5
    test_out_all = test_out_1 + test_out_2 + test_out_3 + test_out_4 + test_out_5
    test_prob_all = (test_prob_1 + test_prob_2 + test_prob_3 + test_prob_4 + test_prob_5)/5
    test_loss = (test_loss_1 + test_loss_2 + test_loss_3 + test_loss_4 + test_loss_5)/5

    test_results_binary = np.zeros_like((test_out_all))
    test_results_binary[test_out_all<2.5] = 0
    test_results_binary[test_out_all>=2.5] = 1

    train_accuracy = metrics.accuracy_score(train_target_all, train_out_all)
    val_accuracy = metrics.accuracy_score(val_target_all, val_out_all)
    test_accuracy = metrics.accuracy_score(test_target_all, test_results_binary)
    Train_accuracy_list.append(train_accuracy)
    Val_accuracy_list.append(val_accuracy)
    Test_accuracy_list.append(test_accuracy)
    Train_loss_list.append(train_loss)
    Val_loss_list.append(val_loss)
    Test_loss_list.append(test_loss)

    if val_accuracy >=best_validation_accuracy:
      best_epoch = epoch
      best_validation_accuracy = val_accuracy
      corresponding_test_accuracy = test_accuracy
      corresponding_test_prob = test_prob_all
      corresponding_test_labels = test_target_all
      corresponding_test_out = test_results_binary
      print('Save models')

      save_model(model_1, save_ensemble_models_path, 'EV_GCN_ensemble' + str(ensemble_fold) + '_1')
      save_model(model_2, save_ensemble_models_path, 'EV_GCN_ensemble' + str(ensemble_fold) + '_2')
      save_model(model_3, save_ensemble_models_path, 'EV_GCN_ensemble' + str(ensemble_fold) + '_3')
      save_model(model_4, save_ensemble_models_path, 'EV_GCN_ensemble' + str(ensemble_fold) + '_4')
      save_model(model_5, save_ensemble_models_path, 'EV_GCN_ensemble' + str(ensemble_fold) + '_5')

    print('Train Epoch: ' + str(epoch) + ': train loss : {:.8f}\t train accuracy : {:.8f}\t val accuracy : {:.8f}\t test accuracy : {:.8f}\t'.format(
      train_loss, train_accuracy, val_accuracy, test_accuracy))

  x_axis = list(range(1, len(Train_accuracy_list)+1))
  plt.figure(figsize=(15,10))
  plt.plot(x_axis, Train_loss_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_loss_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_loss_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()

  plt.figure(figsize=(15,10))
  plt.plot(x_axis, Train_accuracy_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_accuracy_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_accuracy_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()
 
  test_fpr, test_tpr, te_thresholds = roc_curve(corresponding_test_labels, corresponding_test_prob[:,1],pos_label=1)
  test_auc = auc(test_fpr, test_tpr)
  print('\n')
  print('In ensemble ',ensemble_fold+1)
  print('The best validaiton accuracy is: ',best_validation_accuracy)
  print('Happened at epoch: ',best_epoch)
  print('The corresponding test accuracy', corresponding_test_accuracy)
  print('The corresponding test AUC is: ',test_auc)
  print('\n')


  plt.grid()
  plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
  plt.plot([0,1],[0,1],'g--')
  plt.legend()
  plt.xlabel("False Positive Rate")
  plt.ylabel("True Positive Rate")
  plt.title("Test AUC(ROC curve)")
  plt.grid(color='black', linestyle='-', linewidth=0.5)
  plt.show()


  dist_ensemble_test_label[str(ensemble_fold+1)] = corresponding_test_labels
  dist_ensemble_test_result[str(ensemble_fold+1)] = corresponding_test_out
  dist_ensemble_test_prob[str(ensemble_fold+1)] = corresponding_test_prob
  print('\n')

  torch.cuda.empty_cache()

test_labels_concat = np.concatenate((dist_ensemble_test_label['1'], dist_ensemble_test_label['2'],  dist_ensemble_test_label['3'], dist_ensemble_test_label['4'], dist_ensemble_test_label['5']),axis = 0)
test_results_concat = np.concatenate((dist_ensemble_test_result['1'], dist_ensemble_test_result['2'],  dist_ensemble_test_result['3'], dist_ensemble_test_result['4'], dist_ensemble_test_result['5']),axis = 0)
test_probs_concat = np.concatenate((dist_ensemble_test_prob['1'], dist_ensemble_test_prob['2'],  dist_ensemble_test_prob['3'], dist_ensemble_test_prob['4'], dist_ensemble_test_prob['5']),axis = 0)

test_accuracy = metrics.accuracy_score(test_labels_concat, test_results_concat)
test_fpr, test_tpr, te_thresholds = roc_curve(test_labels_concat, test_probs_concat[:,1],pos_label=1)
test_auc = auc(test_fpr, test_tpr)
print('The Max voting test accuracy is: ',test_accuracy)
print('The test AUC is: ',test_auc)

print('\n')
print('\n')
plt.grid()
plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
plt.plot([0,1],[0,1],'g--')
plt.legend()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Test AUC(ROC curve)")
plt.grid(color='black', linestyle='-', linewidth=0.5)
plt.show()
# Out:
# Ensemble  1
# Fitting estimator with 19900 features.
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
#   + Number of params: 196482
# Save models
# Train Epoch: 1: train loss : 0.98516988	 train accuracy : 0.51672727	 val accuracy : 0.54057971	 test accuracy : 0.56043956
# Train Epoch: 2: train loss : 0.91266404	 train accuracy : 0.51745455	 val accuracy : 0.50869565	 test accuracy : 0.52747253
# Train Epoch: 3: train loss : 0.90492278	 train accuracy : 0.55272727	 val accuracy : 0.52463768	 test accuracy : 0.53846154
# Save models
# Train Epoch: 4: train loss : 0.74204564	 train accuracy : 0.63818182	 val accuracy : 0.54927536	 test accuracy : 0.62087912
# Save models
# Train Epoch: 5: train loss : 0.69055632	 train accuracy : 0.67418182	 val accuracy : 0.55942029	 test accuracy : 0.62637363
# Train Epoch: 6: train loss : 0.58355001	 train accuracy : 0.72000000	 val accuracy : 0.55652174	 test accuracy : 0.64285714
# Save models
# Train Epoch: 7: train loss : 0.56503291	 train accuracy : 0.73200000	 val accuracy : 0.58695652	 test accuracy : 0.66483516
# Train Epoch: 8: train loss : 0.50342238	 train accuracy : 0.76109091	 val accuracy : 0.58405797	 test accuracy : 0.71428571
# Save models
# Train Epoch: 9: train loss : 0.43604152	 train accuracy : 0.80654545	 val accuracy : 0.59130435	 test accuracy : 0.70329670
# Save models
# Train Epoch: 10: train loss : 0.40085644	 train accuracy : 0.82400000	 val accuracy : 0.59130435	 test accuracy : 0.73076923
# Save models
# Train Epoch: 11: train loss : 0.36677337	 train accuracy : 0.84763636	 val accuracy : 0.60144928	 test accuracy : 0.70879121
# Save models
# Train Epoch: 12: train loss : 0.32599629	 train accuracy : 0.86800000	 val accuracy : 0.62028986	 test accuracy : 0.69780220
# Save models
# Train Epoch: 13: train loss : 0.28259287	 train accuracy : 0.88872727	 val accuracy : 0.63188406	 test accuracy : 0.71428571
# Save models
# Train Epoch: 14: train loss : 0.26740441	 train accuracy : 0.89272727	 val accuracy : 0.63623188	 test accuracy : 0.74175824
# Train Epoch: 15: train loss : 0.22835079	 train accuracy : 0.91454545	 val accuracy : 0.62898551	 test accuracy : 0.75824176
# Save models
# Train Epoch: 16: train loss : 0.20033778	 train accuracy : 0.92727273	 val accuracy : 0.64202899	 test accuracy : 0.73626374
# Train Epoch: 17: train loss : 0.17509942	 train accuracy : 0.93963636	 val accuracy : 0.63623188	 test accuracy : 0.72527473
# Save models
# Train Epoch: 18: train loss : 0.14696169	 train accuracy : 0.95127273	 val accuracy : 0.64492754	 test accuracy : 0.73076923
# Train Epoch: 19: train loss : 0.12701204	 train accuracy : 0.95709091	 val accuracy : 0.63043478	 test accuracy : 0.74725275
# Train Epoch: 20: train loss : 0.11393732	 train accuracy : 0.96218182	 val accuracy : 0.63623188	 test accuracy : 0.74725275
# Train Epoch: 21: train loss : 0.09516274	 train accuracy : 0.96690909	 val accuracy : 0.64202899	 test accuracy : 0.71428571
# Train Epoch: 22: train loss : 0.07512511	 train accuracy : 0.97563636	 val accuracy : 0.64347826	 test accuracy : 0.73076923
# Train Epoch: 23: train loss : 0.06276512	 train accuracy : 0.98327273	 val accuracy : 0.64347826	 test accuracy : 0.73076923
# Train Epoch: 24: train loss : 0.05474022	 train accuracy : 0.98363636	 val accuracy : 0.64057971	 test accuracy : 0.73076923
# Train Epoch: 25: train loss : 0.04586921	 train accuracy : 0.98763636	 val accuracy : 0.63623188	 test accuracy : 0.71978022
# Train Epoch: 26: train loss : 0.03470510	 train accuracy : 0.99309091	 val accuracy : 0.63913043	 test accuracy : 0.69780220
# Save models
# Train Epoch: 27: train loss : 0.02856021	 train accuracy : 0.99163636	 val accuracy : 0.64492754	 test accuracy : 0.71978022
# Train Epoch: 28: train loss : 0.02874976	 train accuracy : 0.99236364	 val accuracy : 0.64347826	 test accuracy : 0.72527473
# Train Epoch: 29: train loss : 0.02438842	 train accuracy : 0.99272727	 val accuracy : 0.64057971	 test accuracy : 0.73626374
# Train Epoch: 30: train loss : 0.01870473	 train accuracy : 0.99563636	 val accuracy : 0.63768116	 test accuracy : 0.73626374
# Train Epoch: 31: train loss : 0.01652674	 train accuracy : 0.99563636	 val accuracy : 0.63188406	 test accuracy : 0.73076923
# Train Epoch: 32: train loss : 0.01544008	 train accuracy : 0.99454545	 val accuracy : 0.64347826	 test accuracy : 0.72527473
# Train Epoch: 33: train loss : 0.01519757	 train accuracy : 0.99527273	 val accuracy : 0.63768116	 test accuracy : 0.70329670
# Train Epoch: 34: train loss : 0.01165978	 train accuracy : 0.99563636	 val accuracy : 0.63913043	 test accuracy : 0.70329670
# Train Epoch: 35: train loss : 0.00964376	 train accuracy : 0.99745455	 val accuracy : 0.64057971	 test accuracy : 0.70329670
# Train Epoch: 36: train loss : 0.00864024	 train accuracy : 0.99781818	 val accuracy : 0.64202899	 test accuracy : 0.69780220
# Train Epoch: 37: train loss : 0.00618981	 train accuracy : 0.99890909	 val accuracy : 0.63768116	 test accuracy : 0.69780220
# Train Epoch: 38: train loss : 0.00514436	 train accuracy : 0.99818182	 val accuracy : 0.63188406	 test accuracy : 0.70879121
# Train Epoch: 39: train loss : 0.00851686	 train accuracy : 0.99745455	 val accuracy : 0.63623188	 test accuracy : 0.72527473
# Train Epoch: 40: train loss : 0.00490938	 train accuracy : 0.99854545	 val accuracy : 0.64057971	 test accuracy : 0.72527473
# Save models
# Train Epoch: 41: train loss : 0.00302069	 train accuracy : 0.99963636	 val accuracy : 0.64492754	 test accuracy : 0.72527473
# Save models
# Train Epoch: 42: train loss : 0.00365332	 train accuracy : 0.99927273	 val accuracy : 0.65072464	 test accuracy : 0.72527473
# Train Epoch: 43: train loss : 0.00240287	 train accuracy : 1.00000000	 val accuracy : 0.64782609	 test accuracy : 0.72527473
# Train Epoch: 44: train loss : 0.00269217	 train accuracy : 0.99963636	 val accuracy : 0.64057971	 test accuracy : 0.72527473
# Train Epoch: 45: train loss : 0.00175849	 train accuracy : 0.99963636	 val accuracy : 0.64057971	 test accuracy : 0.71428571
# Train Epoch: 46: train loss : 0.00193260	 train accuracy : 0.99963636	 val accuracy : 0.64347826	 test accuracy : 0.71428571
# Train Epoch: 47: train loss : 0.00115656	 train accuracy : 1.00000000	 val accuracy : 0.64347826	 test accuracy : 0.70329670
# Train Epoch: 48: train loss : 0.00162410	 train accuracy : 1.00000000	 val accuracy : 0.64202899	 test accuracy : 0.69780220
# Train Epoch: 49: train loss : 0.00229947	 train accuracy : 0.99927273	 val accuracy : 0.64057971	 test accuracy : 0.70329670
# Train Epoch: 50: train loss : 0.00083568	 train accuracy : 1.00000000	 val accuracy : 0.63623188	 test accuracy : 0.70879121
# Train Epoch: 51: train loss : 0.00080196	 train accuracy : 1.00000000	 val accuracy : 0.63478261	 test accuracy : 0.70329670
# Train Epoch: 52: train loss : 0.00068624	 train accuracy : 1.00000000	 val accuracy : 0.63333333	 test accuracy : 0.70879121
# Train Epoch: 53: train loss : 0.00080426	 train accuracy : 1.00000000	 val accuracy : 0.62753623	 test accuracy : 0.70879121
# Train Epoch: 54: train loss : 0.00085795	 train accuracy : 1.00000000	 val accuracy : 0.62608696	 test accuracy : 0.70879121
# Train Epoch: 55: train loss : 0.00197111	 train accuracy : 0.99890909	 val accuracy : 0.63333333	 test accuracy : 0.70879121
# Train Epoch: 56: train loss : 0.00133085	 train accuracy : 0.99963636	 val accuracy : 0.63623188	 test accuracy : 0.71428571
# Train Epoch: 57: train loss : 0.00136879	 train accuracy : 0.99963636	 val accuracy : 0.63478261	 test accuracy : 0.70879121
# Train Epoch: 58: train loss : 0.00226369	 train accuracy : 0.99927273	 val accuracy : 0.63768116	 test accuracy : 0.70879121
# Train Epoch: 59: train loss : 0.00082862	 train accuracy : 0.99963636	 val accuracy : 0.63478261	 test accuracy : 0.70879121
# Train Epoch: 60: train loss : 0.00153724	 train accuracy : 0.99963636	 val accuracy : 0.64057971	 test accuracy : 0.70879121
# Train Epoch: 61: train loss : 0.00062738	 train accuracy : 1.00000000	 val accuracy : 0.64347826	 test accuracy : 0.70879121
# Train Epoch: 62: train loss : 0.00038235	 train accuracy : 1.00000000	 val accuracy : 0.63913043	 test accuracy : 0.71428571
# Train Epoch: 63: train loss : 0.00060749	 train accuracy : 1.00000000	 val accuracy : 0.63913043	 test accuracy : 0.71428571
# Train Epoch: 64: train loss : 0.00138438	 train accuracy : 0.99927273	 val accuracy : 0.63913043	 test accuracy : 0.70879121
# Train Epoch: 65: train loss : 0.00041434	 train accuracy : 1.00000000	 val accuracy : 0.63913043	 test accuracy : 0.70879121
# Train Epoch: 66: train loss : 0.00050457	 train accuracy : 1.00000000	 val accuracy : 0.63768116	 test accuracy : 0.71428571
# Train Epoch: 67: train loss : 0.00055414	 train accuracy : 1.00000000	 val accuracy : 0.63913043	 test accuracy : 0.71428571
# Train Epoch: 68: train loss : 0.00041422	 train accuracy : 1.00000000	 val accuracy : 0.63768116	 test accuracy : 0.71978022
# Train Epoch: 69: train loss : 0.00031750	 train accuracy : 1.00000000	 val accuracy : 0.63768116	 test accuracy : 0.71978022
# Train Epoch: 70: train loss : 0.00043209	 train accuracy : 1.00000000	 val accuracy : 0.63768116	 test accuracy : 0.71978022
# Train Epoch: 71: train loss : 0.00612712	 train accuracy : 0.99963636	 val accuracy : 0.63768116	 test accuracy : 0.71428571
# Train Epoch: 72: train loss : 0.00121511	 train accuracy : 0.99963636	 val accuracy : 0.63913043	 test accuracy : 0.71978022
# Train Epoch: 73: train loss : 0.00029641	 train accuracy : 1.00000000	 val accuracy : 0.63768116	 test accuracy : 0.72527473
# Train Epoch: 74: train loss : 0.00045354	 train accuracy : 1.00000000	 val accuracy : 0.63333333	 test accuracy : 0.72527473
# Train Epoch: 75: train loss : 0.00028021	 train accuracy : 1.00000000	 val accuracy : 0.63188406	 test accuracy : 0.72527473
# Train Epoch: 76: train loss : 0.00122775	 train accuracy : 0.99927273	 val accuracy : 0.63333333	 test accuracy : 0.72527473
# Train Epoch: 77: train loss : 0.00045261	 train accuracy : 1.00000000	 val accuracy : 0.63623188	 test accuracy : 0.72527473
# Train Epoch: 78: train loss : 0.00038553	 train accuracy : 1.00000000	 val accuracy : 0.63768116	 test accuracy : 0.71428571
# Train Epoch: 79: train loss : 0.00236905	 train accuracy : 0.99927273	 val accuracy : 0.63478261	 test accuracy : 0.71978022
# Train Epoch: 80: train loss : 0.00030236	 train accuracy : 1.00000000	 val accuracy : 0.63043478	 test accuracy : 0.71978022
# Train Epoch: 81: train loss : 0.00037369	 train accuracy : 1.00000000	 val accuracy : 0.63043478	 test accuracy : 0.71978022
# Train Epoch: 82: train loss : 0.00161602	 train accuracy : 0.99963636	 val accuracy : 0.63623188	 test accuracy : 0.72527473
# Train Epoch: 83: train loss : 0.00043074	 train accuracy : 1.00000000	 val accuracy : 0.63913043	 test accuracy : 0.72527473
# Train Epoch: 84: train loss : 0.00048416	 train accuracy : 1.00000000	 val accuracy : 0.63768116	 test accuracy : 0.72527473
# Train Epoch: 85: train loss : 0.00038535	 train accuracy : 1.00000000	 val accuracy : 0.63478261	 test accuracy : 0.71978022
# Train Epoch: 86: train loss : 0.00085238	 train accuracy : 0.99963636	 val accuracy : 0.63768116	 test accuracy : 0.71428571
# Train Epoch: 87: train loss : 0.00025433	 train accuracy : 1.00000000	 val accuracy : 0.64057971	 test accuracy : 0.71428571
# Train Epoch: 88: train loss : 0.00017395	 train accuracy : 1.00000000	 val accuracy : 0.64057971	 test accuracy : 0.71978022
# Train Epoch: 89: train loss : 0.00033545	 train accuracy : 1.00000000	 val accuracy : 0.64057971	 test accuracy : 0.71978022
# Train Epoch: 90: train loss : 0.00015506	 train accuracy : 1.00000000	 val accuracy : 0.63913043	 test accuracy : 0.71978022
# Train Epoch: 91: train loss : 0.00020980	 train accuracy : 1.00000000	 val accuracy : 0.64057971	 test accuracy : 0.71978022
# Train Epoch: 92: train loss : 0.00024106	 train accuracy : 1.00000000	 val accuracy : 0.64057971	 test accuracy : 0.71978022
# Train Epoch: 93: train loss : 0.00043180	 train accuracy : 1.00000000	 val accuracy : 0.64057971	 test accuracy : 0.71978022
# Train Epoch: 94: train loss : 0.00074665	 train accuracy : 0.99963636	 val accuracy : 0.64057971	 test accuracy : 0.71978022
# Train Epoch: 95: train loss : 0.00016099	 train accuracy : 1.00000000	 val accuracy : 0.64202899	 test accuracy : 0.71978022
# Train Epoch: 96: train loss : 0.00035098	 train accuracy : 1.00000000	 val accuracy : 0.64057971	 test accuracy : 0.71978022
# Train Epoch: 97: train loss : 0.00016306	 train accuracy : 1.00000000	 val accuracy : 0.63768116	 test accuracy : 0.71978022
# Train Epoch: 98: train loss : 0.00027187	 train accuracy : 1.00000000	 val accuracy : 0.64057971	 test accuracy : 0.71428571
# Train Epoch: 99: train loss : 0.00035567	 train accuracy : 1.00000000	 val accuracy : 0.63913043	 test accuracy : 0.71428571
# Train Epoch: 100: train loss : 0.00031850	 train accuracy : 1.00000000	 val accuracy : 0.64057971	 test accuracy : 0.71428571
# Train Epoch: 101: train loss : 0.00014368	 train accuracy : 1.00000000	 val accuracy : 0.64202899	 test accuracy : 0.71428571
# Train Epoch: 102: train loss : 0.00014219	 train accuracy : 1.00000000	 val accuracy : 0.64202899	 test accuracy : 0.71428571
# Train Epoch: 103: train loss : 0.00035392	 train accuracy : 1.00000000	 val accuracy : 0.63768116	 test accuracy : 0.71428571
# Train Epoch: 104: train loss : 0.00023012	 train accuracy : 1.00000000	 val accuracy : 0.63913043	 test accuracy : 0.71428571
# Train Epoch: 105: train loss : 0.00014941	 train accuracy : 1.00000000	 val accuracy : 0.64057971	 test accuracy : 0.71428571
# Train Epoch: 106: train loss : 0.00017978	 train accuracy : 1.00000000	 val accuracy : 0.64057971	 test accuracy : 0.71428571
# Train Epoch: 107: train loss : 0.00012714	 train accuracy : 1.00000000	 val accuracy : 0.63768116	 test accuracy : 0.71428571
# Train Epoch: 108: train loss : 0.00044437	 train accuracy : 1.00000000	 val accuracy : 0.63623188	 test accuracy : 0.71428571
# Train Epoch: 109: train loss : 0.00014584	 train accuracy : 1.00000000	 val accuracy : 0.63623188	 test accuracy : 0.70329670
# Train Epoch: 110: train loss : 0.00016942	 train accuracy : 1.00000000	 val accuracy : 0.64057971	 test accuracy : 0.70329670
# Train Epoch: 111: train loss : 0.00015082	 train accuracy : 1.00000000	 val accuracy : 0.63768116	 test accuracy : 0.71428571
# Train Epoch: 112: train loss : 0.00012376	 train accuracy : 1.00000000	 val accuracy : 0.63623188	 test accuracy : 0.71428571
# Train Epoch: 113: train loss : 0.00017330	 train accuracy : 1.00000000	 val accuracy : 0.63478261	 test accuracy : 0.71978022
# Train Epoch: 114: train loss : 0.00021773	 train accuracy : 1.00000000	 val accuracy : 0.63333333	 test accuracy : 0.71978022
# Train Epoch: 115: train loss : 0.00014474	 train accuracy : 1.00000000	 val accuracy : 0.63333333	 test accuracy : 0.71978022
# Train Epoch: 116: train loss : 0.00013183	 train accuracy : 1.00000000	 val accuracy : 0.63333333	 test accuracy : 0.71978022
# Train Epoch: 117: train loss : 0.00022116	 train accuracy : 1.00000000	 val accuracy : 0.63623188	 test accuracy : 0.71978022
# Train Epoch: 118: train loss : 0.00014953	 train accuracy : 1.00000000	 val accuracy : 0.63623188	 test accuracy : 0.71978022
# Train Epoch: 119: train loss : 0.00013354	 train accuracy : 1.00000000	 val accuracy : 0.63913043	 test accuracy : 0.71978022
# Train Epoch: 120: train loss : 0.00015591	 train accuracy : 1.00000000	 val accuracy : 0.63913043	 test accuracy : 0.71978022
# Train Epoch: 121: train loss : 0.00018712	 train accuracy : 1.00000000	 val accuracy : 0.63768116	 test accuracy : 0.71978022
# Train Epoch: 122: train loss : 0.00012307	 train accuracy : 1.00000000	 val accuracy : 0.63333333	 test accuracy : 0.71978022
# Train Epoch: 123: train loss : 0.00031609	 train accuracy : 1.00000000	 val accuracy : 0.63333333	 test accuracy : 0.71978022
# Train Epoch: 124: train loss : 0.00015642	 train accuracy : 1.00000000	 val accuracy : 0.63333333	 test accuracy : 0.71978022
# Train Epoch: 125: train loss : 0.00015470	 train accuracy : 1.00000000	 val accuracy : 0.63478261	 test accuracy : 0.71978022
# Train Epoch: 126: train loss : 0.00015778	 train accuracy : 1.00000000	 val accuracy : 0.63333333	 test accuracy : 0.71978022
# Train Epoch: 127: train loss : 0.00013293	 train accuracy : 1.00000000	 val accuracy : 0.63333333	 test accuracy : 0.71428571
# Train Epoch: 128: train loss : 0.00015415	 train accuracy : 1.00000000	 val accuracy : 0.63478261	 test accuracy : 0.71428571
# Train Epoch: 129: train loss : 0.00014613	 train accuracy : 1.00000000	 val accuracy : 0.63478261	 test accuracy : 0.71428571
# Train Epoch: 130: train loss : 0.00017894	 train accuracy : 1.00000000	 val accuracy : 0.63333333	 test accuracy : 0.70879121
# Train Epoch: 131: train loss : 0.00011395	 train accuracy : 1.00000000	 val accuracy : 0.63478261	 test accuracy : 0.71428571
# Train Epoch: 132: train loss : 0.00048170	 train accuracy : 0.99963636	 val accuracy : 0.63623188	 test accuracy : 0.71428571
# Train Epoch: 133: train loss : 0.00038519	 train accuracy : 1.00000000	 val accuracy : 0.63768116	 test accuracy : 0.71978022
# Train Epoch: 134: train loss : 0.00029479	 train accuracy : 1.00000000	 val accuracy : 0.63768116	 test accuracy : 0.71428571
# Train Epoch: 135: train loss : 0.00015495	 train accuracy : 1.00000000	 val accuracy : 0.64057971	 test accuracy : 0.71428571
# Train Epoch: 136: train loss : 0.00018299	 train accuracy : 1.00000000	 val accuracy : 0.64202899	 test accuracy : 0.71428571
# Train Epoch: 137: train loss : 0.00013412	 train accuracy : 1.00000000	 val accuracy : 0.64057971	 test accuracy : 0.71428571
# Train Epoch: 138: train loss : 0.00018184	 train accuracy : 1.00000000	 val accuracy : 0.63913043	 test accuracy : 0.71428571
# Train Epoch: 139: train loss : 0.00040531	 train accuracy : 1.00000000	 val accuracy : 0.63623188	 test accuracy : 0.71428571
# Train Epoch: 140: train loss : 0.00043583	 train accuracy : 1.00000000	 val accuracy : 0.63913043	 test accuracy : 0.71428571
# Train Epoch: 141: train loss : 0.00016612	 train accuracy : 1.00000000	 val accuracy : 0.64057971	 test accuracy : 0.71428571
# Train Epoch: 142: train loss : 0.00017550	 train accuracy : 1.00000000	 val accuracy : 0.64347826	 test accuracy : 0.71978022
# Train Epoch: 143: train loss : 0.00053482	 train accuracy : 1.00000000	 val accuracy : 0.64057971	 test accuracy : 0.71428571
# Train Epoch: 144: train loss : 0.00012426	 train accuracy : 1.00000000	 val accuracy : 0.64202899	 test accuracy : 0.71428571
# Train Epoch: 145: train loss : 0.00012779	 train accuracy : 1.00000000	 val accuracy : 0.63623188	 test accuracy : 0.71428571
# Train Epoch: 146: train loss : 0.00013186	 train accuracy : 1.00000000	 val accuracy : 0.63913043	 test accuracy : 0.71428571
# Train Epoch: 147: train loss : 0.00015525	 train accuracy : 1.00000000	 val accuracy : 0.64057971	 test accuracy : 0.71428571
# Train Epoch: 148: train loss : 0.00011257	 train accuracy : 1.00000000	 val accuracy : 0.64057971	 test accuracy : 0.71428571
# ...
# Train Epoch: 78: train loss : 0.00020948	 train accuracy : 1.00000000	 val accuracy : 0.67425320	 test accuracy : 0.70059880
# Train Epoch: 79: train loss : 0.00019734	 train accuracy : 1.00000000	 val accuracy : 0.67567568	 test accuracy : 0.70059880
# Train Epoch: 80: train loss : 0.00035157	 train accuracy : 1.00000000	 val accuracy : 0.67425320	 test accuracy : 0.70059880
# Train Epoch: 81: train loss : 0.00022986	 train accuracy : 1.00000000	 val accuracy : 0.67567568	 test accuracy : 0.70059880
# Train Epoch: 82: train loss : 0.00070966	 train accuracy : 0.99964438	 val accuracy : 0.67140825	 test accuracy : 0.70059880
# Train Epoch: 83: train loss : 0.00029904	 train accuracy : 1.00000000	 val accuracy : 0.67283073	 test accuracy : 0.70059880
# Train Epoch: 84: train loss : 0.00024757	 train accuracy : 1.00000000	 val accuracy : 0.66856330	 test accuracy : 0.70658683
# Train Epoch: 85: train loss : 0.00020726	 train accuracy : 1.00000000	 val accuracy : 0.66571835	 test accuracy : 0.70059880
# Train Epoch: 86: train loss : 0.00021293	 train accuracy : 1.00000000	 val accuracy : 0.66571835	 test accuracy : 0.70658683
# Train Epoch: 87: train loss : 0.00033079	 train accuracy : 1.00000000	 val accuracy : 0.66429587	 test accuracy : 0.70059880
# Train Epoch: 88: train loss : 0.00129385	 train accuracy : 0.99964438	 val accuracy : 0.66429587	 test accuracy : 0.70059880
# Train Epoch: 89: train loss : 0.00238252	 train accuracy : 0.99964438	 val accuracy : 0.66856330	 test accuracy : 0.68862275
# Train Epoch: 90: train loss : 0.00021128	 train accuracy : 1.00000000	 val accuracy : 0.66856330	 test accuracy : 0.69461078
# Train Epoch: 91: train loss : 0.00019860	 train accuracy : 1.00000000	 val accuracy : 0.67425320	 test accuracy : 0.69461078
# Train Epoch: 92: train loss : 0.00024549	 train accuracy : 1.00000000	 val accuracy : 0.67283073	 test accuracy : 0.69461078
# Train Epoch: 93: train loss : 0.00021309	 train accuracy : 1.00000000	 val accuracy : 0.67283073	 test accuracy : 0.70059880
# Train Epoch: 94: train loss : 0.00022588	 train accuracy : 1.00000000	 val accuracy : 0.67425320	 test accuracy : 0.70059880
# Train Epoch: 95: train loss : 0.00019134	 train accuracy : 1.00000000	 val accuracy : 0.67140825	 test accuracy : 0.69461078
# Train Epoch: 96: train loss : 0.00018988	 train accuracy : 1.00000000	 val accuracy : 0.67140825	 test accuracy : 0.68862275
# Train Epoch: 97: train loss : 0.00034809	 train accuracy : 1.00000000	 val accuracy : 0.67140825	 test accuracy : 0.68862275
# Train Epoch: 98: train loss : 0.00027716	 train accuracy : 1.00000000	 val accuracy : 0.67140825	 test accuracy : 0.68862275
# Train Epoch: 99: train loss : 0.00040480	 train accuracy : 1.00000000	 val accuracy : 0.67140825	 test accuracy : 0.68862275
# Train Epoch: 100: train loss : 0.00016514	 train accuracy : 1.00000000	 val accuracy : 0.67425320	 test accuracy : 0.69461078
# Train Epoch: 101: train loss : 0.00021474	 train accuracy : 1.00000000	 val accuracy : 0.67283073	 test accuracy : 0.69461078
# Train Epoch: 102: train loss : 0.00015905	 train accuracy : 1.00000000	 val accuracy : 0.66998578	 test accuracy : 0.68862275
# Train Epoch: 103: train loss : 0.00021927	 train accuracy : 1.00000000	 val accuracy : 0.67140825	 test accuracy : 0.68263473
# Train Epoch: 104: train loss : 0.00019561	 train accuracy : 1.00000000	 val accuracy : 0.67283073	 test accuracy : 0.68862275
# Train Epoch: 105: train loss : 0.00019127	 train accuracy : 1.00000000	 val accuracy : 0.67140825	 test accuracy : 0.69461078
# Train Epoch: 106: train loss : 0.00018249	 train accuracy : 1.00000000	 val accuracy : 0.66998578	 test accuracy : 0.69461078
# Train Epoch: 107: train loss : 0.00020661	 train accuracy : 1.00000000	 val accuracy : 0.66998578	 test accuracy : 0.70059880
# Train Epoch: 108: train loss : 0.00034886	 train accuracy : 1.00000000	 val accuracy : 0.66714083	 test accuracy : 0.69461078
# Train Epoch: 109: train loss : 0.00014788	 train accuracy : 1.00000000	 val accuracy : 0.66856330	 test accuracy : 0.69461078
# Train Epoch: 110: train loss : 0.00019405	 train accuracy : 1.00000000	 val accuracy : 0.67140825	 test accuracy : 0.69461078
# Train Epoch: 111: train loss : 0.00022339	 train accuracy : 1.00000000	 val accuracy : 0.66856330	 test accuracy : 0.69461078
# Train Epoch: 112: train loss : 0.00019665	 train accuracy : 1.00000000	 val accuracy : 0.66856330	 test accuracy : 0.69461078
# Train Epoch: 113: train loss : 0.00016926	 train accuracy : 1.00000000	 val accuracy : 0.66998578	 test accuracy : 0.70059880
# Train Epoch: 114: train loss : 0.00102917	 train accuracy : 0.99964438	 val accuracy : 0.67140825	 test accuracy : 0.70059880
# Train Epoch: 115: train loss : 0.00021018	 train accuracy : 1.00000000	 val accuracy : 0.67567568	 test accuracy : 0.70059880
# Train Epoch: 116: train loss : 0.00018389	 train accuracy : 1.00000000	 val accuracy : 0.67567568	 test accuracy : 0.70059880
# Train Epoch: 117: train loss : 0.00018188	 train accuracy : 1.00000000	 val accuracy : 0.67567568	 test accuracy : 0.70059880
# Train Epoch: 118: train loss : 0.00023468	 train accuracy : 1.00000000	 val accuracy : 0.67709815	 test accuracy : 0.70059880
# Train Epoch: 119: train loss : 0.00013797	 train accuracy : 1.00000000	 val accuracy : 0.67709815	 test accuracy : 0.70059880
# Train Epoch: 120: train loss : 0.00015692	 train accuracy : 1.00000000	 val accuracy : 0.67709815	 test accuracy : 0.70059880
# Train Epoch: 121: train loss : 0.00014783	 train accuracy : 1.00000000	 val accuracy : 0.67567568	 test accuracy : 0.70059880
# Train Epoch: 122: train loss : 0.00016992	 train accuracy : 1.00000000	 val accuracy : 0.67425320	 test accuracy : 0.70059880
# Train Epoch: 123: train loss : 0.00014146	 train accuracy : 1.00000000	 val accuracy : 0.67425320	 test accuracy : 0.69461078
# Train Epoch: 124: train loss : 0.00022162	 train accuracy : 1.00000000	 val accuracy : 0.67283073	 test accuracy : 0.69461078
# Train Epoch: 125: train loss : 0.00015898	 train accuracy : 1.00000000	 val accuracy : 0.67709815	 test accuracy : 0.69461078
# Train Epoch: 126: train loss : 0.00016944	 train accuracy : 1.00000000	 val accuracy : 0.67709815	 test accuracy : 0.69461078
# Train Epoch: 127: train loss : 0.00012183	 train accuracy : 1.00000000	 val accuracy : 0.67709815	 test accuracy : 0.70059880
# Train Epoch: 128: train loss : 0.00014250	 train accuracy : 1.00000000	 val accuracy : 0.67709815	 test accuracy : 0.70059880
# Train Epoch: 129: train loss : 0.00011561	 train accuracy : 1.00000000	 val accuracy : 0.67709815	 test accuracy : 0.70059880
# Train Epoch: 130: train loss : 0.00016978	 train accuracy : 1.00000000	 val accuracy : 0.67425320	 test accuracy : 0.70059880
# Train Epoch: 131: train loss : 0.00012127	 train accuracy : 1.00000000	 val accuracy : 0.67425320	 test accuracy : 0.70059880
# Train Epoch: 132: train loss : 0.00013481	 train accuracy : 1.00000000	 val accuracy : 0.67425320	 test accuracy : 0.70059880
# Train Epoch: 133: train loss : 0.00011895	 train accuracy : 1.00000000	 val accuracy : 0.67425320	 test accuracy : 0.70059880
# Train Epoch: 134: train loss : 0.00039166	 train accuracy : 0.99964438	 val accuracy : 0.67425320	 test accuracy : 0.70059880
# Train Epoch: 135: train loss : 0.00018038	 train accuracy : 1.00000000	 val accuracy : 0.67425320	 test accuracy : 0.70059880
# Train Epoch: 136: train loss : 0.00016572	 train accuracy : 1.00000000	 val accuracy : 0.67283073	 test accuracy : 0.70658683
# Train Epoch: 137: train loss : 0.00014328	 train accuracy : 1.00000000	 val accuracy : 0.66856330	 test accuracy : 0.70658683
# Train Epoch: 138: train loss : 0.00012953	 train accuracy : 1.00000000	 val accuracy : 0.66714083	 test accuracy : 0.70658683
# Train Epoch: 139: train loss : 0.00020033	 train accuracy : 1.00000000	 val accuracy : 0.66714083	 test accuracy : 0.70658683
# Train Epoch: 140: train loss : 0.00018871	 train accuracy : 1.00000000	 val accuracy : 0.66714083	 test accuracy : 0.70658683
# Train Epoch: 141: train loss : 0.00014026	 train accuracy : 1.00000000	 val accuracy : 0.66714083	 test accuracy : 0.70658683
# Train Epoch: 142: train loss : 0.00012006	 train accuracy : 1.00000000	 val accuracy : 0.66714083	 test accuracy : 0.70658683
# Train Epoch: 143: train loss : 0.00015280	 train accuracy : 1.00000000	 val accuracy : 0.66856330	 test accuracy : 0.70658683
# Train Epoch: 144: train loss : 0.00013976	 train accuracy : 1.00000000	 val accuracy : 0.66998578	 test accuracy : 0.71257485
# Train Epoch: 145: train loss : 0.00011618	 train accuracy : 1.00000000	 val accuracy : 0.66998578	 test accuracy : 0.71257485
# Train Epoch: 146: train loss : 0.00010729	 train accuracy : 1.00000000	 val accuracy : 0.67140825	 test accuracy : 0.71257485
# Train Epoch: 147: train loss : 0.00011645	 train accuracy : 1.00000000	 val accuracy : 0.66998578	 test accuracy : 0.71257485
# Train Epoch: 148: train loss : 0.00011958	 train accuracy : 1.00000000	 val accuracy : 0.66998578	 test accuracy : 0.71257485
# Train Epoch: 149: train loss : 0.00028771	 train accuracy : 1.00000000	 val accuracy : 0.66998578	 test accuracy : 0.71257485
# Train Epoch: 150: train loss : 0.00140894	 train accuracy : 0.99964438	 val accuracy : 0.67425320	 test accuracy : 0.71257485
# Train Epoch: 151: train loss : 0.00010320	 train accuracy : 1.00000000	 val accuracy : 0.66856330	 test accuracy : 0.71257485
# Train Epoch: 152: train loss : 0.00011800	 train accuracy : 1.00000000	 val accuracy : 0.66856330	 test accuracy : 0.71257485
# Train Epoch: 153: train loss : 0.00012067	 train accuracy : 1.00000000	 val accuracy : 0.66287340	 test accuracy : 0.71257485
# Train Epoch: 154: train loss : 0.00013732	 train accuracy : 1.00000000	 val accuracy : 0.66145092	 test accuracy : 0.71257485
# Train Epoch: 155: train loss : 0.00040619	 train accuracy : 1.00000000	 val accuracy : 0.66145092	 test accuracy : 0.70658683
# Train Epoch: 156: train loss : 0.00016043	 train accuracy : 1.00000000	 val accuracy : 0.66287340	 test accuracy : 0.70658683
# Train Epoch: 157: train loss : 0.00049965	 train accuracy : 1.00000000	 val accuracy : 0.66571835	 test accuracy : 0.71257485
# Train Epoch: 158: train loss : 0.00015489	 train accuracy : 1.00000000	 val accuracy : 0.66714083	 test accuracy : 0.71257485
# Train Epoch: 159: train loss : 0.00204044	 train accuracy : 0.99928876	 val accuracy : 0.66856330	 test accuracy : 0.71257485
# Train Epoch: 160: train loss : 0.00013221	 train accuracy : 1.00000000	 val accuracy : 0.67140825	 test accuracy : 0.71257485
# Train Epoch: 161: train loss : 0.00016400	 train accuracy : 1.00000000	 val accuracy : 0.66998578	 test accuracy : 0.70658683
# Train Epoch: 162: train loss : 0.00012680	 train accuracy : 1.00000000	 val accuracy : 0.66856330	 test accuracy : 0.71257485
# Train Epoch: 163: train loss : 0.00010643	 train accuracy : 1.00000000	 val accuracy : 0.66998578	 test accuracy : 0.71257485
# Train Epoch: 164: train loss : 0.00015795	 train accuracy : 1.00000000	 val accuracy : 0.67567568	 test accuracy : 0.70658683
# Train Epoch: 165: train loss : 0.00015081	 train accuracy : 1.00000000	 val accuracy : 0.67283073	 test accuracy : 0.70658683
# Train Epoch: 166: train loss : 0.00026698	 train accuracy : 1.00000000	 val accuracy : 0.67283073	 test accuracy : 0.70658683
# Train Epoch: 167: train loss : 0.00103482	 train accuracy : 0.99928876	 val accuracy : 0.67283073	 test accuracy : 0.71257485
# Train Epoch: 168: train loss : 0.00114486	 train accuracy : 0.99964438	 val accuracy : 0.66714083	 test accuracy : 0.71257485
# Train Epoch: 169: train loss : 0.00114402	 train accuracy : 0.99964438	 val accuracy : 0.66714083	 test accuracy : 0.71856287
# Train Epoch: 170: train loss : 0.00040202	 train accuracy : 1.00000000	 val accuracy : 0.66287340	 test accuracy : 0.71257485
# Train Epoch: 171: train loss : 0.00043131	 train accuracy : 1.00000000	 val accuracy : 0.66287340	 test accuracy : 0.71257485
# Train Epoch: 172: train loss : 0.00024644	 train accuracy : 1.00000000	 val accuracy : 0.66145092	 test accuracy : 0.71257485
# Train Epoch: 173: train loss : 0.00025601	 train accuracy : 1.00000000	 val accuracy : 0.66145092	 test accuracy : 0.70658683
# Train Epoch: 174: train loss : 0.00012671	 train accuracy : 1.00000000	 val accuracy : 0.66287340	 test accuracy : 0.70658683
# Train Epoch: 175: train loss : 0.00011658	 train accuracy : 1.00000000	 val accuracy : 0.66856330	 test accuracy : 0.71257485
# Train Epoch: 176: train loss : 0.00012090	 train accuracy : 1.00000000	 val accuracy : 0.66571835	 test accuracy : 0.70658683
# Train Epoch: 177: train loss : 0.00010491	 train accuracy : 1.00000000	 val accuracy : 0.66714083	 test accuracy : 0.70658683
# Train Epoch: 178: train loss : 0.00008832	 train accuracy : 1.00000000	 val accuracy : 0.66714083	 test accuracy : 0.70059880
# Train Epoch: 179: train loss : 0.00010147	 train accuracy : 1.00000000	 val accuracy : 0.66714083	 test accuracy : 0.70059880
# Train Epoch: 180: train loss : 0.00012181	 train accuracy : 1.00000000	 val accuracy : 0.66856330	 test accuracy : 0.70059880
# Train Epoch: 181: train loss : 0.00079664	 train accuracy : 0.99964438	 val accuracy : 0.66998578	 test accuracy : 0.70059880
# Train Epoch: 182: train loss : 0.00044661	 train accuracy : 0.99964438	 val accuracy : 0.66571835	 test accuracy : 0.70658683
# Train Epoch: 183: train loss : 0.00022003	 train accuracy : 1.00000000	 val accuracy : 0.66571835	 test accuracy : 0.70059880
# Train Epoch: 184: train loss : 0.00011769	 train accuracy : 1.00000000	 val accuracy : 0.66571835	 test accuracy : 0.70658683
# Train Epoch: 185: train loss : 0.00011870	 train accuracy : 1.00000000	 val accuracy : 0.66571835	 test accuracy : 0.70658683
# Train Epoch: 186: train loss : 0.00030320	 train accuracy : 1.00000000	 val accuracy : 0.66571835	 test accuracy : 0.70658683
# Train Epoch: 187: train loss : 0.00014923	 train accuracy : 1.00000000	 val accuracy : 0.66998578	 test accuracy : 0.70658683
# Train Epoch: 188: train loss : 0.00023607	 train accuracy : 1.00000000	 val accuracy : 0.66998578	 test accuracy : 0.70658683
# Train Epoch: 189: train loss : 0.00010373	 train accuracy : 1.00000000	 val accuracy : 0.67140825	 test accuracy : 0.70059880
# Train Epoch: 190: train loss : 0.00014765	 train accuracy : 1.00000000	 val accuracy : 0.67140825	 test accuracy : 0.70059880
# Train Epoch: 191: train loss : 0.00024706	 train accuracy : 1.00000000	 val accuracy : 0.67425320	 test accuracy : 0.70059880
# Train Epoch: 192: train loss : 0.00011865	 train accuracy : 1.00000000	 val accuracy : 0.67283073	 test accuracy : 0.70059880
# Train Epoch: 193: train loss : 0.00014427	 train accuracy : 1.00000000	 val accuracy : 0.67283073	 test accuracy : 0.70658683
# Train Epoch: 194: train loss : 0.00011161	 train accuracy : 1.00000000	 val accuracy : 0.67567568	 test accuracy : 0.70658683
# Train Epoch: 195: train loss : 0.00011740	 train accuracy : 1.00000000	 val accuracy : 0.67140825	 test accuracy : 0.70658683
# Train Epoch: 196: train loss : 0.00012004	 train accuracy : 1.00000000	 val accuracy : 0.67140825	 test accuracy : 0.70658683
# Train Epoch: 197: train loss : 0.00010865	 train accuracy : 1.00000000	 val accuracy : 0.67283073	 test accuracy : 0.70658683
# Train Epoch: 198: train loss : 0.00016958	 train accuracy : 1.00000000	 val accuracy : 0.67425320	 test accuracy : 0.70658683
# Train Epoch: 199: train loss : 0.00012223	 train accuracy : 1.00000000	 val accuracy : 0.67567568	 test accuracy : 0.71257485
# Train Epoch: 200: train loss : 0.00012824	 train accuracy : 1.00000000	 val accuracy : 0.67567568	 test accuracy : 0.71257485
# In ensemble  5
# The best validaiton accuracy is:  0.6813655761024182
# Happened at epoch:  18
# The corresponding test accuracy 0.6766467065868264
# The corresponding test AUC is:  0.7604347826086957
# The Max voting test accuracy is:  0.6977011494252874
# The test AUC is:  0.7700437298420306
