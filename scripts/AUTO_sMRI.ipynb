# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/ABIDE/")
# Out:
# Mounted at /content/drive

# %%
# load ComBat algorithm
# !python /content/drive/MyDrive/ABIDE/neuralCombat.py 
import sys
sys.path.append('/content/drive/MyDrive/ABIDE/')

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from neuralCombat import *
# from neuralCombat.py import neuralCombat
import pandas as pd
from sklearn import svm
import joblib
import openpyxl
from openpyxl import load_workbook
import os
import scipy.io as scio
import argparse
import numpy as np
import time
import torch
import torch.utils.data
import torch.nn as nn
import torch.optim as optim
from torch.utils.data.dataset import Dataset
from torch.autograd import Variable
from torchvision import datasets, transforms
from torchvision.utils import make_grid , save_image
import torchvision.utils as vutils
from os.path import join
from os import listdir
from torch.utils.data.dataloader import DataLoader
from torch.utils.data import DataLoader
from collections import OrderedDict
import nibabel as nib
import matplotlib.pyplot as plt
import cv2 as cv
from os import path
import shutil
import scipy.stats
import scipy.ndimage
import random
import torch.nn.init as init
import torch.nn.functional as F
import sys
import math
from functools import reduce
import operator
from scipy.interpolate import interp1d
from torch.optim import lr_scheduler
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import RidgeClassifier
from sklearn.feature_selection import RFE

def feature_selection(matrix, labels, train_ind, fnum):
    """
        matrix       : feature matrix (num_subjects x num_features)
        labels       : ground truth labels (num_subjects x 1)
        train_ind    : indices of the training samples
        fnum         : size of the feature vector after feature selection 

    return:
        x_data      : feature matrix of lower dimension (num_subjects x fnum)
    """

    estimator = RidgeClassifier()
    selector = RFE(estimator, n_features_to_select=fnum, step=100, verbose=1)

    featureX = matrix[train_ind, :]
    featureY = labels[train_ind]
    selector = selector.fit(featureX, featureY.ravel())

    return selector

def get_index(lst=None, item=''):
	return [i for i in range(len(lst)) if lst[i] == item]

def flatten_one(length, img):
	'''
	  In some situations, the dimension on z-axis of images are smaller than
	  the dimension of z-axis of patches, this function will be used to pad
	'''

	one_line = np.zeros((1, int(length)))
	position = 0
	for i in range(img.shape[0]):  # column
		for j in range(i + 1, img.shape[1]):  # row
			one_line[0, position] = img[j, i]
			position = position + 1
	return one_line


def get_ids(num_subjects=None,dir_path=''):
	"""
	return:
		subject_IDs    : list of all subject IDs
	"""
	subject_IDs = np.genfromtxt(os.path.join(dir_path, 'subject_IDs.txt'), dtype=str)

	if num_subjects is not None:
		subject_IDs = subject_IDs[:num_subjects]

	return subject_IDs

def save_model(net,path, name_net):

  # This fucntion is used to save a specific model

    path_net =  path + '/' + name_net + '.pth'
    torch.save(net.cpu().state_dict(), path_net)
    net.cuda()

def load_model(net, path, name_net):

  # This function is used to load a specific model we saved before

    path_net =  path + '/' + name_net + '.pth'
    net.load_state_dict(torch.load(path_net))

    return net

# %%
########################################### Load Data ###############################################
#####################################################################################################
#####################################################################################################
combat = True    # True or False


if combat == False:
  save_combat = '/without_ComBat/'
else:
  save_combat = '/with_ComBat/'

save_path = '/content/drive/MyDrive/ABIDE/save_models/sMRI' + save_combat
localDir = '/content/sMRI_dataset/'
if os.path.exists(localDir):
  shutil.rmtree(localDir) 
# shutil.copy('/content/drive/MyDrive/ABIDE/freesurfer_stats.7z', localDir)
os.makedirs(localDir)
# !unzip '/content/drive/MyDrive/ABIDE/freesurfer_stats.zip' -d '/content/sMRI_dataset'

label_dir = '/content/drive/MyDrive/ABIDE/phenotypic_image_quality'
localDir = localDir + 'freesurfer_stats/'

k_fold = 5
new_number_features = 1435
number_samples = 871
useless_samples = ['51334']
scaler = True

age_name = 'ages.mat'
gender_name = 'genders.mat'
label_name = 'ABIDE_label_871.mat'
label = scio.loadmat(os.path.join(label_dir, label_name))
label = label['label'][0]
labels = np.zeros(number_samples - len(useless_samples))
site_name = 'sites.mat'
site = scio.loadmat(os.path.join(label_dir, site_name))
all_sites = site['sites']
for i in range(len(all_sites)):
	site = all_sites[i]
	all_sites[i] = site.replace(' ', '')
unique_sites = np.unique(all_sites)
sites = []
unique_sites = list(unique_sites)

gender = scio.loadmat(os.path.join(label_dir, gender_name))
gender = gender['genders']
genders = np.zeros((number_samples - len(useless_samples), 1))

age = scio.loadmat(os.path.join(label_dir, age_name))
age = age['ages']
ages = np.zeros((number_samples - len(useless_samples), 1))

subject_IDs = get_ids(number_samples,dir_path=label_dir)
subject_IDs = subject_IDs.tolist()

position = 0
for i in range(number_samples):
  subject_name = subject_IDs[i]
  if subject_name in useless_samples:
    subject_index = get_index(lst=subject_IDs, item=subject_name)
    print('The index for sample ' + subject_name + ' is : ', subject_index)
  else:
    image_name = subject_name + '.mat'
    subject_index = get_index(lst=subject_IDs, item=subject_name)
    sites.append(all_sites[subject_index[0]])
    labels[position] = label[subject_index[0]]
    genders[position] = int(gender[subject_index[0]]) + 1
    ages[position] = float(age[subject_index[0]].replace(' ', ''))
    position = position + 1
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51096/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51097/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51098/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51099/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51100/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51101/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51102/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51103/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51104/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51105/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51106/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51107/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51109/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51110/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51111/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51112/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51113/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51114/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51116/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51117/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51118/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51122/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51123/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51124/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51126/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51127/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51128/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51129/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51130/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51131/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.curv.stats
# ...
#   inflating: /content/sMRI_dataset/freesurfer_stats/51576/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51576/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51576/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51576/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51576/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51577/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51578/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51579/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51580/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51582/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51583/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51584/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51585/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51606/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51607/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/wmparc.stats
# The index for sample 51334 is :  [799]

# %%
############################################### Load sMRI ###############################################################
############################################### Load sMRI ###############################################################
############################################### Load sMRI ###############################################################
############################################### Load Desikan_Killiany_features
left = 'lh.aparc.stats'
right = 'rh.aparc.stats'
number_roi = 68
feature_list = ['NumVert', 'SurfArea', 'GrayVol', 'ThickAvg', 'ThickStd', 'MeanCurv', 'GausCurv', 'FoldInd', 'CurvInd']
names = ['StructName', 'NumVert', 'SurfArea', 'GrayVol', 'ThickAvg', 'ThickStd', 'MeanCurv', 'GausCurv', 'FoldInd', 'CurvInd']
skiprows= list(range(0,61))
Desikan_Killiany_features = np.zeros((number_samples - len(useless_samples), number_roi * len(feature_list)))


position = 0
print('constructing Desikan-Killiany Atlas features')
for i in range(number_samples):
  subject_name = subject_IDs[i]
  if subject_name in useless_samples:
    subject_index = get_index(lst=subject_IDs, item=subject_name)
    print('The index for sample ' + subject_name + ' is : ', subject_index)
  else:
    table_left = pd.read_table(localDir + subject_name + '/' + left, sep='\s+', names=names,
						  skiprows=skiprows)
    table_right = pd.read_table(localDir + subject_name + '/' + right, sep='\s+', names=names,
						  skiprows=skiprows)

    for j in range(len(feature_list)):
      feature_name = feature_list[j]
      left_features = table_left[feature_name].values.tolist()
      right_features = table_right[feature_name].values.tolist()
      all_features = left_features + right_features
      if len(all_features) != number_roi:
       print('The sample ' + subject_name + ' has mistake!')
      all_features = np.array(all_features)
      Desikan_Killiany_features[position, j*number_roi : (j+1)*number_roi] = all_features
    position = position + 1

if scaler == True:
	for i in range(len(feature_list)):
		Desikan_Killiany_features[:, i * number_roi: (i+1) * number_roi] = StandardScaler().fit_transform(Desikan_Killiany_features[:, i * number_roi: (i+1) * number_roi])

print('finished')

############################################### Load aseg features
print('constructing aseg features')
number_roi_aseg = 45
aseg = 'aseg.stats'
feature_list_aseg = ['Number of Voxels', 'Volume', 'Intensity normMean', 'Itensity normStdDev', 'Intensity normMin', 'Intensity normMax', 'Intensity normRange']
names_aseg = ['ColHeader Index', 'Segmentation Id ', 'Number of Voxels', 'Volume', 'Structure Name', 'Intensity normMean', 'Itensity normStdDev', 'Intensity normMin', 'Intensity normMax', 'Intensity normRange']
skiprows_aseg= list(range(0,79))
aseg_features = np.zeros((number_samples - len(useless_samples), number_roi_aseg * len(feature_list_aseg)))

position = 0
for i in range(number_samples):
	subject_name = subject_IDs[i]
	if subject_name in useless_samples:
		subject_index = get_index(lst=subject_IDs, item=subject_name)
		print('The index for sample ' + subject_name + ' is : ', subject_index)
	else:
		table_left = pd.read_table(localDir + subject_name + '/' + aseg, sep='\s+', names=names_aseg,
						  skiprows=skiprows_aseg)
		for j in range(len(feature_list_aseg)):
			feature_name = feature_list_aseg[j]
			left_features = table_left[feature_name].values.tolist()
			if len(left_features) != number_roi_aseg:
				print('The sample ' + subject_name + ' has mistake!')
			all_features = np.array(left_features)
			aseg_features[position, j*number_roi_aseg : (j+1)*number_roi_aseg] = all_features
		position = position + 1

if scaler == True:
	for i in range(len(feature_list_aseg)):
		aseg_features[:, i * number_roi_aseg: (i+1) * number_roi_aseg] = StandardScaler().fit_transform(aseg_features[:, i * number_roi_aseg: (i+1) * number_roi_aseg])
print('finished')

############################################### Load wmparc features
number_roi_wmparc = 70
wmparc = 'wmparc.stats'
feature_list_wmparc = ['Number of Voxels', 'Volume', 'Intensity normMean', 'Itensity normStdDev', 'Intensity normMin', 'Intensity normMax', 'Intensity normRange']
names_wmparc = ['ColHeader Index', 'Segmentation Id ', 'Number of Voxels', 'Volume', 'Structure Name', 'Intensity normMean', 'Itensity normStdDev', 'Intensity normMin', 'Intensity normMax', 'Intensity normRange']
skiprows_wmparc= list(range(0,65))
wmparc_features = np.zeros((number_samples - len(useless_samples), number_roi_wmparc * len(feature_list_wmparc)))

print('constructing wmparc features')
position = 0
for i in range(number_samples):
	subject_name = subject_IDs[i]
	if subject_name in useless_samples:
		subject_index = get_index(lst=subject_IDs, item=subject_name)
		print('The index for sample ' + subject_name + ' is : ', subject_index)
	else:
		table_left = pd.read_table(localDir + subject_name + '/' + wmparc, sep='\s+', names = names_wmparc,
						  skiprows=skiprows_wmparc)
		for j in range(len(feature_list_wmparc)):
			feature_name = feature_list_wmparc[j]
			left_features = table_left[feature_name].values.tolist()
			if len(left_features) != number_roi_wmparc:
				print('The sample ' + subject_name + ' has mistake!')
			all_features = np.array(left_features)
			wmparc_features[position, j*number_roi_wmparc : (j+1)*number_roi_wmparc] = all_features
		position = position + 1
if scaler == True:
	for i in range(len(feature_list_wmparc)):
		wmparc_features[:, i * number_roi_wmparc: (i+1) * number_roi_wmparc] = StandardScaler().fit_transform(wmparc_features[:, i * number_roi_wmparc: (i+1) * number_roi_wmparc])
print('finished')

############################################### concatenation
sMRI_features = np.concatenate((Desikan_Killiany_features, aseg_features, wmparc_features),axis = 1)
# Out:
# constructing Desikan-Killiany Atlas features
# The index for sample 51334 is :  [799]
# finished
# constructing aseg features
# The index for sample 51334 is :  [799]
# finished
# constructing wmparc features
# The index for sample 51334 is :  [799]
# finished

# %%
############################################### Combat ###############################################################
############################################### Combat ###############################################################
############################################### Combat ###############################################################
if combat == True:
	batch = []
	for i in range(len(sites)):
		batch.append(get_index(lst=unique_sites, item=sites[i])[0]+1)

	combat_labels = []
	combat_genders = []
	combat_ages = []
	for i in range(len(labels)):
		combat_labels.append(labels[i] + 1)
		combat_genders.append(genders[i])
		combat_ages.append(ages[i])

	new_all_samples_feature = sMRI_features.T
	covars = {}
	covars['batch'] = batch
	covars['labels'] = combat_labels
	covars['genders'] = combat_genders
	covars['ages'] = combat_ages
	covars = pd.DataFrame(covars)

	# To specify names of the variables that are categorical:
	categorical_cols = ['labels', 'genders']
	# To specify the name of the variable that encodes for the scanner/batch covariate:
	batch_col = 'batch'
	continuous_cols = ['ages']
	# Harmonization step:
	new_all_samples_feature = neuroCombat(dat=new_all_samples_feature,
										  covars=covars,
										  batch_col=batch_col,
										  categorical_cols=categorical_cols,
											continuous_cols=continuous_cols)["data"]
	sMRI_features = new_all_samples_feature.T
# Out:
# [neuroCombat] Creating design matrix
# [neuroCombat] Standardizing data across features
# [neuroCombat] Fitting L/S model and finding priors
# [neuroCombat] Finding parametric adjustments
# [neuroCombat] Final adjustment of data
# /content/drive/MyDrive/ABIDE/neuralCombat.py:325: RuntimeWarning: divide by zero encountered in true_divide
#   change = max((abs(g_new - g_old) / g_old).max(), (abs(d_new - d_old) / d_old).max())

# %%
############################################### phenotypic ###############################################################
############################################### phenotypic ###############################################################
############################################### phenotypic ###############################################################
ages_name = 'ages.mat'
ages = scio.loadmat(os.path.join(label_dir, ages_name))
ages = ages['ages']

gender_name = 'genders.mat'
genders = scio.loadmat(os.path.join(label_dir, gender_name))
genders = genders['genders']

FIQ_name = 'FIQS.mat'
FIQS = scio.loadmat(os.path.join(label_dir, FIQ_name))
FIQS = FIQS['FIQS']

NUM_name = 'NUM.mat'
NUM = scio.loadmat(os.path.join(label_dir, NUM_name))
NUMS = NUM['NUM']

PEC_name = 'PEC.mat'
PEC = scio.loadmat(os.path.join(label_dir, PEC_name))
PECS = PEC['PEC']

RAT_name = 'RAT.mat'
RAT = scio.loadmat(os.path.join(label_dir, RAT_name))
RATS = RAT['RAT']

age = np.zeros((number_samples - len(useless_samples), 1))
gender = np.zeros((number_samples - len(useless_samples), 1))
FIQ = np.zeros((number_samples - len(useless_samples), 1))
NUM = np.zeros((number_samples - len(useless_samples), 1))
PEC = np.zeros((number_samples - len(useless_samples), 1))
RAT = np.zeros((number_samples - len(useless_samples), 1))

position = 0
print('constructing phenotypic features')
for i in range(number_samples):
	subject_name = subject_IDs[i]
	if subject_name in useless_samples:
		subject_index = get_index(lst=subject_IDs, item=subject_name)
		print('The index for sample ' + subject_name + ' is : ', subject_index)
	else:
		subject_index = get_index(lst=subject_IDs, item=subject_name)
		age[position] = float(ages[subject_index[0]].replace(' ', ''))
		gender[position] = int(genders[subject_index[0]]) + 1
		FIQ[position] = int(FIQS[subject_index[0]])
		NUM[position] = float(NUMS[subject_index[0]])
		PEC[position] = float(PECS[subject_index[0]])
		RAT[position] = int(RATS[subject_index[0]])
		position = position + 1
FIQ[FIQ == -9999] = 108

if scaler == True:

  age[:,0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(age[:,0], axis = 1)))
  FIQ[:, 0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(FIQ[:, 0], axis = 1)))
  NUM[:, 0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(NUM[:, 0], axis = 1)))
  PEC[:, 0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(PEC[:, 0], axis = 1)))

# age, gender, FIQ, NUM, PEC, RAT
for i in range(3):
	sMRI_features = np.concatenate((sMRI_features, age, gender, FIQ, NUM, PEC, RAT),axis = 1)
# Out:
# constructing phenotypic features
# The index for sample 51334 is :  [799]

# %%
dist_train = {}
dist_validation = {}
dist_test = {}
for i in range(k_fold):
	dist_train[str(i + 1)] = []
	dist_validation[str(i + 1)] = []
	dist_test[str(i + 1)] = []

for each_site in unique_sites:
	index_site = get_index(sites, each_site)
	label = np.zeros((len(index_site)))
	for i in range(len(index_site)):
		index = index_site[i]
		label[i] = int(labels[int(index)])
	########################################### StratifiedKFold ####################################################
	sfolder = StratifiedKFold(n_splits=k_fold,random_state=0,shuffle=True)
	group = 0
	for train, validation in sfolder.split(index_site,label):
		for i in train:
			dist_train[str(group + 1)].append(index_site[i])
			name = 0
		for j in validation:
			dist_validation[str(group + 1)].append(index_site[j])
			name = 0
		group = group+1

	group = 0
	for train, validation in sfolder.split(index_site,label):
		if group == 0:
			for j in validation:
				dist_test[str(group + k_fold)].append(index_site[j])
				dist_train[str(group + k_fold)].remove(index_site[j])
		else:
			for j in validation:
				dist_test[str(group)].append(index_site[j])
				dist_train[str(group)].remove(index_site[j])
		group = group+1

# %%
import torch.nn as nn
############################################### AUTO model ###############################################################
############################################### AUTO model ###############################################################
############################################### AUTO model ###############################################################
class Stacked_autoencoder(nn.Module):
	def __init__(self, in_c, hid_1, hid_2, hid_3, out, dropout_rate):

		super(Stacked_autoencoder, self).__init__()
		self.linear_1 = nn.Linear(in_features=in_c, out_features=hid_1)
		self.linear_2 = nn.Linear(in_features=hid_1, out_features=hid_2)
		self.linear_3 = nn.Linear(in_features=hid_2, out_features=hid_3)
		self.linear_4 = nn.Linear(in_features=hid_3, out_features=out)
		self.relu = nn.ReLU(inplace=True)
		self.dropout = nn.Dropout(dropout_rate)

	def forward(self, data):

		input_data = torch.flatten(data, start_dim=1, end_dim=-1)
		lin1 = self.relu(self.dropout(self.linear_1(input_data)))
		lin2 = self.relu(self.linear_2(lin1))
		lin3 = self.relu(self.linear_3(lin2))
		lin4 = self.relu(self.linear_4(lin3))

		return lin4

class MLP(nn.Module):
	def __init__(self, in_c, hid_1, hid_2, out, dropout_rate):

		super(MLP, self).__init__()
		self.linear_1 = nn.Linear(in_features=in_c, out_features=hid_1)
		self.linear_2 = nn.Linear(in_features=hid_1, out_features=hid_2)
		self.linear_3 = nn.Linear(in_features=hid_2, out_features=out)
		self.relu = nn.ReLU(inplace=True)
		self.dropout = nn.Dropout(dropout_rate)

	def forward(self, data):

		lin1 = self.relu(self.linear_1(data))
		lin2 = self.dropout(self.relu(self.linear_2(lin1)))
		lin3 = self.linear_3(lin2)

		return lin3


class Auto_encoder_MLP(nn.Module):
	def __init__(self, in_c, auto_1, auto_2, auto_3, MLP_1, MLP_2, MLP_out, dropout_rate):

		super(Auto_encoder_MLP, self).__init__()
		self.auto_encoder = Stacked_autoencoder(in_c, auto_1, auto_2, auto_3, in_c, dropout_rate)
		self.MLP = MLP(in_c, MLP_1, MLP_2, MLP_out, dropout_rate)
		self.softmax = nn.LogSoftmax(dim=1)

	def forward(self, data):

		auto_output = self.auto_encoder(data)
		MLP_out = self.MLP(auto_output)
		out = self.softmax(MLP_out)

		return out, auto_output

# %%
AUTO_labels = np.zeros((number_samples - len(useless_samples), 2))
for i in range(len(labels)):
    if labels[i] == 1:
        AUTO_labels[i,0] = 1
    else:
        AUTO_labels[i,1] = 1

data = {}
for fold in range(1, k_fold+1):
  data[str(fold)] = []
  selector = feature_selection(sMRI_features, labels, dist_train[str(fold)], new_number_features)
  fold_data = selector.transform(sMRI_features)

  data[str(fold)].append(fold_data)
  data[str(fold)].append(AUTO_labels)

# %%
############################################### Train, validaiton, test pipelines ###############################################################
############################################### Train, validaiton, test pipelines ###############################################################
############################################### Train, validaiton, test pipelines ###############################################################
def train_AUTO(args, model, all_data, fold_train_index, fold_validation_index, fold_test_index, scheduler):

    model.train()
    loss_function=torch.nn.MSELoss()

    data = torch.from_numpy(all_data[0])
    data = Variable(data, requires_grad=True)
    data = data.float()

    target = torch.from_numpy(all_data[1])
    target = target.float().long()


    if args.cuda:
        data, target = data.cuda(), target.cuda()
    
    data_train = data[fold_train_index,:] 
    target = target[fold_train_index, :]
    scheduler.zero_grad()
    out,out_auto = model(data_train)

    cross_loss = torch.nn.functional.nll_loss(out, torch.max(target, 1)[1])
    data2 = torch.squeeze(data_train)
    MSE_loss = loss_function(out_auto,data2)
    total_loss = cross_loss + MSE_loss
    total_loss.backward()
    scheduler.step()

    out = torch.max(out, 1)[1]
    target = torch.max(target, 1)[1]
    target = target.cpu().numpy()
    out = out.cpu().numpy()

    ############################## validation and test ################################################################################
    val_target, val_out, val_loss = validation_AUTO(args, model, all_data, fold_validation_index)
    test_target, test_out, test_out_prob, test_loss = test_AUTO(args, model, all_data, fold_test_index)

    return model, target, out, total_loss.item(), val_target, val_out,val_loss, test_target, test_out, test_out_prob, test_loss

    
def validation_AUTO(args, model,all_data,  fold_validation_index):

    model.eval()
    loss_function=torch.nn.MSELoss()
    data = torch.from_numpy(all_data[0])
    data = Variable(data, requires_grad=False)
    data = data.float()

    target = torch.from_numpy(all_data[1])
    target = target.float().long()


    if args.cuda:
        data, target = data.cuda(), target.cuda()


    data_val = data[fold_validation_index,:] 
    target = target[fold_validation_index, :]
    out,out_auto = model(data_val)

    cross_loss = torch.nn.functional.nll_loss(out, torch.max(target, 1)[1])
    data2 = torch.squeeze(data_val)
    MSE_loss = loss_function(out_auto,data2)
    total_loss = cross_loss + MSE_loss

    out = torch.max(out, 1)[1]
    target = torch.max(target, 1)[1]
    target = target.cpu().numpy()
    out = out.cpu().numpy()

    return target, out, total_loss.item()


def test_AUTO(args, model, all_data,  fold_test_index):

    model.eval()
    loss_function=torch.nn.MSELoss()

    data = torch.from_numpy(all_data[0])
    data = Variable(data, requires_grad=False)
    data = data.float()

    target = torch.from_numpy(all_data[1])
    target = target.float().long()


    if args.cuda:
        data, target = data.cuda(), target.cuda()
    
    data_test = data[fold_test_index,:] 
    target = target[fold_test_index, :]
    out,out_auto = model(data_test)

    cross_loss = torch.nn.functional.nll_loss(out, torch.max(target, 1)[1])
    data2 = torch.squeeze(data_test)
    MSE_loss = loss_function(out_auto,data2)
    total_loss = cross_loss + MSE_loss

    out_prob = torch.exp(out)
    out = torch.max(out, 1)[1]
    target = torch.max(target, 1)[1]
    target = target.cpu().numpy()
    out = out.cpu().numpy()
    out_prob = out_prob.cpu().detach().numpy()

    return target, out, out_prob, total_loss.item()

# %%
########################################### Training setting ################################################
########################################### Training setting ################################################
########################################### Training setting ################################################
parser = argparse.ArgumentParser()
parser.add_argument('--ngpu', type=int, default=1)
parser.add_argument('--nEpochs', type=int, default=200)
parser.add_argument('--no-cuda', action='store_true')
parser.add_argument('--seed', type=int, default=1)
parser.add_argument('--lr', type=str, default=8e-4)
# I define three kinds of optimizer, adam sgd and rmsprop, but adam performs the best
parser.add_argument('--opt', type=str, default='adam')
parser.add_argument('--auto_in', type=int, default=new_number_features)
parser.add_argument('--auto_hid_1', type=int, default=300)
parser.add_argument('--auto_hid_2', type=int, default=150)
parser.add_argument('--auto_hid_3', type=int, default=300)
parser.add_argument('--MLP_1', type=int, default=300)
parser.add_argument('--MLP_2', type=int, default=16)
parser.add_argument('--MLP_out', type=int, default=2)
parser.add_argument('--dropout_rate', type=int, default=0.5)

args, unknown = parser.parse_known_args()
args.cuda = not args.no_cuda and torch.cuda.is_available()
torch.manual_seed(args.seed)
if args.cuda:
    torch.cuda.manual_seed(args.seed)
    
gpu_ids = range(args.ngpu)
train = train_AUTO

# %%
########################################### Training ################################################
########################################### Training ################################################
########################################### Training ################################################
for fold in range(1, k_fold+1):
  model = Auto_encoder_MLP(in_c=args.auto_in, auto_1=args.auto_hid_1, auto_2=args.auto_hid_2, auto_3=args.auto_hid_3, MLP_1=args.MLP_1, MLP_2=args.MLP_2, MLP_out=args.MLP_out, dropout_rate=args.dropout_rate)
  print('  + Number of params: {}'.format(
    sum([p.data.nelement() for p in model.parameters()])))
  model = nn.parallel.DataParallel(model, device_ids=gpu_ids)
  if args.cuda:
    model = model.cuda()
  optimizer = optim.Adam(model.parameters(), lr = args.lr)

  best_validation_accuracy = 0
  Train_accuracy_list =[]
  Train_loss_list = []
  Val_accuracy_list =[]
  Val_loss_list = []
  Test_accuracy_list =[]
  Test_loss_list = []

  for epoch in range(1, args.nEpochs + 1):

    model, train_target, train_out, train_loss, val_target, val_out, val_loss, test_target, test_out, test_prob, test_loss = train(args, model, data[str(fold)], dist_train[str(fold)], dist_validation[str(fold)], dist_test[str(fold)], optimizer)

    train_accuracy = metrics.accuracy_score(train_target, train_out)
    val_accuracy = metrics.accuracy_score(val_target, val_out)
    test_accuracy = metrics.accuracy_score(test_target, test_out)
    Train_accuracy_list.append(train_accuracy)
    Val_accuracy_list.append(val_accuracy)
    Test_accuracy_list.append(test_accuracy)
    Train_loss_list.append(train_loss)
    Val_loss_list.append(val_loss)
    Test_loss_list.append(test_loss)

    if val_accuracy >=best_validation_accuracy:
      best_epoch = epoch
      best_validation_accuracy = val_accuracy
      corresponding_val_out = val_out
      corresponding_test_accuracy = test_accuracy
      corresponding_test_out = test_out
      corresponding_test_prob = test_prob

      print('Save models')
      save_model(model, save_path, 'AUTO_'+str(fold))

    print('Train Epoch: ' + str(epoch) + ': train loss : {:.8f}\t train accuracy : {:.8f}\t val accuracy : {:.8f}\t test accuracy : {:.8f}\t'.format(
      train_loss, train_accuracy, val_accuracy, test_accuracy))
  
  if fold == 1:
    all_fold_val_label = val_target
    all_fold_val_out = corresponding_val_out
    all_fold_test_label = test_target
    all_fold_test_out = corresponding_test_out
    all_fold_test_prob = corresponding_test_prob
  else:
    all_fold_val_label = np.concatenate((all_fold_val_label, val_target),axis = 0)
    all_fold_val_out = np.concatenate((all_fold_val_out, corresponding_val_out),axis = 0)
    all_fold_test_label = np.concatenate((all_fold_test_label, test_target),axis = 0)
    all_fold_test_out = np.concatenate((all_fold_test_out, corresponding_test_out),axis = 0)
    all_fold_test_prob = np.concatenate((all_fold_test_prob, corresponding_test_prob),axis = 0)

  x_axis = list(range(1, len(Train_accuracy_list)+1))
  plt.figure(figsize=(10,6))
  plt.plot(x_axis, Train_loss_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_loss_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_loss_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()

  plt.figure(figsize=(10,6))
  plt.plot(x_axis, Train_accuracy_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_accuracy_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_accuracy_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()


  test_fpr, test_tpr, te_thresholds = roc_curve(test_target, corresponding_test_prob[:,1],pos_label=1)
  test_auc = auc(test_fpr, test_tpr)
  print('\n')
  print('In fold ',str(fold))
  print('The best validaiton accuracy is: ',best_validation_accuracy)
  print('Happened at epoch: ',best_epoch)
  print('The corresponding test accuracy', corresponding_test_accuracy)
  print('The corresponding test AUC is: ',test_auc)
  print('\n')


  plt.grid()
  plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
  plt.plot([0,1],[0,1],'g--')
  plt.legend()
  plt.xlabel("False Positive Rate")
  plt.ylabel("True Positive Rate")
  plt.title("Test AUC(ROC curve)")
  plt.grid(color='black', linestyle='-', linewidth=0.5)
  plt.show()

print('Finish 5-fold training')
# Out:
#   + Number of params: 1388835
# Save models
# Train Epoch: 1: train loss : 1.38859582	 train accuracy : 0.54598826	 val accuracy : 0.52747253	 test accuracy : 0.51977401
# Save models
# Train Epoch: 2: train loss : 1.38392663	 train accuracy : 0.54598826	 val accuracy : 0.52747253	 test accuracy : 0.51977401
# Save models
# Train Epoch: 3: train loss : 1.37905812	 train accuracy : 0.54598826	 val accuracy : 0.52747253	 test accuracy : 0.51412429
# Save models
# Train Epoch: 4: train loss : 1.37025070	 train accuracy : 0.57338552	 val accuracy : 0.55494505	 test accuracy : 0.54802260
# Train Epoch: 5: train loss : 1.35884571	 train accuracy : 0.59099804	 val accuracy : 0.53846154	 test accuracy : 0.54802260
# Train Epoch: 6: train loss : 1.34942698	 train accuracy : 0.59491194	 val accuracy : 0.51098901	 test accuracy : 0.54237288
# Save models
# Train Epoch: 7: train loss : 1.33200991	 train accuracy : 0.59686888	 val accuracy : 0.56043956	 test accuracy : 0.54802260
# Train Epoch: 8: train loss : 1.30841887	 train accuracy : 0.65166341	 val accuracy : 0.55494505	 test accuracy : 0.56497175
# Save models
# Train Epoch: 9: train loss : 1.28179121	 train accuracy : 0.67710372	 val accuracy : 0.59890110	 test accuracy : 0.57062147
# Save models
# Train Epoch: 10: train loss : 1.27107859	 train accuracy : 0.68297456	 val accuracy : 0.60989011	 test accuracy : 0.58192090
# Save models
# Train Epoch: 11: train loss : 1.22016561	 train accuracy : 0.74951076	 val accuracy : 0.64835165	 test accuracy : 0.57062147
# Train Epoch: 12: train loss : 1.19943988	 train accuracy : 0.73972603	 val accuracy : 0.63736264	 test accuracy : 0.58192090
# Save models
# Train Epoch: 13: train loss : 1.14179778	 train accuracy : 0.78669276	 val accuracy : 0.65934066	 test accuracy : 0.58757062
# Train Epoch: 14: train loss : 1.07499921	 train accuracy : 0.86105675	 val accuracy : 0.64285714	 test accuracy : 0.58192090
# Train Epoch: 15: train loss : 1.03584075	 train accuracy : 0.86692759	 val accuracy : 0.64285714	 test accuracy : 0.57627119
# Save models
# Train Epoch: 16: train loss : 1.00905454	 train accuracy : 0.88454012	 val accuracy : 0.67032967	 test accuracy : 0.59887006
# Train Epoch: 17: train loss : 0.98225451	 train accuracy : 0.88258317	 val accuracy : 0.64285714	 test accuracy : 0.62711864
# Save models
# Train Epoch: 18: train loss : 0.93786883	 train accuracy : 0.91389432	 val accuracy : 0.67582418	 test accuracy : 0.60451977
# Train Epoch: 19: train loss : 0.89792413	 train accuracy : 0.94520548	 val accuracy : 0.67032967	 test accuracy : 0.61016949
# Train Epoch: 20: train loss : 0.85130286	 train accuracy : 0.95107632	 val accuracy : 0.65934066	 test accuracy : 0.59887006
# Train Epoch: 21: train loss : 0.85319424	 train accuracy : 0.94716243	 val accuracy : 0.64835165	 test accuracy : 0.59887006
# Train Epoch: 22: train loss : 0.85198778	 train accuracy : 0.95890411	 val accuracy : 0.63186813	 test accuracy : 0.59322034
# Train Epoch: 23: train loss : 0.78613466	 train accuracy : 0.97064579	 val accuracy : 0.62087912	 test accuracy : 0.57062147
# Train Epoch: 24: train loss : 0.80385762	 train accuracy : 0.96868885	 val accuracy : 0.62087912	 test accuracy : 0.59322034
# Train Epoch: 25: train loss : 0.76505709	 train accuracy : 0.97651663	 val accuracy : 0.59890110	 test accuracy : 0.58757062
# Train Epoch: 26: train loss : 0.76464975	 train accuracy : 0.97260274	 val accuracy : 0.58791209	 test accuracy : 0.57062147
# Train Epoch: 27: train loss : 0.76441568	 train accuracy : 0.95694716	 val accuracy : 0.60439560	 test accuracy : 0.57627119
# Train Epoch: 28: train loss : 0.77313638	 train accuracy : 0.95694716	 val accuracy : 0.60439560	 test accuracy : 0.58192090
# Train Epoch: 29: train loss : 0.73902941	 train accuracy : 0.97651663	 val accuracy : 0.60439560	 test accuracy : 0.59887006
# Train Epoch: 30: train loss : 0.72544754	 train accuracy : 0.98043053	 val accuracy : 0.60989011	 test accuracy : 0.57627119
# Train Epoch: 31: train loss : 0.73754364	 train accuracy : 0.97064579	 val accuracy : 0.62087912	 test accuracy : 0.58757062
# Train Epoch: 32: train loss : 0.73359764	 train accuracy : 0.97064579	 val accuracy : 0.62087912	 test accuracy : 0.58757062
# Train Epoch: 33: train loss : 0.72125292	 train accuracy : 0.97651663	 val accuracy : 0.58241758	 test accuracy : 0.61581921
# Train Epoch: 34: train loss : 0.72122771	 train accuracy : 0.96281800	 val accuracy : 0.57692308	 test accuracy : 0.61016949
# Train Epoch: 35: train loss : 0.70187020	 train accuracy : 0.98434442	 val accuracy : 0.57692308	 test accuracy : 0.60451977
# Train Epoch: 36: train loss : 0.72802812	 train accuracy : 0.97260274	 val accuracy : 0.58791209	 test accuracy : 0.59887006
# Train Epoch: 37: train loss : 0.71665317	 train accuracy : 0.97064579	 val accuracy : 0.59340659	 test accuracy : 0.61016949
# Train Epoch: 38: train loss : 0.71370900	 train accuracy : 0.97260274	 val accuracy : 0.58791209	 test accuracy : 0.62146893
# Train Epoch: 39: train loss : 0.69119912	 train accuracy : 0.97651663	 val accuracy : 0.59890110	 test accuracy : 0.59887006
# Train Epoch: 40: train loss : 0.69250667	 train accuracy : 0.97455969	 val accuracy : 0.59890110	 test accuracy : 0.61016949
# Train Epoch: 41: train loss : 0.68800539	 train accuracy : 0.98630137	 val accuracy : 0.60989011	 test accuracy : 0.59887006
# Train Epoch: 42: train loss : 0.68986320	 train accuracy : 0.97455969	 val accuracy : 0.61538462	 test accuracy : 0.60451977
# Train Epoch: 43: train loss : 0.73050892	 train accuracy : 0.96477495	 val accuracy : 0.61538462	 test accuracy : 0.62711864
# Train Epoch: 44: train loss : 0.68951541	 train accuracy : 0.97064579	 val accuracy : 0.60989011	 test accuracy : 0.60451977
# Train Epoch: 45: train loss : 0.72348547	 train accuracy : 0.95890411	 val accuracy : 0.59890110	 test accuracy : 0.62146893
# Train Epoch: 46: train loss : 0.69873893	 train accuracy : 0.98043053	 val accuracy : 0.59340659	 test accuracy : 0.58192090
# Train Epoch: 47: train loss : 0.68115366	 train accuracy : 0.98238748	 val accuracy : 0.59340659	 test accuracy : 0.57627119
# Train Epoch: 48: train loss : 0.70177841	 train accuracy : 0.96868885	 val accuracy : 0.59890110	 test accuracy : 0.58757062
# Train Epoch: 49: train loss : 0.66774553	 train accuracy : 0.98825832	 val accuracy : 0.59340659	 test accuracy : 0.60451977
# Train Epoch: 50: train loss : 0.68113828	 train accuracy : 0.98043053	 val accuracy : 0.60439560	 test accuracy : 0.61581921
# Train Epoch: 51: train loss : 0.70740575	 train accuracy : 0.97455969	 val accuracy : 0.59340659	 test accuracy : 0.58757062
# Train Epoch: 52: train loss : 0.68444431	 train accuracy : 0.97455969	 val accuracy : 0.58241758	 test accuracy : 0.59887006
# Train Epoch: 53: train loss : 0.66623145	 train accuracy : 0.98434442	 val accuracy : 0.58241758	 test accuracy : 0.58192090
# Train Epoch: 54: train loss : 0.67510301	 train accuracy : 0.98043053	 val accuracy : 0.58791209	 test accuracy : 0.57062147
# Train Epoch: 55: train loss : 0.68214053	 train accuracy : 0.97847358	 val accuracy : 0.58241758	 test accuracy : 0.58192090
# Train Epoch: 56: train loss : 0.68076849	 train accuracy : 0.97651663	 val accuracy : 0.58791209	 test accuracy : 0.62146893
# Train Epoch: 57: train loss : 0.68559110	 train accuracy : 0.97651663	 val accuracy : 0.57692308	 test accuracy : 0.62711864
# Train Epoch: 58: train loss : 0.65871119	 train accuracy : 0.99217221	 val accuracy : 0.56593407	 test accuracy : 0.61016949
# Train Epoch: 59: train loss : 0.67259669	 train accuracy : 0.98630137	 val accuracy : 0.56593407	 test accuracy : 0.61016949
# Train Epoch: 60: train loss : 0.67505264	 train accuracy : 0.99021526	 val accuracy : 0.60439560	 test accuracy : 0.61016949
# Train Epoch: 61: train loss : 0.65786934	 train accuracy : 0.99021526	 val accuracy : 0.60989011	 test accuracy : 0.62146893
# Train Epoch: 62: train loss : 0.65379953	 train accuracy : 0.99412916	 val accuracy : 0.62637363	 test accuracy : 0.58192090
# Train Epoch: 63: train loss : 0.67207056	 train accuracy : 0.98434442	 val accuracy : 0.62087912	 test accuracy : 0.57062147
# Train Epoch: 64: train loss : 0.65635681	 train accuracy : 0.98825832	 val accuracy : 0.62087912	 test accuracy : 0.58192090
# Train Epoch: 65: train loss : 0.65121794	 train accuracy : 0.98434442	 val accuracy : 0.61538462	 test accuracy : 0.57627119
# Train Epoch: 66: train loss : 0.65097153	 train accuracy : 0.99412916	 val accuracy : 0.60439560	 test accuracy : 0.59322034
# Train Epoch: 67: train loss : 0.66788316	 train accuracy : 0.98630137	 val accuracy : 0.61538462	 test accuracy : 0.61581921
# Train Epoch: 68: train loss : 0.65011042	 train accuracy : 0.98630137	 val accuracy : 0.60989011	 test accuracy : 0.62146893
# Train Epoch: 69: train loss : 0.65225589	 train accuracy : 0.98630137	 val accuracy : 0.60989011	 test accuracy : 0.61581921
# Train Epoch: 70: train loss : 0.67870599	 train accuracy : 0.97651663	 val accuracy : 0.60989011	 test accuracy : 0.59322034
# Train Epoch: 71: train loss : 0.65017968	 train accuracy : 0.99021526	 val accuracy : 0.61538462	 test accuracy : 0.60451977
# Train Epoch: 72: train loss : 0.66621381	 train accuracy : 0.98825832	 val accuracy : 0.58241758	 test accuracy : 0.59887006
# Train Epoch: 73: train loss : 0.64408171	 train accuracy : 0.99217221	 val accuracy : 0.59340659	 test accuracy : 0.60451977
# Train Epoch: 74: train loss : 0.65335625	 train accuracy : 0.99021526	 val accuracy : 0.59340659	 test accuracy : 0.59322034
# Train Epoch: 75: train loss : 0.64501488	 train accuracy : 0.99412916	 val accuracy : 0.61538462	 test accuracy : 0.60451977
# Train Epoch: 76: train loss : 0.64667279	 train accuracy : 0.99217221	 val accuracy : 0.61538462	 test accuracy : 0.59887006
# Train Epoch: 77: train loss : 0.63815784	 train accuracy : 0.99608611	 val accuracy : 0.61538462	 test accuracy : 0.61016949
# Train Epoch: 78: train loss : 0.63983536	 train accuracy : 0.99412916	 val accuracy : 0.58791209	 test accuracy : 0.60451977
# Train Epoch: 79: train loss : 0.64424419	 train accuracy : 0.99021526	 val accuracy : 0.58791209	 test accuracy : 0.59887006
# Train Epoch: 80: train loss : 0.64767653	 train accuracy : 0.99021526	 val accuracy : 0.59890110	 test accuracy : 0.59887006
# Train Epoch: 81: train loss : 0.64174968	 train accuracy : 0.99608611	 val accuracy : 0.60989011	 test accuracy : 0.59322034
# Train Epoch: 82: train loss : 0.64127213	 train accuracy : 0.99412916	 val accuracy : 0.59890110	 test accuracy : 0.59322034
# Train Epoch: 83: train loss : 0.63571852	 train accuracy : 0.99217221	 val accuracy : 0.59890110	 test accuracy : 0.59322034
# Train Epoch: 84: train loss : 0.65503252	 train accuracy : 0.98630137	 val accuracy : 0.60989011	 test accuracy : 0.57627119
# Train Epoch: 85: train loss : 0.64008147	 train accuracy : 0.99021526	 val accuracy : 0.59340659	 test accuracy : 0.57627119
# Train Epoch: 86: train loss : 0.63247746	 train accuracy : 0.99804305	 val accuracy : 0.58241758	 test accuracy : 0.58757062
# Train Epoch: 87: train loss : 0.64054245	 train accuracy : 0.99217221	 val accuracy : 0.58791209	 test accuracy : 0.57627119
# Train Epoch: 88: train loss : 0.66176397	 train accuracy : 0.99021526	 val accuracy : 0.62087912	 test accuracy : 0.59322034
# Train Epoch: 89: train loss : 0.64318985	 train accuracy : 0.98825832	 val accuracy : 0.62637363	 test accuracy : 0.58192090
# Train Epoch: 90: train loss : 0.63096303	 train accuracy : 0.99412916	 val accuracy : 0.61538462	 test accuracy : 0.57062147
# Train Epoch: 91: train loss : 0.64430153	 train accuracy : 0.99021526	 val accuracy : 0.58791209	 test accuracy : 0.59322034
# Train Epoch: 92: train loss : 0.63919759	 train accuracy : 0.99412916	 val accuracy : 0.58791209	 test accuracy : 0.58757062
# Train Epoch: 93: train loss : 0.64632976	 train accuracy : 0.99412916	 val accuracy : 0.59340659	 test accuracy : 0.59322034
# Train Epoch: 94: train loss : 0.65549946	 train accuracy : 0.99021526	 val accuracy : 0.55494505	 test accuracy : 0.58192090
# Train Epoch: 95: train loss : 0.67649812	 train accuracy : 0.98043053	 val accuracy : 0.58241758	 test accuracy : 0.60451977
# Train Epoch: 96: train loss : 0.63606340	 train accuracy : 0.99412916	 val accuracy : 0.59340659	 test accuracy : 0.60451977
# Train Epoch: 97: train loss : 0.62656474	 train accuracy : 0.99608611	 val accuracy : 0.56043956	 test accuracy : 0.57062147
# Train Epoch: 98: train loss : 0.64066964	 train accuracy : 0.98825832	 val accuracy : 0.57692308	 test accuracy : 0.59887006
# Train Epoch: 99: train loss : 0.63354117	 train accuracy : 0.99412916	 val accuracy : 0.59340659	 test accuracy : 0.59887006
# Train Epoch: 100: train loss : 0.63727927	 train accuracy : 0.99412916	 val accuracy : 0.57692308	 test accuracy : 0.59322034
# Train Epoch: 101: train loss : 0.64295977	 train accuracy : 0.98825832	 val accuracy : 0.59340659	 test accuracy : 0.58757062
# Train Epoch: 102: train loss : 0.64338094	 train accuracy : 0.99021526	 val accuracy : 0.59340659	 test accuracy : 0.59322034
# Train Epoch: 103: train loss : 0.66579759	 train accuracy : 0.98434442	 val accuracy : 0.60439560	 test accuracy : 0.59887006
# Train Epoch: 104: train loss : 0.62950104	 train accuracy : 0.99608611	 val accuracy : 0.59340659	 test accuracy : 0.59887006
# Train Epoch: 105: train loss : 0.66832387	 train accuracy : 0.98043053	 val accuracy : 0.59340659	 test accuracy : 0.59322034
# Train Epoch: 106: train loss : 0.63218039	 train accuracy : 0.99412916	 val accuracy : 0.60989011	 test accuracy : 0.59887006
# Train Epoch: 107: train loss : 0.66793501	 train accuracy : 0.99217221	 val accuracy : 0.60439560	 test accuracy : 0.61016949
# Train Epoch: 108: train loss : 0.63519120	 train accuracy : 0.99412916	 val accuracy : 0.60439560	 test accuracy : 0.60451977
# Train Epoch: 109: train loss : 0.63241297	 train accuracy : 0.99412916	 val accuracy : 0.59890110	 test accuracy : 0.59322034
# Train Epoch: 110: train loss : 0.63253534	 train accuracy : 0.99412916	 val accuracy : 0.57142857	 test accuracy : 0.57627119
# Train Epoch: 111: train loss : 0.62922674	 train accuracy : 0.99608611	 val accuracy : 0.58791209	 test accuracy : 0.57062147
# Train Epoch: 112: train loss : 0.63134402	 train accuracy : 0.99608611	 val accuracy : 0.59340659	 test accuracy : 0.55932203
# Train Epoch: 113: train loss : 0.62430012	 train accuracy : 0.99608611	 val accuracy : 0.59340659	 test accuracy : 0.55367232
# Train Epoch: 114: train loss : 0.63478065	 train accuracy : 0.99021526	 val accuracy : 0.59340659	 test accuracy : 0.57627119
# Train Epoch: 115: train loss : 0.62449819	 train accuracy : 0.99412916	 val accuracy : 0.58791209	 test accuracy : 0.57062147
# Train Epoch: 116: train loss : 0.62387747	 train accuracy : 0.99217221	 val accuracy : 0.58241758	 test accuracy : 0.57627119
# Train Epoch: 117: train loss : 0.62338132	 train accuracy : 0.99608611	 val accuracy : 0.58241758	 test accuracy : 0.57062147
# Train Epoch: 118: train loss : 0.62399828	 train accuracy : 0.99804305	 val accuracy : 0.57692308	 test accuracy : 0.56497175
# Train Epoch: 119: train loss : 0.63327807	 train accuracy : 0.99608611	 val accuracy : 0.58791209	 test accuracy : 0.56497175
# Train Epoch: 120: train loss : 0.63945216	 train accuracy : 0.98825832	 val accuracy : 0.57692308	 test accuracy : 0.58192090
# Train Epoch: 121: train loss : 0.64021200	 train accuracy : 0.98825832	 val accuracy : 0.58241758	 test accuracy : 0.58192090
# Train Epoch: 122: train loss : 0.64592212	 train accuracy : 0.99804305	 val accuracy : 0.56593407	 test accuracy : 0.58757062
# Train Epoch: 123: train loss : 0.63415515	 train accuracy : 0.99021526	 val accuracy : 0.58241758	 test accuracy : 0.57627119
# Train Epoch: 124: train loss : 0.61582547	 train accuracy : 0.99804305	 val accuracy : 0.58241758	 test accuracy : 0.56497175
# Train Epoch: 125: train loss : 0.63627416	 train accuracy : 0.99021526	 val accuracy : 0.59340659	 test accuracy : 0.55932203
# Train Epoch: 126: train loss : 0.64078176	 train accuracy : 0.98434442	 val accuracy : 0.58241758	 test accuracy : 0.56497175
# Train Epoch: 127: train loss : 0.62095320	 train accuracy : 0.99412916	 val accuracy : 0.58241758	 test accuracy : 0.57627119
# Train Epoch: 128: train loss : 0.63424671	 train accuracy : 0.99608611	 val accuracy : 0.59890110	 test accuracy : 0.58757062
# Train Epoch: 129: train loss : 0.63347638	 train accuracy : 0.98630137	 val accuracy : 0.59890110	 test accuracy : 0.59887006
# Train Epoch: 130: train loss : 0.62736017	 train accuracy : 0.99217221	 val accuracy : 0.57692308	 test accuracy : 0.59887006
# Train Epoch: 131: train loss : 0.62759560	 train accuracy : 0.99412916	 val accuracy : 0.58241758	 test accuracy : 0.58192090
# Train Epoch: 132: train loss : 0.64042372	 train accuracy : 0.99412916	 val accuracy : 0.57692308	 test accuracy : 0.58757062
# Train Epoch: 133: train loss : 0.62907559	 train accuracy : 0.99217221	 val accuracy : 0.60989011	 test accuracy : 0.58192090
# Train Epoch: 134: train loss : 0.61621428	 train accuracy : 0.99412916	 val accuracy : 0.62637363	 test accuracy : 0.61581921
# Train Epoch: 135: train loss : 0.62865561	 train accuracy : 0.99217221	 val accuracy : 0.63186813	 test accuracy : 0.60451977
# Train Epoch: 136: train loss : 0.62704021	 train accuracy : 0.98825832	 val accuracy : 0.62637363	 test accuracy : 0.58757062
# Train Epoch: 137: train loss : 0.63355947	 train accuracy : 0.99217221	 val accuracy : 0.63186813	 test accuracy : 0.58192090
# Train Epoch: 138: train loss : 0.62686026	 train accuracy : 0.98630137	 val accuracy : 0.61538462	 test accuracy : 0.57062147
# Train Epoch: 139: train loss : 0.61227745	 train accuracy : 0.99804305	 val accuracy : 0.59340659	 test accuracy : 0.58757062
# Train Epoch: 140: train loss : 0.62655300	 train accuracy : 0.99804305	 val accuracy : 0.58241758	 test accuracy : 0.58192090
# Train Epoch: 141: train loss : 0.61224657	 train accuracy : 0.99608611	 val accuracy : 0.58241758	 test accuracy : 0.58757062
# Train Epoch: 142: train loss : 0.67075872	 train accuracy : 0.98043053	 val accuracy : 0.58241758	 test accuracy : 0.59887006
# Train Epoch: 143: train loss : 0.64723217	 train accuracy : 0.99021526	 val accuracy : 0.58241758	 test accuracy : 0.60451977
# Train Epoch: 144: train loss : 0.62680781	 train accuracy : 0.99021526	 val accuracy : 0.60439560	 test accuracy : 0.60451977
# Train Epoch: 145: train loss : 0.61921984	 train accuracy : 0.99412916	 val accuracy : 0.62087912	 test accuracy : 0.59322034
# Train Epoch: 146: train loss : 0.62471110	 train accuracy : 0.99804305	 val accuracy : 0.63186813	 test accuracy : 0.58757062
# Train Epoch: 147: train loss : 0.62918919	 train accuracy : 0.99217221	 val accuracy : 0.63186813	 test accuracy : 0.59887006
# Train Epoch: 148: train loss : 0.61359936	 train accuracy : 0.99608611	 val accuracy : 0.62637363	 test accuracy : 0.59322034
# Train Epoch: 149: train loss : 0.61255538	 train accuracy : 0.99608611	 val accuracy : 0.61538462	 test accuracy : 0.59887006
# Train Epoch: 150: train loss : 0.61211258	 train accuracy : 0.99608611	 val accuracy : 0.60439560	 test accuracy : 0.60451977
# Train Epoch: 151: train loss : 0.62054121	 train accuracy : 0.99021526	 val accuracy : 0.59890110	 test accuracy : 0.59887006
# Train Epoch: 152: train loss : 0.61643648	 train accuracy : 0.99217221	 val accuracy : 0.60989011	 test accuracy : 0.59887006
# Train Epoch: 153: train loss : 0.62953204	 train accuracy : 0.99804305	 val accuracy : 0.62637363	 test accuracy : 0.61016949
# Train Epoch: 154: train loss : 0.63888961	 train accuracy : 0.99217221	 val accuracy : 0.60989011	 test accuracy : 0.61016949
# Train Epoch: 155: train loss : 0.62246615	 train accuracy : 0.99217221	 val accuracy : 0.60989011	 test accuracy : 0.59887006
# Train Epoch: 156: train loss : 0.62078005	 train accuracy : 0.99021526	 val accuracy : 0.60439560	 test accuracy : 0.58192090
# Train Epoch: 157: train loss : 0.61747217	 train accuracy : 0.99412916	 val accuracy : 0.59340659	 test accuracy : 0.58192090
# Train Epoch: 158: train loss : 0.62669426	 train accuracy : 0.99412916	 val accuracy : 0.59890110	 test accuracy : 0.57627119
# Train Epoch: 159: train loss : 0.62055582	 train accuracy : 0.99608611	 val accuracy : 0.56043956	 test accuracy : 0.59322034
# Train Epoch: 160: train loss : 0.61361802	 train accuracy : 0.99217221	 val accuracy : 0.57692308	 test accuracy : 0.61581921
# Train Epoch: 161: train loss : 0.60759491	 train accuracy : 0.99804305	 val accuracy : 0.58791209	 test accuracy : 0.60451977
# Train Epoch: 162: train loss : 0.61622238	 train accuracy : 0.99608611	 val accuracy : 0.59890110	 test accuracy : 0.57627119
# Train Epoch: 163: train loss : 0.62842131	 train accuracy : 0.98630137	 val accuracy : 0.59890110	 test accuracy : 0.58757062
# Train Epoch: 164: train loss : 0.61008298	 train accuracy : 0.99804305	 val accuracy : 0.57692308	 test accuracy : 0.59887006
# Train Epoch: 165: train loss : 0.61221623	 train accuracy : 0.99217221	 val accuracy : 0.59340659	 test accuracy : 0.60451977
# Train Epoch: 166: train loss : 0.63424814	 train accuracy : 0.99021526	 val accuracy : 0.62087912	 test accuracy : 0.60451977
# Train Epoch: 167: train loss : 0.61348444	 train accuracy : 0.99608611	 val accuracy : 0.60439560	 test accuracy : 0.60451977
# Train Epoch: 168: train loss : 0.61129719	 train accuracy : 0.99412916	 val accuracy : 0.59340659	 test accuracy : 0.61581921
# Train Epoch: 169: train loss : 0.60847718	 train accuracy : 0.99804305	 val accuracy : 0.60439560	 test accuracy : 0.61581921
# Train Epoch: 170: train loss : 0.60964668	 train accuracy : 0.99804305	 val accuracy : 0.60439560	 test accuracy : 0.60451977
# Train Epoch: 171: train loss : 0.61441374	 train accuracy : 0.99021526	 val accuracy : 0.61538462	 test accuracy : 0.59887006
# Train Epoch: 172: train loss : 0.61082643	 train accuracy : 0.99608611	 val accuracy : 0.61538462	 test accuracy : 0.58757062
# Train Epoch: 173: train loss : 0.61681640	 train accuracy : 0.99412916	 val accuracy : 0.60439560	 test accuracy : 0.58757062
# Train Epoch: 174: train loss : 0.62801361	 train accuracy : 0.99021526	 val accuracy : 0.61538462	 test accuracy : 0.59322034
# Train Epoch: 175: train loss : 0.60532546	 train accuracy : 0.99412916	 val accuracy : 0.59890110	 test accuracy : 0.58757062
# Train Epoch: 176: train loss : 0.63018990	 train accuracy : 0.99804305	 val accuracy : 0.60439560	 test accuracy : 0.59887006
# Train Epoch: 177: train loss : 0.61145365	 train accuracy : 0.99608611	 val accuracy : 0.60439560	 test accuracy : 0.61581921
# Train Epoch: 178: train loss : 0.60796887	 train accuracy : 0.99608611	 val accuracy : 0.60989011	 test accuracy : 0.61016949
# Train Epoch: 179: train loss : 0.61373115	 train accuracy : 0.99217221	 val accuracy : 0.60439560	 test accuracy : 0.60451977
# Train Epoch: 180: train loss : 0.60529488	 train accuracy : 0.99804305	 val accuracy : 0.60439560	 test accuracy : 0.61016949
# Train Epoch: 181: train loss : 0.61267257	 train accuracy : 0.99217221	 val accuracy : 0.61538462	 test accuracy : 0.59887006
# Train Epoch: 182: train loss : 0.60949981	 train accuracy : 0.99412916	 val accuracy : 0.62087912	 test accuracy : 0.61016949
# Train Epoch: 183: train loss : 0.61622643	 train accuracy : 0.99021526	 val accuracy : 0.61538462	 test accuracy : 0.62711864
# Train Epoch: 184: train loss : 0.60368729	 train accuracy : 0.99804305	 val accuracy : 0.62087912	 test accuracy : 0.61581921
# Train Epoch: 185: train loss : 0.60710073	 train accuracy : 0.99217221	 val accuracy : 0.61538462	 test accuracy : 0.61581921
# Train Epoch: 186: train loss : 0.60104251	 train accuracy : 0.99608611	 val accuracy : 0.60989011	 test accuracy : 0.59887006
# Train Epoch: 187: train loss : 0.60525781	 train accuracy : 0.99608611	 val accuracy : 0.59890110	 test accuracy : 0.59887006
# Train Epoch: 188: train loss : 0.60789943	 train accuracy : 0.99412916	 val accuracy : 0.59890110	 test accuracy : 0.59887006
# Train Epoch: 189: train loss : 0.61007458	 train accuracy : 0.99412916	 val accuracy : 0.62087912	 test accuracy : 0.59887006
# Train Epoch: 190: train loss : 0.60836232	 train accuracy : 0.99217221	 val accuracy : 0.60989011	 test accuracy : 0.59887006
# Train Epoch: 191: train loss : 0.60547882	 train accuracy : 0.99217221	 val accuracy : 0.60989011	 test accuracy : 0.59322034
# Train Epoch: 192: train loss : 0.61344016	 train accuracy : 0.99021526	 val accuracy : 0.60439560	 test accuracy : 0.59887006
# Train Epoch: 193: train loss : 0.60267675	 train accuracy : 0.99412916	 val accuracy : 0.61538462	 test accuracy : 0.58192090
# Train Epoch: 194: train loss : 0.59925663	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.57627119
# Train Epoch: 195: train loss : 0.60870147	 train accuracy : 0.99021526	 val accuracy : 0.62087912	 test accuracy : 0.57627119
# Train Epoch: 196: train loss : 0.59766340	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.57627119
# Train Epoch: 197: train loss : 0.60334474	 train accuracy : 0.99608611	 val accuracy : 0.59340659	 test accuracy : 0.57627119
# Train Epoch: 198: train loss : 0.59765077	 train accuracy : 0.99804305	 val accuracy : 0.59890110	 test accuracy : 0.58192090
# Train Epoch: 199: train loss : 0.59562075	 train accuracy : 1.00000000	 val accuracy : 0.58241758	 test accuracy : 0.59322034
# Train Epoch: 200: train loss : 0.59949458	 train accuracy : 0.99608611	 val accuracy : 0.58241758	 test accuracy : 0.58757062
# In fold  1
# The best validaiton accuracy is:  0.6758241758241759
# Happened at epoch:  18
# The corresponding test accuracy 0.6045197740112994
# The corresponding test AUC is:  0.629539641943734
#   + Number of params: 1388835
# Save models
# Train Epoch: 1: train loss : 1.39305186	 train accuracy : 0.54527938	 val accuracy : 0.51977401	 test accuracy : 0.53448276
# Save models
# Train Epoch: 2: train loss : 1.38723147	 train accuracy : 0.54913295	 val accuracy : 0.51977401	 test accuracy : 0.53448276
# Save models
# Train Epoch: 3: train loss : 1.38012075	 train accuracy : 0.58381503	 val accuracy : 0.55367232	 test accuracy : 0.59770115
# Train Epoch: 4: train loss : 1.37019181	 train accuracy : 0.59152216	 val accuracy : 0.54237288	 test accuracy : 0.58045977
# Train Epoch: 5: train loss : 1.36254680	 train accuracy : 0.56840077	 val accuracy : 0.54237288	 test accuracy : 0.59195402
# Train Epoch: 6: train loss : 1.35687935	 train accuracy : 0.58188825	 val accuracy : 0.53107345	 test accuracy : 0.58620690
# Train Epoch: 7: train loss : 1.34876585	 train accuracy : 0.61657033	 val accuracy : 0.54237288	 test accuracy : 0.57471264
# Train Epoch: 8: train loss : 1.33673143	 train accuracy : 0.63391137	 val accuracy : 0.54802260	 test accuracy : 0.58045977
# Train Epoch: 9: train loss : 1.31557393	 train accuracy : 0.65895954	 val accuracy : 0.54237288	 test accuracy : 0.59195402
# Train Epoch: 10: train loss : 1.30232882	 train accuracy : 0.66473988	 val accuracy : 0.53107345	 test accuracy : 0.63218391
# Train Epoch: 11: train loss : 1.29057789	 train accuracy : 0.67630058	 val accuracy : 0.53107345	 test accuracy : 0.62643678
# Train Epoch: 12: train loss : 1.27519822	 train accuracy : 0.73988439	 val accuracy : 0.51977401	 test accuracy : 0.61494253
# Train Epoch: 13: train loss : 1.24612749	 train accuracy : 0.75144509	 val accuracy : 0.54237288	 test accuracy : 0.56896552
# Train Epoch: 14: train loss : 1.22010016	 train accuracy : 0.76878613	 val accuracy : 0.53672316	 test accuracy : 0.60344828
# Train Epoch: 15: train loss : 1.18654144	 train accuracy : 0.82851638	 val accuracy : 0.54802260	 test accuracy : 0.59770115
# Save models
# Train Epoch: 16: train loss : 1.16137195	 train accuracy : 0.80732177	 val accuracy : 0.55367232	 test accuracy : 0.60919540
# Save models
# Train Epoch: 17: train loss : 1.11898577	 train accuracy : 0.84971098	 val accuracy : 0.55367232	 test accuracy : 0.61494253
# Save models
# Train Epoch: 18: train loss : 1.10347307	 train accuracy : 0.87668593	 val accuracy : 0.55367232	 test accuracy : 0.62643678
# Train Epoch: 19: train loss : 1.07884288	 train accuracy : 0.89980732	 val accuracy : 0.54802260	 test accuracy : 0.62643678
# Save models
# Train Epoch: 20: train loss : 1.06912088	 train accuracy : 0.89980732	 val accuracy : 0.55932203	 test accuracy : 0.63793103
# Save models
# Train Epoch: 21: train loss : 1.01873517	 train accuracy : 0.93448940	 val accuracy : 0.57062147	 test accuracy : 0.59770115
# Save models
# Train Epoch: 22: train loss : 1.03163075	 train accuracy : 0.90558767	 val accuracy : 0.58757062	 test accuracy : 0.60919540
# Train Epoch: 23: train loss : 1.00398815	 train accuracy : 0.92485549	 val accuracy : 0.57062147	 test accuracy : 0.58620690
# Train Epoch: 24: train loss : 0.97944397	 train accuracy : 0.94026975	 val accuracy : 0.57062147	 test accuracy : 0.61494253
# Train Epoch: 25: train loss : 0.96848625	 train accuracy : 0.93834297	 val accuracy : 0.54237288	 test accuracy : 0.60344828
# Train Epoch: 26: train loss : 0.95734298	 train accuracy : 0.94990366	 val accuracy : 0.56497175	 test accuracy : 0.60919540
# Train Epoch: 27: train loss : 0.95003200	 train accuracy : 0.94990366	 val accuracy : 0.53107345	 test accuracy : 0.61494253
# Train Epoch: 28: train loss : 0.92679489	 train accuracy : 0.94797688	 val accuracy : 0.55367232	 test accuracy : 0.61494253
# Train Epoch: 29: train loss : 0.92033136	 train accuracy : 0.94219653	 val accuracy : 0.57062147	 test accuracy : 0.60919540
# Train Epoch: 30: train loss : 0.90585905	 train accuracy : 0.96146435	 val accuracy : 0.56497175	 test accuracy : 0.61494253
# Train Epoch: 31: train loss : 0.88266486	 train accuracy : 0.95761079	 val accuracy : 0.55367232	 test accuracy : 0.62643678
# Train Epoch: 32: train loss : 0.87527227	 train accuracy : 0.96146435	 val accuracy : 0.53672316	 test accuracy : 0.60919540
# Train Epoch: 33: train loss : 0.87690306	 train accuracy : 0.97109827	 val accuracy : 0.55932203	 test accuracy : 0.62068966
# Train Epoch: 34: train loss : 0.85461158	 train accuracy : 0.96531792	 val accuracy : 0.55932203	 test accuracy : 0.62068966
# Train Epoch: 35: train loss : 0.81184220	 train accuracy : 0.97687861	 val accuracy : 0.56497175	 test accuracy : 0.62643678
# Train Epoch: 36: train loss : 0.82240200	 train accuracy : 0.97109827	 val accuracy : 0.54237288	 test accuracy : 0.63793103
# Train Epoch: 37: train loss : 0.83194309	 train accuracy : 0.96531792	 val accuracy : 0.55932203	 test accuracy : 0.61494253
# Train Epoch: 38: train loss : 0.80367124	 train accuracy : 0.98073218	 val accuracy : 0.56497175	 test accuracy : 0.63218391
# Train Epoch: 39: train loss : 0.77977204	 train accuracy : 0.98073218	 val accuracy : 0.54802260	 test accuracy : 0.63793103
# Train Epoch: 40: train loss : 0.78644192	 train accuracy : 0.96917148	 val accuracy : 0.55932203	 test accuracy : 0.60919540
# Train Epoch: 41: train loss : 0.75552738	 train accuracy : 0.98073218	 val accuracy : 0.55367232	 test accuracy : 0.60919540
# Train Epoch: 42: train loss : 0.75305438	 train accuracy : 0.98073218	 val accuracy : 0.55367232	 test accuracy : 0.60919540
# Train Epoch: 43: train loss : 0.72033638	 train accuracy : 0.99614644	 val accuracy : 0.54237288	 test accuracy : 0.63793103
# Train Epoch: 44: train loss : 0.72555476	 train accuracy : 0.98843931	 val accuracy : 0.54802260	 test accuracy : 0.63218391
# Train Epoch: 45: train loss : 0.72643739	 train accuracy : 0.99036609	 val accuracy : 0.55367232	 test accuracy : 0.60919540
# Train Epoch: 46: train loss : 0.74151105	 train accuracy : 0.98458574	 val accuracy : 0.56497175	 test accuracy : 0.63218391
# Train Epoch: 47: train loss : 0.72941601	 train accuracy : 0.99229287	 val accuracy : 0.56497175	 test accuracy : 0.61494253
# Train Epoch: 48: train loss : 0.74083656	 train accuracy : 0.99229287	 val accuracy : 0.55932203	 test accuracy : 0.61494253
# Train Epoch: 49: train loss : 0.73297292	 train accuracy : 0.97687861	 val accuracy : 0.56497175	 test accuracy : 0.61494253
# Train Epoch: 50: train loss : 0.71797490	 train accuracy : 0.99421965	 val accuracy : 0.55932203	 test accuracy : 0.60919540
# Train Epoch: 51: train loss : 0.71850687	 train accuracy : 0.99614644	 val accuracy : 0.54237288	 test accuracy : 0.61494253
# Train Epoch: 52: train loss : 0.71015173	 train accuracy : 0.99036609	 val accuracy : 0.54237288	 test accuracy : 0.60919540
# Train Epoch: 53: train loss : 0.71847695	 train accuracy : 0.98651252	 val accuracy : 0.54237288	 test accuracy : 0.63218391
# Train Epoch: 54: train loss : 0.70104045	 train accuracy : 0.99229287	 val accuracy : 0.54237288	 test accuracy : 0.64367816
# Train Epoch: 55: train loss : 0.71978861	 train accuracy : 0.99036609	 val accuracy : 0.55367232	 test accuracy : 0.67816092
# Train Epoch: 56: train loss : 0.69961733	 train accuracy : 0.99421965	 val accuracy : 0.57062147	 test accuracy : 0.66666667
# Train Epoch: 57: train loss : 0.70581585	 train accuracy : 0.99229287	 val accuracy : 0.53672316	 test accuracy : 0.64367816
# Train Epoch: 58: train loss : 0.71196163	 train accuracy : 0.99036609	 val accuracy : 0.53107345	 test accuracy : 0.62643678
# Train Epoch: 59: train loss : 0.70412773	 train accuracy : 0.99229287	 val accuracy : 0.53672316	 test accuracy : 0.63218391
# Train Epoch: 60: train loss : 0.69370133	 train accuracy : 0.99036609	 val accuracy : 0.55367232	 test accuracy : 0.66666667
# Train Epoch: 61: train loss : 0.69335622	 train accuracy : 0.99036609	 val accuracy : 0.55932203	 test accuracy : 0.66091954
# Train Epoch: 62: train loss : 0.68844855	 train accuracy : 0.99229287	 val accuracy : 0.53672316	 test accuracy : 0.66091954
# Train Epoch: 63: train loss : 0.72581112	 train accuracy : 0.98843931	 val accuracy : 0.57062147	 test accuracy : 0.66666667
# Train Epoch: 64: train loss : 0.68447942	 train accuracy : 0.99036609	 val accuracy : 0.56497175	 test accuracy : 0.67241379
# Train Epoch: 65: train loss : 0.70300043	 train accuracy : 0.98843931	 val accuracy : 0.54802260	 test accuracy : 0.63218391
# Train Epoch: 66: train loss : 0.70376599	 train accuracy : 0.98843931	 val accuracy : 0.55367232	 test accuracy : 0.63218391
# Train Epoch: 67: train loss : 0.69721365	 train accuracy : 0.99229287	 val accuracy : 0.55367232	 test accuracy : 0.66091954
# Train Epoch: 68: train loss : 0.70880520	 train accuracy : 0.98843931	 val accuracy : 0.55932203	 test accuracy : 0.67241379
# Train Epoch: 69: train loss : 0.70273817	 train accuracy : 0.97880539	 val accuracy : 0.54802260	 test accuracy : 0.64942529
# Train Epoch: 70: train loss : 0.68517536	 train accuracy : 0.99229287	 val accuracy : 0.55367232	 test accuracy : 0.64942529
# Train Epoch: 71: train loss : 0.68622148	 train accuracy : 0.99036609	 val accuracy : 0.54237288	 test accuracy : 0.59195402
# Train Epoch: 72: train loss : 0.70553118	 train accuracy : 0.98651252	 val accuracy : 0.57062147	 test accuracy : 0.62068966
# Train Epoch: 73: train loss : 0.67655396	 train accuracy : 0.99807322	 val accuracy : 0.57062147	 test accuracy : 0.64367816
# Save models
# Train Epoch: 74: train loss : 0.69961077	 train accuracy : 0.99036609	 val accuracy : 0.58757062	 test accuracy : 0.64942529
# Train Epoch: 75: train loss : 0.69300210	 train accuracy : 0.98843931	 val accuracy : 0.58192090	 test accuracy : 0.64942529
# Train Epoch: 76: train loss : 0.68240535	 train accuracy : 0.99421965	 val accuracy : 0.56497175	 test accuracy : 0.62643678
# Train Epoch: 77: train loss : 0.69519120	 train accuracy : 0.98843931	 val accuracy : 0.57062147	 test accuracy : 0.63218391
# Train Epoch: 78: train loss : 0.69745803	 train accuracy : 0.99229287	 val accuracy : 0.58192090	 test accuracy : 0.64942529
# Train Epoch: 79: train loss : 0.68003047	 train accuracy : 0.99229287	 val accuracy : 0.57062147	 test accuracy : 0.63793103
# Train Epoch: 80: train loss : 0.67254716	 train accuracy : 0.99614644	 val accuracy : 0.54802260	 test accuracy : 0.63218391
# Train Epoch: 81: train loss : 0.70549232	 train accuracy : 0.98843931	 val accuracy : 0.56497175	 test accuracy : 0.62643678
# Train Epoch: 82: train loss : 0.68216771	 train accuracy : 0.99229287	 val accuracy : 0.57062147	 test accuracy : 0.61494253
# Train Epoch: 83: train loss : 0.67342818	 train accuracy : 0.99807322	 val accuracy : 0.57062147	 test accuracy : 0.60919540
# Train Epoch: 84: train loss : 0.67287529	 train accuracy : 0.99229287	 val accuracy : 0.56497175	 test accuracy : 0.61494253
# Train Epoch: 85: train loss : 0.67488235	 train accuracy : 0.99807322	 val accuracy : 0.57062147	 test accuracy : 0.60344828
# Train Epoch: 86: train loss : 0.66991019	 train accuracy : 0.99229287	 val accuracy : 0.55932203	 test accuracy : 0.63793103
# Train Epoch: 87: train loss : 0.65862781	 train accuracy : 0.99421965	 val accuracy : 0.56497175	 test accuracy : 0.64942529
# Train Epoch: 88: train loss : 0.66791719	 train accuracy : 0.99421965	 val accuracy : 0.57062147	 test accuracy : 0.65517241
# Save models
# Train Epoch: 89: train loss : 0.66796339	 train accuracy : 1.00000000	 val accuracy : 0.58757062	 test accuracy : 0.64942529
# Save models
# Train Epoch: 90: train loss : 0.67561090	 train accuracy : 0.99614644	 val accuracy : 0.58757062	 test accuracy : 0.66091954
# Train Epoch: 91: train loss : 0.68371648	 train accuracy : 0.99421965	 val accuracy : 0.56497175	 test accuracy : 0.65517241
# Train Epoch: 92: train loss : 0.67064655	 train accuracy : 0.99421965	 val accuracy : 0.54802260	 test accuracy : 0.63793103
# Train Epoch: 93: train loss : 0.66344923	 train accuracy : 0.99807322	 val accuracy : 0.57062147	 test accuracy : 0.61494253
# Train Epoch: 94: train loss : 0.67761898	 train accuracy : 0.99229287	 val accuracy : 0.56497175	 test accuracy : 0.62068966
# Train Epoch: 95: train loss : 0.66363555	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.63218391
# Train Epoch: 96: train loss : 0.66714185	 train accuracy : 0.99614644	 val accuracy : 0.57627119	 test accuracy : 0.64367816
# Train Epoch: 97: train loss : 0.66515559	 train accuracy : 0.98843931	 val accuracy : 0.57627119	 test accuracy : 0.61494253
# Train Epoch: 98: train loss : 0.64853090	 train accuracy : 0.99807322	 val accuracy : 0.57062147	 test accuracy : 0.59770115
# Train Epoch: 99: train loss : 0.65927470	 train accuracy : 0.99614644	 val accuracy : 0.56497175	 test accuracy : 0.60919540
# Train Epoch: 100: train loss : 0.66403842	 train accuracy : 0.99807322	 val accuracy : 0.57062147	 test accuracy : 0.62643678
# Train Epoch: 101: train loss : 0.65833408	 train accuracy : 1.00000000	 val accuracy : 0.57062147	 test accuracy : 0.60919540
# Train Epoch: 102: train loss : 0.67243743	 train accuracy : 0.99421965	 val accuracy : 0.55932203	 test accuracy : 0.60344828
# Train Epoch: 103: train loss : 0.65362245	 train accuracy : 0.99421965	 val accuracy : 0.55367232	 test accuracy : 0.61494253
# Train Epoch: 104: train loss : 0.65792555	 train accuracy : 0.99229287	 val accuracy : 0.55367232	 test accuracy : 0.62068966
# Train Epoch: 105: train loss : 0.64513040	 train accuracy : 0.99421965	 val accuracy : 0.55932203	 test accuracy : 0.62643678
# Train Epoch: 106: train loss : 0.66336066	 train accuracy : 0.99421965	 val accuracy : 0.54802260	 test accuracy : 0.63793103
# Train Epoch: 107: train loss : 0.65741205	 train accuracy : 0.99229287	 val accuracy : 0.55932203	 test accuracy : 0.63793103
# Train Epoch: 108: train loss : 0.64659774	 train accuracy : 0.99807322	 val accuracy : 0.55367232	 test accuracy : 0.62643678
# Train Epoch: 109: train loss : 0.64729613	 train accuracy : 0.99807322	 val accuracy : 0.55932203	 test accuracy : 0.61494253
# Train Epoch: 110: train loss : 0.65899289	 train accuracy : 0.99421965	 val accuracy : 0.54802260	 test accuracy : 0.59195402
# Train Epoch: 111: train loss : 0.66844797	 train accuracy : 0.99421965	 val accuracy : 0.56497175	 test accuracy : 0.59195402
# Train Epoch: 112: train loss : 0.65133166	 train accuracy : 0.99229287	 val accuracy : 0.57062147	 test accuracy : 0.60344828
# Train Epoch: 113: train loss : 0.64398360	 train accuracy : 0.99614644	 val accuracy : 0.56497175	 test accuracy : 0.60344828
# Train Epoch: 114: train loss : 0.63762522	 train accuracy : 1.00000000	 val accuracy : 0.54802260	 test accuracy : 0.62068966
# Train Epoch: 115: train loss : 0.65426105	 train accuracy : 0.99229287	 val accuracy : 0.55367232	 test accuracy : 0.60919540
# Train Epoch: 116: train loss : 0.65798473	 train accuracy : 0.99614644	 val accuracy : 0.54237288	 test accuracy : 0.60344828
# Train Epoch: 117: train loss : 0.63688046	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.61494253
# Train Epoch: 118: train loss : 0.64833480	 train accuracy : 0.99807322	 val accuracy : 0.53672316	 test accuracy : 0.60919540
# Train Epoch: 119: train loss : 0.64521724	 train accuracy : 0.99614644	 val accuracy : 0.54237288	 test accuracy : 0.61494253
# Train Epoch: 120: train loss : 0.64608634	 train accuracy : 0.99614644	 val accuracy : 0.54802260	 test accuracy : 0.60919540
# Train Epoch: 121: train loss : 0.64742047	 train accuracy : 0.99807322	 val accuracy : 0.54237288	 test accuracy : 0.60344828
# Train Epoch: 122: train loss : 0.64638406	 train accuracy : 0.99807322	 val accuracy : 0.55932203	 test accuracy : 0.60919540
# Train Epoch: 123: train loss : 0.65103835	 train accuracy : 0.99421965	 val accuracy : 0.55367232	 test accuracy : 0.60344828
# Train Epoch: 124: train loss : 0.65085775	 train accuracy : 0.99421965	 val accuracy : 0.54237288	 test accuracy : 0.60344828
# Train Epoch: 125: train loss : 0.64860785	 train accuracy : 0.99421965	 val accuracy : 0.54237288	 test accuracy : 0.60919540
# Train Epoch: 126: train loss : 0.63828850	 train accuracy : 0.99807322	 val accuracy : 0.55367232	 test accuracy : 0.61494253
# Train Epoch: 127: train loss : 0.64991474	 train accuracy : 0.99421965	 val accuracy : 0.54802260	 test accuracy : 0.61494253
# Train Epoch: 128: train loss : 0.65242976	 train accuracy : 0.99807322	 val accuracy : 0.54802260	 test accuracy : 0.60344828
# Train Epoch: 129: train loss : 0.63752913	 train accuracy : 0.99614644	 val accuracy : 0.53672316	 test accuracy : 0.61494253
# Train Epoch: 130: train loss : 0.64427602	 train accuracy : 0.99421965	 val accuracy : 0.54802260	 test accuracy : 0.58045977
# Train Epoch: 131: train loss : 0.64975804	 train accuracy : 0.99036609	 val accuracy : 0.54802260	 test accuracy : 0.58620690
# Train Epoch: 132: train loss : 0.65450454	 train accuracy : 0.98651252	 val accuracy : 0.53107345	 test accuracy : 0.59195402
# Train Epoch: 133: train loss : 0.64203572	 train accuracy : 1.00000000	 val accuracy : 0.53672316	 test accuracy : 0.61494253
# Train Epoch: 134: train loss : 0.64382851	 train accuracy : 0.99807322	 val accuracy : 0.53672316	 test accuracy : 0.62068966
# Train Epoch: 135: train loss : 0.67082995	 train accuracy : 0.99421965	 val accuracy : 0.55932203	 test accuracy : 0.63218391
# Train Epoch: 136: train loss : 0.64203358	 train accuracy : 0.99421965	 val accuracy : 0.54802260	 test accuracy : 0.62068966
# Train Epoch: 137: train loss : 0.64753264	 train accuracy : 0.99807322	 val accuracy : 0.55367232	 test accuracy : 0.60919540
# Train Epoch: 138: train loss : 0.64183509	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.60919540
# Train Epoch: 139: train loss : 0.64806318	 train accuracy : 0.99036609	 val accuracy : 0.57062147	 test accuracy : 0.59195402
# Train Epoch: 140: train loss : 0.69156986	 train accuracy : 0.98651252	 val accuracy : 0.55932203	 test accuracy : 0.59770115
# Train Epoch: 141: train loss : 0.63921279	 train accuracy : 0.99807322	 val accuracy : 0.57627119	 test accuracy : 0.59770115
# Train Epoch: 142: train loss : 0.65860903	 train accuracy : 0.99421965	 val accuracy : 0.55367232	 test accuracy : 0.59770115
# Train Epoch: 143: train loss : 0.66203892	 train accuracy : 0.99229287	 val accuracy : 0.51977401	 test accuracy : 0.60344828
# Train Epoch: 144: train loss : 0.63757402	 train accuracy : 0.99614644	 val accuracy : 0.54237288	 test accuracy : 0.62068966
# Train Epoch: 145: train loss : 0.64678723	 train accuracy : 0.99229287	 val accuracy : 0.54802260	 test accuracy : 0.60919540
# Train Epoch: 146: train loss : 0.67467684	 train accuracy : 0.99614644	 val accuracy : 0.54237288	 test accuracy : 0.60344828
# Train Epoch: 147: train loss : 0.66565233	 train accuracy : 0.99229287	 val accuracy : 0.54237288	 test accuracy : 0.59195402
# Train Epoch: 148: train loss : 0.67401278	 train accuracy : 0.99229287	 val accuracy : 0.54802260	 test accuracy : 0.60344828
# Train Epoch: 149: train loss : 0.66993827	 train accuracy : 0.99229287	 val accuracy : 0.55367232	 test accuracy : 0.60919540
# Train Epoch: 150: train loss : 0.64826262	 train accuracy : 0.99807322	 val accuracy : 0.53672316	 test accuracy : 0.60919540
# Train Epoch: 151: train loss : 0.64629060	 train accuracy : 0.99807322	 val accuracy : 0.53672316	 test accuracy : 0.62068966
# Train Epoch: 152: train loss : 0.65324533	 train accuracy : 0.99421965	 val accuracy : 0.53672316	 test accuracy : 0.61494253
# Train Epoch: 153: train loss : 0.67559224	 train accuracy : 0.99229287	 val accuracy : 0.53107345	 test accuracy : 0.60344828
# Train Epoch: 154: train loss : 0.66972971	 train accuracy : 0.98843931	 val accuracy : 0.53107345	 test accuracy : 0.61494253
# Train Epoch: 155: train loss : 0.65640038	 train accuracy : 0.99421965	 val accuracy : 0.55367232	 test accuracy : 0.61494253
# Train Epoch: 156: train loss : 0.66726255	 train accuracy : 0.99614644	 val accuracy : 0.56497175	 test accuracy : 0.59195402
# Train Epoch: 157: train loss : 0.67538232	 train accuracy : 0.99229287	 val accuracy : 0.55932203	 test accuracy : 0.59770115
# Train Epoch: 158: train loss : 0.66661847	 train accuracy : 0.99036609	 val accuracy : 0.56497175	 test accuracy : 0.59770115
# Train Epoch: 159: train loss : 0.67879355	 train accuracy : 0.98843931	 val accuracy : 0.54802260	 test accuracy : 0.62068966
# Train Epoch: 160: train loss : 0.64329201	 train accuracy : 0.99614644	 val accuracy : 0.56497175	 test accuracy : 0.63793103
# Train Epoch: 161: train loss : 0.65220082	 train accuracy : 0.99807322	 val accuracy : 0.55367232	 test accuracy : 0.62068966
# Train Epoch: 162: train loss : 0.65042299	 train accuracy : 0.99614644	 val accuracy : 0.53672316	 test accuracy : 0.62068966
# Train Epoch: 163: train loss : 0.69782645	 train accuracy : 0.98843931	 val accuracy : 0.57062147	 test accuracy : 0.60344828
# Train Epoch: 164: train loss : 0.66092563	 train accuracy : 0.99807322	 val accuracy : 0.54802260	 test accuracy : 0.60344828
# Train Epoch: 165: train loss : 0.65252173	 train accuracy : 0.99807322	 val accuracy : 0.57062147	 test accuracy : 0.62068966
# Train Epoch: 166: train loss : 0.65704936	 train accuracy : 0.99614644	 val accuracy : 0.55367232	 test accuracy : 0.61494253
# Train Epoch: 167: train loss : 0.64081091	 train accuracy : 0.99421965	 val accuracy : 0.55367232	 test accuracy : 0.60919540
# Train Epoch: 168: train loss : 0.65120369	 train accuracy : 0.99614644	 val accuracy : 0.55367232	 test accuracy : 0.60344828
# Train Epoch: 169: train loss : 0.65212840	 train accuracy : 0.99421965	 val accuracy : 0.55367232	 test accuracy : 0.60919540
# Train Epoch: 170: train loss : 0.64966738	 train accuracy : 0.99614644	 val accuracy : 0.55932203	 test accuracy : 0.62068966
# Train Epoch: 171: train loss : 0.66027856	 train accuracy : 0.99807322	 val accuracy : 0.55367232	 test accuracy : 0.62643678
# Train Epoch: 172: train loss : 0.64498693	 train accuracy : 0.99614644	 val accuracy : 0.56497175	 test accuracy : 0.64367816
# Train Epoch: 173: train loss : 0.64946562	 train accuracy : 0.99807322	 val accuracy : 0.55932203	 test accuracy : 0.62068966
# Train Epoch: 174: train loss : 0.64262229	 train accuracy : 0.99807322	 val accuracy : 0.55932203	 test accuracy : 0.63218391
# Train Epoch: 175: train loss : 0.63527596	 train accuracy : 0.99807322	 val accuracy : 0.55367232	 test accuracy : 0.63793103
# ...
# Train Epoch: 77: train loss : 0.68618572	 train accuracy : 0.98272553	 val accuracy : 0.55688623	 test accuracy : 0.59890110
# Train Epoch: 78: train loss : 0.67382717	 train accuracy : 0.98272553	 val accuracy : 0.53293413	 test accuracy : 0.59890110
# Train Epoch: 79: train loss : 0.66942090	 train accuracy : 0.98272553	 val accuracy : 0.53293413	 test accuracy : 0.60439560
# Train Epoch: 80: train loss : 0.68656409	 train accuracy : 0.98080614	 val accuracy : 0.52694611	 test accuracy : 0.60989011
# Train Epoch: 81: train loss : 0.67765355	 train accuracy : 0.97120921	 val accuracy : 0.54491018	 test accuracy : 0.60439560
# Train Epoch: 82: train loss : 0.67703503	 train accuracy : 0.97888676	 val accuracy : 0.54491018	 test accuracy : 0.58241758
# Train Epoch: 83: train loss : 0.66718072	 train accuracy : 0.98080614	 val accuracy : 0.55688623	 test accuracy : 0.59340659
# Train Epoch: 84: train loss : 0.68314230	 train accuracy : 0.96737044	 val accuracy : 0.55688623	 test accuracy : 0.59340659
# Train Epoch: 85: train loss : 0.66870749	 train accuracy : 0.98080614	 val accuracy : 0.53293413	 test accuracy : 0.62087912
# Train Epoch: 86: train loss : 0.65733415	 train accuracy : 0.97888676	 val accuracy : 0.53892216	 test accuracy : 0.59340659
# Train Epoch: 87: train loss : 0.66519892	 train accuracy : 0.98272553	 val accuracy : 0.53892216	 test accuracy : 0.57692308
# Train Epoch: 88: train loss : 0.65845579	 train accuracy : 0.98848369	 val accuracy : 0.54491018	 test accuracy : 0.58241758
# Train Epoch: 89: train loss : 0.66482139	 train accuracy : 0.97888676	 val accuracy : 0.54491018	 test accuracy : 0.57692308
# Train Epoch: 90: train loss : 0.66078615	 train accuracy : 0.97696737	 val accuracy : 0.54491018	 test accuracy : 0.58241758
# Train Epoch: 91: train loss : 0.68140697	 train accuracy : 0.97504798	 val accuracy : 0.55089820	 test accuracy : 0.60439560
# Train Epoch: 92: train loss : 0.65471810	 train accuracy : 0.98272553	 val accuracy : 0.55089820	 test accuracy : 0.61538462
# Train Epoch: 93: train loss : 0.67266136	 train accuracy : 0.97888676	 val accuracy : 0.55688623	 test accuracy : 0.59340659
# Train Epoch: 94: train loss : 0.65424645	 train accuracy : 0.98656430	 val accuracy : 0.57485030	 test accuracy : 0.58241758
# Train Epoch: 95: train loss : 0.65724742	 train accuracy : 0.98656430	 val accuracy : 0.56287425	 test accuracy : 0.57692308
# Train Epoch: 96: train loss : 0.67068410	 train accuracy : 0.97312860	 val accuracy : 0.55688623	 test accuracy : 0.58241758
# Train Epoch: 97: train loss : 0.64831299	 train accuracy : 0.98848369	 val accuracy : 0.55089820	 test accuracy : 0.56593407
# Train Epoch: 98: train loss : 0.66111559	 train accuracy : 0.97888676	 val accuracy : 0.56287425	 test accuracy : 0.58241758
# Train Epoch: 99: train loss : 0.64407039	 train accuracy : 0.98848369	 val accuracy : 0.55688623	 test accuracy : 0.58241758
# Train Epoch: 100: train loss : 0.65299094	 train accuracy : 0.97696737	 val accuracy : 0.53892216	 test accuracy : 0.58241758
# Train Epoch: 101: train loss : 0.65019524	 train accuracy : 0.98848369	 val accuracy : 0.54491018	 test accuracy : 0.59340659
# Train Epoch: 102: train loss : 0.64937341	 train accuracy : 0.99232246	 val accuracy : 0.55688623	 test accuracy : 0.58791209
# Train Epoch: 103: train loss : 0.65582591	 train accuracy : 0.98464491	 val accuracy : 0.55089820	 test accuracy : 0.58791209
# Train Epoch: 104: train loss : 0.65061557	 train accuracy : 0.99232246	 val accuracy : 0.55089820	 test accuracy : 0.59340659
# Train Epoch: 105: train loss : 0.66294664	 train accuracy : 0.98080614	 val accuracy : 0.55089820	 test accuracy : 0.59340659
# Train Epoch: 106: train loss : 0.64355677	 train accuracy : 0.99040307	 val accuracy : 0.56287425	 test accuracy : 0.58241758
# Train Epoch: 107: train loss : 0.63979578	 train accuracy : 0.99040307	 val accuracy : 0.53293413	 test accuracy : 0.57692308
# Train Epoch: 108: train loss : 0.65545762	 train accuracy : 0.98848369	 val accuracy : 0.53892216	 test accuracy : 0.57692308
# Train Epoch: 109: train loss : 0.65870786	 train accuracy : 0.98656430	 val accuracy : 0.59281437	 test accuracy : 0.57692308
# Train Epoch: 110: train loss : 0.64697379	 train accuracy : 0.99424184	 val accuracy : 0.56886228	 test accuracy : 0.60439560
# Train Epoch: 111: train loss : 0.65650499	 train accuracy : 0.99232246	 val accuracy : 0.55688623	 test accuracy : 0.58791209
# Train Epoch: 112: train loss : 0.63572973	 train accuracy : 0.99616123	 val accuracy : 0.55688623	 test accuracy : 0.59340659
# Train Epoch: 113: train loss : 0.64698797	 train accuracy : 0.99232246	 val accuracy : 0.53892216	 test accuracy : 0.59340659
# Train Epoch: 114: train loss : 0.64578974	 train accuracy : 0.98656430	 val accuracy : 0.52694611	 test accuracy : 0.58241758
# Train Epoch: 115: train loss : 0.64316016	 train accuracy : 0.98656430	 val accuracy : 0.52694611	 test accuracy : 0.58791209
# Train Epoch: 116: train loss : 0.70804209	 train accuracy : 0.97504798	 val accuracy : 0.54491018	 test accuracy : 0.58241758
# Train Epoch: 117: train loss : 0.64225787	 train accuracy : 0.99232246	 val accuracy : 0.54491018	 test accuracy : 0.57692308
# Train Epoch: 118: train loss : 0.65036416	 train accuracy : 0.98848369	 val accuracy : 0.55688623	 test accuracy : 0.57692308
# Train Epoch: 119: train loss : 0.64995956	 train accuracy : 0.98464491	 val accuracy : 0.57485030	 test accuracy : 0.56593407
# Train Epoch: 120: train loss : 0.68226016	 train accuracy : 0.98464491	 val accuracy : 0.55688623	 test accuracy : 0.56593407
# Train Epoch: 121: train loss : 0.65161705	 train accuracy : 0.98464491	 val accuracy : 0.55089820	 test accuracy : 0.56043956
# Train Epoch: 122: train loss : 0.64495677	 train accuracy : 0.99616123	 val accuracy : 0.53892216	 test accuracy : 0.54945055
# Train Epoch: 123: train loss : 0.66038907	 train accuracy : 0.98656430	 val accuracy : 0.53892216	 test accuracy : 0.55494505
# Train Epoch: 124: train loss : 0.66501808	 train accuracy : 0.98464491	 val accuracy : 0.55089820	 test accuracy : 0.56043956
# Train Epoch: 125: train loss : 0.64900804	 train accuracy : 0.98848369	 val accuracy : 0.52694611	 test accuracy : 0.56593407
# Train Epoch: 126: train loss : 0.65718699	 train accuracy : 0.98272553	 val accuracy : 0.54491018	 test accuracy : 0.57142857
# Train Epoch: 127: train loss : 0.64481056	 train accuracy : 0.99232246	 val accuracy : 0.54491018	 test accuracy : 0.56043956
# Train Epoch: 128: train loss : 0.64721721	 train accuracy : 0.98272553	 val accuracy : 0.54491018	 test accuracy : 0.54945055
# Train Epoch: 129: train loss : 0.64705688	 train accuracy : 0.99424184	 val accuracy : 0.53293413	 test accuracy : 0.56043956
# Train Epoch: 130: train loss : 0.66334105	 train accuracy : 0.99040307	 val accuracy : 0.52694611	 test accuracy : 0.57142857
# Train Epoch: 131: train loss : 0.67955863	 train accuracy : 0.98464491	 val accuracy : 0.53892216	 test accuracy : 0.58241758
# Train Epoch: 132: train loss : 0.65469366	 train accuracy : 0.98848369	 val accuracy : 0.55089820	 test accuracy : 0.58791209
# Train Epoch: 133: train loss : 0.66188961	 train accuracy : 0.98848369	 val accuracy : 0.52095808	 test accuracy : 0.63186813
# Train Epoch: 134: train loss : 0.65064716	 train accuracy : 0.98848369	 val accuracy : 0.48502994	 test accuracy : 0.63736264
# Train Epoch: 135: train loss : 0.68549097	 train accuracy : 0.97120921	 val accuracy : 0.50898204	 test accuracy : 0.62087912
# Train Epoch: 136: train loss : 0.65099841	 train accuracy : 0.98656430	 val accuracy : 0.49101796	 test accuracy : 0.61538462
# Train Epoch: 137: train loss : 0.64800507	 train accuracy : 0.99232246	 val accuracy : 0.53293413	 test accuracy : 0.57692308
# Train Epoch: 138: train loss : 0.65035444	 train accuracy : 0.98848369	 val accuracy : 0.55688623	 test accuracy : 0.57142857
# Train Epoch: 139: train loss : 0.64506102	 train accuracy : 0.99232246	 val accuracy : 0.57485030	 test accuracy : 0.56043956
# Train Epoch: 140: train loss : 0.64282274	 train accuracy : 0.99232246	 val accuracy : 0.55688623	 test accuracy : 0.56043956
# Train Epoch: 141: train loss : 0.65511149	 train accuracy : 0.99232246	 val accuracy : 0.55089820	 test accuracy : 0.56043956
# Train Epoch: 142: train loss : 0.64617258	 train accuracy : 0.98848369	 val accuracy : 0.55688623	 test accuracy : 0.57142857
# Train Epoch: 143: train loss : 0.65556937	 train accuracy : 0.98464491	 val accuracy : 0.53892216	 test accuracy : 0.58791209
# Train Epoch: 144: train loss : 0.66759640	 train accuracy : 0.98656430	 val accuracy : 0.53293413	 test accuracy : 0.59890110
# Train Epoch: 145: train loss : 0.66211915	 train accuracy : 0.98656430	 val accuracy : 0.49700599	 test accuracy : 0.58791209
# Train Epoch: 146: train loss : 0.67054099	 train accuracy : 0.98272553	 val accuracy : 0.49700599	 test accuracy : 0.59340659
# Train Epoch: 147: train loss : 0.64610511	 train accuracy : 0.99040307	 val accuracy : 0.49700599	 test accuracy : 0.58791209
# Train Epoch: 148: train loss : 0.64577943	 train accuracy : 0.98848369	 val accuracy : 0.52095808	 test accuracy : 0.59340659
# Train Epoch: 149: train loss : 0.64796811	 train accuracy : 0.98656430	 val accuracy : 0.53293413	 test accuracy : 0.58791209
# Train Epoch: 150: train loss : 0.63413405	 train accuracy : 0.99424184	 val accuracy : 0.53293413	 test accuracy : 0.57142857
# Train Epoch: 151: train loss : 0.64897031	 train accuracy : 0.98272553	 val accuracy : 0.53892216	 test accuracy : 0.55494505
# Train Epoch: 152: train loss : 0.65802366	 train accuracy : 0.98656430	 val accuracy : 0.55688623	 test accuracy : 0.53296703
# Train Epoch: 153: train loss : 0.63563520	 train accuracy : 0.99424184	 val accuracy : 0.55089820	 test accuracy : 0.53296703
# Train Epoch: 154: train loss : 0.63310730	 train accuracy : 0.99232246	 val accuracy : 0.55089820	 test accuracy : 0.54395604
# Train Epoch: 155: train loss : 0.63472313	 train accuracy : 0.99424184	 val accuracy : 0.55089820	 test accuracy : 0.54945055
# Train Epoch: 156: train loss : 0.64582092	 train accuracy : 0.98848369	 val accuracy : 0.54491018	 test accuracy : 0.54395604
# Train Epoch: 157: train loss : 0.65763676	 train accuracy : 0.98272553	 val accuracy : 0.54491018	 test accuracy : 0.55494505
# Train Epoch: 158: train loss : 0.63644052	 train accuracy : 0.98656430	 val accuracy : 0.53892216	 test accuracy : 0.54945055
# Train Epoch: 159: train loss : 0.63360798	 train accuracy : 0.99232246	 val accuracy : 0.53892216	 test accuracy : 0.56593407
# Train Epoch: 160: train loss : 0.63778925	 train accuracy : 0.99232246	 val accuracy : 0.55089820	 test accuracy : 0.57692308
# Train Epoch: 161: train loss : 0.64077544	 train accuracy : 0.99040307	 val accuracy : 0.54491018	 test accuracy : 0.57692308
# Train Epoch: 162: train loss : 0.63351536	 train accuracy : 0.99616123	 val accuracy : 0.52694611	 test accuracy : 0.60439560
# Train Epoch: 163: train loss : 0.63084155	 train accuracy : 0.99232246	 val accuracy : 0.50898204	 test accuracy : 0.61538462
# Train Epoch: 164: train loss : 0.65554601	 train accuracy : 0.98464491	 val accuracy : 0.51497006	 test accuracy : 0.59890110
# Train Epoch: 165: train loss : 0.64458096	 train accuracy : 0.98272553	 val accuracy : 0.51497006	 test accuracy : 0.58791209
# Train Epoch: 166: train loss : 0.63458353	 train accuracy : 0.99040307	 val accuracy : 0.53293413	 test accuracy : 0.58791209
# Train Epoch: 167: train loss : 0.63706440	 train accuracy : 0.98464491	 val accuracy : 0.53293413	 test accuracy : 0.58791209
# Train Epoch: 168: train loss : 0.62637907	 train accuracy : 0.99616123	 val accuracy : 0.53892216	 test accuracy : 0.54945055
# Train Epoch: 169: train loss : 0.63436311	 train accuracy : 0.99040307	 val accuracy : 0.52694611	 test accuracy : 0.55494505
# Train Epoch: 170: train loss : 0.64555478	 train accuracy : 0.98080614	 val accuracy : 0.52694611	 test accuracy : 0.56043956
# Train Epoch: 171: train loss : 0.63323665	 train accuracy : 0.99232246	 val accuracy : 0.54491018	 test accuracy : 0.57692308
# Train Epoch: 172: train loss : 0.64193153	 train accuracy : 0.98656430	 val accuracy : 0.54491018	 test accuracy : 0.56043956
# Train Epoch: 173: train loss : 0.63784695	 train accuracy : 0.98656430	 val accuracy : 0.53892216	 test accuracy : 0.53846154
# Train Epoch: 174: train loss : 0.63366497	 train accuracy : 0.99232246	 val accuracy : 0.53892216	 test accuracy : 0.53846154
# Train Epoch: 175: train loss : 0.62843943	 train accuracy : 0.99232246	 val accuracy : 0.52694611	 test accuracy : 0.53296703
# Train Epoch: 176: train loss : 0.62792706	 train accuracy : 0.98656430	 val accuracy : 0.52095808	 test accuracy : 0.53296703
# Train Epoch: 177: train loss : 0.63147688	 train accuracy : 0.99616123	 val accuracy : 0.52694611	 test accuracy : 0.53846154
# Train Epoch: 178: train loss : 0.63178831	 train accuracy : 0.99424184	 val accuracy : 0.52095808	 test accuracy : 0.54395604
# Train Epoch: 179: train loss : 0.62040848	 train accuracy : 0.99808061	 val accuracy : 0.55688623	 test accuracy : 0.53846154
# Train Epoch: 180: train loss : 0.62381876	 train accuracy : 0.99232246	 val accuracy : 0.56287425	 test accuracy : 0.53846154
# Train Epoch: 181: train loss : 0.64193213	 train accuracy : 0.98272553	 val accuracy : 0.55089820	 test accuracy : 0.53846154
# Train Epoch: 182: train loss : 0.62666881	 train accuracy : 0.99616123	 val accuracy : 0.55089820	 test accuracy : 0.54395604
# Train Epoch: 183: train loss : 0.62983394	 train accuracy : 0.98464491	 val accuracy : 0.54491018	 test accuracy : 0.53296703
# Train Epoch: 184: train loss : 0.64038169	 train accuracy : 0.97888676	 val accuracy : 0.53892216	 test accuracy : 0.53846154
# Train Epoch: 185: train loss : 0.63811332	 train accuracy : 0.98848369	 val accuracy : 0.53892216	 test accuracy : 0.54395604
# Train Epoch: 186: train loss : 0.61940831	 train accuracy : 0.99808061	 val accuracy : 0.53892216	 test accuracy : 0.54945055
# Train Epoch: 187: train loss : 0.62807375	 train accuracy : 0.99424184	 val accuracy : 0.53892216	 test accuracy : 0.55494505
# Train Epoch: 188: train loss : 0.64636469	 train accuracy : 0.98272553	 val accuracy : 0.53293413	 test accuracy : 0.54945055
# Train Epoch: 189: train loss : 0.63088667	 train accuracy : 0.99424184	 val accuracy : 0.54491018	 test accuracy : 0.54945055
# Train Epoch: 190: train loss : 0.63856417	 train accuracy : 0.98464491	 val accuracy : 0.55688623	 test accuracy : 0.54945055
# Train Epoch: 191: train loss : 0.62660635	 train accuracy : 0.99040307	 val accuracy : 0.56287425	 test accuracy : 0.55494505
# Train Epoch: 192: train loss : 0.63269889	 train accuracy : 0.98848369	 val accuracy : 0.55089820	 test accuracy : 0.56043956
# Train Epoch: 193: train loss : 0.62480557	 train accuracy : 0.98464491	 val accuracy : 0.53892216	 test accuracy : 0.56593407
# Train Epoch: 194: train loss : 0.62724078	 train accuracy : 0.99616123	 val accuracy : 0.50898204	 test accuracy : 0.56593407
# Train Epoch: 195: train loss : 0.62554663	 train accuracy : 0.98656430	 val accuracy : 0.50299401	 test accuracy : 0.57142857
# Train Epoch: 196: train loss : 0.62925047	 train accuracy : 0.98272553	 val accuracy : 0.55089820	 test accuracy : 0.56593407
# Train Epoch: 197: train loss : 0.63511914	 train accuracy : 0.98464491	 val accuracy : 0.56287425	 test accuracy : 0.57142857
# Train Epoch: 198: train loss : 0.63014245	 train accuracy : 0.99232246	 val accuracy : 0.54491018	 test accuracy : 0.58791209
# Train Epoch: 199: train loss : 0.62559283	 train accuracy : 0.98848369	 val accuracy : 0.55688623	 test accuracy : 0.58241758
# Train Epoch: 200: train loss : 0.63984531	 train accuracy : 0.98272553	 val accuracy : 0.57485030	 test accuracy : 0.57692308
# In fold  5
# The best validaiton accuracy is:  0.6167664670658682
# Happened at epoch:  18
# The corresponding test accuracy 0.6043956043956044
# The corresponding test AUC is:  0.5812742248062015
# Finish 5-fold training

# %%
val_accuracy = metrics.accuracy_score(all_fold_val_label, all_fold_val_out)
test_accuracy = metrics.accuracy_score(all_fold_test_label, all_fold_test_out)
test_fpr, test_tpr, te_thresholds = roc_curve(all_fold_test_label, all_fold_test_prob[:,1],pos_label=1)
test_auc = auc(test_fpr, test_tpr)
print('The best validation accuracy is ',val_accuracy)
print('The corresponding test accuracy is ',test_accuracy)
print('The corresponding test AUC is: ',test_auc)
plt.grid()
plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
plt.plot([0,1],[0,1],'g--')
plt.legend()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Test AUC(ROC curve)")
plt.grid(color='black', linestyle='-', linewidth=0.5)
plt.show()
# Out:
# The best validation accuracy is  0.6459770114942529
# The corresponding test accuracy is  0.6367816091954023
# The corresponding test AUC is:  0.6510459561851425

# %%
torch.cuda.empty_cache()
torch.manual_seed(args.seed)
if args.cuda:
    torch.cuda.manual_seed(args.seed)
############################################### Max voting ###############################################################
############################################### Max voting ###############################################################
############################################### Max voting ###############################################################
dist_ensemble_val_label = {}
dist_ensemble_val_result = {}
dist_ensemble_test_label = {}
dist_ensemble_test_result = {}
dist_ensemble_test_prob = {}

for ensemble_fold in range(5):
  print('Ensemble ',ensemble_fold+1)
  save_ensemble_models_path = save_path + 'Max_voting/AUTO/'
  dist_train = {}
  dist_validation = {}
  dist_test = {}
  for i in range(k_fold):
    dist_train[str(i + 1)] = []
    dist_validation[str(i + 1)] = []
    dist_test[str(i + 1)] = []
  test_name = {}
  for i in range(len(unique_sites)):
    test_name[unique_sites[i]] = []
  for each_site in unique_sites:
    index_site = get_index(sites, each_site)
    label = np.zeros((len(index_site)))
    for i in range(len(index_site)):
      index = index_site[i]
      label[i] = int(labels[int(index)])
    test_name_list = test_name[each_site]
    ########################################### StratifiedKFold ####################################################
    sfolder = StratifiedKFold(n_splits=k_fold,random_state=0,shuffle=True)
    group = 0
    for train, validation in sfolder.split(index_site,label):
      if group == ensemble_fold:
        for j in validation:
          name = index_site[j]
          dist_test['1'].append(name)
          dist_test['2'].append(name)
          dist_test['3'].append(name)
          dist_test['4'].append(name)
          dist_test['5'].append(name)
          test_name_list.append(name)
      group = group + 1
    test_name[each_site] = test_name_list

  for each_site in unique_sites:
    if ensemble_fold == 0:

      index_site = get_index(sites, each_site)
      label = np.zeros((len(index_site)))
      for i in range(len(index_site)):
        index = index_site[i]
        label[i] = int(labels[int(index)])
      test_name_list = test_name[each_site]
      index_site_new = []
      label_new = np.zeros((len(index_site) - len(test_name_list)))
      position = 0
      for x in range(len(index_site)):
        sample_name = index_site[x]
        if sample_name in test_name_list:
          c=0
        else:
          index_site_new.append(sample_name)
          label_new[position] = label[x]
          position = position + 1
      if each_site == 'CMU':  # ONLY 4 AUTISM SAMPLES AND 4 TD SAMPLES, CAN NOT BE DEVIDED INTO 5 GROUPS
        group_autism_val = []
        group_autism_train = []
        group_TD_val = []
        group_TD_train = []
        autism_validation_number = len(label_new[label_new ==1])/4
        TD_validation_number = len(label_new[label_new ==0]) / 4
        for j in range(len(label_new)):
          if label_new[j] == 1:
            if len(group_autism_val)<autism_validation_number:
              group_autism_val.append(index_site_new[j])
            else:
              group_autism_train.append(index_site_new[j])
          else:
            if len(group_TD_val)<TD_validation_number:
              group_TD_val.append(index_site_new[j])
            else:
              group_TD_train.append(index_site_new[j])

        dist_validation['1'] = dist_validation['1'] + group_autism_val + group_TD_val
        dist_validation['2'] = dist_validation['2'] + group_autism_val + group_TD_val
        dist_validation['3'] = dist_validation['3'] + group_autism_val + group_TD_val
        dist_validation['4'] = dist_validation['4'] + group_autism_val + group_TD_val
        dist_validation['5'] = dist_validation['5'] + group_autism_val + group_TD_val
        dist_train['1'] = dist_train['1'] + group_autism_train + group_TD_train
        dist_train['2'] = dist_train['2'] + group_autism_train + group_TD_train
        dist_train['3'] = dist_train['3'] + group_autism_train + group_TD_train
        dist_train['4'] = dist_train['4'] + group_autism_train + group_TD_train
        dist_train['5'] = dist_train['5'] + group_autism_train + group_TD_train
      else:
        ########################################### StratifiedKFold ####################################################
        sfolder = StratifiedKFold(n_splits=k_fold, random_state=0, shuffle=True)
        group = 0
        for train, validation in sfolder.split(index_site_new, label_new):

          for i in train:
            name = index_site_new[i]
            dist_train[str(group + 1)].append(name)
          for j in validation:
            name = index_site_new[j]
            dist_validation[str(group + 1)].append(name)
          group = group + 1
    else:

      index_site = get_index(sites, each_site)
      label = np.zeros((len(index_site)))
      for i in range(len(index_site)):
        index = index_site[i]
        label[i] = int(labels[int(index)])
      test_name_list = test_name[each_site]
      index_site_new = []
      label_new = np.zeros((len(index_site) - len(test_name_list)))
      position = 0
      for x in range(len(index_site)):
        sample_name = index_site[x]
        if sample_name in test_name_list:
          c=0
        else:
          index_site_new.append(sample_name)
          label_new[position] = label[x]
          position = position + 1
      ########################################### StratifiedKFold ####################################################
      sfolder = StratifiedKFold(n_splits=k_fold,random_state=0,shuffle=True)
      group = 0
      for train, validation in sfolder.split(index_site_new,label_new):

        for i in train:
          name = index_site_new[i]
          dist_train[str(group + 1)].append(name)
        for j in validation:
          name = index_site_new[j]
          dist_validation[str(group + 1)].append(name)
        group = group+1
  
  
  data = {}
  for fold in range(1, k_fold+1):
    data[str(fold)] = []
    selector = feature_selection(sMRI_features, labels, dist_train[str(fold)], new_number_features)
    fold_data = selector.transform(sMRI_features)

    data[str(fold)].append(fold_data)
    data[str(fold)].append(AUTO_labels)

  ############################################### Train ###############################################################
  ############################################### Train ###############################################################
  ############################################### Train ###############################################################

  model_1 = Auto_encoder_MLP(in_c=args.auto_in, auto_1=args.auto_hid_1, auto_2=args.auto_hid_2, auto_3=args.auto_hid_3, MLP_1=args.MLP_1, MLP_2=args.MLP_2, MLP_out=args.MLP_out, dropout_rate=args.dropout_rate)
  model_2 = Auto_encoder_MLP(in_c=args.auto_in, auto_1=args.auto_hid_1, auto_2=args.auto_hid_2, auto_3=args.auto_hid_3, MLP_1=args.MLP_1, MLP_2=args.MLP_2, MLP_out=args.MLP_out, dropout_rate=args.dropout_rate)
  model_3 = Auto_encoder_MLP(in_c=args.auto_in, auto_1=args.auto_hid_1, auto_2=args.auto_hid_2, auto_3=args.auto_hid_3, MLP_1=args.MLP_1, MLP_2=args.MLP_2, MLP_out=args.MLP_out, dropout_rate=args.dropout_rate)
  model_4 = Auto_encoder_MLP(in_c=args.auto_in, auto_1=args.auto_hid_1, auto_2=args.auto_hid_2, auto_3=args.auto_hid_3, MLP_1=args.MLP_1, MLP_2=args.MLP_2, MLP_out=args.MLP_out, dropout_rate=args.dropout_rate)
  model_5 = Auto_encoder_MLP(in_c=args.auto_in, auto_1=args.auto_hid_1, auto_2=args.auto_hid_2, auto_3=args.auto_hid_3, MLP_1=args.MLP_1, MLP_2=args.MLP_2, MLP_out=args.MLP_out, dropout_rate=args.dropout_rate)

  gpu_ids = range(args.ngpu)
  model_1 = nn.parallel.DataParallel(model_1, device_ids=gpu_ids)
  model_2 = nn.parallel.DataParallel(model_2, device_ids=gpu_ids)
  model_3 = nn.parallel.DataParallel(model_3, device_ids=gpu_ids)
  model_4 = nn.parallel.DataParallel(model_4, device_ids=gpu_ids)
  model_5 = nn.parallel.DataParallel(model_5, device_ids=gpu_ids)
  train = train_AUTO

  print('  + Number of params: {}'.format(
      sum([p.data.nelement() for p in model_1.parameters()])))
  if args.cuda:
      model_1 = model_1.cuda()
      model_2 = model_2.cuda()
      model_3 = model_3.cuda()
      model_4 = model_4.cuda()
      model_5 = model_5.cuda()

  optimizer_1 = optim.Adam(model_1.parameters(), lr = args.lr)
  optimizer_2 = optim.Adam(model_2.parameters(), lr = args.lr)
  optimizer_3 = optim.Adam(model_3.parameters(), lr = args.lr)
  optimizer_4 = optim.Adam(model_4.parameters(), lr = args.lr)
  optimizer_5 = optim.Adam(model_5.parameters(), lr = args.lr)

  Train_accuracy_list =[]
  Train_loss_list = []
  Val_accuracy_list =[]
  Val_loss_list = []
  Test_accuracy_list =[]
  Test_loss_list = []
  best_validation_accuracy = 0

  for epoch in range(1, args.nEpochs + 1):


    model_1, train_target_1, train_out_1, train_loss_1, val_target_1, val_out_1, val_loss_1, test_target_1, test_out_1, test_prob_1, test_loss_1 = train(args, model_1, data['1'], dist_train['1'], dist_validation['1'], dist_test['1'], optimizer_1)
    model_2, train_target_2, train_out_2, train_loss_2, val_target_2, val_out_2, val_loss_2, test_target_2, test_out_2, test_prob_2, test_loss_2 = train(args, model_2, data['2'], dist_train['2'], dist_validation['2'], dist_test['2'], optimizer_2)
    model_3, train_target_3, train_out_3, train_loss_3, val_target_3, val_out_3, val_loss_3, test_target_3, test_out_3, test_prob_3, test_loss_3 = train(args, model_3, data['3'], dist_train['3'], dist_validation['3'], dist_test['3'], optimizer_3)
    model_4, train_target_4, train_out_4, train_loss_4, val_target_4, val_out_4, val_loss_4, test_target_4, test_out_4, test_prob_4, test_loss_4 = train(args, model_4, data['4'], dist_train['4'], dist_validation['4'], dist_test['4'], optimizer_4)
    model_5, train_target_5, train_out_5, train_loss_5, val_target_5, val_out_5, val_loss_5, test_target_5, test_out_5, test_prob_5, test_loss_5 = train(args, model_5, data['5'], dist_train['5'], dist_validation['5'], dist_test['5'], optimizer_5)

    train_target_all = np.concatenate((train_target_1, train_target_2, train_target_3, train_target_4, train_target_5),axis = 0)
    train_out_all = np.concatenate((train_out_1, train_out_2, train_out_3, train_out_4, train_out_5),axis = 0)
    train_loss = (train_loss_1 + train_loss_2 + train_loss_3 + train_loss_4 + train_loss_5)/5
    val_target_all = np.concatenate((val_target_1, val_target_2, val_target_3, val_target_4, val_target_5),axis = 0)
    val_out_all = np.concatenate((val_out_1, val_out_2, val_out_3, val_out_4, val_out_5),axis = 0)
    val_loss = (val_loss_1 + val_loss_2 + val_loss_3 + val_loss_4 + val_loss_5)/5
    test_target_all = test_target_1 # test_target_1 = test_target_2 = test_target_3 = test_target_4 = test_target_5
    test_out_all = test_out_1 + test_out_2 + test_out_3 + test_out_4 + test_out_5
    test_prob_all = (test_prob_1 + test_prob_2 + test_prob_3 + test_prob_4 + test_prob_5)/5
    test_loss = (test_loss_1 + test_loss_2 + test_loss_3 + test_loss_4 + test_loss_5)/5

    test_results_binary = np.zeros_like((test_out_all))
    test_results_binary[test_out_all<2.5] = 0
    test_results_binary[test_out_all>=2.5] = 1

    train_accuracy = metrics.accuracy_score(train_target_all, train_out_all)
    val_accuracy = metrics.accuracy_score(val_target_all, val_out_all)
    test_accuracy = metrics.accuracy_score(test_target_all, test_results_binary)
    Train_accuracy_list.append(train_accuracy)
    Val_accuracy_list.append(val_accuracy)
    Test_accuracy_list.append(test_accuracy)
    Train_loss_list.append(train_loss)
    Val_loss_list.append(val_loss)
    Test_loss_list.append(test_loss)

    if val_accuracy >=best_validation_accuracy:
      best_epoch = epoch
      best_validation_accuracy = val_accuracy
      corresponding_test_accuracy = test_accuracy
      corresponding_test_prob = test_prob_all
      corresponding_test_labels = test_target_all
      corresponding_test_out = test_results_binary
      print('Save models')

      save_model(model_1, save_ensemble_models_path, 'AUTO_ensemble' + str(ensemble_fold) + '_1')
      save_model(model_2, save_ensemble_models_path, 'AUTO_ensemble' + str(ensemble_fold) + '_2')
      save_model(model_3, save_ensemble_models_path, 'AUTO_ensemble' + str(ensemble_fold) + '_3')
      save_model(model_4, save_ensemble_models_path, 'AUTO_ensemble' + str(ensemble_fold) + '_4')
      save_model(model_5, save_ensemble_models_path, 'AUTO_ensemble' + str(ensemble_fold) + '_5')

    print('Train Epoch: ' + str(epoch) + ': train loss : {:.8f}\t train accuracy : {:.8f}\t val accuracy : {:.8f}\t test accuracy : {:.8f}\t'.format(
      train_loss, train_accuracy, val_accuracy, test_accuracy))

  x_axis = list(range(1, len(Train_accuracy_list)+1))
  plt.figure(figsize=(15,10))
  plt.plot(x_axis, Train_loss_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_loss_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_loss_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()

  plt.figure(figsize=(15,10))
  plt.plot(x_axis, Train_accuracy_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_accuracy_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_accuracy_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()
 
  test_fpr, test_tpr, te_thresholds = roc_curve(corresponding_test_labels, corresponding_test_prob[:,1],pos_label=1)
  test_auc = auc(test_fpr, test_tpr)
  print('\n')
  print('In ensemble ',ensemble_fold+1)
  print('The best validaiton accuracy is: ',best_validation_accuracy)
  print('Happened at epoch: ',best_epoch)
  print('The corresponding test accuracy', corresponding_test_accuracy)
  print('The corresponding test AUC is: ',test_auc)
  print('\n')


  plt.grid()
  plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
  plt.plot([0,1],[0,1],'g--')
  plt.legend()
  plt.xlabel("False Positive Rate")
  plt.ylabel("True Positive Rate")
  plt.title("Test AUC(ROC curve)")
  plt.grid(color='black', linestyle='-', linewidth=0.5)
  plt.show()


  dist_ensemble_test_label[str(ensemble_fold+1)] = corresponding_test_labels
  dist_ensemble_test_result[str(ensemble_fold+1)] = corresponding_test_out
  dist_ensemble_test_prob[str(ensemble_fold+1)] = corresponding_test_prob
  print('\n')

  torch.cuda.empty_cache()

test_labels_concat = np.concatenate((dist_ensemble_test_label['1'], dist_ensemble_test_label['2'],  dist_ensemble_test_label['3'], dist_ensemble_test_label['4'], dist_ensemble_test_label['5']),axis = 0)
test_results_concat = np.concatenate((dist_ensemble_test_result['1'], dist_ensemble_test_result['2'],  dist_ensemble_test_result['3'], dist_ensemble_test_result['4'], dist_ensemble_test_result['5']),axis = 0)
test_probs_concat = np.concatenate((dist_ensemble_test_prob['1'], dist_ensemble_test_prob['2'],  dist_ensemble_test_prob['3'], dist_ensemble_test_prob['4'], dist_ensemble_test_prob['5']),axis = 0)

test_accuracy = metrics.accuracy_score(test_labels_concat, test_results_concat)
test_fpr, test_tpr, te_thresholds = roc_curve(test_labels_concat, test_probs_concat[:,1],pos_label=1)
test_auc = auc(test_fpr, test_tpr)
print('The Max voting test accuracy is: ',test_accuracy)
print('The test AUC is: ',test_auc)

print('\n')
print('\n')
plt.grid()
plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
plt.plot([0,1],[0,1],'g--')
plt.legend()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Test AUC(ROC curve)")
plt.grid(color='black', linestyle='-', linewidth=0.5)
plt.show()
# Out:
# Ensemble  1
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
#   + Number of params: 1388835
# Save models
# Train Epoch: 1: train loss : 1.39672830	 train accuracy : 0.52654545	 val accuracy : 0.51159420	 test accuracy : 0.52747253
# Save models
# Train Epoch: 2: train loss : 1.39194536	 train accuracy : 0.53018182	 val accuracy : 0.51884058	 test accuracy : 0.53846154
# Save models
# Train Epoch: 3: train loss : 1.38656244	 train accuracy : 0.52981818	 val accuracy : 0.53188406	 test accuracy : 0.57142857
# Save models
# Train Epoch: 4: train loss : 1.37781463	 train accuracy : 0.54545455	 val accuracy : 0.54492754	 test accuracy : 0.56593407
# Train Epoch: 5: train loss : 1.36992633	 train accuracy : 0.55454545	 val accuracy : 0.54057971	 test accuracy : 0.56593407
# Save models
# Train Epoch: 6: train loss : 1.36075699	 train accuracy : 0.58509091	 val accuracy : 0.55362319	 test accuracy : 0.56043956
# Save models
# Train Epoch: 7: train loss : 1.34745235	 train accuracy : 0.60072727	 val accuracy : 0.56666667	 test accuracy : 0.58791209
# Save models
# Train Epoch: 8: train loss : 1.32993135	 train accuracy : 0.63163636	 val accuracy : 0.57536232	 test accuracy : 0.57692308
# Save models
# Train Epoch: 9: train loss : 1.31337729	 train accuracy : 0.65563636	 val accuracy : 0.59130435	 test accuracy : 0.57692308
# Train Epoch: 10: train loss : 1.29864995	 train accuracy : 0.67890909	 val accuracy : 0.58405797	 test accuracy : 0.58791209
# Save models
# Train Epoch: 11: train loss : 1.26606557	 train accuracy : 0.70836364	 val accuracy : 0.59275362	 test accuracy : 0.61538462
# Save models
# Train Epoch: 12: train loss : 1.24015219	 train accuracy : 0.74545455	 val accuracy : 0.61739130	 test accuracy : 0.60989011
# Train Epoch: 13: train loss : 1.20821815	 train accuracy : 0.76327273	 val accuracy : 0.60579710	 test accuracy : 0.60439560
# Train Epoch: 14: train loss : 1.17511792	 train accuracy : 0.78836364	 val accuracy : 0.60579710	 test accuracy : 0.61538462
# Save models
# Train Epoch: 15: train loss : 1.13495049	 train accuracy : 0.81490909	 val accuracy : 0.62028986	 test accuracy : 0.60989011
# Train Epoch: 16: train loss : 1.10275419	 train accuracy : 0.84472727	 val accuracy : 0.61739130	 test accuracy : 0.60989011
# Train Epoch: 17: train loss : 1.06619060	 train accuracy : 0.85781818	 val accuracy : 0.60869565	 test accuracy : 0.62637363
# Save models
# Train Epoch: 18: train loss : 1.05410028	 train accuracy : 0.87272727	 val accuracy : 0.62318841	 test accuracy : 0.60989011
# Train Epoch: 19: train loss : 1.02257912	 train accuracy : 0.88654545	 val accuracy : 0.60579710	 test accuracy : 0.62087912
# Train Epoch: 20: train loss : 0.99044106	 train accuracy : 0.90981818	 val accuracy : 0.59565217	 test accuracy : 0.59890110
# Train Epoch: 21: train loss : 0.96925491	 train accuracy : 0.91127273	 val accuracy : 0.61159420	 test accuracy : 0.61538462
# Train Epoch: 22: train loss : 0.94186120	 train accuracy : 0.92945455	 val accuracy : 0.60579710	 test accuracy : 0.61538462
# Train Epoch: 23: train loss : 0.92041720	 train accuracy : 0.94290909	 val accuracy : 0.60289855	 test accuracy : 0.60989011
# Train Epoch: 24: train loss : 0.90396032	 train accuracy : 0.94472727	 val accuracy : 0.60434783	 test accuracy : 0.57692308
# Train Epoch: 25: train loss : 0.89673339	 train accuracy : 0.94290909	 val accuracy : 0.60289855	 test accuracy : 0.60989011
# Train Epoch: 26: train loss : 0.86443764	 train accuracy : 0.95781818	 val accuracy : 0.57971014	 test accuracy : 0.58241758
# Train Epoch: 27: train loss : 0.84893786	 train accuracy : 0.96509091	 val accuracy : 0.59275362	 test accuracy : 0.58791209
# Train Epoch: 28: train loss : 0.84273152	 train accuracy : 0.96654545	 val accuracy : 0.58550725	 test accuracy : 0.60989011
# Train Epoch: 29: train loss : 0.83338250	 train accuracy : 0.96509091	 val accuracy : 0.58550725	 test accuracy : 0.62637363
# Train Epoch: 30: train loss : 0.81076024	 train accuracy : 0.97127273	 val accuracy : 0.59275362	 test accuracy : 0.62637363
# Train Epoch: 31: train loss : 0.81530665	 train accuracy : 0.96618182	 val accuracy : 0.60289855	 test accuracy : 0.60989011
# Train Epoch: 32: train loss : 0.81226876	 train accuracy : 0.96654545	 val accuracy : 0.59420290	 test accuracy : 0.63736264
# Train Epoch: 33: train loss : 0.78323557	 train accuracy : 0.97454545	 val accuracy : 0.58550725	 test accuracy : 0.64835165
# Train Epoch: 34: train loss : 0.77709090	 train accuracy : 0.97745455	 val accuracy : 0.59130435	 test accuracy : 0.64285714
# Train Epoch: 35: train loss : 0.77562568	 train accuracy : 0.97200000	 val accuracy : 0.58405797	 test accuracy : 0.64835165
# Train Epoch: 36: train loss : 0.76968110	 train accuracy : 0.97636364	 val accuracy : 0.58985507	 test accuracy : 0.65384615
# Train Epoch: 37: train loss : 0.76499604	 train accuracy : 0.97345455	 val accuracy : 0.58405797	 test accuracy : 0.64835165
# Train Epoch: 38: train loss : 0.76251884	 train accuracy : 0.97709091	 val accuracy : 0.57536232	 test accuracy : 0.67032967
# Train Epoch: 39: train loss : 0.76088573	 train accuracy : 0.97527273	 val accuracy : 0.57971014	 test accuracy : 0.63736264
# Train Epoch: 40: train loss : 0.74579009	 train accuracy : 0.97854545	 val accuracy : 0.57101449	 test accuracy : 0.62087912
# Train Epoch: 41: train loss : 0.75349723	 train accuracy : 0.97272727	 val accuracy : 0.57101449	 test accuracy : 0.60989011
# Train Epoch: 42: train loss : 0.74595758	 train accuracy : 0.97781818	 val accuracy : 0.58405797	 test accuracy : 0.60439560
# Train Epoch: 43: train loss : 0.73675994	 train accuracy : 0.98072727	 val accuracy : 0.59710145	 test accuracy : 0.59890110
# Train Epoch: 44: train loss : 0.73400942	 train accuracy : 0.97781818	 val accuracy : 0.58985507	 test accuracy : 0.61538462
# Train Epoch: 45: train loss : 0.73321512	 train accuracy : 0.98545455	 val accuracy : 0.58840580	 test accuracy : 0.63736264
# Train Epoch: 46: train loss : 0.73775553	 train accuracy : 0.97563636	 val accuracy : 0.58550725	 test accuracy : 0.64835165
# Train Epoch: 47: train loss : 0.72677699	 train accuracy : 0.97890909	 val accuracy : 0.57536232	 test accuracy : 0.62637363
# Train Epoch: 48: train loss : 0.72305524	 train accuracy : 0.98072727	 val accuracy : 0.58840580	 test accuracy : 0.64285714
# Train Epoch: 49: train loss : 0.72852677	 train accuracy : 0.97818182	 val accuracy : 0.58405797	 test accuracy : 0.65384615
# Train Epoch: 50: train loss : 0.72901542	 train accuracy : 0.97381818	 val accuracy : 0.59420290	 test accuracy : 0.60439560
# Train Epoch: 51: train loss : 0.71883368	 train accuracy : 0.97963636	 val accuracy : 0.58985507	 test accuracy : 0.62087912
# Train Epoch: 52: train loss : 0.72602906	 train accuracy : 0.98400000	 val accuracy : 0.58840580	 test accuracy : 0.63736264
# Train Epoch: 53: train loss : 0.71717167	 train accuracy : 0.98254545	 val accuracy : 0.59275362	 test accuracy : 0.63186813
# Train Epoch: 54: train loss : 0.72140726	 train accuracy : 0.97709091	 val accuracy : 0.57391304	 test accuracy : 0.62637363
# Train Epoch: 55: train loss : 0.73322142	 train accuracy : 0.98000000	 val accuracy : 0.57826087	 test accuracy : 0.62637363
# Train Epoch: 56: train loss : 0.71521616	 train accuracy : 0.97745455	 val accuracy : 0.57101449	 test accuracy : 0.62637363
# Train Epoch: 57: train loss : 0.70185256	 train accuracy : 0.98218182	 val accuracy : 0.57681159	 test accuracy : 0.60439560
# Train Epoch: 58: train loss : 0.71495312	 train accuracy : 0.98109091	 val accuracy : 0.59420290	 test accuracy : 0.61538462
# Train Epoch: 59: train loss : 0.71277617	 train accuracy : 0.98145455	 val accuracy : 0.58985507	 test accuracy : 0.58791209
# Train Epoch: 60: train loss : 0.71253186	 train accuracy : 0.97963636	 val accuracy : 0.57971014	 test accuracy : 0.58241758
# Train Epoch: 61: train loss : 0.70334492	 train accuracy : 0.98290909	 val accuracy : 0.57971014	 test accuracy : 0.59890110
# Train Epoch: 62: train loss : 0.71098965	 train accuracy : 0.98109091	 val accuracy : 0.57681159	 test accuracy : 0.62637363
# Train Epoch: 63: train loss : 0.70361657	 train accuracy : 0.98000000	 val accuracy : 0.57246377	 test accuracy : 0.61538462
# Train Epoch: 64: train loss : 0.70030361	 train accuracy : 0.97927273	 val accuracy : 0.58115942	 test accuracy : 0.62087912
# Train Epoch: 65: train loss : 0.69547973	 train accuracy : 0.98763636	 val accuracy : 0.57826087	 test accuracy : 0.61538462
# Train Epoch: 66: train loss : 0.71344978	 train accuracy : 0.98109091	 val accuracy : 0.58115942	 test accuracy : 0.61538462
# Train Epoch: 67: train loss : 0.70703079	 train accuracy : 0.98400000	 val accuracy : 0.60144928	 test accuracy : 0.60439560
# Train Epoch: 68: train loss : 0.70105006	 train accuracy : 0.98509091	 val accuracy : 0.58405797	 test accuracy : 0.59890110
# Train Epoch: 69: train loss : 0.70259955	 train accuracy : 0.98436364	 val accuracy : 0.59710145	 test accuracy : 0.58241758
# Train Epoch: 70: train loss : 0.69438570	 train accuracy : 0.98472727	 val accuracy : 0.60144928	 test accuracy : 0.60439560
# Train Epoch: 71: train loss : 0.69324225	 train accuracy : 0.98581818	 val accuracy : 0.59420290	 test accuracy : 0.62637363
# Train Epoch: 72: train loss : 0.68853633	 train accuracy : 0.98509091	 val accuracy : 0.59420290	 test accuracy : 0.62087912
# Train Epoch: 73: train loss : 0.70243171	 train accuracy : 0.98218182	 val accuracy : 0.59275362	 test accuracy : 0.61538462
# Train Epoch: 74: train loss : 0.69138526	 train accuracy : 0.98472727	 val accuracy : 0.59130435	 test accuracy : 0.59890110
# Train Epoch: 75: train loss : 0.69064652	 train accuracy : 0.98581818	 val accuracy : 0.58985507	 test accuracy : 0.61538462
# Train Epoch: 76: train loss : 0.68556011	 train accuracy : 0.98763636	 val accuracy : 0.58405797	 test accuracy : 0.59890110
# Train Epoch: 77: train loss : 0.69352769	 train accuracy : 0.98472727	 val accuracy : 0.58840580	 test accuracy : 0.59340659
# Train Epoch: 78: train loss : 0.69164236	 train accuracy : 0.98472727	 val accuracy : 0.58260870	 test accuracy : 0.60439560
# Train Epoch: 79: train loss : 0.69103832	 train accuracy : 0.98618182	 val accuracy : 0.58405797	 test accuracy : 0.62087912
# Train Epoch: 80: train loss : 0.68020514	 train accuracy : 0.99054545	 val accuracy : 0.58260870	 test accuracy : 0.60439560
# Train Epoch: 81: train loss : 0.70274818	 train accuracy : 0.97454545	 val accuracy : 0.57826087	 test accuracy : 0.62087912
# Train Epoch: 82: train loss : 0.69070140	 train accuracy : 0.98618182	 val accuracy : 0.58695652	 test accuracy : 0.63736264
# Train Epoch: 83: train loss : 0.68019507	 train accuracy : 0.98836364	 val accuracy : 0.58260870	 test accuracy : 0.62087912
# Train Epoch: 84: train loss : 0.67894750	 train accuracy : 0.98909091	 val accuracy : 0.58260870	 test accuracy : 0.60989011
# Train Epoch: 85: train loss : 0.68260632	 train accuracy : 0.98763636	 val accuracy : 0.57101449	 test accuracy : 0.61538462
# Train Epoch: 86: train loss : 0.68542656	 train accuracy : 0.98363636	 val accuracy : 0.57246377	 test accuracy : 0.61538462
# Train Epoch: 87: train loss : 0.68897263	 train accuracy : 0.98363636	 val accuracy : 0.57101449	 test accuracy : 0.62637363
# Train Epoch: 88: train loss : 0.67539072	 train accuracy : 0.98618182	 val accuracy : 0.57971014	 test accuracy : 0.61538462
# Train Epoch: 89: train loss : 0.67464628	 train accuracy : 0.98727273	 val accuracy : 0.57826087	 test accuracy : 0.61538462
# Train Epoch: 90: train loss : 0.68274653	 train accuracy : 0.98763636	 val accuracy : 0.59565217	 test accuracy : 0.62087912
# Train Epoch: 91: train loss : 0.68172966	 train accuracy : 0.98436364	 val accuracy : 0.57971014	 test accuracy : 0.62637363
# Train Epoch: 92: train loss : 0.70418960	 train accuracy : 0.97854545	 val accuracy : 0.58985507	 test accuracy : 0.61538462
# Train Epoch: 93: train loss : 0.68533789	 train accuracy : 0.98109091	 val accuracy : 0.58260870	 test accuracy : 0.60989011
# Train Epoch: 94: train loss : 0.67701005	 train accuracy : 0.98654545	 val accuracy : 0.59420290	 test accuracy : 0.61538462
# Train Epoch: 95: train loss : 0.68088896	 train accuracy : 0.98654545	 val accuracy : 0.58260870	 test accuracy : 0.60989011
# Train Epoch: 96: train loss : 0.67932602	 train accuracy : 0.98690909	 val accuracy : 0.57826087	 test accuracy : 0.59890110
# Train Epoch: 97: train loss : 0.67449065	 train accuracy : 0.98581818	 val accuracy : 0.58695652	 test accuracy : 0.60439560
# Train Epoch: 98: train loss : 0.67884363	 train accuracy : 0.98545455	 val accuracy : 0.58985507	 test accuracy : 0.59890110
# Train Epoch: 99: train loss : 0.67551965	 train accuracy : 0.98727273	 val accuracy : 0.57536232	 test accuracy : 0.59890110
# Train Epoch: 100: train loss : 0.67899026	 train accuracy : 0.98618182	 val accuracy : 0.58405797	 test accuracy : 0.58241758
# Train Epoch: 101: train loss : 0.67429670	 train accuracy : 0.98727273	 val accuracy : 0.58985507	 test accuracy : 0.61538462
# Train Epoch: 102: train loss : 0.66867586	 train accuracy : 0.98909091	 val accuracy : 0.59130435	 test accuracy : 0.63736264
# Train Epoch: 103: train loss : 0.66633259	 train accuracy : 0.98836364	 val accuracy : 0.59130435	 test accuracy : 0.62637363
# Train Epoch: 104: train loss : 0.67374849	 train accuracy : 0.98581818	 val accuracy : 0.58115942	 test accuracy : 0.61538462
# Train Epoch: 105: train loss : 0.67915990	 train accuracy : 0.98509091	 val accuracy : 0.57971014	 test accuracy : 0.63186813
# Train Epoch: 106: train loss : 0.67374061	 train accuracy : 0.98800000	 val accuracy : 0.58985507	 test accuracy : 0.60989011
# Train Epoch: 107: train loss : 0.66850140	 train accuracy : 0.98909091	 val accuracy : 0.59420290	 test accuracy : 0.61538462
# Train Epoch: 108: train loss : 0.67401420	 train accuracy : 0.98909091	 val accuracy : 0.59275362	 test accuracy : 0.60439560
# Train Epoch: 109: train loss : 0.67264935	 train accuracy : 0.98509091	 val accuracy : 0.59855072	 test accuracy : 0.60439560
# Train Epoch: 110: train loss : 0.66504126	 train accuracy : 0.98945455	 val accuracy : 0.59420290	 test accuracy : 0.62087912
# Train Epoch: 111: train loss : 0.67061168	 train accuracy : 0.98763636	 val accuracy : 0.58985507	 test accuracy : 0.60989011
# Train Epoch: 112: train loss : 0.67452470	 train accuracy : 0.98472727	 val accuracy : 0.58985507	 test accuracy : 0.62637363
# Train Epoch: 113: train loss : 0.66981506	 train accuracy : 0.98800000	 val accuracy : 0.58695652	 test accuracy : 0.62637363
# Train Epoch: 114: train loss : 0.66645014	 train accuracy : 0.98800000	 val accuracy : 0.60000000	 test accuracy : 0.60989011
# Train Epoch: 115: train loss : 0.67323666	 train accuracy : 0.98654545	 val accuracy : 0.59710145	 test accuracy : 0.62087912
# Train Epoch: 116: train loss : 0.67436601	 train accuracy : 0.98800000	 val accuracy : 0.59420290	 test accuracy : 0.62087912
# Train Epoch: 117: train loss : 0.66378669	 train accuracy : 0.98727273	 val accuracy : 0.60000000	 test accuracy : 0.62637363
# Train Epoch: 118: train loss : 0.66716166	 train accuracy : 0.98763636	 val accuracy : 0.59855072	 test accuracy : 0.60989011
# Train Epoch: 119: train loss : 0.66610997	 train accuracy : 0.98836364	 val accuracy : 0.59710145	 test accuracy : 0.61538462
# Train Epoch: 120: train loss : 0.66959662	 train accuracy : 0.98727273	 val accuracy : 0.59565217	 test accuracy : 0.60989011
# Train Epoch: 121: train loss : 0.66876668	 train accuracy : 0.98800000	 val accuracy : 0.59275362	 test accuracy : 0.60989011
# Train Epoch: 122: train loss : 0.66166323	 train accuracy : 0.99127273	 val accuracy : 0.58115942	 test accuracy : 0.62087912
# Train Epoch: 123: train loss : 0.66377333	 train accuracy : 0.98618182	 val accuracy : 0.58550725	 test accuracy : 0.60989011
# Train Epoch: 124: train loss : 0.67189852	 train accuracy : 0.98436364	 val accuracy : 0.57971014	 test accuracy : 0.61538462
# Train Epoch: 125: train loss : 0.66246932	 train accuracy : 0.98836364	 val accuracy : 0.58550725	 test accuracy : 0.61538462
# Train Epoch: 126: train loss : 0.66673791	 train accuracy : 0.98436364	 val accuracy : 0.58550725	 test accuracy : 0.64285714
# Train Epoch: 127: train loss : 0.66236327	 train accuracy : 0.98872727	 val accuracy : 0.59130435	 test accuracy : 0.62637363
# Train Epoch: 128: train loss : 0.66959354	 train accuracy : 0.98836364	 val accuracy : 0.59710145	 test accuracy : 0.62637363
# Train Epoch: 129: train loss : 0.66051031	 train accuracy : 0.99127273	 val accuracy : 0.59420290	 test accuracy : 0.60439560
# Train Epoch: 130: train loss : 0.66715043	 train accuracy : 0.99018182	 val accuracy : 0.58695652	 test accuracy : 0.60989011
# Train Epoch: 131: train loss : 0.65985160	 train accuracy : 0.99236364	 val accuracy : 0.59565217	 test accuracy : 0.62087912
# Train Epoch: 132: train loss : 0.66379858	 train accuracy : 0.99054545	 val accuracy : 0.59420290	 test accuracy : 0.60439560
# Train Epoch: 133: train loss : 0.66364163	 train accuracy : 0.99018182	 val accuracy : 0.59130435	 test accuracy : 0.59890110
# Train Epoch: 134: train loss : 0.65855668	 train accuracy : 0.98836364	 val accuracy : 0.60144928	 test accuracy : 0.60439560
# Train Epoch: 135: train loss : 0.66570619	 train accuracy : 0.98945455	 val accuracy : 0.59420290	 test accuracy : 0.60989011
# Train Epoch: 136: train loss : 0.66073362	 train accuracy : 0.99054545	 val accuracy : 0.58985507	 test accuracy : 0.58791209
# Train Epoch: 137: train loss : 0.66055325	 train accuracy : 0.99127273	 val accuracy : 0.58840580	 test accuracy : 0.57692308
# Train Epoch: 138: train loss : 0.65526230	 train accuracy : 0.99018182	 val accuracy : 0.59275362	 test accuracy : 0.59340659
# Train Epoch: 139: train loss : 0.65662633	 train accuracy : 0.99309091	 val accuracy : 0.59710145	 test accuracy : 0.59340659
# Train Epoch: 140: train loss : 0.65529474	 train accuracy : 0.99236364	 val accuracy : 0.59275362	 test accuracy : 0.60439560
# Train Epoch: 141: train loss : 0.65692956	 train accuracy : 0.99090909	 val accuracy : 0.58985507	 test accuracy : 0.60439560
# Train Epoch: 142: train loss : 0.65115774	 train accuracy : 0.99127273	 val accuracy : 0.59420290	 test accuracy : 0.62087912
# Train Epoch: 143: train loss : 0.65458378	 train accuracy : 0.99236364	 val accuracy : 0.59565217	 test accuracy : 0.61538462
# Train Epoch: 144: train loss : 0.65233289	 train accuracy : 0.99309091	 val accuracy : 0.59275362	 test accuracy : 0.62087912
# Train Epoch: 145: train loss : 0.65252540	 train accuracy : 0.98981818	 val accuracy : 0.58840580	 test accuracy : 0.60989011
# Train Epoch: 146: train loss : 0.65461046	 train accuracy : 0.99200000	 val accuracy : 0.59420290	 test accuracy : 0.61538462
# Train Epoch: 147: train loss : 0.66573037	 train accuracy : 0.98654545	 val accuracy : 0.59275362	 test accuracy : 0.59890110
# Train Epoch: 148: train loss : 0.65448753	 train accuracy : 0.99272727	 val accuracy : 0.58840580	 test accuracy : 0.59890110
# Train Epoch: 149: train loss : 0.65137987	 train accuracy : 0.99272727	 val accuracy : 0.58260870	 test accuracy : 0.60989011
# Train Epoch: 150: train loss : 0.65824931	 train accuracy : 0.99090909	 val accuracy : 0.57536232	 test accuracy : 0.62087912
# Train Epoch: 151: train loss : 0.65234097	 train accuracy : 0.99018182	 val accuracy : 0.58115942	 test accuracy : 0.60989011
# Train Epoch: 152: train loss : 0.64951656	 train accuracy : 0.99236364	 val accuracy : 0.58840580	 test accuracy : 0.61538462
# Train Epoch: 153: train loss : 0.65054810	 train accuracy : 0.99200000	 val accuracy : 0.59275362	 test accuracy : 0.61538462
# Train Epoch: 154: train loss : 0.65184180	 train accuracy : 0.99018182	 val accuracy : 0.58405797	 test accuracy : 0.61538462
# Train Epoch: 155: train loss : 0.64874624	 train accuracy : 0.99309091	 val accuracy : 0.57971014	 test accuracy : 0.63736264
# Train Epoch: 156: train loss : 0.65323141	 train accuracy : 0.98836364	 val accuracy : 0.59565217	 test accuracy : 0.63186813
# Train Epoch: 157: train loss : 0.65244497	 train accuracy : 0.99418182	 val accuracy : 0.58695652	 test accuracy : 0.62637363
# Train Epoch: 158: train loss : 0.64854255	 train accuracy : 0.99127273	 val accuracy : 0.58405797	 test accuracy : 0.61538462
# Train Epoch: 159: train loss : 0.65378402	 train accuracy : 0.99127273	 val accuracy : 0.58985507	 test accuracy : 0.60989011
# Train Epoch: 160: train loss : 0.64990356	 train accuracy : 0.99090909	 val accuracy : 0.58115942	 test accuracy : 0.62087912
# Train Epoch: 161: train loss : 0.66327630	 train accuracy : 0.98472727	 val accuracy : 0.58260870	 test accuracy : 0.61538462
# Train Epoch: 162: train loss : 0.64738224	 train accuracy : 0.99200000	 val accuracy : 0.59130435	 test accuracy : 0.63736264
# Train Epoch: 163: train loss : 0.66632246	 train accuracy : 0.98836364	 val accuracy : 0.60579710	 test accuracy : 0.61538462
# Train Epoch: 164: train loss : 0.66538019	 train accuracy : 0.98981818	 val accuracy : 0.59855072	 test accuracy : 0.63186813
# Train Epoch: 165: train loss : 0.65728021	 train accuracy : 0.99054545	 val accuracy : 0.58840580	 test accuracy : 0.62087912
# Train Epoch: 166: train loss : 0.65865221	 train accuracy : 0.98981818	 val accuracy : 0.59420290	 test accuracy : 0.60989011
# Train Epoch: 167: train loss : 0.66203502	 train accuracy : 0.99054545	 val accuracy : 0.59275362	 test accuracy : 0.59890110
# Train Epoch: 168: train loss : 0.65588099	 train accuracy : 0.98945455	 val accuracy : 0.58260870	 test accuracy : 0.62637363
# Train Epoch: 169: train loss : 0.64556363	 train accuracy : 0.99272727	 val accuracy : 0.58405797	 test accuracy : 0.62087912
# Train Epoch: 170: train loss : 0.65714961	 train accuracy : 0.98981818	 val accuracy : 0.58405797	 test accuracy : 0.59890110
# Train Epoch: 171: train loss : 0.64910424	 train accuracy : 0.99272727	 val accuracy : 0.59855072	 test accuracy : 0.60439560
# Train Epoch: 172: train loss : 0.65823696	 train accuracy : 0.98872727	 val accuracy : 0.59855072	 test accuracy : 0.60439560
# Train Epoch: 173: train loss : 0.64990790	 train accuracy : 0.98909091	 val accuracy : 0.60000000	 test accuracy : 0.62637363
# Train Epoch: 174: train loss : 0.64576648	 train accuracy : 0.99418182	 val accuracy : 0.59420290	 test accuracy : 0.62637363
# Train Epoch: 175: train loss : 0.66300445	 train accuracy : 0.98690909	 val accuracy : 0.59565217	 test accuracy : 0.58241758
# Train Epoch: 176: train loss : 0.65578814	 train accuracy : 0.99054545	 val accuracy : 0.59565217	 test accuracy : 0.59890110
# Train Epoch: 177: train loss : 0.65039451	 train accuracy : 0.99272727	 val accuracy : 0.59130435	 test accuracy : 0.60439560
# Train Epoch: 178: train loss : 0.67220205	 train accuracy : 0.98727273	 val accuracy : 0.59275362	 test accuracy : 0.57692308
# Train Epoch: 179: train loss : 0.65041516	 train accuracy : 0.99127273	 val accuracy : 0.58840580	 test accuracy : 0.58791209
# Train Epoch: 180: train loss : 0.64830762	 train accuracy : 0.99200000	 val accuracy : 0.59420290	 test accuracy : 0.62087912
# Train Epoch: 181: train loss : 0.64798601	 train accuracy : 0.98836364	 val accuracy : 0.60000000	 test accuracy : 0.60989011
# Train Epoch: 182: train loss : 0.65267801	 train accuracy : 0.99163636	 val accuracy : 0.59420290	 test accuracy : 0.62087912
# Train Epoch: 183: train loss : 0.65070322	 train accuracy : 0.98836364	 val accuracy : 0.59565217	 test accuracy : 0.63186813
# Train Epoch: 184: train loss : 0.66458606	 train accuracy : 0.98800000	 val accuracy : 0.59855072	 test accuracy : 0.62087912
# Train Epoch: 185: train loss : 0.64498018	 train accuracy : 0.99018182	 val accuracy : 0.59710145	 test accuracy : 0.61538462
# Train Epoch: 186: train loss : 0.64897326	 train accuracy : 0.99236364	 val accuracy : 0.59275362	 test accuracy : 0.61538462
# Train Epoch: 187: train loss : 0.65317031	 train accuracy : 0.98836364	 val accuracy : 0.59275362	 test accuracy : 0.62637363
# Train Epoch: 188: train loss : 0.65710803	 train accuracy : 0.98909091	 val accuracy : 0.58260870	 test accuracy : 0.62637363
# Train Epoch: 189: train loss : 0.64910924	 train accuracy : 0.99090909	 val accuracy : 0.57971014	 test accuracy : 0.60989011
# Train Epoch: 190: train loss : 0.64174514	 train accuracy : 0.99200000	 val accuracy : 0.57391304	 test accuracy : 0.59340659
# Train Epoch: 191: train loss : 0.64833437	 train accuracy : 0.98981818	 val accuracy : 0.58260870	 test accuracy : 0.60439560
# Train Epoch: 192: train loss : 0.64063779	 train accuracy : 0.99200000	 val accuracy : 0.58550725	 test accuracy : 0.57692308
# Train Epoch: 193: train loss : 0.64525597	 train accuracy : 0.99309091	 val accuracy : 0.59565217	 test accuracy : 0.59890110
# Train Epoch: 194: train loss : 0.64236101	 train accuracy : 0.99236364	 val accuracy : 0.59130435	 test accuracy : 0.60989011
# Train Epoch: 195: train loss : 0.64370768	 train accuracy : 0.99200000	 val accuracy : 0.59275362	 test accuracy : 0.60989011
# Train Epoch: 196: train loss : 0.64356112	 train accuracy : 0.99454545	 val accuracy : 0.58695652	 test accuracy : 0.62087912
# Train Epoch: 197: train loss : 0.63668441	 train accuracy : 0.99418182	 val accuracy : 0.58985507	 test accuracy : 0.61538462
# Train Epoch: 198: train loss : 0.64321650	 train accuracy : 0.99018182	 val accuracy : 0.57971014	 test accuracy : 0.59340659
# Train Epoch: 199: train loss : 0.64844944	 train accuracy : 0.98945455	 val accuracy : 0.59275362	 test accuracy : 0.59890110
# Train Epoch: 200: train loss : 0.64524105	 train accuracy : 0.99127273	 val accuracy : 0.59420290	 test accuracy : 0.59890110
# In ensemble  1
# The best validaiton accuracy is:  0.6231884057971014
# Happened at epoch:  18
# The corresponding test accuracy 0.6098901098901099
# The corresponding test AUC is:  0.6265746124031008
# Ensemble  2
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
#   + Number of params: 1388835
# Save models
# Train Epoch: 1: train loss : 1.39408765	 train accuracy : 0.50829726	 val accuracy : 0.50505051	 test accuracy : 0.51977401
# Save models
# Train Epoch: 2: train loss : 1.38872671	 train accuracy : 0.51479076	 val accuracy : 0.52092352	 test accuracy : 0.51977401
# Save models
# Train Epoch: 3: train loss : 1.38310201	 train accuracy : 0.52633478	 val accuracy : 0.53535354	 test accuracy : 0.51977401
# Save models
# Train Epoch: 4: train loss : 1.37423775	 train accuracy : 0.54689755	 val accuracy : 0.53679654	 test accuracy : 0.56497175
# Save models
# Train Epoch: 5: train loss : 1.36764858	 train accuracy : 0.55122655	 val accuracy : 0.54545455	 test accuracy : 0.55932203
# Save models
# Train Epoch: 6: train loss : 1.35681255	 train accuracy : 0.55808081	 val accuracy : 0.55266955	 test accuracy : 0.54237288
# Train Epoch: 7: train loss : 1.34245710	 train accuracy : 0.59343434	 val accuracy : 0.54401154	 test accuracy : 0.54237288
# Train Epoch: 8: train loss : 1.33010204	 train accuracy : 0.61507937	 val accuracy : 0.55122655	 test accuracy : 0.55932203
# Train Epoch: 9: train loss : 1.31524129	 train accuracy : 0.63672439	 val accuracy : 0.55122655	 test accuracy : 0.56497175
# Save models
# Train Epoch: 10: train loss : 1.29870050	 train accuracy : 0.65981241	 val accuracy : 0.58152958	 test accuracy : 0.58192090
# Save models
# Train Epoch: 11: train loss : 1.27515311	 train accuracy : 0.68253968	 val accuracy : 0.60894661	 test accuracy : 0.57627119
# Train Epoch: 12: train loss : 1.24795136	 train accuracy : 0.70238095	 val accuracy : 0.58874459	 test accuracy : 0.61581921
# Train Epoch: 13: train loss : 1.21653478	 train accuracy : 0.74386724	 val accuracy : 0.59740260	 test accuracy : 0.59322034
# Train Epoch: 14: train loss : 1.19125483	 train accuracy : 0.77128427	 val accuracy : 0.60750361	 test accuracy : 0.57627119
# Train Epoch: 15: train loss : 1.14423506	 train accuracy : 0.79834055	 val accuracy : 0.59740260	 test accuracy : 0.57627119
# Save models
# Train Epoch: 16: train loss : 1.10959675	 train accuracy : 0.83261183	 val accuracy : 0.62193362	 test accuracy : 0.57627119
# Train Epoch: 17: train loss : 1.07195828	 train accuracy : 0.85858586	 val accuracy : 0.59740260	 test accuracy : 0.57627119
# Train Epoch: 18: train loss : 1.04353728	 train accuracy : 0.87229437	 val accuracy : 0.60750361	 test accuracy : 0.59322034
# Train Epoch: 19: train loss : 1.00623221	 train accuracy : 0.89502165	 val accuracy : 0.59595960	 test accuracy : 0.58192090
# Train Epoch: 20: train loss : 0.97021755	 train accuracy : 0.90909091	 val accuracy : 0.59307359	 test accuracy : 0.61016949
# Train Epoch: 21: train loss : 0.93103060	 train accuracy : 0.93398268	 val accuracy : 0.59740260	 test accuracy : 0.62146893
# Train Epoch: 22: train loss : 0.91334139	 train accuracy : 0.93686869	 val accuracy : 0.60894661	 test accuracy : 0.59887006
# Train Epoch: 23: train loss : 0.88907673	 train accuracy : 0.94083694	 val accuracy : 0.61616162	 test accuracy : 0.60451977
# Train Epoch: 24: train loss : 0.87939993	 train accuracy : 0.95093795	 val accuracy : 0.61183261	 test accuracy : 0.58192090
# Train Epoch: 25: train loss : 0.84034503	 train accuracy : 0.96284271	 val accuracy : 0.61038961	 test accuracy : 0.60451977
# Train Epoch: 26: train loss : 0.83577920	 train accuracy : 0.96645022	 val accuracy : 0.61471861	 test accuracy : 0.55932203
# Train Epoch: 27: train loss : 0.82785324	 train accuracy : 0.96320346	 val accuracy : 0.62049062	 test accuracy : 0.58192090
# Train Epoch: 28: train loss : 0.80328591	 train accuracy : 0.97438672	 val accuracy : 0.61038961	 test accuracy : 0.57627119
# Train Epoch: 29: train loss : 0.79750137	 train accuracy : 0.97077922	 val accuracy : 0.61904762	 test accuracy : 0.62146893
# Save models
# Train Epoch: 30: train loss : 0.78567661	 train accuracy : 0.97582973	 val accuracy : 0.63636364	 test accuracy : 0.58192090
# Train Epoch: 31: train loss : 0.79442573	 train accuracy : 0.97294372	 val accuracy : 0.63059163	 test accuracy : 0.57627119
# Train Epoch: 32: train loss : 0.77377635	 train accuracy : 0.97655123	 val accuracy : 0.61327561	 test accuracy : 0.57627119
# Train Epoch: 33: train loss : 0.75794890	 train accuracy : 0.97871573	 val accuracy : 0.60750361	 test accuracy : 0.59322034
# Train Epoch: 34: train loss : 0.75039663	 train accuracy : 0.98015873	 val accuracy : 0.60750361	 test accuracy : 0.58757062
# Train Epoch: 35: train loss : 0.75510176	 train accuracy : 0.97474747	 val accuracy : 0.59307359	 test accuracy : 0.58192090
# Train Epoch: 36: train loss : 0.74205240	 train accuracy : 0.97979798	 val accuracy : 0.60317460	 test accuracy : 0.57627119
# Train Epoch: 37: train loss : 0.74528295	 train accuracy : 0.97943723	 val accuracy : 0.60750361	 test accuracy : 0.58757062
# Train Epoch: 38: train loss : 0.73081254	 train accuracy : 0.97799423	 val accuracy : 0.60461760	 test accuracy : 0.59322034
# Train Epoch: 39: train loss : 0.73096976	 train accuracy : 0.97979798	 val accuracy : 0.59740260	 test accuracy : 0.58757062
# Train Epoch: 40: train loss : 0.72524993	 train accuracy : 0.98124098	 val accuracy : 0.59307359	 test accuracy : 0.58192090
# Train Epoch: 41: train loss : 0.72524712	 train accuracy : 0.97691198	 val accuracy : 0.59307359	 test accuracy : 0.58192090
# Train Epoch: 42: train loss : 0.71509849	 train accuracy : 0.98376623	 val accuracy : 0.58585859	 test accuracy : 0.61581921
# Train Epoch: 43: train loss : 0.71900437	 train accuracy : 0.97943723	 val accuracy : 0.58874459	 test accuracy : 0.61581921
# Train Epoch: 44: train loss : 0.70829986	 train accuracy : 0.98665224	 val accuracy : 0.59163059	 test accuracy : 0.62146893
# Train Epoch: 45: train loss : 0.71695178	 train accuracy : 0.98015873	 val accuracy : 0.58730159	 test accuracy : 0.59887006
# Train Epoch: 46: train loss : 0.70442904	 train accuracy : 0.98556999	 val accuracy : 0.58297258	 test accuracy : 0.59322034
# Train Epoch: 47: train loss : 0.70274370	 train accuracy : 0.98448773	 val accuracy : 0.58585859	 test accuracy : 0.58192090
# Train Epoch: 48: train loss : 0.69333109	 train accuracy : 0.98448773	 val accuracy : 0.60461760	 test accuracy : 0.56497175
# Train Epoch: 49: train loss : 0.69811836	 train accuracy : 0.98665224	 val accuracy : 0.60750361	 test accuracy : 0.57627119
# Train Epoch: 50: train loss : 0.69348458	 train accuracy : 0.98484848	 val accuracy : 0.60461760	 test accuracy : 0.58757062
# Train Epoch: 51: train loss : 0.68613610	 train accuracy : 0.98845599	 val accuracy : 0.59884560	 test accuracy : 0.58192090
# Train Epoch: 52: train loss : 0.69218034	 train accuracy : 0.98629149	 val accuracy : 0.60317460	 test accuracy : 0.56497175
# Train Epoch: 53: train loss : 0.69389877	 train accuracy : 0.98196248	 val accuracy : 0.60606061	 test accuracy : 0.57062147
# Train Epoch: 54: train loss : 0.68466803	 train accuracy : 0.98556999	 val accuracy : 0.59884560	 test accuracy : 0.61581921
# Train Epoch: 55: train loss : 0.69302939	 train accuracy : 0.98412698	 val accuracy : 0.59307359	 test accuracy : 0.59322034
# Train Epoch: 56: train loss : 0.68246907	 train accuracy : 0.98773449	 val accuracy : 0.59884560	 test accuracy : 0.59322034
# Train Epoch: 57: train loss : 0.68049392	 train accuracy : 0.98593074	 val accuracy : 0.59163059	 test accuracy : 0.57627119
# Train Epoch: 58: train loss : 0.68438483	 train accuracy : 0.98556999	 val accuracy : 0.59451659	 test accuracy : 0.57627119
# Train Epoch: 59: train loss : 0.68253552	 train accuracy : 0.98376623	 val accuracy : 0.58585859	 test accuracy : 0.57062147
# Train Epoch: 60: train loss : 0.67447640	 train accuracy : 0.98737374	 val accuracy : 0.58008658	 test accuracy : 0.58757062
# Train Epoch: 61: train loss : 0.67400572	 train accuracy : 0.98629149	 val accuracy : 0.57287157	 test accuracy : 0.57627119
# Train Epoch: 62: train loss : 0.68239435	 train accuracy : 0.98556999	 val accuracy : 0.58874459	 test accuracy : 0.58192090
# Train Epoch: 63: train loss : 0.67272027	 train accuracy : 0.98484848	 val accuracy : 0.58441558	 test accuracy : 0.56497175
# Train Epoch: 64: train loss : 0.67569993	 train accuracy : 0.98376623	 val accuracy : 0.58297258	 test accuracy : 0.56497175
# Train Epoch: 65: train loss : 0.66650637	 train accuracy : 0.98881674	 val accuracy : 0.57431457	 test accuracy : 0.56497175
# Train Epoch: 66: train loss : 0.67042937	 train accuracy : 0.98701299	 val accuracy : 0.58441558	 test accuracy : 0.54802260
# Train Epoch: 67: train loss : 0.67508373	 train accuracy : 0.98160173	 val accuracy : 0.59740260	 test accuracy : 0.58192090
# Train Epoch: 68: train loss : 0.66837857	 train accuracy : 0.98773449	 val accuracy : 0.60606061	 test accuracy : 0.57627119
# Train Epoch: 69: train loss : 0.66713445	 train accuracy : 0.98737374	 val accuracy : 0.60894661	 test accuracy : 0.61016949
# Train Epoch: 70: train loss : 0.66466861	 train accuracy : 0.98917749	 val accuracy : 0.60750361	 test accuracy : 0.58192090
# Train Epoch: 71: train loss : 0.66685416	 train accuracy : 0.98881674	 val accuracy : 0.61471861	 test accuracy : 0.57627119
# Train Epoch: 72: train loss : 0.65922730	 train accuracy : 0.98845599	 val accuracy : 0.61471861	 test accuracy : 0.56497175
# Train Epoch: 73: train loss : 0.66036133	 train accuracy : 0.98989899	 val accuracy : 0.61183261	 test accuracy : 0.56497175
# Train Epoch: 74: train loss : 0.66400205	 train accuracy : 0.98773449	 val accuracy : 0.61038961	 test accuracy : 0.55367232
# Train Epoch: 75: train loss : 0.65680848	 train accuracy : 0.98917749	 val accuracy : 0.60606061	 test accuracy : 0.55367232
# Train Epoch: 76: train loss : 0.65773146	 train accuracy : 0.98845599	 val accuracy : 0.60461760	 test accuracy : 0.54237288
# Train Epoch: 77: train loss : 0.66918902	 train accuracy : 0.98665224	 val accuracy : 0.60317460	 test accuracy : 0.57627119
# Train Epoch: 78: train loss : 0.65836555	 train accuracy : 0.99062049	 val accuracy : 0.60750361	 test accuracy : 0.57627119
# Train Epoch: 79: train loss : 0.65789876	 train accuracy : 0.98917749	 val accuracy : 0.61038961	 test accuracy : 0.59322034
# Train Epoch: 80: train loss : 0.66240435	 train accuracy : 0.98917749	 val accuracy : 0.60894661	 test accuracy : 0.57627119
# Train Epoch: 81: train loss : 0.65824118	 train accuracy : 0.98845599	 val accuracy : 0.60317460	 test accuracy : 0.55367232
# Train Epoch: 82: train loss : 0.65148747	 train accuracy : 0.99098124	 val accuracy : 0.59451659	 test accuracy : 0.57627119
# Train Epoch: 83: train loss : 0.65687467	 train accuracy : 0.98520924	 val accuracy : 0.59451659	 test accuracy : 0.57062147
# Train Epoch: 84: train loss : 0.65073528	 train accuracy : 0.99170274	 val accuracy : 0.57864358	 test accuracy : 0.55932203
# Train Epoch: 85: train loss : 0.65737939	 train accuracy : 0.98701299	 val accuracy : 0.59163059	 test accuracy : 0.57627119
# Train Epoch: 86: train loss : 0.66076467	 train accuracy : 0.98737374	 val accuracy : 0.59595960	 test accuracy : 0.57627119
# Train Epoch: 87: train loss : 0.65381026	 train accuracy : 0.98845599	 val accuracy : 0.59163059	 test accuracy : 0.57627119
# Train Epoch: 88: train loss : 0.65325994	 train accuracy : 0.98737374	 val accuracy : 0.60317460	 test accuracy : 0.57627119
# Train Epoch: 89: train loss : 0.65884038	 train accuracy : 0.98845599	 val accuracy : 0.60317460	 test accuracy : 0.57627119
# Train Epoch: 90: train loss : 0.65157571	 train accuracy : 0.98989899	 val accuracy : 0.60606061	 test accuracy : 0.55367232
# Train Epoch: 91: train loss : 0.65850500	 train accuracy : 0.98809524	 val accuracy : 0.62193362	 test accuracy : 0.57062147
# Train Epoch: 92: train loss : 0.64880534	 train accuracy : 0.98989899	 val accuracy : 0.59451659	 test accuracy : 0.59322034
# Train Epoch: 93: train loss : 0.65196099	 train accuracy : 0.98917749	 val accuracy : 0.59163059	 test accuracy : 0.58757062
# Train Epoch: 94: train loss : 0.65594879	 train accuracy : 0.98953824	 val accuracy : 0.59451659	 test accuracy : 0.59887006
# Train Epoch: 95: train loss : 0.65877690	 train accuracy : 0.98556999	 val accuracy : 0.59018759	 test accuracy : 0.60451977
# Train Epoch: 96: train loss : 0.64770721	 train accuracy : 0.99025974	 val accuracy : 0.60028860	 test accuracy : 0.59887006
# Train Epoch: 97: train loss : 0.64670339	 train accuracy : 0.99098124	 val accuracy : 0.59307359	 test accuracy : 0.59887006
# Train Epoch: 98: train loss : 0.66104733	 train accuracy : 0.98520924	 val accuracy : 0.59884560	 test accuracy : 0.59322034
# Train Epoch: 99: train loss : 0.64806724	 train accuracy : 0.98665224	 val accuracy : 0.59307359	 test accuracy : 0.59322034
# Train Epoch: 100: train loss : 0.64762807	 train accuracy : 0.99062049	 val accuracy : 0.59451659	 test accuracy : 0.58757062
# Train Epoch: 101: train loss : 0.65308802	 train accuracy : 0.98881674	 val accuracy : 0.58874459	 test accuracy : 0.59322034
# Train Epoch: 102: train loss : 0.64255546	 train accuracy : 0.98989899	 val accuracy : 0.58730159	 test accuracy : 0.58757062
# Train Epoch: 103: train loss : 0.64628975	 train accuracy : 0.98809524	 val accuracy : 0.59884560	 test accuracy : 0.57627119
# Train Epoch: 104: train loss : 0.65253972	 train accuracy : 0.98773449	 val accuracy : 0.60173160	 test accuracy : 0.59322034
# Train Epoch: 105: train loss : 0.64731953	 train accuracy : 0.98809524	 val accuracy : 0.59163059	 test accuracy : 0.58192090
# Train Epoch: 106: train loss : 0.64953803	 train accuracy : 0.98989899	 val accuracy : 0.58730159	 test accuracy : 0.57627119
# Train Epoch: 107: train loss : 0.64782450	 train accuracy : 0.98881674	 val accuracy : 0.60028860	 test accuracy : 0.57627119
# Train Epoch: 108: train loss : 0.64908950	 train accuracy : 0.98917749	 val accuracy : 0.59163059	 test accuracy : 0.59322034
# Train Epoch: 109: train loss : 0.64419490	 train accuracy : 0.98989899	 val accuracy : 0.59163059	 test accuracy : 0.58192090
# Train Epoch: 110: train loss : 0.65037805	 train accuracy : 0.98809524	 val accuracy : 0.59163059	 test accuracy : 0.57627119
# Train Epoch: 111: train loss : 0.64061599	 train accuracy : 0.98917749	 val accuracy : 0.59018759	 test accuracy : 0.57627119
# Train Epoch: 112: train loss : 0.65075839	 train accuracy : 0.98701299	 val accuracy : 0.60317460	 test accuracy : 0.57062147
# Train Epoch: 113: train loss : 0.64361275	 train accuracy : 0.98845599	 val accuracy : 0.59451659	 test accuracy : 0.58192090
# Train Epoch: 114: train loss : 0.64593819	 train accuracy : 0.99025974	 val accuracy : 0.59595960	 test accuracy : 0.55367232
# Train Epoch: 115: train loss : 0.64332799	 train accuracy : 0.98737374	 val accuracy : 0.60317460	 test accuracy : 0.54802260
# Train Epoch: 116: train loss : 0.64290998	 train accuracy : 0.98989899	 val accuracy : 0.62049062	 test accuracy : 0.54802260
# Train Epoch: 117: train loss : 0.64416604	 train accuracy : 0.98845599	 val accuracy : 0.61760462	 test accuracy : 0.57062147
# Train Epoch: 118: train loss : 0.64589195	 train accuracy : 0.98881674	 val accuracy : 0.60173160	 test accuracy : 0.59322034
# Train Epoch: 119: train loss : 0.63954898	 train accuracy : 0.98989899	 val accuracy : 0.59740260	 test accuracy : 0.59322034
# Train Epoch: 120: train loss : 0.64392968	 train accuracy : 0.98629149	 val accuracy : 0.59451659	 test accuracy : 0.56497175
# Train Epoch: 121: train loss : 0.64018074	 train accuracy : 0.98845599	 val accuracy : 0.59018759	 test accuracy : 0.55367232
# Train Epoch: 122: train loss : 0.64115220	 train accuracy : 0.99386724	 val accuracy : 0.60606061	 test accuracy : 0.56497175
# Train Epoch: 123: train loss : 0.64495069	 train accuracy : 0.98665224	 val accuracy : 0.60028860	 test accuracy : 0.55367232
# Train Epoch: 124: train loss : 0.64783517	 train accuracy : 0.98773449	 val accuracy : 0.59884560	 test accuracy : 0.59322034
# Train Epoch: 125: train loss : 0.64666146	 train accuracy : 0.98665224	 val accuracy : 0.59740260	 test accuracy : 0.60451977
# Train Epoch: 126: train loss : 0.64563594	 train accuracy : 0.98989899	 val accuracy : 0.60461760	 test accuracy : 0.59322034
# Train Epoch: 127: train loss : 0.64566228	 train accuracy : 0.98701299	 val accuracy : 0.60461760	 test accuracy : 0.61581921
# Train Epoch: 128: train loss : 0.64593154	 train accuracy : 0.98737374	 val accuracy : 0.59884560	 test accuracy : 0.61581921
# Train Epoch: 129: train loss : 0.63923682	 train accuracy : 0.98917749	 val accuracy : 0.61760462	 test accuracy : 0.59887006
# Train Epoch: 130: train loss : 0.64237050	 train accuracy : 0.98917749	 val accuracy : 0.61327561	 test accuracy : 0.61016949
# Train Epoch: 131: train loss : 0.63396198	 train accuracy : 0.99242424	 val accuracy : 0.60173160	 test accuracy : 0.60451977
# Train Epoch: 132: train loss : 0.63950949	 train accuracy : 0.98701299	 val accuracy : 0.58585859	 test accuracy : 0.58757062
# Train Epoch: 133: train loss : 0.64049855	 train accuracy : 0.99062049	 val accuracy : 0.58874459	 test accuracy : 0.58757062
# Train Epoch: 134: train loss : 0.63461500	 train accuracy : 0.99025974	 val accuracy : 0.58297258	 test accuracy : 0.61581921
# Train Epoch: 135: train loss : 0.63599805	 train accuracy : 0.99242424	 val accuracy : 0.58441558	 test accuracy : 0.59887006
# Train Epoch: 136: train loss : 0.63285606	 train accuracy : 0.99098124	 val accuracy : 0.59595960	 test accuracy : 0.59322034
# Train Epoch: 137: train loss : 0.63794188	 train accuracy : 0.99062049	 val accuracy : 0.59595960	 test accuracy : 0.60451977
# Train Epoch: 138: train loss : 0.63458204	 train accuracy : 0.98917749	 val accuracy : 0.59595960	 test accuracy : 0.59887006
# Train Epoch: 139: train loss : 0.63801945	 train accuracy : 0.98917749	 val accuracy : 0.60028860	 test accuracy : 0.59322034
# Train Epoch: 140: train loss : 0.63662668	 train accuracy : 0.99206349	 val accuracy : 0.59884560	 test accuracy : 0.57627119
# Train Epoch: 141: train loss : 0.63556602	 train accuracy : 0.99098124	 val accuracy : 0.59595960	 test accuracy : 0.57627119
# Train Epoch: 142: train loss : 0.62566136	 train accuracy : 0.99458874	 val accuracy : 0.59740260	 test accuracy : 0.58192090
# Train Epoch: 143: train loss : 0.63144225	 train accuracy : 0.99062049	 val accuracy : 0.59740260	 test accuracy : 0.58757062
# Train Epoch: 144: train loss : 0.64732370	 train accuracy : 0.98593074	 val accuracy : 0.58874459	 test accuracy : 0.58757062
# Train Epoch: 145: train loss : 0.63229644	 train accuracy : 0.99062049	 val accuracy : 0.58874459	 test accuracy : 0.58192090
# Train Epoch: 146: train loss : 0.63460833	 train accuracy : 0.98845599	 val accuracy : 0.59163059	 test accuracy : 0.58192090
# Train Epoch: 147: train loss : 0.63380682	 train accuracy : 0.99098124	 val accuracy : 0.58585859	 test accuracy : 0.58757062
# Train Epoch: 148: train loss : 0.63800470	 train accuracy : 0.98845599	 val accuracy : 0.58730159	 test accuracy : 0.57627119
# Train Epoch: 149: train loss : 0.63023076	 train accuracy : 0.99025974	 val accuracy : 0.59163059	 test accuracy : 0.61016949
# Train Epoch: 150: train loss : 0.62919313	 train accuracy : 0.99134199	 val accuracy : 0.59163059	 test accuracy : 0.59887006
# Train Epoch: 151: train loss : 0.63660798	 train accuracy : 0.98448773	 val accuracy : 0.59595960	 test accuracy : 0.59887006
# Train Epoch: 152: train loss : 0.62560935	 train accuracy : 0.99314574	 val accuracy : 0.59740260	 test accuracy : 0.57627119
# Train Epoch: 153: train loss : 0.62656980	 train accuracy : 0.99062049	 val accuracy : 0.59595960	 test accuracy : 0.57627119
# Train Epoch: 154: train loss : 0.62922646	 train accuracy : 0.98989899	 val accuracy : 0.59307359	 test accuracy : 0.57062147
# Train Epoch: 155: train loss : 0.62718837	 train accuracy : 0.98881674	 val accuracy : 0.59884560	 test accuracy : 0.58192090
# Train Epoch: 156: train loss : 0.63118478	 train accuracy : 0.98953824	 val accuracy : 0.59307359	 test accuracy : 0.57627119
# Train Epoch: 157: train loss : 0.62575825	 train accuracy : 0.99170274	 val accuracy : 0.58730159	 test accuracy : 0.57627119
# Train Epoch: 158: train loss : 0.62766196	 train accuracy : 0.99098124	 val accuracy : 0.58730159	 test accuracy : 0.58192090
# Train Epoch: 159: train loss : 0.62826178	 train accuracy : 0.98917749	 val accuracy : 0.60028860	 test accuracy : 0.60451977
# Train Epoch: 160: train loss : 0.62691480	 train accuracy : 0.98953824	 val accuracy : 0.60028860	 test accuracy : 0.57627119
# Train Epoch: 161: train loss : 0.62374698	 train accuracy : 0.99242424	 val accuracy : 0.59884560	 test accuracy : 0.57062147
# Train Epoch: 162: train loss : 0.63121772	 train accuracy : 0.98809524	 val accuracy : 0.59884560	 test accuracy : 0.57627119
# Train Epoch: 163: train loss : 0.63015566	 train accuracy : 0.98665224	 val accuracy : 0.60894661	 test accuracy : 0.56497175
# Train Epoch: 164: train loss : 0.62287730	 train accuracy : 0.99025974	 val accuracy : 0.60894661	 test accuracy : 0.56497175
# Train Epoch: 165: train loss : 0.63093832	 train accuracy : 0.98773449	 val accuracy : 0.61327561	 test accuracy : 0.54237288
# Train Epoch: 166: train loss : 0.62898264	 train accuracy : 0.98989899	 val accuracy : 0.60461760	 test accuracy : 0.53672316
# Train Epoch: 167: train loss : 0.63532026	 train accuracy : 0.98809524	 val accuracy : 0.60894661	 test accuracy : 0.56497175
# Train Epoch: 168: train loss : 0.62720749	 train accuracy : 0.99025974	 val accuracy : 0.59740260	 test accuracy : 0.60451977
# Train Epoch: 169: train loss : 0.62178857	 train accuracy : 0.99422799	 val accuracy : 0.59163059	 test accuracy : 0.57627119
# Train Epoch: 170: train loss : 0.63533547	 train accuracy : 0.98809524	 val accuracy : 0.59595960	 test accuracy : 0.59887006
# ...
# Train Epoch: 78: train loss : 0.68799359	 train accuracy : 0.97617354	 val accuracy : 0.60455192	 test accuracy : 0.61676647
# Train Epoch: 79: train loss : 0.69144934	 train accuracy : 0.97261735	 val accuracy : 0.62873400	 test accuracy : 0.65868263
# Train Epoch: 80: train loss : 0.68351505	 train accuracy : 0.97617354	 val accuracy : 0.61593172	 test accuracy : 0.67065868
# Train Epoch: 81: train loss : 0.69916611	 train accuracy : 0.97581792	 val accuracy : 0.59317212	 test accuracy : 0.67065868
# Train Epoch: 82: train loss : 0.68511195	 train accuracy : 0.97688478	 val accuracy : 0.60881935	 test accuracy : 0.65868263
# Train Epoch: 83: train loss : 0.67924930	 train accuracy : 0.97724040	 val accuracy : 0.61166430	 test accuracy : 0.63473054
# Train Epoch: 84: train loss : 0.68181208	 train accuracy : 0.97795164	 val accuracy : 0.61735420	 test accuracy : 0.65868263
# Train Epoch: 85: train loss : 0.69364517	 train accuracy : 0.97368421	 val accuracy : 0.61024182	 test accuracy : 0.67065868
# Train Epoch: 86: train loss : 0.68368577	 train accuracy : 0.97759602	 val accuracy : 0.61735420	 test accuracy : 0.64071856
# Train Epoch: 87: train loss : 0.68371590	 train accuracy : 0.97546230	 val accuracy : 0.60739687	 test accuracy : 0.63473054
# Train Epoch: 88: train loss : 0.68388325	 train accuracy : 0.97830725	 val accuracy : 0.60881935	 test accuracy : 0.64670659
# Train Epoch: 89: train loss : 0.67445308	 train accuracy : 0.98008535	 val accuracy : 0.61877667	 test accuracy : 0.62874251
# Train Epoch: 90: train loss : 0.68387798	 train accuracy : 0.97261735	 val accuracy : 0.60881935	 test accuracy : 0.64071856
# Train Epoch: 91: train loss : 0.68056594	 train accuracy : 0.98008535	 val accuracy : 0.60028450	 test accuracy : 0.64670659
# Train Epoch: 92: train loss : 0.67682621	 train accuracy : 0.97759602	 val accuracy : 0.60455192	 test accuracy : 0.64670659
# Train Epoch: 93: train loss : 0.68599925	 train accuracy : 0.97581792	 val accuracy : 0.60739687	 test accuracy : 0.65868263
# Train Epoch: 94: train loss : 0.67381552	 train accuracy : 0.97652916	 val accuracy : 0.60170697	 test accuracy : 0.62874251
# Train Epoch: 95: train loss : 0.67766659	 train accuracy : 0.97795164	 val accuracy : 0.60881935	 test accuracy : 0.63473054
# Train Epoch: 96: train loss : 0.67894052	 train accuracy : 0.97724040	 val accuracy : 0.60881935	 test accuracy : 0.62874251
# Train Epoch: 97: train loss : 0.67547776	 train accuracy : 0.98079659	 val accuracy : 0.61166430	 test accuracy : 0.62874251
# Train Epoch: 98: train loss : 0.67302330	 train accuracy : 0.97688478	 val accuracy : 0.62162162	 test accuracy : 0.63473054
# Train Epoch: 99: train loss : 0.67377638	 train accuracy : 0.97866287	 val accuracy : 0.62162162	 test accuracy : 0.62874251
# Train Epoch: 100: train loss : 0.67600631	 train accuracy : 0.97617354	 val accuracy : 0.60881935	 test accuracy : 0.64670659
# Train Epoch: 101: train loss : 0.66896113	 train accuracy : 0.98008535	 val accuracy : 0.60739687	 test accuracy : 0.67065868
# Train Epoch: 102: train loss : 0.66592481	 train accuracy : 0.97652916	 val accuracy : 0.59032717	 test accuracy : 0.66467066
# Train Epoch: 103: train loss : 0.67609956	 train accuracy : 0.98008535	 val accuracy : 0.59601707	 test accuracy : 0.65269461
# Train Epoch: 104: train loss : 0.68027326	 train accuracy : 0.97759602	 val accuracy : 0.60312945	 test accuracy : 0.64670659
# Train Epoch: 105: train loss : 0.67321420	 train accuracy : 0.97368421	 val accuracy : 0.60881935	 test accuracy : 0.65868263
# Train Epoch: 106: train loss : 0.67019137	 train accuracy : 0.97759602	 val accuracy : 0.60597440	 test accuracy : 0.61676647
# Train Epoch: 107: train loss : 0.67326181	 train accuracy : 0.97546230	 val accuracy : 0.60028450	 test accuracy : 0.62275449
# Train Epoch: 108: train loss : 0.66856885	 train accuracy : 0.97439545	 val accuracy : 0.59174964	 test accuracy : 0.63473054
# Train Epoch: 109: train loss : 0.66934226	 train accuracy : 0.97546230	 val accuracy : 0.59174964	 test accuracy : 0.62874251
# Train Epoch: 110: train loss : 0.65994115	 train accuracy : 0.97510669	 val accuracy : 0.59743954	 test accuracy : 0.63473054
# Train Epoch: 111: train loss : 0.67051054	 train accuracy : 0.97439545	 val accuracy : 0.60597440	 test accuracy : 0.61676647
# Train Epoch: 112: train loss : 0.66918640	 train accuracy : 0.97155050	 val accuracy : 0.61308677	 test accuracy : 0.62874251
# Train Epoch: 113: train loss : 0.65950402	 train accuracy : 0.98435277	 val accuracy : 0.61308677	 test accuracy : 0.62275449
# Train Epoch: 114: train loss : 0.66636240	 train accuracy : 0.97617354	 val accuracy : 0.60881935	 test accuracy : 0.61676647
# Train Epoch: 115: train loss : 0.66781197	 train accuracy : 0.97724040	 val accuracy : 0.61024182	 test accuracy : 0.62874251
# Train Epoch: 116: train loss : 0.67314063	 train accuracy : 0.97403983	 val accuracy : 0.60455192	 test accuracy : 0.61676647
# Train Epoch: 117: train loss : 0.66359771	 train accuracy : 0.98079659	 val accuracy : 0.61308677	 test accuracy : 0.60479042
# Train Epoch: 118: train loss : 0.66026515	 train accuracy : 0.98008535	 val accuracy : 0.60881935	 test accuracy : 0.61676647
# Train Epoch: 119: train loss : 0.66202273	 train accuracy : 0.98044097	 val accuracy : 0.60597440	 test accuracy : 0.61077844
# Train Epoch: 120: train loss : 0.65999320	 train accuracy : 0.97795164	 val accuracy : 0.61308677	 test accuracy : 0.62275449
# Train Epoch: 121: train loss : 0.66594870	 train accuracy : 0.97581792	 val accuracy : 0.61308677	 test accuracy : 0.61676647
# Train Epoch: 122: train loss : 0.66255295	 train accuracy : 0.97866287	 val accuracy : 0.62304410	 test accuracy : 0.62275449
# Train Epoch: 123: train loss : 0.65678965	 train accuracy : 0.98115220	 val accuracy : 0.60312945	 test accuracy : 0.60479042
# Train Epoch: 124: train loss : 0.65649921	 train accuracy : 0.97866287	 val accuracy : 0.61166430	 test accuracy : 0.61077844
# Train Epoch: 125: train loss : 0.67200294	 train accuracy : 0.97226174	 val accuracy : 0.61024182	 test accuracy : 0.59281437
# Train Epoch: 126: train loss : 0.66716751	 train accuracy : 0.97581792	 val accuracy : 0.59459459	 test accuracy : 0.59281437
# Train Epoch: 127: train loss : 0.66347591	 train accuracy : 0.97688478	 val accuracy : 0.58748222	 test accuracy : 0.59880240
# Train Epoch: 128: train loss : 0.66595823	 train accuracy : 0.97759602	 val accuracy : 0.59743954	 test accuracy : 0.60479042
# Train Epoch: 129: train loss : 0.66561139	 train accuracy : 0.97475107	 val accuracy : 0.59743954	 test accuracy : 0.61077844
# Train Epoch: 130: train loss : 0.66297207	 train accuracy : 0.97972973	 val accuracy : 0.60739687	 test accuracy : 0.60479042
# Train Epoch: 131: train loss : 0.66659362	 train accuracy : 0.98008535	 val accuracy : 0.60881935	 test accuracy : 0.58682635
# Train Epoch: 132: train loss : 0.65971839	 train accuracy : 0.97617354	 val accuracy : 0.62588905	 test accuracy : 0.58083832
# Train Epoch: 133: train loss : 0.66228442	 train accuracy : 0.98044097	 val accuracy : 0.62304410	 test accuracy : 0.59281437
# Train Epoch: 134: train loss : 0.65938271	 train accuracy : 0.97617354	 val accuracy : 0.60455192	 test accuracy : 0.60479042
# Train Epoch: 135: train loss : 0.66535120	 train accuracy : 0.97261735	 val accuracy : 0.61735420	 test accuracy : 0.61676647
# Train Epoch: 136: train loss : 0.65798963	 train accuracy : 0.98186344	 val accuracy : 0.62446657	 test accuracy : 0.61676647
# Train Epoch: 137: train loss : 0.65989962	 train accuracy : 0.97688478	 val accuracy : 0.62162162	 test accuracy : 0.62275449
# Train Epoch: 138: train loss : 0.66034985	 train accuracy : 0.97546230	 val accuracy : 0.61877667	 test accuracy : 0.61676647
# Train Epoch: 139: train loss : 0.65771699	 train accuracy : 0.97795164	 val accuracy : 0.61593172	 test accuracy : 0.61077844
# Train Epoch: 140: train loss : 0.65576771	 train accuracy : 0.97617354	 val accuracy : 0.61166430	 test accuracy : 0.60479042
# Train Epoch: 141: train loss : 0.65345128	 train accuracy : 0.97830725	 val accuracy : 0.61166430	 test accuracy : 0.61077844
# Train Epoch: 142: train loss : 0.65386577	 train accuracy : 0.98648649	 val accuracy : 0.60739687	 test accuracy : 0.61077844
# Train Epoch: 143: train loss : 0.65360681	 train accuracy : 0.98826458	 val accuracy : 0.60597440	 test accuracy : 0.62874251
# Train Epoch: 144: train loss : 0.65540584	 train accuracy : 0.98684211	 val accuracy : 0.60739687	 test accuracy : 0.64071856
# Train Epoch: 145: train loss : 0.65368587	 train accuracy : 0.98719772	 val accuracy : 0.60312945	 test accuracy : 0.62874251
# Train Epoch: 146: train loss : 0.65172515	 train accuracy : 0.98755334	 val accuracy : 0.60170697	 test accuracy : 0.62275449
# Train Epoch: 147: train loss : 0.65307230	 train accuracy : 0.98684211	 val accuracy : 0.60455192	 test accuracy : 0.61676647
# Train Epoch: 148: train loss : 0.65768518	 train accuracy : 0.98186344	 val accuracy : 0.61735420	 test accuracy : 0.62874251
# Train Epoch: 149: train loss : 0.65720840	 train accuracy : 0.99075391	 val accuracy : 0.61877667	 test accuracy : 0.62275449
# Train Epoch: 150: train loss : 0.66164610	 train accuracy : 0.98257468	 val accuracy : 0.62162162	 test accuracy : 0.61676647
# Train Epoch: 151: train loss : 0.65334096	 train accuracy : 0.98328592	 val accuracy : 0.61450925	 test accuracy : 0.62275449
# Train Epoch: 152: train loss : 0.65790887	 train accuracy : 0.98755334	 val accuracy : 0.61450925	 test accuracy : 0.62275449
# Train Epoch: 153: train loss : 0.64974067	 train accuracy : 0.98790896	 val accuracy : 0.61024182	 test accuracy : 0.61077844
# Train Epoch: 154: train loss : 0.64999470	 train accuracy : 0.99004267	 val accuracy : 0.60455192	 test accuracy : 0.61676647
# Train Epoch: 155: train loss : 0.65440509	 train accuracy : 0.98968706	 val accuracy : 0.60597440	 test accuracy : 0.63473054
# Train Epoch: 156: train loss : 0.65648267	 train accuracy : 0.98719772	 val accuracy : 0.60028450	 test accuracy : 0.63473054
# Train Epoch: 157: train loss : 0.64544566	 train accuracy : 0.98719772	 val accuracy : 0.60028450	 test accuracy : 0.61676647
# Train Epoch: 158: train loss : 0.64914094	 train accuracy : 0.98755334	 val accuracy : 0.60028450	 test accuracy : 0.61077844
# Train Epoch: 159: train loss : 0.65425469	 train accuracy : 0.98506401	 val accuracy : 0.60028450	 test accuracy : 0.59281437
# Train Epoch: 160: train loss : 0.65106561	 train accuracy : 0.98577525	 val accuracy : 0.61166430	 test accuracy : 0.60479042
# Train Epoch: 161: train loss : 0.65270326	 train accuracy : 0.98470839	 val accuracy : 0.61166430	 test accuracy : 0.62874251
# Train Epoch: 162: train loss : 0.64461703	 train accuracy : 0.98790896	 val accuracy : 0.60455192	 test accuracy : 0.61676647
# Train Epoch: 163: train loss : 0.64787906	 train accuracy : 0.98826458	 val accuracy : 0.61308677	 test accuracy : 0.62275449
# Train Epoch: 164: train loss : 0.64571234	 train accuracy : 0.98577525	 val accuracy : 0.60881935	 test accuracy : 0.60479042
# Train Epoch: 165: train loss : 0.64470586	 train accuracy : 0.98897582	 val accuracy : 0.61166430	 test accuracy : 0.63473054
# Train Epoch: 166: train loss : 0.64433664	 train accuracy : 0.98897582	 val accuracy : 0.60312945	 test accuracy : 0.62275449
# Train Epoch: 167: train loss : 0.65139691	 train accuracy : 0.98577525	 val accuracy : 0.61450925	 test accuracy : 0.63473054
# Train Epoch: 168: train loss : 0.65157589	 train accuracy : 0.98613087	 val accuracy : 0.60170697	 test accuracy : 0.62275449
# Train Epoch: 169: train loss : 0.63978256	 train accuracy : 0.98968706	 val accuracy : 0.59886202	 test accuracy : 0.59880240
# Train Epoch: 170: train loss : 0.64841800	 train accuracy : 0.98755334	 val accuracy : 0.60170697	 test accuracy : 0.61676647
# Train Epoch: 171: train loss : 0.64830581	 train accuracy : 0.98577525	 val accuracy : 0.59886202	 test accuracy : 0.62275449
# Train Epoch: 172: train loss : 0.64877026	 train accuracy : 0.98541963	 val accuracy : 0.60170697	 test accuracy : 0.62275449
# Train Epoch: 173: train loss : 0.65319264	 train accuracy : 0.98897582	 val accuracy : 0.60455192	 test accuracy : 0.61676647
# Train Epoch: 174: train loss : 0.64194168	 train accuracy : 0.98719772	 val accuracy : 0.60028450	 test accuracy : 0.62275449
# Train Epoch: 175: train loss : 0.64323395	 train accuracy : 0.98897582	 val accuracy : 0.60597440	 test accuracy : 0.62874251
# Train Epoch: 176: train loss : 0.64147942	 train accuracy : 0.98826458	 val accuracy : 0.60739687	 test accuracy : 0.61077844
# Train Epoch: 177: train loss : 0.63885930	 train accuracy : 0.99182077	 val accuracy : 0.61024182	 test accuracy : 0.61077844
# Train Epoch: 178: train loss : 0.64059410	 train accuracy : 0.98826458	 val accuracy : 0.61024182	 test accuracy : 0.62275449
# Train Epoch: 179: train loss : 0.65055777	 train accuracy : 0.98364154	 val accuracy : 0.60881935	 test accuracy : 0.62275449
# Train Epoch: 180: train loss : 0.64256694	 train accuracy : 0.98968706	 val accuracy : 0.60739687	 test accuracy : 0.63473054
# Train Epoch: 181: train loss : 0.64335566	 train accuracy : 0.98790896	 val accuracy : 0.61308677	 test accuracy : 0.63473054
# Train Epoch: 182: train loss : 0.63697587	 train accuracy : 0.98684211	 val accuracy : 0.60881935	 test accuracy : 0.63473054
# Train Epoch: 183: train loss : 0.64392059	 train accuracy : 0.98755334	 val accuracy : 0.61877667	 test accuracy : 0.64071856
# Train Epoch: 184: train loss : 0.64994029	 train accuracy : 0.98719772	 val accuracy : 0.62304410	 test accuracy : 0.64670659
# Train Epoch: 185: train loss : 0.63537064	 train accuracy : 0.98862020	 val accuracy : 0.62162162	 test accuracy : 0.64670659
# Train Epoch: 186: train loss : 0.64349251	 train accuracy : 0.98719772	 val accuracy : 0.61450925	 test accuracy : 0.63473054
# Train Epoch: 187: train loss : 0.64142113	 train accuracy : 0.98790896	 val accuracy : 0.60028450	 test accuracy : 0.64071856
# Train Epoch: 188: train loss : 0.64417546	 train accuracy : 0.98684211	 val accuracy : 0.60597440	 test accuracy : 0.63473054
# Train Epoch: 189: train loss : 0.63671539	 train accuracy : 0.99004267	 val accuracy : 0.60597440	 test accuracy : 0.62874251
# Train Epoch: 190: train loss : 0.64283928	 train accuracy : 0.98897582	 val accuracy : 0.59886202	 test accuracy : 0.64670659
# Train Epoch: 191: train loss : 0.64026787	 train accuracy : 0.99039829	 val accuracy : 0.62019915	 test accuracy : 0.63473054
# Train Epoch: 192: train loss : 0.63697002	 train accuracy : 0.99217639	 val accuracy : 0.62588905	 test accuracy : 0.63473054
# Train Epoch: 193: train loss : 0.64296368	 train accuracy : 0.98719772	 val accuracy : 0.62304410	 test accuracy : 0.63473054
# Train Epoch: 194: train loss : 0.63856788	 train accuracy : 0.98968706	 val accuracy : 0.62304410	 test accuracy : 0.63473054
# Train Epoch: 195: train loss : 0.64117551	 train accuracy : 0.98826458	 val accuracy : 0.62446657	 test accuracy : 0.64071856
# Train Epoch: 196: train loss : 0.64103504	 train accuracy : 0.98719772	 val accuracy : 0.62873400	 test accuracy : 0.65269461
# Train Epoch: 197: train loss : 0.63485633	 train accuracy : 0.98826458	 val accuracy : 0.61593172	 test accuracy : 0.62874251
# Train Epoch: 198: train loss : 0.63173534	 train accuracy : 0.99039829	 val accuracy : 0.60739687	 test accuracy : 0.62275449
# Train Epoch: 199: train loss : 0.63438790	 train accuracy : 0.98933144	 val accuracy : 0.59886202	 test accuracy : 0.61676647
# Train Epoch: 200: train loss : 0.63580676	 train accuracy : 0.98933144	 val accuracy : 0.59743954	 test accuracy : 0.62275449
# In ensemble  5
# The best validaiton accuracy is:  0.6330014224751067
# Happened at epoch:  50
# The corresponding test accuracy 0.6407185628742516
# The corresponding test AUC is:  0.646231884057971
# The Max voting test accuracy is:  0.6195402298850575
# The test AUC is:  0.6512452112369223
