# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/ABIDE/")
# Out:
# Mounted at /content/drive

# %%
# load ComBat algorithm
# !python /content/drive/MyDrive/ABIDE/neuralCombat.py 
import sys
sys.path.append('/content/drive/MyDrive/ABIDE/')

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from neuralCombat import *
# from neuralCombat.py import neuralCombat
import pandas as pd
from sklearn import svm
import joblib
import openpyxl
from openpyxl import load_workbook
import os
import scipy.io as scio
import argparse
import numpy as np
import time
import torch
import torch.utils.data
import torch.nn as nn
import torch.optim as optim
from torch.utils.data.dataset import Dataset
from torch.autograd import Variable
from torchvision import datasets, transforms
from torchvision.utils import make_grid , save_image
import torchvision.utils as vutils
from os.path import join
from os import listdir
from torch.utils.data.dataloader import DataLoader
from torch.utils.data import DataLoader
from collections import OrderedDict
import nibabel as nib
import matplotlib.pyplot as plt
import cv2 as cv
from os import path
import shutil
import scipy.stats
import scipy.ndimage
import random
import torch.nn.init as init
import torch.nn.functional as F
import sys
import math
from functools import reduce
import operator
from scipy.interpolate import interp1d
from torch.optim import lr_scheduler
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import RidgeClassifier
from sklearn.feature_selection import RFE

def feature_selection_fMRI(matrix, labels, train_ind, fnum):
    """
        matrix       : feature matrix (num_subjects x num_features)
        labels       : ground truth labels (num_subjects x 1)
        train_ind    : indices of the training samples
        fnum         : size of the feature vector after feature selection 

    return:
        x_data      : feature matrix of lower dimension (num_subjects x fnum)
    """

    estimator = RidgeClassifier()
    selector = RFE(estimator, n_features_to_select=fnum, step=100, verbose=1)

    featureX = matrix[train_ind, :]
    featureY = labels[train_ind]
    selector = selector.fit(featureX, featureY.ravel())

    return selector
def feature_selection_sMRI(matrix, labels, train_ind, fnum):
    """
        matrix       : feature matrix (num_subjects x num_features)
        labels       : ground truth labels (num_subjects x 1)
        train_ind    : indices of the training samples
        fnum         : size of the feature vector after feature selection 

    return:
        x_data      : feature matrix of lower dimension (num_subjects x fnum)
    """

    estimator = RidgeClassifier()
    selector = RFE(estimator, n_features_to_select=fnum, step=10, verbose=1)

    featureX = matrix[train_ind, :]
    featureY = labels[train_ind]
    selector = selector.fit(featureX, featureY.ravel())

    return selector

def get_index(lst=None, item=''):
	return [i for i in range(len(lst)) if lst[i] == item]

def flatten_one(length, img):
	'''
	  In some situations, the dimension on z-axis of images are smaller than
	  the dimension of z-axis of patches, this function will be used to pad
	'''

	one_line = np.zeros((1, int(length)))
	position = 0
	for i in range(img.shape[0]):  # column
		for j in range(i + 1, img.shape[1]):  # row
			one_line[0, position] = img[j, i]
			position = position + 1
	return one_line


def get_ids(num_subjects=None,dir_path=''):
	"""
	return:
		subject_IDs    : list of all subject IDs
	"""
	subject_IDs = np.genfromtxt(os.path.join(dir_path, 'subject_IDs.txt'), dtype=str)

	if num_subjects is not None:
		subject_IDs = subject_IDs[:num_subjects]

	return subject_IDs

def save_model(net,path, name_net):

  # This fucntion is used to save a specific model

    path_net =  path + '/' + name_net + '.pth'
    torch.save(net.cpu().state_dict(), path_net)
    net.cuda()

def load_model(net, path, name_net):

  # This function is used to load a specific model we saved before

    path_net =  path + '/' + name_net + '.pth'
    net.load_state_dict(torch.load(path_net))

    return net

# %%
########################################### Load Data ###############################################
#####################################################################################################
#####################################################################################################
fMRI_atlas = 'CC200'  # AAL or CC200
combat_fMRI = True    # True or False
combat_sMRI = True

if combat_sMRI == False:
  save_combat_sMRI = '/without_ComBat/'
else:
  save_combat_sMRI = '/with_ComBat/'

# fMRI path
save_path = '/content/drive/MyDrive/ABIDE/save_models/CC200_sMRI/'+ save_combat_sMRI
root_path_fMRI = '/content/dataset'
if os.path.exists(root_path_fMRI):
  shutil.rmtree(root_path_fMRI) 
shutil.copytree('/content/drive/MyDrive/ABIDE/' + fMRI_atlas + '/original/', root_path_fMRI) 
label_dir = '/content/drive/MyDrive/ABIDE/phenotypic_image_quality'

# sMRI path
localDir = '/content/sMRI_dataset/'
if os.path.exists(localDir):
  shutil.rmtree(localDir) 
os.makedirs(localDir)
# !unzip '/content/drive/MyDrive/ABIDE/freesurfer_stats.zip' -d '/content/sMRI_dataset'
localDir = localDir + 'freesurfer_stats/'


k_fold = 5
new_number_features_fMRI = 5000
new_number_features_sMRI = 1435
new_number_features_combine = 6000
number_samples = 871
useless_samples = ['51334']
if fMRI_atlas == 'AAL':
  image_size = [116, 116]
else:
  image_size = [200, 200]
scaler = True


age_name = 'ages.mat'
gender_name = 'genders.mat'
label_name = 'ABIDE_label_871.mat'
label = scio.loadmat(os.path.join(label_dir, label_name))
label = label['label'][0]
labels = np.zeros(number_samples - len(useless_samples))
site_name = 'sites.mat'
site = scio.loadmat(os.path.join(label_dir, site_name))
all_sites = site['sites']
for i in range(len(all_sites)):
	site = all_sites[i]
	all_sites[i] = site.replace(' ', '')
unique_sites = np.unique(all_sites)
sites = []
unique_sites = list(unique_sites)

gender = scio.loadmat(os.path.join(label_dir, gender_name))
gender = gender['genders']
genders = np.zeros((number_samples - len(useless_samples), 1))

age = scio.loadmat(os.path.join(label_dir, age_name))
age = age['ages']
ages = np.zeros((number_samples - len(useless_samples), 1))

subject_IDs = get_ids(number_samples,dir_path=label_dir)
subject_IDs = subject_IDs.tolist()
length = image_size[0] * (image_size[1]-1) / 2
fMRI_images = np.zeros((number_samples - len(useless_samples), int(length)))

position = 0
print('constructing fMRI features')
for i in range(number_samples):
  subject_name = subject_IDs[i]
  if subject_name in useless_samples:
    subject_index = get_index(lst=subject_IDs, item=subject_name)
    print('The index for sample ' + subject_name + ' is : ', subject_index)
  else:
    image_name = subject_name + '.mat'
    subject_index = get_index(lst=subject_IDs, item=subject_name)
    image = scio.loadmat(os.path.join(root_path_fMRI, image_name))
    img = image['connectivity']

    idx = np.triu_indices_from(img, 1)
    fMRI_images[position, :] = img[idx]
    sites.append(all_sites[subject_index[0]])
    labels[position] = label[subject_index[0]]
    genders[position] = int(gender[subject_index[0]]) + 1
    ages[position] = float(age[subject_index[0]].replace(' ', ''))
    position = position + 1

if scaler == True:
	fMRI_images = StandardScaler().fit_transform(fMRI_images)
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51096/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51097/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51098/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51099/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51100/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51101/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51102/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51103/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51104/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51105/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51106/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51107/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51109/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51110/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51111/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51112/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51113/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51114/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51116/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51117/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51118/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51122/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51123/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51124/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51126/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51127/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51128/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51129/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51130/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51131/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.w-g.pct.stats
# ...
#   inflating: /content/sMRI_dataset/freesurfer_stats/51576/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51576/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51576/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51576/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51576/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51577/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51578/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51579/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51580/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51582/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51583/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51584/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51585/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51606/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51607/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/wmparc.stats
# constructing fMRI features
# The index for sample 51334 is :  [799]

# %%
############################################### Load sMRI ###############################################################
############################################### Load sMRI ###############################################################
############################################### Load sMRI ###############################################################
############################################### Load Desikan_Killiany_features
left = 'lh.aparc.stats'
right = 'rh.aparc.stats'
number_roi = 68
feature_list = ['NumVert', 'SurfArea', 'GrayVol', 'ThickAvg', 'ThickStd', 'MeanCurv', 'GausCurv', 'FoldInd', 'CurvInd']
names = ['StructName', 'NumVert', 'SurfArea', 'GrayVol', 'ThickAvg', 'ThickStd', 'MeanCurv', 'GausCurv', 'FoldInd', 'CurvInd']
skiprows= list(range(0,61))
Desikan_Killiany_features = np.zeros((number_samples - len(useless_samples), number_roi * len(feature_list)))


position = 0
print('constructing Desikan-Killiany Atlas features')
for i in range(number_samples):
  subject_name = subject_IDs[i]
  if subject_name in useless_samples:
    subject_index = get_index(lst=subject_IDs, item=subject_name)
    print('The index for sample ' + subject_name + ' is : ', subject_index)
  else:
    table_left = pd.read_table(localDir + subject_name + '/' + left, sep='\s+', names=names,
						  skiprows=skiprows)
    table_right = pd.read_table(localDir + subject_name + '/' + right, sep='\s+', names=names,
						  skiprows=skiprows)

    for j in range(len(feature_list)):
      feature_name = feature_list[j]
      left_features = table_left[feature_name].values.tolist()
      right_features = table_right[feature_name].values.tolist()
      all_features = left_features + right_features
      if len(all_features) != number_roi:
       print('The sample ' + subject_name + ' has mistake!')
      all_features = np.array(all_features)
      Desikan_Killiany_features[position, j*number_roi : (j+1)*number_roi] = all_features
    position = position + 1

if scaler == True:
	for i in range(len(feature_list)):
		Desikan_Killiany_features[:, i * number_roi: (i+1) * number_roi] = StandardScaler().fit_transform(Desikan_Killiany_features[:, i * number_roi: (i+1) * number_roi])

print('finished')

############################################### Load aseg features
print('constructing aseg features')
number_roi_aseg = 45
aseg = 'aseg.stats'
feature_list_aseg = ['Number of Voxels', 'Volume', 'Intensity normMean', 'Itensity normStdDev', 'Intensity normMin', 'Intensity normMax', 'Intensity normRange']
names_aseg = ['ColHeader Index', 'Segmentation Id ', 'Number of Voxels', 'Volume', 'Structure Name', 'Intensity normMean', 'Itensity normStdDev', 'Intensity normMin', 'Intensity normMax', 'Intensity normRange']
skiprows_aseg= list(range(0,79))
aseg_features = np.zeros((number_samples - len(useless_samples), number_roi_aseg * len(feature_list_aseg)))

position = 0
for i in range(number_samples):
	subject_name = subject_IDs[i]
	if subject_name in useless_samples:
		subject_index = get_index(lst=subject_IDs, item=subject_name)
		print('The index for sample ' + subject_name + ' is : ', subject_index)
	else:
		table_left = pd.read_table(localDir + subject_name + '/' + aseg, sep='\s+', names=names_aseg,
						  skiprows=skiprows_aseg)
		for j in range(len(feature_list_aseg)):
			feature_name = feature_list_aseg[j]
			left_features = table_left[feature_name].values.tolist()
			if len(left_features) != number_roi_aseg:
				print('The sample ' + subject_name + ' has mistake!')
			all_features = np.array(left_features)
			aseg_features[position, j*number_roi_aseg : (j+1)*number_roi_aseg] = all_features
		position = position + 1

if scaler == True:
	for i in range(len(feature_list_aseg)):
		aseg_features[:, i * number_roi_aseg: (i+1) * number_roi_aseg] = StandardScaler().fit_transform(aseg_features[:, i * number_roi_aseg: (i+1) * number_roi_aseg])
print('finished')

############################################### Load wmparc features
number_roi_wmparc = 70
wmparc = 'wmparc.stats'
feature_list_wmparc = ['Number of Voxels', 'Volume', 'Intensity normMean', 'Itensity normStdDev', 'Intensity normMin', 'Intensity normMax', 'Intensity normRange']
names_wmparc = ['ColHeader Index', 'Segmentation Id ', 'Number of Voxels', 'Volume', 'Structure Name', 'Intensity normMean', 'Itensity normStdDev', 'Intensity normMin', 'Intensity normMax', 'Intensity normRange']
skiprows_wmparc= list(range(0,65))
wmparc_features = np.zeros((number_samples - len(useless_samples), number_roi_wmparc * len(feature_list_wmparc)))

print('constructing wmparc features')
position = 0
for i in range(number_samples):
	subject_name = subject_IDs[i]
	if subject_name in useless_samples:
		subject_index = get_index(lst=subject_IDs, item=subject_name)
		print('The index for sample ' + subject_name + ' is : ', subject_index)
	else:
		table_left = pd.read_table(localDir + subject_name + '/' + wmparc, sep='\s+', names = names_wmparc,
						  skiprows=skiprows_wmparc)
		for j in range(len(feature_list_wmparc)):
			feature_name = feature_list_wmparc[j]
			left_features = table_left[feature_name].values.tolist()
			if len(left_features) != number_roi_wmparc:
				print('The sample ' + subject_name + ' has mistake!')
			all_features = np.array(left_features)
			wmparc_features[position, j*number_roi_wmparc : (j+1)*number_roi_wmparc] = all_features
		position = position + 1
if scaler == True:
	for i in range(len(feature_list_wmparc)):
		wmparc_features[:, i * number_roi_wmparc: (i+1) * number_roi_wmparc] = StandardScaler().fit_transform(wmparc_features[:, i * number_roi_wmparc: (i+1) * number_roi_wmparc])
print('finished')

############################################### concatenation
sMRI_features = np.concatenate((Desikan_Killiany_features, aseg_features, wmparc_features),axis = 1)
# Out:
# constructing Desikan-Killiany Atlas features
# The index for sample 51334 is :  [799]
# finished
# constructing aseg features
# The index for sample 51334 is :  [799]
# finished
# constructing wmparc features
# The index for sample 51334 is :  [799]
# finished

# %%
plt.matshow(sMRI_features, vmin=-6, vmax=6)
plt.show()

# %%
############################################### Combat ###############################################################
############################################### Combat ###############################################################
############################################### Combat ###############################################################

batch = []
for i in range(len(sites)):
	batch.append(get_index(lst=unique_sites, item=sites[i])[0]+1)

combat_labels = []
combat_genders = []
combat_ages = []
for i in range(len(labels)):
	combat_labels.append(labels[i] + 1)
	combat_genders.append(genders[i])
	combat_ages.append(ages[i])
 
if combat_fMRI == True:
	print('The ComBat for fMRI')
	new_all_samples_feature = fMRI_images.T
	covars = {}
	covars['batch'] = batch
	covars['labels'] = combat_labels
	covars['genders'] = combat_genders
	covars['ages'] = combat_ages
	covars = pd.DataFrame(covars)

	# To specify names of the variables that are categorical:
	categorical_cols = ['labels','genders']
	continuous_cols = ['ages']
	# To specify the name of the variable that encodes for the scanner/batch covariate:
	batch_col = 'batch'
	# Harmonization step:
	new_all_samples_feature = neuroCombat(dat=new_all_samples_feature,
											covars=covars,
											batch_col=batch_col,
											categorical_cols=categorical_cols,
											continuous_cols=continuous_cols)["data"]
	fMRI_images = new_all_samples_feature.T

if combat_sMRI == True:
	print('The ComBat for sMRI')
	new_all_samples_feature = sMRI_features.T
	covars = {}
	covars['batch'] = batch
	covars['labels'] = combat_labels
	covars['genders'] = combat_genders
	covars['ages'] = combat_ages
	covars = pd.DataFrame(covars)

	# To specify names of the variables that are categorical:
	categorical_cols = ['labels', 'genders']
	continuous_cols = ['ages']
	# To specify the name of the variable that encodes for the scanner/batch covariate:
	batch_col = 'batch'
	# Harmonization step:
	new_all_samples_feature = neuroCombat(dat=new_all_samples_feature,
											covars=covars,
											batch_col=batch_col,
											categorical_cols=categorical_cols,
											continuous_cols=continuous_cols)["data"]
	sMRI_features = new_all_samples_feature.T
# Out:
# The ComBat for fMRI
# [neuroCombat] Creating design matrix
# [neuroCombat] Standardizing data across features
# [neuroCombat] Fitting L/S model and finding priors
# [neuroCombat] Finding parametric adjustments
# [neuroCombat] Final adjustment of data
# The ComBat for sMRI
# [neuroCombat] Creating design matrix
# [neuroCombat] Standardizing data across features
# [neuroCombat] Fitting L/S model and finding priors
# [neuroCombat] Finding parametric adjustments
# [neuroCombat] Final adjustment of data
# /content/drive/MyDrive/ABIDE/neuralCombat.py:325: RuntimeWarning: divide by zero encountered in true_divide
#   change = max((abs(g_new - g_old) / g_old).max(), (abs(d_new - d_old) / d_old).max())

# %%
plt.matshow(sMRI_features, vmin=-4, vmax=4)
plt.show()

# %%
############################################### phenotypic ###############################################################
############################################### phenotypic ###############################################################
############################################### phenotypic ###############################################################
ages_name = 'ages.mat'
ages = scio.loadmat(os.path.join(label_dir, ages_name))
ages = ages['ages']

gender_name = 'genders.mat'
genders = scio.loadmat(os.path.join(label_dir, gender_name))
genders = genders['genders']

FIQ_name = 'FIQS.mat'
FIQS = scio.loadmat(os.path.join(label_dir, FIQ_name))
FIQS = FIQS['FIQS']

NUM_name = 'NUM.mat'
NUM = scio.loadmat(os.path.join(label_dir, NUM_name))
NUMS = NUM['NUM']

PEC_name = 'PEC.mat'
PEC = scio.loadmat(os.path.join(label_dir, PEC_name))
PECS = PEC['PEC']

RAT_name = 'RAT.mat'
RAT = scio.loadmat(os.path.join(label_dir, RAT_name))
RATS = RAT['RAT']

age = np.zeros((number_samples - len(useless_samples), 1))
gender = np.zeros((number_samples - len(useless_samples), 1))
FIQ = np.zeros((number_samples - len(useless_samples), 1))
NUM = np.zeros((number_samples - len(useless_samples), 1))
PEC = np.zeros((number_samples - len(useless_samples), 1))
RAT = np.zeros((number_samples - len(useless_samples), 1))

position = 0
print('constructing phenotypic features')
for i in range(number_samples):
	subject_name = subject_IDs[i]
	if subject_name in useless_samples:
		subject_index = get_index(lst=subject_IDs, item=subject_name)
		print('The index for sample ' + subject_name + ' is : ', subject_index)
	else:
		subject_index = get_index(lst=subject_IDs, item=subject_name)
		age[position] = float(ages[subject_index[0]].replace(' ', ''))
		gender[position] = int(genders[subject_index[0]]) + 1
		FIQ[position] = int(FIQS[subject_index[0]])
		NUM[position] = float(NUMS[subject_index[0]])
		PEC[position] = float(PECS[subject_index[0]])
		RAT[position] = int(RATS[subject_index[0]])
		position = position + 1
FIQ[FIQ == -9999] = 108

if scaler == True:

  age[:,0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(age[:,0], axis = 1)))
  FIQ[:, 0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(FIQ[:, 0], axis = 1)))
  NUM[:, 0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(NUM[:, 0], axis = 1)))
  PEC[:, 0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(PEC[:, 0], axis = 1)))

# age, gender, FIQ, NUM, PEC, RAT
for i in range(3):
	sMRI_features = np.concatenate((sMRI_features, age, gender, FIQ, NUM, PEC, RAT),axis = 1)
# Out:
# constructing phenotypic features
# The index for sample 51334 is :  [799]

# %%
dist_train = {}
dist_validation = {}
dist_test = {}
for i in range(k_fold):
	dist_train[str(i + 1)] = []
	dist_validation[str(i + 1)] = []
	dist_test[str(i + 1)] = []

for each_site in unique_sites:
	index_site = get_index(sites, each_site)
	label = np.zeros((len(index_site)))
	for i in range(len(index_site)):
		index = index_site[i]
		label[i] = int(labels[int(index)])
	########################################### StratifiedKFold ####################################################
	sfolder = StratifiedKFold(n_splits=k_fold,random_state=0,shuffle=True)
	group = 0
	for train, validation in sfolder.split(index_site,label):
		for i in train:
			dist_train[str(group + 1)].append(index_site[i])
			name = 0
		for j in validation:
			dist_validation[str(group + 1)].append(index_site[j])
			name = 0
		group = group+1

	group = 0
	for train, validation in sfolder.split(index_site,label):
		if group == 0:
			for j in validation:
				dist_test[str(group + k_fold)].append(index_site[j])
				dist_train[str(group + k_fold)].remove(index_site[j])
		else:
			for j in validation:
				dist_test[str(group)].append(index_site[j])
				dist_train[str(group)].remove(index_site[j])
		group = group+1

# %%
import torch.nn as nn
############################################### FCN model ###############################################################
############################################### FCN model ###############################################################
############################################### FCN model ###############################################################
def single_linear(in_channels, out_channels, dropout):
    return nn.Sequential(
        nn.Linear(in_features=in_channels, out_features=out_channels),
        nn.Dropout(dropout),
        nn.ReLU(inplace=True),
        nn.BatchNorm1d(out_channels)
    )

class FCN(nn.Module):
    def __init__(self, input_c, hid_1, hid_2, out_c, dropout):
        super().__init__()

        self.linear_1 = single_linear(input_c, hid_1, dropout)
        self.linear_2 = nn.Linear(in_features=hid_1, out_features=hid_2)
        self.linear_3 = nn.Linear(in_features=hid_2, out_features=out_c)

        self.dropout = nn.Dropout(dropout)
        self.relu = nn.ReLU(inplace=True)
        self.softmax = nn.LogSoftmax(dim=1)


    def forward(self, x):

        input = torch.flatten(x, start_dim=1, end_dim=-1)
        x = self.relu(self.linear_1(input))
        x = self.relu(self.dropout(self.linear_2(x)))
        x = self.linear_3(x)
        out = self.softmax(x)
        return out

# %%
FCN_labels = np.zeros((number_samples - len(useless_samples), 2))
for i in range(len(labels)):
    if labels[i] == 1:
        FCN_labels[i,0] = 1
    else:
        FCN_labels[i,1] = 1

data = {}
for fold in range(1, k_fold+1):

  data[str(fold)] = []
  selector_fMRI = feature_selection_fMRI(fMRI_images, labels, dist_train[str(fold)], new_number_features_fMRI)
  selector_sMRI = feature_selection_sMRI(sMRI_features, labels, dist_train[str(fold)], new_number_features_sMRI)

  new_fMRI_data = selector_fMRI.transform(fMRI_images)
  new_sMRI_data = selector_sMRI.transform(sMRI_features)
  ################################################# combine ##########################################
  sMRI_fMRI_combine = np.concatenate((new_sMRI_data, new_fMRI_data), axis = 1)
  selector_combine = feature_selection_fMRI(sMRI_fMRI_combine, labels, dist_train[str(fold)], new_number_features_combine)
  fold_data = selector_combine.transform(sMRI_fMRI_combine)

  data[str(fold)].append(fold_data)
  data[str(fold)].append(FCN_labels)
# Out:
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 6435 features.
# Fitting estimator with 6335 features.
# Fitting estimator with 6235 features.
# Fitting estimator with 6135 features.
# Fitting estimator with 6035 features.
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 6435 features.
# Fitting estimator with 6335 features.
# Fitting estimator with 6235 features.
# Fitting estimator with 6135 features.
# Fitting estimator with 6035 features.
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 6435 features.
# Fitting estimator with 6335 features.
# Fitting estimator with 6235 features.
# Fitting estimator with 6135 features.
# Fitting estimator with 6035 features.
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 6435 features.
# Fitting estimator with 6335 features.
# Fitting estimator with 6235 features.
# Fitting estimator with 6135 features.
# Fitting estimator with 6035 features.
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 6435 features.
# Fitting estimator with 6335 features.
# Fitting estimator with 6235 features.
# Fitting estimator with 6135 features.
# Fitting estimator with 6035 features.

# %%
############################################### Train, validaiton, test pipelines ###############################################################
############################################### Train, validaiton, test pipelines ###############################################################
############################################### Train, validaiton, test pipelines ###############################################################
def train_FCN(args, model, all_data, fold_train_index, fold_validation_index, fold_test_index, scheduler):

    model.train()

    data = torch.from_numpy(all_data[0])
    data = Variable(data, requires_grad=True)
    data = data.float()

    target = torch.from_numpy(all_data[1])
    target = target.float().long()

    if args.cuda:
        data, target = data.cuda(), target.cuda()
    
    data_train = data[fold_train_index,:] 
    target = target[fold_train_index, :]
    scheduler.zero_grad()
    out = model(data_train)

    cross_loss = torch.nn.functional.nll_loss(out, torch.max(target, 1)[1])
    cross_loss.backward()
    scheduler.step()

    out = torch.max(out, 1)[1]
    target = torch.max(target, 1)[1]
    target = target.cpu().numpy()
    out = out.cpu().numpy()

    ############################## validation and test ################################################################################
    val_target, val_out, val_loss = validation_FCN(args, model, all_data, fold_validation_index)
    test_target, test_out, test_out_prob, test_loss = test_FCN(args, model, all_data, fold_test_index)

    return model, target, out, cross_loss.item(), val_target, val_out,val_loss, test_target, test_out, test_out_prob, test_loss

    
def validation_FCN(args, model,all_data,  fold_validation_index):

    model.eval()
    data = torch.from_numpy(all_data[0])
    data = Variable(data, requires_grad=False)
    data = data.float()

    target = torch.from_numpy(all_data[1])
    target = target.float().long()


    if args.cuda:
        data, target = data.cuda(), target.cuda()


    data_val = data[fold_validation_index,:] 
    target = target[fold_validation_index, :]
    out = model(data_val)

    cross_loss = torch.nn.functional.nll_loss(out, torch.max(target, 1)[1])

    out = torch.max(out, 1)[1]
    target = torch.max(target, 1)[1]
    target = target.cpu().numpy()
    out = out.cpu().numpy()

    return target, out, cross_loss.item()


def test_FCN(args, model, all_data,  fold_test_index):

    model.eval()

    data = torch.from_numpy(all_data[0])
    data = Variable(data, requires_grad=False)
    data = data.float()

    target = torch.from_numpy(all_data[1])
    target = target.float().long()


    if args.cuda:
        data, target = data.cuda(), target.cuda()
    
    data_test = data[fold_test_index,:] 
    target = target[fold_test_index, :]
    out = model(data_test)

    cross_loss = torch.nn.functional.nll_loss(out, torch.max(target, 1)[1])

    out_prob = torch.exp(out)
    out = torch.max(out, 1)[1]
    target = torch.max(target, 1)[1]
    target = target.cpu().numpy()
    out = out.cpu().numpy()
    out_prob = out_prob.cpu().detach().numpy()

    return target, out, out_prob, cross_loss.item()

# %%
########################################### Training setting ################################################
########################################### Training setting ################################################
########################################### Training setting ################################################
parser = argparse.ArgumentParser()
parser.add_argument('--ngpu', type=int, default=1)
parser.add_argument('--nEpochs', type=int, default=200)
parser.add_argument('--no-cuda', action='store_true')
parser.add_argument('--seed', type=int, default=1)
parser.add_argument('--lr', type=str, default=8e-4)
# I define three kinds of optimizer, adam sgd and rmsprop, but adam performs the best
parser.add_argument('--opt', type=str, default='adam')
parser.add_argument('--input_c', type=int, default=new_number_features_combine)
parser.add_argument('--hid_1', type=int, default=500)
parser.add_argument('--hid_2', type=int, default=30)
parser.add_argument('--out_c', type=int, default=2)
parser.add_argument('--dropout_rate', type=int, default=0.5)


args, unknown = parser.parse_known_args()
args.cuda = not args.no_cuda and torch.cuda.is_available()
torch.manual_seed(args.seed)
if args.cuda:
    torch.cuda.manual_seed(args.seed)
    
gpu_ids = range(args.ngpu)
train = train_FCN

# %%
########################################### Training ################################################
########################################### Training ################################################
########################################### Training ################################################


for fold in range(1, k_fold+1):
  model = FCN(input_c=args.input_c, hid_1=args.hid_1, hid_2=args.hid_2, out_c=args.out_c, dropout=args.dropout_rate)
  print('  + Number of params: {}'.format(
    sum([p.data.nelement() for p in model.parameters()])))
  model = nn.parallel.DataParallel(model, device_ids=gpu_ids)
  if args.cuda:
    model = model.cuda()
  optimizer = optim.Adam(model.parameters(), lr = args.lr)

  best_validation_accuracy = 0
  Train_accuracy_list =[]
  Train_loss_list = []
  Val_accuracy_list =[]
  Val_loss_list = []
  Test_accuracy_list =[]
  Test_loss_list = []

  for epoch in range(1, args.nEpochs + 1):

    model, train_target, train_out, train_loss, val_target, val_out, val_loss, test_target, test_out, test_prob, test_loss = train(args, model, data[str(fold)], dist_train[str(fold)], dist_validation[str(fold)], dist_test[str(fold)], optimizer)

    train_accuracy = metrics.accuracy_score(train_target, train_out)
    val_accuracy = metrics.accuracy_score(val_target, val_out)
    test_accuracy = metrics.accuracy_score(test_target, test_out)
    Train_accuracy_list.append(train_accuracy)
    Val_accuracy_list.append(val_accuracy)
    Test_accuracy_list.append(test_accuracy)
    Train_loss_list.append(train_loss)
    Val_loss_list.append(val_loss)
    Test_loss_list.append(test_loss)

    if val_accuracy >=best_validation_accuracy:
      best_epoch = epoch
      best_validation_accuracy = val_accuracy
      corresponding_val_out = val_out
      corresponding_test_accuracy = test_accuracy
      corresponding_test_out = test_out
      corresponding_test_prob = test_prob

      print('Save models')
      save_model(model, save_path, 'FCN_'+str(fold))

    print('Train Epoch: ' + str(epoch) + ': train loss : {:.8f}\t train accuracy : {:.8f}\t val accuracy : {:.8f}\t test accuracy : {:.8f}\t'.format(
      train_loss, train_accuracy, val_accuracy, test_accuracy))
  
  if fold == 1:
    all_fold_val_label = val_target
    all_fold_val_out = corresponding_val_out
    all_fold_test_label = test_target
    all_fold_test_out = corresponding_test_out
    all_fold_test_prob = corresponding_test_prob
  else:
    all_fold_val_label = np.concatenate((all_fold_val_label, val_target),axis = 0)
    all_fold_val_out = np.concatenate((all_fold_val_out, corresponding_val_out),axis = 0)
    all_fold_test_label = np.concatenate((all_fold_test_label, test_target),axis = 0)
    all_fold_test_out = np.concatenate((all_fold_test_out, corresponding_test_out),axis = 0)
    all_fold_test_prob = np.concatenate((all_fold_test_prob, corresponding_test_prob),axis = 0)

  x_axis = list(range(1, len(Train_accuracy_list)+1))
  plt.figure(figsize=(10,6))
  plt.plot(x_axis, Train_loss_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_loss_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_loss_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()

  plt.figure(figsize=(10,6))
  plt.plot(x_axis, Train_accuracy_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_accuracy_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_accuracy_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()


  test_fpr, test_tpr, te_thresholds = roc_curve(test_target, corresponding_test_prob[:,1],pos_label=1)
  test_auc = auc(test_fpr, test_tpr)
  print('\n')
  print('In fold ',str(fold))
  print('The best validaiton accuracy is: ',best_validation_accuracy)
  print('Happened at epoch: ',best_epoch)
  print('The corresponding test accuracy', corresponding_test_accuracy)
  print('The corresponding test AUC is: ',test_auc)
  print('\n')


  plt.grid()
  plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
  plt.plot([0,1],[0,1],'g--')
  plt.legend()
  plt.xlabel("False Positive Rate")
  plt.ylabel("True Positive Rate")
  plt.title("Test AUC(ROC curve)")
  plt.grid(color='black', linestyle='-', linewidth=0.5)
  plt.show()

print('Finish 5-fold training')
# Out:
#   + Number of params: 3016592
# Save models
# Train Epoch: 1: train loss : 0.73393315	 train accuracy : 0.48140900	 val accuracy : 0.59340659	 test accuracy : 0.59322034
# Save models
# Train Epoch: 2: train loss : 0.62029290	 train accuracy : 0.68101761	 val accuracy : 0.65934066	 test accuracy : 0.65536723
# Save models
# Train Epoch: 3: train loss : 0.54863572	 train accuracy : 0.79256360	 val accuracy : 0.67032967	 test accuracy : 0.68926554
# Save models
# Train Epoch: 4: train loss : 0.49028516	 train accuracy : 0.85714286	 val accuracy : 0.69230769	 test accuracy : 0.68926554
# Save models
# Train Epoch: 5: train loss : 0.45973504	 train accuracy : 0.88454012	 val accuracy : 0.70329670	 test accuracy : 0.66101695
# Save models
# Train Epoch: 6: train loss : 0.41087875	 train accuracy : 0.90802348	 val accuracy : 0.71428571	 test accuracy : 0.66101695
# Save models
# Train Epoch: 7: train loss : 0.38419572	 train accuracy : 0.90998043	 val accuracy : 0.72527473	 test accuracy : 0.65536723
# Save models
# Train Epoch: 8: train loss : 0.33799034	 train accuracy : 0.94716243	 val accuracy : 0.73626374	 test accuracy : 0.67231638
# Train Epoch: 9: train loss : 0.31376034	 train accuracy : 0.96281800	 val accuracy : 0.72527473	 test accuracy : 0.68361582
# Train Epoch: 10: train loss : 0.27133039	 train accuracy : 0.96868885	 val accuracy : 0.72527473	 test accuracy : 0.68361582
# Save models
# Train Epoch: 11: train loss : 0.26101834	 train accuracy : 0.96281800	 val accuracy : 0.74175824	 test accuracy : 0.69491525
# Save models
# Train Epoch: 12: train loss : 0.22362305	 train accuracy : 0.96673190	 val accuracy : 0.74175824	 test accuracy : 0.69491525
# Train Epoch: 13: train loss : 0.18799165	 train accuracy : 0.98825832	 val accuracy : 0.73626374	 test accuracy : 0.70621469
# Save models
# Train Epoch: 14: train loss : 0.15954214	 train accuracy : 0.99021526	 val accuracy : 0.74725275	 test accuracy : 0.70621469
# Save models
# Train Epoch: 15: train loss : 0.14486238	 train accuracy : 0.99021526	 val accuracy : 0.74725275	 test accuracy : 0.69491525
# Save models
# Train Epoch: 16: train loss : 0.13351627	 train accuracy : 0.99608611	 val accuracy : 0.74725275	 test accuracy : 0.70056497
# Save models
# Train Epoch: 17: train loss : 0.11388240	 train accuracy : 0.99412916	 val accuracy : 0.74725275	 test accuracy : 0.69491525
# Train Epoch: 18: train loss : 0.09508157	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.70056497
# Save models
# Train Epoch: 19: train loss : 0.08178145	 train accuracy : 0.99608611	 val accuracy : 0.76373626	 test accuracy : 0.70621469
# Save models
# Train Epoch: 20: train loss : 0.08872634	 train accuracy : 0.99804305	 val accuracy : 0.77472527	 test accuracy : 0.70621469
# Train Epoch: 21: train loss : 0.06256551	 train accuracy : 1.00000000	 val accuracy : 0.76373626	 test accuracy : 0.71186441
# Train Epoch: 22: train loss : 0.05111737	 train accuracy : 0.99608611	 val accuracy : 0.76923077	 test accuracy : 0.70056497
# Train Epoch: 23: train loss : 0.05019888	 train accuracy : 0.99608611	 val accuracy : 0.76373626	 test accuracy : 0.70621469
# Train Epoch: 24: train loss : 0.04137420	 train accuracy : 0.99804305	 val accuracy : 0.76923077	 test accuracy : 0.70056497
# Save models
# Train Epoch: 25: train loss : 0.03899490	 train accuracy : 0.99804305	 val accuracy : 0.78021978	 test accuracy : 0.71186441
# Save models
# Train Epoch: 26: train loss : 0.03733550	 train accuracy : 1.00000000	 val accuracy : 0.79120879	 test accuracy : 0.71186441
# Save models
# Train Epoch: 27: train loss : 0.03140001	 train accuracy : 1.00000000	 val accuracy : 0.79120879	 test accuracy : 0.71751412
# Save models
# Train Epoch: 28: train loss : 0.02188154	 train accuracy : 1.00000000	 val accuracy : 0.79670330	 test accuracy : 0.71186441
# Train Epoch: 29: train loss : 0.02644005	 train accuracy : 1.00000000	 val accuracy : 0.79120879	 test accuracy : 0.70621469
# Train Epoch: 30: train loss : 0.02430804	 train accuracy : 0.99804305	 val accuracy : 0.78021978	 test accuracy : 0.72316384
# Train Epoch: 31: train loss : 0.02337110	 train accuracy : 1.00000000	 val accuracy : 0.76923077	 test accuracy : 0.71751412
# Train Epoch: 32: train loss : 0.01626485	 train accuracy : 1.00000000	 val accuracy : 0.76373626	 test accuracy : 0.71751412
# Train Epoch: 33: train loss : 0.01527998	 train accuracy : 0.99804305	 val accuracy : 0.74725275	 test accuracy : 0.71751412
# Train Epoch: 34: train loss : 0.01968451	 train accuracy : 0.99608611	 val accuracy : 0.76373626	 test accuracy : 0.71751412
# Train Epoch: 35: train loss : 0.01200563	 train accuracy : 1.00000000	 val accuracy : 0.77472527	 test accuracy : 0.71186441
# Train Epoch: 36: train loss : 0.01051276	 train accuracy : 1.00000000	 val accuracy : 0.77472527	 test accuracy : 0.71186441
# Train Epoch: 37: train loss : 0.01101561	 train accuracy : 1.00000000	 val accuracy : 0.76923077	 test accuracy : 0.71751412
# Train Epoch: 38: train loss : 0.01153630	 train accuracy : 1.00000000	 val accuracy : 0.77472527	 test accuracy : 0.72316384
# Train Epoch: 39: train loss : 0.00983159	 train accuracy : 1.00000000	 val accuracy : 0.77472527	 test accuracy : 0.72881356
# Train Epoch: 40: train loss : 0.00981486	 train accuracy : 1.00000000	 val accuracy : 0.77472527	 test accuracy : 0.72881356
# Train Epoch: 41: train loss : 0.01170033	 train accuracy : 1.00000000	 val accuracy : 0.77472527	 test accuracy : 0.72316384
# Train Epoch: 42: train loss : 0.00932464	 train accuracy : 0.99804305	 val accuracy : 0.77472527	 test accuracy : 0.71751412
# Train Epoch: 43: train loss : 0.00854591	 train accuracy : 1.00000000	 val accuracy : 0.77472527	 test accuracy : 0.71186441
# Train Epoch: 44: train loss : 0.00894313	 train accuracy : 1.00000000	 val accuracy : 0.76923077	 test accuracy : 0.71751412
# Train Epoch: 45: train loss : 0.00707727	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.72316384
# Train Epoch: 46: train loss : 0.00609755	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.72316384
# Train Epoch: 47: train loss : 0.00849754	 train accuracy : 0.99804305	 val accuracy : 0.76373626	 test accuracy : 0.72316384
# Train Epoch: 48: train loss : 0.00636676	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.72316384
# Train Epoch: 49: train loss : 0.00600155	 train accuracy : 1.00000000	 val accuracy : 0.76373626	 test accuracy : 0.72316384
# Train Epoch: 50: train loss : 0.00595434	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.71751412
# Train Epoch: 51: train loss : 0.00655916	 train accuracy : 1.00000000	 val accuracy : 0.76373626	 test accuracy : 0.72881356
# Train Epoch: 52: train loss : 0.00614210	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.72316384
# Train Epoch: 53: train loss : 0.00647155	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.72881356
# Train Epoch: 54: train loss : 0.00457893	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.72881356
# Train Epoch: 55: train loss : 0.00427104	 train accuracy : 1.00000000	 val accuracy : 0.76373626	 test accuracy : 0.73446328
# Train Epoch: 56: train loss : 0.00572708	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.73446328
# Train Epoch: 57: train loss : 0.00519297	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.73446328
# Train Epoch: 58: train loss : 0.00660494	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.73446328
# Train Epoch: 59: train loss : 0.00493538	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.73446328
# Train Epoch: 60: train loss : 0.00520166	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.73446328
# Train Epoch: 61: train loss : 0.00323579	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.72881356
# Train Epoch: 62: train loss : 0.00352107	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.73446328
# Train Epoch: 63: train loss : 0.00537737	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.73446328
# Train Epoch: 64: train loss : 0.00435762	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.73446328
# Train Epoch: 65: train loss : 0.00377940	 train accuracy : 1.00000000	 val accuracy : 0.76373626	 test accuracy : 0.73446328
# Train Epoch: 66: train loss : 0.00530455	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.71751412
# Train Epoch: 67: train loss : 0.00309064	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.71751412
# Train Epoch: 68: train loss : 0.00439446	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.72316384
# Train Epoch: 69: train loss : 0.00257518	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.73446328
# Train Epoch: 70: train loss : 0.00308370	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.73446328
# Train Epoch: 71: train loss : 0.00345902	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.72881356
# Train Epoch: 72: train loss : 0.00313178	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.72881356
# Train Epoch: 73: train loss : 0.00208621	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.72881356
# Train Epoch: 74: train loss : 0.00202209	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.72881356
# Train Epoch: 75: train loss : 0.00252185	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.72881356
# Train Epoch: 76: train loss : 0.00331104	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.72881356
# Train Epoch: 77: train loss : 0.00241373	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.72316384
# Train Epoch: 78: train loss : 0.00180836	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.72316384
# Train Epoch: 79: train loss : 0.00323081	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.72316384
# Train Epoch: 80: train loss : 0.00293836	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.72316384
# Train Epoch: 81: train loss : 0.00270951	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.72881356
# Train Epoch: 82: train loss : 0.00229689	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.72881356
# Train Epoch: 83: train loss : 0.00159164	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.72316384
# Train Epoch: 84: train loss : 0.00189373	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.72316384
# Train Epoch: 85: train loss : 0.00305545	 train accuracy : 0.99804305	 val accuracy : 0.74175824	 test accuracy : 0.72881356
# Train Epoch: 86: train loss : 0.00234969	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.72881356
# Train Epoch: 87: train loss : 0.00157375	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.72881356
# Train Epoch: 88: train loss : 0.00186689	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.72881356
# Train Epoch: 89: train loss : 0.00491346	 train accuracy : 0.99804305	 val accuracy : 0.75274725	 test accuracy : 0.72881356
# Train Epoch: 90: train loss : 0.00120441	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.72881356
# Train Epoch: 91: train loss : 0.00198977	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.72881356
# Train Epoch: 92: train loss : 0.00144793	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.72881356
# Train Epoch: 93: train loss : 0.00176497	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.72881356
# Train Epoch: 94: train loss : 0.00209462	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.72881356
# Train Epoch: 95: train loss : 0.00451133	 train accuracy : 0.99804305	 val accuracy : 0.75274725	 test accuracy : 0.72881356
# Train Epoch: 96: train loss : 0.00139407	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.72881356
# Train Epoch: 97: train loss : 0.00161110	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.72881356
# Train Epoch: 98: train loss : 0.00221342	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.72881356
# Train Epoch: 99: train loss : 0.00179556	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.72881356
# Train Epoch: 100: train loss : 0.00176199	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.72881356
# Train Epoch: 101: train loss : 0.00126033	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.72881356
# Train Epoch: 102: train loss : 0.00130581	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.72881356
# Train Epoch: 103: train loss : 0.00338824	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.72881356
# Train Epoch: 104: train loss : 0.00154112	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.72881356
# Train Epoch: 105: train loss : 0.00135106	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.72881356
# Train Epoch: 106: train loss : 0.00188150	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.72881356
# Train Epoch: 107: train loss : 0.00300590	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.72316384
# Train Epoch: 108: train loss : 0.00229779	 train accuracy : 0.99804305	 val accuracy : 0.75274725	 test accuracy : 0.72316384
# Train Epoch: 109: train loss : 0.00130040	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.72316384
# Train Epoch: 110: train loss : 0.00170464	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.72316384
# Train Epoch: 111: train loss : 0.00275797	 train accuracy : 0.99804305	 val accuracy : 0.75274725	 test accuracy : 0.72316384
# Train Epoch: 112: train loss : 0.00160118	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.72881356
# Train Epoch: 113: train loss : 0.00421275	 train accuracy : 0.99608611	 val accuracy : 0.75274725	 test accuracy : 0.72316384
# Train Epoch: 114: train loss : 0.00199748	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.72316384
# Train Epoch: 115: train loss : 0.00158841	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.72316384
# Train Epoch: 116: train loss : 0.00107115	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.72316384
# Train Epoch: 117: train loss : 0.00205944	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.72881356
# Train Epoch: 118: train loss : 0.00173339	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.72881356
# Train Epoch: 119: train loss : 0.00201800	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.72316384
# Train Epoch: 120: train loss : 0.00311760	 train accuracy : 0.99804305	 val accuracy : 0.75824176	 test accuracy : 0.72316384
# Train Epoch: 121: train loss : 0.00119737	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.72316384
# Train Epoch: 122: train loss : 0.00109784	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.72316384
# Train Epoch: 123: train loss : 0.00194862	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.72316384
# Train Epoch: 124: train loss : 0.00107459	 train accuracy : 1.00000000	 val accuracy : 0.76373626	 test accuracy : 0.72316384
# Train Epoch: 125: train loss : 0.00112509	 train accuracy : 1.00000000	 val accuracy : 0.76373626	 test accuracy : 0.72316384
# Train Epoch: 126: train loss : 0.00171658	 train accuracy : 1.00000000	 val accuracy : 0.77472527	 test accuracy : 0.72316384
# Train Epoch: 127: train loss : 0.00316182	 train accuracy : 0.99804305	 val accuracy : 0.77472527	 test accuracy : 0.72316384
# Train Epoch: 128: train loss : 0.00102830	 train accuracy : 1.00000000	 val accuracy : 0.77472527	 test accuracy : 0.71751412
# Train Epoch: 129: train loss : 0.00237715	 train accuracy : 0.99804305	 val accuracy : 0.76373626	 test accuracy : 0.72316384
# Train Epoch: 130: train loss : 0.00132756	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.72316384
# Train Epoch: 131: train loss : 0.00133076	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.72316384
# Train Epoch: 132: train loss : 0.00107524	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.71751412
# Train Epoch: 133: train loss : 0.00151310	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.72881356
# Train Epoch: 134: train loss : 0.00094171	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.72881356
# Train Epoch: 135: train loss : 0.00179803	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.72316384
# Train Epoch: 136: train loss : 0.00097625	 train accuracy : 1.00000000	 val accuracy : 0.71428571	 test accuracy : 0.72316384
# Train Epoch: 137: train loss : 0.00137909	 train accuracy : 1.00000000	 val accuracy : 0.70879121	 test accuracy : 0.72316384
# Train Epoch: 138: train loss : 0.00256275	 train accuracy : 1.00000000	 val accuracy : 0.71428571	 test accuracy : 0.72316384
# Train Epoch: 139: train loss : 0.00284918	 train accuracy : 0.99804305	 val accuracy : 0.71978022	 test accuracy : 0.72316384
# Train Epoch: 140: train loss : 0.00135800	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.71751412
# Train Epoch: 141: train loss : 0.00065630	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.71751412
# Train Epoch: 142: train loss : 0.00142480	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.71751412
# Train Epoch: 143: train loss : 0.00134144	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.71751412
# Train Epoch: 144: train loss : 0.00155538	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.71751412
# Train Epoch: 145: train loss : 0.00116545	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.71751412
# Train Epoch: 146: train loss : 0.00119262	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.71751412
# Train Epoch: 147: train loss : 0.00184685	 train accuracy : 1.00000000	 val accuracy : 0.73626374	 test accuracy : 0.71751412
# Train Epoch: 148: train loss : 0.00232663	 train accuracy : 0.99804305	 val accuracy : 0.75274725	 test accuracy : 0.72316384
# Train Epoch: 149: train loss : 0.00121913	 train accuracy : 1.00000000	 val accuracy : 0.76373626	 test accuracy : 0.72881356
# Train Epoch: 150: train loss : 0.00089075	 train accuracy : 1.00000000	 val accuracy : 0.76373626	 test accuracy : 0.72881356
# Train Epoch: 151: train loss : 0.00071605	 train accuracy : 1.00000000	 val accuracy : 0.76373626	 test accuracy : 0.72881356
# Train Epoch: 152: train loss : 0.00088579	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.72881356
# Train Epoch: 153: train loss : 0.00111955	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.72881356
# Train Epoch: 154: train loss : 0.00151750	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.72881356
# Train Epoch: 155: train loss : 0.00206246	 train accuracy : 1.00000000	 val accuracy : 0.76373626	 test accuracy : 0.72881356
# Train Epoch: 156: train loss : 0.00148510	 train accuracy : 1.00000000	 val accuracy : 0.76373626	 test accuracy : 0.72881356
# Train Epoch: 157: train loss : 0.00083203	 train accuracy : 1.00000000	 val accuracy : 0.76373626	 test accuracy : 0.72316384
# Train Epoch: 158: train loss : 0.00062156	 train accuracy : 1.00000000	 val accuracy : 0.76373626	 test accuracy : 0.72316384
# Train Epoch: 159: train loss : 0.00101526	 train accuracy : 1.00000000	 val accuracy : 0.76373626	 test accuracy : 0.72316384
# Train Epoch: 160: train loss : 0.00063635	 train accuracy : 1.00000000	 val accuracy : 0.76373626	 test accuracy : 0.72881356
# Train Epoch: 161: train loss : 0.00155648	 train accuracy : 1.00000000	 val accuracy : 0.76373626	 test accuracy : 0.72881356
# Train Epoch: 162: train loss : 0.00106852	 train accuracy : 1.00000000	 val accuracy : 0.76373626	 test accuracy : 0.72316384
# Train Epoch: 163: train loss : 0.00080275	 train accuracy : 1.00000000	 val accuracy : 0.76373626	 test accuracy : 0.72316384
# Train Epoch: 164: train loss : 0.00057328	 train accuracy : 1.00000000	 val accuracy : 0.76373626	 test accuracy : 0.72316384
# Train Epoch: 165: train loss : 0.00101566	 train accuracy : 1.00000000	 val accuracy : 0.76923077	 test accuracy : 0.72316384
# Train Epoch: 166: train loss : 0.00107366	 train accuracy : 1.00000000	 val accuracy : 0.76923077	 test accuracy : 0.72316384
# Train Epoch: 167: train loss : 0.00100047	 train accuracy : 1.00000000	 val accuracy : 0.76923077	 test accuracy : 0.72316384
# Train Epoch: 168: train loss : 0.00079138	 train accuracy : 1.00000000	 val accuracy : 0.76923077	 test accuracy : 0.71751412
# Train Epoch: 169: train loss : 0.00077360	 train accuracy : 1.00000000	 val accuracy : 0.76923077	 test accuracy : 0.72316384
# Train Epoch: 170: train loss : 0.00156493	 train accuracy : 1.00000000	 val accuracy : 0.77472527	 test accuracy : 0.72316384
# Train Epoch: 171: train loss : 0.00233799	 train accuracy : 0.99804305	 val accuracy : 0.77472527	 test accuracy : 0.72881356
# Train Epoch: 172: train loss : 0.00112076	 train accuracy : 1.00000000	 val accuracy : 0.77472527	 test accuracy : 0.72881356
# Train Epoch: 173: train loss : 0.00071026	 train accuracy : 1.00000000	 val accuracy : 0.77472527	 test accuracy : 0.72316384
# Train Epoch: 174: train loss : 0.00089832	 train accuracy : 1.00000000	 val accuracy : 0.77472527	 test accuracy : 0.72316384
# Train Epoch: 175: train loss : 0.00089970	 train accuracy : 1.00000000	 val accuracy : 0.77472527	 test accuracy : 0.72316384
# Train Epoch: 176: train loss : 0.00071238	 train accuracy : 1.00000000	 val accuracy : 0.76923077	 test accuracy : 0.72316384
# Train Epoch: 177: train loss : 0.00088994	 train accuracy : 1.00000000	 val accuracy : 0.76373626	 test accuracy : 0.72316384
# Train Epoch: 178: train loss : 0.00219297	 train accuracy : 0.99804305	 val accuracy : 0.76373626	 test accuracy : 0.72316384
# Train Epoch: 179: train loss : 0.00049053	 train accuracy : 1.00000000	 val accuracy : 0.76373626	 test accuracy : 0.72316384
# Train Epoch: 180: train loss : 0.00217927	 train accuracy : 0.99804305	 val accuracy : 0.75824176	 test accuracy : 0.72316384
# Train Epoch: 181: train loss : 0.00064269	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.72316384
# Train Epoch: 182: train loss : 0.00106747	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.72316384
# Train Epoch: 183: train loss : 0.00085897	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.72316384
# Train Epoch: 184: train loss : 0.00110376	 train accuracy : 1.00000000	 val accuracy : 0.76923077	 test accuracy : 0.72316384
# Train Epoch: 185: train loss : 0.00050702	 train accuracy : 1.00000000	 val accuracy : 0.77472527	 test accuracy : 0.72881356
# Train Epoch: 186: train loss : 0.00245808	 train accuracy : 0.99804305	 val accuracy : 0.77472527	 test accuracy : 0.72881356
# Train Epoch: 187: train loss : 0.00076734	 train accuracy : 1.00000000	 val accuracy : 0.77472527	 test accuracy : 0.72881356
# Train Epoch: 188: train loss : 0.00117422	 train accuracy : 1.00000000	 val accuracy : 0.76373626	 test accuracy : 0.72316384
# Train Epoch: 189: train loss : 0.00076983	 train accuracy : 1.00000000	 val accuracy : 0.76373626	 test accuracy : 0.72316384
# Train Epoch: 190: train loss : 0.00096878	 train accuracy : 1.00000000	 val accuracy : 0.76373626	 test accuracy : 0.72316384
# Train Epoch: 191: train loss : 0.00072786	 train accuracy : 1.00000000	 val accuracy : 0.76373626	 test accuracy : 0.72316384
# Train Epoch: 192: train loss : 0.00079250	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.71751412
# Train Epoch: 193: train loss : 0.00074954	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.71751412
# Train Epoch: 194: train loss : 0.00099930	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.71751412
# Train Epoch: 195: train loss : 0.00047551	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.71751412
# Train Epoch: 196: train loss : 0.00049869	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.71751412
# Train Epoch: 197: train loss : 0.00067015	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.71751412
# Train Epoch: 198: train loss : 0.00045962	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.71751412
# Train Epoch: 199: train loss : 0.00069520	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.71751412
# Train Epoch: 200: train loss : 0.00039966	 train accuracy : 1.00000000	 val accuracy : 0.75274725	 test accuracy : 0.71751412
# In fold  1
# The best validaiton accuracy is:  0.7967032967032966
# Happened at epoch:  28
# The corresponding test accuracy 0.711864406779661
# The corresponding test AUC is:  0.7858056265984654
#   + Number of params: 3016592
# Save models
# Train Epoch: 1: train loss : 0.72863179	 train accuracy : 0.48362235	 val accuracy : 0.57062147	 test accuracy : 0.63218391
# Save models
# Train Epoch: 2: train loss : 0.60438460	 train accuracy : 0.70327553	 val accuracy : 0.66666667	 test accuracy : 0.63218391
# Train Epoch: 3: train loss : 0.54311353	 train accuracy : 0.82851638	 val accuracy : 0.65536723	 test accuracy : 0.65517241
# Train Epoch: 4: train loss : 0.49895141	 train accuracy : 0.84585742	 val accuracy : 0.65536723	 test accuracy : 0.69540230
# Save models
# Train Epoch: 5: train loss : 0.44518760	 train accuracy : 0.89788054	 val accuracy : 0.67796610	 test accuracy : 0.70114943
# Save models
# Train Epoch: 6: train loss : 0.42442244	 train accuracy : 0.90751445	 val accuracy : 0.67796610	 test accuracy : 0.69540230
# Save models
# Train Epoch: 7: train loss : 0.36792451	 train accuracy : 0.93834297	 val accuracy : 0.68926554	 test accuracy : 0.68965517
# Train Epoch: 8: train loss : 0.33072993	 train accuracy : 0.95761079	 val accuracy : 0.67796610	 test accuracy : 0.66666667
# Train Epoch: 9: train loss : 0.29842556	 train accuracy : 0.96339114	 val accuracy : 0.67231638	 test accuracy : 0.67241379
# Train Epoch: 10: train loss : 0.26009679	 train accuracy : 0.97495183	 val accuracy : 0.67231638	 test accuracy : 0.67241379
# Train Epoch: 11: train loss : 0.24775551	 train accuracy : 0.97495183	 val accuracy : 0.65536723	 test accuracy : 0.70114943
# Train Epoch: 12: train loss : 0.21126561	 train accuracy : 0.98265896	 val accuracy : 0.64406780	 test accuracy : 0.70114943
# Train Epoch: 13: train loss : 0.18174034	 train accuracy : 0.99036609	 val accuracy : 0.66101695	 test accuracy : 0.70114943
# Train Epoch: 14: train loss : 0.16880360	 train accuracy : 0.99421965	 val accuracy : 0.67796610	 test accuracy : 0.67816092
# Train Epoch: 15: train loss : 0.14414395	 train accuracy : 0.99614644	 val accuracy : 0.68361582	 test accuracy : 0.66091954
# Train Epoch: 16: train loss : 0.12580658	 train accuracy : 0.99421965	 val accuracy : 0.67231638	 test accuracy : 0.69540230
# Train Epoch: 17: train loss : 0.11297943	 train accuracy : 0.99807322	 val accuracy : 0.66666667	 test accuracy : 0.71264368
# Train Epoch: 18: train loss : 0.09577283	 train accuracy : 1.00000000	 val accuracy : 0.67231638	 test accuracy : 0.70689655
# Train Epoch: 19: train loss : 0.08891539	 train accuracy : 0.99421965	 val accuracy : 0.68361582	 test accuracy : 0.70689655
# Save models
# Train Epoch: 20: train loss : 0.08086131	 train accuracy : 0.99807322	 val accuracy : 0.68926554	 test accuracy : 0.69540230
# Save models
# Train Epoch: 21: train loss : 0.07732721	 train accuracy : 1.00000000	 val accuracy : 0.69491525	 test accuracy : 0.68965517
# Save models
# Train Epoch: 22: train loss : 0.06464458	 train accuracy : 0.99614644	 val accuracy : 0.69491525	 test accuracy : 0.68390805
# Train Epoch: 23: train loss : 0.05615208	 train accuracy : 1.00000000	 val accuracy : 0.68926554	 test accuracy : 0.68390805
# Train Epoch: 24: train loss : 0.04500715	 train accuracy : 1.00000000	 val accuracy : 0.68926554	 test accuracy : 0.69540230
# Save models
# Train Epoch: 25: train loss : 0.04538026	 train accuracy : 0.99614644	 val accuracy : 0.69491525	 test accuracy : 0.68965517
# Save models
# Train Epoch: 26: train loss : 0.04008703	 train accuracy : 0.99614644	 val accuracy : 0.69491525	 test accuracy : 0.68965517
# Save models
# Train Epoch: 27: train loss : 0.02795409	 train accuracy : 1.00000000	 val accuracy : 0.70056497	 test accuracy : 0.68965517
# Save models
# Train Epoch: 28: train loss : 0.02921107	 train accuracy : 1.00000000	 val accuracy : 0.70621469	 test accuracy : 0.68390805
# Save models
# Train Epoch: 29: train loss : 0.03236509	 train accuracy : 1.00000000	 val accuracy : 0.70621469	 test accuracy : 0.68390805
# Save models
# Train Epoch: 30: train loss : 0.02242959	 train accuracy : 1.00000000	 val accuracy : 0.70621469	 test accuracy : 0.67816092
# Train Epoch: 31: train loss : 0.02433240	 train accuracy : 1.00000000	 val accuracy : 0.70056497	 test accuracy : 0.68965517
# Train Epoch: 32: train loss : 0.01786074	 train accuracy : 1.00000000	 val accuracy : 0.69491525	 test accuracy : 0.69540230
# Train Epoch: 33: train loss : 0.01691368	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.70114943
# Train Epoch: 34: train loss : 0.01623264	 train accuracy : 1.00000000	 val accuracy : 0.67231638	 test accuracy : 0.71264368
# Train Epoch: 35: train loss : 0.01686960	 train accuracy : 1.00000000	 val accuracy : 0.67231638	 test accuracy : 0.71264368
# Train Epoch: 36: train loss : 0.01737464	 train accuracy : 1.00000000	 val accuracy : 0.67231638	 test accuracy : 0.71264368
# Train Epoch: 37: train loss : 0.01523431	 train accuracy : 1.00000000	 val accuracy : 0.67231638	 test accuracy : 0.70689655
# Train Epoch: 38: train loss : 0.01453890	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.70689655
# Train Epoch: 39: train loss : 0.01161195	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.69540230
# Train Epoch: 40: train loss : 0.01167670	 train accuracy : 1.00000000	 val accuracy : 0.70056497	 test accuracy : 0.69540230
# Train Epoch: 41: train loss : 0.01189850	 train accuracy : 1.00000000	 val accuracy : 0.70056497	 test accuracy : 0.68965517
# Save models
# Train Epoch: 42: train loss : 0.01132642	 train accuracy : 1.00000000	 val accuracy : 0.71186441	 test accuracy : 0.68390805
# Save models
# Train Epoch: 43: train loss : 0.00876299	 train accuracy : 1.00000000	 val accuracy : 0.71186441	 test accuracy : 0.68390805
# Train Epoch: 44: train loss : 0.01032433	 train accuracy : 1.00000000	 val accuracy : 0.70621469	 test accuracy : 0.67816092
# Train Epoch: 45: train loss : 0.00875991	 train accuracy : 1.00000000	 val accuracy : 0.69491525	 test accuracy : 0.68390805
# Train Epoch: 46: train loss : 0.01118862	 train accuracy : 1.00000000	 val accuracy : 0.70056497	 test accuracy : 0.68965517
# Train Epoch: 47: train loss : 0.00870730	 train accuracy : 1.00000000	 val accuracy : 0.70056497	 test accuracy : 0.68390805
# Train Epoch: 48: train loss : 0.00611824	 train accuracy : 1.00000000	 val accuracy : 0.70056497	 test accuracy : 0.68390805
# Train Epoch: 49: train loss : 0.01129814	 train accuracy : 1.00000000	 val accuracy : 0.70621469	 test accuracy : 0.68390805
# Train Epoch: 50: train loss : 0.00584008	 train accuracy : 1.00000000	 val accuracy : 0.69491525	 test accuracy : 0.68390805
# Train Epoch: 51: train loss : 0.00657127	 train accuracy : 1.00000000	 val accuracy : 0.68926554	 test accuracy : 0.68390805
# Train Epoch: 52: train loss : 0.00620253	 train accuracy : 1.00000000	 val accuracy : 0.68926554	 test accuracy : 0.70114943
# Train Epoch: 53: train loss : 0.00691899	 train accuracy : 1.00000000	 val accuracy : 0.68926554	 test accuracy : 0.69540230
# Train Epoch: 54: train loss : 0.00563135	 train accuracy : 1.00000000	 val accuracy : 0.68926554	 test accuracy : 0.69540230
# Train Epoch: 55: train loss : 0.00486692	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.69540230
# Train Epoch: 56: train loss : 0.00510713	 train accuracy : 1.00000000	 val accuracy : 0.67796610	 test accuracy : 0.69540230
# Train Epoch: 57: train loss : 0.00654520	 train accuracy : 1.00000000	 val accuracy : 0.67796610	 test accuracy : 0.69540230
# Train Epoch: 58: train loss : 0.00497070	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.69540230
# Train Epoch: 59: train loss : 0.00617370	 train accuracy : 1.00000000	 val accuracy : 0.68926554	 test accuracy : 0.69540230
# Train Epoch: 60: train loss : 0.00537991	 train accuracy : 1.00000000	 val accuracy : 0.67796610	 test accuracy : 0.68390805
# Train Epoch: 61: train loss : 0.00483375	 train accuracy : 1.00000000	 val accuracy : 0.67796610	 test accuracy : 0.67816092
# Train Epoch: 62: train loss : 0.00369284	 train accuracy : 1.00000000	 val accuracy : 0.67796610	 test accuracy : 0.68390805
# Train Epoch: 63: train loss : 0.00636907	 train accuracy : 1.00000000	 val accuracy : 0.67796610	 test accuracy : 0.68390805
# Train Epoch: 64: train loss : 0.00698388	 train accuracy : 1.00000000	 val accuracy : 0.67796610	 test accuracy : 0.67816092
# Train Epoch: 65: train loss : 0.00569818	 train accuracy : 1.00000000	 val accuracy : 0.67796610	 test accuracy : 0.67816092
# Train Epoch: 66: train loss : 0.00609431	 train accuracy : 1.00000000	 val accuracy : 0.67231638	 test accuracy : 0.68390805
# Train Epoch: 67: train loss : 0.00417846	 train accuracy : 1.00000000	 val accuracy : 0.67231638	 test accuracy : 0.68390805
# Train Epoch: 68: train loss : 0.00377666	 train accuracy : 1.00000000	 val accuracy : 0.67796610	 test accuracy : 0.68390805
# Train Epoch: 69: train loss : 0.00496248	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.69540230
# Train Epoch: 70: train loss : 0.00343284	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.68965517
# Train Epoch: 71: train loss : 0.00396038	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.68965517
# Train Epoch: 72: train loss : 0.00556627	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.68965517
# Train Epoch: 73: train loss : 0.00468198	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.68965517
# Train Epoch: 74: train loss : 0.00349161	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.68965517
# Train Epoch: 75: train loss : 0.00331334	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.68965517
# Train Epoch: 76: train loss : 0.00379502	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.68965517
# Train Epoch: 77: train loss : 0.00327881	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.68965517
# Train Epoch: 78: train loss : 0.00563704	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.68965517
# Train Epoch: 79: train loss : 0.00261971	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.68965517
# Train Epoch: 80: train loss : 0.00332111	 train accuracy : 1.00000000	 val accuracy : 0.68926554	 test accuracy : 0.68965517
# Train Epoch: 81: train loss : 0.00281889	 train accuracy : 1.00000000	 val accuracy : 0.68926554	 test accuracy : 0.68965517
# Train Epoch: 82: train loss : 0.00346523	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.67816092
# Train Epoch: 83: train loss : 0.00296545	 train accuracy : 1.00000000	 val accuracy : 0.68926554	 test accuracy : 0.67816092
# Train Epoch: 84: train loss : 0.00385118	 train accuracy : 1.00000000	 val accuracy : 0.69491525	 test accuracy : 0.67816092
# Train Epoch: 85: train loss : 0.00445656	 train accuracy : 1.00000000	 val accuracy : 0.69491525	 test accuracy : 0.67816092
# Train Epoch: 86: train loss : 0.00353812	 train accuracy : 1.00000000	 val accuracy : 0.69491525	 test accuracy : 0.67816092
# Train Epoch: 87: train loss : 0.00610763	 train accuracy : 1.00000000	 val accuracy : 0.68926554	 test accuracy : 0.67816092
# Train Epoch: 88: train loss : 0.00471200	 train accuracy : 1.00000000	 val accuracy : 0.69491525	 test accuracy : 0.67816092
# Train Epoch: 89: train loss : 0.00772276	 train accuracy : 0.99614644	 val accuracy : 0.68361582	 test accuracy : 0.69540230
# Train Epoch: 90: train loss : 0.00251268	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.70114943
# Train Epoch: 91: train loss : 0.00247934	 train accuracy : 1.00000000	 val accuracy : 0.67796610	 test accuracy : 0.70114943
# Train Epoch: 92: train loss : 0.00308523	 train accuracy : 1.00000000	 val accuracy : 0.65536723	 test accuracy : 0.70114943
# Train Epoch: 93: train loss : 0.00397273	 train accuracy : 1.00000000	 val accuracy : 0.66101695	 test accuracy : 0.71264368
# Train Epoch: 94: train loss : 0.00302447	 train accuracy : 1.00000000	 val accuracy : 0.66101695	 test accuracy : 0.71264368
# Train Epoch: 95: train loss : 0.00456880	 train accuracy : 1.00000000	 val accuracy : 0.66666667	 test accuracy : 0.69540230
# Train Epoch: 96: train loss : 0.00251791	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.70114943
# Train Epoch: 97: train loss : 0.00612665	 train accuracy : 0.99807322	 val accuracy : 0.67231638	 test accuracy : 0.66666667
# Train Epoch: 98: train loss : 0.00326138	 train accuracy : 1.00000000	 val accuracy : 0.66101695	 test accuracy : 0.67241379
# Train Epoch: 99: train loss : 0.00446381	 train accuracy : 1.00000000	 val accuracy : 0.66666667	 test accuracy : 0.67241379
# Train Epoch: 100: train loss : 0.00403575	 train accuracy : 1.00000000	 val accuracy : 0.66101695	 test accuracy : 0.67241379
# Train Epoch: 101: train loss : 0.00438131	 train accuracy : 1.00000000	 val accuracy : 0.66101695	 test accuracy : 0.67816092
# Train Epoch: 102: train loss : 0.00480250	 train accuracy : 1.00000000	 val accuracy : 0.66101695	 test accuracy : 0.67816092
# Train Epoch: 103: train loss : 0.00434704	 train accuracy : 1.00000000	 val accuracy : 0.66666667	 test accuracy : 0.67241379
# Train Epoch: 104: train loss : 0.00276115	 train accuracy : 1.00000000	 val accuracy : 0.67231638	 test accuracy : 0.66666667
# Train Epoch: 105: train loss : 0.00357309	 train accuracy : 1.00000000	 val accuracy : 0.66666667	 test accuracy : 0.67241379
# Train Epoch: 106: train loss : 0.00337376	 train accuracy : 1.00000000	 val accuracy : 0.67231638	 test accuracy : 0.68965517
# Train Epoch: 107: train loss : 0.00460123	 train accuracy : 1.00000000	 val accuracy : 0.67796610	 test accuracy : 0.69540230
# Train Epoch: 108: train loss : 0.00343068	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.71839080
# Train Epoch: 109: train loss : 0.00425558	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.72988506
# Train Epoch: 110: train loss : 0.00556892	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.72988506
# Train Epoch: 111: train loss : 0.00440391	 train accuracy : 1.00000000	 val accuracy : 0.68926554	 test accuracy : 0.71839080
# Train Epoch: 112: train loss : 0.00362903	 train accuracy : 1.00000000	 val accuracy : 0.68926554	 test accuracy : 0.71264368
# Train Epoch: 113: train loss : 0.00214378	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.70114943
# Train Epoch: 114: train loss : 0.00441571	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.70689655
# Train Epoch: 115: train loss : 0.00257182	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.70689655
# Train Epoch: 116: train loss : 0.00279006	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.70689655
# Train Epoch: 117: train loss : 0.00773941	 train accuracy : 0.99807322	 val accuracy : 0.68361582	 test accuracy : 0.70114943
# Train Epoch: 118: train loss : 0.00225534	 train accuracy : 1.00000000	 val accuracy : 0.68926554	 test accuracy : 0.70114943
# Train Epoch: 119: train loss : 0.00202543	 train accuracy : 1.00000000	 val accuracy : 0.68926554	 test accuracy : 0.69540230
# Train Epoch: 120: train loss : 0.00299402	 train accuracy : 1.00000000	 val accuracy : 0.69491525	 test accuracy : 0.70114943
# Train Epoch: 121: train loss : 0.00240172	 train accuracy : 1.00000000	 val accuracy : 0.69491525	 test accuracy : 0.70114943
# Train Epoch: 122: train loss : 0.00236164	 train accuracy : 1.00000000	 val accuracy : 0.69491525	 test accuracy : 0.70689655
# Train Epoch: 123: train loss : 0.00282499	 train accuracy : 1.00000000	 val accuracy : 0.69491525	 test accuracy : 0.70114943
# Train Epoch: 124: train loss : 0.00350764	 train accuracy : 1.00000000	 val accuracy : 0.69491525	 test accuracy : 0.69540230
# Train Epoch: 125: train loss : 0.00226336	 train accuracy : 1.00000000	 val accuracy : 0.68926554	 test accuracy : 0.68965517
# Train Epoch: 126: train loss : 0.00405656	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.70114943
# Train Epoch: 127: train loss : 0.00228624	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.70114943
# Train Epoch: 128: train loss : 0.00321612	 train accuracy : 1.00000000	 val accuracy : 0.68926554	 test accuracy : 0.70114943
# Train Epoch: 129: train loss : 0.00206598	 train accuracy : 1.00000000	 val accuracy : 0.68926554	 test accuracy : 0.71264368
# Train Epoch: 130: train loss : 0.00227636	 train accuracy : 1.00000000	 val accuracy : 0.68926554	 test accuracy : 0.71264368
# Train Epoch: 131: train loss : 0.00559527	 train accuracy : 1.00000000	 val accuracy : 0.68926554	 test accuracy : 0.71839080
# Train Epoch: 132: train loss : 0.00139129	 train accuracy : 1.00000000	 val accuracy : 0.69491525	 test accuracy : 0.71839080
# Train Epoch: 133: train loss : 0.00152552	 train accuracy : 1.00000000	 val accuracy : 0.69491525	 test accuracy : 0.71839080
# Train Epoch: 134: train loss : 0.00250972	 train accuracy : 1.00000000	 val accuracy : 0.69491525	 test accuracy : 0.71839080
# Train Epoch: 135: train loss : 0.00233566	 train accuracy : 1.00000000	 val accuracy : 0.69491525	 test accuracy : 0.72988506
# Train Epoch: 136: train loss : 0.00350692	 train accuracy : 1.00000000	 val accuracy : 0.69491525	 test accuracy : 0.72988506
# Train Epoch: 137: train loss : 0.00132709	 train accuracy : 1.00000000	 val accuracy : 0.69491525	 test accuracy : 0.72413793
# Train Epoch: 138: train loss : 0.00260699	 train accuracy : 1.00000000	 val accuracy : 0.69491525	 test accuracy : 0.71839080
# Train Epoch: 139: train loss : 0.00221467	 train accuracy : 1.00000000	 val accuracy : 0.69491525	 test accuracy : 0.71839080
# Train Epoch: 140: train loss : 0.00170176	 train accuracy : 1.00000000	 val accuracy : 0.69491525	 test accuracy : 0.71839080
# Train Epoch: 141: train loss : 0.00208818	 train accuracy : 1.00000000	 val accuracy : 0.69491525	 test accuracy : 0.71839080
# Train Epoch: 142: train loss : 0.00170486	 train accuracy : 1.00000000	 val accuracy : 0.68926554	 test accuracy : 0.70689655
# Train Epoch: 143: train loss : 0.00112797	 train accuracy : 1.00000000	 val accuracy : 0.68926554	 test accuracy : 0.69540230
# Train Epoch: 144: train loss : 0.00144379	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.68390805
# Train Epoch: 145: train loss : 0.00241405	 train accuracy : 1.00000000	 val accuracy : 0.67796610	 test accuracy : 0.67816092
# Train Epoch: 146: train loss : 0.00197381	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.67816092
# Train Epoch: 147: train loss : 0.00254487	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.67816092
# Train Epoch: 148: train loss : 0.00197286	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.70114943
# Train Epoch: 149: train loss : 0.00154920	 train accuracy : 1.00000000	 val accuracy : 0.68926554	 test accuracy : 0.70114943
# Train Epoch: 150: train loss : 0.00321013	 train accuracy : 0.99807322	 val accuracy : 0.68361582	 test accuracy : 0.70114943
# Train Epoch: 151: train loss : 0.00356967	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.70114943
# Train Epoch: 152: train loss : 0.00217826	 train accuracy : 1.00000000	 val accuracy : 0.68926554	 test accuracy : 0.70114943
# Train Epoch: 153: train loss : 0.00185159	 train accuracy : 1.00000000	 val accuracy : 0.68926554	 test accuracy : 0.70114943
# Train Epoch: 154: train loss : 0.00128103	 train accuracy : 1.00000000	 val accuracy : 0.68926554	 test accuracy : 0.70114943
# Train Epoch: 155: train loss : 0.00330143	 train accuracy : 1.00000000	 val accuracy : 0.69491525	 test accuracy : 0.70114943
# Train Epoch: 156: train loss : 0.00361631	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.69540230
# Train Epoch: 157: train loss : 0.00414036	 train accuracy : 0.99807322	 val accuracy : 0.67796610	 test accuracy : 0.69540230
# Train Epoch: 158: train loss : 0.00080999	 train accuracy : 1.00000000	 val accuracy : 0.67796610	 test accuracy : 0.69540230
# Train Epoch: 159: train loss : 0.00069938	 train accuracy : 1.00000000	 val accuracy : 0.67796610	 test accuracy : 0.69540230
# Train Epoch: 160: train loss : 0.00157380	 train accuracy : 1.00000000	 val accuracy : 0.67796610	 test accuracy : 0.68965517
# Train Epoch: 161: train loss : 0.00086829	 train accuracy : 1.00000000	 val accuracy : 0.67796610	 test accuracy : 0.68965517
# Train Epoch: 162: train loss : 0.00108827	 train accuracy : 1.00000000	 val accuracy : 0.67796610	 test accuracy : 0.68965517
# Train Epoch: 163: train loss : 0.00121317	 train accuracy : 1.00000000	 val accuracy : 0.67796610	 test accuracy : 0.68390805
# Train Epoch: 164: train loss : 0.00228462	 train accuracy : 1.00000000	 val accuracy : 0.67796610	 test accuracy : 0.68965517
# Train Epoch: 165: train loss : 0.00085279	 train accuracy : 1.00000000	 val accuracy : 0.67796610	 test accuracy : 0.68965517
# Train Epoch: 166: train loss : 0.00086506	 train accuracy : 1.00000000	 val accuracy : 0.67231638	 test accuracy : 0.68965517
# Train Epoch: 167: train loss : 0.00136837	 train accuracy : 1.00000000	 val accuracy : 0.67796610	 test accuracy : 0.68965517
# Train Epoch: 168: train loss : 0.00044191	 train accuracy : 1.00000000	 val accuracy : 0.67796610	 test accuracy : 0.68965517
# Train Epoch: 169: train loss : 0.00117292	 train accuracy : 1.00000000	 val accuracy : 0.67796610	 test accuracy : 0.69540230
# Train Epoch: 170: train loss : 0.00104805	 train accuracy : 1.00000000	 val accuracy : 0.67796610	 test accuracy : 0.69540230
# Train Epoch: 171: train loss : 0.00087456	 train accuracy : 1.00000000	 val accuracy : 0.67796610	 test accuracy : 0.70114943
# Train Epoch: 172: train loss : 0.00155084	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.70114943
# Train Epoch: 173: train loss : 0.00129103	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.70114943
# Train Epoch: 174: train loss : 0.00151561	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.70114943
# ...
# Train Epoch: 77: train loss : 0.00118456	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 78: train loss : 0.00089258	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 79: train loss : 0.00288424	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.68131868
# Train Epoch: 80: train loss : 0.00145667	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.68131868
# Train Epoch: 81: train loss : 0.00145233	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.68131868
# Train Epoch: 82: train loss : 0.00088396	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.68131868
# Train Epoch: 83: train loss : 0.00255934	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.68681319
# Train Epoch: 84: train loss : 0.00156713	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.68681319
# Train Epoch: 85: train loss : 0.00104149	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.68681319
# Train Epoch: 86: train loss : 0.00210755	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.68681319
# Train Epoch: 87: train loss : 0.00188843	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.68681319
# Train Epoch: 88: train loss : 0.00104357	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.68681319
# Train Epoch: 89: train loss : 0.00183848	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.68681319
# Train Epoch: 90: train loss : 0.00156711	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.68681319
# Train Epoch: 91: train loss : 0.00230006	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.68681319
# Train Epoch: 92: train loss : 0.00144667	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 93: train loss : 0.00105115	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 94: train loss : 0.00085145	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 95: train loss : 0.00099505	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67032967
# Train Epoch: 96: train loss : 0.00132167	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67032967
# Train Epoch: 97: train loss : 0.00115315	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67032967
# Train Epoch: 98: train loss : 0.00107517	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67032967
# Train Epoch: 99: train loss : 0.00114283	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 100: train loss : 0.00172719	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 101: train loss : 0.00110295	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 102: train loss : 0.00087958	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 103: train loss : 0.00107971	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 104: train loss : 0.00073495	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 105: train loss : 0.00072790	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 106: train loss : 0.00118257	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 107: train loss : 0.00101735	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 108: train loss : 0.00101563	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 109: train loss : 0.00098086	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 110: train loss : 0.00062350	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 111: train loss : 0.00127951	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 112: train loss : 0.00161535	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 113: train loss : 0.00110024	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67032967
# Train Epoch: 114: train loss : 0.00090119	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67032967
# Train Epoch: 115: train loss : 0.00093713	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67032967
# Train Epoch: 116: train loss : 0.00073173	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67032967
# Train Epoch: 117: train loss : 0.00109128	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67032967
# Train Epoch: 118: train loss : 0.00081589	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67032967
# Train Epoch: 119: train loss : 0.00085597	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67032967
# Train Epoch: 120: train loss : 0.00127046	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67032967
# Train Epoch: 121: train loss : 0.00111637	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.67032967
# Train Epoch: 122: train loss : 0.00062794	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.67582418
# Train Epoch: 123: train loss : 0.00081100	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.67582418
# Train Epoch: 124: train loss : 0.00077959	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.67582418
# Train Epoch: 125: train loss : 0.00045718	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.67582418
# Train Epoch: 126: train loss : 0.00146855	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67032967
# Train Epoch: 127: train loss : 0.00123239	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67032967
# Train Epoch: 128: train loss : 0.00098801	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.65934066
# Train Epoch: 129: train loss : 0.00113382	 train accuracy : 1.00000000	 val accuracy : 0.70658683	 test accuracy : 0.67032967
# Train Epoch: 130: train loss : 0.00081871	 train accuracy : 1.00000000	 val accuracy : 0.70658683	 test accuracy : 0.67032967
# Train Epoch: 131: train loss : 0.00065170	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.68131868
# Train Epoch: 132: train loss : 0.00089342	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.68681319
# Train Epoch: 133: train loss : 0.00221229	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.68681319
# Train Epoch: 134: train loss : 0.00106224	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.68681319
# Train Epoch: 135: train loss : 0.00103009	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 136: train loss : 0.00084933	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 137: train loss : 0.00144714	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 138: train loss : 0.00119241	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 139: train loss : 0.00126203	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 140: train loss : 0.00058176	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.68131868
# Train Epoch: 141: train loss : 0.00086326	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.68131868
# Train Epoch: 142: train loss : 0.00152141	 train accuracy : 1.00000000	 val accuracy : 0.70658683	 test accuracy : 0.68131868
# Train Epoch: 143: train loss : 0.00054189	 train accuracy : 1.00000000	 val accuracy : 0.70658683	 test accuracy : 0.68131868
# Train Epoch: 144: train loss : 0.00089724	 train accuracy : 1.00000000	 val accuracy : 0.70658683	 test accuracy : 0.68131868
# Train Epoch: 145: train loss : 0.00091187	 train accuracy : 1.00000000	 val accuracy : 0.70658683	 test accuracy : 0.68131868
# Train Epoch: 146: train loss : 0.00076105	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 147: train loss : 0.00093598	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 148: train loss : 0.00081526	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 149: train loss : 0.00086228	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 150: train loss : 0.00047285	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 151: train loss : 0.00064114	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 152: train loss : 0.00109097	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 153: train loss : 0.00118561	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.68131868
# Train Epoch: 154: train loss : 0.00035192	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.67582418
# Train Epoch: 155: train loss : 0.00124214	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.67582418
# Train Epoch: 156: train loss : 0.00134624	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 157: train loss : 0.00066056	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 158: train loss : 0.00056499	 train accuracy : 1.00000000	 val accuracy : 0.70658683	 test accuracy : 0.67582418
# Train Epoch: 159: train loss : 0.00058763	 train accuracy : 1.00000000	 val accuracy : 0.71257485	 test accuracy : 0.67582418
# Train Epoch: 160: train loss : 0.00110816	 train accuracy : 1.00000000	 val accuracy : 0.70658683	 test accuracy : 0.67582418
# Train Epoch: 161: train loss : 0.00059794	 train accuracy : 1.00000000	 val accuracy : 0.70658683	 test accuracy : 0.67032967
# Train Epoch: 162: train loss : 0.00057349	 train accuracy : 1.00000000	 val accuracy : 0.70658683	 test accuracy : 0.67032967
# Train Epoch: 163: train loss : 0.00051176	 train accuracy : 1.00000000	 val accuracy : 0.70658683	 test accuracy : 0.67032967
# Train Epoch: 164: train loss : 0.00058504	 train accuracy : 1.00000000	 val accuracy : 0.70658683	 test accuracy : 0.67032967
# Train Epoch: 165: train loss : 0.00241046	 train accuracy : 0.99808061	 val accuracy : 0.69461078	 test accuracy : 0.67582418
# Train Epoch: 166: train loss : 0.00067905	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.68131868
# Train Epoch: 167: train loss : 0.00130704	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.68131868
# Train Epoch: 168: train loss : 0.00078825	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.68131868
# Train Epoch: 169: train loss : 0.00061513	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.67032967
# Train Epoch: 170: train loss : 0.00109905	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.67032967
# Train Epoch: 171: train loss : 0.00063237	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.67032967
# Train Epoch: 172: train loss : 0.00308464	 train accuracy : 0.99808061	 val accuracy : 0.68263473	 test accuracy : 0.68681319
# Train Epoch: 173: train loss : 0.00088284	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.68131868
# Train Epoch: 174: train loss : 0.00089232	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.68681319
# Train Epoch: 175: train loss : 0.00109269	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.67582418
# Train Epoch: 176: train loss : 0.00177097	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.67582418
# Train Epoch: 177: train loss : 0.00088795	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.67582418
# Train Epoch: 178: train loss : 0.00075383	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.67582418
# Train Epoch: 179: train loss : 0.00085174	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.67582418
# Train Epoch: 180: train loss : 0.00052250	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.66483516
# Train Epoch: 181: train loss : 0.00079763	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.67032967
# Train Epoch: 182: train loss : 0.00064780	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.67032967
# Train Epoch: 183: train loss : 0.00072419	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.66483516
# Train Epoch: 184: train loss : 0.00296364	 train accuracy : 0.99808061	 val accuracy : 0.68263473	 test accuracy : 0.67582418
# Train Epoch: 185: train loss : 0.00111275	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.67032967
# Train Epoch: 186: train loss : 0.00096254	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.68681319
# Train Epoch: 187: train loss : 0.00112498	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.69230769
# Train Epoch: 188: train loss : 0.00106844	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.69230769
# Train Epoch: 189: train loss : 0.00125236	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.69780220
# Train Epoch: 190: train loss : 0.00079298	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.69780220
# Train Epoch: 191: train loss : 0.00236272	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.67582418
# Train Epoch: 192: train loss : 0.00079815	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.67032967
# Train Epoch: 193: train loss : 0.00129210	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 194: train loss : 0.00121268	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67032967
# Train Epoch: 195: train loss : 0.00036729	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.66483516
# Train Epoch: 196: train loss : 0.00109483	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65934066
# Train Epoch: 197: train loss : 0.00087317	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.67032967
# Train Epoch: 198: train loss : 0.00088344	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.68131868
# Train Epoch: 199: train loss : 0.00072441	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.68131868
# Train Epoch: 200: train loss : 0.00139183	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# In fold  5
# The best validaiton accuracy is:  0.718562874251497
# Happened at epoch:  20
# The corresponding test accuracy 0.6703296703296703
# The corresponding test AUC is:  0.7762839147286821
# Finish 5-fold training

# %%
val_accuracy = metrics.accuracy_score(all_fold_val_label, all_fold_val_out)
test_accuracy = metrics.accuracy_score(all_fold_test_label, all_fold_test_out)
test_fpr, test_tpr, te_thresholds = roc_curve(all_fold_test_label, all_fold_test_prob[:,1],pos_label=1)
test_auc = auc(test_fpr, test_tpr)
print('The best validation accuracy is ',val_accuracy)
print('The corresponding test accuracy is ',test_accuracy)
print('The corresponding test AUC is: ',test_auc)
plt.grid()
plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
plt.plot([0,1],[0,1],'g--')
plt.legend()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Test AUC(ROC curve)")
plt.grid(color='black', linestyle='-', linewidth=0.5)
plt.show()
# Out:
# The best validation accuracy is  0.7367816091954023
# The corresponding test accuracy is  0.6804597701149425
# The corresponding test AUC is:  0.7536091731712373

# %%
torch.cuda.empty_cache()
torch.manual_seed(args.seed)
if args.cuda:
    torch.cuda.manual_seed(args.seed)
############################################### Max voting ###############################################################
############################################### Max voting ###############################################################
############################################### Max voting ###############################################################
dist_ensemble_val_label = {}
dist_ensemble_val_result = {}
dist_ensemble_test_label = {}
dist_ensemble_test_result = {}
dist_ensemble_test_prob = {}

for ensemble_fold in range(5):
  print('Ensemble ',ensemble_fold+1)
  save_ensemble_models_path = save_path + 'Max_voting/FCN/'
  dist_train = {}
  dist_validation = {}
  dist_test = {}
  for i in range(k_fold):
    dist_train[str(i + 1)] = []
    dist_validation[str(i + 1)] = []
    dist_test[str(i + 1)] = []
  test_name = {}
  for i in range(len(unique_sites)):
    test_name[unique_sites[i]] = []
  for each_site in unique_sites:
    index_site = get_index(sites, each_site)
    label = np.zeros((len(index_site)))
    for i in range(len(index_site)):
      index = index_site[i]
      label[i] = int(labels[int(index)])
    test_name_list = test_name[each_site]
    ########################################### StratifiedKFold ####################################################
    sfolder = StratifiedKFold(n_splits=k_fold,random_state=0,shuffle=True)
    group = 0
    for train, validation in sfolder.split(index_site,label):
      if group == ensemble_fold:
        for j in validation:
          name = index_site[j]
          dist_test['1'].append(name)
          dist_test['2'].append(name)
          dist_test['3'].append(name)
          dist_test['4'].append(name)
          dist_test['5'].append(name)
          test_name_list.append(name)
      group = group + 1
    test_name[each_site] = test_name_list

  for each_site in unique_sites:
    if ensemble_fold == 0:

      index_site = get_index(sites, each_site)
      label = np.zeros((len(index_site)))
      for i in range(len(index_site)):
        index = index_site[i]
        label[i] = int(labels[int(index)])
      test_name_list = test_name[each_site]
      index_site_new = []
      label_new = np.zeros((len(index_site) - len(test_name_list)))
      position = 0
      for x in range(len(index_site)):
        sample_name = index_site[x]
        if sample_name in test_name_list:
          c=0
        else:
          index_site_new.append(sample_name)
          label_new[position] = label[x]
          position = position + 1
      if each_site == 'CMU':  # ONLY 4 AUTISM SAMPLES AND 4 TD SAMPLES, CAN NOT BE DEVIDED INTO 5 GROUPS
        group_autism_val = []
        group_autism_train = []
        group_TD_val = []
        group_TD_train = []
        autism_validation_number = len(label_new[label_new ==1])/4
        TD_validation_number = len(label_new[label_new ==0]) / 4
        for j in range(len(label_new)):
          if label_new[j] == 1:
            if len(group_autism_val)<autism_validation_number:
              group_autism_val.append(index_site_new[j])
            else:
              group_autism_train.append(index_site_new[j])
          else:
            if len(group_TD_val)<TD_validation_number:
              group_TD_val.append(index_site_new[j])
            else:
              group_TD_train.append(index_site_new[j])

        dist_validation['1'] = dist_validation['1'] + group_autism_val + group_TD_val
        dist_validation['2'] = dist_validation['2'] + group_autism_val + group_TD_val
        dist_validation['3'] = dist_validation['3'] + group_autism_val + group_TD_val
        dist_validation['4'] = dist_validation['4'] + group_autism_val + group_TD_val
        dist_validation['5'] = dist_validation['5'] + group_autism_val + group_TD_val
        dist_train['1'] = dist_train['1'] + group_autism_train + group_TD_train
        dist_train['2'] = dist_train['2'] + group_autism_train + group_TD_train
        dist_train['3'] = dist_train['3'] + group_autism_train + group_TD_train
        dist_train['4'] = dist_train['4'] + group_autism_train + group_TD_train
        dist_train['5'] = dist_train['5'] + group_autism_train + group_TD_train
      else:
        ########################################### StratifiedKFold ####################################################
        sfolder = StratifiedKFold(n_splits=k_fold, random_state=0, shuffle=True)
        group = 0
        for train, validation in sfolder.split(index_site_new, label_new):

          for i in train:
            name = index_site_new[i]
            dist_train[str(group + 1)].append(name)
          for j in validation:
            name = index_site_new[j]
            dist_validation[str(group + 1)].append(name)
          group = group + 1
    else:

      index_site = get_index(sites, each_site)
      label = np.zeros((len(index_site)))
      for i in range(len(index_site)):
        index = index_site[i]
        label[i] = int(labels[int(index)])
      test_name_list = test_name[each_site]
      index_site_new = []
      label_new = np.zeros((len(index_site) - len(test_name_list)))
      position = 0
      for x in range(len(index_site)):
        sample_name = index_site[x]
        if sample_name in test_name_list:
          c=0
        else:
          index_site_new.append(sample_name)
          label_new[position] = label[x]
          position = position + 1
      ########################################### StratifiedKFold ####################################################
      sfolder = StratifiedKFold(n_splits=k_fold,random_state=0,shuffle=True)
      group = 0
      for train, validation in sfolder.split(index_site_new,label_new):

        for i in train:
          name = index_site_new[i]
          dist_train[str(group + 1)].append(name)
        for j in validation:
          name = index_site_new[j]
          dist_validation[str(group + 1)].append(name)
        group = group+1
  
  
  data = {}
  for fold in range(1, k_fold+1):
    data[str(fold)] = []
    ################################################# feature selection #########################################################
    selector_fMRI = feature_selection_fMRI(fMRI_images, labels, dist_train[str(fold)], new_number_features_fMRI)
    selector_sMRI = feature_selection_sMRI(sMRI_features, labels, dist_train[str(fold)], new_number_features_sMRI)

    new_fMRI_data = selector_fMRI.transform(fMRI_images)
    new_sMRI_data = selector_sMRI.transform(sMRI_features)
    ################################################# combine ##########################################
    sMRI_fMRI_combine = np.concatenate((new_sMRI_data, new_fMRI_data), axis = 1)
    selector_combine = feature_selection_fMRI(sMRI_fMRI_combine, labels, dist_train[str(fold)], new_number_features_combine)
    fold_data = selector_combine.transform(sMRI_fMRI_combine)

    data[str(fold)].append(fold_data)
    data[str(fold)].append(FCN_labels)

  ############################################### Train ###############################################################
  ############################################### Train ###############################################################
  ############################################### Train ###############################################################

  model_1 = FCN(input_c=args.input_c, hid_1=args.hid_1, hid_2=args.hid_2, out_c=args.out_c, dropout=args.dropout_rate)
  model_2 = FCN(input_c=args.input_c, hid_1=args.hid_1, hid_2=args.hid_2, out_c=args.out_c, dropout=args.dropout_rate)
  model_3 = FCN(input_c=args.input_c, hid_1=args.hid_1, hid_2=args.hid_2, out_c=args.out_c, dropout=args.dropout_rate)
  model_4 = FCN(input_c=args.input_c, hid_1=args.hid_1, hid_2=args.hid_2, out_c=args.out_c, dropout=args.dropout_rate)
  model_5 = FCN(input_c=args.input_c, hid_1=args.hid_1, hid_2=args.hid_2, out_c=args.out_c, dropout=args.dropout_rate)

  gpu_ids = range(args.ngpu)
  model_1 = nn.parallel.DataParallel(model_1, device_ids=gpu_ids)
  model_2 = nn.parallel.DataParallel(model_2, device_ids=gpu_ids)
  model_3 = nn.parallel.DataParallel(model_3, device_ids=gpu_ids)
  model_4 = nn.parallel.DataParallel(model_4, device_ids=gpu_ids)
  model_5 = nn.parallel.DataParallel(model_5, device_ids=gpu_ids)
  train = train_FCN

  print('  + Number of params: {}'.format(
      sum([p.data.nelement() for p in model_1.parameters()])))
  if args.cuda:
      model_1 = model_1.cuda()
      model_2 = model_2.cuda()
      model_3 = model_3.cuda()
      model_4 = model_4.cuda()
      model_5 = model_5.cuda()

  optimizer_1 = optim.Adam(model_1.parameters(), lr = args.lr)
  optimizer_2 = optim.Adam(model_2.parameters(), lr = args.lr)
  optimizer_3 = optim.Adam(model_3.parameters(), lr = args.lr)
  optimizer_4 = optim.Adam(model_4.parameters(), lr = args.lr)
  optimizer_5 = optim.Adam(model_5.parameters(), lr = args.lr)

  Train_accuracy_list =[]
  Train_loss_list = []
  Val_accuracy_list =[]
  Val_loss_list = []
  Test_accuracy_list =[]
  Test_loss_list = []
  best_validation_accuracy = 0

  for epoch in range(1, args.nEpochs + 1):


    model_1, train_target_1, train_out_1, train_loss_1, val_target_1, val_out_1, val_loss_1, test_target_1, test_out_1, test_prob_1, test_loss_1 = train(args, model_1, data['1'], dist_train['1'], dist_validation['1'], dist_test['1'], optimizer_1)
    model_2, train_target_2, train_out_2, train_loss_2, val_target_2, val_out_2, val_loss_2, test_target_2, test_out_2, test_prob_2, test_loss_2 = train(args, model_2, data['2'], dist_train['2'], dist_validation['2'], dist_test['2'], optimizer_2)
    model_3, train_target_3, train_out_3, train_loss_3, val_target_3, val_out_3, val_loss_3, test_target_3, test_out_3, test_prob_3, test_loss_3 = train(args, model_3, data['3'], dist_train['3'], dist_validation['3'], dist_test['3'], optimizer_3)
    model_4, train_target_4, train_out_4, train_loss_4, val_target_4, val_out_4, val_loss_4, test_target_4, test_out_4, test_prob_4, test_loss_4 = train(args, model_4, data['4'], dist_train['4'], dist_validation['4'], dist_test['4'], optimizer_4)
    model_5, train_target_5, train_out_5, train_loss_5, val_target_5, val_out_5, val_loss_5, test_target_5, test_out_5, test_prob_5, test_loss_5 = train(args, model_5, data['5'], dist_train['5'], dist_validation['5'], dist_test['5'], optimizer_5)

    train_target_all = np.concatenate((train_target_1, train_target_2, train_target_3, train_target_4, train_target_5),axis = 0)
    train_out_all = np.concatenate((train_out_1, train_out_2, train_out_3, train_out_4, train_out_5),axis = 0)
    train_loss = (train_loss_1 + train_loss_2 + train_loss_3 + train_loss_4 + train_loss_5)/5
    val_target_all = np.concatenate((val_target_1, val_target_2, val_target_3, val_target_4, val_target_5),axis = 0)
    val_out_all = np.concatenate((val_out_1, val_out_2, val_out_3, val_out_4, val_out_5),axis = 0)
    val_loss = (val_loss_1 + val_loss_2 + val_loss_3 + val_loss_4 + val_loss_5)/5
    test_target_all = test_target_1 # test_target_1 = test_target_2 = test_target_3 = test_target_4 = test_target_5
    test_out_all = test_out_1 + test_out_2 + test_out_3 + test_out_4 + test_out_5
    test_prob_all = (test_prob_1 + test_prob_2 + test_prob_3 + test_prob_4 + test_prob_5)/5
    test_loss = (test_loss_1 + test_loss_2 + test_loss_3 + test_loss_4 + test_loss_5)/5

    test_results_binary = np.zeros_like((test_out_all))
    test_results_binary[test_out_all<2.5] = 0
    test_results_binary[test_out_all>=2.5] = 1

    train_accuracy = metrics.accuracy_score(train_target_all, train_out_all)
    val_accuracy = metrics.accuracy_score(val_target_all, val_out_all)
    test_accuracy = metrics.accuracy_score(test_target_all, test_results_binary)
    Train_accuracy_list.append(train_accuracy)
    Val_accuracy_list.append(val_accuracy)
    Test_accuracy_list.append(test_accuracy)
    Train_loss_list.append(train_loss)
    Val_loss_list.append(val_loss)
    Test_loss_list.append(test_loss)

    if val_accuracy >=best_validation_accuracy:
      best_epoch = epoch
      best_validation_accuracy = val_accuracy
      corresponding_test_accuracy = test_accuracy
      corresponding_test_prob = test_prob_all
      corresponding_test_labels = test_target_all
      corresponding_test_out = test_results_binary
      print('Save models')

      save_model(model_1, save_ensemble_models_path, 'FCN_ensemble' + str(ensemble_fold) + '_1')
      save_model(model_2, save_ensemble_models_path, 'FCN_ensemble' + str(ensemble_fold) + '_2')
      save_model(model_3, save_ensemble_models_path, 'FCN_ensemble' + str(ensemble_fold) + '_3')
      save_model(model_4, save_ensemble_models_path, 'FCN_ensemble' + str(ensemble_fold) + '_4')
      save_model(model_5, save_ensemble_models_path, 'FCN_ensemble' + str(ensemble_fold) + '_5')

    print('Train Epoch: ' + str(epoch) + ': train loss : {:.8f}\t train accuracy : {:.8f}\t val accuracy : {:.8f}\t test accuracy : {:.8f}\t'.format(
      train_loss, train_accuracy, val_accuracy, test_accuracy))

  x_axis = list(range(1, len(Train_accuracy_list)+1))
  plt.figure(figsize=(15,10))
  plt.plot(x_axis, Train_loss_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_loss_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_loss_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()

  plt.figure(figsize=(15,10))
  plt.plot(x_axis, Train_accuracy_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_accuracy_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_accuracy_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()
 
  test_fpr, test_tpr, te_thresholds = roc_curve(corresponding_test_labels, corresponding_test_prob[:,1],pos_label=1)
  test_auc = auc(test_fpr, test_tpr)
  print('\n')
  print('In ensemble ',ensemble_fold+1)
  print('The best validaiton accuracy is: ',best_validation_accuracy)
  print('Happened at epoch: ',best_epoch)
  print('The corresponding test accuracy', corresponding_test_accuracy)
  print('The corresponding test AUC is: ',test_auc)
  print('\n')


  plt.grid()
  plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
  plt.plot([0,1],[0,1],'g--')
  plt.legend()
  plt.xlabel("False Positive Rate")
  plt.ylabel("True Positive Rate")
  plt.title("Test AUC(ROC curve)")
  plt.grid(color='black', linestyle='-', linewidth=0.5)
  plt.show()


  dist_ensemble_test_label[str(ensemble_fold+1)] = corresponding_test_labels
  dist_ensemble_test_result[str(ensemble_fold+1)] = corresponding_test_out
  dist_ensemble_test_prob[str(ensemble_fold+1)] = corresponding_test_prob
  print('\n')

  torch.cuda.empty_cache()

test_labels_concat = np.concatenate((dist_ensemble_test_label['1'], dist_ensemble_test_label['2'],  dist_ensemble_test_label['3'], dist_ensemble_test_label['4'], dist_ensemble_test_label['5']),axis = 0)
test_results_concat = np.concatenate((dist_ensemble_test_result['1'], dist_ensemble_test_result['2'],  dist_ensemble_test_result['3'], dist_ensemble_test_result['4'], dist_ensemble_test_result['5']),axis = 0)
test_probs_concat = np.concatenate((dist_ensemble_test_prob['1'], dist_ensemble_test_prob['2'],  dist_ensemble_test_prob['3'], dist_ensemble_test_prob['4'], dist_ensemble_test_prob['5']),axis = 0)

test_accuracy = metrics.accuracy_score(test_labels_concat, test_results_concat)
test_fpr, test_tpr, te_thresholds = roc_curve(test_labels_concat, test_probs_concat[:,1],pos_label=1)
test_auc = auc(test_fpr, test_tpr)
print('The Max voting test accuracy is: ',test_accuracy)
print('The test AUC is: ',test_auc)

print('\n')
print('\n')
plt.grid()
plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
plt.plot([0,1],[0,1],'g--')
plt.legend()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Test AUC(ROC curve)")
plt.grid(color='black', linestyle='-', linewidth=0.5)
plt.show()
# Out:
# Ensemble  1
# Fitting estimator with 19900 features.
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:680: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   UserWarning,
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 6435 features.
# Fitting estimator with 6335 features.
# Fitting estimator with 6235 features.
# Fitting estimator with 6135 features.
# Fitting estimator with 6035 features.
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 6435 features.
# Fitting estimator with 6335 features.
# Fitting estimator with 6235 features.
# Fitting estimator with 6135 features.
# Fitting estimator with 6035 features.
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 6435 features.
# Fitting estimator with 6335 features.
# Fitting estimator with 6235 features.
# Fitting estimator with 6135 features.
# Fitting estimator with 6035 features.
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 6435 features.
# Fitting estimator with 6335 features.
# Fitting estimator with 6235 features.
# Fitting estimator with 6135 features.
# Fitting estimator with 6035 features.
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 6435 features.
# Fitting estimator with 6335 features.
# Fitting estimator with 6235 features.
# Fitting estimator with 6135 features.
# Fitting estimator with 6035 features.
#   + Number of params: 3016592
# Save models
# Train Epoch: 1: train loss : 0.71899606	 train accuracy : 0.50472727	 val accuracy : 0.61014493	 test accuracy : 0.63736264
# Save models
# Train Epoch: 2: train loss : 0.61372660	 train accuracy : 0.69781818	 val accuracy : 0.63623188	 test accuracy : 0.70879121
# Save models
# Train Epoch: 3: train loss : 0.53463202	 train accuracy : 0.79890909	 val accuracy : 0.64202899	 test accuracy : 0.68681319
# Save models
# Train Epoch: 4: train loss : 0.49041200	 train accuracy : 0.83963636	 val accuracy : 0.65362319	 test accuracy : 0.68681319
# Save models
# Train Epoch: 5: train loss : 0.43906153	 train accuracy : 0.88690909	 val accuracy : 0.65362319	 test accuracy : 0.71978022
# Save models
# Train Epoch: 6: train loss : 0.40137501	 train accuracy : 0.90800000	 val accuracy : 0.65362319	 test accuracy : 0.72527473
# Save models
# Train Epoch: 7: train loss : 0.36096672	 train accuracy : 0.92181818	 val accuracy : 0.65652174	 test accuracy : 0.74725275
# Save models
# Train Epoch: 8: train loss : 0.32035272	 train accuracy : 0.94363636	 val accuracy : 0.66521739	 test accuracy : 0.75824176
# Save models
# Train Epoch: 9: train loss : 0.28653044	 train accuracy : 0.95818182	 val accuracy : 0.68405797	 test accuracy : 0.75824176
# Train Epoch: 10: train loss : 0.25159299	 train accuracy : 0.96872727	 val accuracy : 0.68115942	 test accuracy : 0.75274725
# Train Epoch: 11: train loss : 0.21509554	 train accuracy : 0.97927273	 val accuracy : 0.68260870	 test accuracy : 0.76373626
# Train Epoch: 12: train loss : 0.19175254	 train accuracy : 0.98472727	 val accuracy : 0.67681159	 test accuracy : 0.74725275
# Train Epoch: 13: train loss : 0.17069053	 train accuracy : 0.98981818	 val accuracy : 0.68115942	 test accuracy : 0.74725275
# Save models
# Train Epoch: 14: train loss : 0.14682589	 train accuracy : 0.99163636	 val accuracy : 0.68550725	 test accuracy : 0.73076923
# Train Epoch: 15: train loss : 0.12435784	 train accuracy : 0.99454545	 val accuracy : 0.67681159	 test accuracy : 0.73626374
# Train Epoch: 16: train loss : 0.10960122	 train accuracy : 0.99418182	 val accuracy : 0.67391304	 test accuracy : 0.75274725
# Train Epoch: 17: train loss : 0.09303552	 train accuracy : 0.99781818	 val accuracy : 0.67101449	 test accuracy : 0.75274725
# Train Epoch: 18: train loss : 0.08719154	 train accuracy : 0.99563636	 val accuracy : 0.67536232	 test accuracy : 0.75824176
# Train Epoch: 19: train loss : 0.07282810	 train accuracy : 0.99890909	 val accuracy : 0.66956522	 test accuracy : 0.76373626
# Train Epoch: 20: train loss : 0.06184458	 train accuracy : 0.99890909	 val accuracy : 0.67391304	 test accuracy : 0.76373626
# Train Epoch: 21: train loss : 0.05410058	 train accuracy : 0.99818182	 val accuracy : 0.67391304	 test accuracy : 0.75274725
# Train Epoch: 22: train loss : 0.04876948	 train accuracy : 0.99854545	 val accuracy : 0.66811594	 test accuracy : 0.75274725
# Train Epoch: 23: train loss : 0.04277285	 train accuracy : 0.99818182	 val accuracy : 0.66666667	 test accuracy : 0.75824176
# Train Epoch: 24: train loss : 0.03653204	 train accuracy : 1.00000000	 val accuracy : 0.66956522	 test accuracy : 0.75274725
# Train Epoch: 25: train loss : 0.03372571	 train accuracy : 0.99890909	 val accuracy : 0.67246377	 test accuracy : 0.75274725
# Train Epoch: 26: train loss : 0.02899915	 train accuracy : 0.99963636	 val accuracy : 0.67391304	 test accuracy : 0.75274725
# Train Epoch: 27: train loss : 0.02597807	 train accuracy : 0.99963636	 val accuracy : 0.67391304	 test accuracy : 0.75274725
# Train Epoch: 28: train loss : 0.02544578	 train accuracy : 0.99927273	 val accuracy : 0.67101449	 test accuracy : 0.75274725
# Train Epoch: 29: train loss : 0.02081250	 train accuracy : 1.00000000	 val accuracy : 0.67246377	 test accuracy : 0.74725275
# Train Epoch: 30: train loss : 0.01862623	 train accuracy : 1.00000000	 val accuracy : 0.66956522	 test accuracy : 0.74175824
# Train Epoch: 31: train loss : 0.01621409	 train accuracy : 1.00000000	 val accuracy : 0.66956522	 test accuracy : 0.73626374
# Train Epoch: 32: train loss : 0.01710746	 train accuracy : 0.99890909	 val accuracy : 0.67246377	 test accuracy : 0.74175824
# Train Epoch: 33: train loss : 0.01529358	 train accuracy : 0.99890909	 val accuracy : 0.66956522	 test accuracy : 0.74175824
# Train Epoch: 34: train loss : 0.01263539	 train accuracy : 1.00000000	 val accuracy : 0.66666667	 test accuracy : 0.75274725
# Train Epoch: 35: train loss : 0.01229832	 train accuracy : 1.00000000	 val accuracy : 0.67246377	 test accuracy : 0.73626374
# Train Epoch: 36: train loss : 0.01111971	 train accuracy : 0.99963636	 val accuracy : 0.66956522	 test accuracy : 0.73076923
# Train Epoch: 37: train loss : 0.01200985	 train accuracy : 0.99963636	 val accuracy : 0.67246377	 test accuracy : 0.71978022
# Train Epoch: 38: train loss : 0.01095494	 train accuracy : 0.99963636	 val accuracy : 0.66811594	 test accuracy : 0.73076923
# Train Epoch: 39: train loss : 0.00882181	 train accuracy : 1.00000000	 val accuracy : 0.66376812	 test accuracy : 0.74175824
# Train Epoch: 40: train loss : 0.00795152	 train accuracy : 0.99963636	 val accuracy : 0.66521739	 test accuracy : 0.73626374
# Train Epoch: 41: train loss : 0.00800378	 train accuracy : 1.00000000	 val accuracy : 0.66666667	 test accuracy : 0.74175824
# Train Epoch: 42: train loss : 0.00750286	 train accuracy : 1.00000000	 val accuracy : 0.67101449	 test accuracy : 0.73626374
# Train Epoch: 43: train loss : 0.00693274	 train accuracy : 1.00000000	 val accuracy : 0.67101449	 test accuracy : 0.74175824
# Train Epoch: 44: train loss : 0.00668060	 train accuracy : 0.99963636	 val accuracy : 0.66811594	 test accuracy : 0.74175824
# Train Epoch: 45: train loss : 0.00645000	 train accuracy : 0.99963636	 val accuracy : 0.66956522	 test accuracy : 0.74175824
# Train Epoch: 46: train loss : 0.00604819	 train accuracy : 1.00000000	 val accuracy : 0.66956522	 test accuracy : 0.74175824
# Train Epoch: 47: train loss : 0.00627174	 train accuracy : 1.00000000	 val accuracy : 0.66811594	 test accuracy : 0.74175824
# Train Epoch: 48: train loss : 0.00549865	 train accuracy : 1.00000000	 val accuracy : 0.66811594	 test accuracy : 0.74725275
# Train Epoch: 49: train loss : 0.00533734	 train accuracy : 1.00000000	 val accuracy : 0.66956522	 test accuracy : 0.74725275
# Train Epoch: 50: train loss : 0.00558753	 train accuracy : 1.00000000	 val accuracy : 0.66811594	 test accuracy : 0.74175824
# Train Epoch: 51: train loss : 0.00479600	 train accuracy : 1.00000000	 val accuracy : 0.66956522	 test accuracy : 0.73626374
# Train Epoch: 52: train loss : 0.00472973	 train accuracy : 1.00000000	 val accuracy : 0.66811594	 test accuracy : 0.74175824
# Train Epoch: 53: train loss : 0.00421572	 train accuracy : 1.00000000	 val accuracy : 0.66666667	 test accuracy : 0.73626374
# Train Epoch: 54: train loss : 0.00455965	 train accuracy : 1.00000000	 val accuracy : 0.66811594	 test accuracy : 0.73626374
# Train Epoch: 55: train loss : 0.00354204	 train accuracy : 1.00000000	 val accuracy : 0.66666667	 test accuracy : 0.73626374
# Train Epoch: 56: train loss : 0.00464472	 train accuracy : 1.00000000	 val accuracy : 0.66811594	 test accuracy : 0.73626374
# Train Epoch: 57: train loss : 0.00418353	 train accuracy : 1.00000000	 val accuracy : 0.66811594	 test accuracy : 0.73626374
# Train Epoch: 58: train loss : 0.00389741	 train accuracy : 1.00000000	 val accuracy : 0.66521739	 test accuracy : 0.74175824
# Train Epoch: 59: train loss : 0.00372772	 train accuracy : 0.99963636	 val accuracy : 0.66666667	 test accuracy : 0.74175824
# Train Epoch: 60: train loss : 0.00343866	 train accuracy : 1.00000000	 val accuracy : 0.66956522	 test accuracy : 0.73076923
# Train Epoch: 61: train loss : 0.00382583	 train accuracy : 1.00000000	 val accuracy : 0.66956522	 test accuracy : 0.73076923
# Train Epoch: 62: train loss : 0.00337350	 train accuracy : 1.00000000	 val accuracy : 0.67246377	 test accuracy : 0.73076923
# Train Epoch: 63: train loss : 0.00298925	 train accuracy : 1.00000000	 val accuracy : 0.66956522	 test accuracy : 0.73076923
# Train Epoch: 64: train loss : 0.00271913	 train accuracy : 1.00000000	 val accuracy : 0.66956522	 test accuracy : 0.72527473
# Train Epoch: 65: train loss : 0.00299965	 train accuracy : 0.99963636	 val accuracy : 0.67101449	 test accuracy : 0.72527473
# Train Epoch: 66: train loss : 0.00335317	 train accuracy : 1.00000000	 val accuracy : 0.66956522	 test accuracy : 0.72527473
# Train Epoch: 67: train loss : 0.00311314	 train accuracy : 1.00000000	 val accuracy : 0.67101449	 test accuracy : 0.71978022
# Train Epoch: 68: train loss : 0.00297498	 train accuracy : 1.00000000	 val accuracy : 0.67391304	 test accuracy : 0.71978022
# Train Epoch: 69: train loss : 0.00309508	 train accuracy : 1.00000000	 val accuracy : 0.67246377	 test accuracy : 0.71978022
# Train Epoch: 70: train loss : 0.00321587	 train accuracy : 1.00000000	 val accuracy : 0.67536232	 test accuracy : 0.71978022
# Train Epoch: 71: train loss : 0.00326910	 train accuracy : 1.00000000	 val accuracy : 0.67391304	 test accuracy : 0.72527473
# Train Epoch: 72: train loss : 0.00313105	 train accuracy : 0.99963636	 val accuracy : 0.67391304	 test accuracy : 0.73076923
# Train Epoch: 73: train loss : 0.00321520	 train accuracy : 0.99963636	 val accuracy : 0.67101449	 test accuracy : 0.73626374
# Train Epoch: 74: train loss : 0.00278346	 train accuracy : 1.00000000	 val accuracy : 0.67246377	 test accuracy : 0.74175824
# Train Epoch: 75: train loss : 0.00228615	 train accuracy : 1.00000000	 val accuracy : 0.67246377	 test accuracy : 0.73076923
# Train Epoch: 76: train loss : 0.00278703	 train accuracy : 1.00000000	 val accuracy : 0.67101449	 test accuracy : 0.73076923
# Train Epoch: 77: train loss : 0.00248081	 train accuracy : 1.00000000	 val accuracy : 0.67101449	 test accuracy : 0.73076923
# Train Epoch: 78: train loss : 0.00212448	 train accuracy : 1.00000000	 val accuracy : 0.66956522	 test accuracy : 0.73076923
# Train Epoch: 79: train loss : 0.00250708	 train accuracy : 0.99963636	 val accuracy : 0.67101449	 test accuracy : 0.73076923
# Train Epoch: 80: train loss : 0.00227414	 train accuracy : 0.99963636	 val accuracy : 0.67101449	 test accuracy : 0.72527473
# Train Epoch: 81: train loss : 0.00253062	 train accuracy : 0.99963636	 val accuracy : 0.67101449	 test accuracy : 0.72527473
# Train Epoch: 82: train loss : 0.00201864	 train accuracy : 1.00000000	 val accuracy : 0.67101449	 test accuracy : 0.72527473
# Train Epoch: 83: train loss : 0.00242269	 train accuracy : 1.00000000	 val accuracy : 0.67391304	 test accuracy : 0.72527473
# Train Epoch: 84: train loss : 0.00218863	 train accuracy : 1.00000000	 val accuracy : 0.66956522	 test accuracy : 0.72527473
# Train Epoch: 85: train loss : 0.00250383	 train accuracy : 1.00000000	 val accuracy : 0.66956522	 test accuracy : 0.73076923
# Train Epoch: 86: train loss : 0.00300200	 train accuracy : 0.99927273	 val accuracy : 0.66956522	 test accuracy : 0.72527473
# Train Epoch: 87: train loss : 0.00174545	 train accuracy : 1.00000000	 val accuracy : 0.67246377	 test accuracy : 0.71978022
# Train Epoch: 88: train loss : 0.00225842	 train accuracy : 1.00000000	 val accuracy : 0.67246377	 test accuracy : 0.72527473
# Train Epoch: 89: train loss : 0.00274436	 train accuracy : 1.00000000	 val accuracy : 0.67246377	 test accuracy : 0.73076923
# Train Epoch: 90: train loss : 0.00196096	 train accuracy : 1.00000000	 val accuracy : 0.67101449	 test accuracy : 0.73076923
# Train Epoch: 91: train loss : 0.00265036	 train accuracy : 0.99927273	 val accuracy : 0.67246377	 test accuracy : 0.74175824
# Train Epoch: 92: train loss : 0.00202796	 train accuracy : 1.00000000	 val accuracy : 0.66666667	 test accuracy : 0.74175824
# Train Epoch: 93: train loss : 0.00182515	 train accuracy : 1.00000000	 val accuracy : 0.66666667	 test accuracy : 0.74175824
# Train Epoch: 94: train loss : 0.00207312	 train accuracy : 1.00000000	 val accuracy : 0.66666667	 test accuracy : 0.74175824
# Train Epoch: 95: train loss : 0.00209258	 train accuracy : 1.00000000	 val accuracy : 0.66521739	 test accuracy : 0.74175824
# Train Epoch: 96: train loss : 0.00305475	 train accuracy : 0.99927273	 val accuracy : 0.66376812	 test accuracy : 0.74175824
# Train Epoch: 97: train loss : 0.00170830	 train accuracy : 1.00000000	 val accuracy : 0.66666667	 test accuracy : 0.73626374
# Train Epoch: 98: train loss : 0.00259205	 train accuracy : 0.99927273	 val accuracy : 0.66666667	 test accuracy : 0.73076923
# Train Epoch: 99: train loss : 0.00182946	 train accuracy : 1.00000000	 val accuracy : 0.66666667	 test accuracy : 0.73076923
# Train Epoch: 100: train loss : 0.00230034	 train accuracy : 1.00000000	 val accuracy : 0.66521739	 test accuracy : 0.73076923
# Train Epoch: 101: train loss : 0.00162003	 train accuracy : 1.00000000	 val accuracy : 0.66521739	 test accuracy : 0.73076923
# Train Epoch: 102: train loss : 0.00218192	 train accuracy : 1.00000000	 val accuracy : 0.66521739	 test accuracy : 0.74175824
# Train Epoch: 103: train loss : 0.00161661	 train accuracy : 1.00000000	 val accuracy : 0.66956522	 test accuracy : 0.74175824
# Train Epoch: 104: train loss : 0.00209877	 train accuracy : 0.99963636	 val accuracy : 0.67246377	 test accuracy : 0.74175824
# Train Epoch: 105: train loss : 0.00269195	 train accuracy : 0.99963636	 val accuracy : 0.67391304	 test accuracy : 0.73626374
# Train Epoch: 106: train loss : 0.00158868	 train accuracy : 1.00000000	 val accuracy : 0.67681159	 test accuracy : 0.73626374
# Train Epoch: 107: train loss : 0.00235444	 train accuracy : 1.00000000	 val accuracy : 0.67826087	 test accuracy : 0.73076923
# Train Epoch: 108: train loss : 0.00189390	 train accuracy : 1.00000000	 val accuracy : 0.67681159	 test accuracy : 0.71978022
# Train Epoch: 109: train loss : 0.00155162	 train accuracy : 1.00000000	 val accuracy : 0.67826087	 test accuracy : 0.71978022
# Train Epoch: 110: train loss : 0.00225750	 train accuracy : 1.00000000	 val accuracy : 0.67681159	 test accuracy : 0.71978022
# Train Epoch: 111: train loss : 0.00166167	 train accuracy : 1.00000000	 val accuracy : 0.67826087	 test accuracy : 0.71978022
# Train Epoch: 112: train loss : 0.00165403	 train accuracy : 1.00000000	 val accuracy : 0.67536232	 test accuracy : 0.71978022
# Train Epoch: 113: train loss : 0.00157479	 train accuracy : 1.00000000	 val accuracy : 0.67536232	 test accuracy : 0.72527473
# Train Epoch: 114: train loss : 0.00247911	 train accuracy : 1.00000000	 val accuracy : 0.67681159	 test accuracy : 0.72527473
# Train Epoch: 115: train loss : 0.00179073	 train accuracy : 1.00000000	 val accuracy : 0.67681159	 test accuracy : 0.72527473
# Train Epoch: 116: train loss : 0.00193813	 train accuracy : 0.99963636	 val accuracy : 0.67536232	 test accuracy : 0.72527473
# Train Epoch: 117: train loss : 0.00169325	 train accuracy : 1.00000000	 val accuracy : 0.67391304	 test accuracy : 0.73076923
# Train Epoch: 118: train loss : 0.00168035	 train accuracy : 1.00000000	 val accuracy : 0.67536232	 test accuracy : 0.73076923
# Train Epoch: 119: train loss : 0.00154422	 train accuracy : 1.00000000	 val accuracy : 0.67536232	 test accuracy : 0.73076923
# Train Epoch: 120: train loss : 0.00186362	 train accuracy : 1.00000000	 val accuracy : 0.67391304	 test accuracy : 0.73076923
# Train Epoch: 121: train loss : 0.00140722	 train accuracy : 1.00000000	 val accuracy : 0.67536232	 test accuracy : 0.73626374
# Train Epoch: 122: train loss : 0.00177777	 train accuracy : 0.99963636	 val accuracy : 0.67536232	 test accuracy : 0.74175824
# Train Epoch: 123: train loss : 0.00167868	 train accuracy : 1.00000000	 val accuracy : 0.67536232	 test accuracy : 0.74175824
# Train Epoch: 124: train loss : 0.00226498	 train accuracy : 0.99927273	 val accuracy : 0.67826087	 test accuracy : 0.73626374
# Train Epoch: 125: train loss : 0.00135140	 train accuracy : 1.00000000	 val accuracy : 0.67536232	 test accuracy : 0.73626374
# Train Epoch: 126: train loss : 0.00169163	 train accuracy : 0.99963636	 val accuracy : 0.67536232	 test accuracy : 0.73626374
# Train Epoch: 127: train loss : 0.00169545	 train accuracy : 1.00000000	 val accuracy : 0.67536232	 test accuracy : 0.73626374
# Train Epoch: 128: train loss : 0.00143683	 train accuracy : 0.99963636	 val accuracy : 0.67536232	 test accuracy : 0.73076923
# Train Epoch: 129: train loss : 0.00184348	 train accuracy : 1.00000000	 val accuracy : 0.67536232	 test accuracy : 0.73626374
# Train Epoch: 130: train loss : 0.00156301	 train accuracy : 1.00000000	 val accuracy : 0.67536232	 test accuracy : 0.73076923
# Train Epoch: 131: train loss : 0.00227164	 train accuracy : 0.99927273	 val accuracy : 0.67826087	 test accuracy : 0.73076923
# Train Epoch: 132: train loss : 0.00149687	 train accuracy : 1.00000000	 val accuracy : 0.67826087	 test accuracy : 0.72527473
# Train Epoch: 133: train loss : 0.00239345	 train accuracy : 0.99927273	 val accuracy : 0.67826087	 test accuracy : 0.72527473
# Train Epoch: 134: train loss : 0.00107702	 train accuracy : 1.00000000	 val accuracy : 0.67681159	 test accuracy : 0.71978022
# Train Epoch: 135: train loss : 0.00115022	 train accuracy : 1.00000000	 val accuracy : 0.67681159	 test accuracy : 0.71978022
# Train Epoch: 136: train loss : 0.00117563	 train accuracy : 1.00000000	 val accuracy : 0.67971014	 test accuracy : 0.72527473
# Train Epoch: 137: train loss : 0.00144726	 train accuracy : 1.00000000	 val accuracy : 0.67971014	 test accuracy : 0.72527473
# Train Epoch: 138: train loss : 0.00127512	 train accuracy : 1.00000000	 val accuracy : 0.67971014	 test accuracy : 0.72527473
# Train Epoch: 139: train loss : 0.00167505	 train accuracy : 0.99963636	 val accuracy : 0.67971014	 test accuracy : 0.73076923
# Train Epoch: 140: train loss : 0.00099026	 train accuracy : 1.00000000	 val accuracy : 0.67971014	 test accuracy : 0.73076923
# Train Epoch: 141: train loss : 0.00152729	 train accuracy : 1.00000000	 val accuracy : 0.67826087	 test accuracy : 0.73076923
# ...
# Train Epoch: 78: train loss : 0.00254186	 train accuracy : 1.00000000	 val accuracy : 0.71408250	 test accuracy : 0.69461078
# Train Epoch: 79: train loss : 0.00274913	 train accuracy : 1.00000000	 val accuracy : 0.71834993	 test accuracy : 0.69461078
# Train Epoch: 80: train loss : 0.00261202	 train accuracy : 1.00000000	 val accuracy : 0.71266003	 test accuracy : 0.69461078
# Train Epoch: 81: train loss : 0.00249794	 train accuracy : 1.00000000	 val accuracy : 0.71834993	 test accuracy : 0.69461078
# Train Epoch: 82: train loss : 0.00253498	 train accuracy : 1.00000000	 val accuracy : 0.72119488	 test accuracy : 0.69461078
# Train Epoch: 83: train loss : 0.00246384	 train accuracy : 0.99964438	 val accuracy : 0.72119488	 test accuracy : 0.70059880
# Train Epoch: 84: train loss : 0.00250623	 train accuracy : 1.00000000	 val accuracy : 0.72119488	 test accuracy : 0.70059880
# Train Epoch: 85: train loss : 0.00255396	 train accuracy : 0.99964438	 val accuracy : 0.71977240	 test accuracy : 0.70658683
# Train Epoch: 86: train loss : 0.00241176	 train accuracy : 0.99964438	 val accuracy : 0.71834993	 test accuracy : 0.70059880
# Train Epoch: 87: train loss : 0.00163373	 train accuracy : 1.00000000	 val accuracy : 0.71834993	 test accuracy : 0.70059880
# Train Epoch: 88: train loss : 0.00259010	 train accuracy : 1.00000000	 val accuracy : 0.71834993	 test accuracy : 0.69461078
# Train Epoch: 89: train loss : 0.00208859	 train accuracy : 0.99964438	 val accuracy : 0.71834993	 test accuracy : 0.69461078
# Train Epoch: 90: train loss : 0.00256186	 train accuracy : 0.99964438	 val accuracy : 0.71977240	 test accuracy : 0.69461078
# Train Epoch: 91: train loss : 0.00212291	 train accuracy : 1.00000000	 val accuracy : 0.71834993	 test accuracy : 0.69461078
# Train Epoch: 92: train loss : 0.00232502	 train accuracy : 1.00000000	 val accuracy : 0.71550498	 test accuracy : 0.70059880
# Train Epoch: 93: train loss : 0.00224027	 train accuracy : 1.00000000	 val accuracy : 0.71834993	 test accuracy : 0.69461078
# Train Epoch: 94: train loss : 0.00210250	 train accuracy : 1.00000000	 val accuracy : 0.72119488	 test accuracy : 0.69461078
# Train Epoch: 95: train loss : 0.00273082	 train accuracy : 0.99928876	 val accuracy : 0.72403983	 test accuracy : 0.68862275
# Train Epoch: 96: train loss : 0.00232494	 train accuracy : 1.00000000	 val accuracy : 0.71977240	 test accuracy : 0.68263473
# Train Epoch: 97: train loss : 0.00171949	 train accuracy : 1.00000000	 val accuracy : 0.71834993	 test accuracy : 0.68862275
# Train Epoch: 98: train loss : 0.00245943	 train accuracy : 1.00000000	 val accuracy : 0.71834993	 test accuracy : 0.68862275
# Train Epoch: 99: train loss : 0.00199150	 train accuracy : 0.99964438	 val accuracy : 0.71834993	 test accuracy : 0.68862275
# Train Epoch: 100: train loss : 0.00182310	 train accuracy : 1.00000000	 val accuracy : 0.71977240	 test accuracy : 0.68862275
# Train Epoch: 101: train loss : 0.00175512	 train accuracy : 1.00000000	 val accuracy : 0.71977240	 test accuracy : 0.68862275
# Train Epoch: 102: train loss : 0.00214884	 train accuracy : 1.00000000	 val accuracy : 0.72119488	 test accuracy : 0.68862275
# Train Epoch: 103: train loss : 0.00230491	 train accuracy : 0.99928876	 val accuracy : 0.72119488	 test accuracy : 0.68862275
# Train Epoch: 104: train loss : 0.00153394	 train accuracy : 1.00000000	 val accuracy : 0.71834993	 test accuracy : 0.68862275
# Train Epoch: 105: train loss : 0.00184624	 train accuracy : 1.00000000	 val accuracy : 0.71834993	 test accuracy : 0.68862275
# Train Epoch: 106: train loss : 0.00186352	 train accuracy : 0.99964438	 val accuracy : 0.71692745	 test accuracy : 0.68862275
# Train Epoch: 107: train loss : 0.00184568	 train accuracy : 0.99964438	 val accuracy : 0.71977240	 test accuracy : 0.69461078
# Train Epoch: 108: train loss : 0.00225648	 train accuracy : 0.99964438	 val accuracy : 0.71977240	 test accuracy : 0.69461078
# Train Epoch: 109: train loss : 0.00204465	 train accuracy : 1.00000000	 val accuracy : 0.71977240	 test accuracy : 0.69461078
# Train Epoch: 110: train loss : 0.00209924	 train accuracy : 0.99964438	 val accuracy : 0.71834993	 test accuracy : 0.69461078
# Train Epoch: 111: train loss : 0.00196230	 train accuracy : 0.99964438	 val accuracy : 0.71692745	 test accuracy : 0.69461078
# Train Epoch: 112: train loss : 0.00224350	 train accuracy : 0.99928876	 val accuracy : 0.71550498	 test accuracy : 0.69461078
# Train Epoch: 113: train loss : 0.00198055	 train accuracy : 0.99964438	 val accuracy : 0.71408250	 test accuracy : 0.70059880
# Train Epoch: 114: train loss : 0.00151594	 train accuracy : 1.00000000	 val accuracy : 0.71408250	 test accuracy : 0.70059880
# Train Epoch: 115: train loss : 0.00163733	 train accuracy : 1.00000000	 val accuracy : 0.71266003	 test accuracy : 0.70059880
# Train Epoch: 116: train loss : 0.00154718	 train accuracy : 1.00000000	 val accuracy : 0.71266003	 test accuracy : 0.70059880
# Train Epoch: 117: train loss : 0.00156025	 train accuracy : 1.00000000	 val accuracy : 0.71550498	 test accuracy : 0.70059880
# Train Epoch: 118: train loss : 0.00203774	 train accuracy : 1.00000000	 val accuracy : 0.71834993	 test accuracy : 0.70059880
# Train Epoch: 119: train loss : 0.00143136	 train accuracy : 1.00000000	 val accuracy : 0.71977240	 test accuracy : 0.69461078
# Train Epoch: 120: train loss : 0.00135615	 train accuracy : 1.00000000	 val accuracy : 0.71834993	 test accuracy : 0.69461078
# Train Epoch: 121: train loss : 0.00135914	 train accuracy : 1.00000000	 val accuracy : 0.72119488	 test accuracy : 0.69461078
# Train Epoch: 122: train loss : 0.00168902	 train accuracy : 1.00000000	 val accuracy : 0.71977240	 test accuracy : 0.69461078
# Train Epoch: 123: train loss : 0.00112722	 train accuracy : 1.00000000	 val accuracy : 0.72261735	 test accuracy : 0.69461078
# Train Epoch: 124: train loss : 0.00158795	 train accuracy : 1.00000000	 val accuracy : 0.71977240	 test accuracy : 0.68862275
# Train Epoch: 125: train loss : 0.00141848	 train accuracy : 1.00000000	 val accuracy : 0.71977240	 test accuracy : 0.68862275
# Train Epoch: 126: train loss : 0.00206031	 train accuracy : 0.99928876	 val accuracy : 0.71977240	 test accuracy : 0.69461078
# Train Epoch: 127: train loss : 0.00137391	 train accuracy : 1.00000000	 val accuracy : 0.71977240	 test accuracy : 0.69461078
# Train Epoch: 128: train loss : 0.00161038	 train accuracy : 0.99964438	 val accuracy : 0.71977240	 test accuracy : 0.68862275
# Train Epoch: 129: train loss : 0.00108852	 train accuracy : 1.00000000	 val accuracy : 0.71692745	 test accuracy : 0.68862275
# Train Epoch: 130: train loss : 0.00105177	 train accuracy : 1.00000000	 val accuracy : 0.71550498	 test accuracy : 0.68862275
# Train Epoch: 131: train loss : 0.00139725	 train accuracy : 0.99964438	 val accuracy : 0.71550498	 test accuracy : 0.68862275
# Train Epoch: 132: train loss : 0.00129327	 train accuracy : 1.00000000	 val accuracy : 0.71550498	 test accuracy : 0.68862275
# Train Epoch: 133: train loss : 0.00124301	 train accuracy : 1.00000000	 val accuracy : 0.71550498	 test accuracy : 0.68862275
# Train Epoch: 134: train loss : 0.00111330	 train accuracy : 1.00000000	 val accuracy : 0.71692745	 test accuracy : 0.69461078
# Train Epoch: 135: train loss : 0.00114461	 train accuracy : 1.00000000	 val accuracy : 0.71692745	 test accuracy : 0.69461078
# Train Epoch: 136: train loss : 0.00189764	 train accuracy : 0.99964438	 val accuracy : 0.71834993	 test accuracy : 0.69461078
# Train Epoch: 137: train loss : 0.00173671	 train accuracy : 1.00000000	 val accuracy : 0.71834993	 test accuracy : 0.68862275
# Train Epoch: 138: train loss : 0.00126237	 train accuracy : 1.00000000	 val accuracy : 0.71834993	 test accuracy : 0.68862275
# Train Epoch: 139: train loss : 0.00098680	 train accuracy : 1.00000000	 val accuracy : 0.71834993	 test accuracy : 0.68862275
# Train Epoch: 140: train loss : 0.00151626	 train accuracy : 0.99928876	 val accuracy : 0.71977240	 test accuracy : 0.68862275
# Train Epoch: 141: train loss : 0.00094168	 train accuracy : 1.00000000	 val accuracy : 0.71977240	 test accuracy : 0.68862275
# Train Epoch: 142: train loss : 0.00144722	 train accuracy : 0.99964438	 val accuracy : 0.71977240	 test accuracy : 0.70059880
# Train Epoch: 143: train loss : 0.00105299	 train accuracy : 1.00000000	 val accuracy : 0.72261735	 test accuracy : 0.69461078
# Train Epoch: 144: train loss : 0.00114609	 train accuracy : 1.00000000	 val accuracy : 0.72403983	 test accuracy : 0.69461078
# Train Epoch: 145: train loss : 0.00151624	 train accuracy : 1.00000000	 val accuracy : 0.72261735	 test accuracy : 0.68862275
# Train Epoch: 146: train loss : 0.00128071	 train accuracy : 0.99964438	 val accuracy : 0.72119488	 test accuracy : 0.69461078
# Train Epoch: 147: train loss : 0.00142761	 train accuracy : 1.00000000	 val accuracy : 0.72119488	 test accuracy : 0.69461078
# Train Epoch: 148: train loss : 0.00105439	 train accuracy : 1.00000000	 val accuracy : 0.71977240	 test accuracy : 0.69461078
# Train Epoch: 149: train loss : 0.00077166	 train accuracy : 1.00000000	 val accuracy : 0.71977240	 test accuracy : 0.69461078
# Train Epoch: 150: train loss : 0.00110615	 train accuracy : 1.00000000	 val accuracy : 0.71834993	 test accuracy : 0.69461078
# Train Epoch: 151: train loss : 0.00151268	 train accuracy : 1.00000000	 val accuracy : 0.71834993	 test accuracy : 0.69461078
# Train Epoch: 152: train loss : 0.00105954	 train accuracy : 1.00000000	 val accuracy : 0.71834993	 test accuracy : 0.69461078
# Train Epoch: 153: train loss : 0.00111218	 train accuracy : 0.99964438	 val accuracy : 0.71977240	 test accuracy : 0.69461078
# Train Epoch: 154: train loss : 0.00127035	 train accuracy : 0.99964438	 val accuracy : 0.71977240	 test accuracy : 0.69461078
# Train Epoch: 155: train loss : 0.00087002	 train accuracy : 1.00000000	 val accuracy : 0.71977240	 test accuracy : 0.69461078
# Train Epoch: 156: train loss : 0.00101548	 train accuracy : 1.00000000	 val accuracy : 0.71977240	 test accuracy : 0.69461078
# Train Epoch: 157: train loss : 0.00108274	 train accuracy : 1.00000000	 val accuracy : 0.71977240	 test accuracy : 0.69461078
# Train Epoch: 158: train loss : 0.00085420	 train accuracy : 1.00000000	 val accuracy : 0.71977240	 test accuracy : 0.69461078
# Train Epoch: 159: train loss : 0.00103750	 train accuracy : 1.00000000	 val accuracy : 0.71977240	 test accuracy : 0.69461078
# Train Epoch: 160: train loss : 0.00109598	 train accuracy : 1.00000000	 val accuracy : 0.71692745	 test accuracy : 0.69461078
# Train Epoch: 161: train loss : 0.00147269	 train accuracy : 0.99964438	 val accuracy : 0.71692745	 test accuracy : 0.69461078
# Train Epoch: 162: train loss : 0.00108916	 train accuracy : 1.00000000	 val accuracy : 0.71977240	 test accuracy : 0.69461078
# Train Epoch: 163: train loss : 0.00091007	 train accuracy : 1.00000000	 val accuracy : 0.71977240	 test accuracy : 0.69461078
# Train Epoch: 164: train loss : 0.00070610	 train accuracy : 1.00000000	 val accuracy : 0.71977240	 test accuracy : 0.69461078
# Train Epoch: 165: train loss : 0.00108070	 train accuracy : 1.00000000	 val accuracy : 0.71834993	 test accuracy : 0.68862275
# Train Epoch: 166: train loss : 0.00078972	 train accuracy : 1.00000000	 val accuracy : 0.71550498	 test accuracy : 0.68862275
# Train Epoch: 167: train loss : 0.00088260	 train accuracy : 1.00000000	 val accuracy : 0.71550498	 test accuracy : 0.68862275
# Train Epoch: 168: train loss : 0.00068551	 train accuracy : 1.00000000	 val accuracy : 0.71408250	 test accuracy : 0.68862275
# Train Epoch: 169: train loss : 0.00084916	 train accuracy : 1.00000000	 val accuracy : 0.71550498	 test accuracy : 0.68862275
# Train Epoch: 170: train loss : 0.00107173	 train accuracy : 0.99964438	 val accuracy : 0.71692745	 test accuracy : 0.68862275
# Train Epoch: 171: train loss : 0.00148951	 train accuracy : 0.99964438	 val accuracy : 0.71692745	 test accuracy : 0.68862275
# Train Epoch: 172: train loss : 0.00092783	 train accuracy : 1.00000000	 val accuracy : 0.71550498	 test accuracy : 0.68263473
# Train Epoch: 173: train loss : 0.00093142	 train accuracy : 1.00000000	 val accuracy : 0.71692745	 test accuracy : 0.68263473
# Train Epoch: 174: train loss : 0.00104137	 train accuracy : 1.00000000	 val accuracy : 0.71692745	 test accuracy : 0.68263473
# Train Epoch: 175: train loss : 0.00106529	 train accuracy : 1.00000000	 val accuracy : 0.71692745	 test accuracy : 0.68263473
# Train Epoch: 176: train loss : 0.00127312	 train accuracy : 0.99964438	 val accuracy : 0.71550498	 test accuracy : 0.68862275
# Train Epoch: 177: train loss : 0.00120264	 train accuracy : 1.00000000	 val accuracy : 0.71550498	 test accuracy : 0.68862275
# Train Epoch: 178: train loss : 0.00100540	 train accuracy : 1.00000000	 val accuracy : 0.71692745	 test accuracy : 0.68263473
# Train Epoch: 179: train loss : 0.00094491	 train accuracy : 1.00000000	 val accuracy : 0.71834993	 test accuracy : 0.68263473
# Train Epoch: 180: train loss : 0.00101136	 train accuracy : 1.00000000	 val accuracy : 0.71834993	 test accuracy : 0.68263473
# Train Epoch: 181: train loss : 0.00050622	 train accuracy : 1.00000000	 val accuracy : 0.71834993	 test accuracy : 0.68263473
# Train Epoch: 182: train loss : 0.00079896	 train accuracy : 1.00000000	 val accuracy : 0.71834993	 test accuracy : 0.68263473
# Train Epoch: 183: train loss : 0.00094502	 train accuracy : 1.00000000	 val accuracy : 0.71977240	 test accuracy : 0.68263473
# Train Epoch: 184: train loss : 0.00098349	 train accuracy : 1.00000000	 val accuracy : 0.72119488	 test accuracy : 0.68263473
# Train Epoch: 185: train loss : 0.00077155	 train accuracy : 1.00000000	 val accuracy : 0.72119488	 test accuracy : 0.68263473
# Train Epoch: 186: train loss : 0.00077934	 train accuracy : 1.00000000	 val accuracy : 0.71977240	 test accuracy : 0.68263473
# Train Epoch: 187: train loss : 0.00122100	 train accuracy : 0.99928876	 val accuracy : 0.72119488	 test accuracy : 0.68263473
# Train Epoch: 188: train loss : 0.00077067	 train accuracy : 1.00000000	 val accuracy : 0.72119488	 test accuracy : 0.68263473
# Train Epoch: 189: train loss : 0.00092151	 train accuracy : 0.99964438	 val accuracy : 0.72119488	 test accuracy : 0.68263473
# Train Epoch: 190: train loss : 0.00096091	 train accuracy : 0.99964438	 val accuracy : 0.72119488	 test accuracy : 0.68263473
# Train Epoch: 191: train loss : 0.00085917	 train accuracy : 1.00000000	 val accuracy : 0.72119488	 test accuracy : 0.68263473
# Train Epoch: 192: train loss : 0.00081088	 train accuracy : 1.00000000	 val accuracy : 0.72403983	 test accuracy : 0.68263473
# Train Epoch: 193: train loss : 0.00096059	 train accuracy : 0.99964438	 val accuracy : 0.72546230	 test accuracy : 0.68263473
# Save models
# Train Epoch: 194: train loss : 0.00150767	 train accuracy : 0.99893314	 val accuracy : 0.72830725	 test accuracy : 0.68263473
# Train Epoch: 195: train loss : 0.00085742	 train accuracy : 1.00000000	 val accuracy : 0.72546230	 test accuracy : 0.68263473
# Train Epoch: 196: train loss : 0.00100206	 train accuracy : 1.00000000	 val accuracy : 0.72119488	 test accuracy : 0.68862275
# Train Epoch: 197: train loss : 0.00130655	 train accuracy : 1.00000000	 val accuracy : 0.72119488	 test accuracy : 0.68263473
# Train Epoch: 198: train loss : 0.00136771	 train accuracy : 0.99928876	 val accuracy : 0.72546230	 test accuracy : 0.68862275
# Train Epoch: 199: train loss : 0.00050416	 train accuracy : 1.00000000	 val accuracy : 0.72546230	 test accuracy : 0.70059880
# Train Epoch: 200: train loss : 0.00079964	 train accuracy : 1.00000000	 val accuracy : 0.72403983	 test accuracy : 0.70059880
# In ensemble  5
# The best validaiton accuracy is:  0.7283072546230441
# Happened at epoch:  194
# The corresponding test accuracy 0.6826347305389222
# The corresponding test AUC is:  0.7914492753623188
# The Max voting test accuracy is:  0.7091954022988506
# The test AUC is:  0.7841137932317044
