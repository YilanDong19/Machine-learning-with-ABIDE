# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/ABIDE/")
# Out:
# Mounted at /content/drive

# %%
# load ComBat algorithm
# !python /content/drive/MyDrive/ABIDE/neuralCombat.py 
import sys
sys.path.append('/content/drive/MyDrive/ABIDE/')

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from neuralCombat import *
# from neuralCombat.py import neuralCombat
import pandas as pd
from sklearn import svm
import joblib
import openpyxl
from openpyxl import load_workbook
import os
import scipy.io as scio
import argparse
import numpy as np
import time
import torch
import torch.utils.data
import torch.nn as nn
import torch.optim as optim
from torch.utils.data.dataset import Dataset
from torch.autograd import Variable
from torchvision import datasets, transforms
from torchvision.utils import make_grid , save_image
import torchvision.utils as vutils
from os.path import join
from os import listdir
from torch.utils.data.dataloader import DataLoader
from torch.utils.data import DataLoader
from collections import OrderedDict
import nibabel as nib
import matplotlib.pyplot as plt
import cv2 as cv
from os import path
import shutil
import scipy.stats
import scipy.ndimage
import random
import torch.nn.init as init
import torch.nn.functional as F
import sys
import math
from functools import reduce
import operator
from scipy.interpolate import interp1d
from torch.optim import lr_scheduler
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import RidgeClassifier
from sklearn.feature_selection import RFE

def feature_selection(matrix, labels, train_ind, fnum):
    """
        matrix       : feature matrix (num_subjects x num_features)
        labels       : ground truth labels (num_subjects x 1)
        train_ind    : indices of the training samples
        fnum         : size of the feature vector after feature selection 

    return:
        x_data      : feature matrix of lower dimension (num_subjects x fnum)
    """

    estimator = RidgeClassifier()
    selector = RFE(estimator, n_features_to_select=fnum, step=100, verbose=1)

    featureX = matrix[train_ind, :]
    featureY = labels[train_ind]
    selector = selector.fit(featureX, featureY.ravel())

    return selector

def get_index(lst=None, item=''):
	return [i for i in range(len(lst)) if lst[i] == item]

def flatten_one(length, img):
	'''
	  In some situations, the dimension on z-axis of images are smaller than
	  the dimension of z-axis of patches, this function will be used to pad
	'''

	one_line = np.zeros((1, int(length)))
	position = 0
	for i in range(img.shape[0]):  # column
		for j in range(i + 1, img.shape[1]):  # row
			one_line[0, position] = img[j, i]
			position = position + 1
	return one_line


def get_ids(num_subjects=None,dir_path=''):
	"""
	return:
		subject_IDs    : list of all subject IDs
	"""
	subject_IDs = np.genfromtxt(os.path.join(dir_path, 'subject_IDs.txt'), dtype=str)

	if num_subjects is not None:
		subject_IDs = subject_IDs[:num_subjects]

	return subject_IDs

def save_model(net,path, name_net):

  # This fucntion is used to save a specific model

    path_net =  path + '/' + name_net + '.pth'
    torch.save(net.cpu().state_dict(), path_net)
    net.cuda()
    

def load_model(net, path, name_net):

  # This function is used to load a specific model we saved before

    path_net =  path + '/' + name_net + '.pth'
    net.load_state_dict(torch.load(path_net))

    return net

# %%
########################################### Load Data ###############################################
#####################################################################################################
#####################################################################################################
combat = True    # True or False


if combat == False:
  save_combat = '/without_ComBat/'
else:
  save_combat = '/with_ComBat/'

save_path = '/content/drive/MyDrive/ABIDE/save_models/sMRI' + save_combat
localDir = '/content/sMRI_dataset/'
if os.path.exists(localDir):
  shutil.rmtree(localDir) 

os.makedirs(localDir)
# !unzip '/content/drive/MyDrive/ABIDE/freesurfer_stats.zip' -d '/content/sMRI_dataset'

label_dir = '/content/drive/MyDrive/ABIDE/phenotypic_image_quality'
localDir = localDir + 'freesurfer_stats/'

k_fold = 5
new_number_features = 1435
number_samples = 871
useless_samples = ['51334']
scaler = True

age_name = 'ages.mat'
gender_name = 'genders.mat'
label_name = 'ABIDE_label_871.mat'
label = scio.loadmat(os.path.join(label_dir, label_name))
label = label['label'][0]
labels = np.zeros(number_samples - len(useless_samples))
site_name = 'sites.mat'
site = scio.loadmat(os.path.join(label_dir, site_name))
all_sites = site['sites']
for i in range(len(all_sites)):
	site = all_sites[i]
	all_sites[i] = site.replace(' ', '')
unique_sites = np.unique(all_sites)
sites = []
unique_sites = list(unique_sites)

gender = scio.loadmat(os.path.join(label_dir, gender_name))
gender = gender['genders']
genders = np.zeros((number_samples - len(useless_samples), 1))

age = scio.loadmat(os.path.join(label_dir, age_name))
age = age['ages']
ages = np.zeros((number_samples - len(useless_samples), 1))

subject_IDs = get_ids(number_samples,dir_path=label_dir)
subject_IDs = subject_IDs.tolist()

position = 0
for i in range(number_samples):
  subject_name = subject_IDs[i]
  if subject_name in useless_samples:
    subject_index = get_index(lst=subject_IDs, item=subject_name)
    print('The index for sample ' + subject_name + ' is : ', subject_index)
  else:
    image_name = subject_name + '.mat'
    subject_index = get_index(lst=subject_IDs, item=subject_name)
    sites.append(all_sites[subject_index[0]])
    labels[position] = label[subject_index[0]]
    genders[position] = int(gender[subject_index[0]]) + 1
    ages[position] = float(age[subject_index[0]].replace(' ', ''))
    position = position + 1
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51096/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51097/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51098/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51099/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51100/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51101/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51102/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51103/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51104/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51105/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51106/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51107/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51109/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51110/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51111/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51112/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51113/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51114/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51116/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51117/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51118/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51122/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51123/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51124/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51126/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51127/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51128/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51129/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51130/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51131/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.curv.stats
# ...
#   inflating: /content/sMRI_dataset/freesurfer_stats/51576/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51576/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51576/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51576/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51576/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51577/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51578/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51579/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51580/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51582/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51583/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51584/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51585/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51606/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51607/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/wmparc.stats
# The index for sample 51334 is :  [799]

# %%
############################################### Load sMRI ###############################################################
############################################### Load sMRI ###############################################################
############################################### Load sMRI ###############################################################
############################################### Load Desikan_Killiany_features
left = 'lh.aparc.stats'
right = 'rh.aparc.stats'
number_roi = 68
feature_list = ['NumVert', 'SurfArea', 'GrayVol', 'ThickAvg', 'ThickStd', 'MeanCurv', 'GausCurv', 'FoldInd', 'CurvInd']
names = ['StructName', 'NumVert', 'SurfArea', 'GrayVol', 'ThickAvg', 'ThickStd', 'MeanCurv', 'GausCurv', 'FoldInd', 'CurvInd']
skiprows= list(range(0,61))
Desikan_Killiany_features = np.zeros((number_samples - len(useless_samples), number_roi * len(feature_list)))


position = 0
print('constructing Desikan-Killiany Atlas features')
for i in range(number_samples):
  subject_name = subject_IDs[i]
  if subject_name in useless_samples:
    subject_index = get_index(lst=subject_IDs, item=subject_name)
    print('The index for sample ' + subject_name + ' is : ', subject_index)
  else:
    table_left = pd.read_table(localDir + subject_name + '/' + left, sep='\s+', names=names,
						  skiprows=skiprows)
    table_right = pd.read_table(localDir + subject_name + '/' + right, sep='\s+', names=names,
						  skiprows=skiprows)

    for j in range(len(feature_list)):
      feature_name = feature_list[j]
      left_features = table_left[feature_name].values.tolist()
      right_features = table_right[feature_name].values.tolist()
      all_features = left_features + right_features
      if len(all_features) != number_roi:
       print('The sample ' + subject_name + ' has mistake!')
      all_features = np.array(all_features)
      Desikan_Killiany_features[position, j*number_roi : (j+1)*number_roi] = all_features
    position = position + 1

if scaler == True:
	for i in range(len(feature_list)):
		Desikan_Killiany_features[:, i * number_roi: (i+1) * number_roi] = StandardScaler().fit_transform(Desikan_Killiany_features[:, i * number_roi: (i+1) * number_roi])

print('finished')

############################################### Load aseg features
print('constructing aseg features')
number_roi_aseg = 45
aseg = 'aseg.stats'
feature_list_aseg = ['Number of Voxels', 'Volume', 'Intensity normMean', 'Itensity normStdDev', 'Intensity normMin', 'Intensity normMax', 'Intensity normRange']
names_aseg = ['ColHeader Index', 'Segmentation Id ', 'Number of Voxels', 'Volume', 'Structure Name', 'Intensity normMean', 'Itensity normStdDev', 'Intensity normMin', 'Intensity normMax', 'Intensity normRange']
skiprows_aseg= list(range(0,79))
aseg_features = np.zeros((number_samples - len(useless_samples), number_roi_aseg * len(feature_list_aseg)))

position = 0
for i in range(number_samples):
	subject_name = subject_IDs[i]
	if subject_name in useless_samples:
		subject_index = get_index(lst=subject_IDs, item=subject_name)
		print('The index for sample ' + subject_name + ' is : ', subject_index)
	else:
		table_left = pd.read_table(localDir + subject_name + '/' + aseg, sep='\s+', names=names_aseg,
						  skiprows=skiprows_aseg)
		for j in range(len(feature_list_aseg)):
			feature_name = feature_list_aseg[j]
			left_features = table_left[feature_name].values.tolist()
			if len(left_features) != number_roi_aseg:
				print('The sample ' + subject_name + ' has mistake!')
			all_features = np.array(left_features)
			aseg_features[position, j*number_roi_aseg : (j+1)*number_roi_aseg] = all_features
		position = position + 1

if scaler == True:
	for i in range(len(feature_list_aseg)):
		aseg_features[:, i * number_roi_aseg: (i+1) * number_roi_aseg] = StandardScaler().fit_transform(aseg_features[:, i * number_roi_aseg: (i+1) * number_roi_aseg])
print('finished')

############################################### Load wmparc features
number_roi_wmparc = 70
wmparc = 'wmparc.stats'
feature_list_wmparc = ['Number of Voxels', 'Volume', 'Intensity normMean', 'Itensity normStdDev', 'Intensity normMin', 'Intensity normMax', 'Intensity normRange']
names_wmparc = ['ColHeader Index', 'Segmentation Id ', 'Number of Voxels', 'Volume', 'Structure Name', 'Intensity normMean', 'Itensity normStdDev', 'Intensity normMin', 'Intensity normMax', 'Intensity normRange']
skiprows_wmparc= list(range(0,65))
wmparc_features = np.zeros((number_samples - len(useless_samples), number_roi_wmparc * len(feature_list_wmparc)))

print('constructing wmparc features')
position = 0
for i in range(number_samples):
	subject_name = subject_IDs[i]
	if subject_name in useless_samples:
		subject_index = get_index(lst=subject_IDs, item=subject_name)
		print('The index for sample ' + subject_name + ' is : ', subject_index)
	else:
		table_left = pd.read_table(localDir + subject_name + '/' + wmparc, sep='\s+', names = names_wmparc,
						  skiprows=skiprows_wmparc)
		for j in range(len(feature_list_wmparc)):
			feature_name = feature_list_wmparc[j]
			left_features = table_left[feature_name].values.tolist()
			if len(left_features) != number_roi_wmparc:
				print('The sample ' + subject_name + ' has mistake!')
			all_features = np.array(left_features)
			wmparc_features[position, j*number_roi_wmparc : (j+1)*number_roi_wmparc] = all_features
		position = position + 1
if scaler == True:
	for i in range(len(feature_list_wmparc)):
		wmparc_features[:, i * number_roi_wmparc: (i+1) * number_roi_wmparc] = StandardScaler().fit_transform(wmparc_features[:, i * number_roi_wmparc: (i+1) * number_roi_wmparc])
print('finished')

############################################### concatenation
sMRI_features = np.concatenate((Desikan_Killiany_features, aseg_features, wmparc_features),axis = 1)
# Out:
# constructing Desikan-Killiany Atlas features
# The index for sample 51334 is :  [799]
# finished
# constructing aseg features
# The index for sample 51334 is :  [799]
# finished
# constructing wmparc features
# The index for sample 51334 is :  [799]
# finished

# %%
############################################### Combat ###############################################################
############################################### Combat ###############################################################
############################################### Combat ###############################################################
if combat == True:
	batch = []
	for i in range(len(sites)):
		batch.append(get_index(lst=unique_sites, item=sites[i])[0]+1)

	combat_labels = []
	combat_genders = []
	combat_ages = []
	for i in range(len(labels)):
		combat_labels.append(labels[i] + 1)
		combat_genders.append(genders[i])
		combat_ages.append(ages[i])

	new_all_samples_feature = sMRI_features.T
	covars = {}
	covars['batch'] = batch
	covars['labels'] = combat_labels
	covars['genders'] = combat_genders
	covars['ages'] = combat_ages
	covars = pd.DataFrame(covars)

	# To specify names of the variables that are categorical:
	categorical_cols = ['labels', 'genders']
	# To specify the name of the variable that encodes for the scanner/batch covariate:
	batch_col = 'batch'
	continuous_cols = ['ages']
	# Harmonization step:
	new_all_samples_feature = neuroCombat(dat=new_all_samples_feature,
										  covars=covars,
										  batch_col=batch_col,
										  categorical_cols=categorical_cols,
											continuous_cols=continuous_cols)["data"]
	sMRI_features = new_all_samples_feature.T
# Out:
# [neuroCombat] Creating design matrix
# [neuroCombat] Standardizing data across features
# [neuroCombat] Fitting L/S model and finding priors
# [neuroCombat] Finding parametric adjustments
# [neuroCombat] Final adjustment of data
# /content/drive/MyDrive/ABIDE/neuralCombat.py:325: RuntimeWarning: divide by zero encountered in true_divide
#   change = max((abs(g_new - g_old) / g_old).max(), (abs(d_new - d_old) / d_old).max())

# %%
############################################### phenotypic ###############################################################
############################################### phenotypic ###############################################################
############################################### phenotypic ###############################################################
ages_name = 'ages.mat'
ages = scio.loadmat(os.path.join(label_dir, ages_name))
ages = ages['ages']

gender_name = 'genders.mat'
genders = scio.loadmat(os.path.join(label_dir, gender_name))
genders = genders['genders']

FIQ_name = 'FIQS.mat'
FIQS = scio.loadmat(os.path.join(label_dir, FIQ_name))
FIQS = FIQS['FIQS']

NUM_name = 'NUM.mat'
NUM = scio.loadmat(os.path.join(label_dir, NUM_name))
NUMS = NUM['NUM']

PEC_name = 'PEC.mat'
PEC = scio.loadmat(os.path.join(label_dir, PEC_name))
PECS = PEC['PEC']

RAT_name = 'RAT.mat'
RAT = scio.loadmat(os.path.join(label_dir, RAT_name))
RATS = RAT['RAT']

age = np.zeros((number_samples - len(useless_samples), 1))
gender = np.zeros((number_samples - len(useless_samples), 1))
FIQ = np.zeros((number_samples - len(useless_samples), 1))
NUM = np.zeros((number_samples - len(useless_samples), 1))
PEC = np.zeros((number_samples - len(useless_samples), 1))
RAT = np.zeros((number_samples - len(useless_samples), 1))

position = 0
print('constructing phenotypic features')
for i in range(number_samples):
	subject_name = subject_IDs[i]
	if subject_name in useless_samples:
		subject_index = get_index(lst=subject_IDs, item=subject_name)
		print('The index for sample ' + subject_name + ' is : ', subject_index)
	else:
		subject_index = get_index(lst=subject_IDs, item=subject_name)
		age[position] = float(ages[subject_index[0]].replace(' ', ''))
		gender[position] = int(genders[subject_index[0]]) + 1
		FIQ[position] = int(FIQS[subject_index[0]])
		NUM[position] = float(NUMS[subject_index[0]])
		PEC[position] = float(PECS[subject_index[0]])
		RAT[position] = int(RATS[subject_index[0]])
		position = position + 1
FIQ[FIQ == -9999] = 108

if scaler == True:

  age[:,0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(age[:,0], axis = 1)))
  FIQ[:, 0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(FIQ[:, 0], axis = 1)))
  NUM[:, 0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(NUM[:, 0], axis = 1)))
  PEC[:, 0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(PEC[:, 0], axis = 1)))

# age, gender, FIQ, NUM, PEC, RAT
for i in range(3):
	sMRI_features = np.concatenate((sMRI_features, age, gender, FIQ, NUM, PEC, RAT),axis = 1)
# Out:
# constructing phenotypic features
# The index for sample 51334 is :  [799]

# %%
dist_train = {}
dist_validation = {}
dist_test = {}
for i in range(k_fold):
	dist_train[str(i + 1)] = []
	dist_validation[str(i + 1)] = []
	dist_test[str(i + 1)] = []

for each_site in unique_sites:
	index_site = get_index(sites, each_site)
	label = np.zeros((len(index_site)))
	for i in range(len(index_site)):
		index = index_site[i]
		label[i] = int(labels[int(index)])
	########################################### StratifiedKFold ####################################################
	sfolder = StratifiedKFold(n_splits=k_fold,random_state=0,shuffle=True)
	group = 0
	for train, validation in sfolder.split(index_site,label):
		for i in train:
			dist_train[str(group + 1)].append(index_site[i])
			name = 0
		for j in validation:
			dist_validation[str(group + 1)].append(index_site[j])
			name = 0
		group = group+1

	group = 0
	for train, validation in sfolder.split(index_site,label):
		if group == 0:
			for j in validation:
				dist_test[str(group + k_fold)].append(index_site[j])
				dist_train[str(group + k_fold)].remove(index_site[j])
		else:
			for j in validation:
				dist_test[str(group)].append(index_site[j])
				dist_train[str(group)].remove(index_site[j])
		group = group+1

# %%
import torch.nn as nn
############################################### FCN model ###############################################################
############################################### FCN model ###############################################################
############################################### FCN model ###############################################################
def single_linear(in_channels, out_channels, dropout):
    return nn.Sequential(
        nn.Linear(in_features=in_channels, out_features=out_channels),
        nn.Dropout(dropout),
        nn.ReLU(inplace=True),
        nn.BatchNorm1d(out_channels)
    )

class FCN(nn.Module):
    def __init__(self, input_c, hid_1, hid_2, out_c, dropout):
        super().__init__()

        self.linear_1 = single_linear(input_c, hid_1, dropout)
        self.linear_2 = nn.Linear(in_features=hid_1, out_features=hid_2)
        self.linear_3 = nn.Linear(in_features=hid_2, out_features=out_c)

        self.dropout = nn.Dropout(dropout)
        self.relu = nn.ReLU(inplace=True)
        self.softmax = nn.LogSoftmax(dim=1)


    def forward(self, x):

        input = torch.flatten(x, start_dim=1, end_dim=-1)
        x = self.relu(self.linear_1(input))
        x = self.relu(self.dropout(self.linear_2(x)))
        x = self.linear_3(x)
        out = self.softmax(x)
        return out

# %%
FCN_labels = np.zeros((number_samples - len(useless_samples), 2))
for i in range(len(labels)):
    if labels[i] == 1:
        FCN_labels[i,0] = 1
    else:
        FCN_labels[i,1] = 1

data = {}
for fold in range(1, k_fold+1):
  data[str(fold)] = []
  selector = feature_selection(sMRI_features, labels, dist_train[str(fold)], new_number_features)
  fold_data = selector.transform(sMRI_features)

  data[str(fold)].append(fold_data)
  data[str(fold)].append(FCN_labels)

# %%
############################################### Train, validaiton, test pipelines ###############################################################
############################################### Train, validaiton, test pipelines ###############################################################
############################################### Train, validaiton, test pipelines ###############################################################
def train_FCN(args, model, all_data, fold_train_index, fold_validation_index, fold_test_index, scheduler):

    model.train()

    data = torch.from_numpy(all_data[0])
    data = Variable(data, requires_grad=True)
    data = data.float()

    target = torch.from_numpy(all_data[1])
    target = target.float().long()

    if args.cuda:
        data, target = data.cuda(), target.cuda()
    
    data_train = data[fold_train_index,:] 
    target = target[fold_train_index, :]
    scheduler.zero_grad()
    out = model(data_train)

    cross_loss = torch.nn.functional.nll_loss(out, torch.max(target, 1)[1])
    cross_loss.backward()
    scheduler.step()

    out = torch.max(out, 1)[1]
    target = torch.max(target, 1)[1]
    target = target.cpu().numpy()
    out = out.cpu().numpy()

    ############################## validation and test ################################################################################
    val_target, val_out, val_loss = validation_FCN(args, model, all_data, fold_validation_index)
    test_target, test_out, test_out_prob, test_loss = test_FCN(args, model, all_data, fold_test_index)

    return model, target, out, cross_loss.item(), val_target, val_out,val_loss, test_target, test_out, test_out_prob, test_loss

    
def validation_FCN(args, model,all_data,  fold_validation_index):

    model.eval()
    data = torch.from_numpy(all_data[0])
    data = Variable(data, requires_grad=False)
    data = data.float()

    target = torch.from_numpy(all_data[1])
    target = target.float().long()


    if args.cuda:
        data, target = data.cuda(), target.cuda()


    data_val = data[fold_validation_index,:] 
    target = target[fold_validation_index, :]
    out = model(data_val)

    cross_loss = torch.nn.functional.nll_loss(out, torch.max(target, 1)[1])

    out = torch.max(out, 1)[1]
    target = torch.max(target, 1)[1]
    target = target.cpu().numpy()
    out = out.cpu().numpy()

    return target, out, cross_loss.item()


def test_FCN(args, model, all_data,  fold_test_index):

    model.eval()

    data = torch.from_numpy(all_data[0])
    data = Variable(data, requires_grad=False)
    data = data.float()

    target = torch.from_numpy(all_data[1])
    target = target.float().long()


    if args.cuda:
        data, target = data.cuda(), target.cuda()
    
    data_test = data[fold_test_index,:] 
    target = target[fold_test_index, :]
    out = model(data_test)

    cross_loss = torch.nn.functional.nll_loss(out, torch.max(target, 1)[1])

    out_prob = torch.exp(out)
    out = torch.max(out, 1)[1]
    target = torch.max(target, 1)[1]
    target = target.cpu().numpy()
    out = out.cpu().numpy()
    out_prob = out_prob.cpu().detach().numpy()

    return target, out, out_prob, cross_loss.item()

# %%
########################################### Training setting ################################################
########################################### Training setting ################################################
########################################### Training setting ################################################
parser = argparse.ArgumentParser()
parser.add_argument('--ngpu', type=int, default=1)
parser.add_argument('--nEpochs', type=int, default=200)
parser.add_argument('--no-cuda', action='store_true')
parser.add_argument('--seed', type=int, default=1)
parser.add_argument('--lr', type=str, default=8e-4)
# I define three kinds of optimizer, adam sgd and rmsprop, but adam performs the best
parser.add_argument('--opt', type=str, default='adam')
parser.add_argument('--input_c', type=int, default=new_number_features)
parser.add_argument('--hid_1', type=int, default=500)
parser.add_argument('--hid_2', type=int, default=30)
parser.add_argument('--out_c', type=int, default=2)
parser.add_argument('--dropout_rate', type=int, default=0.5)


args, unknown = parser.parse_known_args()
args.cuda = not args.no_cuda and torch.cuda.is_available()
torch.manual_seed(args.seed)
if args.cuda:
    torch.cuda.manual_seed(args.seed)
    
gpu_ids = range(args.ngpu)
train = train_FCN

# %%
########################################### Training ################################################
########################################### Training ################################################
########################################### Training ################################################


for fold in range(1, k_fold+1):
  model = FCN(input_c=args.input_c, hid_1=args.hid_1, hid_2=args.hid_2, out_c=args.out_c, dropout=args.dropout_rate)
  print('  + Number of params: {}'.format(
    sum([p.data.nelement() for p in model.parameters()])))
  model = nn.parallel.DataParallel(model, device_ids=gpu_ids)
  if args.cuda:
    model = model.cuda()
  optimizer = optim.Adam(model.parameters(), lr = args.lr)

  best_validation_accuracy = 0
  Train_accuracy_list =[]
  Train_loss_list = []
  Val_accuracy_list =[]
  Val_loss_list = []
  Test_accuracy_list =[]
  Test_loss_list = []

  for epoch in range(1, args.nEpochs + 1):
    model, train_target, train_out, train_loss, val_target, val_out, val_loss, test_target, test_out, test_prob, test_loss = train(args, model, data[str(fold)], dist_train[str(fold)], dist_validation[str(fold)], dist_test[str(fold)], optimizer)

    train_accuracy = metrics.accuracy_score(train_target, train_out)
    val_accuracy = metrics.accuracy_score(val_target, val_out)
    test_accuracy = metrics.accuracy_score(test_target, test_out)
    Train_accuracy_list.append(train_accuracy)
    Val_accuracy_list.append(val_accuracy)
    Test_accuracy_list.append(test_accuracy)
    Train_loss_list.append(train_loss)
    Val_loss_list.append(val_loss)
    Test_loss_list.append(test_loss)

    if val_accuracy >=best_validation_accuracy:
      best_epoch = epoch
      best_validation_accuracy = val_accuracy
      corresponding_val_out = val_out
      corresponding_test_accuracy = test_accuracy
      corresponding_test_out = test_out
      corresponding_test_prob = test_prob

      print('Save models')
      save_model(model, save_path, 'FCN_'+str(fold))

    print('Train Epoch: ' + str(epoch) + ': train loss : {:.8f}\t train accuracy : {:.8f}\t val accuracy : {:.8f}\t test accuracy : {:.8f}\t'.format(
      train_loss, train_accuracy, val_accuracy, test_accuracy))
  
  if fold == 1:
    all_fold_val_label = val_target
    all_fold_val_out = corresponding_val_out
    all_fold_test_label = test_target
    all_fold_test_out = corresponding_test_out
    all_fold_test_prob = corresponding_test_prob
  else:
    all_fold_val_label = np.concatenate((all_fold_val_label, val_target),axis = 0)
    all_fold_val_out = np.concatenate((all_fold_val_out, corresponding_val_out),axis = 0)
    all_fold_test_label = np.concatenate((all_fold_test_label, test_target),axis = 0)
    all_fold_test_out = np.concatenate((all_fold_test_out, corresponding_test_out),axis = 0)
    all_fold_test_prob = np.concatenate((all_fold_test_prob, corresponding_test_prob),axis = 0)

  x_axis = list(range(1, len(Train_accuracy_list)+1))
  plt.figure(figsize=(10,6))
  plt.plot(x_axis, Train_loss_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_loss_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_loss_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()

  plt.figure(figsize=(10,6))
  plt.plot(x_axis, Train_accuracy_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_accuracy_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_accuracy_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()


  test_fpr, test_tpr, te_thresholds = roc_curve(test_target, corresponding_test_prob[:,1],pos_label=1)
  test_auc = auc(test_fpr, test_tpr)
  print('\n')
  print('In fold ',str(fold))
  print('The best validaiton accuracy is: ',best_validation_accuracy)
  print('Happened at epoch: ',best_epoch)
  print('The corresponding test accuracy', corresponding_test_accuracy)
  print('The corresponding test AUC is: ',test_auc)
  print('\n')


  plt.grid()
  plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
  plt.plot([0,1],[0,1],'g--')
  plt.legend()
  plt.xlabel("False Positive Rate")
  plt.ylabel("True Positive Rate")
  plt.title("Test AUC(ROC curve)")
  plt.grid(color='black', linestyle='-', linewidth=0.5)
  plt.show()

print('Finish 5-fold training')
# Out:
#   + Number of params: 734092
# Save models
# Train Epoch: 1: train loss : 0.71190983	 train accuracy : 0.49706458	 val accuracy : 0.57692308	 test accuracy : 0.53107345
# Save models
# Train Epoch: 2: train loss : 0.65534848	 train accuracy : 0.60861057	 val accuracy : 0.58241758	 test accuracy : 0.54237288
# Save models
# Train Epoch: 3: train loss : 0.60658115	 train accuracy : 0.69471624	 val accuracy : 0.60439560	 test accuracy : 0.54802260
# Train Epoch: 4: train loss : 0.58842647	 train accuracy : 0.70254403	 val accuracy : 0.58241758	 test accuracy : 0.57627119
# Save models
# Train Epoch: 5: train loss : 0.58039808	 train accuracy : 0.70645793	 val accuracy : 0.60989011	 test accuracy : 0.57062147
# Save models
# Train Epoch: 6: train loss : 0.54026926	 train accuracy : 0.74755382	 val accuracy : 0.62637363	 test accuracy : 0.57062147
# Save models
# Train Epoch: 7: train loss : 0.51501888	 train accuracy : 0.74951076	 val accuracy : 0.63736264	 test accuracy : 0.57062147
# Save models
# Train Epoch: 8: train loss : 0.48406816	 train accuracy : 0.78864971	 val accuracy : 0.64835165	 test accuracy : 0.56497175
# Save models
# Train Epoch: 9: train loss : 0.46304452	 train accuracy : 0.81800391	 val accuracy : 0.65934066	 test accuracy : 0.56497175
# Train Epoch: 10: train loss : 0.43176335	 train accuracy : 0.86301370	 val accuracy : 0.64835165	 test accuracy : 0.58192090
# Train Epoch: 11: train loss : 0.40495962	 train accuracy : 0.87671233	 val accuracy : 0.64285714	 test accuracy : 0.59887006
# Train Epoch: 12: train loss : 0.37454870	 train accuracy : 0.88454012	 val accuracy : 0.64835165	 test accuracy : 0.59322034
# Train Epoch: 13: train loss : 0.35531121	 train accuracy : 0.89432485	 val accuracy : 0.63736264	 test accuracy : 0.60451977
# Train Epoch: 14: train loss : 0.33423632	 train accuracy : 0.89628180	 val accuracy : 0.63736264	 test accuracy : 0.61581921
# Train Epoch: 15: train loss : 0.30122587	 train accuracy : 0.93542074	 val accuracy : 0.63186813	 test accuracy : 0.62711864
# Train Epoch: 16: train loss : 0.27085212	 train accuracy : 0.93933464	 val accuracy : 0.64285714	 test accuracy : 0.61016949
# Train Epoch: 17: train loss : 0.25108537	 train accuracy : 0.95303327	 val accuracy : 0.63736264	 test accuracy : 0.62146893
# Train Epoch: 18: train loss : 0.22312795	 train accuracy : 0.97260274	 val accuracy : 0.63186813	 test accuracy : 0.62146893
# Train Epoch: 19: train loss : 0.20479572	 train accuracy : 0.96281800	 val accuracy : 0.63186813	 test accuracy : 0.63276836
# Train Epoch: 20: train loss : 0.17742392	 train accuracy : 0.97064579	 val accuracy : 0.62637363	 test accuracy : 0.62146893
# Train Epoch: 21: train loss : 0.15766259	 train accuracy : 0.97847358	 val accuracy : 0.60439560	 test accuracy : 0.62146893
# Train Epoch: 22: train loss : 0.13894406	 train accuracy : 0.98434442	 val accuracy : 0.59340659	 test accuracy : 0.62146893
# Train Epoch: 23: train loss : 0.12294758	 train accuracy : 0.99217221	 val accuracy : 0.60439560	 test accuracy : 0.62146893
# Train Epoch: 24: train loss : 0.11080696	 train accuracy : 0.99021526	 val accuracy : 0.60989011	 test accuracy : 0.63276836
# Train Epoch: 25: train loss : 0.09395631	 train accuracy : 0.99608611	 val accuracy : 0.61538462	 test accuracy : 0.64406780
# Train Epoch: 26: train loss : 0.07568604	 train accuracy : 0.99412916	 val accuracy : 0.62087912	 test accuracy : 0.63276836
# Train Epoch: 27: train loss : 0.06826174	 train accuracy : 0.99412916	 val accuracy : 0.62087912	 test accuracy : 0.62711864
# Train Epoch: 28: train loss : 0.05976921	 train accuracy : 0.99412916	 val accuracy : 0.62637363	 test accuracy : 0.62711864
# Train Epoch: 29: train loss : 0.05480332	 train accuracy : 0.99804305	 val accuracy : 0.60989011	 test accuracy : 0.62146893
# Train Epoch: 30: train loss : 0.04319780	 train accuracy : 0.99804305	 val accuracy : 0.60439560	 test accuracy : 0.62146893
# Train Epoch: 31: train loss : 0.03820270	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.61581921
# Train Epoch: 32: train loss : 0.03655015	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.62711864
# Train Epoch: 33: train loss : 0.02925406	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.63276836
# Train Epoch: 34: train loss : 0.02658425	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.63841808
# Train Epoch: 35: train loss : 0.02379883	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.63276836
# Train Epoch: 36: train loss : 0.02131263	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.62146893
# Train Epoch: 37: train loss : 0.01745577	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.61016949
# Train Epoch: 38: train loss : 0.01635201	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.61016949
# Train Epoch: 39: train loss : 0.01606616	 train accuracy : 0.99804305	 val accuracy : 0.62087912	 test accuracy : 0.61016949
# Train Epoch: 40: train loss : 0.01456933	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.61016949
# Train Epoch: 41: train loss : 0.01148450	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.61016949
# Train Epoch: 42: train loss : 0.01293132	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.61016949
# Train Epoch: 43: train loss : 0.01137639	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.61016949
# Train Epoch: 44: train loss : 0.00918492	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.61016949
# Train Epoch: 45: train loss : 0.00991036	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.60451977
# Train Epoch: 46: train loss : 0.00870866	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.61581921
# Train Epoch: 47: train loss : 0.00832909	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.61016949
# Train Epoch: 48: train loss : 0.00809627	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.61581921
# Train Epoch: 49: train loss : 0.00827311	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.62146893
# Train Epoch: 50: train loss : 0.00818801	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.63276836
# Train Epoch: 51: train loss : 0.00860472	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.63841808
# Train Epoch: 52: train loss : 0.00594290	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.64406780
# Train Epoch: 53: train loss : 0.00639865	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.64971751
# Train Epoch: 54: train loss : 0.00513539	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.64406780
# Train Epoch: 55: train loss : 0.00602739	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.63841808
# Train Epoch: 56: train loss : 0.00688914	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.63276836
# Train Epoch: 57: train loss : 0.00486703	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.61581921
# Train Epoch: 58: train loss : 0.00414979	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.61581921
# Train Epoch: 59: train loss : 0.00524006	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.61581921
# Train Epoch: 60: train loss : 0.00315797	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.61581921
# Train Epoch: 61: train loss : 0.00471580	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.60451977
# Train Epoch: 62: train loss : 0.00350836	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.60451977
# Train Epoch: 63: train loss : 0.00411903	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.60451977
# Train Epoch: 64: train loss : 0.00374082	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.60451977
# Train Epoch: 65: train loss : 0.00438408	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.59887006
# Train Epoch: 66: train loss : 0.00392618	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.60451977
# Train Epoch: 67: train loss : 0.00319824	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.60451977
# Train Epoch: 68: train loss : 0.00296560	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.60451977
# Train Epoch: 69: train loss : 0.00313158	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.60451977
# Train Epoch: 70: train loss : 0.00320348	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.60451977
# Train Epoch: 71: train loss : 0.00260759	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.60451977
# Train Epoch: 72: train loss : 0.00376990	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.60451977
# Train Epoch: 73: train loss : 0.00274042	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.60451977
# Train Epoch: 74: train loss : 0.00248817	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.61016949
# Train Epoch: 75: train loss : 0.00246188	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.61016949
# Train Epoch: 76: train loss : 0.00382698	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.61016949
# Train Epoch: 77: train loss : 0.00272624	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.61016949
# Train Epoch: 78: train loss : 0.00278299	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.61016949
# Train Epoch: 79: train loss : 0.00207695	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.61016949
# Train Epoch: 80: train loss : 0.00297927	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.61016949
# Train Epoch: 81: train loss : 0.00254300	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.61016949
# Train Epoch: 82: train loss : 0.00182733	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.61016949
# Train Epoch: 83: train loss : 0.00232440	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.61016949
# Train Epoch: 84: train loss : 0.00138671	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.61016949
# Train Epoch: 85: train loss : 0.00310795	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.61016949
# Train Epoch: 86: train loss : 0.00313318	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.61016949
# Train Epoch: 87: train loss : 0.00241078	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.60451977
# Train Epoch: 88: train loss : 0.00154965	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.60451977
# Train Epoch: 89: train loss : 0.00204036	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.60451977
# Train Epoch: 90: train loss : 0.00157678	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.60451977
# Train Epoch: 91: train loss : 0.00377748	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.60451977
# Train Epoch: 92: train loss : 0.00166675	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.60451977
# Train Epoch: 93: train loss : 0.00137755	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.60451977
# Train Epoch: 94: train loss : 0.00265270	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.59887006
# Train Epoch: 95: train loss : 0.00243370	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.59887006
# Train Epoch: 96: train loss : 0.00130775	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.59887006
# Train Epoch: 97: train loss : 0.00170280	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.59887006
# Train Epoch: 98: train loss : 0.00154327	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.59887006
# Train Epoch: 99: train loss : 0.00127636	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.59887006
# Train Epoch: 100: train loss : 0.00244675	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.59887006
# Train Epoch: 101: train loss : 0.00134510	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.59887006
# Train Epoch: 102: train loss : 0.00220072	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.59887006
# Train Epoch: 103: train loss : 0.00165593	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.59887006
# Train Epoch: 104: train loss : 0.00200268	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.59887006
# Train Epoch: 105: train loss : 0.00126532	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.60451977
# Train Epoch: 106: train loss : 0.00148029	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.60451977
# Train Epoch: 107: train loss : 0.00128986	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.60451977
# Train Epoch: 108: train loss : 0.00191202	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.60451977
# Train Epoch: 109: train loss : 0.00219778	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.61016949
# Train Epoch: 110: train loss : 0.00167682	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.61016949
# Train Epoch: 111: train loss : 0.00139352	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.61016949
# Train Epoch: 112: train loss : 0.00186195	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.61016949
# Train Epoch: 113: train loss : 0.00128001	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.61016949
# Train Epoch: 114: train loss : 0.00124479	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.61016949
# Train Epoch: 115: train loss : 0.00085033	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.61016949
# Train Epoch: 116: train loss : 0.00150453	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.61016949
# Train Epoch: 117: train loss : 0.00107106	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.61016949
# Train Epoch: 118: train loss : 0.00170725	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.60451977
# Train Epoch: 119: train loss : 0.00161866	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.60451977
# Train Epoch: 120: train loss : 0.00114807	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.60451977
# Train Epoch: 121: train loss : 0.00168294	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.60451977
# Train Epoch: 122: train loss : 0.00157534	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.60451977
# Train Epoch: 123: train loss : 0.00145626	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.60451977
# Train Epoch: 124: train loss : 0.00138628	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.61016949
# Train Epoch: 125: train loss : 0.00165816	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.61016949
# Train Epoch: 126: train loss : 0.00105437	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.61016949
# Train Epoch: 127: train loss : 0.00093333	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.61016949
# Train Epoch: 128: train loss : 0.00128482	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.61016949
# Train Epoch: 129: train loss : 0.00189189	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.61016949
# Train Epoch: 130: train loss : 0.00215902	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.61016949
# Train Epoch: 131: train loss : 0.00136025	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.61016949
# Train Epoch: 132: train loss : 0.00155759	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.61016949
# Train Epoch: 133: train loss : 0.00107991	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.61016949
# Train Epoch: 134: train loss : 0.00068312	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.61016949
# Train Epoch: 135: train loss : 0.00090542	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.61016949
# Train Epoch: 136: train loss : 0.00081291	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.61016949
# Train Epoch: 137: train loss : 0.00134451	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.61581921
# Train Epoch: 138: train loss : 0.00100435	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.61581921
# Train Epoch: 139: train loss : 0.00151784	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.61581921
# Train Epoch: 140: train loss : 0.00151842	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.61581921
# Train Epoch: 141: train loss : 0.00142843	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.62146893
# Train Epoch: 142: train loss : 0.00089822	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.62711864
# Train Epoch: 143: train loss : 0.00122394	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.62711864
# Train Epoch: 144: train loss : 0.00063303	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.62711864
# Train Epoch: 145: train loss : 0.00079087	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.62146893
# Train Epoch: 146: train loss : 0.00120272	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.62146893
# Train Epoch: 147: train loss : 0.00170263	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.62146893
# Train Epoch: 148: train loss : 0.00180344	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.62146893
# Train Epoch: 149: train loss : 0.00166861	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.62146893
# Train Epoch: 150: train loss : 0.00088780	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.62146893
# Train Epoch: 151: train loss : 0.00111453	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.62146893
# Train Epoch: 152: train loss : 0.00083626	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.61581921
# Train Epoch: 153: train loss : 0.00101564	 train accuracy : 1.00000000	 val accuracy : 0.58791209	 test accuracy : 0.61581921
# Train Epoch: 154: train loss : 0.00097721	 train accuracy : 1.00000000	 val accuracy : 0.58791209	 test accuracy : 0.61581921
# Train Epoch: 155: train loss : 0.00156796	 train accuracy : 1.00000000	 val accuracy : 0.58791209	 test accuracy : 0.62146893
# Train Epoch: 156: train loss : 0.00175545	 train accuracy : 1.00000000	 val accuracy : 0.58791209	 test accuracy : 0.62146893
# Train Epoch: 157: train loss : 0.00116318	 train accuracy : 1.00000000	 val accuracy : 0.58791209	 test accuracy : 0.62146893
# Train Epoch: 158: train loss : 0.00153594	 train accuracy : 1.00000000	 val accuracy : 0.58791209	 test accuracy : 0.61581921
# Train Epoch: 159: train loss : 0.00152993	 train accuracy : 1.00000000	 val accuracy : 0.58791209	 test accuracy : 0.61016949
# Train Epoch: 160: train loss : 0.00074327	 train accuracy : 1.00000000	 val accuracy : 0.58791209	 test accuracy : 0.61016949
# Train Epoch: 161: train loss : 0.00093185	 train accuracy : 1.00000000	 val accuracy : 0.58791209	 test accuracy : 0.61016949
# Train Epoch: 162: train loss : 0.00114959	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.61581921
# Train Epoch: 163: train loss : 0.00066041	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.61581921
# Train Epoch: 164: train loss : 0.00131915	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.61581921
# Train Epoch: 165: train loss : 0.00173063	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.61016949
# Train Epoch: 166: train loss : 0.00087308	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.61016949
# Train Epoch: 167: train loss : 0.00118248	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.61016949
# Train Epoch: 168: train loss : 0.00062882	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.61016949
# Train Epoch: 169: train loss : 0.00117589	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.61016949
# Train Epoch: 170: train loss : 0.00124059	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.61016949
# Train Epoch: 171: train loss : 0.00096372	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.61016949
# Train Epoch: 172: train loss : 0.00080808	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.61016949
# Train Epoch: 173: train loss : 0.00149214	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.60451977
# Train Epoch: 174: train loss : 0.00053286	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.59887006
# Train Epoch: 175: train loss : 0.00091586	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.59322034
# Train Epoch: 176: train loss : 0.00174441	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.59322034
# Train Epoch: 177: train loss : 0.00137743	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.59322034
# Train Epoch: 178: train loss : 0.00102149	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.59322034
# Train Epoch: 179: train loss : 0.00059831	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.59887006
# Train Epoch: 180: train loss : 0.00104828	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.60451977
# Train Epoch: 181: train loss : 0.00052689	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.60451977
# Train Epoch: 182: train loss : 0.00070516	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.61016949
# Train Epoch: 183: train loss : 0.00068471	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.61016949
# Train Epoch: 184: train loss : 0.00105720	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.61016949
# Train Epoch: 185: train loss : 0.00044194	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.61016949
# Train Epoch: 186: train loss : 0.00043364	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.61016949
# Train Epoch: 187: train loss : 0.00083643	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.61016949
# Train Epoch: 188: train loss : 0.00060889	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.61016949
# Train Epoch: 189: train loss : 0.00072895	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.61016949
# Train Epoch: 190: train loss : 0.00060669	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.60451977
# Train Epoch: 191: train loss : 0.00068960	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.59887006
# Train Epoch: 192: train loss : 0.00067565	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.59887006
# Train Epoch: 193: train loss : 0.00059174	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.59887006
# Train Epoch: 194: train loss : 0.00047831	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.61016949
# Train Epoch: 195: train loss : 0.00070590	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.61016949
# Train Epoch: 196: train loss : 0.00040344	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.61016949
# Train Epoch: 197: train loss : 0.00083050	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.61016949
# Train Epoch: 198: train loss : 0.00051278	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.61016949
# Train Epoch: 199: train loss : 0.00065085	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.61016949
# Train Epoch: 200: train loss : 0.00035286	 train accuracy : 1.00000000	 val accuracy : 0.59340659	 test accuracy : 0.61581921
# In fold  1
# The best validaiton accuracy is:  0.6593406593406593
# Happened at epoch:  9
# The corresponding test accuracy 0.5649717514124294
# The corresponding test AUC is:  0.6303069053708441
#   + Number of params: 734092
# Save models
# Train Epoch: 1: train loss : 0.71103776	 train accuracy : 0.47784200	 val accuracy : 0.48587571	 test accuracy : 0.50574713
# Save models
# Train Epoch: 2: train loss : 0.67383933	 train accuracy : 0.55876686	 val accuracy : 0.49717514	 test accuracy : 0.54597701
# Save models
# Train Epoch: 3: train loss : 0.62995911	 train accuracy : 0.64932563	 val accuracy : 0.53672316	 test accuracy : 0.58620690
# Save models
# Train Epoch: 4: train loss : 0.61660582	 train accuracy : 0.67630058	 val accuracy : 0.54237288	 test accuracy : 0.58045977
# Train Epoch: 5: train loss : 0.58583617	 train accuracy : 0.69749518	 val accuracy : 0.53107345	 test accuracy : 0.60919540
# Save models
# Train Epoch: 6: train loss : 0.56328177	 train accuracy : 0.72447013	 val accuracy : 0.54802260	 test accuracy : 0.61494253
# Save models
# Train Epoch: 7: train loss : 0.54197186	 train accuracy : 0.75915222	 val accuracy : 0.55367232	 test accuracy : 0.60919540
# Save models
# Train Epoch: 8: train loss : 0.51339942	 train accuracy : 0.81117534	 val accuracy : 0.55932203	 test accuracy : 0.59770115
# Save models
# Train Epoch: 9: train loss : 0.47866693	 train accuracy : 0.81888247	 val accuracy : 0.57062147	 test accuracy : 0.59770115
# Train Epoch: 10: train loss : 0.46604854	 train accuracy : 0.84585742	 val accuracy : 0.55932203	 test accuracy : 0.59770115
# Train Epoch: 11: train loss : 0.43763760	 train accuracy : 0.85356455	 val accuracy : 0.54802260	 test accuracy : 0.60919540
# Train Epoch: 12: train loss : 0.40093726	 train accuracy : 0.88439306	 val accuracy : 0.55932203	 test accuracy : 0.63218391
# Train Epoch: 13: train loss : 0.38203204	 train accuracy : 0.88246628	 val accuracy : 0.55932203	 test accuracy : 0.63218391
# Train Epoch: 14: train loss : 0.35715353	 train accuracy : 0.89788054	 val accuracy : 0.54802260	 test accuracy : 0.63218391
# Train Epoch: 15: train loss : 0.32302737	 train accuracy : 0.93256262	 val accuracy : 0.54802260	 test accuracy : 0.63218391
# Train Epoch: 16: train loss : 0.30223817	 train accuracy : 0.93834297	 val accuracy : 0.54237288	 test accuracy : 0.62643678
# Train Epoch: 17: train loss : 0.28188190	 train accuracy : 0.94412331	 val accuracy : 0.54237288	 test accuracy : 0.63793103
# Train Epoch: 18: train loss : 0.24430573	 train accuracy : 0.95568401	 val accuracy : 0.53107345	 test accuracy : 0.63793103
# Train Epoch: 19: train loss : 0.22609927	 train accuracy : 0.96917148	 val accuracy : 0.53672316	 test accuracy : 0.63793103
# Train Epoch: 20: train loss : 0.21402094	 train accuracy : 0.97687861	 val accuracy : 0.54237288	 test accuracy : 0.63218391
# Train Epoch: 21: train loss : 0.16854839	 train accuracy : 0.98843931	 val accuracy : 0.54237288	 test accuracy : 0.62068966
# Train Epoch: 22: train loss : 0.16379538	 train accuracy : 0.98073218	 val accuracy : 0.54237288	 test accuracy : 0.63218391
# Train Epoch: 23: train loss : 0.14636852	 train accuracy : 0.97495183	 val accuracy : 0.55932203	 test accuracy : 0.63793103
# Train Epoch: 24: train loss : 0.13218977	 train accuracy : 0.98843931	 val accuracy : 0.55367232	 test accuracy : 0.64942529
# Train Epoch: 25: train loss : 0.11632489	 train accuracy : 0.98651252	 val accuracy : 0.55367232	 test accuracy : 0.63218391
# Train Epoch: 26: train loss : 0.09151210	 train accuracy : 0.99807322	 val accuracy : 0.54237288	 test accuracy : 0.63218391
# Train Epoch: 27: train loss : 0.07631544	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.63793103
# Train Epoch: 28: train loss : 0.07369772	 train accuracy : 0.99807322	 val accuracy : 0.55367232	 test accuracy : 0.62643678
# Train Epoch: 29: train loss : 0.06074381	 train accuracy : 0.99614644	 val accuracy : 0.55367232	 test accuracy : 0.62068966
# Train Epoch: 30: train loss : 0.05451140	 train accuracy : 1.00000000	 val accuracy : 0.54802260	 test accuracy : 0.61494253
# Train Epoch: 31: train loss : 0.05171880	 train accuracy : 0.99807322	 val accuracy : 0.55367232	 test accuracy : 0.61494253
# Train Epoch: 32: train loss : 0.04536090	 train accuracy : 0.99807322	 val accuracy : 0.54802260	 test accuracy : 0.61494253
# Train Epoch: 33: train loss : 0.04709991	 train accuracy : 0.99614644	 val accuracy : 0.54802260	 test accuracy : 0.62643678
# Train Epoch: 34: train loss : 0.03498803	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.62643678
# Train Epoch: 35: train loss : 0.03182301	 train accuracy : 0.99807322	 val accuracy : 0.54802260	 test accuracy : 0.63218391
# Train Epoch: 36: train loss : 0.02764812	 train accuracy : 0.99614644	 val accuracy : 0.54802260	 test accuracy : 0.62643678
# Train Epoch: 37: train loss : 0.02633774	 train accuracy : 0.99807322	 val accuracy : 0.54802260	 test accuracy : 0.60919540
# Train Epoch: 38: train loss : 0.01940204	 train accuracy : 1.00000000	 val accuracy : 0.53672316	 test accuracy : 0.60919540
# Train Epoch: 39: train loss : 0.02086166	 train accuracy : 1.00000000	 val accuracy : 0.53672316	 test accuracy : 0.60919540
# Train Epoch: 40: train loss : 0.01646918	 train accuracy : 1.00000000	 val accuracy : 0.54237288	 test accuracy : 0.62643678
# Train Epoch: 41: train loss : 0.01633132	 train accuracy : 1.00000000	 val accuracy : 0.54237288	 test accuracy : 0.61494253
# Train Epoch: 42: train loss : 0.01453175	 train accuracy : 0.99807322	 val accuracy : 0.54237288	 test accuracy : 0.62068966
# Train Epoch: 43: train loss : 0.01100995	 train accuracy : 1.00000000	 val accuracy : 0.54237288	 test accuracy : 0.62068966
# Train Epoch: 44: train loss : 0.01065244	 train accuracy : 1.00000000	 val accuracy : 0.54802260	 test accuracy : 0.62643678
# Train Epoch: 45: train loss : 0.01119037	 train accuracy : 1.00000000	 val accuracy : 0.54802260	 test accuracy : 0.62643678
# Train Epoch: 46: train loss : 0.00939185	 train accuracy : 1.00000000	 val accuracy : 0.54237288	 test accuracy : 0.63218391
# Train Epoch: 47: train loss : 0.00929951	 train accuracy : 1.00000000	 val accuracy : 0.54237288	 test accuracy : 0.63793103
# Train Epoch: 48: train loss : 0.00817283	 train accuracy : 1.00000000	 val accuracy : 0.54237288	 test accuracy : 0.63793103
# Train Epoch: 49: train loss : 0.00640904	 train accuracy : 1.00000000	 val accuracy : 0.54237288	 test accuracy : 0.63218391
# Train Epoch: 50: train loss : 0.00803828	 train accuracy : 1.00000000	 val accuracy : 0.54802260	 test accuracy : 0.63793103
# Train Epoch: 51: train loss : 0.00676997	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.63793103
# Train Epoch: 52: train loss : 0.00728242	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.64942529
# Train Epoch: 53: train loss : 0.00722651	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.65517241
# Train Epoch: 54: train loss : 0.00644344	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.64367816
# Train Epoch: 55: train loss : 0.00369931	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.64367816
# Train Epoch: 56: train loss : 0.00642124	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.64367816
# Train Epoch: 57: train loss : 0.00410736	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.63218391
# Train Epoch: 58: train loss : 0.00436713	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.63793103
# Train Epoch: 59: train loss : 0.00456460	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.63793103
# Train Epoch: 60: train loss : 0.00357237	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.63218391
# Train Epoch: 61: train loss : 0.00517101	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.63218391
# Train Epoch: 62: train loss : 0.00416125	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.63218391
# Train Epoch: 63: train loss : 0.00348707	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.63793103
# Train Epoch: 64: train loss : 0.00401605	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.64367816
# Train Epoch: 65: train loss : 0.00308553	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.63793103
# Train Epoch: 66: train loss : 0.00575916	 train accuracy : 0.99807322	 val accuracy : 0.56497175	 test accuracy : 0.63793103
# Train Epoch: 67: train loss : 0.00359067	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.64367816
# Train Epoch: 68: train loss : 0.00246103	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.63793103
# Train Epoch: 69: train loss : 0.00333557	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.63793103
# Train Epoch: 70: train loss : 0.00335999	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.64367816
# Save models
# Train Epoch: 71: train loss : 0.00362589	 train accuracy : 1.00000000	 val accuracy : 0.57062147	 test accuracy : 0.65517241
# Train Epoch: 72: train loss : 0.00499790	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.64942529
# Train Epoch: 73: train loss : 0.00304122	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.64942529
# Save models
# Train Epoch: 74: train loss : 0.00196609	 train accuracy : 1.00000000	 val accuracy : 0.57062147	 test accuracy : 0.65517241
# Train Epoch: 75: train loss : 0.00249476	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.64942529
# Train Epoch: 76: train loss : 0.00384540	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.65517241
# Train Epoch: 77: train loss : 0.00203475	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.65517241
# Train Epoch: 78: train loss : 0.00323081	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.65517241
# Train Epoch: 79: train loss : 0.00330493	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.65517241
# Train Epoch: 80: train loss : 0.00229674	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.65517241
# Train Epoch: 81: train loss : 0.00317411	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.65517241
# Train Epoch: 82: train loss : 0.00302794	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.64942529
# Train Epoch: 83: train loss : 0.00238987	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.64367816
# Train Epoch: 84: train loss : 0.00229088	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.64367816
# Train Epoch: 85: train loss : 0.00141735	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.64367816
# Train Epoch: 86: train loss : 0.00233549	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.63793103
# Train Epoch: 87: train loss : 0.00162620	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.63218391
# Train Epoch: 88: train loss : 0.00323585	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.63218391
# Train Epoch: 89: train loss : 0.00165111	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.63218391
# Train Epoch: 90: train loss : 0.00177044	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.63793103
# Train Epoch: 91: train loss : 0.00176147	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.64367816
# Train Epoch: 92: train loss : 0.00188762	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.64367816
# Train Epoch: 93: train loss : 0.00206834	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.64367816
# Train Epoch: 94: train loss : 0.00214842	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.64367816
# Train Epoch: 95: train loss : 0.00188035	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.64367816
# Train Epoch: 96: train loss : 0.00280918	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.64367816
# Train Epoch: 97: train loss : 0.00170748	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.64367816
# Train Epoch: 98: train loss : 0.00229254	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.64367816
# Train Epoch: 99: train loss : 0.00224630	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.64367816
# Train Epoch: 100: train loss : 0.00131780	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.64367816
# Train Epoch: 101: train loss : 0.00179534	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.64367816
# Train Epoch: 102: train loss : 0.00146211	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.63793103
# Train Epoch: 103: train loss : 0.00138348	 train accuracy : 1.00000000	 val accuracy : 0.54802260	 test accuracy : 0.63793103
# Train Epoch: 104: train loss : 0.00203258	 train accuracy : 1.00000000	 val accuracy : 0.54802260	 test accuracy : 0.63793103
# Train Epoch: 105: train loss : 0.00148690	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.63793103
# Train Epoch: 106: train loss : 0.00166644	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.63218391
# Train Epoch: 107: train loss : 0.00205216	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.63218391
# Train Epoch: 108: train loss : 0.00204877	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.63793103
# Train Epoch: 109: train loss : 0.00132940	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.63793103
# Train Epoch: 110: train loss : 0.00118337	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.64367816
# Train Epoch: 111: train loss : 0.00110620	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.64367816
# Train Epoch: 112: train loss : 0.00138489	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.64367816
# Train Epoch: 113: train loss : 0.00132996	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.64367816
# Train Epoch: 114: train loss : 0.00217335	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.64367816
# Train Epoch: 115: train loss : 0.00136575	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.64367816
# Train Epoch: 116: train loss : 0.00144251	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.63793103
# Train Epoch: 117: train loss : 0.00171276	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.63793103
# Train Epoch: 118: train loss : 0.00189214	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.63218391
# Train Epoch: 119: train loss : 0.00199814	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.63218391
# Train Epoch: 120: train loss : 0.00158832	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.63218391
# Train Epoch: 121: train loss : 0.00084433	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.63218391
# Train Epoch: 122: train loss : 0.00149685	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.63218391
# Train Epoch: 123: train loss : 0.00149505	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.63793103
# Train Epoch: 124: train loss : 0.00121482	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.63218391
# Train Epoch: 125: train loss : 0.00147582	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.62643678
# Train Epoch: 126: train loss : 0.00155019	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.62643678
# Train Epoch: 127: train loss : 0.00085828	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.62643678
# Train Epoch: 128: train loss : 0.00071269	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.62643678
# Train Epoch: 129: train loss : 0.00135526	 train accuracy : 1.00000000	 val accuracy : 0.54802260	 test accuracy : 0.62643678
# Train Epoch: 130: train loss : 0.00162634	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.62643678
# Train Epoch: 131: train loss : 0.00132264	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.62643678
# Train Epoch: 132: train loss : 0.00110672	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.62643678
# Train Epoch: 133: train loss : 0.00144436	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.62068966
# Train Epoch: 134: train loss : 0.00173722	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.62068966
# Train Epoch: 135: train loss : 0.00077398	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.62068966
# Train Epoch: 136: train loss : 0.00086908	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.62068966
# Train Epoch: 137: train loss : 0.00090786	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.62068966
# Train Epoch: 138: train loss : 0.00137642	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.62068966
# Train Epoch: 139: train loss : 0.00084597	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.62068966
# Train Epoch: 140: train loss : 0.00116918	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.62068966
# Train Epoch: 141: train loss : 0.00137971	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.62068966
# Train Epoch: 142: train loss : 0.00091479	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.62068966
# Train Epoch: 143: train loss : 0.00120859	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.62068966
# Train Epoch: 144: train loss : 0.00115271	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.62068966
# Train Epoch: 145: train loss : 0.00165734	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.62068966
# Train Epoch: 146: train loss : 0.00081164	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.62068966
# Train Epoch: 147: train loss : 0.00109423	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.62068966
# Train Epoch: 148: train loss : 0.00079406	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.62068966
# Train Epoch: 149: train loss : 0.00191220	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.62068966
# Train Epoch: 150: train loss : 0.00103126	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.62068966
# Train Epoch: 151: train loss : 0.00160754	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.61494253
# Train Epoch: 152: train loss : 0.00111779	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.62068966
# Train Epoch: 153: train loss : 0.00272156	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.62068966
# Train Epoch: 154: train loss : 0.00186658	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.62068966
# Save models
# Train Epoch: 155: train loss : 0.00091347	 train accuracy : 1.00000000	 val accuracy : 0.57062147	 test accuracy : 0.62068966
# Save models
# Train Epoch: 156: train loss : 0.00112213	 train accuracy : 1.00000000	 val accuracy : 0.57062147	 test accuracy : 0.62643678
# Save models
# Train Epoch: 157: train loss : 0.00141203	 train accuracy : 1.00000000	 val accuracy : 0.57062147	 test accuracy : 0.62643678
# Save models
# Train Epoch: 158: train loss : 0.00075027	 train accuracy : 1.00000000	 val accuracy : 0.57062147	 test accuracy : 0.62643678
# Save models
# Train Epoch: 159: train loss : 0.00078109	 train accuracy : 1.00000000	 val accuracy : 0.57062147	 test accuracy : 0.63218391
# Save models
# Train Epoch: 160: train loss : 0.00080343	 train accuracy : 1.00000000	 val accuracy : 0.57062147	 test accuracy : 0.63218391
# Save models
# Train Epoch: 161: train loss : 0.00077811	 train accuracy : 1.00000000	 val accuracy : 0.57062147	 test accuracy : 0.62643678
# Save models
# Train Epoch: 162: train loss : 0.00097080	 train accuracy : 1.00000000	 val accuracy : 0.57062147	 test accuracy : 0.62643678
# Save models
# Train Epoch: 163: train loss : 0.00072763	 train accuracy : 1.00000000	 val accuracy : 0.57062147	 test accuracy : 0.62643678
# Save models
# Train Epoch: 164: train loss : 0.00126938	 train accuracy : 1.00000000	 val accuracy : 0.57062147	 test accuracy : 0.62643678
# Save models
# Train Epoch: 165: train loss : 0.00078219	 train accuracy : 1.00000000	 val accuracy : 0.57062147	 test accuracy : 0.61494253
# Save models
# Train Epoch: 166: train loss : 0.00080608	 train accuracy : 1.00000000	 val accuracy : 0.57062147	 test accuracy : 0.61494253
# Train Epoch: 167: train loss : 0.00070490	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.61494253
# Train Epoch: 168: train loss : 0.00108190	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.62068966
# Train Epoch: 169: train loss : 0.00085434	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.62068966
# Save models
# Train Epoch: 170: train loss : 0.00159317	 train accuracy : 1.00000000	 val accuracy : 0.57062147	 test accuracy : 0.62643678
# Save models
# Train Epoch: 171: train loss : 0.00083193	 train accuracy : 1.00000000	 val accuracy : 0.57062147	 test accuracy : 0.62643678
# Save models
# Train Epoch: 172: train loss : 0.00113071	 train accuracy : 1.00000000	 val accuracy : 0.57062147	 test accuracy : 0.62643678
# Save models
# Train Epoch: 173: train loss : 0.00059006	 train accuracy : 1.00000000	 val accuracy : 0.57627119	 test accuracy : 0.62643678
# Save models
# Train Epoch: 174: train loss : 0.00083396	 train accuracy : 1.00000000	 val accuracy : 0.57627119	 test accuracy : 0.63218391
# ...
# Train Epoch: 77: train loss : 0.00270457	 train accuracy : 1.00000000	 val accuracy : 0.58083832	 test accuracy : 0.56593407
# Train Epoch: 78: train loss : 0.00158026	 train accuracy : 1.00000000	 val accuracy : 0.58083832	 test accuracy : 0.57142857
# Train Epoch: 79: train loss : 0.00232848	 train accuracy : 1.00000000	 val accuracy : 0.58083832	 test accuracy : 0.57142857
# Train Epoch: 80: train loss : 0.00280360	 train accuracy : 1.00000000	 val accuracy : 0.58083832	 test accuracy : 0.57142857
# Train Epoch: 81: train loss : 0.00389600	 train accuracy : 1.00000000	 val accuracy : 0.58083832	 test accuracy : 0.57142857
# Train Epoch: 82: train loss : 0.00166893	 train accuracy : 1.00000000	 val accuracy : 0.58083832	 test accuracy : 0.57692308
# Train Epoch: 83: train loss : 0.00382106	 train accuracy : 0.99808061	 val accuracy : 0.58083832	 test accuracy : 0.57692308
# Train Epoch: 84: train loss : 0.00239497	 train accuracy : 1.00000000	 val accuracy : 0.58083832	 test accuracy : 0.56593407
# Train Epoch: 85: train loss : 0.00226524	 train accuracy : 1.00000000	 val accuracy : 0.58083832	 test accuracy : 0.56593407
# Train Epoch: 86: train loss : 0.00218732	 train accuracy : 1.00000000	 val accuracy : 0.58083832	 test accuracy : 0.56593407
# Train Epoch: 87: train loss : 0.00297587	 train accuracy : 1.00000000	 val accuracy : 0.58083832	 test accuracy : 0.57142857
# Train Epoch: 88: train loss : 0.00155510	 train accuracy : 1.00000000	 val accuracy : 0.58083832	 test accuracy : 0.57142857
# Train Epoch: 89: train loss : 0.00251056	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57142857
# Train Epoch: 90: train loss : 0.00215164	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57142857
# Train Epoch: 91: train loss : 0.00269486	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57142857
# Train Epoch: 92: train loss : 0.00197408	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57142857
# Train Epoch: 93: train loss : 0.00238335	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57142857
# Train Epoch: 94: train loss : 0.00176717	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57142857
# Train Epoch: 95: train loss : 0.00117965	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57142857
# Train Epoch: 96: train loss : 0.00131118	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57142857
# Train Epoch: 97: train loss : 0.00109582	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57142857
# Train Epoch: 98: train loss : 0.00188275	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57142857
# Train Epoch: 99: train loss : 0.00177514	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57142857
# Train Epoch: 100: train loss : 0.00208996	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57142857
# Train Epoch: 101: train loss : 0.00192926	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57142857
# Train Epoch: 102: train loss : 0.00161014	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57142857
# Train Epoch: 103: train loss : 0.00150095	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57142857
# Train Epoch: 104: train loss : 0.00165519	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57142857
# Train Epoch: 105: train loss : 0.00195250	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57142857
# Train Epoch: 106: train loss : 0.00317292	 train accuracy : 0.99808061	 val accuracy : 0.57485030	 test accuracy : 0.57142857
# Train Epoch: 107: train loss : 0.00243666	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57142857
# Train Epoch: 108: train loss : 0.00147798	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 109: train loss : 0.00113549	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 110: train loss : 0.00076012	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 111: train loss : 0.00144825	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 112: train loss : 0.00142572	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 113: train loss : 0.00179636	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 114: train loss : 0.00130225	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 115: train loss : 0.00154506	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 116: train loss : 0.00123483	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 117: train loss : 0.00109533	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 118: train loss : 0.00105379	 train accuracy : 1.00000000	 val accuracy : 0.56287425	 test accuracy : 0.57142857
# Train Epoch: 119: train loss : 0.00166407	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 120: train loss : 0.00190549	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 121: train loss : 0.00191196	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57142857
# Train Epoch: 122: train loss : 0.00114240	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57142857
# Train Epoch: 123: train loss : 0.00190658	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57142857
# Train Epoch: 124: train loss : 0.00105284	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 125: train loss : 0.00062783	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 126: train loss : 0.00100381	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 127: train loss : 0.00126386	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 128: train loss : 0.00066349	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 129: train loss : 0.00123501	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 130: train loss : 0.00106294	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 131: train loss : 0.00087425	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 132: train loss : 0.00157316	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 133: train loss : 0.00081653	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57692308
# Train Epoch: 134: train loss : 0.00151738	 train accuracy : 1.00000000	 val accuracy : 0.56287425	 test accuracy : 0.57692308
# Train Epoch: 135: train loss : 0.00109607	 train accuracy : 1.00000000	 val accuracy : 0.56287425	 test accuracy : 0.57692308
# Train Epoch: 136: train loss : 0.00126602	 train accuracy : 1.00000000	 val accuracy : 0.56287425	 test accuracy : 0.57692308
# Train Epoch: 137: train loss : 0.00101116	 train accuracy : 1.00000000	 val accuracy : 0.56287425	 test accuracy : 0.57692308
# Train Epoch: 138: train loss : 0.00086523	 train accuracy : 1.00000000	 val accuracy : 0.56287425	 test accuracy : 0.57692308
# Train Epoch: 139: train loss : 0.00197579	 train accuracy : 1.00000000	 val accuracy : 0.56287425	 test accuracy : 0.57692308
# Train Epoch: 140: train loss : 0.00157538	 train accuracy : 1.00000000	 val accuracy : 0.56287425	 test accuracy : 0.57692308
# Train Epoch: 141: train loss : 0.00118295	 train accuracy : 1.00000000	 val accuracy : 0.56287425	 test accuracy : 0.57142857
# Train Epoch: 142: train loss : 0.00125856	 train accuracy : 1.00000000	 val accuracy : 0.56287425	 test accuracy : 0.57142857
# Train Epoch: 143: train loss : 0.00118596	 train accuracy : 1.00000000	 val accuracy : 0.56287425	 test accuracy : 0.57142857
# Train Epoch: 144: train loss : 0.00080598	 train accuracy : 1.00000000	 val accuracy : 0.56287425	 test accuracy : 0.57142857
# Train Epoch: 145: train loss : 0.00163825	 train accuracy : 1.00000000	 val accuracy : 0.56287425	 test accuracy : 0.57142857
# Train Epoch: 146: train loss : 0.00083879	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 147: train loss : 0.00156492	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 148: train loss : 0.00102486	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 149: train loss : 0.00155576	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 150: train loss : 0.00106714	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 151: train loss : 0.00086021	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57692308
# Train Epoch: 152: train loss : 0.00063132	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57692308
# Train Epoch: 153: train loss : 0.00124573	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57692308
# Train Epoch: 154: train loss : 0.00121734	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57692308
# Train Epoch: 155: train loss : 0.00094756	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57692308
# Train Epoch: 156: train loss : 0.00089255	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57692308
# Train Epoch: 157: train loss : 0.00135111	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57692308
# Train Epoch: 158: train loss : 0.00115390	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57692308
# Train Epoch: 159: train loss : 0.00086016	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57692308
# Train Epoch: 160: train loss : 0.00153654	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57692308
# Train Epoch: 161: train loss : 0.00115501	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57692308
# Train Epoch: 162: train loss : 0.00071930	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57692308
# Train Epoch: 163: train loss : 0.00122831	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57692308
# Train Epoch: 164: train loss : 0.00057549	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57692308
# Train Epoch: 165: train loss : 0.00058910	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57692308
# Train Epoch: 166: train loss : 0.00096387	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57142857
# Train Epoch: 167: train loss : 0.00078599	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57142857
# Train Epoch: 168: train loss : 0.00150217	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57692308
# Train Epoch: 169: train loss : 0.00100803	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57692308
# Train Epoch: 170: train loss : 0.00061188	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57692308
# Train Epoch: 171: train loss : 0.00088263	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57692308
# Train Epoch: 172: train loss : 0.00088375	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57692308
# Train Epoch: 173: train loss : 0.00086156	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57692308
# Train Epoch: 174: train loss : 0.00052349	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57692308
# Train Epoch: 175: train loss : 0.00046866	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57692308
# Train Epoch: 176: train loss : 0.00114415	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57692308
# Train Epoch: 177: train loss : 0.00073000	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57692308
# Train Epoch: 178: train loss : 0.00168263	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57692308
# Train Epoch: 179: train loss : 0.00139989	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57692308
# Train Epoch: 180: train loss : 0.00086564	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57692308
# Train Epoch: 181: train loss : 0.00068845	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57692308
# Train Epoch: 182: train loss : 0.00071009	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57692308
# Train Epoch: 183: train loss : 0.00076262	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.58241758
# Train Epoch: 184: train loss : 0.00142447	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57692308
# Train Epoch: 185: train loss : 0.00089909	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57692308
# Train Epoch: 186: train loss : 0.00061578	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57692308
# Train Epoch: 187: train loss : 0.00206188	 train accuracy : 0.99808061	 val accuracy : 0.57485030	 test accuracy : 0.57692308
# Train Epoch: 188: train loss : 0.00057191	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.58241758
# Train Epoch: 189: train loss : 0.00063097	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.58241758
# Train Epoch: 190: train loss : 0.00068680	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.58241758
# Train Epoch: 191: train loss : 0.00125119	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57692308
# Train Epoch: 192: train loss : 0.00040083	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57692308
# Train Epoch: 193: train loss : 0.00047810	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57692308
# Train Epoch: 194: train loss : 0.00092498	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57692308
# Train Epoch: 195: train loss : 0.00049909	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57692308
# Train Epoch: 196: train loss : 0.00052960	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.58241758
# Train Epoch: 197: train loss : 0.00088759	 train accuracy : 1.00000000	 val accuracy : 0.56287425	 test accuracy : 0.58241758
# Train Epoch: 198: train loss : 0.00188307	 train accuracy : 0.99808061	 val accuracy : 0.56287425	 test accuracy : 0.58241758
# Train Epoch: 199: train loss : 0.00247777	 train accuracy : 0.99808061	 val accuracy : 0.56886228	 test accuracy : 0.57692308
# Train Epoch: 200: train loss : 0.00034511	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57692308
# In fold  5
# The best validaiton accuracy is:  0.6347305389221557
# Happened at epoch:  18
# The corresponding test accuracy 0.5824175824175825
# The corresponding test AUC is:  0.6184593023255814
# Finish 5-fold training

# %%
val_accuracy = metrics.accuracy_score(all_fold_val_label, all_fold_val_out)
test_accuracy = metrics.accuracy_score(all_fold_test_label, all_fold_test_out)
test_fpr, test_tpr, te_thresholds = roc_curve(all_fold_test_label, all_fold_test_prob[:,1],pos_label=1)
test_auc = auc(test_fpr, test_tpr)
print('The best validation accuracy is ',val_accuracy)
print('The corresponding test accuracy is ',test_accuracy)
print('The corresponding test AUC is: ',test_auc)
plt.grid()
plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
plt.plot([0,1],[0,1],'g--')
plt.legend()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Test AUC(ROC curve)")
plt.grid(color='black', linestyle='-', linewidth=0.5)
plt.show()
# Out:
# The best validation accuracy is  0.6459770114942529
# The corresponding test accuracy is  0.6091954022988506
# The corresponding test AUC is:  0.6542951418961642

# %%
torch.cuda.empty_cache()
torch.manual_seed(args.seed)
if args.cuda:
    torch.cuda.manual_seed(args.seed)
############################################### Max voting ###############################################################
############################################### Max voting ###############################################################
############################################### Max voting ###############################################################
dist_ensemble_val_label = {}
dist_ensemble_val_result = {}
dist_ensemble_test_label = {}
dist_ensemble_test_result = {}
dist_ensemble_test_prob = {}

for ensemble_fold in range(5):
  print('Ensemble ',ensemble_fold+1)
  save_ensemble_models_path = save_path + 'Max_voting/FCN/'
  dist_train = {}
  dist_validation = {}
  dist_test = {}
  for i in range(k_fold):
    dist_train[str(i + 1)] = []
    dist_validation[str(i + 1)] = []
    dist_test[str(i + 1)] = []
  test_name = {}
  for i in range(len(unique_sites)):
    test_name[unique_sites[i]] = []
  for each_site in unique_sites:
    index_site = get_index(sites, each_site)
    label = np.zeros((len(index_site)))
    for i in range(len(index_site)):
      index = index_site[i]
      label[i] = int(labels[int(index)])
    test_name_list = test_name[each_site]
    ########################################### StratifiedKFold ####################################################
    sfolder = StratifiedKFold(n_splits=k_fold,random_state=0,shuffle=True)
    group = 0
    for train, validation in sfolder.split(index_site,label):
      if group == ensemble_fold:
        for j in validation:
          name = index_site[j]
          dist_test['1'].append(name)
          dist_test['2'].append(name)
          dist_test['3'].append(name)
          dist_test['4'].append(name)
          dist_test['5'].append(name)
          test_name_list.append(name)
      group = group + 1
    test_name[each_site] = test_name_list

  for each_site in unique_sites:
    if ensemble_fold == 0:

      index_site = get_index(sites, each_site)
      label = np.zeros((len(index_site)))
      for i in range(len(index_site)):
        index = index_site[i]
        label[i] = int(labels[int(index)])
      test_name_list = test_name[each_site]
      index_site_new = []
      label_new = np.zeros((len(index_site) - len(test_name_list)))
      position = 0
      for x in range(len(index_site)):
        sample_name = index_site[x]
        if sample_name in test_name_list:
          c=0
        else:
          index_site_new.append(sample_name)
          label_new[position] = label[x]
          position = position + 1
      if each_site == 'CMU':  # ONLY 4 AUTISM SAMPLES AND 4 TD SAMPLES, CAN NOT BE DEVIDED INTO 5 GROUPS
        group_autism_val = []
        group_autism_train = []
        group_TD_val = []
        group_TD_train = []
        autism_validation_number = len(label_new[label_new ==1])/4
        TD_validation_number = len(label_new[label_new ==0]) / 4
        for j in range(len(label_new)):
          if label_new[j] == 1:
            if len(group_autism_val)<autism_validation_number:
              group_autism_val.append(index_site_new[j])
            else:
              group_autism_train.append(index_site_new[j])
          else:
            if len(group_TD_val)<TD_validation_number:
              group_TD_val.append(index_site_new[j])
            else:
              group_TD_train.append(index_site_new[j])

        dist_validation['1'] = dist_validation['1'] + group_autism_val + group_TD_val
        dist_validation['2'] = dist_validation['2'] + group_autism_val + group_TD_val
        dist_validation['3'] = dist_validation['3'] + group_autism_val + group_TD_val
        dist_validation['4'] = dist_validation['4'] + group_autism_val + group_TD_val
        dist_validation['5'] = dist_validation['5'] + group_autism_val + group_TD_val
        dist_train['1'] = dist_train['1'] + group_autism_train + group_TD_train
        dist_train['2'] = dist_train['2'] + group_autism_train + group_TD_train
        dist_train['3'] = dist_train['3'] + group_autism_train + group_TD_train
        dist_train['4'] = dist_train['4'] + group_autism_train + group_TD_train
        dist_train['5'] = dist_train['5'] + group_autism_train + group_TD_train
      else:
        ########################################### StratifiedKFold ####################################################
        sfolder = StratifiedKFold(n_splits=k_fold, random_state=0, shuffle=True)
        group = 0
        for train, validation in sfolder.split(index_site_new, label_new):

          for i in train:
            name = index_site_new[i]
            dist_train[str(group + 1)].append(name)
          for j in validation:
            name = index_site_new[j]
            dist_validation[str(group + 1)].append(name)
          group = group + 1
    else:

      index_site = get_index(sites, each_site)
      label = np.zeros((len(index_site)))
      for i in range(len(index_site)):
        index = index_site[i]
        label[i] = int(labels[int(index)])
      test_name_list = test_name[each_site]
      index_site_new = []
      label_new = np.zeros((len(index_site) - len(test_name_list)))
      position = 0
      for x in range(len(index_site)):
        sample_name = index_site[x]
        if sample_name in test_name_list:
          c=0
        else:
          index_site_new.append(sample_name)
          label_new[position] = label[x]
          position = position + 1
      ########################################### StratifiedKFold ####################################################
      sfolder = StratifiedKFold(n_splits=k_fold,random_state=0,shuffle=True)
      group = 0
      for train, validation in sfolder.split(index_site_new,label_new):

        for i in train:
          name = index_site_new[i]
          dist_train[str(group + 1)].append(name)
        for j in validation:
          name = index_site_new[j]
          dist_validation[str(group + 1)].append(name)
        group = group+1
  
  
  data = {}
  for fold in range(1, k_fold+1):
    data[str(fold)] = []
    selector = feature_selection(sMRI_features, labels, dist_train[str(fold)], new_number_features)
    fold_data = selector.transform(sMRI_features)

    data[str(fold)].append(fold_data)
    data[str(fold)].append(FCN_labels)

  ############################################### Train ###############################################################
  ############################################### Train ###############################################################
  ############################################### Train ###############################################################

  model_1 = FCN(input_c=args.input_c, hid_1=args.hid_1, hid_2=args.hid_2, out_c=args.out_c, dropout=args.dropout_rate)
  model_2 = FCN(input_c=args.input_c, hid_1=args.hid_1, hid_2=args.hid_2, out_c=args.out_c, dropout=args.dropout_rate)
  model_3 = FCN(input_c=args.input_c, hid_1=args.hid_1, hid_2=args.hid_2, out_c=args.out_c, dropout=args.dropout_rate)
  model_4 = FCN(input_c=args.input_c, hid_1=args.hid_1, hid_2=args.hid_2, out_c=args.out_c, dropout=args.dropout_rate)
  model_5 = FCN(input_c=args.input_c, hid_1=args.hid_1, hid_2=args.hid_2, out_c=args.out_c, dropout=args.dropout_rate)

  gpu_ids = range(args.ngpu)
  model_1 = nn.parallel.DataParallel(model_1, device_ids=gpu_ids)
  model_2 = nn.parallel.DataParallel(model_2, device_ids=gpu_ids)
  model_3 = nn.parallel.DataParallel(model_3, device_ids=gpu_ids)
  model_4 = nn.parallel.DataParallel(model_4, device_ids=gpu_ids)
  model_5 = nn.parallel.DataParallel(model_5, device_ids=gpu_ids)
  train = train_FCN

  print('  + Number of params: {}'.format(
      sum([p.data.nelement() for p in model_1.parameters()])))
  if args.cuda:
      model_1 = model_1.cuda()
      model_2 = model_2.cuda()
      model_3 = model_3.cuda()
      model_4 = model_4.cuda()
      model_5 = model_5.cuda()

  optimizer_1 = optim.Adam(model_1.parameters(), lr = args.lr)
  optimizer_2 = optim.Adam(model_2.parameters(), lr = args.lr)
  optimizer_3 = optim.Adam(model_3.parameters(), lr = args.lr)
  optimizer_4 = optim.Adam(model_4.parameters(), lr = args.lr)
  optimizer_5 = optim.Adam(model_5.parameters(), lr = args.lr)

  Train_accuracy_list =[]
  Train_loss_list = []
  Val_accuracy_list =[]
  Val_loss_list = []
  Test_accuracy_list =[]
  Test_loss_list = []
  best_validation_accuracy = 0

  for epoch in range(1, args.nEpochs + 1):


    model_1, train_target_1, train_out_1, train_loss_1, val_target_1, val_out_1, val_loss_1, test_target_1, test_out_1, test_prob_1, test_loss_1 = train(args, model_1, data['1'], dist_train['1'], dist_validation['1'], dist_test['1'], optimizer_1)
    model_2, train_target_2, train_out_2, train_loss_2, val_target_2, val_out_2, val_loss_2, test_target_2, test_out_2, test_prob_2, test_loss_2 = train(args, model_2, data['2'], dist_train['2'], dist_validation['2'], dist_test['2'], optimizer_2)
    model_3, train_target_3, train_out_3, train_loss_3, val_target_3, val_out_3, val_loss_3, test_target_3, test_out_3, test_prob_3, test_loss_3 = train(args, model_3, data['3'], dist_train['3'], dist_validation['3'], dist_test['3'], optimizer_3)
    model_4, train_target_4, train_out_4, train_loss_4, val_target_4, val_out_4, val_loss_4, test_target_4, test_out_4, test_prob_4, test_loss_4 = train(args, model_4, data['4'], dist_train['4'], dist_validation['4'], dist_test['4'], optimizer_4)
    model_5, train_target_5, train_out_5, train_loss_5, val_target_5, val_out_5, val_loss_5, test_target_5, test_out_5, test_prob_5, test_loss_5 = train(args, model_5, data['5'], dist_train['5'], dist_validation['5'], dist_test['5'], optimizer_5)

    train_target_all = np.concatenate((train_target_1, train_target_2, train_target_3, train_target_4, train_target_5),axis = 0)
    train_out_all = np.concatenate((train_out_1, train_out_2, train_out_3, train_out_4, train_out_5),axis = 0)
    train_loss = (train_loss_1 + train_loss_2 + train_loss_3 + train_loss_4 + train_loss_5)/5
    val_target_all = np.concatenate((val_target_1, val_target_2, val_target_3, val_target_4, val_target_5),axis = 0)
    val_out_all = np.concatenate((val_out_1, val_out_2, val_out_3, val_out_4, val_out_5),axis = 0)
    val_loss = (val_loss_1 + val_loss_2 + val_loss_3 + val_loss_4 + val_loss_5)/5
    test_target_all = test_target_1 # test_target_1 = test_target_2 = test_target_3 = test_target_4 = test_target_5
    test_out_all = test_out_1 + test_out_2 + test_out_3 + test_out_4 + test_out_5
    test_prob_all = (test_prob_1 + test_prob_2 + test_prob_3 + test_prob_4 + test_prob_5)/5
    test_loss = (test_loss_1 + test_loss_2 + test_loss_3 + test_loss_4 + test_loss_5)/5

    test_results_binary = np.zeros_like((test_out_all))
    test_results_binary[test_out_all<2.5] = 0
    test_results_binary[test_out_all>=2.5] = 1

    train_accuracy = metrics.accuracy_score(train_target_all, train_out_all)
    val_accuracy = metrics.accuracy_score(val_target_all, val_out_all)
    test_accuracy = metrics.accuracy_score(test_target_all, test_results_binary)
    Train_accuracy_list.append(train_accuracy)
    Val_accuracy_list.append(val_accuracy)
    Test_accuracy_list.append(test_accuracy)
    Train_loss_list.append(train_loss)
    Val_loss_list.append(val_loss)
    Test_loss_list.append(test_loss)

    if val_accuracy >=best_validation_accuracy:
      best_epoch = epoch
      best_validation_accuracy = val_accuracy
      corresponding_test_accuracy = test_accuracy
      corresponding_test_prob = test_prob_all
      corresponding_test_labels = test_target_all
      corresponding_test_out = test_results_binary
      print('Save models')

      save_model(model_1, save_ensemble_models_path, 'FCN_ensemble' + str(ensemble_fold) + '_1')
      save_model(model_2, save_ensemble_models_path, 'FCN_ensemble' + str(ensemble_fold) + '_2')
      save_model(model_3, save_ensemble_models_path, 'FCN_ensemble' + str(ensemble_fold) + '_3')
      save_model(model_4, save_ensemble_models_path, 'FCN_ensemble' + str(ensemble_fold) + '_4')
      save_model(model_5, save_ensemble_models_path, 'FCN_ensemble' + str(ensemble_fold) + '_5')

    print('Train Epoch: ' + str(epoch) + ': train loss : {:.8f}\t train accuracy : {:.8f}\t val accuracy : {:.8f}\t test accuracy : {:.8f}\t'.format(
      train_loss, train_accuracy, val_accuracy, test_accuracy))

  x_axis = list(range(1, len(Train_accuracy_list)+1))
  plt.figure(figsize=(15,10))
  plt.plot(x_axis, Train_loss_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_loss_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_loss_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()

  plt.figure(figsize=(15,10))
  plt.plot(x_axis, Train_accuracy_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_accuracy_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_accuracy_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()
 
  test_fpr, test_tpr, te_thresholds = roc_curve(corresponding_test_labels, corresponding_test_prob[:,1],pos_label=1)
  test_auc = auc(test_fpr, test_tpr)
  print('\n')
  print('In ensemble ',ensemble_fold+1)
  print('The best validaiton accuracy is: ',best_validation_accuracy)
  print('Happened at epoch: ',best_epoch)
  print('The corresponding test accuracy', corresponding_test_accuracy)
  print('The corresponding test AUC is: ',test_auc)
  print('\n')


  plt.grid()
  plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
  plt.plot([0,1],[0,1],'g--')
  plt.legend()
  plt.xlabel("False Positive Rate")
  plt.ylabel("True Positive Rate")
  plt.title("Test AUC(ROC curve)")
  plt.grid(color='black', linestyle='-', linewidth=0.5)
  plt.show()


  dist_ensemble_test_label[str(ensemble_fold+1)] = corresponding_test_labels
  dist_ensemble_test_result[str(ensemble_fold+1)] = corresponding_test_out
  dist_ensemble_test_prob[str(ensemble_fold+1)] = corresponding_test_prob
  print('\n')

  torch.cuda.empty_cache()

test_labels_concat = np.concatenate((dist_ensemble_test_label['1'], dist_ensemble_test_label['2'],  dist_ensemble_test_label['3'], dist_ensemble_test_label['4'], dist_ensemble_test_label['5']),axis = 0)
test_results_concat = np.concatenate((dist_ensemble_test_result['1'], dist_ensemble_test_result['2'],  dist_ensemble_test_result['3'], dist_ensemble_test_result['4'], dist_ensemble_test_result['5']),axis = 0)
test_probs_concat = np.concatenate((dist_ensemble_test_prob['1'], dist_ensemble_test_prob['2'],  dist_ensemble_test_prob['3'], dist_ensemble_test_prob['4'], dist_ensemble_test_prob['5']),axis = 0)

test_accuracy = metrics.accuracy_score(test_labels_concat, test_results_concat)
test_fpr, test_tpr, te_thresholds = roc_curve(test_labels_concat, test_probs_concat[:,1],pos_label=1)
test_auc = auc(test_fpr, test_tpr)
print('The Max voting test accuracy is: ',test_accuracy)
print('The test AUC is: ',test_auc)

print('\n')
print('\n')
plt.grid()
plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
plt.plot([0,1],[0,1],'g--')
plt.legend()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Test AUC(ROC curve)")
plt.grid(color='black', linestyle='-', linewidth=0.5)
plt.show()
# Out:
# Ensemble  1
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
#   + Number of params: 734092
# Save models
# Train Epoch: 1: train loss : 0.71575521	 train accuracy : 0.49381818	 val accuracy : 0.55942029	 test accuracy : 0.57692308
# Save models
# Train Epoch: 2: train loss : 0.66575987	 train accuracy : 0.59927273	 val accuracy : 0.56811594	 test accuracy : 0.56593407
# Save models
# Train Epoch: 3: train loss : 0.63801879	 train accuracy : 0.64254545	 val accuracy : 0.58985507	 test accuracy : 0.57142857
# Train Epoch: 4: train loss : 0.60434161	 train accuracy : 0.70290909	 val accuracy : 0.58405797	 test accuracy : 0.59340659
# Save models
# Train Epoch: 5: train loss : 0.58304352	 train accuracy : 0.71272727	 val accuracy : 0.59420290	 test accuracy : 0.59890110
# Train Epoch: 6: train loss : 0.55100067	 train accuracy : 0.75018182	 val accuracy : 0.58985507	 test accuracy : 0.60439560
# Save models
# Train Epoch: 7: train loss : 0.53721756	 train accuracy : 0.75781818	 val accuracy : 0.60289855	 test accuracy : 0.62087912
# Save models
# Train Epoch: 8: train loss : 0.50292912	 train accuracy : 0.80181818	 val accuracy : 0.61449275	 test accuracy : 0.61538462
# Train Epoch: 9: train loss : 0.47254294	 train accuracy : 0.84109091	 val accuracy : 0.61014493	 test accuracy : 0.62087912
# Save models
# Train Epoch: 10: train loss : 0.46301368	 train accuracy : 0.83490909	 val accuracy : 0.61449275	 test accuracy : 0.62637363
# Train Epoch: 11: train loss : 0.42740478	 train accuracy : 0.85745455	 val accuracy : 0.60289855	 test accuracy : 0.61538462
# Train Epoch: 12: train loss : 0.40150902	 train accuracy : 0.88072727	 val accuracy : 0.60144928	 test accuracy : 0.61538462
# Train Epoch: 13: train loss : 0.37311423	 train accuracy : 0.89018182	 val accuracy : 0.60000000	 test accuracy : 0.61538462
# Train Epoch: 14: train loss : 0.34557365	 train accuracy : 0.90363636	 val accuracy : 0.60289855	 test accuracy : 0.61538462
# Train Epoch: 15: train loss : 0.32017396	 train accuracy : 0.91818182	 val accuracy : 0.60434783	 test accuracy : 0.60989011
# Train Epoch: 16: train loss : 0.29149258	 train accuracy : 0.93418182	 val accuracy : 0.60434783	 test accuracy : 0.61538462
# Train Epoch: 17: train loss : 0.26614308	 train accuracy : 0.94036364	 val accuracy : 0.60289855	 test accuracy : 0.61538462
# Train Epoch: 18: train loss : 0.24453239	 train accuracy : 0.95018182	 val accuracy : 0.60289855	 test accuracy : 0.62087912
# Train Epoch: 19: train loss : 0.21266835	 train accuracy : 0.96545455	 val accuracy : 0.61159420	 test accuracy : 0.60989011
# Train Epoch: 20: train loss : 0.18986108	 train accuracy : 0.97636364	 val accuracy : 0.61014493	 test accuracy : 0.59890110
# Train Epoch: 21: train loss : 0.16641149	 train accuracy : 0.97854545	 val accuracy : 0.61159420	 test accuracy : 0.60989011
# Train Epoch: 22: train loss : 0.15364250	 train accuracy : 0.98290909	 val accuracy : 0.60724638	 test accuracy : 0.61538462
# Train Epoch: 23: train loss : 0.13050751	 train accuracy : 0.98690909	 val accuracy : 0.60724638	 test accuracy : 0.60989011
# Train Epoch: 24: train loss : 0.11833051	 train accuracy : 0.98763636	 val accuracy : 0.60869565	 test accuracy : 0.60989011
# Train Epoch: 25: train loss : 0.10848115	 train accuracy : 0.98800000	 val accuracy : 0.60144928	 test accuracy : 0.60989011
# Train Epoch: 26: train loss : 0.09063220	 train accuracy : 0.99381818	 val accuracy : 0.60000000	 test accuracy : 0.62637363
# Train Epoch: 27: train loss : 0.08147246	 train accuracy : 0.99454545	 val accuracy : 0.60289855	 test accuracy : 0.62087912
# Train Epoch: 28: train loss : 0.07100961	 train accuracy : 0.99600000	 val accuracy : 0.59565217	 test accuracy : 0.63186813
# Train Epoch: 29: train loss : 0.06350940	 train accuracy : 0.99490909	 val accuracy : 0.60579710	 test accuracy : 0.63186813
# Train Epoch: 30: train loss : 0.05193806	 train accuracy : 0.99890909	 val accuracy : 0.61014493	 test accuracy : 0.63186813
# Save models
# Train Epoch: 31: train loss : 0.04685402	 train accuracy : 0.99781818	 val accuracy : 0.61739130	 test accuracy : 0.63186813
# Train Epoch: 32: train loss : 0.04014035	 train accuracy : 0.99927273	 val accuracy : 0.61594203	 test accuracy : 0.63736264
# Save models
# Train Epoch: 33: train loss : 0.03763268	 train accuracy : 0.99963636	 val accuracy : 0.61739130	 test accuracy : 0.62637363
# Train Epoch: 34: train loss : 0.03066872	 train accuracy : 0.99963636	 val accuracy : 0.61304348	 test accuracy : 0.62087912
# Train Epoch: 35: train loss : 0.02880926	 train accuracy : 0.99963636	 val accuracy : 0.61014493	 test accuracy : 0.62637363
# Train Epoch: 36: train loss : 0.02536388	 train accuracy : 0.99927273	 val accuracy : 0.61159420	 test accuracy : 0.62087912
# Train Epoch: 37: train loss : 0.02026611	 train accuracy : 0.99963636	 val accuracy : 0.60869565	 test accuracy : 0.60989011
# Train Epoch: 38: train loss : 0.02045621	 train accuracy : 1.00000000	 val accuracy : 0.61014493	 test accuracy : 0.60989011
# Train Epoch: 39: train loss : 0.01778401	 train accuracy : 0.99927273	 val accuracy : 0.60579710	 test accuracy : 0.59890110
# Train Epoch: 40: train loss : 0.01716711	 train accuracy : 1.00000000	 val accuracy : 0.61304348	 test accuracy : 0.59340659
# Train Epoch: 41: train loss : 0.01464000	 train accuracy : 1.00000000	 val accuracy : 0.61449275	 test accuracy : 0.60439560
# Train Epoch: 42: train loss : 0.01422675	 train accuracy : 1.00000000	 val accuracy : 0.61594203	 test accuracy : 0.59890110
# Train Epoch: 43: train loss : 0.01385239	 train accuracy : 0.99927273	 val accuracy : 0.60724638	 test accuracy : 0.60439560
# Train Epoch: 44: train loss : 0.01133668	 train accuracy : 0.99963636	 val accuracy : 0.60579710	 test accuracy : 0.60439560
# Train Epoch: 45: train loss : 0.01118683	 train accuracy : 0.99963636	 val accuracy : 0.60579710	 test accuracy : 0.60989011
# Train Epoch: 46: train loss : 0.01122426	 train accuracy : 0.99963636	 val accuracy : 0.60724638	 test accuracy : 0.60439560
# Train Epoch: 47: train loss : 0.00945828	 train accuracy : 1.00000000	 val accuracy : 0.60724638	 test accuracy : 0.60439560
# Train Epoch: 48: train loss : 0.00979008	 train accuracy : 1.00000000	 val accuracy : 0.60869565	 test accuracy : 0.60439560
# Train Epoch: 49: train loss : 0.00865618	 train accuracy : 0.99963636	 val accuracy : 0.60869565	 test accuracy : 0.60439560
# Train Epoch: 50: train loss : 0.00802942	 train accuracy : 1.00000000	 val accuracy : 0.61014493	 test accuracy : 0.60439560
# Train Epoch: 51: train loss : 0.00684273	 train accuracy : 1.00000000	 val accuracy : 0.61014493	 test accuracy : 0.60439560
# Train Epoch: 52: train loss : 0.00773813	 train accuracy : 1.00000000	 val accuracy : 0.60724638	 test accuracy : 0.62087912
# Train Epoch: 53: train loss : 0.00715428	 train accuracy : 1.00000000	 val accuracy : 0.61159420	 test accuracy : 0.60989011
# Train Epoch: 54: train loss : 0.00782467	 train accuracy : 1.00000000	 val accuracy : 0.61159420	 test accuracy : 0.60989011
# Train Epoch: 55: train loss : 0.00609527	 train accuracy : 1.00000000	 val accuracy : 0.61159420	 test accuracy : 0.60989011
# Train Epoch: 56: train loss : 0.00570120	 train accuracy : 1.00000000	 val accuracy : 0.61304348	 test accuracy : 0.60989011
# Train Epoch: 57: train loss : 0.00638586	 train accuracy : 1.00000000	 val accuracy : 0.60724638	 test accuracy : 0.60989011
# Train Epoch: 58: train loss : 0.00540857	 train accuracy : 1.00000000	 val accuracy : 0.60289855	 test accuracy : 0.60989011
# Train Epoch: 59: train loss : 0.00516768	 train accuracy : 1.00000000	 val accuracy : 0.60144928	 test accuracy : 0.60989011
# Train Epoch: 60: train loss : 0.00484067	 train accuracy : 1.00000000	 val accuracy : 0.60289855	 test accuracy : 0.60989011
# Train Epoch: 61: train loss : 0.00491569	 train accuracy : 1.00000000	 val accuracy : 0.60144928	 test accuracy : 0.62087912
# Train Epoch: 62: train loss : 0.00395417	 train accuracy : 1.00000000	 val accuracy : 0.60289855	 test accuracy : 0.62087912
# Train Epoch: 63: train loss : 0.00416454	 train accuracy : 1.00000000	 val accuracy : 0.60144928	 test accuracy : 0.62087912
# Train Epoch: 64: train loss : 0.00419785	 train accuracy : 1.00000000	 val accuracy : 0.60144928	 test accuracy : 0.62087912
# Train Epoch: 65: train loss : 0.00357505	 train accuracy : 1.00000000	 val accuracy : 0.60144928	 test accuracy : 0.62087912
# Train Epoch: 66: train loss : 0.00378101	 train accuracy : 1.00000000	 val accuracy : 0.60289855	 test accuracy : 0.62087912
# Train Epoch: 67: train loss : 0.00420442	 train accuracy : 1.00000000	 val accuracy : 0.60144928	 test accuracy : 0.61538462
# Train Epoch: 68: train loss : 0.00344503	 train accuracy : 1.00000000	 val accuracy : 0.60289855	 test accuracy : 0.61538462
# Train Epoch: 69: train loss : 0.00353621	 train accuracy : 1.00000000	 val accuracy : 0.60000000	 test accuracy : 0.60989011
# Train Epoch: 70: train loss : 0.00349072	 train accuracy : 1.00000000	 val accuracy : 0.60289855	 test accuracy : 0.60439560
# Train Epoch: 71: train loss : 0.00333145	 train accuracy : 1.00000000	 val accuracy : 0.60434783	 test accuracy : 0.60439560
# Train Epoch: 72: train loss : 0.00318636	 train accuracy : 0.99963636	 val accuracy : 0.60144928	 test accuracy : 0.59890110
# Train Epoch: 73: train loss : 0.00324711	 train accuracy : 0.99963636	 val accuracy : 0.59855072	 test accuracy : 0.59890110
# Train Epoch: 74: train loss : 0.00382327	 train accuracy : 1.00000000	 val accuracy : 0.59420290	 test accuracy : 0.59340659
# Train Epoch: 75: train loss : 0.00331588	 train accuracy : 1.00000000	 val accuracy : 0.59710145	 test accuracy : 0.59340659
# Train Epoch: 76: train loss : 0.00311500	 train accuracy : 1.00000000	 val accuracy : 0.59710145	 test accuracy : 0.59340659
# Train Epoch: 77: train loss : 0.00299256	 train accuracy : 1.00000000	 val accuracy : 0.59855072	 test accuracy : 0.59890110
# Train Epoch: 78: train loss : 0.00264614	 train accuracy : 1.00000000	 val accuracy : 0.60434783	 test accuracy : 0.59890110
# Train Epoch: 79: train loss : 0.00246311	 train accuracy : 1.00000000	 val accuracy : 0.60289855	 test accuracy : 0.59890110
# Train Epoch: 80: train loss : 0.00280198	 train accuracy : 1.00000000	 val accuracy : 0.60579710	 test accuracy : 0.59890110
# Train Epoch: 81: train loss : 0.00262146	 train accuracy : 1.00000000	 val accuracy : 0.60869565	 test accuracy : 0.59890110
# Train Epoch: 82: train loss : 0.00251988	 train accuracy : 1.00000000	 val accuracy : 0.61014493	 test accuracy : 0.59890110
# Train Epoch: 83: train loss : 0.00243273	 train accuracy : 1.00000000	 val accuracy : 0.60724638	 test accuracy : 0.59340659
# Train Epoch: 84: train loss : 0.00243146	 train accuracy : 1.00000000	 val accuracy : 0.61159420	 test accuracy : 0.59890110
# Train Epoch: 85: train loss : 0.00234603	 train accuracy : 1.00000000	 val accuracy : 0.60579710	 test accuracy : 0.59890110
# Train Epoch: 86: train loss : 0.00268426	 train accuracy : 1.00000000	 val accuracy : 0.60579710	 test accuracy : 0.60439560
# Train Epoch: 87: train loss : 0.00304802	 train accuracy : 1.00000000	 val accuracy : 0.60434783	 test accuracy : 0.60439560
# Train Epoch: 88: train loss : 0.00263516	 train accuracy : 1.00000000	 val accuracy : 0.60579710	 test accuracy : 0.60439560
# Train Epoch: 89: train loss : 0.00195025	 train accuracy : 1.00000000	 val accuracy : 0.60724638	 test accuracy : 0.60439560
# Train Epoch: 90: train loss : 0.00220618	 train accuracy : 1.00000000	 val accuracy : 0.60724638	 test accuracy : 0.60439560
# Train Epoch: 91: train loss : 0.00200528	 train accuracy : 1.00000000	 val accuracy : 0.60724638	 test accuracy : 0.60989011
# Train Epoch: 92: train loss : 0.00280678	 train accuracy : 0.99963636	 val accuracy : 0.61014493	 test accuracy : 0.60989011
# Train Epoch: 93: train loss : 0.00210797	 train accuracy : 1.00000000	 val accuracy : 0.61014493	 test accuracy : 0.60989011
# Train Epoch: 94: train loss : 0.00230365	 train accuracy : 1.00000000	 val accuracy : 0.61159420	 test accuracy : 0.61538462
# Train Epoch: 95: train loss : 0.00235947	 train accuracy : 1.00000000	 val accuracy : 0.61304348	 test accuracy : 0.62087912
# Train Epoch: 96: train loss : 0.00222642	 train accuracy : 1.00000000	 val accuracy : 0.61304348	 test accuracy : 0.62087912
# Train Epoch: 97: train loss : 0.00212766	 train accuracy : 1.00000000	 val accuracy : 0.61304348	 test accuracy : 0.62087912
# Train Epoch: 98: train loss : 0.00212487	 train accuracy : 1.00000000	 val accuracy : 0.61304348	 test accuracy : 0.62087912
# Train Epoch: 99: train loss : 0.00185787	 train accuracy : 1.00000000	 val accuracy : 0.61304348	 test accuracy : 0.62087912
# Train Epoch: 100: train loss : 0.00187292	 train accuracy : 1.00000000	 val accuracy : 0.61449275	 test accuracy : 0.62087912
# Train Epoch: 101: train loss : 0.00179275	 train accuracy : 1.00000000	 val accuracy : 0.61449275	 test accuracy : 0.62087912
# Train Epoch: 102: train loss : 0.00192265	 train accuracy : 1.00000000	 val accuracy : 0.61449275	 test accuracy : 0.62087912
# Save models
# Train Epoch: 103: train loss : 0.00159879	 train accuracy : 1.00000000	 val accuracy : 0.61739130	 test accuracy : 0.61538462
# Save models
# Train Epoch: 104: train loss : 0.00157901	 train accuracy : 1.00000000	 val accuracy : 0.61884058	 test accuracy : 0.61538462
# Save models
# Train Epoch: 105: train loss : 0.00196451	 train accuracy : 1.00000000	 val accuracy : 0.61884058	 test accuracy : 0.61538462
# Train Epoch: 106: train loss : 0.00247364	 train accuracy : 1.00000000	 val accuracy : 0.61594203	 test accuracy : 0.61538462
# Train Epoch: 107: train loss : 0.00273600	 train accuracy : 0.99890909	 val accuracy : 0.61594203	 test accuracy : 0.61538462
# Train Epoch: 108: train loss : 0.00166297	 train accuracy : 1.00000000	 val accuracy : 0.61739130	 test accuracy : 0.61538462
# Save models
# Train Epoch: 109: train loss : 0.00204926	 train accuracy : 1.00000000	 val accuracy : 0.62028986	 test accuracy : 0.60989011
# Train Epoch: 110: train loss : 0.00164979	 train accuracy : 1.00000000	 val accuracy : 0.61884058	 test accuracy : 0.60439560
# Train Epoch: 111: train loss : 0.00198508	 train accuracy : 1.00000000	 val accuracy : 0.61884058	 test accuracy : 0.60439560
# Train Epoch: 112: train loss : 0.00161688	 train accuracy : 1.00000000	 val accuracy : 0.61739130	 test accuracy : 0.60439560
# Train Epoch: 113: train loss : 0.00164914	 train accuracy : 1.00000000	 val accuracy : 0.61594203	 test accuracy : 0.60989011
# Train Epoch: 114: train loss : 0.00159048	 train accuracy : 1.00000000	 val accuracy : 0.61594203	 test accuracy : 0.61538462
# Train Epoch: 115: train loss : 0.00145828	 train accuracy : 1.00000000	 val accuracy : 0.61304348	 test accuracy : 0.60439560
# Train Epoch: 116: train loss : 0.00158894	 train accuracy : 1.00000000	 val accuracy : 0.61014493	 test accuracy : 0.60439560
# Train Epoch: 117: train loss : 0.00147501	 train accuracy : 1.00000000	 val accuracy : 0.61159420	 test accuracy : 0.60439560
# Train Epoch: 118: train loss : 0.00152930	 train accuracy : 1.00000000	 val accuracy : 0.61159420	 test accuracy : 0.60439560
# Train Epoch: 119: train loss : 0.00175282	 train accuracy : 1.00000000	 val accuracy : 0.61014493	 test accuracy : 0.60989011
# Train Epoch: 120: train loss : 0.00149382	 train accuracy : 1.00000000	 val accuracy : 0.61014493	 test accuracy : 0.60989011
# Train Epoch: 121: train loss : 0.00187175	 train accuracy : 1.00000000	 val accuracy : 0.61014493	 test accuracy : 0.60989011
# Train Epoch: 122: train loss : 0.00186014	 train accuracy : 1.00000000	 val accuracy : 0.61159420	 test accuracy : 0.60989011
# Train Epoch: 123: train loss : 0.00176879	 train accuracy : 1.00000000	 val accuracy : 0.61014493	 test accuracy : 0.60989011
# Train Epoch: 124: train loss : 0.00177542	 train accuracy : 1.00000000	 val accuracy : 0.60869565	 test accuracy : 0.62087912
# Train Epoch: 125: train loss : 0.00162507	 train accuracy : 1.00000000	 val accuracy : 0.61014493	 test accuracy : 0.62087912
# Train Epoch: 126: train loss : 0.00126569	 train accuracy : 1.00000000	 val accuracy : 0.60869565	 test accuracy : 0.62087912
# Train Epoch: 127: train loss : 0.00116128	 train accuracy : 1.00000000	 val accuracy : 0.60579710	 test accuracy : 0.61538462
# Train Epoch: 128: train loss : 0.00147287	 train accuracy : 1.00000000	 val accuracy : 0.60724638	 test accuracy : 0.60989011
# Train Epoch: 129: train loss : 0.00134362	 train accuracy : 1.00000000	 val accuracy : 0.60869565	 test accuracy : 0.60989011
# Train Epoch: 130: train loss : 0.00164201	 train accuracy : 1.00000000	 val accuracy : 0.60869565	 test accuracy : 0.61538462
# Train Epoch: 131: train loss : 0.00160244	 train accuracy : 1.00000000	 val accuracy : 0.60869565	 test accuracy : 0.61538462
# Train Epoch: 132: train loss : 0.00185069	 train accuracy : 1.00000000	 val accuracy : 0.60724638	 test accuracy : 0.61538462
# Train Epoch: 133: train loss : 0.00146481	 train accuracy : 1.00000000	 val accuracy : 0.60724638	 test accuracy : 0.62087912
# Train Epoch: 134: train loss : 0.00165986	 train accuracy : 1.00000000	 val accuracy : 0.60289855	 test accuracy : 0.62087912
# Train Epoch: 135: train loss : 0.00116677	 train accuracy : 1.00000000	 val accuracy : 0.60434783	 test accuracy : 0.62087912
# Train Epoch: 136: train loss : 0.00146402	 train accuracy : 1.00000000	 val accuracy : 0.60289855	 test accuracy : 0.62087912
# Train Epoch: 137: train loss : 0.00119674	 train accuracy : 1.00000000	 val accuracy : 0.60434783	 test accuracy : 0.62087912
# Train Epoch: 138: train loss : 0.00140474	 train accuracy : 1.00000000	 val accuracy : 0.60289855	 test accuracy : 0.62087912
# Train Epoch: 139: train loss : 0.00175963	 train accuracy : 1.00000000	 val accuracy : 0.60144928	 test accuracy : 0.62087912
# Train Epoch: 140: train loss : 0.00174971	 train accuracy : 1.00000000	 val accuracy : 0.60000000	 test accuracy : 0.62087912
# Train Epoch: 141: train loss : 0.00143851	 train accuracy : 1.00000000	 val accuracy : 0.60144928	 test accuracy : 0.62087912
# Train Epoch: 142: train loss : 0.00146790	 train accuracy : 1.00000000	 val accuracy : 0.60144928	 test accuracy : 0.62087912
# Train Epoch: 143: train loss : 0.00159994	 train accuracy : 1.00000000	 val accuracy : 0.59855072	 test accuracy : 0.62087912
# Train Epoch: 144: train loss : 0.00112080	 train accuracy : 1.00000000	 val accuracy : 0.60144928	 test accuracy : 0.60989011
# Train Epoch: 145: train loss : 0.00141376	 train accuracy : 1.00000000	 val accuracy : 0.60289855	 test accuracy : 0.60989011
# Train Epoch: 146: train loss : 0.00122728	 train accuracy : 1.00000000	 val accuracy : 0.60289855	 test accuracy : 0.60989011
# Train Epoch: 147: train loss : 0.00132781	 train accuracy : 1.00000000	 val accuracy : 0.59855072	 test accuracy : 0.60989011
# Train Epoch: 148: train loss : 0.00152518	 train accuracy : 1.00000000	 val accuracy : 0.59710145	 test accuracy : 0.61538462
# Train Epoch: 149: train loss : 0.00156708	 train accuracy : 1.00000000	 val accuracy : 0.59855072	 test accuracy : 0.61538462
# Train Epoch: 150: train loss : 0.00149653	 train accuracy : 1.00000000	 val accuracy : 0.59855072	 test accuracy : 0.61538462
# Train Epoch: 151: train loss : 0.00160868	 train accuracy : 1.00000000	 val accuracy : 0.60000000	 test accuracy : 0.61538462
# Train Epoch: 152: train loss : 0.00148162	 train accuracy : 1.00000000	 val accuracy : 0.60144928	 test accuracy : 0.61538462
# Train Epoch: 153: train loss : 0.00104726	 train accuracy : 1.00000000	 val accuracy : 0.60289855	 test accuracy : 0.61538462
# Train Epoch: 154: train loss : 0.00116424	 train accuracy : 1.00000000	 val accuracy : 0.60434783	 test accuracy : 0.61538462
# Train Epoch: 155: train loss : 0.00116195	 train accuracy : 1.00000000	 val accuracy : 0.60579710	 test accuracy : 0.62087912
# Train Epoch: 156: train loss : 0.00130951	 train accuracy : 1.00000000	 val accuracy : 0.60289855	 test accuracy : 0.62087912
# Train Epoch: 157: train loss : 0.00143247	 train accuracy : 0.99963636	 val accuracy : 0.60289855	 test accuracy : 0.62087912
# Train Epoch: 158: train loss : 0.00106794	 train accuracy : 1.00000000	 val accuracy : 0.60434783	 test accuracy : 0.62087912
# Train Epoch: 159: train loss : 0.00130675	 train accuracy : 1.00000000	 val accuracy : 0.60434783	 test accuracy : 0.62087912
# Train Epoch: 160: train loss : 0.00146873	 train accuracy : 0.99963636	 val accuracy : 0.60579710	 test accuracy : 0.62087912
# Train Epoch: 161: train loss : 0.00132531	 train accuracy : 1.00000000	 val accuracy : 0.60579710	 test accuracy : 0.61538462
# Train Epoch: 162: train loss : 0.00133817	 train accuracy : 1.00000000	 val accuracy : 0.60144928	 test accuracy : 0.61538462
# Train Epoch: 163: train loss : 0.00090363	 train accuracy : 1.00000000	 val accuracy : 0.60434783	 test accuracy : 0.61538462
# Train Epoch: 164: train loss : 0.00130714	 train accuracy : 1.00000000	 val accuracy : 0.60289855	 test accuracy : 0.60439560
# Train Epoch: 165: train loss : 0.00152709	 train accuracy : 0.99963636	 val accuracy : 0.60434783	 test accuracy : 0.60989011
# Train Epoch: 166: train loss : 0.00077367	 train accuracy : 1.00000000	 val accuracy : 0.60434783	 test accuracy : 0.60439560
# Train Epoch: 167: train loss : 0.00116899	 train accuracy : 1.00000000	 val accuracy : 0.60434783	 test accuracy : 0.60439560
# Train Epoch: 168: train loss : 0.00106807	 train accuracy : 1.00000000	 val accuracy : 0.60579710	 test accuracy : 0.60439560
# Train Epoch: 169: train loss : 0.00108274	 train accuracy : 1.00000000	 val accuracy : 0.60289855	 test accuracy : 0.60439560
# Train Epoch: 170: train loss : 0.00099271	 train accuracy : 1.00000000	 val accuracy : 0.60289855	 test accuracy : 0.60989011
# Train Epoch: 171: train loss : 0.00084989	 train accuracy : 1.00000000	 val accuracy : 0.60434783	 test accuracy : 0.62087912
# Train Epoch: 172: train loss : 0.00089541	 train accuracy : 1.00000000	 val accuracy : 0.60289855	 test accuracy : 0.61538462
# Train Epoch: 173: train loss : 0.00093895	 train accuracy : 1.00000000	 val accuracy : 0.60579710	 test accuracy : 0.60989011
# Train Epoch: 174: train loss : 0.00077910	 train accuracy : 1.00000000	 val accuracy : 0.60434783	 test accuracy : 0.61538462
# Train Epoch: 175: train loss : 0.00096646	 train accuracy : 1.00000000	 val accuracy : 0.60434783	 test accuracy : 0.61538462
# Train Epoch: 176: train loss : 0.00122714	 train accuracy : 1.00000000	 val accuracy : 0.60434783	 test accuracy : 0.61538462
# Train Epoch: 177: train loss : 0.00116716	 train accuracy : 1.00000000	 val accuracy : 0.60434783	 test accuracy : 0.60989011
# Train Epoch: 178: train loss : 0.00084473	 train accuracy : 1.00000000	 val accuracy : 0.60289855	 test accuracy : 0.60989011
# Train Epoch: 179: train loss : 0.00115131	 train accuracy : 1.00000000	 val accuracy : 0.60289855	 test accuracy : 0.60989011
# Train Epoch: 180: train loss : 0.00113218	 train accuracy : 1.00000000	 val accuracy : 0.60434783	 test accuracy : 0.60989011
# Train Epoch: 181: train loss : 0.00094166	 train accuracy : 1.00000000	 val accuracy : 0.60724638	 test accuracy : 0.60989011
# Train Epoch: 182: train loss : 0.00151678	 train accuracy : 1.00000000	 val accuracy : 0.60724638	 test accuracy : 0.60989011
# Train Epoch: 183: train loss : 0.00077037	 train accuracy : 1.00000000	 val accuracy : 0.61014493	 test accuracy : 0.61538462
# Train Epoch: 184: train loss : 0.00114304	 train accuracy : 1.00000000	 val accuracy : 0.61159420	 test accuracy : 0.60989011
# Train Epoch: 185: train loss : 0.00117617	 train accuracy : 1.00000000	 val accuracy : 0.61159420	 test accuracy : 0.61538462
# Train Epoch: 186: train loss : 0.00103775	 train accuracy : 1.00000000	 val accuracy : 0.61159420	 test accuracy : 0.61538462
# Train Epoch: 187: train loss : 0.00092355	 train accuracy : 1.00000000	 val accuracy : 0.61159420	 test accuracy : 0.61538462
# Train Epoch: 188: train loss : 0.00098140	 train accuracy : 1.00000000	 val accuracy : 0.61014493	 test accuracy : 0.61538462
# Train Epoch: 189: train loss : 0.00134070	 train accuracy : 1.00000000	 val accuracy : 0.61304348	 test accuracy : 0.60989011
# Train Epoch: 190: train loss : 0.00083364	 train accuracy : 1.00000000	 val accuracy : 0.61014493	 test accuracy : 0.60989011
# Train Epoch: 191: train loss : 0.00115746	 train accuracy : 1.00000000	 val accuracy : 0.61014493	 test accuracy : 0.61538462
# Train Epoch: 192: train loss : 0.00083558	 train accuracy : 1.00000000	 val accuracy : 0.60869565	 test accuracy : 0.61538462
# Train Epoch: 193: train loss : 0.00105521	 train accuracy : 1.00000000	 val accuracy : 0.60724638	 test accuracy : 0.60989011
# Train Epoch: 194: train loss : 0.00102972	 train accuracy : 1.00000000	 val accuracy : 0.60724638	 test accuracy : 0.60989011
# Train Epoch: 195: train loss : 0.00088590	 train accuracy : 1.00000000	 val accuracy : 0.60869565	 test accuracy : 0.61538462
# Train Epoch: 196: train loss : 0.00112829	 train accuracy : 1.00000000	 val accuracy : 0.61159420	 test accuracy : 0.61538462
# Train Epoch: 197: train loss : 0.00095042	 train accuracy : 1.00000000	 val accuracy : 0.61304348	 test accuracy : 0.61538462
# Train Epoch: 198: train loss : 0.00071676	 train accuracy : 1.00000000	 val accuracy : 0.61159420	 test accuracy : 0.61538462
# Train Epoch: 199: train loss : 0.00081256	 train accuracy : 1.00000000	 val accuracy : 0.61014493	 test accuracy : 0.61538462
# Train Epoch: 200: train loss : 0.00100285	 train accuracy : 1.00000000	 val accuracy : 0.61014493	 test accuracy : 0.61538462
# In ensemble  1
# The best validaiton accuracy is:  0.6202898550724638
# Happened at epoch:  109
# The corresponding test accuracy 0.6098901098901099
# The corresponding test AUC is:  0.6569767441860465
# Ensemble  2
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
#   + Number of params: 734092
# Save models
# Train Epoch: 1: train loss : 0.70720594	 train accuracy : 0.50865801	 val accuracy : 0.54401154	 test accuracy : 0.57627119
# Save models
# Train Epoch: 2: train loss : 0.65789793	 train accuracy : 0.59776335	 val accuracy : 0.56132756	 test accuracy : 0.55367232
# Save models
# Train Epoch: 3: train loss : 0.62880183	 train accuracy : 0.65404040	 val accuracy : 0.57864358	 test accuracy : 0.55367232
# Save models
# Train Epoch: 4: train loss : 0.60206279	 train accuracy : 0.69805195	 val accuracy : 0.58585859	 test accuracy : 0.57627119
# Save models
# Train Epoch: 5: train loss : 0.57516623	 train accuracy : 0.72077922	 val accuracy : 0.60173160	 test accuracy : 0.57062147
# Train Epoch: 6: train loss : 0.55162545	 train accuracy : 0.74891775	 val accuracy : 0.59595960	 test accuracy : 0.57062147
# Train Epoch: 7: train loss : 0.52884687	 train accuracy : 0.77669553	 val accuracy : 0.60028860	 test accuracy : 0.57627119
# Save models
# Train Epoch: 8: train loss : 0.50613041	 train accuracy : 0.78715729	 val accuracy : 0.61760462	 test accuracy : 0.56497175
# Save models
# Train Epoch: 9: train loss : 0.47979049	 train accuracy : 0.81313131	 val accuracy : 0.61760462	 test accuracy : 0.55932203
# Save models
# Train Epoch: 10: train loss : 0.45508187	 train accuracy : 0.82936508	 val accuracy : 0.61760462	 test accuracy : 0.57062147
# Save models
# Train Epoch: 11: train loss : 0.42465224	 train accuracy : 0.85461760	 val accuracy : 0.62337662	 test accuracy : 0.56497175
# Save models
# Train Epoch: 12: train loss : 0.39900349	 train accuracy : 0.87193362	 val accuracy : 0.63059163	 test accuracy : 0.55932203
# Save models
# Train Epoch: 13: train loss : 0.37038519	 train accuracy : 0.88888889	 val accuracy : 0.63203463	 test accuracy : 0.57627119
# Train Epoch: 14: train loss : 0.34488267	 train accuracy : 0.89935065	 val accuracy : 0.62626263	 test accuracy : 0.57627119
# Train Epoch: 15: train loss : 0.31747038	 train accuracy : 0.91666667	 val accuracy : 0.62193362	 test accuracy : 0.58192090
# Train Epoch: 16: train loss : 0.28737099	 train accuracy : 0.92965368	 val accuracy : 0.62914863	 test accuracy : 0.58192090
# Train Epoch: 17: train loss : 0.26698434	 train accuracy : 0.93722944	 val accuracy : 0.62481962	 test accuracy : 0.58192090
# Train Epoch: 18: train loss : 0.23920590	 train accuracy : 0.95562771	 val accuracy : 0.62193362	 test accuracy : 0.57627119
# Train Epoch: 19: train loss : 0.21399182	 train accuracy : 0.96428571	 val accuracy : 0.63059163	 test accuracy : 0.58192090
# Save models
# Train Epoch: 20: train loss : 0.18918494	 train accuracy : 0.97077922	 val accuracy : 0.63636364	 test accuracy : 0.57062147
# Train Epoch: 21: train loss : 0.17523876	 train accuracy : 0.97619048	 val accuracy : 0.63203463	 test accuracy : 0.56497175
# Train Epoch: 22: train loss : 0.15251969	 train accuracy : 0.98088023	 val accuracy : 0.62770563	 test accuracy : 0.56497175
# Train Epoch: 23: train loss : 0.13145168	 train accuracy : 0.98412698	 val accuracy : 0.61760462	 test accuracy : 0.55932203
# Train Epoch: 24: train loss : 0.11157935	 train accuracy : 0.98917749	 val accuracy : 0.61616162	 test accuracy : 0.56497175
# Train Epoch: 25: train loss : 0.10591180	 train accuracy : 0.99062049	 val accuracy : 0.61904762	 test accuracy : 0.55932203
# Train Epoch: 26: train loss : 0.09019345	 train accuracy : 0.99639250	 val accuracy : 0.62626263	 test accuracy : 0.55932203
# Train Epoch: 27: train loss : 0.07428615	 train accuracy : 0.99711400	 val accuracy : 0.62337662	 test accuracy : 0.56497175
# Train Epoch: 28: train loss : 0.06663337	 train accuracy : 0.99783550	 val accuracy : 0.61904762	 test accuracy : 0.58192090
# Train Epoch: 29: train loss : 0.06126468	 train accuracy : 0.99675325	 val accuracy : 0.62481962	 test accuracy : 0.57062147
# Train Epoch: 30: train loss : 0.05322613	 train accuracy : 0.99711400	 val accuracy : 0.61760462	 test accuracy : 0.55932203
# Train Epoch: 31: train loss : 0.04503519	 train accuracy : 0.99819625	 val accuracy : 0.62193362	 test accuracy : 0.57627119
# Train Epoch: 32: train loss : 0.03898756	 train accuracy : 0.99927850	 val accuracy : 0.61904762	 test accuracy : 0.57062147
# Train Epoch: 33: train loss : 0.03690718	 train accuracy : 0.99855700	 val accuracy : 0.61904762	 test accuracy : 0.57062147
# Train Epoch: 34: train loss : 0.03110773	 train accuracy : 1.00000000	 val accuracy : 0.61760462	 test accuracy : 0.56497175
# Train Epoch: 35: train loss : 0.02866866	 train accuracy : 0.99783550	 val accuracy : 0.61760462	 test accuracy : 0.55932203
# Train Epoch: 36: train loss : 0.02444964	 train accuracy : 0.99963925	 val accuracy : 0.61760462	 test accuracy : 0.55367232
# Train Epoch: 37: train loss : 0.02284191	 train accuracy : 1.00000000	 val accuracy : 0.61904762	 test accuracy : 0.55932203
# Train Epoch: 38: train loss : 0.02134343	 train accuracy : 0.99963925	 val accuracy : 0.61471861	 test accuracy : 0.55932203
# Train Epoch: 39: train loss : 0.02009084	 train accuracy : 0.99963925	 val accuracy : 0.61616162	 test accuracy : 0.54802260
# Train Epoch: 40: train loss : 0.01751717	 train accuracy : 0.99963925	 val accuracy : 0.61327561	 test accuracy : 0.55932203
# Train Epoch: 41: train loss : 0.01695474	 train accuracy : 1.00000000	 val accuracy : 0.60750361	 test accuracy : 0.57062147
# Train Epoch: 42: train loss : 0.01421688	 train accuracy : 0.99963925	 val accuracy : 0.60606061	 test accuracy : 0.56497175
# Train Epoch: 43: train loss : 0.01211839	 train accuracy : 1.00000000	 val accuracy : 0.60606061	 test accuracy : 0.56497175
# Train Epoch: 44: train loss : 0.01284535	 train accuracy : 0.99927850	 val accuracy : 0.61038961	 test accuracy : 0.55932203
# Train Epoch: 45: train loss : 0.01080387	 train accuracy : 1.00000000	 val accuracy : 0.61183261	 test accuracy : 0.55932203
# Train Epoch: 46: train loss : 0.01037012	 train accuracy : 1.00000000	 val accuracy : 0.61038961	 test accuracy : 0.55932203
# Train Epoch: 47: train loss : 0.00930273	 train accuracy : 1.00000000	 val accuracy : 0.61038961	 test accuracy : 0.56497175
# Train Epoch: 48: train loss : 0.00918316	 train accuracy : 0.99963925	 val accuracy : 0.60894661	 test accuracy : 0.56497175
# Train Epoch: 49: train loss : 0.00848222	 train accuracy : 1.00000000	 val accuracy : 0.60894661	 test accuracy : 0.56497175
# Train Epoch: 50: train loss : 0.00842227	 train accuracy : 0.99963925	 val accuracy : 0.61038961	 test accuracy : 0.56497175
# Train Epoch: 51: train loss : 0.00784421	 train accuracy : 1.00000000	 val accuracy : 0.61038961	 test accuracy : 0.55932203
# Train Epoch: 52: train loss : 0.00753812	 train accuracy : 0.99963925	 val accuracy : 0.60606061	 test accuracy : 0.56497175
# Train Epoch: 53: train loss : 0.00628965	 train accuracy : 1.00000000	 val accuracy : 0.60461760	 test accuracy : 0.58192090
# Train Epoch: 54: train loss : 0.00637817	 train accuracy : 1.00000000	 val accuracy : 0.60317460	 test accuracy : 0.58192090
# Train Epoch: 55: train loss : 0.00533117	 train accuracy : 1.00000000	 val accuracy : 0.60461760	 test accuracy : 0.57627119
# Train Epoch: 56: train loss : 0.00627490	 train accuracy : 1.00000000	 val accuracy : 0.60461760	 test accuracy : 0.58192090
# Train Epoch: 57: train loss : 0.00645908	 train accuracy : 0.99927850	 val accuracy : 0.60317460	 test accuracy : 0.58192090
# Train Epoch: 58: train loss : 0.00566200	 train accuracy : 0.99963925	 val accuracy : 0.60461760	 test accuracy : 0.58192090
# Train Epoch: 59: train loss : 0.00560290	 train accuracy : 0.99963925	 val accuracy : 0.60317460	 test accuracy : 0.59322034
# Train Epoch: 60: train loss : 0.00496390	 train accuracy : 1.00000000	 val accuracy : 0.60606061	 test accuracy : 0.59887006
# Train Epoch: 61: train loss : 0.00486982	 train accuracy : 1.00000000	 val accuracy : 0.61183261	 test accuracy : 0.59887006
# Train Epoch: 62: train loss : 0.00430027	 train accuracy : 1.00000000	 val accuracy : 0.61038961	 test accuracy : 0.59887006
# Train Epoch: 63: train loss : 0.00492734	 train accuracy : 1.00000000	 val accuracy : 0.60750361	 test accuracy : 0.59887006
# Train Epoch: 64: train loss : 0.00501069	 train accuracy : 1.00000000	 val accuracy : 0.60894661	 test accuracy : 0.60451977
# Train Epoch: 65: train loss : 0.00401812	 train accuracy : 1.00000000	 val accuracy : 0.60894661	 test accuracy : 0.59887006
# Train Epoch: 66: train loss : 0.00419294	 train accuracy : 1.00000000	 val accuracy : 0.60894661	 test accuracy : 0.59887006
# Train Epoch: 67: train loss : 0.00407931	 train accuracy : 1.00000000	 val accuracy : 0.61183261	 test accuracy : 0.59887006
# Train Epoch: 68: train loss : 0.00358744	 train accuracy : 1.00000000	 val accuracy : 0.61183261	 test accuracy : 0.58192090
# Train Epoch: 69: train loss : 0.00362261	 train accuracy : 1.00000000	 val accuracy : 0.61183261	 test accuracy : 0.57627119
# Train Epoch: 70: train loss : 0.00358500	 train accuracy : 1.00000000	 val accuracy : 0.60894661	 test accuracy : 0.58192090
# Train Epoch: 71: train loss : 0.00399809	 train accuracy : 1.00000000	 val accuracy : 0.60606061	 test accuracy : 0.57627119
# Train Epoch: 72: train loss : 0.00341485	 train accuracy : 1.00000000	 val accuracy : 0.60606061	 test accuracy : 0.57627119
# Train Epoch: 73: train loss : 0.00371492	 train accuracy : 1.00000000	 val accuracy : 0.60461760	 test accuracy : 0.57062147
# Train Epoch: 74: train loss : 0.00305507	 train accuracy : 0.99963925	 val accuracy : 0.60461760	 test accuracy : 0.57062147
# Train Epoch: 75: train loss : 0.00370239	 train accuracy : 1.00000000	 val accuracy : 0.60461760	 test accuracy : 0.57627119
# Train Epoch: 76: train loss : 0.00290056	 train accuracy : 1.00000000	 val accuracy : 0.60461760	 test accuracy : 0.57627119
# Train Epoch: 77: train loss : 0.00368743	 train accuracy : 1.00000000	 val accuracy : 0.60606061	 test accuracy : 0.57627119
# Train Epoch: 78: train loss : 0.00321194	 train accuracy : 1.00000000	 val accuracy : 0.60606061	 test accuracy : 0.57627119
# Train Epoch: 79: train loss : 0.00286908	 train accuracy : 1.00000000	 val accuracy : 0.60606061	 test accuracy : 0.57627119
# Train Epoch: 80: train loss : 0.00359348	 train accuracy : 1.00000000	 val accuracy : 0.60461760	 test accuracy : 0.57627119
# Train Epoch: 81: train loss : 0.00261229	 train accuracy : 1.00000000	 val accuracy : 0.60317460	 test accuracy : 0.57627119
# Train Epoch: 82: train loss : 0.00243395	 train accuracy : 1.00000000	 val accuracy : 0.60317460	 test accuracy : 0.57062147
# Train Epoch: 83: train loss : 0.00305759	 train accuracy : 1.00000000	 val accuracy : 0.60461760	 test accuracy : 0.56497175
# Train Epoch: 84: train loss : 0.00256985	 train accuracy : 1.00000000	 val accuracy : 0.60461760	 test accuracy : 0.56497175
# Train Epoch: 85: train loss : 0.00271645	 train accuracy : 1.00000000	 val accuracy : 0.60606061	 test accuracy : 0.56497175
# Train Epoch: 86: train loss : 0.00200855	 train accuracy : 1.00000000	 val accuracy : 0.60750361	 test accuracy : 0.56497175
# Train Epoch: 87: train loss : 0.00273258	 train accuracy : 1.00000000	 val accuracy : 0.60750361	 test accuracy : 0.56497175
# Train Epoch: 88: train loss : 0.00245334	 train accuracy : 1.00000000	 val accuracy : 0.60750361	 test accuracy : 0.56497175
# Train Epoch: 89: train loss : 0.00265534	 train accuracy : 1.00000000	 val accuracy : 0.60606061	 test accuracy : 0.56497175
# Train Epoch: 90: train loss : 0.00255247	 train accuracy : 1.00000000	 val accuracy : 0.60750361	 test accuracy : 0.56497175
# Train Epoch: 91: train loss : 0.00289388	 train accuracy : 1.00000000	 val accuracy : 0.60461760	 test accuracy : 0.56497175
# Train Epoch: 92: train loss : 0.00254287	 train accuracy : 1.00000000	 val accuracy : 0.60606061	 test accuracy : 0.56497175
# Train Epoch: 93: train loss : 0.00245201	 train accuracy : 1.00000000	 val accuracy : 0.60894661	 test accuracy : 0.56497175
# Train Epoch: 94: train loss : 0.00228336	 train accuracy : 1.00000000	 val accuracy : 0.61038961	 test accuracy : 0.57627119
# Train Epoch: 95: train loss : 0.00205552	 train accuracy : 1.00000000	 val accuracy : 0.60750361	 test accuracy : 0.57627119
# Train Epoch: 96: train loss : 0.00249501	 train accuracy : 1.00000000	 val accuracy : 0.61038961	 test accuracy : 0.58192090
# Train Epoch: 97: train loss : 0.00249637	 train accuracy : 1.00000000	 val accuracy : 0.60894661	 test accuracy : 0.57627119
# Train Epoch: 98: train loss : 0.00259259	 train accuracy : 1.00000000	 val accuracy : 0.60894661	 test accuracy : 0.57627119
# Train Epoch: 99: train loss : 0.00220957	 train accuracy : 1.00000000	 val accuracy : 0.61038961	 test accuracy : 0.57627119
# Train Epoch: 100: train loss : 0.00246537	 train accuracy : 1.00000000	 val accuracy : 0.60894661	 test accuracy : 0.57627119
# Train Epoch: 101: train loss : 0.00210152	 train accuracy : 1.00000000	 val accuracy : 0.60894661	 test accuracy : 0.57627119
# Train Epoch: 102: train loss : 0.00196654	 train accuracy : 1.00000000	 val accuracy : 0.60894661	 test accuracy : 0.57627119
# Train Epoch: 103: train loss : 0.00262085	 train accuracy : 1.00000000	 val accuracy : 0.60894661	 test accuracy : 0.57627119
# Train Epoch: 104: train loss : 0.00251736	 train accuracy : 1.00000000	 val accuracy : 0.60894661	 test accuracy : 0.57627119
# Train Epoch: 105: train loss : 0.00190682	 train accuracy : 1.00000000	 val accuracy : 0.60894661	 test accuracy : 0.57627119
# Train Epoch: 106: train loss : 0.00276476	 train accuracy : 0.99963925	 val accuracy : 0.60894661	 test accuracy : 0.57627119
# Train Epoch: 107: train loss : 0.00188960	 train accuracy : 1.00000000	 val accuracy : 0.60894661	 test accuracy : 0.56497175
# Train Epoch: 108: train loss : 0.00210227	 train accuracy : 1.00000000	 val accuracy : 0.61183261	 test accuracy : 0.57062147
# Train Epoch: 109: train loss : 0.00207302	 train accuracy : 1.00000000	 val accuracy : 0.61038961	 test accuracy : 0.57062147
# Train Epoch: 110: train loss : 0.00205438	 train accuracy : 1.00000000	 val accuracy : 0.60750361	 test accuracy : 0.57062147
# Train Epoch: 111: train loss : 0.00169639	 train accuracy : 1.00000000	 val accuracy : 0.60750361	 test accuracy : 0.57062147
# Train Epoch: 112: train loss : 0.00171641	 train accuracy : 1.00000000	 val accuracy : 0.60894661	 test accuracy : 0.57062147
# Train Epoch: 113: train loss : 0.00214194	 train accuracy : 1.00000000	 val accuracy : 0.60894661	 test accuracy : 0.57062147
# Train Epoch: 114: train loss : 0.00196696	 train accuracy : 1.00000000	 val accuracy : 0.60606061	 test accuracy : 0.57062147
# Train Epoch: 115: train loss : 0.00175555	 train accuracy : 1.00000000	 val accuracy : 0.60606061	 test accuracy : 0.57062147
# Train Epoch: 116: train loss : 0.00164920	 train accuracy : 1.00000000	 val accuracy : 0.60606061	 test accuracy : 0.56497175
# Train Epoch: 117: train loss : 0.00190712	 train accuracy : 0.99963925	 val accuracy : 0.60750361	 test accuracy : 0.56497175
# Train Epoch: 118: train loss : 0.00223428	 train accuracy : 1.00000000	 val accuracy : 0.60750361	 test accuracy : 0.56497175
# Train Epoch: 119: train loss : 0.00176197	 train accuracy : 1.00000000	 val accuracy : 0.60894661	 test accuracy : 0.56497175
# Train Epoch: 120: train loss : 0.00168243	 train accuracy : 1.00000000	 val accuracy : 0.60894661	 test accuracy : 0.55932203
# Train Epoch: 121: train loss : 0.00143428	 train accuracy : 1.00000000	 val accuracy : 0.61183261	 test accuracy : 0.55932203
# Train Epoch: 122: train loss : 0.00196797	 train accuracy : 1.00000000	 val accuracy : 0.60894661	 test accuracy : 0.55932203
# Train Epoch: 123: train loss : 0.00125013	 train accuracy : 1.00000000	 val accuracy : 0.60894661	 test accuracy : 0.55932203
# Train Epoch: 124: train loss : 0.00145521	 train accuracy : 1.00000000	 val accuracy : 0.60606061	 test accuracy : 0.55932203
# Train Epoch: 125: train loss : 0.00167249	 train accuracy : 1.00000000	 val accuracy : 0.60461760	 test accuracy : 0.56497175
# Train Epoch: 126: train loss : 0.00187196	 train accuracy : 1.00000000	 val accuracy : 0.60606061	 test accuracy : 0.57062147
# Train Epoch: 127: train loss : 0.00195959	 train accuracy : 0.99963925	 val accuracy : 0.60461760	 test accuracy : 0.57062147
# Train Epoch: 128: train loss : 0.00176424	 train accuracy : 1.00000000	 val accuracy : 0.60461760	 test accuracy : 0.57062147
# Train Epoch: 129: train loss : 0.00145989	 train accuracy : 1.00000000	 val accuracy : 0.60317460	 test accuracy : 0.57062147
# Train Epoch: 130: train loss : 0.00165077	 train accuracy : 1.00000000	 val accuracy : 0.60461760	 test accuracy : 0.57062147
# Train Epoch: 131: train loss : 0.00147638	 train accuracy : 1.00000000	 val accuracy : 0.60606061	 test accuracy : 0.57062147
# Train Epoch: 132: train loss : 0.00121111	 train accuracy : 1.00000000	 val accuracy : 0.60606061	 test accuracy : 0.57062147
# Train Epoch: 133: train loss : 0.00116760	 train accuracy : 1.00000000	 val accuracy : 0.60606061	 test accuracy : 0.57062147
# Train Epoch: 134: train loss : 0.00147772	 train accuracy : 1.00000000	 val accuracy : 0.60606061	 test accuracy : 0.57062147
# Train Epoch: 135: train loss : 0.00158671	 train accuracy : 1.00000000	 val accuracy : 0.60606061	 test accuracy : 0.57062147
# Train Epoch: 136: train loss : 0.00137910	 train accuracy : 1.00000000	 val accuracy : 0.60461760	 test accuracy : 0.57062147
# Train Epoch: 137: train loss : 0.00140800	 train accuracy : 1.00000000	 val accuracy : 0.60461760	 test accuracy : 0.57627119
# Train Epoch: 138: train loss : 0.00146392	 train accuracy : 1.00000000	 val accuracy : 0.60461760	 test accuracy : 0.57627119
# Train Epoch: 139: train loss : 0.00153972	 train accuracy : 1.00000000	 val accuracy : 0.60461760	 test accuracy : 0.57627119
# Train Epoch: 140: train loss : 0.00185967	 train accuracy : 0.99963925	 val accuracy : 0.60317460	 test accuracy : 0.57062147
# Train Epoch: 141: train loss : 0.00176157	 train accuracy : 1.00000000	 val accuracy : 0.60461760	 test accuracy : 0.57062147
# Train Epoch: 142: train loss : 0.00119815	 train accuracy : 1.00000000	 val accuracy : 0.60750361	 test accuracy : 0.57062147
# Train Epoch: 143: train loss : 0.00127607	 train accuracy : 1.00000000	 val accuracy : 0.61183261	 test accuracy : 0.57627119
# Train Epoch: 144: train loss : 0.00164024	 train accuracy : 1.00000000	 val accuracy : 0.61183261	 test accuracy : 0.57627119
# Train Epoch: 145: train loss : 0.00166584	 train accuracy : 1.00000000	 val accuracy : 0.61471861	 test accuracy : 0.57627119
# Train Epoch: 146: train loss : 0.00150555	 train accuracy : 1.00000000	 val accuracy : 0.61616162	 test accuracy : 0.57627119
# Train Epoch: 147: train loss : 0.00177665	 train accuracy : 0.99963925	 val accuracy : 0.61471861	 test accuracy : 0.57627119
# Train Epoch: 148: train loss : 0.00150174	 train accuracy : 1.00000000	 val accuracy : 0.61471861	 test accuracy : 0.57627119
# Train Epoch: 149: train loss : 0.00167359	 train accuracy : 1.00000000	 val accuracy : 0.61183261	 test accuracy : 0.58192090
# Train Epoch: 150: train loss : 0.00141276	 train accuracy : 1.00000000	 val accuracy : 0.60894661	 test accuracy : 0.57627119
# Train Epoch: 151: train loss : 0.00137535	 train accuracy : 1.00000000	 val accuracy : 0.60461760	 test accuracy : 0.57062147
# Train Epoch: 152: train loss : 0.00135535	 train accuracy : 1.00000000	 val accuracy : 0.60317460	 test accuracy : 0.57062147
# Train Epoch: 153: train loss : 0.00131243	 train accuracy : 1.00000000	 val accuracy : 0.60461760	 test accuracy : 0.56497175
# Train Epoch: 154: train loss : 0.00118922	 train accuracy : 1.00000000	 val accuracy : 0.60317460	 test accuracy : 0.56497175
# Train Epoch: 155: train loss : 0.00190269	 train accuracy : 1.00000000	 val accuracy : 0.60317460	 test accuracy : 0.56497175
# Train Epoch: 156: train loss : 0.00107172	 train accuracy : 1.00000000	 val accuracy : 0.60606061	 test accuracy : 0.55367232
# Train Epoch: 157: train loss : 0.00096696	 train accuracy : 1.00000000	 val accuracy : 0.60606061	 test accuracy : 0.55367232
# Train Epoch: 158: train loss : 0.00135551	 train accuracy : 1.00000000	 val accuracy : 0.60317460	 test accuracy : 0.56497175
# Train Epoch: 159: train loss : 0.00125127	 train accuracy : 1.00000000	 val accuracy : 0.60317460	 test accuracy : 0.56497175
# Train Epoch: 160: train loss : 0.00125597	 train accuracy : 1.00000000	 val accuracy : 0.60461760	 test accuracy : 0.56497175
# Train Epoch: 161: train loss : 0.00115141	 train accuracy : 1.00000000	 val accuracy : 0.60461760	 test accuracy : 0.56497175
# Train Epoch: 162: train loss : 0.00144688	 train accuracy : 1.00000000	 val accuracy : 0.60461760	 test accuracy : 0.56497175
# Train Epoch: 163: train loss : 0.00134056	 train accuracy : 1.00000000	 val accuracy : 0.60461760	 test accuracy : 0.56497175
# Train Epoch: 164: train loss : 0.00112678	 train accuracy : 1.00000000	 val accuracy : 0.60317460	 test accuracy : 0.57062147
# Train Epoch: 165: train loss : 0.00143269	 train accuracy : 1.00000000	 val accuracy : 0.60606061	 test accuracy : 0.56497175
# Train Epoch: 166: train loss : 0.00145921	 train accuracy : 0.99963925	 val accuracy : 0.60606061	 test accuracy : 0.57062147
# Train Epoch: 167: train loss : 0.00093286	 train accuracy : 1.00000000	 val accuracy : 0.60750361	 test accuracy : 0.57062147
# Train Epoch: 168: train loss : 0.00090856	 train accuracy : 1.00000000	 val accuracy : 0.60894661	 test accuracy : 0.57062147
# Train Epoch: 169: train loss : 0.00119290	 train accuracy : 1.00000000	 val accuracy : 0.60750361	 test accuracy : 0.57062147
# Train Epoch: 170: train loss : 0.00096563	 train accuracy : 1.00000000	 val accuracy : 0.60606061	 test accuracy : 0.57062147
# ...
# Train Epoch: 78: train loss : 0.00367161	 train accuracy : 0.99893314	 val accuracy : 0.61166430	 test accuracy : 0.62275449
# Train Epoch: 79: train loss : 0.00273697	 train accuracy : 1.00000000	 val accuracy : 0.61166430	 test accuracy : 0.61676647
# Train Epoch: 80: train loss : 0.00304455	 train accuracy : 0.99964438	 val accuracy : 0.61450925	 test accuracy : 0.61676647
# Train Epoch: 81: train loss : 0.00266844	 train accuracy : 1.00000000	 val accuracy : 0.61308677	 test accuracy : 0.61676647
# Train Epoch: 82: train loss : 0.00255879	 train accuracy : 1.00000000	 val accuracy : 0.61166430	 test accuracy : 0.61077844
# Train Epoch: 83: train loss : 0.00249509	 train accuracy : 1.00000000	 val accuracy : 0.60881935	 test accuracy : 0.61676647
# Train Epoch: 84: train loss : 0.00252339	 train accuracy : 1.00000000	 val accuracy : 0.60739687	 test accuracy : 0.61077844
# Train Epoch: 85: train loss : 0.00251400	 train accuracy : 1.00000000	 val accuracy : 0.60597440	 test accuracy : 0.61077844
# Train Epoch: 86: train loss : 0.00227668	 train accuracy : 1.00000000	 val accuracy : 0.60597440	 test accuracy : 0.61676647
# Train Epoch: 87: train loss : 0.00222763	 train accuracy : 1.00000000	 val accuracy : 0.60455192	 test accuracy : 0.61077844
# Train Epoch: 88: train loss : 0.00226084	 train accuracy : 1.00000000	 val accuracy : 0.60170697	 test accuracy : 0.61676647
# Train Epoch: 89: train loss : 0.00226176	 train accuracy : 1.00000000	 val accuracy : 0.60312945	 test accuracy : 0.61676647
# Train Epoch: 90: train loss : 0.00256711	 train accuracy : 1.00000000	 val accuracy : 0.60170697	 test accuracy : 0.61676647
# Train Epoch: 91: train loss : 0.00203568	 train accuracy : 1.00000000	 val accuracy : 0.59886202	 test accuracy : 0.61077844
# Train Epoch: 92: train loss : 0.00221307	 train accuracy : 1.00000000	 val accuracy : 0.60028450	 test accuracy : 0.61077844
# Train Epoch: 93: train loss : 0.00203217	 train accuracy : 1.00000000	 val accuracy : 0.59886202	 test accuracy : 0.61077844
# Train Epoch: 94: train loss : 0.00212776	 train accuracy : 1.00000000	 val accuracy : 0.59743954	 test accuracy : 0.61077844
# Train Epoch: 95: train loss : 0.00199563	 train accuracy : 1.00000000	 val accuracy : 0.59743954	 test accuracy : 0.61077844
# Train Epoch: 96: train loss : 0.00220343	 train accuracy : 1.00000000	 val accuracy : 0.59317212	 test accuracy : 0.61077844
# Train Epoch: 97: train loss : 0.00265092	 train accuracy : 1.00000000	 val accuracy : 0.59601707	 test accuracy : 0.61077844
# Train Epoch: 98: train loss : 0.00202138	 train accuracy : 1.00000000	 val accuracy : 0.59601707	 test accuracy : 0.61077844
# Train Epoch: 99: train loss : 0.00206003	 train accuracy : 1.00000000	 val accuracy : 0.60312945	 test accuracy : 0.61077844
# Train Epoch: 100: train loss : 0.00150252	 train accuracy : 1.00000000	 val accuracy : 0.60597440	 test accuracy : 0.61077844
# Train Epoch: 101: train loss : 0.00204801	 train accuracy : 1.00000000	 val accuracy : 0.60597440	 test accuracy : 0.60479042
# Train Epoch: 102: train loss : 0.00203615	 train accuracy : 1.00000000	 val accuracy : 0.60312945	 test accuracy : 0.60479042
# Train Epoch: 103: train loss : 0.00187338	 train accuracy : 0.99964438	 val accuracy : 0.60455192	 test accuracy : 0.61077844
# Train Epoch: 104: train loss : 0.00196480	 train accuracy : 0.99964438	 val accuracy : 0.60455192	 test accuracy : 0.61077844
# Train Epoch: 105: train loss : 0.00168043	 train accuracy : 1.00000000	 val accuracy : 0.60455192	 test accuracy : 0.62275449
# Train Epoch: 106: train loss : 0.00161619	 train accuracy : 1.00000000	 val accuracy : 0.60739687	 test accuracy : 0.61676647
# Train Epoch: 107: train loss : 0.00187101	 train accuracy : 1.00000000	 val accuracy : 0.60881935	 test accuracy : 0.62275449
# Train Epoch: 108: train loss : 0.00165626	 train accuracy : 1.00000000	 val accuracy : 0.60597440	 test accuracy : 0.62275449
# Train Epoch: 109: train loss : 0.00164364	 train accuracy : 1.00000000	 val accuracy : 0.60455192	 test accuracy : 0.62275449
# Train Epoch: 110: train loss : 0.00148144	 train accuracy : 1.00000000	 val accuracy : 0.60597440	 test accuracy : 0.62275449
# Train Epoch: 111: train loss : 0.00155840	 train accuracy : 1.00000000	 val accuracy : 0.60739687	 test accuracy : 0.62275449
# Train Epoch: 112: train loss : 0.00156617	 train accuracy : 1.00000000	 val accuracy : 0.60739687	 test accuracy : 0.62275449
# Train Epoch: 113: train loss : 0.00186232	 train accuracy : 0.99964438	 val accuracy : 0.60597440	 test accuracy : 0.62275449
# Train Epoch: 114: train loss : 0.00162412	 train accuracy : 1.00000000	 val accuracy : 0.60597440	 test accuracy : 0.61676647
# Train Epoch: 115: train loss : 0.00153161	 train accuracy : 1.00000000	 val accuracy : 0.60739687	 test accuracy : 0.62275449
# Train Epoch: 116: train loss : 0.00170251	 train accuracy : 1.00000000	 val accuracy : 0.60739687	 test accuracy : 0.62275449
# Train Epoch: 117: train loss : 0.00129362	 train accuracy : 1.00000000	 val accuracy : 0.60881935	 test accuracy : 0.62275449
# Train Epoch: 118: train loss : 0.00198283	 train accuracy : 1.00000000	 val accuracy : 0.60881935	 test accuracy : 0.62275449
# Train Epoch: 119: train loss : 0.00152721	 train accuracy : 1.00000000	 val accuracy : 0.60739687	 test accuracy : 0.62275449
# Train Epoch: 120: train loss : 0.00136328	 train accuracy : 1.00000000	 val accuracy : 0.61024182	 test accuracy : 0.62275449
# Train Epoch: 121: train loss : 0.00127815	 train accuracy : 1.00000000	 val accuracy : 0.61166430	 test accuracy : 0.62874251
# Train Epoch: 122: train loss : 0.00191009	 train accuracy : 1.00000000	 val accuracy : 0.61308677	 test accuracy : 0.62275449
# Train Epoch: 123: train loss : 0.00144558	 train accuracy : 1.00000000	 val accuracy : 0.61450925	 test accuracy : 0.62275449
# Train Epoch: 124: train loss : 0.00164371	 train accuracy : 1.00000000	 val accuracy : 0.61450925	 test accuracy : 0.61676647
# Train Epoch: 125: train loss : 0.00144780	 train accuracy : 1.00000000	 val accuracy : 0.61450925	 test accuracy : 0.61676647
# Train Epoch: 126: train loss : 0.00155298	 train accuracy : 1.00000000	 val accuracy : 0.61450925	 test accuracy : 0.61676647
# Train Epoch: 127: train loss : 0.00152020	 train accuracy : 1.00000000	 val accuracy : 0.61308677	 test accuracy : 0.61676647
# Train Epoch: 128: train loss : 0.00134308	 train accuracy : 1.00000000	 val accuracy : 0.61308677	 test accuracy : 0.61676647
# Train Epoch: 129: train loss : 0.00160772	 train accuracy : 0.99964438	 val accuracy : 0.61308677	 test accuracy : 0.61676647
# Train Epoch: 130: train loss : 0.00136847	 train accuracy : 1.00000000	 val accuracy : 0.61450925	 test accuracy : 0.61676647
# Train Epoch: 131: train loss : 0.00103269	 train accuracy : 1.00000000	 val accuracy : 0.61450925	 test accuracy : 0.61676647
# Train Epoch: 132: train loss : 0.00137313	 train accuracy : 1.00000000	 val accuracy : 0.61450925	 test accuracy : 0.61676647
# Train Epoch: 133: train loss : 0.00124395	 train accuracy : 1.00000000	 val accuracy : 0.61308677	 test accuracy : 0.61077844
# Train Epoch: 134: train loss : 0.00115862	 train accuracy : 1.00000000	 val accuracy : 0.61024182	 test accuracy : 0.61077844
# Train Epoch: 135: train loss : 0.00130133	 train accuracy : 1.00000000	 val accuracy : 0.60739687	 test accuracy : 0.61077844
# Train Epoch: 136: train loss : 0.00164977	 train accuracy : 1.00000000	 val accuracy : 0.60455192	 test accuracy : 0.61077844
# Train Epoch: 137: train loss : 0.00169977	 train accuracy : 0.99964438	 val accuracy : 0.60597440	 test accuracy : 0.61077844
# Train Epoch: 138: train loss : 0.00111111	 train accuracy : 1.00000000	 val accuracy : 0.60739687	 test accuracy : 0.61077844
# Train Epoch: 139: train loss : 0.00161056	 train accuracy : 0.99964438	 val accuracy : 0.60739687	 test accuracy : 0.61676647
# Train Epoch: 140: train loss : 0.00128620	 train accuracy : 1.00000000	 val accuracy : 0.60739687	 test accuracy : 0.61676647
# Train Epoch: 141: train loss : 0.00089749	 train accuracy : 1.00000000	 val accuracy : 0.60455192	 test accuracy : 0.61676647
# Train Epoch: 142: train loss : 0.00127569	 train accuracy : 1.00000000	 val accuracy : 0.60455192	 test accuracy : 0.61676647
# Train Epoch: 143: train loss : 0.00095374	 train accuracy : 1.00000000	 val accuracy : 0.60597440	 test accuracy : 0.61676647
# Train Epoch: 144: train loss : 0.00109107	 train accuracy : 0.99964438	 val accuracy : 0.61166430	 test accuracy : 0.62275449
# Train Epoch: 145: train loss : 0.00158399	 train accuracy : 1.00000000	 val accuracy : 0.60881935	 test accuracy : 0.61077844
# Train Epoch: 146: train loss : 0.00107817	 train accuracy : 1.00000000	 val accuracy : 0.60739687	 test accuracy : 0.61077844
# Train Epoch: 147: train loss : 0.00106713	 train accuracy : 1.00000000	 val accuracy : 0.61308677	 test accuracy : 0.61077844
# Train Epoch: 148: train loss : 0.00120749	 train accuracy : 1.00000000	 val accuracy : 0.61450925	 test accuracy : 0.61077844
# Train Epoch: 149: train loss : 0.00095323	 train accuracy : 1.00000000	 val accuracy : 0.61593172	 test accuracy : 0.61077844
# Train Epoch: 150: train loss : 0.00110680	 train accuracy : 1.00000000	 val accuracy : 0.61593172	 test accuracy : 0.61077844
# Train Epoch: 151: train loss : 0.00119002	 train accuracy : 1.00000000	 val accuracy : 0.61593172	 test accuracy : 0.61077844
# Train Epoch: 152: train loss : 0.00109197	 train accuracy : 1.00000000	 val accuracy : 0.61593172	 test accuracy : 0.61077844
# Train Epoch: 153: train loss : 0.00127213	 train accuracy : 1.00000000	 val accuracy : 0.61308677	 test accuracy : 0.61077844
# Train Epoch: 154: train loss : 0.00089542	 train accuracy : 1.00000000	 val accuracy : 0.61450925	 test accuracy : 0.61077844
# Train Epoch: 155: train loss : 0.00097917	 train accuracy : 1.00000000	 val accuracy : 0.61450925	 test accuracy : 0.61077844
# Train Epoch: 156: train loss : 0.00099569	 train accuracy : 1.00000000	 val accuracy : 0.61166430	 test accuracy : 0.61077844
# Train Epoch: 157: train loss : 0.00116164	 train accuracy : 1.00000000	 val accuracy : 0.61024182	 test accuracy : 0.61077844
# Train Epoch: 158: train loss : 0.00111704	 train accuracy : 1.00000000	 val accuracy : 0.61166430	 test accuracy : 0.61077844
# Train Epoch: 159: train loss : 0.00120659	 train accuracy : 0.99964438	 val accuracy : 0.61024182	 test accuracy : 0.61077844
# Train Epoch: 160: train loss : 0.00091749	 train accuracy : 1.00000000	 val accuracy : 0.61166430	 test accuracy : 0.61676647
# Train Epoch: 161: train loss : 0.00096234	 train accuracy : 1.00000000	 val accuracy : 0.61024182	 test accuracy : 0.61676647
# Train Epoch: 162: train loss : 0.00099815	 train accuracy : 1.00000000	 val accuracy : 0.61024182	 test accuracy : 0.61676647
# Train Epoch: 163: train loss : 0.00089588	 train accuracy : 1.00000000	 val accuracy : 0.61166430	 test accuracy : 0.61676647
# Train Epoch: 164: train loss : 0.00110920	 train accuracy : 1.00000000	 val accuracy : 0.61166430	 test accuracy : 0.62275449
# Train Epoch: 165: train loss : 0.00089921	 train accuracy : 1.00000000	 val accuracy : 0.61166430	 test accuracy : 0.62275449
# Train Epoch: 166: train loss : 0.00093718	 train accuracy : 1.00000000	 val accuracy : 0.61024182	 test accuracy : 0.62275449
# Train Epoch: 167: train loss : 0.00118070	 train accuracy : 1.00000000	 val accuracy : 0.61024182	 test accuracy : 0.61676647
# Train Epoch: 168: train loss : 0.00085587	 train accuracy : 1.00000000	 val accuracy : 0.61024182	 test accuracy : 0.61676647
# Train Epoch: 169: train loss : 0.00082047	 train accuracy : 1.00000000	 val accuracy : 0.61166430	 test accuracy : 0.61077844
# Train Epoch: 170: train loss : 0.00087363	 train accuracy : 1.00000000	 val accuracy : 0.61166430	 test accuracy : 0.61077844
# Train Epoch: 171: train loss : 0.00078002	 train accuracy : 1.00000000	 val accuracy : 0.61166430	 test accuracy : 0.61077844
# Train Epoch: 172: train loss : 0.00099559	 train accuracy : 1.00000000	 val accuracy : 0.61024182	 test accuracy : 0.61077844
# Train Epoch: 173: train loss : 0.00095272	 train accuracy : 1.00000000	 val accuracy : 0.61166430	 test accuracy : 0.61077844
# Train Epoch: 174: train loss : 0.00076507	 train accuracy : 1.00000000	 val accuracy : 0.61308677	 test accuracy : 0.61077844
# Train Epoch: 175: train loss : 0.00111422	 train accuracy : 1.00000000	 val accuracy : 0.61450925	 test accuracy : 0.61077844
# Train Epoch: 176: train loss : 0.00090340	 train accuracy : 1.00000000	 val accuracy : 0.61450925	 test accuracy : 0.61077844
# Train Epoch: 177: train loss : 0.00116045	 train accuracy : 0.99964438	 val accuracy : 0.61450925	 test accuracy : 0.61077844
# Train Epoch: 178: train loss : 0.00076003	 train accuracy : 1.00000000	 val accuracy : 0.61593172	 test accuracy : 0.61676647
# Train Epoch: 179: train loss : 0.00073724	 train accuracy : 1.00000000	 val accuracy : 0.61308677	 test accuracy : 0.61676647
# Train Epoch: 180: train loss : 0.00109630	 train accuracy : 0.99964438	 val accuracy : 0.61735420	 test accuracy : 0.61676647
# Train Epoch: 181: train loss : 0.00104420	 train accuracy : 1.00000000	 val accuracy : 0.61593172	 test accuracy : 0.61676647
# Train Epoch: 182: train loss : 0.00120706	 train accuracy : 1.00000000	 val accuracy : 0.61593172	 test accuracy : 0.61077844
# Train Epoch: 183: train loss : 0.00143163	 train accuracy : 1.00000000	 val accuracy : 0.61450925	 test accuracy : 0.61077844
# Train Epoch: 184: train loss : 0.00068824	 train accuracy : 1.00000000	 val accuracy : 0.61024182	 test accuracy : 0.61077844
# Train Epoch: 185: train loss : 0.00117294	 train accuracy : 1.00000000	 val accuracy : 0.61166430	 test accuracy : 0.61077844
# Train Epoch: 186: train loss : 0.00103313	 train accuracy : 1.00000000	 val accuracy : 0.61024182	 test accuracy : 0.60479042
# Train Epoch: 187: train loss : 0.00070967	 train accuracy : 1.00000000	 val accuracy : 0.60881935	 test accuracy : 0.59880240
# Train Epoch: 188: train loss : 0.00075449	 train accuracy : 1.00000000	 val accuracy : 0.61024182	 test accuracy : 0.60479042
# Train Epoch: 189: train loss : 0.00085903	 train accuracy : 1.00000000	 val accuracy : 0.60597440	 test accuracy : 0.59880240
# Train Epoch: 190: train loss : 0.00081420	 train accuracy : 1.00000000	 val accuracy : 0.60455192	 test accuracy : 0.59880240
# Train Epoch: 191: train loss : 0.00101224	 train accuracy : 1.00000000	 val accuracy : 0.60597440	 test accuracy : 0.59880240
# Train Epoch: 192: train loss : 0.00094810	 train accuracy : 1.00000000	 val accuracy : 0.60739687	 test accuracy : 0.59880240
# Train Epoch: 193: train loss : 0.00091358	 train accuracy : 1.00000000	 val accuracy : 0.61024182	 test accuracy : 0.59880240
# Train Epoch: 194: train loss : 0.00130711	 train accuracy : 0.99964438	 val accuracy : 0.61024182	 test accuracy : 0.59281437
# Train Epoch: 195: train loss : 0.00068971	 train accuracy : 1.00000000	 val accuracy : 0.61308677	 test accuracy : 0.59880240
# Train Epoch: 196: train loss : 0.00062459	 train accuracy : 1.00000000	 val accuracy : 0.61024182	 test accuracy : 0.59880240
# Train Epoch: 197: train loss : 0.00083087	 train accuracy : 1.00000000	 val accuracy : 0.60881935	 test accuracy : 0.59880240
# Train Epoch: 198: train loss : 0.00082719	 train accuracy : 1.00000000	 val accuracy : 0.60597440	 test accuracy : 0.59880240
# Train Epoch: 199: train loss : 0.00081475	 train accuracy : 1.00000000	 val accuracy : 0.60739687	 test accuracy : 0.61077844
# Train Epoch: 200: train loss : 0.00094477	 train accuracy : 1.00000000	 val accuracy : 0.60881935	 test accuracy : 0.60479042
# In ensemble  5
# The best validaiton accuracy is:  0.6258890469416786
# Happened at epoch:  32
# The corresponding test accuracy 0.6407185628742516
# The corresponding test AUC is:  0.6669565217391304
# The Max voting test accuracy is:  0.6298850574712643
# The test AUC is:  0.6593482500092986
