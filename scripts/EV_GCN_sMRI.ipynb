# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/ABIDE/")
# Out:
# Mounted at /content/drive

# %%
# !pip install torch==1.11.0 torchvision==0.12.0 torchaudio==0.11.0
# !pip install --no-index torch-scatter -f https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# !pip install --no-index torch-sparse -f https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# !pip install --no-index torch-cluster -f https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# !pip install --no-index torch-spline-conv -f https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# !pip install torch-geometric
import torch
print(torch.__version__)  
print(torch.version.cuda)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch==1.11.0
#   Downloading torch-1.11.0-cp38-cp38-manylinux1_x86_64.whl (750.6 MB)
#      |████████████████████████████████| 750.6 MB 17 kB/s
# Collecting torchvision==0.12.0
#   Downloading torchvision-0.12.0-cp38-cp38-manylinux1_x86_64.whl (21.0 MB)
#      |████████████████████████████████| 21.0 MB 1.3 MB/s
# Collecting torchaudio==0.11.0
#   Downloading torchaudio-0.11.0-cp38-cp38-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 41.8 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch==1.11.0) (4.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torchvision==0.12.0) (2.23.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision==0.12.0) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torchvision==0.12.0) (1.21.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision==0.12.0) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision==0.12.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision==0.12.0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision==0.12.0) (3.0.4)
# Installing collected packages: torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.1+cu113
#     Uninstalling torchvision-0.13.1+cu113:
#       Successfully uninstalled torchvision-0.13.1+cu113
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 0.12.1+cu113
#     Uninstalling torchaudio-0.12.1+cu113:
#       Successfully uninstalled torchaudio-0.12.1+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.13.1 requires torch==1.12.1, but you have torch 1.11.0 which is incompatible.
# Successfully installed torch-1.11.0 torchaudio-0.11.0 torchvision-0.12.0
# Looking in links: https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# Collecting torch-scatter
#   Downloading https://data.pyg.org/whl/torch-1.11.0%2Bcu102/torch_scatter-2.0.9-cp38-cp38-linux_x86_64.whl (8.0 MB)
#      |████████████████████████████████| 8.0 MB 5.0 MB/s
# Installing collected packages: torch-scatter
# Successfully installed torch-scatter-2.0.9
# Looking in links: https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# Collecting torch-sparse
#   Downloading https://data.pyg.org/whl/torch-1.11.0%2Bcu102/torch_sparse-0.6.15-cp38-cp38-linux_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 4.5 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from torch-sparse) (1.7.3)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /usr/local/lib/python3.8/dist-packages (from scipy->torch-sparse) (1.21.6)
# Installing collected packages: torch-sparse
# Successfully installed torch-sparse-0.6.15
# Looking in links: https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# Collecting torch-cluster
#   Downloading https://data.pyg.org/whl/torch-1.11.0%2Bcu102/torch_cluster-1.6.0-cp38-cp38-linux_x86_64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 5.1 MB/s
# Installing collected packages: torch-cluster
# Successfully installed torch-cluster-1.6.0
# Looking in links: https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# Collecting torch-spline-conv
#   Downloading https://data.pyg.org/whl/torch-1.11.0%2Bcu102/torch_spline_conv-1.2.1-cp38-cp38-linux_x86_64.whl (672 kB)
#      |████████████████████████████████| 672 kB 882 kB/s
# Installing collected packages: torch-spline-conv
# Successfully installed torch-spline-conv-1.2.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch-geometric
#   Downloading torch_geometric-2.2.0.tar.gz (564 kB)
#      |████████████████████████████████| 564 kB 4.4 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from torch-geometric) (4.64.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torch-geometric) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from torch-geometric) (1.7.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from torch-geometric) (2.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torch-geometric) (2.23.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.8/dist-packages (from torch-geometric) (3.0.9)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from torch-geometric) (1.0.2)
# Collecting psutil>=5.8.0
#   Downloading psutil-5.9.4-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
#      |████████████████████████████████| 280 kB 69.6 MB/s
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->torch-geometric) (2.0.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->torch-geometric) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torch-geometric) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->torch-geometric) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torch-geometric) (2022.9.24)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->torch-geometric) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->torch-geometric) (3.1.0)
# Building wheels for collected packages: torch-geometric
#   Building wheel for torch-geometric (setup.py) ... done
#   Created wheel for torch-geometric: filename=torch_geometric-2.2.0-py3-none-any.whl size=773302 sha256=219ff59227c456cfa43ea374a321cb98430670740315297a6f7cb77b691b28f4
#   Stored in directory: /root/.cache/pip/wheels/59/a3/20/198928106d3169865ae73afcbd3d3d1796cf6b429b55c65378
# Successfully built torch-geometric
# Installing collected packages: psutil, torch-geometric
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
# Successfully installed psutil-5.9.4 torch-geometric-2.2.0
# 1.11.0+cu102
# 10.2

# %%
# load ComBat algorithm
# !python /content/drive/MyDrive/ABIDE/neuralCombat.py 
import sys
sys.path.append('/content/drive/MyDrive/ABIDE/')

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from neuralCombat import *
# from neuralCombat.py import neuralCombat
import pandas as pd
from sklearn import svm
import joblib
import openpyxl
from openpyxl import load_workbook
import os
import scipy.io as scio
import argparse
import numpy as np
import time
import torch
import torch.utils.data
import torch.nn as nn
import torch.optim as optim
from torch.utils.data.dataset import Dataset
from torch.autograd import Variable
from torchvision import datasets, transforms
from torchvision.utils import make_grid , save_image
import torchvision.utils as vutils
from os.path import join
from os import listdir
from torch.utils.data.dataloader import DataLoader
from torch.utils.data import DataLoader
from collections import OrderedDict
import nibabel as nib
import matplotlib.pyplot as plt
import cv2 as cv
from os import path
import shutil
import scipy.stats
import scipy.ndimage
import random
import torch.nn.init as init
import torch.nn.functional as F
import sys
import math
from functools import reduce
import operator
from scipy.interpolate import interp1d
from torch.optim import lr_scheduler
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import RidgeClassifier
from sklearn.feature_selection import RFE

def feature_selection(matrix, labels, train_ind, fnum):
    """
        matrix       : feature matrix (num_subjects x num_features)
        labels       : ground truth labels (num_subjects x 1)
        train_ind    : indices of the training samples
        fnum         : size of the feature vector after feature selection 

    return:
        x_data      : feature matrix of lower dimension (num_subjects x fnum)
    """

    estimator = RidgeClassifier()
    selector = RFE(estimator, n_features_to_select=fnum, step=100, verbose=1)

    featureX = matrix[train_ind, :]
    featureY = labels[train_ind]
    selector = selector.fit(featureX, featureY.ravel())

    return selector

def get_index(lst=None, item=''):
	return [i for i in range(len(lst)) if lst[i] == item]

def flatten_one(length, img):
	'''
	  In some situations, the dimension on z-axis of images are smaller than
	  the dimension of z-axis of patches, this function will be used to pad
	'''

	one_line = np.zeros((1, int(length)))
	position = 0
	for i in range(img.shape[0]):  # column
		for j in range(i + 1, img.shape[1]):  # row
			one_line[0, position] = img[j, i]
			position = position + 1
	return one_line


def get_ids(num_subjects=None,dir_path=''):
	"""
	return:
		subject_IDs    : list of all subject IDs
	"""
	subject_IDs = np.genfromtxt(os.path.join(dir_path, 'subject_IDs.txt'), dtype=str)

	if num_subjects is not None:
		subject_IDs = subject_IDs[:num_subjects]

	return subject_IDs

def save_model(net,path, name_net):

  # This fucntion is used to save a specific model

    path_net =  path + '/' + name_net + '.pth'
    torch.save(net.cpu().state_dict(), path_net)
    net.cuda()

def load_model(net, path, name_net):

  # This function is used to load a specific model we saved before

    path_net =  path + '/' + name_net + '.pth'
    net.load_state_dict(torch.load(path_net))

    return net

# %%
########################################### Load Data ###############################################
#####################################################################################################
#####################################################################################################
combat = True    # True or False


if combat == False:
  save_combat = '/without_ComBat/'
else:
  save_combat = '/with_ComBat/'

save_path = '/content/drive/MyDrive/ABIDE/save_models/sMRI' + save_combat
localDir = '/content/sMRI_dataset/'
if os.path.exists(localDir):
  shutil.rmtree(localDir) 
# shutil.copy('/content/drive/MyDrive/ABIDE/freesurfer_stats.7z', localDir)
os.makedirs(localDir)
# !unzip '/content/drive/MyDrive/ABIDE/freesurfer_stats.zip' -d '/content/sMRI_dataset'

label_dir = '/content/drive/MyDrive/ABIDE/phenotypic_image_quality'
localDir = localDir + 'freesurfer_stats/'

k_fold = 5
new_number_features = 1435
number_samples = 871
useless_samples = ['51334']
scaler = True

age_name = 'ages.mat'
gender_name = 'genders.mat'
label_name = 'ABIDE_label_871.mat'
label = scio.loadmat(os.path.join(label_dir, label_name))
label = label['label'][0]
labels = np.zeros(number_samples - len(useless_samples))
site_name = 'sites.mat'
site = scio.loadmat(os.path.join(label_dir, site_name))
all_sites = site['sites']
for i in range(len(all_sites)):
	site = all_sites[i]
	all_sites[i] = site.replace(' ', '')
unique_sites = np.unique(all_sites)
sites = []
unique_sites = list(unique_sites)

age = scio.loadmat(os.path.join(label_dir, age_name))
age = age['ages']
ages = np.zeros((number_samples - len(useless_samples), 1))

gender = scio.loadmat(os.path.join(label_dir, gender_name))
gender = gender['genders']
genders = np.zeros((number_samples - len(useless_samples), 1))

subject_IDs = get_ids(number_samples,dir_path=label_dir)
subject_IDs = subject_IDs.tolist()

EV_GCN_unique = list(unique_sites)
EV_GCN_site = np.zeros([number_samples - len(useless_samples)], dtype=np.int)
EV_GCN_age = np.zeros([number_samples - len(useless_samples)], dtype=np.float32)
EV_GCN_gender = np.zeros([number_samples - len(useless_samples)], dtype=np.int)

position = 0
for i in range(number_samples):
  subject_name = subject_IDs[i]
  if subject_name in useless_samples:
    subject_index = get_index(lst=subject_IDs, item=subject_name)
    print('The index for sample ' + subject_name + ' is : ', subject_index)
  else:
    image_name = subject_name + '.mat'
    subject_index = get_index(lst=subject_IDs, item=subject_name)
    sites.append(all_sites[subject_index[0]])
    labels[position] = label[subject_index[0]]
    genders[position] = int(gender[subject_index[0]]) + 1
    ages[position] = float(age[subject_index[0]])
    position = position + 1

for i in range(number_samples - len(useless_samples)): 

  EV_GCN_site[i] = EV_GCN_unique.index(sites[i])
  EV_GCN_age[i] = ages[i]
  EV_GCN_gender[i] = genders[i]

phonetic_data = np.zeros([number_samples - len(useless_samples), 3], dtype=np.float32)
phonetic_data[:,0] = EV_GCN_site 
phonetic_data[:,1] = EV_GCN_gender 
phonetic_data[:,2] = EV_GCN_age

pd_dict = {}
pd_dict['SITE_ID'] = np.copy(phonetic_data[:,0])
pd_dict['SEX'] = np.copy(phonetic_data[:,1])
pd_dict['AGE_AT_SCAN'] = np.copy(phonetic_data[:,2])
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51096/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51097/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51098/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51099/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51100/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51101/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51102/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51103/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51104/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51105/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51106/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51107/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51109/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51110/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51111/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51112/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51113/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51114/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51116/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51117/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51118/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51122/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51123/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51124/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51126/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51127/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51128/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51129/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51130/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51131/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.curv.stats
# ...
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51578/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51579/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51580/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51582/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51583/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51584/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51585/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51606/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51607/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/wmparc.stats
# The index for sample 51334 is :  [799]
# <ipython-input-5-76e6318a1635>:57: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   EV_GCN_site = np.zeros([number_samples - len(useless_samples)], dtype=np.int)
# <ipython-input-5-76e6318a1635>:59: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   EV_GCN_gender = np.zeros([number_samples - len(useless_samples)], dtype=np.int)

# %%
############################################### Load sMRI ###############################################################
############################################### Load sMRI ###############################################################
############################################### Load sMRI ###############################################################
############################################### Load Desikan_Killiany_features
left = 'lh.aparc.stats'
right = 'rh.aparc.stats'
number_roi = 68
feature_list = ['NumVert', 'SurfArea', 'GrayVol', 'ThickAvg', 'ThickStd', 'MeanCurv', 'GausCurv', 'FoldInd', 'CurvInd']
names = ['StructName', 'NumVert', 'SurfArea', 'GrayVol', 'ThickAvg', 'ThickStd', 'MeanCurv', 'GausCurv', 'FoldInd', 'CurvInd']
skiprows= list(range(0,61))
Desikan_Killiany_features = np.zeros((number_samples - len(useless_samples), number_roi * len(feature_list)))


position = 0
print('constructing Desikan-Killiany Atlas features')
for i in range(number_samples):
  subject_name = subject_IDs[i]
  if subject_name in useless_samples:
    subject_index = get_index(lst=subject_IDs, item=subject_name)
    print('The index for sample ' + subject_name + ' is : ', subject_index)
  else:
    table_left = pd.read_table(localDir + subject_name + '/' + left, sep='\s+', names=names,
						  skiprows=skiprows)
    table_right = pd.read_table(localDir + subject_name + '/' + right, sep='\s+', names=names,
						  skiprows=skiprows)

    for j in range(len(feature_list)):
      feature_name = feature_list[j]
      left_features = table_left[feature_name].values.tolist()
      right_features = table_right[feature_name].values.tolist()
      all_features = left_features + right_features
      if len(all_features) != number_roi:
       print('The sample ' + subject_name + ' has mistake!')
      all_features = np.array(all_features)
      Desikan_Killiany_features[position, j*number_roi : (j+1)*number_roi] = all_features
    position = position + 1

if scaler == True:
	for i in range(len(feature_list)):
		Desikan_Killiany_features[:, i * number_roi: (i+1) * number_roi] = StandardScaler().fit_transform(Desikan_Killiany_features[:, i * number_roi: (i+1) * number_roi])

print('finished')

############################################### Load aseg features
print('constructing aseg features')
number_roi_aseg = 45
aseg = 'aseg.stats'
feature_list_aseg = ['Number of Voxels', 'Volume', 'Intensity normMean', 'Itensity normStdDev', 'Intensity normMin', 'Intensity normMax', 'Intensity normRange']
names_aseg = ['ColHeader Index', 'Segmentation Id ', 'Number of Voxels', 'Volume', 'Structure Name', 'Intensity normMean', 'Itensity normStdDev', 'Intensity normMin', 'Intensity normMax', 'Intensity normRange']
skiprows_aseg= list(range(0,79))
aseg_features = np.zeros((number_samples - len(useless_samples), number_roi_aseg * len(feature_list_aseg)))

position = 0
for i in range(number_samples):
	subject_name = subject_IDs[i]
	if subject_name in useless_samples:
		subject_index = get_index(lst=subject_IDs, item=subject_name)
		print('The index for sample ' + subject_name + ' is : ', subject_index)
	else:
		table_left = pd.read_table(localDir + subject_name + '/' + aseg, sep='\s+', names=names_aseg,
						  skiprows=skiprows_aseg)
		for j in range(len(feature_list_aseg)):
			feature_name = feature_list_aseg[j]
			left_features = table_left[feature_name].values.tolist()
			if len(left_features) != number_roi_aseg:
				print('The sample ' + subject_name + ' has mistake!')
			all_features = np.array(left_features)
			aseg_features[position, j*number_roi_aseg : (j+1)*number_roi_aseg] = all_features
		position = position + 1

if scaler == True:
	for i in range(len(feature_list_aseg)):
		aseg_features[:, i * number_roi_aseg: (i+1) * number_roi_aseg] = StandardScaler().fit_transform(aseg_features[:, i * number_roi_aseg: (i+1) * number_roi_aseg])
print('finished')

############################################### Load wmparc features
number_roi_wmparc = 70
wmparc = 'wmparc.stats'
feature_list_wmparc = ['Number of Voxels', 'Volume', 'Intensity normMean', 'Itensity normStdDev', 'Intensity normMin', 'Intensity normMax', 'Intensity normRange']
names_wmparc = ['ColHeader Index', 'Segmentation Id ', 'Number of Voxels', 'Volume', 'Structure Name', 'Intensity normMean', 'Itensity normStdDev', 'Intensity normMin', 'Intensity normMax', 'Intensity normRange']
skiprows_wmparc= list(range(0,65))
wmparc_features = np.zeros((number_samples - len(useless_samples), number_roi_wmparc * len(feature_list_wmparc)))

print('constructing wmparc features')
position = 0
for i in range(number_samples):
	subject_name = subject_IDs[i]
	if subject_name in useless_samples:
		subject_index = get_index(lst=subject_IDs, item=subject_name)
		print('The index for sample ' + subject_name + ' is : ', subject_index)
	else:
		table_left = pd.read_table(localDir + subject_name + '/' + wmparc, sep='\s+', names = names_wmparc,
						  skiprows=skiprows_wmparc)
		for j in range(len(feature_list_wmparc)):
			feature_name = feature_list_wmparc[j]
			left_features = table_left[feature_name].values.tolist()
			if len(left_features) != number_roi_wmparc:
				print('The sample ' + subject_name + ' has mistake!')
			all_features = np.array(left_features)
			wmparc_features[position, j*number_roi_wmparc : (j+1)*number_roi_wmparc] = all_features
		position = position + 1
if scaler == True:
	for i in range(len(feature_list_wmparc)):
		wmparc_features[:, i * number_roi_wmparc: (i+1) * number_roi_wmparc] = StandardScaler().fit_transform(wmparc_features[:, i * number_roi_wmparc: (i+1) * number_roi_wmparc])
print('finished')

############################################### concatenation
sMRI_features = np.concatenate((Desikan_Killiany_features, aseg_features, wmparc_features),axis = 1)
# Out:
# constructing Desikan-Killiany Atlas features
# The index for sample 51334 is :  [799]
# finished
# constructing aseg features
# The index for sample 51334 is :  [799]
# finished
# constructing wmparc features
# The index for sample 51334 is :  [799]
# finished

# %%
############################################### Combat ###############################################################
############################################### Combat ###############################################################
############################################### Combat ###############################################################
if combat == True:
	batch = []
	for i in range(len(sites)):
		batch.append(get_index(lst=unique_sites, item=sites[i])[0]+1)

	combat_labels = []
	combat_genders = []
	combat_ages = []
	for i in range(len(labels)):
		combat_labels.append(labels[i] + 1)
		combat_genders.append(genders[i])
		combat_ages.append(ages[i])

	new_all_samples_feature = sMRI_features.T
	covars = {}
	covars['batch'] = batch
	covars['labels'] = combat_labels
	covars['genders'] = combat_genders
	covars['ages'] = combat_ages
	covars = pd.DataFrame(covars)

	# To specify names of the variables that are categorical:
	categorical_cols = ['labels', 'genders']
	# To specify the name of the variable that encodes for the scanner/batch covariate:
	batch_col = 'batch'
	continuous_cols = ['ages']
	# Harmonization step:
	new_all_samples_feature = neuroCombat(dat=new_all_samples_feature,
										  covars=covars,
										  batch_col=batch_col,
										  categorical_cols=categorical_cols,
											continuous_cols=continuous_cols)["data"]
	sMRI_features = new_all_samples_feature.T
# Out:
# [neuroCombat] Creating design matrix
# [neuroCombat] Standardizing data across features
# [neuroCombat] Fitting L/S model and finding priors
# [neuroCombat] Finding parametric adjustments
# [neuroCombat] Final adjustment of data
# /content/drive/MyDrive/ABIDE/neuralCombat.py:325: RuntimeWarning: divide by zero encountered in true_divide
#   change = max((abs(g_new - g_old) / g_old).max(), (abs(d_new - d_old) / d_old).max())

# %%
############################################### phenotypic ###############################################################
############################################### phenotypic ###############################################################
############################################### phenotypic ###############################################################
ages_name = 'ages.mat'
ages = scio.loadmat(os.path.join(label_dir, ages_name))
ages = ages['ages']

gender_name = 'genders.mat'
genders = scio.loadmat(os.path.join(label_dir, gender_name))
genders = genders['genders']

FIQ_name = 'FIQS.mat'
FIQS = scio.loadmat(os.path.join(label_dir, FIQ_name))
FIQS = FIQS['FIQS']

NUM_name = 'NUM.mat'
NUM = scio.loadmat(os.path.join(label_dir, NUM_name))
NUMS = NUM['NUM']

PEC_name = 'PEC.mat'
PEC = scio.loadmat(os.path.join(label_dir, PEC_name))
PECS = PEC['PEC']

RAT_name = 'RAT.mat'
RAT = scio.loadmat(os.path.join(label_dir, RAT_name))
RATS = RAT['RAT']

age = np.zeros((number_samples - len(useless_samples), 1))
gender = np.zeros((number_samples - len(useless_samples), 1))
FIQ = np.zeros((number_samples - len(useless_samples), 1))
NUM = np.zeros((number_samples - len(useless_samples), 1))
PEC = np.zeros((number_samples - len(useless_samples), 1))
RAT = np.zeros((number_samples - len(useless_samples), 1))

position = 0
print('constructing phenotypic features')
for i in range(number_samples):
	subject_name = subject_IDs[i]
	if subject_name in useless_samples:
		subject_index = get_index(lst=subject_IDs, item=subject_name)
		print('The index for sample ' + subject_name + ' is : ', subject_index)
	else:
		subject_index = get_index(lst=subject_IDs, item=subject_name)
		age[position] = float(ages[subject_index[0]].replace(' ', ''))
		gender[position] = int(genders[subject_index[0]]) + 1
		FIQ[position] = int(FIQS[subject_index[0]])
		NUM[position] = float(NUMS[subject_index[0]])
		PEC[position] = float(PECS[subject_index[0]])
		RAT[position] = int(RATS[subject_index[0]])
		position = position + 1
FIQ[FIQ == -9999] = 108

if scaler == True:

  age[:,0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(age[:,0], axis = 1)))
  FIQ[:, 0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(FIQ[:, 0], axis = 1)))
  NUM[:, 0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(NUM[:, 0], axis = 1)))
  PEC[:, 0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(PEC[:, 0], axis = 1)))

# age, gender, FIQ, NUM, PEC, RAT
for i in range(3):
	sMRI_features = np.concatenate((sMRI_features, age, gender, FIQ, NUM, PEC, RAT),axis = 1)
# Out:
# constructing phenotypic features
# The index for sample 51334 is :  [799]

# %%
dist_train = {}
dist_validation = {}
dist_test = {}
for i in range(k_fold):
	dist_train[str(i + 1)] = []
	dist_validation[str(i + 1)] = []
	dist_test[str(i + 1)] = []

for each_site in unique_sites:
	index_site = get_index(sites, each_site)
	label = np.zeros((len(index_site)))
	for i in range(len(index_site)):
		index = index_site[i]
		label[i] = int(labels[int(index)])
	########################################### StratifiedKFold ####################################################
	sfolder = StratifiedKFold(n_splits=k_fold,random_state=0,shuffle=True)
	group = 0
	for train, validation in sfolder.split(index_site,label):
		for i in train:
			dist_train[str(group + 1)].append(index_site[i])
			name = 0
		for j in validation:
			dist_validation[str(group + 1)].append(index_site[j])
			name = 0
		group = group+1

	group = 0
	for train, validation in sfolder.split(index_site,label):
		if group == 0:
			for j in validation:
				dist_test[str(group + k_fold)].append(index_site[j])
				dist_train[str(group + k_fold)].remove(index_site[j])
		else:
			for j in validation:
				dist_test[str(group)].append(index_site[j])
				dist_train[str(group)].remove(index_site[j])
		group = group+1

# %%
import torch
import torch_geometric as tg
from torch.nn import Linear as Lin, Sequential as Seq
import torch.nn.functional as F
from torch import nn

############################################### PAE and EV-GCN ###############################################################
############################################### PAE and EV-GCN ###############################################################
############################################### PAE and EV-GCN ###############################################################
class PAE(torch.nn.Module):
    def __init__(self, input_dim, dropout=0.2):
        super(PAE, self).__init__()
        hidden=128
        self.parser =nn.Sequential(
                nn.Linear(input_dim, hidden, bias=True),
                nn.ReLU(inplace=True),
                nn.BatchNorm1d(hidden),
                nn.Dropout(dropout),
                nn.Linear(hidden, hidden, bias=True),
                )
        self.cos = nn.CosineSimilarity(dim=1, eps=1e-8)
        self.input_dim = input_dim
        self.model_init()
        self.relu = nn.ReLU(inplace=True)
        self.elu = nn.ReLU()

    def forward(self, x):
        x1 = x[:,0:self.input_dim]
        x2 = x[:,self.input_dim:]
        h1 = self.parser(x1)
        h2 = self.parser(x2)
        p = (self.cos(h1,h2) + 1)*0.5
        return p

    def model_init(self):
        for m in self.modules():
            if isinstance(m, Lin):
                torch.nn.init.kaiming_normal_(m.weight)
                m.weight.requires_grad = True
                if m.bias is not None:
                    m.bias.data.zero_()
                    m.bias.requires_grad = True


class EV_GCN(torch.nn.Module):
    def __init__(self, input_dim, num_classes, dropout, edgenet_input_dim, edge_dropout, hgc, lg):
        super(EV_GCN, self).__init__()
        K=2
        hidden = [hgc for i in range(lg)]
        self.dropout = dropout 
        self.edge_dropout = edge_dropout  
        bias = False 
        self.relu = torch.nn.ReLU(inplace=True) 
        self.lg = lg 
        self.gconv = nn.ModuleList()
        for i in range(lg): 
            in_channels = input_dim if i==0  else hidden[i-1]
            self.gconv.append(tg.nn.ChebConv(in_channels, hidden[i], K, normalization='sym', bias=bias)) 
        cls_input_dim = sum(hidden) 

        self.cls = nn.Sequential(
                torch.nn.Linear(cls_input_dim, 256),
                torch.nn.ReLU(inplace=True),
                nn.BatchNorm1d(256), 
                torch.nn.Linear(256, num_classes))

        self.edge_net = PAE(input_dim=edgenet_input_dim//2, dropout=dropout)
        self.model_init()
        self.softmax = nn.LogSoftmax(dim=1)

    def model_init(self):
        for m in self.modules():
            if isinstance(m, Lin):
                torch.nn.init.kaiming_normal_(m.weight)
                m.weight.requires_grad = True
                if m.bias is not None:
                    m.bias.data.zero_()
                    m.bias.requires_grad = True

    def forward(self, features, edge_index, edgenet_input, enforce_edropout=False): 
        if self.edge_dropout>0:  
            if enforce_edropout or self.training: 
                one_mask = torch.ones([edgenet_input.shape[0],1]).cuda() 
                self.drop_mask = F.dropout(one_mask, self.edge_dropout, True)
                self.bool_mask = torch.squeeze(self.drop_mask.type(torch.bool))
                edge_index = edge_index[:, self.bool_mask]
                edgenet_input = edgenet_input[self.bool_mask] 


        edge_weight = torch.squeeze(self.edge_net(edgenet_input))
        features = F.dropout(features, self.dropout, self.training)
        h = self.relu(self.gconv[0](features, edge_index, edge_weight)) 
        h0 = h
        for i in range(1, self.lg): 
            h = F.dropout(h, self.dropout, self.training)
            h= self.relu(self.gconv[i](h, edge_index, edge_weight)) 
            jk = torch.cat((h0, h), axis=1)
            h0 = jk
        logit = self.cls(jk)


        return self.softmax(logit), edge_weight

# %%
EV_GCN_labels = np.zeros((number_samples - len(useless_samples), 2))
for i in range(len(labels)):
    if labels[i] == 1:
        EV_GCN_labels[i,0] = 1
    else:
        EV_GCN_labels[i,1] = 1


all_subject_IDs = get_ids(number_samples,dir_path=label_dir)
all_subject_IDs = all_subject_IDs.tolist()
for i in useless_samples:
    subject_IDs.remove(i)

# %%
from scipy.spatial import distance

def create_affinity_graph_from_scores(scores, pd_dict):
    num_nodes = len(pd_dict[scores[0]]) 
    graph = np.zeros((num_nodes, num_nodes))

    for l in scores:
        label_dict = pd_dict[l]

        if l in ['AGE_AT_SCAN', 'FIQ']:
            for k in range(num_nodes):
                for j in range(k + 1, num_nodes):
                    try:
                        val = abs(float(label_dict[k]) - float(label_dict[j]))
                        if val < 2:
                            graph[k, j] += 1
                            graph[j, k] += 1
                    except ValueError:  # missing label
                        pass

        else:
            for k in range(num_nodes):
                for j in range(k + 1, num_nodes):
                    if label_dict[k] == label_dict[j]:
                        graph[k, j] += 1
                        graph[j, k] += 1

    return graph

def get_static_affinity_adj(features, pd_dict):
    pd_affinity = create_affinity_graph_from_scores(['SEX', 'SITE_ID'], pd_dict) 
    distv = distance.pdist(features, metric='correlation') 
    dist = distance.squareform(distv)  
    sigma = np.mean(dist)
    feature_sim = np.exp(- dist ** 2 / (2 * sigma ** 2))
    adj = pd_affinity * feature_sim  

    return adj



data = {}
for fold in range(1, k_fold+1):
  data[str(fold)] = []
  selector = feature_selection(sMRI_features, labels, dist_train[str(fold)], new_number_features)
  fold_data = selector.transform(sMRI_features)

  n = fold_data.shape[0]
  num_edge = n * n
  edge_index = np.zeros([2, num_edge], dtype=np.int64)
  edgenet_input = np.zeros([num_edge, 2*phonetic_data.shape[1]], dtype=np.float32) 
  aff_score = np.zeros(num_edge, dtype=np.float32)
  
  aff_adj = get_static_affinity_adj(fold_data, pd_dict)  

########################################################## Change #########################################################################
########################################################## Change #########################################################################
########################################################## Change #########################################################################
# !!! Must enter the entire the whole population graph instead of the upper triangle area, otherwise information leakage will occur

  flatten_ind = 0
  for i in range(n): 
    for j in range(n):
      edge_index[:, flatten_ind] = [i, j]
      edgenet_input[flatten_ind] = np.concatenate((phonetic_data[i], phonetic_data[j]))
      aff_score[flatten_ind] = aff_adj[i][j]
      flatten_ind += 1
########################################################## Change #########################################################################
########################################################## Change #########################################################################
########################################################## Change #########################################################################

  keep_ind = np.where(aff_score > 1.1)[0]
  edge_index = edge_index[:, keep_ind]
  edgenet_input = edgenet_input[keep_ind]
  edgenet_input = (edgenet_input- edgenet_input.mean(axis=0)) / edgenet_input.std(axis=0)

  data[str(fold)].append(fold_data)
  data[str(fold)].append(EV_GCN_labels)
  data[str(fold)].append(edge_index)
  data[str(fold)].append(edgenet_input)

# %%
############################################### Train, validaiton, test pipelines ###############################################################
############################################### Train, validaiton, test pipelines ###############################################################
############################################### Train, validaiton, test pipelines ###############################################################
def train_EV_GCN(args, model, all_data, fold_train_index, fold_validation_index, fold_test_index, scheduler):

    model.train()
    data = torch.from_numpy(all_data[0])
    data = Variable(data, requires_grad=True)
    data = data.float()

    target = torch.from_numpy(all_data[1])
    target = target.float().long()

    edge_index = torch.from_numpy(all_data[2])
    edge_index = Variable(edge_index, requires_grad=False)

    edgenet_input = torch.from_numpy(all_data[3])
    edgenet_input = Variable(edgenet_input, requires_grad=True)
    edgenet_input = edgenet_input.float()

    if args.cuda:
        data, target, edge_index, edgenet_input = data.cuda(), target.cuda(), edge_index.cuda(), edgenet_input.cuda()

    scheduler.zero_grad()
    out, _ = model(data, edge_index, edgenet_input)
    out = out[fold_train_index,:]
    target = target[fold_train_index, :]

    cross_loss = torch.nn.functional.nll_loss(out, torch.max(target, 1)[1]) # only train set will be included
    out = torch.max(out, 1)[1]
    target = torch.max(target, 1)[1]
    target = target.cpu().numpy()
    out = out.cpu().numpy()
    cross_loss.backward()
    scheduler.step()

    ############################## validation and test ################################################################################
    val_target, val_out, val_loss = validation_EV_GCN(args, model, all_data, fold_validation_index)
    test_target, test_out, test_out_prob, test_loss = test_EV_GCN(args, model, all_data, fold_test_index)

    return model, target, out, cross_loss.item(), val_target, val_out,val_loss, test_target, test_out, test_out_prob, test_loss

    
def validation_EV_GCN(args, model,all_data,  fold_validation_index):

    model.eval()
    data = torch.from_numpy(all_data[0])
    data = Variable(data, requires_grad=False)
    data = data.float()

    target = torch.from_numpy(all_data[1])
    target = target.float().long()

    edge_index = torch.from_numpy(all_data[2])
    edge_index = Variable(edge_index, requires_grad=False)

    edgenet_input = torch.from_numpy(all_data[3])
    edgenet_input = Variable(edgenet_input, requires_grad=False)
    edgenet_input = edgenet_input.float()

    if args.cuda:
        data, target, edge_index, edgenet_input = data.cuda(), target.cuda(), edge_index.cuda(), edgenet_input.cuda()

    out, _ = model(data, edge_index, edgenet_input)
    out = out[fold_validation_index, :]
    target = target[fold_validation_index, :]
    cross_loss = torch.nn.functional.nll_loss(out, torch.max(target, 1)[1])

    out = torch.max(out, 1)[1]
    target = torch.max(target, 1)[1]
    target = target.cpu().numpy()
    out = out.cpu().numpy()

    return target, out, cross_loss.item()


def test_EV_GCN(args, model, all_data,  fold_test_index):

    model.eval()

    data = torch.from_numpy(all_data[0])
    data = Variable(data, requires_grad=False)
    data = data.float()

    target = torch.from_numpy(all_data[1])
    target = target.float().long()

    edge_index = torch.from_numpy(all_data[2])
    edge_index = Variable(edge_index, requires_grad=False)

    edgenet_input = torch.from_numpy(all_data[3])
    edgenet_input = Variable(edgenet_input, requires_grad=False)
    edgenet_input = edgenet_input.float()

    if args.cuda:
        data, target, edge_index, edgenet_input = data.cuda(), target.cuda(), edge_index.cuda(), edgenet_input.cuda()

    out, _ = model(data, edge_index, edgenet_input)
    out = out[fold_test_index, :]
    target = target[fold_test_index, :]
    cross_loss = torch.nn.functional.nll_loss(out, torch.max(target, 1)[1])

    out_prob = torch.exp(out)
    out = torch.max(out, 1)[1]
    target = torch.max(target, 1)[1]
    target = target.cpu().numpy()
    out = out.cpu().numpy()
    out_prob = out_prob.cpu().detach().numpy()


    return target, out, out_prob, cross_loss.item()

# %%
########################################### Training setting ################################################
########################################### Training setting ################################################
########################################### Training setting ################################################
torch.cuda.empty_cache()
parser = argparse.ArgumentParser()
parser.add_argument('--ngpu', type=int, default=1)
parser.add_argument('--nEpochs', type=int, default=200)
parser.add_argument('--start-epoch', default=0, type=int, metavar='N',
                    help='manual epoch number (useful on restarts)')
parser.add_argument('--no-cuda', action='store_true')
parser.add_argument('--opt', type=str, default='adam')
parser.add_argument('--seed', type=int, default=1)
parser.add_argument('--input_dimension', type=int, default=new_number_features)

parser.add_argument('--hgc', type=int, default=16, help='hidden units of gconv layer')
parser.add_argument('--lg', type=int, default=4, help='number of gconv layers')
parser.add_argument('--lr', default=0.01, type=float, help='initial learning rate')
parser.add_argument('--wd', default=5e-5, type=float, help='weight decay')
parser.add_argument('--num_iter', default=300, type=int, help='number of epochs for training')
parser.add_argument('--edropout', type=float, default=0.3, help='edge dropout rate')
parser.add_argument('--dropout', default=0.2, type=float, help='ratio of dropout')
parser.add_argument('--num_classes', type=int, default=2, help='number of classes')

#
args, unknown = parser.parse_known_args()
args.cuda = not args.no_cuda and torch.cuda.is_available()
torch.manual_seed(args.seed)
if args.cuda:
    torch.cuda.manual_seed(args.seed)
    
gpu_ids = range(args.ngpu)
train = train_EV_GCN

# %%
########################################### Training ################################################
########################################### Training ################################################
########################################### Training ################################################
for fold in range(1, k_fold+1):
  model = EV_GCN(args.input_dimension, args.num_classes, args.dropout, edge_dropout=args.edropout, hgc=args.hgc, lg=args.lg, edgenet_input_dim=2*phonetic_data.shape[1])
  print('  + Number of params: {}'.format(
    sum([p.data.nelement() for p in model.parameters()])))
  model = nn.parallel.DataParallel(model, device_ids=gpu_ids)
  if args.cuda:
    model = model.cuda()
  optimizer = optim.Adam(model.parameters(), lr = args.lr)

  best_validation_accuracy = 0
  Train_accuracy_list =[]
  Train_loss_list = []
  Val_accuracy_list =[]
  Val_loss_list = []
  Test_accuracy_list =[]
  Test_loss_list = []

  for epoch in range(1, args.nEpochs + 1):

    model, train_target, train_out, train_loss, val_target, val_out, val_loss, test_target, test_out, test_prob, test_loss = train(args, model, data[str(fold)], dist_train[str(fold)], dist_validation[str(fold)], dist_test[str(fold)], optimizer)

    train_accuracy = metrics.accuracy_score(train_target, train_out)
    val_accuracy = metrics.accuracy_score(val_target, val_out)
    test_accuracy = metrics.accuracy_score(test_target, test_out)
    Train_accuracy_list.append(train_accuracy)
    Val_accuracy_list.append(val_accuracy)
    Test_accuracy_list.append(test_accuracy)
    Train_loss_list.append(train_loss)
    Val_loss_list.append(val_loss)
    Test_loss_list.append(test_loss)

    if val_accuracy >=best_validation_accuracy:
      best_epoch = epoch
      best_validation_accuracy = val_accuracy
      corresponding_val_out = val_out
      corresponding_test_accuracy = test_accuracy
      corresponding_test_out = test_out
      corresponding_test_prob = test_prob

      print('Save models')
      save_model(model, save_path, 'EV_GCN_'+str(fold))

    print('Train Epoch: ' + str(epoch) + ': train loss : {:.8f}\t train accuracy : {:.8f}\t val accuracy : {:.8f}\t test accuracy : {:.8f}\t'.format(
      train_loss, train_accuracy, val_accuracy, test_accuracy))
  
  if fold == 1:
    all_fold_val_label = val_target
    all_fold_val_out = corresponding_val_out
    all_fold_test_label = test_target
    all_fold_test_out = corresponding_test_out
    all_fold_test_prob = corresponding_test_prob
  else:
    all_fold_val_label = np.concatenate((all_fold_val_label, val_target),axis = 0)
    all_fold_val_out = np.concatenate((all_fold_val_out, corresponding_val_out),axis = 0)
    all_fold_test_label = np.concatenate((all_fold_test_label, test_target),axis = 0)
    all_fold_test_out = np.concatenate((all_fold_test_out, corresponding_test_out),axis = 0)
    all_fold_test_prob = np.concatenate((all_fold_test_prob, corresponding_test_prob),axis = 0)

  x_axis = list(range(1, len(Train_accuracy_list)+1))
  plt.figure(figsize=(10,6))
  plt.plot(x_axis, Train_loss_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_loss_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_loss_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()

  plt.figure(figsize=(10,6))
  plt.plot(x_axis, Train_accuracy_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_accuracy_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_accuracy_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()


  test_fpr, test_tpr, te_thresholds = roc_curve(test_target, corresponding_test_prob[:,1],pos_label=1)
  test_auc = auc(test_fpr, test_tpr)
  print('\n')
  print('In fold ',str(fold))
  print('The best validaiton accuracy is: ',best_validation_accuracy)
  print('Happened at epoch: ',best_epoch)
  print('The corresponding test accuracy', corresponding_test_accuracy)
  print('The corresponding test AUC is: ',test_auc)
  print('\n')


  plt.grid()
  plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
  plt.plot([0,1],[0,1],'g--')
  plt.legend()
  plt.xlabel("False Positive Rate")
  plt.ylabel("True Positive Rate")
  plt.title("Test AUC(ROC curve)")
  plt.grid(color='black', linestyle='-', linewidth=0.5)
  plt.show()

print('Finish 5-fold training')
# Out:
#   + Number of params: 82402
# Save models
# Train Epoch: 1: train loss : 1.25173402	 train accuracy : 0.45596869	 val accuracy : 0.49450549	 test accuracy : 0.50847458
# Train Epoch: 2: train loss : 1.17911065	 train accuracy : 0.48923679	 val accuracy : 0.48901099	 test accuracy : 0.45197740
# Train Epoch: 3: train loss : 1.12721598	 train accuracy : 0.53228963	 val accuracy : 0.46153846	 test accuracy : 0.48587571
# Save models
# Train Epoch: 4: train loss : 0.74311006	 train accuracy : 0.60665362	 val accuracy : 0.54945055	 test accuracy : 0.54802260
# Save models
# Train Epoch: 5: train loss : 0.77474052	 train accuracy : 0.58708415	 val accuracy : 0.56043956	 test accuracy : 0.49717514
# Train Epoch: 6: train loss : 0.80566776	 train accuracy : 0.58512720	 val accuracy : 0.53846154	 test accuracy : 0.54802260
# Train Epoch: 7: train loss : 0.69971871	 train accuracy : 0.62622309	 val accuracy : 0.53296703	 test accuracy : 0.54802260
# Train Epoch: 8: train loss : 0.66215783	 train accuracy : 0.62818004	 val accuracy : 0.52197802	 test accuracy : 0.53672316
# Save models
# Train Epoch: 9: train loss : 0.62491244	 train accuracy : 0.67710372	 val accuracy : 0.56043956	 test accuracy : 0.54237288
# Save models
# Train Epoch: 10: train loss : 0.57666117	 train accuracy : 0.71232877	 val accuracy : 0.58241758	 test accuracy : 0.56497175
# Save models
# Train Epoch: 11: train loss : 0.54749465	 train accuracy : 0.71232877	 val accuracy : 0.59340659	 test accuracy : 0.57062147
# Save models
# Train Epoch: 12: train loss : 0.54211408	 train accuracy : 0.71624266	 val accuracy : 0.60989011	 test accuracy : 0.55932203
# Save models
# Train Epoch: 13: train loss : 0.53948385	 train accuracy : 0.71428571	 val accuracy : 0.62637363	 test accuracy : 0.54237288
# Save models
# Train Epoch: 14: train loss : 0.50415075	 train accuracy : 0.73776908	 val accuracy : 0.63736264	 test accuracy : 0.53672316
# Train Epoch: 15: train loss : 0.47610483	 train accuracy : 0.75146771	 val accuracy : 0.62087912	 test accuracy : 0.53107345
# Train Epoch: 16: train loss : 0.46120349	 train accuracy : 0.78669276	 val accuracy : 0.59890110	 test accuracy : 0.54237288
# Train Epoch: 17: train loss : 0.44592792	 train accuracy : 0.79256360	 val accuracy : 0.60439560	 test accuracy : 0.56497175
# Train Epoch: 18: train loss : 0.41056725	 train accuracy : 0.82778865	 val accuracy : 0.58791209	 test accuracy : 0.57062147
# Train Epoch: 19: train loss : 0.37356630	 train accuracy : 0.84540117	 val accuracy : 0.58791209	 test accuracy : 0.54237288
# Train Epoch: 20: train loss : 0.37188148	 train accuracy : 0.83365949	 val accuracy : 0.58241758	 test accuracy : 0.53672316
# Train Epoch: 21: train loss : 0.34198216	 train accuracy : 0.85714286	 val accuracy : 0.60439560	 test accuracy : 0.51977401
# Train Epoch: 22: train loss : 0.33464685	 train accuracy : 0.84735812	 val accuracy : 0.60989011	 test accuracy : 0.54237288
# Train Epoch: 23: train loss : 0.28822851	 train accuracy : 0.87475538	 val accuracy : 0.60439560	 test accuracy : 0.55367232
# Train Epoch: 24: train loss : 0.28917000	 train accuracy : 0.88062622	 val accuracy : 0.61538462	 test accuracy : 0.51977401
# Train Epoch: 25: train loss : 0.25602803	 train accuracy : 0.90410959	 val accuracy : 0.59890110	 test accuracy : 0.52542373
# Train Epoch: 26: train loss : 0.21923143	 train accuracy : 0.91976517	 val accuracy : 0.60439560	 test accuracy : 0.53107345
# Train Epoch: 27: train loss : 0.19836777	 train accuracy : 0.94520548	 val accuracy : 0.59340659	 test accuracy : 0.55367232
# Train Epoch: 28: train loss : 0.18582380	 train accuracy : 0.92563601	 val accuracy : 0.60439560	 test accuracy : 0.54237288
# Train Epoch: 29: train loss : 0.16527158	 train accuracy : 0.94520548	 val accuracy : 0.60989011	 test accuracy : 0.57062147
# Train Epoch: 30: train loss : 0.15529273	 train accuracy : 0.94324853	 val accuracy : 0.60439560	 test accuracy : 0.55367232
# Train Epoch: 31: train loss : 0.13033493	 train accuracy : 0.95890411	 val accuracy : 0.62087912	 test accuracy : 0.56497175
# Train Epoch: 32: train loss : 0.10562086	 train accuracy : 0.97260274	 val accuracy : 0.60989011	 test accuracy : 0.54237288
# Train Epoch: 33: train loss : 0.09543356	 train accuracy : 0.96868885	 val accuracy : 0.61538462	 test accuracy : 0.55932203
# Train Epoch: 34: train loss : 0.08282664	 train accuracy : 0.98238748	 val accuracy : 0.61538462	 test accuracy : 0.57062147
# Train Epoch: 35: train loss : 0.07710863	 train accuracy : 0.97651663	 val accuracy : 0.62637363	 test accuracy : 0.57062147
# Train Epoch: 36: train loss : 0.06954709	 train accuracy : 0.97455969	 val accuracy : 0.63186813	 test accuracy : 0.56497175
# Train Epoch: 37: train loss : 0.05059344	 train accuracy : 0.99021526	 val accuracy : 0.62087912	 test accuracy : 0.56497175
# Train Epoch: 38: train loss : 0.03556527	 train accuracy : 0.99412916	 val accuracy : 0.60989011	 test accuracy : 0.55932203
# Train Epoch: 39: train loss : 0.03484173	 train accuracy : 0.99217221	 val accuracy : 0.61538462	 test accuracy : 0.55932203
# Train Epoch: 40: train loss : 0.03676771	 train accuracy : 0.99217221	 val accuracy : 0.61538462	 test accuracy : 0.57627119
# Train Epoch: 41: train loss : 0.02167282	 train accuracy : 0.99804305	 val accuracy : 0.61538462	 test accuracy : 0.57062147
# Train Epoch: 42: train loss : 0.01996696	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.57062147
# Train Epoch: 43: train loss : 0.01578480	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.57062147
# Train Epoch: 44: train loss : 0.02210261	 train accuracy : 0.99412916	 val accuracy : 0.62087912	 test accuracy : 0.57062147
# Train Epoch: 45: train loss : 0.02406141	 train accuracy : 0.99217221	 val accuracy : 0.60989011	 test accuracy : 0.57062147
# Train Epoch: 46: train loss : 0.01398253	 train accuracy : 0.99804305	 val accuracy : 0.60989011	 test accuracy : 0.58192090
# Train Epoch: 47: train loss : 0.01239205	 train accuracy : 0.99804305	 val accuracy : 0.61538462	 test accuracy : 0.58192090
# Train Epoch: 48: train loss : 0.01231535	 train accuracy : 0.99608611	 val accuracy : 0.61538462	 test accuracy : 0.56497175
# Train Epoch: 49: train loss : 0.01343397	 train accuracy : 0.99412916	 val accuracy : 0.62087912	 test accuracy : 0.57062147
# Train Epoch: 50: train loss : 0.01106273	 train accuracy : 0.99608611	 val accuracy : 0.62087912	 test accuracy : 0.56497175
# Train Epoch: 51: train loss : 0.00840245	 train accuracy : 0.99804305	 val accuracy : 0.62087912	 test accuracy : 0.56497175
# Train Epoch: 52: train loss : 0.01313390	 train accuracy : 0.99608611	 val accuracy : 0.62637363	 test accuracy : 0.57627119
# Save models
# Train Epoch: 53: train loss : 0.00536517	 train accuracy : 1.00000000	 val accuracy : 0.64835165	 test accuracy : 0.58192090
# Train Epoch: 54: train loss : 0.01032694	 train accuracy : 0.99608611	 val accuracy : 0.62087912	 test accuracy : 0.58192090
# Train Epoch: 55: train loss : 0.00594639	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.56497175
# Train Epoch: 56: train loss : 0.00511033	 train accuracy : 0.99804305	 val accuracy : 0.63186813	 test accuracy : 0.55367232
# Train Epoch: 57: train loss : 0.00919789	 train accuracy : 0.99608611	 val accuracy : 0.63186813	 test accuracy : 0.55932203
# Train Epoch: 58: train loss : 0.00347211	 train accuracy : 1.00000000	 val accuracy : 0.63186813	 test accuracy : 0.56497175
# Train Epoch: 59: train loss : 0.00557418	 train accuracy : 0.99804305	 val accuracy : 0.63186813	 test accuracy : 0.56497175
# Train Epoch: 60: train loss : 0.00447691	 train accuracy : 0.99804305	 val accuracy : 0.63186813	 test accuracy : 0.57062147
# Train Epoch: 61: train loss : 0.01539071	 train accuracy : 0.99412916	 val accuracy : 0.62637363	 test accuracy : 0.57627119
# Save models
# Train Epoch: 62: train loss : 0.00987431	 train accuracy : 0.99804305	 val accuracy : 0.65384615	 test accuracy : 0.57062147
# Train Epoch: 63: train loss : 0.00303567	 train accuracy : 1.00000000	 val accuracy : 0.64835165	 test accuracy : 0.58192090
# Train Epoch: 64: train loss : 0.00645592	 train accuracy : 0.99804305	 val accuracy : 0.62637363	 test accuracy : 0.58757062
# Train Epoch: 65: train loss : 0.00518118	 train accuracy : 0.99804305	 val accuracy : 0.61538462	 test accuracy : 0.58192090
# Train Epoch: 66: train loss : 0.00519489	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.57627119
# Train Epoch: 67: train loss : 0.00429746	 train accuracy : 0.99804305	 val accuracy : 0.61538462	 test accuracy : 0.57627119
# Train Epoch: 68: train loss : 0.01884522	 train accuracy : 0.99217221	 val accuracy : 0.62087912	 test accuracy : 0.58192090
# Train Epoch: 69: train loss : 0.00572048	 train accuracy : 0.99804305	 val accuracy : 0.62637363	 test accuracy : 0.57062147
# Train Epoch: 70: train loss : 0.01150171	 train accuracy : 0.99217221	 val accuracy : 0.59890110	 test accuracy : 0.57627119
# Train Epoch: 71: train loss : 0.00108057	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.59322034
# Train Epoch: 72: train loss : 0.00265277	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.58757062
# Train Epoch: 73: train loss : 0.01108272	 train accuracy : 0.99608611	 val accuracy : 0.60989011	 test accuracy : 0.58192090
# Train Epoch: 74: train loss : 0.00519647	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.59322034
# Train Epoch: 75: train loss : 0.00472097	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.59322034
# Train Epoch: 76: train loss : 0.00142986	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.58192090
# Train Epoch: 77: train loss : 0.00454922	 train accuracy : 0.99804305	 val accuracy : 0.60989011	 test accuracy : 0.58757062
# Train Epoch: 78: train loss : 0.00413836	 train accuracy : 0.99804305	 val accuracy : 0.61538462	 test accuracy : 0.57627119
# Train Epoch: 79: train loss : 0.00143107	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.57062147
# Train Epoch: 80: train loss : 0.00391804	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.58757062
# Train Epoch: 81: train loss : 0.00946553	 train accuracy : 0.99217221	 val accuracy : 0.62087912	 test accuracy : 0.58192090
# Train Epoch: 82: train loss : 0.02358949	 train accuracy : 0.99217221	 val accuracy : 0.60439560	 test accuracy : 0.58192090
# Train Epoch: 83: train loss : 0.00271939	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.57062147
# Train Epoch: 84: train loss : 0.00218992	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.57627119
# Train Epoch: 85: train loss : 0.01365552	 train accuracy : 0.99608611	 val accuracy : 0.61538462	 test accuracy : 0.56497175
# Train Epoch: 86: train loss : 0.00563572	 train accuracy : 0.99804305	 val accuracy : 0.60989011	 test accuracy : 0.57062147
# Train Epoch: 87: train loss : 0.01154444	 train accuracy : 0.99804305	 val accuracy : 0.60989011	 test accuracy : 0.56497175
# Train Epoch: 88: train loss : 0.00424957	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.55367232
# Train Epoch: 89: train loss : 0.00337001	 train accuracy : 1.00000000	 val accuracy : 0.59890110	 test accuracy : 0.57062147
# Train Epoch: 90: train loss : 0.00688610	 train accuracy : 0.99608611	 val accuracy : 0.62087912	 test accuracy : 0.57062147
# Train Epoch: 91: train loss : 0.00387166	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.57627119
# Train Epoch: 92: train loss : 0.00432045	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.58192090
# Train Epoch: 93: train loss : 0.00409154	 train accuracy : 0.99804305	 val accuracy : 0.60989011	 test accuracy : 0.57627119
# Train Epoch: 94: train loss : 0.00389637	 train accuracy : 0.99804305	 val accuracy : 0.60989011	 test accuracy : 0.57062147
# Train Epoch: 95: train loss : 0.00666117	 train accuracy : 0.99804305	 val accuracy : 0.61538462	 test accuracy : 0.56497175
# Train Epoch: 96: train loss : 0.00078709	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.57627119
# Train Epoch: 97: train loss : 0.01138243	 train accuracy : 0.99804305	 val accuracy : 0.60439560	 test accuracy : 0.56497175
# Train Epoch: 98: train loss : 0.00561375	 train accuracy : 0.99804305	 val accuracy : 0.60439560	 test accuracy : 0.55932203
# Train Epoch: 99: train loss : 0.00598764	 train accuracy : 0.99804305	 val accuracy : 0.61538462	 test accuracy : 0.55932203
# Train Epoch: 100: train loss : 0.00819240	 train accuracy : 0.99412916	 val accuracy : 0.60439560	 test accuracy : 0.55367232
# Train Epoch: 101: train loss : 0.00746023	 train accuracy : 0.99412916	 val accuracy : 0.59340659	 test accuracy : 0.56497175
# Train Epoch: 102: train loss : 0.00413569	 train accuracy : 0.99804305	 val accuracy : 0.60989011	 test accuracy : 0.57627119
# Train Epoch: 103: train loss : 0.00825384	 train accuracy : 0.99608611	 val accuracy : 0.63186813	 test accuracy : 0.59322034
# Train Epoch: 104: train loss : 0.00289037	 train accuracy : 1.00000000	 val accuracy : 0.64285714	 test accuracy : 0.59887006
# Train Epoch: 105: train loss : 0.00205828	 train accuracy : 1.00000000	 val accuracy : 0.64835165	 test accuracy : 0.59887006
# Save models
# Train Epoch: 106: train loss : 0.00894375	 train accuracy : 0.99804305	 val accuracy : 0.65384615	 test accuracy : 0.58192090
# Train Epoch: 107: train loss : 0.00323321	 train accuracy : 0.99804305	 val accuracy : 0.64835165	 test accuracy : 0.59322034
# Train Epoch: 108: train loss : 0.00507859	 train accuracy : 0.99804305	 val accuracy : 0.64835165	 test accuracy : 0.58192090
# Train Epoch: 109: train loss : 0.00401916	 train accuracy : 0.99804305	 val accuracy : 0.64285714	 test accuracy : 0.58192090
# Train Epoch: 110: train loss : 0.00887392	 train accuracy : 0.99608611	 val accuracy : 0.63186813	 test accuracy : 0.58757062
# Train Epoch: 111: train loss : 0.00341629	 train accuracy : 0.99804305	 val accuracy : 0.62087912	 test accuracy : 0.59887006
# Train Epoch: 112: train loss : 0.00505278	 train accuracy : 0.99804305	 val accuracy : 0.60439560	 test accuracy : 0.59322034
# Train Epoch: 113: train loss : 0.00739032	 train accuracy : 0.99608611	 val accuracy : 0.60989011	 test accuracy : 0.59887006
# Train Epoch: 114: train loss : 0.01420578	 train accuracy : 0.99412916	 val accuracy : 0.63736264	 test accuracy : 0.60451977
# Train Epoch: 115: train loss : 0.00245193	 train accuracy : 1.00000000	 val accuracy : 0.63186813	 test accuracy : 0.61581921
# Train Epoch: 116: train loss : 0.00176835	 train accuracy : 1.00000000	 val accuracy : 0.63186813	 test accuracy : 0.59322034
# Train Epoch: 117: train loss : 0.00431139	 train accuracy : 0.99804305	 val accuracy : 0.63736264	 test accuracy : 0.59322034
# Train Epoch: 118: train loss : 0.00903347	 train accuracy : 0.99412916	 val accuracy : 0.64285714	 test accuracy : 0.59887006
# Train Epoch: 119: train loss : 0.00228312	 train accuracy : 1.00000000	 val accuracy : 0.63186813	 test accuracy : 0.58757062
# Train Epoch: 120: train loss : 0.00179065	 train accuracy : 1.00000000	 val accuracy : 0.63186813	 test accuracy : 0.58757062
# Train Epoch: 121: train loss : 0.00352725	 train accuracy : 0.99804305	 val accuracy : 0.61538462	 test accuracy : 0.59322034
# Train Epoch: 122: train loss : 0.00968643	 train accuracy : 0.99608611	 val accuracy : 0.60989011	 test accuracy : 0.59887006
# Train Epoch: 123: train loss : 0.00251726	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.60451977
# Train Epoch: 124: train loss : 0.00096342	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.59322034
# Train Epoch: 125: train loss : 0.00178958	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.59322034
# Train Epoch: 126: train loss : 0.00113852	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.59887006
# Train Epoch: 127: train loss : 0.00125856	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.59887006
# Train Epoch: 128: train loss : 0.00378687	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.59322034
# Train Epoch: 129: train loss : 0.00183402	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.59322034
# Train Epoch: 130: train loss : 0.00230114	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.59322034
# Train Epoch: 131: train loss : 0.00598380	 train accuracy : 0.99804305	 val accuracy : 0.62087912	 test accuracy : 0.61016949
# Train Epoch: 132: train loss : 0.00408366	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.61581921
# Train Epoch: 133: train loss : 0.00264165	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.62146893
# Train Epoch: 134: train loss : 0.00162216	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.62711864
# Train Epoch: 135: train loss : 0.00092927	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.62146893
# Train Epoch: 136: train loss : 0.00201140	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.61016949
# Train Epoch: 137: train loss : 0.00709041	 train accuracy : 0.99804305	 val accuracy : 0.62637363	 test accuracy : 0.61016949
# Train Epoch: 138: train loss : 0.00504507	 train accuracy : 0.99804305	 val accuracy : 0.63186813	 test accuracy : 0.60451977
# Train Epoch: 139: train loss : 0.00131728	 train accuracy : 1.00000000	 val accuracy : 0.63186813	 test accuracy : 0.60451977
# Train Epoch: 140: train loss : 0.00118876	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.61016949
# Train Epoch: 141: train loss : 0.00150815	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.60451977
# Train Epoch: 142: train loss : 0.00468212	 train accuracy : 0.99804305	 val accuracy : 0.61538462	 test accuracy : 0.59887006
# Train Epoch: 143: train loss : 0.00173497	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.59887006
# Train Epoch: 144: train loss : 0.00798581	 train accuracy : 0.99804305	 val accuracy : 0.62087912	 test accuracy : 0.59887006
# Train Epoch: 145: train loss : 0.00090567	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.59322034
# Train Epoch: 146: train loss : 0.00108039	 train accuracy : 1.00000000	 val accuracy : 0.63186813	 test accuracy : 0.57062147
# Train Epoch: 147: train loss : 0.00102853	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.57062147
# Train Epoch: 148: train loss : 0.00189441	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.56497175
# Train Epoch: 149: train loss : 0.00343500	 train accuracy : 0.99804305	 val accuracy : 0.62637363	 test accuracy : 0.56497175
# Train Epoch: 150: train loss : 0.00517338	 train accuracy : 0.99804305	 val accuracy : 0.62637363	 test accuracy : 0.55932203
# Train Epoch: 151: train loss : 0.00455475	 train accuracy : 0.99804305	 val accuracy : 0.62637363	 test accuracy : 0.55932203
# Train Epoch: 152: train loss : 0.00811381	 train accuracy : 0.99804305	 val accuracy : 0.62637363	 test accuracy : 0.55932203
# Train Epoch: 153: train loss : 0.00200995	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.56497175
# Train Epoch: 154: train loss : 0.00192318	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.56497175
# Train Epoch: 155: train loss : 0.00239767	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.55932203
# Train Epoch: 156: train loss : 0.00073295	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.55367232
# Train Epoch: 157: train loss : 0.00087103	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.55932203
# Train Epoch: 158: train loss : 0.00139048	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.55367232
# Train Epoch: 159: train loss : 0.00072467	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.55367232
# Train Epoch: 160: train loss : 0.00100193	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.55932203
# Train Epoch: 161: train loss : 0.00176233	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.55367232
# Train Epoch: 162: train loss : 0.00151221	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.55932203
# Train Epoch: 163: train loss : 0.00906332	 train accuracy : 0.99608611	 val accuracy : 0.61538462	 test accuracy : 0.55932203
# Train Epoch: 164: train loss : 0.00172918	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.56497175
# Train Epoch: 165: train loss : 0.00151459	 train accuracy : 1.00000000	 val accuracy : 0.63736264	 test accuracy : 0.56497175
# Train Epoch: 166: train loss : 0.00051818	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.57627119
# Train Epoch: 167: train loss : 0.00070482	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.57062147
# Train Epoch: 168: train loss : 0.00122363	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.56497175
# Train Epoch: 169: train loss : 0.00312826	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.57062147
# Train Epoch: 170: train loss : 0.01174995	 train accuracy : 0.99804305	 val accuracy : 0.59890110	 test accuracy : 0.57627119
# Train Epoch: 171: train loss : 0.00139918	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.57062147
# Train Epoch: 172: train loss : 0.01597199	 train accuracy : 0.99608611	 val accuracy : 0.62087912	 test accuracy : 0.59322034
# Train Epoch: 173: train loss : 0.00412870	 train accuracy : 0.99804305	 val accuracy : 0.62087912	 test accuracy : 0.58757062
# Train Epoch: 174: train loss : 0.00046179	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.57627119
# Train Epoch: 175: train loss : 0.00875641	 train accuracy : 0.99804305	 val accuracy : 0.61538462	 test accuracy : 0.57627119
# Train Epoch: 176: train loss : 0.00094131	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.58757062
# Train Epoch: 177: train loss : 0.02100164	 train accuracy : 0.99804305	 val accuracy : 0.61538462	 test accuracy : 0.58757062
# Train Epoch: 178: train loss : 0.01930202	 train accuracy : 0.99804305	 val accuracy : 0.61538462	 test accuracy : 0.58192090
# Train Epoch: 179: train loss : 0.00307444	 train accuracy : 0.99804305	 val accuracy : 0.61538462	 test accuracy : 0.58757062
# Train Epoch: 180: train loss : 0.00184783	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.59322034
# Train Epoch: 181: train loss : 0.00368906	 train accuracy : 0.99804305	 val accuracy : 0.61538462	 test accuracy : 0.59322034
# Train Epoch: 182: train loss : 0.00104800	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.59322034
# Train Epoch: 183: train loss : 0.00312498	 train accuracy : 0.99804305	 val accuracy : 0.60989011	 test accuracy : 0.58757062
# Train Epoch: 184: train loss : 0.00130086	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.58757062
# Train Epoch: 185: train loss : 0.00322986	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.57627119
# Train Epoch: 186: train loss : 0.00213337	 train accuracy : 0.99804305	 val accuracy : 0.60989011	 test accuracy : 0.56497175
# Train Epoch: 187: train loss : 0.01053743	 train accuracy : 0.99608611	 val accuracy : 0.60989011	 test accuracy : 0.57062147
# Train Epoch: 188: train loss : 0.00041306	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.58192090
# Train Epoch: 189: train loss : 0.00086744	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.56497175
# Train Epoch: 190: train loss : 0.00207498	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.57062147
# Train Epoch: 191: train loss : 0.00396007	 train accuracy : 0.99804305	 val accuracy : 0.62087912	 test accuracy : 0.57062147
# Train Epoch: 192: train loss : 0.00216552	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.56497175
# Train Epoch: 193: train loss : 0.00051092	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.57062147
# Train Epoch: 194: train loss : 0.00080739	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.56497175
# Train Epoch: 195: train loss : 0.00418754	 train accuracy : 0.99804305	 val accuracy : 0.62087912	 test accuracy : 0.57062147
# Train Epoch: 196: train loss : 0.00101582	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.56497175
# Train Epoch: 197: train loss : 0.00105772	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.56497175
# Train Epoch: 198: train loss : 0.00112642	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.56497175
# Train Epoch: 199: train loss : 0.00086706	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.56497175
# Train Epoch: 200: train loss : 0.00364859	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.58192090
# In fold  1
# The best validaiton accuracy is:  0.6538461538461539
# Happened at epoch:  106
# The corresponding test accuracy 0.5819209039548022
# The corresponding test AUC is:  0.6035166240409207
#   + Number of params: 82402
# Save models
# Train Epoch: 1: train loss : 1.02854693	 train accuracy : 0.51637765	 val accuracy : 0.52542373	 test accuracy : 0.52298851
# Train Epoch: 2: train loss : 1.11491621	 train accuracy : 0.47206166	 val accuracy : 0.50282486	 test accuracy : 0.55172414
# Save models
# Train Epoch: 3: train loss : 0.82622856	 train accuracy : 0.57418112	 val accuracy : 0.55367232	 test accuracy : 0.53448276
# Train Epoch: 4: train loss : 0.72344238	 train accuracy : 0.62620424	 val accuracy : 0.51412429	 test accuracy : 0.48275862
# Train Epoch: 5: train loss : 0.66363436	 train accuracy : 0.63583815	 val accuracy : 0.50847458	 test accuracy : 0.50000000
# Train Epoch: 6: train loss : 0.70095611	 train accuracy : 0.60308285	 val accuracy : 0.54802260	 test accuracy : 0.56896552
# Train Epoch: 7: train loss : 0.65477234	 train accuracy : 0.64161850	 val accuracy : 0.51977401	 test accuracy : 0.58045977
# Train Epoch: 8: train loss : 0.62331295	 train accuracy : 0.64354528	 val accuracy : 0.54237288	 test accuracy : 0.58045977
# Train Epoch: 9: train loss : 0.56630480	 train accuracy : 0.70134875	 val accuracy : 0.50282486	 test accuracy : 0.56321839
# Train Epoch: 10: train loss : 0.55333602	 train accuracy : 0.69749518	 val accuracy : 0.50282486	 test accuracy : 0.58620690
# Train Epoch: 11: train loss : 0.52645624	 train accuracy : 0.75529865	 val accuracy : 0.52542373	 test accuracy : 0.56321839
# Save models
# Train Epoch: 12: train loss : 0.50576019	 train accuracy : 0.76685934	 val accuracy : 0.55932203	 test accuracy : 0.55747126
# Train Epoch: 13: train loss : 0.47744274	 train accuracy : 0.77263969	 val accuracy : 0.53672316	 test accuracy : 0.56896552
# Train Epoch: 14: train loss : 0.44643798	 train accuracy : 0.79576108	 val accuracy : 0.51977401	 test accuracy : 0.53448276
# Train Epoch: 15: train loss : 0.41087496	 train accuracy : 0.81502890	 val accuracy : 0.51977401	 test accuracy : 0.56896552
# Train Epoch: 16: train loss : 0.37745366	 train accuracy : 0.84585742	 val accuracy : 0.50282486	 test accuracy : 0.59195402
# Train Epoch: 17: train loss : 0.35570604	 train accuracy : 0.84971098	 val accuracy : 0.50282486	 test accuracy : 0.55172414
# Train Epoch: 18: train loss : 0.32585937	 train accuracy : 0.86512524	 val accuracy : 0.50282486	 test accuracy : 0.55172414
# Train Epoch: 19: train loss : 0.29087034	 train accuracy : 0.86705202	 val accuracy : 0.48587571	 test accuracy : 0.59770115
# Train Epoch: 20: train loss : 0.27166367	 train accuracy : 0.89595376	 val accuracy : 0.50847458	 test accuracy : 0.60919540
# Train Epoch: 21: train loss : 0.21234016	 train accuracy : 0.93256262	 val accuracy : 0.51977401	 test accuracy : 0.61494253
# Train Epoch: 22: train loss : 0.18585338	 train accuracy : 0.94990366	 val accuracy : 0.50847458	 test accuracy : 0.61494253
# Train Epoch: 23: train loss : 0.17749014	 train accuracy : 0.94797688	 val accuracy : 0.51412429	 test accuracy : 0.62068966
# Train Epoch: 24: train loss : 0.14192270	 train accuracy : 0.95568401	 val accuracy : 0.50282486	 test accuracy : 0.61494253
# Train Epoch: 25: train loss : 0.11732444	 train accuracy : 0.97109827	 val accuracy : 0.51412429	 test accuracy : 0.61494253
# Train Epoch: 26: train loss : 0.10086852	 train accuracy : 0.95953757	 val accuracy : 0.51412429	 test accuracy : 0.60919540
# Train Epoch: 27: train loss : 0.07625711	 train accuracy : 0.98073218	 val accuracy : 0.52542373	 test accuracy : 0.59195402
# Train Epoch: 28: train loss : 0.07143430	 train accuracy : 0.98073218	 val accuracy : 0.51412429	 test accuracy : 0.59195402
# Train Epoch: 29: train loss : 0.07077365	 train accuracy : 0.97880539	 val accuracy : 0.50847458	 test accuracy : 0.62643678
# Train Epoch: 30: train loss : 0.04444686	 train accuracy : 0.99036609	 val accuracy : 0.50282486	 test accuracy : 0.62068966
# Train Epoch: 31: train loss : 0.05688275	 train accuracy : 0.97880539	 val accuracy : 0.52542373	 test accuracy : 0.62643678
# Train Epoch: 32: train loss : 0.04856758	 train accuracy : 0.99036609	 val accuracy : 0.53107345	 test accuracy : 0.61494253
# Train Epoch: 33: train loss : 0.03500082	 train accuracy : 0.99614644	 val accuracy : 0.53107345	 test accuracy : 0.60344828
# Train Epoch: 34: train loss : 0.02722209	 train accuracy : 0.99421965	 val accuracy : 0.51977401	 test accuracy : 0.59770115
# Train Epoch: 35: train loss : 0.02078995	 train accuracy : 0.99421965	 val accuracy : 0.54237288	 test accuracy : 0.58620690
# Train Epoch: 36: train loss : 0.02121387	 train accuracy : 0.99421965	 val accuracy : 0.53107345	 test accuracy : 0.60344828
# Train Epoch: 37: train loss : 0.02011688	 train accuracy : 0.98651252	 val accuracy : 0.53107345	 test accuracy : 0.61494253
# Train Epoch: 38: train loss : 0.01089061	 train accuracy : 0.99807322	 val accuracy : 0.53672316	 test accuracy : 0.60919540
# Train Epoch: 39: train loss : 0.01074832	 train accuracy : 0.99807322	 val accuracy : 0.53107345	 test accuracy : 0.61494253
# Train Epoch: 40: train loss : 0.01568262	 train accuracy : 0.99421965	 val accuracy : 0.53672316	 test accuracy : 0.60344828
# Train Epoch: 41: train loss : 0.01203464	 train accuracy : 0.99614644	 val accuracy : 0.53107345	 test accuracy : 0.61494253
# Train Epoch: 42: train loss : 0.01097173	 train accuracy : 0.99614644	 val accuracy : 0.53107345	 test accuracy : 0.62068966
# Train Epoch: 43: train loss : 0.00619175	 train accuracy : 0.99807322	 val accuracy : 0.55367232	 test accuracy : 0.61494253
# Train Epoch: 44: train loss : 0.00930515	 train accuracy : 0.99807322	 val accuracy : 0.55367232	 test accuracy : 0.62068966
# Train Epoch: 45: train loss : 0.00302847	 train accuracy : 1.00000000	 val accuracy : 0.54237288	 test accuracy : 0.62068966
# Train Epoch: 46: train loss : 0.01161708	 train accuracy : 0.99614644	 val accuracy : 0.54802260	 test accuracy : 0.60919540
# Train Epoch: 47: train loss : 0.00649451	 train accuracy : 0.99807322	 val accuracy : 0.53672316	 test accuracy : 0.62068966
# Train Epoch: 48: train loss : 0.00958939	 train accuracy : 0.99614644	 val accuracy : 0.54237288	 test accuracy : 0.62068966
# Train Epoch: 49: train loss : 0.00233934	 train accuracy : 1.00000000	 val accuracy : 0.53672316	 test accuracy : 0.61494253
# Train Epoch: 50: train loss : 0.00666424	 train accuracy : 0.99807322	 val accuracy : 0.53672316	 test accuracy : 0.62068966
# Train Epoch: 51: train loss : 0.01104838	 train accuracy : 0.99807322	 val accuracy : 0.53672316	 test accuracy : 0.62068966
# Train Epoch: 52: train loss : 0.00386695	 train accuracy : 1.00000000	 val accuracy : 0.54237288	 test accuracy : 0.61494253
# Train Epoch: 53: train loss : 0.00433025	 train accuracy : 0.99807322	 val accuracy : 0.53672316	 test accuracy : 0.62068966
# Train Epoch: 54: train loss : 0.00356818	 train accuracy : 1.00000000	 val accuracy : 0.53672316	 test accuracy : 0.62068966
# Train Epoch: 55: train loss : 0.00337332	 train accuracy : 0.99807322	 val accuracy : 0.53672316	 test accuracy : 0.62643678
# Train Epoch: 56: train loss : 0.00519305	 train accuracy : 1.00000000	 val accuracy : 0.53672316	 test accuracy : 0.63218391
# Train Epoch: 57: train loss : 0.00894012	 train accuracy : 0.99614644	 val accuracy : 0.53107345	 test accuracy : 0.62068966
# Train Epoch: 58: train loss : 0.00605794	 train accuracy : 0.99807322	 val accuracy : 0.53107345	 test accuracy : 0.58620690
# Train Epoch: 59: train loss : 0.00256428	 train accuracy : 1.00000000	 val accuracy : 0.53107345	 test accuracy : 0.60344828
# Train Epoch: 60: train loss : 0.00502628	 train accuracy : 0.99807322	 val accuracy : 0.54237288	 test accuracy : 0.59770115
# Train Epoch: 61: train loss : 0.01425915	 train accuracy : 0.99614644	 val accuracy : 0.52542373	 test accuracy : 0.59195402
# Train Epoch: 62: train loss : 0.00706280	 train accuracy : 0.99614644	 val accuracy : 0.52542373	 test accuracy : 0.59770115
# Train Epoch: 63: train loss : 0.00226669	 train accuracy : 1.00000000	 val accuracy : 0.53672316	 test accuracy : 0.59770115
# Train Epoch: 64: train loss : 0.00818435	 train accuracy : 0.99614644	 val accuracy : 0.52542373	 test accuracy : 0.60344828
# Train Epoch: 65: train loss : 0.00185704	 train accuracy : 1.00000000	 val accuracy : 0.52542373	 test accuracy : 0.60919540
# Train Epoch: 66: train loss : 0.01390066	 train accuracy : 0.99807322	 val accuracy : 0.51412429	 test accuracy : 0.60919540
# Train Epoch: 67: train loss : 0.01317637	 train accuracy : 0.99807322	 val accuracy : 0.51977401	 test accuracy : 0.60344828
# Train Epoch: 68: train loss : 0.01021673	 train accuracy : 0.99807322	 val accuracy : 0.53107345	 test accuracy : 0.60919540
# Train Epoch: 69: train loss : 0.00634567	 train accuracy : 0.99807322	 val accuracy : 0.53672316	 test accuracy : 0.60919540
# Train Epoch: 70: train loss : 0.00196037	 train accuracy : 1.00000000	 val accuracy : 0.53672316	 test accuracy : 0.59195402
# Train Epoch: 71: train loss : 0.00066682	 train accuracy : 1.00000000	 val accuracy : 0.52542373	 test accuracy : 0.59770115
# Train Epoch: 72: train loss : 0.00273214	 train accuracy : 1.00000000	 val accuracy : 0.53672316	 test accuracy : 0.59770115
# Train Epoch: 73: train loss : 0.00086211	 train accuracy : 1.00000000	 val accuracy : 0.54237288	 test accuracy : 0.59195402
# Train Epoch: 74: train loss : 0.00949892	 train accuracy : 0.99807322	 val accuracy : 0.53672316	 test accuracy : 0.59770115
# Train Epoch: 75: train loss : 0.00088190	 train accuracy : 1.00000000	 val accuracy : 0.53107345	 test accuracy : 0.59770115
# Train Epoch: 76: train loss : 0.00319438	 train accuracy : 0.99807322	 val accuracy : 0.52542373	 test accuracy : 0.59770115
# Train Epoch: 77: train loss : 0.00176640	 train accuracy : 1.00000000	 val accuracy : 0.51977401	 test accuracy : 0.59770115
# Train Epoch: 78: train loss : 0.00652836	 train accuracy : 0.99807322	 val accuracy : 0.52542373	 test accuracy : 0.59770115
# Train Epoch: 79: train loss : 0.00301331	 train accuracy : 0.99807322	 val accuracy : 0.53107345	 test accuracy : 0.59195402
# Train Epoch: 80: train loss : 0.00753143	 train accuracy : 0.99807322	 val accuracy : 0.53672316	 test accuracy : 0.58045977
# Train Epoch: 81: train loss : 0.00169613	 train accuracy : 1.00000000	 val accuracy : 0.54237288	 test accuracy : 0.58620690
# Train Epoch: 82: train loss : 0.00794831	 train accuracy : 0.99807322	 val accuracy : 0.54802260	 test accuracy : 0.59770115
# Train Epoch: 83: train loss : 0.00162335	 train accuracy : 1.00000000	 val accuracy : 0.53672316	 test accuracy : 0.59195402
# Train Epoch: 84: train loss : 0.00454605	 train accuracy : 0.99807322	 val accuracy : 0.53672316	 test accuracy : 0.58620690
# Train Epoch: 85: train loss : 0.00412271	 train accuracy : 0.99807322	 val accuracy : 0.54237288	 test accuracy : 0.58045977
# Train Epoch: 86: train loss : 0.00530810	 train accuracy : 0.99807322	 val accuracy : 0.54237288	 test accuracy : 0.58045977
# Train Epoch: 87: train loss : 0.00348426	 train accuracy : 1.00000000	 val accuracy : 0.54802260	 test accuracy : 0.58620690
# Train Epoch: 88: train loss : 0.00143073	 train accuracy : 1.00000000	 val accuracy : 0.54237288	 test accuracy : 0.58620690
# Train Epoch: 89: train loss : 0.00276821	 train accuracy : 1.00000000	 val accuracy : 0.54802260	 test accuracy : 0.58045977
# Save models
# Train Epoch: 90: train loss : 0.00206440	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.58045977
# Train Epoch: 91: train loss : 0.00310600	 train accuracy : 1.00000000	 val accuracy : 0.54802260	 test accuracy : 0.56896552
# Train Epoch: 92: train loss : 0.00041957	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.56321839
# Train Epoch: 93: train loss : 0.00124357	 train accuracy : 1.00000000	 val accuracy : 0.53672316	 test accuracy : 0.57471264
# Train Epoch: 94: train loss : 0.00132461	 train accuracy : 1.00000000	 val accuracy : 0.53672316	 test accuracy : 0.56321839
# Train Epoch: 95: train loss : 0.00205507	 train accuracy : 1.00000000	 val accuracy : 0.53672316	 test accuracy : 0.58045977
# Train Epoch: 96: train loss : 0.00461940	 train accuracy : 0.99614644	 val accuracy : 0.53672316	 test accuracy : 0.58045977
# Train Epoch: 97: train loss : 0.00603131	 train accuracy : 0.99614644	 val accuracy : 0.54802260	 test accuracy : 0.59195402
# Train Epoch: 98: train loss : 0.00330473	 train accuracy : 0.99807322	 val accuracy : 0.53107345	 test accuracy : 0.59770115
# Train Epoch: 99: train loss : 0.00035095	 train accuracy : 1.00000000	 val accuracy : 0.52542373	 test accuracy : 0.60919540
# Train Epoch: 100: train loss : 0.00240221	 train accuracy : 1.00000000	 val accuracy : 0.52542373	 test accuracy : 0.60344828
# Train Epoch: 101: train loss : 0.00083966	 train accuracy : 1.00000000	 val accuracy : 0.51412429	 test accuracy : 0.60919540
# Train Epoch: 102: train loss : 0.00425088	 train accuracy : 1.00000000	 val accuracy : 0.51412429	 test accuracy : 0.59195402
# Train Epoch: 103: train loss : 0.00302589	 train accuracy : 1.00000000	 val accuracy : 0.53107345	 test accuracy : 0.59195402
# Train Epoch: 104: train loss : 0.00443456	 train accuracy : 0.99807322	 val accuracy : 0.51977401	 test accuracy : 0.57471264
# Train Epoch: 105: train loss : 0.00169016	 train accuracy : 1.00000000	 val accuracy : 0.52542373	 test accuracy : 0.59195402
# Train Epoch: 106: train loss : 0.00497339	 train accuracy : 0.99807322	 val accuracy : 0.52542373	 test accuracy : 0.58045977
# Train Epoch: 107: train loss : 0.00234500	 train accuracy : 0.99807322	 val accuracy : 0.51412429	 test accuracy : 0.55172414
# Train Epoch: 108: train loss : 0.00626776	 train accuracy : 0.99807322	 val accuracy : 0.50282486	 test accuracy : 0.56321839
# Train Epoch: 109: train loss : 0.00288845	 train accuracy : 1.00000000	 val accuracy : 0.50282486	 test accuracy : 0.56321839
# Train Epoch: 110: train loss : 0.00247477	 train accuracy : 1.00000000	 val accuracy : 0.49717514	 test accuracy : 0.56896552
# Train Epoch: 111: train loss : 0.00401518	 train accuracy : 0.99807322	 val accuracy : 0.53672316	 test accuracy : 0.58620690
# Train Epoch: 112: train loss : 0.00664815	 train accuracy : 0.99614644	 val accuracy : 0.54802260	 test accuracy : 0.59770115
# Train Epoch: 113: train loss : 0.01218236	 train accuracy : 0.99614644	 val accuracy : 0.55367232	 test accuracy : 0.60344828
# Train Epoch: 114: train loss : 0.00353589	 train accuracy : 0.99807322	 val accuracy : 0.55367232	 test accuracy : 0.60919540
# Train Epoch: 115: train loss : 0.01786429	 train accuracy : 0.99229287	 val accuracy : 0.54802260	 test accuracy : 0.60344828
# Train Epoch: 116: train loss : 0.00653982	 train accuracy : 0.99807322	 val accuracy : 0.54237288	 test accuracy : 0.59770115
# Train Epoch: 117: train loss : 0.00121775	 train accuracy : 1.00000000	 val accuracy : 0.54802260	 test accuracy : 0.59195402
# Train Epoch: 118: train loss : 0.00086293	 train accuracy : 1.00000000	 val accuracy : 0.54802260	 test accuracy : 0.60344828
# Train Epoch: 119: train loss : 0.00334474	 train accuracy : 0.99807322	 val accuracy : 0.52542373	 test accuracy : 0.60344828
# Train Epoch: 120: train loss : 0.00373808	 train accuracy : 0.99807322	 val accuracy : 0.52542373	 test accuracy : 0.60919540
# Train Epoch: 121: train loss : 0.00188411	 train accuracy : 1.00000000	 val accuracy : 0.53107345	 test accuracy : 0.60919540
# Train Epoch: 122: train loss : 0.01112269	 train accuracy : 0.99614644	 val accuracy : 0.53107345	 test accuracy : 0.60919540
# Train Epoch: 123: train loss : 0.00436320	 train accuracy : 0.99807322	 val accuracy : 0.52542373	 test accuracy : 0.60919540
# Train Epoch: 124: train loss : 0.00241680	 train accuracy : 1.00000000	 val accuracy : 0.51977401	 test accuracy : 0.60344828
# Train Epoch: 125: train loss : 0.01057597	 train accuracy : 0.99807322	 val accuracy : 0.51977401	 test accuracy : 0.61494253
# Train Epoch: 126: train loss : 0.00145891	 train accuracy : 1.00000000	 val accuracy : 0.51977401	 test accuracy : 0.61494253
# Train Epoch: 127: train loss : 0.00100799	 train accuracy : 1.00000000	 val accuracy : 0.50847458	 test accuracy : 0.60344828
# Train Epoch: 128: train loss : 0.01385651	 train accuracy : 0.99421965	 val accuracy : 0.51412429	 test accuracy : 0.60919540
# Train Epoch: 129: train loss : 0.01381051	 train accuracy : 0.99614644	 val accuracy : 0.51412429	 test accuracy : 0.61494253
# Train Epoch: 130: train loss : 0.01489826	 train accuracy : 0.99229287	 val accuracy : 0.50282486	 test accuracy : 0.60344828
# Train Epoch: 131: train loss : 0.00201390	 train accuracy : 1.00000000	 val accuracy : 0.53107345	 test accuracy : 0.60919540
# Train Epoch: 132: train loss : 0.00248479	 train accuracy : 0.99807322	 val accuracy : 0.53107345	 test accuracy : 0.60344828
# Train Epoch: 133: train loss : 0.01184211	 train accuracy : 0.99421965	 val accuracy : 0.53672316	 test accuracy : 0.62643678
# Train Epoch: 134: train loss : 0.00217479	 train accuracy : 1.00000000	 val accuracy : 0.50282486	 test accuracy : 0.63793103
# Train Epoch: 135: train loss : 0.00127851	 train accuracy : 1.00000000	 val accuracy : 0.50847458	 test accuracy : 0.63793103
# Train Epoch: 136: train loss : 0.00570117	 train accuracy : 0.99807322	 val accuracy : 0.52542373	 test accuracy : 0.64367816
# Train Epoch: 137: train loss : 0.00344491	 train accuracy : 1.00000000	 val accuracy : 0.51977401	 test accuracy : 0.64942529
# Train Epoch: 138: train loss : 0.00401198	 train accuracy : 1.00000000	 val accuracy : 0.51977401	 test accuracy : 0.60919540
# Train Epoch: 139: train loss : 0.00156926	 train accuracy : 1.00000000	 val accuracy : 0.53672316	 test accuracy : 0.61494253
# Train Epoch: 140: train loss : 0.00291071	 train accuracy : 0.99807322	 val accuracy : 0.52542373	 test accuracy : 0.60919540
# Train Epoch: 141: train loss : 0.05558463	 train accuracy : 0.99614644	 val accuracy : 0.53107345	 test accuracy : 0.63218391
# Train Epoch: 142: train loss : 0.00241312	 train accuracy : 1.00000000	 val accuracy : 0.51977401	 test accuracy : 0.63218391
# Train Epoch: 143: train loss : 0.01598243	 train accuracy : 0.99421965	 val accuracy : 0.53107345	 test accuracy : 0.63218391
# Train Epoch: 144: train loss : 0.01851278	 train accuracy : 0.99036609	 val accuracy : 0.53672316	 test accuracy : 0.60919540
# Train Epoch: 145: train loss : 0.00356687	 train accuracy : 0.99807322	 val accuracy : 0.53107345	 test accuracy : 0.63218391
# Train Epoch: 146: train loss : 0.00619049	 train accuracy : 1.00000000	 val accuracy : 0.51412429	 test accuracy : 0.63793103
# Train Epoch: 147: train loss : 0.00603087	 train accuracy : 1.00000000	 val accuracy : 0.51412429	 test accuracy : 0.62643678
# Train Epoch: 148: train loss : 0.00733056	 train accuracy : 0.99614644	 val accuracy : 0.50847458	 test accuracy : 0.62068966
# Train Epoch: 149: train loss : 0.00263648	 train accuracy : 1.00000000	 val accuracy : 0.51977401	 test accuracy : 0.62643678
# Train Epoch: 150: train loss : 0.00819528	 train accuracy : 0.99807322	 val accuracy : 0.53107345	 test accuracy : 0.62643678
# Save models
# Train Epoch: 151: train loss : 0.00382841	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.62068966
# Save models
# Train Epoch: 152: train loss : 0.00220651	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.62643678
# Train Epoch: 153: train loss : 0.00882331	 train accuracy : 0.99807322	 val accuracy : 0.54802260	 test accuracy : 0.62068966
# Train Epoch: 154: train loss : 0.00742443	 train accuracy : 0.99614644	 val accuracy : 0.54237288	 test accuracy : 0.62068966
# Train Epoch: 155: train loss : 0.00650075	 train accuracy : 0.99614644	 val accuracy : 0.53672316	 test accuracy : 0.62643678
# Train Epoch: 156: train loss : 0.00347445	 train accuracy : 0.99807322	 val accuracy : 0.53107345	 test accuracy : 0.63218391
# Train Epoch: 157: train loss : 0.00147336	 train accuracy : 1.00000000	 val accuracy : 0.53107345	 test accuracy : 0.61494253
# Train Epoch: 158: train loss : 0.01306284	 train accuracy : 0.99614644	 val accuracy : 0.54237288	 test accuracy : 0.60344828
# Train Epoch: 159: train loss : 0.00413396	 train accuracy : 0.99807322	 val accuracy : 0.53107345	 test accuracy : 0.63218391
# Train Epoch: 160: train loss : 0.00433965	 train accuracy : 0.99807322	 val accuracy : 0.52542373	 test accuracy : 0.62068966
# Train Epoch: 161: train loss : 0.01064005	 train accuracy : 0.99807322	 val accuracy : 0.52542373	 test accuracy : 0.62068966
# Save models
# Train Epoch: 162: train loss : 0.01749984	 train accuracy : 0.99614644	 val accuracy : 0.56497175	 test accuracy : 0.62643678
# Train Epoch: 163: train loss : 0.00247110	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.61494253
# Train Epoch: 164: train loss : 0.00309222	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.61494253
# Train Epoch: 165: train loss : 0.00215782	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.62068966
# Train Epoch: 166: train loss : 0.00166021	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.62068966
# Train Epoch: 167: train loss : 0.00927183	 train accuracy : 0.99807322	 val accuracy : 0.55932203	 test accuracy : 0.61494253
# Save models
# Train Epoch: 168: train loss : 0.01841373	 train accuracy : 0.99614644	 val accuracy : 0.57627119	 test accuracy : 0.62068966
# Train Epoch: 169: train loss : 0.00563971	 train accuracy : 0.99807322	 val accuracy : 0.56497175	 test accuracy : 0.61494253
# Train Epoch: 170: train loss : 0.00646621	 train accuracy : 0.99614644	 val accuracy : 0.55932203	 test accuracy : 0.59770115
# Train Epoch: 171: train loss : 0.00073679	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.59770115
# Train Epoch: 172: train loss : 0.00701627	 train accuracy : 0.99614644	 val accuracy : 0.56497175	 test accuracy : 0.59770115
# Train Epoch: 173: train loss : 0.00164612	 train accuracy : 1.00000000	 val accuracy : 0.57062147	 test accuracy : 0.60344828
# Train Epoch: 174: train loss : 0.00213202	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.60344828
# Train Epoch: 175: train loss : 0.00587103	 train accuracy : 0.99614644	 val accuracy : 0.55932203	 test accuracy : 0.59770115
# ...
# Train Epoch: 77: train loss : 0.00671518	 train accuracy : 1.00000000	 val accuracy : 0.55089820	 test accuracy : 0.55494505
# Train Epoch: 78: train loss : 0.00221416	 train accuracy : 1.00000000	 val accuracy : 0.56287425	 test accuracy : 0.56593407
# Train Epoch: 79: train loss : 0.00216278	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 80: train loss : 0.00808704	 train accuracy : 0.99808061	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 81: train loss : 0.00941260	 train accuracy : 0.99808061	 val accuracy : 0.56886228	 test accuracy : 0.56593407
# Train Epoch: 82: train loss : 0.01040541	 train accuracy : 0.99808061	 val accuracy : 0.58083832	 test accuracy : 0.57142857
# Train Epoch: 83: train loss : 0.00357277	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.55494505
# Train Epoch: 84: train loss : 0.00269660	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 85: train loss : 0.01115356	 train accuracy : 0.99616123	 val accuracy : 0.56287425	 test accuracy : 0.56043956
# Train Epoch: 86: train loss : 0.00799270	 train accuracy : 0.99616123	 val accuracy : 0.56886228	 test accuracy : 0.56043956
# Train Epoch: 87: train loss : 0.00461095	 train accuracy : 0.99808061	 val accuracy : 0.56287425	 test accuracy : 0.56043956
# Train Epoch: 88: train loss : 0.00434087	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.55494505
# Train Epoch: 89: train loss : 0.00188163	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.56043956
# Train Epoch: 90: train loss : 0.00505493	 train accuracy : 0.99616123	 val accuracy : 0.58083832	 test accuracy : 0.55494505
# Train Epoch: 91: train loss : 0.00480352	 train accuracy : 0.99808061	 val accuracy : 0.57485030	 test accuracy : 0.54395604
# Train Epoch: 92: train loss : 0.00233844	 train accuracy : 1.00000000	 val accuracy : 0.58083832	 test accuracy : 0.53846154
# Train Epoch: 93: train loss : 0.00297252	 train accuracy : 1.00000000	 val accuracy : 0.58083832	 test accuracy : 0.53846154
# Train Epoch: 94: train loss : 0.00343862	 train accuracy : 1.00000000	 val accuracy : 0.58083832	 test accuracy : 0.52747253
# Train Epoch: 95: train loss : 0.00186327	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.53846154
# Train Epoch: 96: train loss : 0.00157214	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.53296703
# Train Epoch: 97: train loss : 0.00118513	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.53296703
# Train Epoch: 98: train loss : 0.00795564	 train accuracy : 0.99424184	 val accuracy : 0.56886228	 test accuracy : 0.53846154
# Train Epoch: 99: train loss : 0.01019392	 train accuracy : 0.99808061	 val accuracy : 0.57485030	 test accuracy : 0.53296703
# Train Epoch: 100: train loss : 0.00297955	 train accuracy : 1.00000000	 val accuracy : 0.58682635	 test accuracy : 0.53846154
# Train Epoch: 101: train loss : 0.00243523	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.56043956
# Train Epoch: 102: train loss : 0.00141820	 train accuracy : 1.00000000	 val accuracy : 0.58083832	 test accuracy : 0.56043956
# Train Epoch: 103: train loss : 0.00132835	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.55494505
# Train Epoch: 104: train loss : 0.00154271	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.56043956
# Train Epoch: 105: train loss : 0.00232076	 train accuracy : 1.00000000	 val accuracy : 0.58083832	 test accuracy : 0.56043956
# Train Epoch: 106: train loss : 0.00487323	 train accuracy : 0.99808061	 val accuracy : 0.58083832	 test accuracy : 0.56043956
# Train Epoch: 107: train loss : 0.00249151	 train accuracy : 1.00000000	 val accuracy : 0.58083832	 test accuracy : 0.56593407
# Train Epoch: 108: train loss : 0.00180464	 train accuracy : 1.00000000	 val accuracy : 0.58682635	 test accuracy : 0.56593407
# Train Epoch: 109: train loss : 0.00069606	 train accuracy : 1.00000000	 val accuracy : 0.59281437	 test accuracy : 0.56593407
# Train Epoch: 110: train loss : 0.00140466	 train accuracy : 1.00000000	 val accuracy : 0.59281437	 test accuracy : 0.57692308
# Train Epoch: 111: train loss : 0.00437644	 train accuracy : 0.99808061	 val accuracy : 0.58083832	 test accuracy : 0.58241758
# Train Epoch: 112: train loss : 0.00109830	 train accuracy : 1.00000000	 val accuracy : 0.58682635	 test accuracy : 0.58791209
# Train Epoch: 113: train loss : 0.00262937	 train accuracy : 1.00000000	 val accuracy : 0.58083832	 test accuracy : 0.58241758
# Train Epoch: 114: train loss : 0.00252567	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.58241758
# Train Epoch: 115: train loss : 0.00356356	 train accuracy : 0.99808061	 val accuracy : 0.56886228	 test accuracy : 0.57142857
# Train Epoch: 116: train loss : 0.00256143	 train accuracy : 1.00000000	 val accuracy : 0.55688623	 test accuracy : 0.56593407
# Train Epoch: 117: train loss : 0.00188244	 train accuracy : 1.00000000	 val accuracy : 0.55089820	 test accuracy : 0.56593407
# Train Epoch: 118: train loss : 0.00058597	 train accuracy : 1.00000000	 val accuracy : 0.55688623	 test accuracy : 0.54945055
# Train Epoch: 119: train loss : 0.00096072	 train accuracy : 1.00000000	 val accuracy : 0.55688623	 test accuracy : 0.54945055
# Train Epoch: 120: train loss : 0.00208013	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.55494505
# Train Epoch: 121: train loss : 0.00522604	 train accuracy : 0.99808061	 val accuracy : 0.56287425	 test accuracy : 0.56043956
# Train Epoch: 122: train loss : 0.00125961	 train accuracy : 1.00000000	 val accuracy : 0.56287425	 test accuracy : 0.56043956
# Train Epoch: 123: train loss : 0.00455432	 train accuracy : 0.99808061	 val accuracy : 0.55688623	 test accuracy : 0.56043956
# Train Epoch: 124: train loss : 0.00146228	 train accuracy : 1.00000000	 val accuracy : 0.55688623	 test accuracy : 0.56043956
# Train Epoch: 125: train loss : 0.00143127	 train accuracy : 1.00000000	 val accuracy : 0.55688623	 test accuracy : 0.56043956
# Train Epoch: 126: train loss : 0.00283177	 train accuracy : 1.00000000	 val accuracy : 0.56287425	 test accuracy : 0.56593407
# Train Epoch: 127: train loss : 0.00181226	 train accuracy : 1.00000000	 val accuracy : 0.56287425	 test accuracy : 0.56043956
# Train Epoch: 128: train loss : 0.00145259	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.56043956
# Train Epoch: 129: train loss : 0.00427525	 train accuracy : 0.99808061	 val accuracy : 0.57485030	 test accuracy : 0.56593407
# Train Epoch: 130: train loss : 0.00418058	 train accuracy : 0.99808061	 val accuracy : 0.56287425	 test accuracy : 0.57142857
# Train Epoch: 131: train loss : 0.00074217	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.55494505
# Train Epoch: 132: train loss : 0.00270936	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.56043956
# Train Epoch: 133: train loss : 0.00140391	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.56043956
# Train Epoch: 134: train loss : 0.00144870	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.56043956
# Train Epoch: 135: train loss : 0.00259779	 train accuracy : 0.99808061	 val accuracy : 0.56886228	 test accuracy : 0.56043956
# Train Epoch: 136: train loss : 0.00073400	 train accuracy : 1.00000000	 val accuracy : 0.56287425	 test accuracy : 0.56593407
# Train Epoch: 137: train loss : 0.00138206	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.56593407
# Train Epoch: 138: train loss : 0.00180424	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.56593407
# Train Epoch: 139: train loss : 0.00096191	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.56593407
# Train Epoch: 140: train loss : 0.00123863	 train accuracy : 1.00000000	 val accuracy : 0.58083832	 test accuracy : 0.56043956
# Train Epoch: 141: train loss : 0.00076673	 train accuracy : 1.00000000	 val accuracy : 0.58083832	 test accuracy : 0.55494505
# Train Epoch: 142: train loss : 0.00083723	 train accuracy : 1.00000000	 val accuracy : 0.58083832	 test accuracy : 0.56043956
# Train Epoch: 143: train loss : 0.00394310	 train accuracy : 0.99808061	 val accuracy : 0.57485030	 test accuracy : 0.56043956
# Train Epoch: 144: train loss : 0.00110485	 train accuracy : 1.00000000	 val accuracy : 0.58682635	 test accuracy : 0.54945055
# Train Epoch: 145: train loss : 0.00058114	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.54945055
# Train Epoch: 146: train loss : 0.00122634	 train accuracy : 1.00000000	 val accuracy : 0.56287425	 test accuracy : 0.54945055
# Train Epoch: 147: train loss : 0.00260553	 train accuracy : 0.99808061	 val accuracy : 0.55688623	 test accuracy : 0.54945055
# Train Epoch: 148: train loss : 0.00729355	 train accuracy : 0.99808061	 val accuracy : 0.56886228	 test accuracy : 0.54945055
# Train Epoch: 149: train loss : 0.00052539	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.56593407
# Train Epoch: 150: train loss : 0.00063070	 train accuracy : 1.00000000	 val accuracy : 0.58083832	 test accuracy : 0.57142857
# Train Epoch: 151: train loss : 0.00485786	 train accuracy : 0.99808061	 val accuracy : 0.57485030	 test accuracy : 0.57142857
# Train Epoch: 152: train loss : 0.00558331	 train accuracy : 0.99616123	 val accuracy : 0.56886228	 test accuracy : 0.55494505
# Train Epoch: 153: train loss : 0.00151693	 train accuracy : 1.00000000	 val accuracy : 0.55089820	 test accuracy : 0.57142857
# Train Epoch: 154: train loss : 0.00109077	 train accuracy : 1.00000000	 val accuracy : 0.52095808	 test accuracy : 0.57692308
# Train Epoch: 155: train loss : 0.00394517	 train accuracy : 0.99808061	 val accuracy : 0.52095808	 test accuracy : 0.57142857
# Train Epoch: 156: train loss : 0.00456142	 train accuracy : 0.99808061	 val accuracy : 0.53892216	 test accuracy : 0.57692308
# Train Epoch: 157: train loss : 0.00060868	 train accuracy : 1.00000000	 val accuracy : 0.55089820	 test accuracy : 0.56043956
# Train Epoch: 158: train loss : 0.00113278	 train accuracy : 1.00000000	 val accuracy : 0.56287425	 test accuracy : 0.54945055
# Train Epoch: 159: train loss : 0.01667575	 train accuracy : 0.99808061	 val accuracy : 0.56287425	 test accuracy : 0.56043956
# Train Epoch: 160: train loss : 0.00266890	 train accuracy : 0.99808061	 val accuracy : 0.56287425	 test accuracy : 0.54945055
# Train Epoch: 161: train loss : 0.00194701	 train accuracy : 1.00000000	 val accuracy : 0.56287425	 test accuracy : 0.55494505
# Train Epoch: 162: train loss : 0.00650073	 train accuracy : 0.99808061	 val accuracy : 0.56287425	 test accuracy : 0.54945055
# Train Epoch: 163: train loss : 0.00042355	 train accuracy : 1.00000000	 val accuracy : 0.56886228	 test accuracy : 0.56043956
# Train Epoch: 164: train loss : 0.00259888	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.56593407
# Train Epoch: 165: train loss : 0.01109865	 train accuracy : 0.99808061	 val accuracy : 0.58083832	 test accuracy : 0.56043956
# Train Epoch: 166: train loss : 0.00178510	 train accuracy : 1.00000000	 val accuracy : 0.58083832	 test accuracy : 0.54945055
# Train Epoch: 167: train loss : 0.00163549	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.56043956
# Train Epoch: 168: train loss : 0.00671261	 train accuracy : 0.99808061	 val accuracy : 0.58083832	 test accuracy : 0.57142857
# Train Epoch: 169: train loss : 0.00395935	 train accuracy : 0.99808061	 val accuracy : 0.57485030	 test accuracy : 0.56593407
# Train Epoch: 170: train loss : 0.00088539	 train accuracy : 1.00000000	 val accuracy : 0.56287425	 test accuracy : 0.56593407
# Train Epoch: 171: train loss : 0.00488899	 train accuracy : 0.99616123	 val accuracy : 0.56287425	 test accuracy : 0.56043956
# Train Epoch: 172: train loss : 0.00416061	 train accuracy : 0.99808061	 val accuracy : 0.56886228	 test accuracy : 0.56593407
# Train Epoch: 173: train loss : 0.00100141	 train accuracy : 1.00000000	 val accuracy : 0.56287425	 test accuracy : 0.56043956
# Train Epoch: 174: train loss : 0.00087874	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.55494505
# Train Epoch: 175: train loss : 0.00337409	 train accuracy : 0.99808061	 val accuracy : 0.55688623	 test accuracy : 0.56043956
# Train Epoch: 176: train loss : 0.00072901	 train accuracy : 1.00000000	 val accuracy : 0.55089820	 test accuracy : 0.54945055
# Train Epoch: 177: train loss : 0.00103750	 train accuracy : 1.00000000	 val accuracy : 0.56287425	 test accuracy : 0.54945055
# Train Epoch: 178: train loss : 0.00400366	 train accuracy : 0.99808061	 val accuracy : 0.55089820	 test accuracy : 0.55494505
# Train Epoch: 179: train loss : 0.00249635	 train accuracy : 1.00000000	 val accuracy : 0.55688623	 test accuracy : 0.54395604
# Train Epoch: 180: train loss : 0.00272544	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.54395604
# Train Epoch: 181: train loss : 0.00934733	 train accuracy : 0.99808061	 val accuracy : 0.54491018	 test accuracy : 0.53296703
# Train Epoch: 182: train loss : 0.00156387	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.54395604
# Train Epoch: 183: train loss : 0.00145551	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.53846154
# Train Epoch: 184: train loss : 0.01489445	 train accuracy : 0.99232246	 val accuracy : 0.55089820	 test accuracy : 0.54945055
# Train Epoch: 185: train loss : 0.00159346	 train accuracy : 1.00000000	 val accuracy : 0.55089820	 test accuracy : 0.54945055
# Train Epoch: 186: train loss : 0.00186897	 train accuracy : 1.00000000	 val accuracy : 0.55688623	 test accuracy : 0.56593407
# Train Epoch: 187: train loss : 0.00502585	 train accuracy : 0.99808061	 val accuracy : 0.58682635	 test accuracy : 0.55494505
# Train Epoch: 188: train loss : 0.00642514	 train accuracy : 0.99616123	 val accuracy : 0.58682635	 test accuracy : 0.56043956
# Train Epoch: 189: train loss : 0.00333223	 train accuracy : 1.00000000	 val accuracy : 0.59281437	 test accuracy : 0.57692308
# Save models
# Train Epoch: 190: train loss : 0.00112361	 train accuracy : 1.00000000	 val accuracy : 0.61676647	 test accuracy : 0.58241758
# Train Epoch: 191: train loss : 0.00358968	 train accuracy : 0.99808061	 val accuracy : 0.61077844	 test accuracy : 0.58241758
# Save models
# Train Epoch: 192: train loss : 0.00993943	 train accuracy : 0.99616123	 val accuracy : 0.61676647	 test accuracy : 0.57142857
# Train Epoch: 193: train loss : 0.00371897	 train accuracy : 1.00000000	 val accuracy : 0.59880240	 test accuracy : 0.57692308
# Train Epoch: 194: train loss : 0.00922642	 train accuracy : 0.99616123	 val accuracy : 0.59281437	 test accuracy : 0.56043956
# Train Epoch: 195: train loss : 0.00381662	 train accuracy : 1.00000000	 val accuracy : 0.59880240	 test accuracy : 0.56593407
# Train Epoch: 196: train loss : 0.00171070	 train accuracy : 1.00000000	 val accuracy : 0.57485030	 test accuracy : 0.57142857
# Train Epoch: 197: train loss : 0.00072056	 train accuracy : 1.00000000	 val accuracy : 0.58083832	 test accuracy : 0.58241758
# Train Epoch: 198: train loss : 0.00240872	 train accuracy : 0.99808061	 val accuracy : 0.57485030	 test accuracy : 0.57692308
# Train Epoch: 199: train loss : 0.01175647	 train accuracy : 0.99808061	 val accuracy : 0.58083832	 test accuracy : 0.57692308
# Train Epoch: 200: train loss : 0.00061536	 train accuracy : 1.00000000	 val accuracy : 0.58083832	 test accuracy : 0.56043956
# In fold  5
# The best validaiton accuracy is:  0.6167664670658682
# Happened at epoch:  192
# The corresponding test accuracy 0.5714285714285714
# The corresponding test AUC is:  0.6136749031007752
# Finish 5-fold training

# %%
val_accuracy = metrics.accuracy_score(all_fold_val_label, all_fold_val_out)
test_accuracy = metrics.accuracy_score(all_fold_test_label, all_fold_test_out)
test_fpr, test_tpr, te_thresholds = roc_curve(all_fold_test_label, all_fold_test_prob[:,1],pos_label=1)
test_auc = auc(test_fpr, test_tpr)
print('The best validation accuracy is ',val_accuracy)
print('The corresponding test accuracy is ',test_accuracy)
print('The corresponding test AUC is: ',test_auc)
plt.grid()
plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
plt.plot([0,1],[0,1],'g--')
plt.legend()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Test AUC(ROC curve)")
plt.grid(color='black', linestyle='-', linewidth=0.5)
plt.show()
# Out:
# The best validation accuracy is  0.632183908045977
# The corresponding test accuracy is  0.5885057471264368
# The corresponding test AUC is:  0.629515783656835

# %%
torch.cuda.empty_cache()
torch.manual_seed(args.seed)
if args.cuda:
    torch.cuda.manual_seed(args.seed)
############################################### Max voting ###############################################################
############################################### Max voting ###############################################################
############################################### Max voting ###############################################################
dist_ensemble_val_label = {}
dist_ensemble_val_result = {}
dist_ensemble_test_label = {}
dist_ensemble_test_result = {}
dist_ensemble_test_prob = {}

for ensemble_fold in range(5):
  print('Ensemble ',ensemble_fold+1)
  save_ensemble_models_path = save_path + 'Max_voting/EV_GCN/'
  dist_train = {}
  dist_validation = {}
  dist_test = {}
  for i in range(k_fold):
    dist_train[str(i + 1)] = []
    dist_validation[str(i + 1)] = []
    dist_test[str(i + 1)] = []
  test_name = {}
  for i in range(len(unique_sites)):
    test_name[unique_sites[i]] = []
  for each_site in unique_sites:
    index_site = get_index(sites, each_site)
    label = np.zeros((len(index_site)))
    for i in range(len(index_site)):
      index = index_site[i]
      label[i] = int(labels[int(index)])
    test_name_list = test_name[each_site]
    ########################################### StratifiedKFold ####################################################
    sfolder = StratifiedKFold(n_splits=k_fold,random_state=0,shuffle=True)
    group = 0
    for train, validation in sfolder.split(index_site,label):
      if group == ensemble_fold:
        for j in validation:
          name = index_site[j]
          dist_test['1'].append(name)
          dist_test['2'].append(name)
          dist_test['3'].append(name)
          dist_test['4'].append(name)
          dist_test['5'].append(name)
          test_name_list.append(name)
      group = group + 1
    test_name[each_site] = test_name_list

  for each_site in unique_sites:
    if ensemble_fold == 0:

      index_site = get_index(sites, each_site)
      label = np.zeros((len(index_site)))
      for i in range(len(index_site)):
        index = index_site[i]
        label[i] = int(labels[int(index)])
      test_name_list = test_name[each_site]
      index_site_new = []
      label_new = np.zeros((len(index_site) - len(test_name_list)))
      position = 0
      for x in range(len(index_site)):
        sample_name = index_site[x]
        if sample_name in test_name_list:
          c=0
        else:
          index_site_new.append(sample_name)
          label_new[position] = label[x]
          position = position + 1
      if each_site == 'CMU':  # ONLY 4 AUTISM SAMPLES AND 4 TD SAMPLES, CAN NOT BE DEVIDED INTO 5 GROUPS
        group_autism_val = []
        group_autism_train = []
        group_TD_val = []
        group_TD_train = []
        autism_validation_number = len(label_new[label_new ==1])/4
        TD_validation_number = len(label_new[label_new ==0]) / 4
        for j in range(len(label_new)):
          if label_new[j] == 1:
            if len(group_autism_val)<autism_validation_number:
              group_autism_val.append(index_site_new[j])
            else:
              group_autism_train.append(index_site_new[j])
          else:
            if len(group_TD_val)<TD_validation_number:
              group_TD_val.append(index_site_new[j])
            else:
              group_TD_train.append(index_site_new[j])

        dist_validation['1'] = dist_validation['1'] + group_autism_val + group_TD_val
        dist_validation['2'] = dist_validation['2'] + group_autism_val + group_TD_val
        dist_validation['3'] = dist_validation['3'] + group_autism_val + group_TD_val
        dist_validation['4'] = dist_validation['4'] + group_autism_val + group_TD_val
        dist_validation['5'] = dist_validation['5'] + group_autism_val + group_TD_val
        dist_train['1'] = dist_train['1'] + group_autism_train + group_TD_train
        dist_train['2'] = dist_train['2'] + group_autism_train + group_TD_train
        dist_train['3'] = dist_train['3'] + group_autism_train + group_TD_train
        dist_train['4'] = dist_train['4'] + group_autism_train + group_TD_train
        dist_train['5'] = dist_train['5'] + group_autism_train + group_TD_train
      else:
        ########################################### StratifiedKFold ####################################################
        sfolder = StratifiedKFold(n_splits=k_fold, random_state=0, shuffle=True)
        group = 0
        for train, validation in sfolder.split(index_site_new, label_new):

          for i in train:
            name = index_site_new[i]
            dist_train[str(group + 1)].append(name)
          for j in validation:
            name = index_site_new[j]
            dist_validation[str(group + 1)].append(name)
          group = group + 1
    else:

      index_site = get_index(sites, each_site)
      label = np.zeros((len(index_site)))
      for i in range(len(index_site)):
        index = index_site[i]
        label[i] = int(labels[int(index)])
      test_name_list = test_name[each_site]
      index_site_new = []
      label_new = np.zeros((len(index_site) - len(test_name_list)))
      position = 0
      for x in range(len(index_site)):
        sample_name = index_site[x]
        if sample_name in test_name_list:
          c=0
        else:
          index_site_new.append(sample_name)
          label_new[position] = label[x]
          position = position + 1
      ########################################### StratifiedKFold ####################################################
      sfolder = StratifiedKFold(n_splits=k_fold,random_state=0,shuffle=True)
      group = 0
      for train, validation in sfolder.split(index_site_new,label_new):

        for i in train:
          name = index_site_new[i]
          dist_train[str(group + 1)].append(name)
        for j in validation:
          name = index_site_new[j]
          dist_validation[str(group + 1)].append(name)
        group = group+1
  
  
  data = {}

  for fold in range(1, k_fold+1):
    data[str(fold)] = []
    selector = feature_selection(sMRI_features, labels, dist_train[str(fold)], new_number_features)
    fold_data = selector.transform(sMRI_features)
    n = fold_data.shape[0]
    num_edge = n * n
    edge_index = np.zeros([2, num_edge], dtype=np.int64)
    edgenet_input = np.zeros([num_edge, 2*phonetic_data.shape[1]], dtype=np.float32)  
    aff_score = np.zeros(num_edge, dtype=np.float32)

    aff_adj = get_static_affinity_adj(fold_data, pd_dict)  

    flatten_ind = 0
    for i in range(n): 
      for j in range(n):
        edge_index[:, flatten_ind] = [i, j]
        edgenet_input[flatten_ind] = np.concatenate((phonetic_data[i], phonetic_data[j]))
        aff_score[flatten_ind] = aff_adj[i][j]
        flatten_ind += 1


    keep_ind = np.where(aff_score > 1.1)[0]
    edge_index = edge_index[:, keep_ind]
    edgenet_input = edgenet_input[keep_ind]
    edgenet_input = (edgenet_input- edgenet_input.mean(axis=0)) / edgenet_input.std(axis=0)

    data[str(fold)].append(fold_data)
    data[str(fold)].append(EV_GCN_labels)
    data[str(fold)].append(edge_index)
    data[str(fold)].append(edgenet_input)




  ############################################### Train ###############################################################
  ############################################### Train ###############################################################
  ############################################### Train ###############################################################

  model_1 = EV_GCN(args.input_dimension, args.num_classes, args.dropout, edge_dropout=args.edropout, hgc=args.hgc, lg=args.lg, edgenet_input_dim=2*phonetic_data.shape[1])
  model_2 = EV_GCN(args.input_dimension, args.num_classes, args.dropout, edge_dropout=args.edropout, hgc=args.hgc, lg=args.lg, edgenet_input_dim=2*phonetic_data.shape[1])
  model_3 = EV_GCN(args.input_dimension, args.num_classes, args.dropout, edge_dropout=args.edropout, hgc=args.hgc, lg=args.lg, edgenet_input_dim=2*phonetic_data.shape[1])
  model_4 = EV_GCN(args.input_dimension, args.num_classes, args.dropout, edge_dropout=args.edropout, hgc=args.hgc, lg=args.lg, edgenet_input_dim=2*phonetic_data.shape[1])
  model_5 = EV_GCN(args.input_dimension, args.num_classes, args.dropout, edge_dropout=args.edropout, hgc=args.hgc, lg=args.lg, edgenet_input_dim=2*phonetic_data.shape[1])

  gpu_ids = range(args.ngpu)
  model_1 = nn.parallel.DataParallel(model_1, device_ids=gpu_ids)
  model_2 = nn.parallel.DataParallel(model_2, device_ids=gpu_ids)
  model_3 = nn.parallel.DataParallel(model_3, device_ids=gpu_ids)
  model_4 = nn.parallel.DataParallel(model_4, device_ids=gpu_ids)
  model_5 = nn.parallel.DataParallel(model_5, device_ids=gpu_ids)
  train = train_EV_GCN

  print('  + Number of params: {}'.format(
      sum([p.data.nelement() for p in model_1.parameters()])))
  if args.cuda:
      model_1 = model_1.cuda()
      model_2 = model_2.cuda()
      model_3 = model_3.cuda()
      model_4 = model_4.cuda()
      model_5 = model_5.cuda()

  optimizer_1 = optim.Adam(model_1.parameters(), lr = args.lr, weight_decay=args.wd)
  optimizer_2 = optim.Adam(model_2.parameters(), lr = args.lr, weight_decay=args.wd)
  optimizer_3 = optim.Adam(model_3.parameters(), lr = args.lr, weight_decay=args.wd)
  optimizer_4 = optim.Adam(model_4.parameters(), lr = args.lr, weight_decay=args.wd)
  optimizer_5 = optim.Adam(model_5.parameters(), lr = args.lr, weight_decay=args.wd)

  Train_accuracy_list =[]
  Train_loss_list = []
  Val_accuracy_list =[]
  Val_loss_list = []
  Test_accuracy_list =[]
  Test_loss_list = []
  best_validation_accuracy = 0

  for epoch in range(1, args.nEpochs + 1):


    model_1, train_target_1, train_out_1, train_loss_1, val_target_1, val_out_1, val_loss_1, test_target_1, test_out_1, test_prob_1, test_loss_1 = train(args, model_1, data['1'], dist_train['1'], dist_validation['1'], dist_test['1'], optimizer_1)
    model_2, train_target_2, train_out_2, train_loss_2, val_target_2, val_out_2, val_loss_2, test_target_2, test_out_2, test_prob_2, test_loss_2 = train(args, model_2, data['2'], dist_train['2'], dist_validation['2'], dist_test['2'], optimizer_2)
    model_3, train_target_3, train_out_3, train_loss_3, val_target_3, val_out_3, val_loss_3, test_target_3, test_out_3, test_prob_3, test_loss_3 = train(args, model_3, data['3'], dist_train['3'], dist_validation['3'], dist_test['3'], optimizer_3)
    model_4, train_target_4, train_out_4, train_loss_4, val_target_4, val_out_4, val_loss_4, test_target_4, test_out_4, test_prob_4, test_loss_4 = train(args, model_4, data['4'], dist_train['4'], dist_validation['4'], dist_test['4'], optimizer_4)
    model_5, train_target_5, train_out_5, train_loss_5, val_target_5, val_out_5, val_loss_5, test_target_5, test_out_5, test_prob_5, test_loss_5 = train(args, model_5, data['5'], dist_train['5'], dist_validation['5'], dist_test['5'], optimizer_5)

    train_target_all = np.concatenate((train_target_1, train_target_2, train_target_3, train_target_4, train_target_5),axis = 0)
    train_out_all = np.concatenate((train_out_1, train_out_2, train_out_3, train_out_4, train_out_5),axis = 0)
    train_loss = (train_loss_1 + train_loss_2 + train_loss_3 + train_loss_4 + train_loss_5)/5
    val_target_all = np.concatenate((val_target_1, val_target_2, val_target_3, val_target_4, val_target_5),axis = 0)
    val_out_all = np.concatenate((val_out_1, val_out_2, val_out_3, val_out_4, val_out_5),axis = 0)
    val_loss = (val_loss_1 + val_loss_2 + val_loss_3 + val_loss_4 + val_loss_5)/5
    test_target_all = test_target_1 # test_target_1 = test_target_2 = test_target_3 = test_target_4 = test_target_5
    test_out_all = test_out_1 + test_out_2 + test_out_3 + test_out_4 + test_out_5
    test_prob_all = (test_prob_1 + test_prob_2 + test_prob_3 + test_prob_4 + test_prob_5)/5
    test_loss = (test_loss_1 + test_loss_2 + test_loss_3 + test_loss_4 + test_loss_5)/5

    test_results_binary = np.zeros_like((test_out_all))
    test_results_binary[test_out_all<2.5] = 0
    test_results_binary[test_out_all>=2.5] = 1

    train_accuracy = metrics.accuracy_score(train_target_all, train_out_all)
    val_accuracy = metrics.accuracy_score(val_target_all, val_out_all)
    test_accuracy = metrics.accuracy_score(test_target_all, test_results_binary)
    Train_accuracy_list.append(train_accuracy)
    Val_accuracy_list.append(val_accuracy)
    Test_accuracy_list.append(test_accuracy)
    Train_loss_list.append(train_loss)
    Val_loss_list.append(val_loss)
    Test_loss_list.append(test_loss)

    if val_accuracy >=best_validation_accuracy:
      best_epoch = epoch
      best_validation_accuracy = val_accuracy
      corresponding_test_accuracy = test_accuracy
      corresponding_test_prob = test_prob_all
      corresponding_test_labels = test_target_all
      corresponding_test_out = test_results_binary
      print('Save models')

      save_model(model_1, save_ensemble_models_path, 'EV_GCN_ensemble' + str(ensemble_fold) + '_1')
      save_model(model_2, save_ensemble_models_path, 'EV_GCN_ensemble' + str(ensemble_fold) + '_2')
      save_model(model_3, save_ensemble_models_path, 'EV_GCN_ensemble' + str(ensemble_fold) + '_3')
      save_model(model_4, save_ensemble_models_path, 'EV_GCN_ensemble' + str(ensemble_fold) + '_4')
      save_model(model_5, save_ensemble_models_path, 'EV_GCN_ensemble' + str(ensemble_fold) + '_5')

    print('Train Epoch: ' + str(epoch) + ': train loss : {:.8f}\t train accuracy : {:.8f}\t val accuracy : {:.8f}\t test accuracy : {:.8f}\t'.format(
      train_loss, train_accuracy, val_accuracy, test_accuracy))

  x_axis = list(range(1, len(Train_accuracy_list)+1))
  plt.figure(figsize=(15,10))
  plt.plot(x_axis, Train_loss_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_loss_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_loss_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()

  plt.figure(figsize=(15,10))
  plt.plot(x_axis, Train_accuracy_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_accuracy_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_accuracy_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()
 
  test_fpr, test_tpr, te_thresholds = roc_curve(corresponding_test_labels, corresponding_test_prob[:,1],pos_label=1)
  test_auc = auc(test_fpr, test_tpr)
  print('\n')
  print('In ensemble ',ensemble_fold+1)
  print('The best validaiton accuracy is: ',best_validation_accuracy)
  print('Happened at epoch: ',best_epoch)
  print('The corresponding test accuracy', corresponding_test_accuracy)
  print('The corresponding test AUC is: ',test_auc)
  print('\n')


  plt.grid()
  plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
  plt.plot([0,1],[0,1],'g--')
  plt.legend()
  plt.xlabel("False Positive Rate")
  plt.ylabel("True Positive Rate")
  plt.title("Test AUC(ROC curve)")
  plt.grid(color='black', linestyle='-', linewidth=0.5)
  plt.show()


  dist_ensemble_test_label[str(ensemble_fold+1)] = corresponding_test_labels
  dist_ensemble_test_result[str(ensemble_fold+1)] = corresponding_test_out
  dist_ensemble_test_prob[str(ensemble_fold+1)] = corresponding_test_prob
  print('\n')

  torch.cuda.empty_cache()

test_labels_concat = np.concatenate((dist_ensemble_test_label['1'], dist_ensemble_test_label['2'],  dist_ensemble_test_label['3'], dist_ensemble_test_label['4'], dist_ensemble_test_label['5']),axis = 0)
test_results_concat = np.concatenate((dist_ensemble_test_result['1'], dist_ensemble_test_result['2'],  dist_ensemble_test_result['3'], dist_ensemble_test_result['4'], dist_ensemble_test_result['5']),axis = 0)
test_probs_concat = np.concatenate((dist_ensemble_test_prob['1'], dist_ensemble_test_prob['2'],  dist_ensemble_test_prob['3'], dist_ensemble_test_prob['4'], dist_ensemble_test_prob['5']),axis = 0)

test_accuracy = metrics.accuracy_score(test_labels_concat, test_results_concat)
test_fpr, test_tpr, te_thresholds = roc_curve(test_labels_concat, test_probs_concat[:,1],pos_label=1)
test_auc = auc(test_fpr, test_tpr)
print('The Max voting test accuracy is: ',test_accuracy)
print('The test AUC is: ',test_auc)

print('\n')
print('\n')
plt.grid()
plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
plt.plot([0,1],[0,1],'g--')
plt.legend()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Test AUC(ROC curve)")
plt.grid(color='black', linestyle='-', linewidth=0.5)
plt.show()
# Out:
# Ensemble  1
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
#   + Number of params: 82402
# Save models
# Train Epoch: 1: train loss : 1.12445490	 train accuracy : 0.48727273	 val accuracy : 0.46811594	 test accuracy : 0.43956044
# Save models
# Train Epoch: 2: train loss : 1.10739077	 train accuracy : 0.50581818	 val accuracy : 0.51594203	 test accuracy : 0.53296703
# Save models
# Train Epoch: 3: train loss : 1.06604676	 train accuracy : 0.54581818	 val accuracy : 0.53188406	 test accuracy : 0.53296703
# Train Epoch: 4: train loss : 0.80577971	 train accuracy : 0.57527273	 val accuracy : 0.51594203	 test accuracy : 0.53296703
# Save models
# Train Epoch: 5: train loss : 0.76997919	 train accuracy : 0.59236364	 val accuracy : 0.53768116	 test accuracy : 0.58241758
# Save models
# Train Epoch: 6: train loss : 0.77571887	 train accuracy : 0.58181818	 val accuracy : 0.55797101	 test accuracy : 0.60439560
# Save models
# Train Epoch: 7: train loss : 0.67681220	 train accuracy : 0.62872727	 val accuracy : 0.57826087	 test accuracy : 0.58241758
# Train Epoch: 8: train loss : 0.64445083	 train accuracy : 0.64472727	 val accuracy : 0.56521739	 test accuracy : 0.59890110
# Train Epoch: 9: train loss : 0.64392644	 train accuracy : 0.65054545	 val accuracy : 0.54347826	 test accuracy : 0.58791209
# Train Epoch: 10: train loss : 0.61201200	 train accuracy : 0.68800000	 val accuracy : 0.56521739	 test accuracy : 0.58241758
# Save models
# Train Epoch: 11: train loss : 0.57818663	 train accuracy : 0.68836364	 val accuracy : 0.57971014	 test accuracy : 0.57692308
# Save models
# Train Epoch: 12: train loss : 0.56793835	 train accuracy : 0.70327273	 val accuracy : 0.58840580	 test accuracy : 0.59340659
# Train Epoch: 13: train loss : 0.55964087	 train accuracy : 0.71018182	 val accuracy : 0.58550725	 test accuracy : 0.56593407
# Save models
# Train Epoch: 14: train loss : 0.53198740	 train accuracy : 0.72981818	 val accuracy : 0.61159420	 test accuracy : 0.56593407
# Save models
# Train Epoch: 15: train loss : 0.50534684	 train accuracy : 0.75018182	 val accuracy : 0.62898551	 test accuracy : 0.60989011
# Train Epoch: 16: train loss : 0.47313422	 train accuracy : 0.77418182	 val accuracy : 0.60579710	 test accuracy : 0.63186813
# Train Epoch: 17: train loss : 0.46947692	 train accuracy : 0.77890909	 val accuracy : 0.59420290	 test accuracy : 0.62087912
# Train Epoch: 18: train loss : 0.44802563	 train accuracy : 0.79418182	 val accuracy : 0.60579710	 test accuracy : 0.60439560
# Train Epoch: 19: train loss : 0.42180957	 train accuracy : 0.80545455	 val accuracy : 0.60000000	 test accuracy : 0.60439560
# Train Epoch: 20: train loss : 0.38753175	 train accuracy : 0.82254545	 val accuracy : 0.61014493	 test accuracy : 0.59340659
# Train Epoch: 21: train loss : 0.37183781	 train accuracy : 0.83381818	 val accuracy : 0.61449275	 test accuracy : 0.58791209
# Train Epoch: 22: train loss : 0.35817195	 train accuracy : 0.83563636	 val accuracy : 0.59420290	 test accuracy : 0.58241758
# Train Epoch: 23: train loss : 0.33516197	 train accuracy : 0.85454545	 val accuracy : 0.59710145	 test accuracy : 0.59890110
# Train Epoch: 24: train loss : 0.31060022	 train accuracy : 0.86981818	 val accuracy : 0.60724638	 test accuracy : 0.62087912
# Train Epoch: 25: train loss : 0.28172232	 train accuracy : 0.88581818	 val accuracy : 0.59565217	 test accuracy : 0.59340659
# Train Epoch: 26: train loss : 0.26706493	 train accuracy : 0.89600000	 val accuracy : 0.57681159	 test accuracy : 0.57692308
# Train Epoch: 27: train loss : 0.24324896	 train accuracy : 0.90509091	 val accuracy : 0.57681159	 test accuracy : 0.60439560
# Train Epoch: 28: train loss : 0.22531179	 train accuracy : 0.91163636	 val accuracy : 0.57681159	 test accuracy : 0.59340659
# Train Epoch: 29: train loss : 0.19631537	 train accuracy : 0.92545455	 val accuracy : 0.58260870	 test accuracy : 0.58791209
# Train Epoch: 30: train loss : 0.17687679	 train accuracy : 0.93600000	 val accuracy : 0.58550725	 test accuracy : 0.60989011
# Train Epoch: 31: train loss : 0.16406290	 train accuracy : 0.93927273	 val accuracy : 0.58550725	 test accuracy : 0.62637363
# Train Epoch: 32: train loss : 0.15210242	 train accuracy : 0.95236364	 val accuracy : 0.59710145	 test accuracy : 0.62087912
# Train Epoch: 33: train loss : 0.12742650	 train accuracy : 0.95672727	 val accuracy : 0.58260870	 test accuracy : 0.59890110
# Train Epoch: 34: train loss : 0.11706878	 train accuracy : 0.96000000	 val accuracy : 0.56666667	 test accuracy : 0.60439560
# Train Epoch: 35: train loss : 0.10156480	 train accuracy : 0.96836364	 val accuracy : 0.57536232	 test accuracy : 0.59890110
# Train Epoch: 36: train loss : 0.09420679	 train accuracy : 0.97200000	 val accuracy : 0.57971014	 test accuracy : 0.60439560
# Train Epoch: 37: train loss : 0.07860301	 train accuracy : 0.97745455	 val accuracy : 0.58405797	 test accuracy : 0.61538462
# Train Epoch: 38: train loss : 0.07042681	 train accuracy : 0.97927273	 val accuracy : 0.59130435	 test accuracy : 0.62637363
# Train Epoch: 39: train loss : 0.06488419	 train accuracy : 0.98000000	 val accuracy : 0.59420290	 test accuracy : 0.62087912
# Train Epoch: 40: train loss : 0.05069573	 train accuracy : 0.98581818	 val accuracy : 0.59275362	 test accuracy : 0.62637363
# Train Epoch: 41: train loss : 0.04966842	 train accuracy : 0.98909091	 val accuracy : 0.59130435	 test accuracy : 0.63736264
# Train Epoch: 42: train loss : 0.04249861	 train accuracy : 0.98763636	 val accuracy : 0.58840580	 test accuracy : 0.63186813
# Train Epoch: 43: train loss : 0.04297121	 train accuracy : 0.98800000	 val accuracy : 0.59130435	 test accuracy : 0.65384615
# Train Epoch: 44: train loss : 0.03893359	 train accuracy : 0.98909091	 val accuracy : 0.59420290	 test accuracy : 0.64285714
# Train Epoch: 45: train loss : 0.03047074	 train accuracy : 0.99090909	 val accuracy : 0.59565217	 test accuracy : 0.64285714
# Train Epoch: 46: train loss : 0.02638947	 train accuracy : 0.99345455	 val accuracy : 0.60144928	 test accuracy : 0.64835165
# Train Epoch: 47: train loss : 0.02858384	 train accuracy : 0.99200000	 val accuracy : 0.59275362	 test accuracy : 0.65384615
# Train Epoch: 48: train loss : 0.02184716	 train accuracy : 0.99309091	 val accuracy : 0.59855072	 test accuracy : 0.65384615
# Train Epoch: 49: train loss : 0.02510043	 train accuracy : 0.99345455	 val accuracy : 0.60000000	 test accuracy : 0.64285714
# Train Epoch: 50: train loss : 0.01747347	 train accuracy : 0.99672727	 val accuracy : 0.59275362	 test accuracy : 0.64285714
# Train Epoch: 51: train loss : 0.01788577	 train accuracy : 0.99527273	 val accuracy : 0.59420290	 test accuracy : 0.64835165
# Train Epoch: 52: train loss : 0.01416907	 train accuracy : 0.99672727	 val accuracy : 0.59130435	 test accuracy : 0.64835165
# Train Epoch: 53: train loss : 0.01199861	 train accuracy : 0.99709091	 val accuracy : 0.59565217	 test accuracy : 0.63736264
# Train Epoch: 54: train loss : 0.01218855	 train accuracy : 0.99709091	 val accuracy : 0.58840580	 test accuracy : 0.63186813
# Train Epoch: 55: train loss : 0.00908181	 train accuracy : 0.99854545	 val accuracy : 0.59130435	 test accuracy : 0.63186813
# Train Epoch: 56: train loss : 0.00979043	 train accuracy : 0.99890909	 val accuracy : 0.59420290	 test accuracy : 0.63186813
# Train Epoch: 57: train loss : 0.01029006	 train accuracy : 0.99745455	 val accuracy : 0.59565217	 test accuracy : 0.64285714
# Train Epoch: 58: train loss : 0.01288294	 train accuracy : 0.99672727	 val accuracy : 0.60000000	 test accuracy : 0.63736264
# Train Epoch: 59: train loss : 0.00912600	 train accuracy : 0.99890909	 val accuracy : 0.60000000	 test accuracy : 0.62637363
# Train Epoch: 60: train loss : 0.00750886	 train accuracy : 0.99745455	 val accuracy : 0.59420290	 test accuracy : 0.64285714
# Train Epoch: 61: train loss : 0.00969771	 train accuracy : 0.99745455	 val accuracy : 0.58840580	 test accuracy : 0.63736264
# Train Epoch: 62: train loss : 0.00921917	 train accuracy : 0.99709091	 val accuracy : 0.59565217	 test accuracy : 0.62087912
# Train Epoch: 63: train loss : 0.00702541	 train accuracy : 0.99818182	 val accuracy : 0.59710145	 test accuracy : 0.62637363
# Train Epoch: 64: train loss : 0.00761130	 train accuracy : 0.99745455	 val accuracy : 0.60434783	 test accuracy : 0.64835165
# Train Epoch: 65: train loss : 0.00767326	 train accuracy : 0.99818182	 val accuracy : 0.61159420	 test accuracy : 0.65934066
# Train Epoch: 66: train loss : 0.00671973	 train accuracy : 0.99781818	 val accuracy : 0.60869565	 test accuracy : 0.65934066
# Train Epoch: 67: train loss : 0.00661934	 train accuracy : 0.99854545	 val accuracy : 0.60579710	 test accuracy : 0.64285714
# Train Epoch: 68: train loss : 0.00717088	 train accuracy : 0.99745455	 val accuracy : 0.60869565	 test accuracy : 0.64285714
# Train Epoch: 69: train loss : 0.00729282	 train accuracy : 0.99745455	 val accuracy : 0.60289855	 test accuracy : 0.61538462
# Train Epoch: 70: train loss : 0.00705490	 train accuracy : 0.99781818	 val accuracy : 0.60144928	 test accuracy : 0.63736264
# Train Epoch: 71: train loss : 0.00611929	 train accuracy : 0.99818182	 val accuracy : 0.59855072	 test accuracy : 0.64285714
# Train Epoch: 72: train loss : 0.00702065	 train accuracy : 0.99745455	 val accuracy : 0.59710145	 test accuracy : 0.64285714
# Train Epoch: 73: train loss : 0.00552856	 train accuracy : 0.99818182	 val accuracy : 0.60434783	 test accuracy : 0.64285714
# Train Epoch: 74: train loss : 0.00386097	 train accuracy : 0.99963636	 val accuracy : 0.60289855	 test accuracy : 0.64285714
# Train Epoch: 75: train loss : 0.00508800	 train accuracy : 0.99890909	 val accuracy : 0.60579710	 test accuracy : 0.63736264
# Train Epoch: 76: train loss : 0.00335138	 train accuracy : 0.99927273	 val accuracy : 0.60289855	 test accuracy : 0.63186813
# Train Epoch: 77: train loss : 0.00541248	 train accuracy : 0.99927273	 val accuracy : 0.60000000	 test accuracy : 0.62087912
# Train Epoch: 78: train loss : 0.00357473	 train accuracy : 0.99854545	 val accuracy : 0.60000000	 test accuracy : 0.62087912
# Train Epoch: 79: train loss : 0.00442850	 train accuracy : 0.99818182	 val accuracy : 0.59420290	 test accuracy : 0.61538462
# Train Epoch: 80: train loss : 0.00532901	 train accuracy : 0.99890909	 val accuracy : 0.60000000	 test accuracy : 0.62087912
# Train Epoch: 81: train loss : 0.00435096	 train accuracy : 0.99927273	 val accuracy : 0.59420290	 test accuracy : 0.62087912
# Train Epoch: 82: train loss : 0.00324881	 train accuracy : 0.99963636	 val accuracy : 0.59275362	 test accuracy : 0.61538462
# Train Epoch: 83: train loss : 0.00349266	 train accuracy : 0.99890909	 val accuracy : 0.59565217	 test accuracy : 0.60989011
# Train Epoch: 84: train loss : 0.00367080	 train accuracy : 0.99890909	 val accuracy : 0.59420290	 test accuracy : 0.61538462
# Train Epoch: 85: train loss : 0.00388770	 train accuracy : 0.99818182	 val accuracy : 0.59420290	 test accuracy : 0.61538462
# Train Epoch: 86: train loss : 0.00302454	 train accuracy : 0.99927273	 val accuracy : 0.59855072	 test accuracy : 0.62637363
# Train Epoch: 87: train loss : 0.00438474	 train accuracy : 0.99963636	 val accuracy : 0.60869565	 test accuracy : 0.61538462
# Train Epoch: 88: train loss : 0.00261079	 train accuracy : 0.99963636	 val accuracy : 0.60000000	 test accuracy : 0.62087912
# Train Epoch: 89: train loss : 0.00421854	 train accuracy : 0.99854545	 val accuracy : 0.59420290	 test accuracy : 0.62637363
# Train Epoch: 90: train loss : 0.00411741	 train accuracy : 0.99927273	 val accuracy : 0.59130435	 test accuracy : 0.62087912
# Train Epoch: 91: train loss : 0.00515317	 train accuracy : 0.99781818	 val accuracy : 0.58985507	 test accuracy : 0.63186813
# Train Epoch: 92: train loss : 0.00377396	 train accuracy : 0.99890909	 val accuracy : 0.59855072	 test accuracy : 0.60989011
# Train Epoch: 93: train loss : 0.00207959	 train accuracy : 0.99963636	 val accuracy : 0.60289855	 test accuracy : 0.61538462
# Train Epoch: 94: train loss : 0.00396567	 train accuracy : 0.99927273	 val accuracy : 0.59565217	 test accuracy : 0.62087912
# Train Epoch: 95: train loss : 0.00429710	 train accuracy : 0.99890909	 val accuracy : 0.60144928	 test accuracy : 0.61538462
# Train Epoch: 96: train loss : 0.00663844	 train accuracy : 0.99854545	 val accuracy : 0.60289855	 test accuracy : 0.60989011
# Train Epoch: 97: train loss : 0.00236531	 train accuracy : 0.99963636	 val accuracy : 0.60144928	 test accuracy : 0.59890110
# Train Epoch: 98: train loss : 0.00485480	 train accuracy : 0.99890909	 val accuracy : 0.60144928	 test accuracy : 0.60989011
# Train Epoch: 99: train loss : 0.00215594	 train accuracy : 0.99963636	 val accuracy : 0.60289855	 test accuracy : 0.60439560
# Train Epoch: 100: train loss : 0.00441305	 train accuracy : 0.99854545	 val accuracy : 0.60579710	 test accuracy : 0.59340659
# Train Epoch: 101: train loss : 0.00224851	 train accuracy : 0.99963636	 val accuracy : 0.60289855	 test accuracy : 0.59890110
# Train Epoch: 102: train loss : 0.00298348	 train accuracy : 0.99963636	 val accuracy : 0.60579710	 test accuracy : 0.60989011
# Train Epoch: 103: train loss : 0.00812121	 train accuracy : 0.99854545	 val accuracy : 0.60579710	 test accuracy : 0.61538462
# Train Epoch: 104: train loss : 0.00386614	 train accuracy : 0.99890909	 val accuracy : 0.60144928	 test accuracy : 0.62637363
# Train Epoch: 105: train loss : 0.00345996	 train accuracy : 0.99927273	 val accuracy : 0.59710145	 test accuracy : 0.63186813
# Train Epoch: 106: train loss : 0.00320016	 train accuracy : 0.99927273	 val accuracy : 0.60434783	 test accuracy : 0.62637363
# Train Epoch: 107: train loss : 0.00262270	 train accuracy : 0.99963636	 val accuracy : 0.60434783	 test accuracy : 0.62637363
# Train Epoch: 108: train loss : 0.00456988	 train accuracy : 0.99854545	 val accuracy : 0.60144928	 test accuracy : 0.62637363
# Train Epoch: 109: train loss : 0.00595003	 train accuracy : 0.99854545	 val accuracy : 0.60434783	 test accuracy : 0.62637363
# Train Epoch: 110: train loss : 0.00162913	 train accuracy : 1.00000000	 val accuracy : 0.60144928	 test accuracy : 0.62087912
# Train Epoch: 111: train loss : 0.00260314	 train accuracy : 0.99963636	 val accuracy : 0.60000000	 test accuracy : 0.62087912
# Train Epoch: 112: train loss : 0.00280186	 train accuracy : 0.99927273	 val accuracy : 0.60000000	 test accuracy : 0.62087912
# Train Epoch: 113: train loss : 0.00506762	 train accuracy : 0.99781818	 val accuracy : 0.59710145	 test accuracy : 0.62637363
# Train Epoch: 114: train loss : 0.00315081	 train accuracy : 0.99963636	 val accuracy : 0.59130435	 test accuracy : 0.63186813
# Train Epoch: 115: train loss : 0.00439602	 train accuracy : 0.99854545	 val accuracy : 0.59710145	 test accuracy : 0.63186813
# Train Epoch: 116: train loss : 0.00252667	 train accuracy : 1.00000000	 val accuracy : 0.59275362	 test accuracy : 0.62637363
# Train Epoch: 117: train loss : 0.00176620	 train accuracy : 1.00000000	 val accuracy : 0.58985507	 test accuracy : 0.60989011
# Train Epoch: 118: train loss : 0.00226878	 train accuracy : 1.00000000	 val accuracy : 0.58985507	 test accuracy : 0.62087912
# Train Epoch: 119: train loss : 0.00278535	 train accuracy : 0.99890909	 val accuracy : 0.59710145	 test accuracy : 0.62087912
# Train Epoch: 120: train loss : 0.00371207	 train accuracy : 0.99927273	 val accuracy : 0.59420290	 test accuracy : 0.64835165
# Train Epoch: 121: train loss : 0.00406239	 train accuracy : 0.99890909	 val accuracy : 0.60434783	 test accuracy : 0.63736264
# Train Epoch: 122: train loss : 0.00484509	 train accuracy : 0.99745455	 val accuracy : 0.59710145	 test accuracy : 0.62637363
# Train Epoch: 123: train loss : 0.00309552	 train accuracy : 0.99890909	 val accuracy : 0.60144928	 test accuracy : 0.63186813
# Train Epoch: 124: train loss : 0.00215373	 train accuracy : 0.99927273	 val accuracy : 0.60144928	 test accuracy : 0.62637363
# Train Epoch: 125: train loss : 0.00293102	 train accuracy : 0.99927273	 val accuracy : 0.59275362	 test accuracy : 0.62637363
# Train Epoch: 126: train loss : 0.00321776	 train accuracy : 0.99890909	 val accuracy : 0.59275362	 test accuracy : 0.62087912
# Train Epoch: 127: train loss : 0.00330221	 train accuracy : 0.99890909	 val accuracy : 0.58985507	 test accuracy : 0.62637363
# Train Epoch: 128: train loss : 0.00273587	 train accuracy : 0.99927273	 val accuracy : 0.59420290	 test accuracy : 0.62637363
# Train Epoch: 129: train loss : 0.00150125	 train accuracy : 1.00000000	 val accuracy : 0.58695652	 test accuracy : 0.63186813
# Train Epoch: 130: train loss : 0.00473015	 train accuracy : 0.99927273	 val accuracy : 0.58405797	 test accuracy : 0.62637363
# Train Epoch: 131: train loss : 0.00372833	 train accuracy : 0.99854545	 val accuracy : 0.58260870	 test accuracy : 0.62087912
# Train Epoch: 132: train loss : 0.00225059	 train accuracy : 0.99927273	 val accuracy : 0.58985507	 test accuracy : 0.60989011
# Train Epoch: 133: train loss : 0.00361890	 train accuracy : 0.99854545	 val accuracy : 0.59565217	 test accuracy : 0.61538462
# Train Epoch: 134: train loss : 0.00189963	 train accuracy : 0.99963636	 val accuracy : 0.59420290	 test accuracy : 0.60989011
# Train Epoch: 135: train loss : 0.00201711	 train accuracy : 0.99963636	 val accuracy : 0.60144928	 test accuracy : 0.61538462
# Train Epoch: 136: train loss : 0.00448620	 train accuracy : 0.99818182	 val accuracy : 0.59420290	 test accuracy : 0.62087912
# Train Epoch: 137: train loss : 0.00251624	 train accuracy : 0.99927273	 val accuracy : 0.59420290	 test accuracy : 0.62087912
# Train Epoch: 138: train loss : 0.00246311	 train accuracy : 0.99890909	 val accuracy : 0.60000000	 test accuracy : 0.62637363
# Train Epoch: 139: train loss : 0.00288203	 train accuracy : 0.99963636	 val accuracy : 0.59855072	 test accuracy : 0.63736264
# Train Epoch: 140: train loss : 0.00401118	 train accuracy : 0.99890909	 val accuracy : 0.59565217	 test accuracy : 0.63736264
# Train Epoch: 141: train loss : 0.00317445	 train accuracy : 0.99927273	 val accuracy : 0.59420290	 test accuracy : 0.64285714
# Train Epoch: 142: train loss : 0.00237039	 train accuracy : 0.99890909	 val accuracy : 0.59420290	 test accuracy : 0.64835165
# Train Epoch: 143: train loss : 0.00398139	 train accuracy : 0.99854545	 val accuracy : 0.58840580	 test accuracy : 0.64835165
# Train Epoch: 144: train loss : 0.00255659	 train accuracy : 0.99963636	 val accuracy : 0.58840580	 test accuracy : 0.65384615
# Train Epoch: 145: train loss : 0.00312909	 train accuracy : 0.99927273	 val accuracy : 0.58840580	 test accuracy : 0.64835165
# Train Epoch: 146: train loss : 0.00502291	 train accuracy : 0.99854545	 val accuracy : 0.59130435	 test accuracy : 0.63186813
# Train Epoch: 147: train loss : 0.00264550	 train accuracy : 0.99927273	 val accuracy : 0.59420290	 test accuracy : 0.60989011
# Train Epoch: 148: train loss : 0.00156506	 train accuracy : 1.00000000	 val accuracy : 0.59275362	 test accuracy : 0.61538462
# Train Epoch: 149: train loss : 0.00211854	 train accuracy : 0.99963636	 val accuracy : 0.59420290	 test accuracy : 0.61538462
# Train Epoch: 150: train loss : 0.00421873	 train accuracy : 0.99818182	 val accuracy : 0.60000000	 test accuracy : 0.61538462
# Train Epoch: 151: train loss : 0.00510740	 train accuracy : 0.99854545	 val accuracy : 0.60289855	 test accuracy : 0.60989011
# Train Epoch: 152: train loss : 0.00526208	 train accuracy : 0.99781818	 val accuracy : 0.60289855	 test accuracy : 0.62087912
# Train Epoch: 153: train loss : 0.00239320	 train accuracy : 0.99927273	 val accuracy : 0.60724638	 test accuracy : 0.62637363
# Train Epoch: 154: train loss : 0.00227390	 train accuracy : 0.99927273	 val accuracy : 0.60724638	 test accuracy : 0.63186813
# Train Epoch: 155: train loss : 0.00255168	 train accuracy : 0.99927273	 val accuracy : 0.61159420	 test accuracy : 0.62637363
# Train Epoch: 156: train loss : 0.00389393	 train accuracy : 0.99890909	 val accuracy : 0.60724638	 test accuracy : 0.63186813
# Train Epoch: 157: train loss : 0.00325151	 train accuracy : 0.99890909	 val accuracy : 0.60144928	 test accuracy : 0.63186813
# Train Epoch: 158: train loss : 0.00557954	 train accuracy : 0.99818182	 val accuracy : 0.58985507	 test accuracy : 0.64285714
# Train Epoch: 159: train loss : 0.00280983	 train accuracy : 0.99890909	 val accuracy : 0.58985507	 test accuracy : 0.63186813
# Train Epoch: 160: train loss : 0.00587601	 train accuracy : 0.99745455	 val accuracy : 0.58405797	 test accuracy : 0.62637363
# Train Epoch: 161: train loss : 0.00370479	 train accuracy : 0.99890909	 val accuracy : 0.59130435	 test accuracy : 0.62087912
# Train Epoch: 162: train loss : 0.00402969	 train accuracy : 0.99927273	 val accuracy : 0.58405797	 test accuracy : 0.60989011
# Train Epoch: 163: train loss : 0.00517247	 train accuracy : 0.99818182	 val accuracy : 0.58985507	 test accuracy : 0.61538462
# Train Epoch: 164: train loss : 0.00485102	 train accuracy : 0.99854545	 val accuracy : 0.58550725	 test accuracy : 0.62087912
# Train Epoch: 165: train loss : 0.00353422	 train accuracy : 0.99890909	 val accuracy : 0.58695652	 test accuracy : 0.62637363
# Train Epoch: 166: train loss : 0.00439838	 train accuracy : 0.99818182	 val accuracy : 0.58840580	 test accuracy : 0.62637363
# Train Epoch: 167: train loss : 0.00257279	 train accuracy : 0.99927273	 val accuracy : 0.58405797	 test accuracy : 0.62637363
# Train Epoch: 168: train loss : 0.00318311	 train accuracy : 0.99890909	 val accuracy : 0.58260870	 test accuracy : 0.63186813
# Train Epoch: 169: train loss : 0.01104091	 train accuracy : 0.99636364	 val accuracy : 0.57971014	 test accuracy : 0.63186813
# Train Epoch: 170: train loss : 0.00647817	 train accuracy : 0.99745455	 val accuracy : 0.57971014	 test accuracy : 0.64835165
# Train Epoch: 171: train loss : 0.00283926	 train accuracy : 0.99927273	 val accuracy : 0.57391304	 test accuracy : 0.63186813
# Train Epoch: 172: train loss : 0.00426238	 train accuracy : 0.99854545	 val accuracy : 0.57391304	 test accuracy : 0.62637363
# Train Epoch: 173: train loss : 0.00704331	 train accuracy : 0.99745455	 val accuracy : 0.58115942	 test accuracy : 0.61538462
# Train Epoch: 174: train loss : 0.00958669	 train accuracy : 0.99781818	 val accuracy : 0.57391304	 test accuracy : 0.63186813
# Train Epoch: 175: train loss : 0.00715786	 train accuracy : 0.99672727	 val accuracy : 0.58405797	 test accuracy : 0.62637363
# Train Epoch: 176: train loss : 0.00496345	 train accuracy : 0.99781818	 val accuracy : 0.58985507	 test accuracy : 0.63186813
# Train Epoch: 177: train loss : 0.00588293	 train accuracy : 0.99781818	 val accuracy : 0.59130435	 test accuracy : 0.62637363
# Train Epoch: 178: train loss : 0.00698402	 train accuracy : 0.99745455	 val accuracy : 0.59275362	 test accuracy : 0.60989011
# Train Epoch: 179: train loss : 0.00684777	 train accuracy : 0.99890909	 val accuracy : 0.59710145	 test accuracy : 0.59890110
# Train Epoch: 180: train loss : 0.00486350	 train accuracy : 0.99854545	 val accuracy : 0.59275362	 test accuracy : 0.61538462
# Train Epoch: 181: train loss : 0.00404226	 train accuracy : 0.99927273	 val accuracy : 0.58840580	 test accuracy : 0.60439560
# Train Epoch: 182: train loss : 0.00642357	 train accuracy : 0.99890909	 val accuracy : 0.59420290	 test accuracy : 0.59890110
# Train Epoch: 183: train loss : 0.00557306	 train accuracy : 0.99854545	 val accuracy : 0.59130435	 test accuracy : 0.59340659
# Train Epoch: 184: train loss : 0.00402253	 train accuracy : 0.99781818	 val accuracy : 0.59855072	 test accuracy : 0.59340659
# Train Epoch: 185: train loss : 0.00782842	 train accuracy : 0.99745455	 val accuracy : 0.59420290	 test accuracy : 0.59890110
# Train Epoch: 186: train loss : 0.00256500	 train accuracy : 0.99890909	 val accuracy : 0.58115942	 test accuracy : 0.60989011
# Train Epoch: 187: train loss : 0.00407451	 train accuracy : 0.99890909	 val accuracy : 0.58405797	 test accuracy : 0.61538462
# Train Epoch: 188: train loss : 0.00542179	 train accuracy : 0.99854545	 val accuracy : 0.57971014	 test accuracy : 0.61538462
# Train Epoch: 189: train loss : 0.00500584	 train accuracy : 0.99781818	 val accuracy : 0.57101449	 test accuracy : 0.60989011
# Train Epoch: 190: train loss : 0.00523445	 train accuracy : 0.99890909	 val accuracy : 0.57826087	 test accuracy : 0.60989011
# Train Epoch: 191: train loss : 0.00311114	 train accuracy : 0.99890909	 val accuracy : 0.57246377	 test accuracy : 0.60989011
# Train Epoch: 192: train loss : 0.00381166	 train accuracy : 0.99890909	 val accuracy : 0.56956522	 test accuracy : 0.61538462
# Train Epoch: 193: train loss : 0.00347753	 train accuracy : 0.99890909	 val accuracy : 0.56811594	 test accuracy : 0.60989011
# Train Epoch: 194: train loss : 0.00563850	 train accuracy : 0.99709091	 val accuracy : 0.56956522	 test accuracy : 0.62087912
# Train Epoch: 195: train loss : 0.00535873	 train accuracy : 0.99781818	 val accuracy : 0.57101449	 test accuracy : 0.62087912
# Train Epoch: 196: train loss : 0.00463306	 train accuracy : 0.99818182	 val accuracy : 0.57971014	 test accuracy : 0.62637363
# Train Epoch: 197: train loss : 0.00812028	 train accuracy : 0.99672727	 val accuracy : 0.57536232	 test accuracy : 0.63186813
# Train Epoch: 198: train loss : 0.00160583	 train accuracy : 1.00000000	 val accuracy : 0.58260870	 test accuracy : 0.62087912
# Train Epoch: 199: train loss : 0.00327628	 train accuracy : 0.99854545	 val accuracy : 0.58840580	 test accuracy : 0.62087912
# Train Epoch: 200: train loss : 0.00189357	 train accuracy : 0.99927273	 val accuracy : 0.57826087	 test accuracy : 0.60989011
# In ensemble  1
# The best validaiton accuracy is:  0.6289855072463768
# Happened at epoch:  15
# The corresponding test accuracy 0.6098901098901099
# The corresponding test AUC is:  0.6421996124031008
# Ensemble  2
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
#   + Number of params: 82402
# Save models
# Train Epoch: 1: train loss : 1.05331587	 train accuracy : 0.47763348	 val accuracy : 0.48340548	 test accuracy : 0.46327684
# Save models
# Train Epoch: 2: train loss : 1.01521680	 train accuracy : 0.50252525	 val accuracy : 0.51226551	 test accuracy : 0.53672316
# Save models
# Train Epoch: 3: train loss : 0.86168365	 train accuracy : 0.55375180	 val accuracy : 0.56421356	 test accuracy : 0.53672316
# Save models
# Train Epoch: 4: train loss : 0.77393812	 train accuracy : 0.59126984	 val accuracy : 0.58730159	 test accuracy : 0.51977401
# Train Epoch: 5: train loss : 0.72567965	 train accuracy : 0.60245310	 val accuracy : 0.55266955	 test accuracy : 0.56497175
# Train Epoch: 6: train loss : 0.68157738	 train accuracy : 0.62121212	 val accuracy : 0.52380952	 test accuracy : 0.48587571
# Train Epoch: 7: train loss : 0.67253777	 train accuracy : 0.62193362	 val accuracy : 0.53535354	 test accuracy : 0.57627119
# Save models
# Train Epoch: 8: train loss : 0.64555614	 train accuracy : 0.63961039	 val accuracy : 0.59307359	 test accuracy : 0.55932203
# Save models
# Train Epoch: 9: train loss : 0.61660351	 train accuracy : 0.67207792	 val accuracy : 0.59740260	 test accuracy : 0.51977401
# Train Epoch: 10: train loss : 0.58875539	 train accuracy : 0.68326118	 val accuracy : 0.58008658	 test accuracy : 0.61016949
# Train Epoch: 11: train loss : 0.56792215	 train accuracy : 0.70779221	 val accuracy : 0.59451659	 test accuracy : 0.61016949
# Save models
# Train Epoch: 12: train loss : 0.54775058	 train accuracy : 0.71717172	 val accuracy : 0.61038961	 test accuracy : 0.62146893
# Save models
# Train Epoch: 13: train loss : 0.50898482	 train accuracy : 0.75649351	 val accuracy : 0.61038961	 test accuracy : 0.59322034
# Train Epoch: 14: train loss : 0.49913234	 train accuracy : 0.75468975	 val accuracy : 0.60028860	 test accuracy : 0.59887006
# Save models
# Train Epoch: 15: train loss : 0.46447241	 train accuracy : 0.78463203	 val accuracy : 0.61616162	 test accuracy : 0.60451977
# Train Epoch: 16: train loss : 0.43967381	 train accuracy : 0.80266955	 val accuracy : 0.60750361	 test accuracy : 0.59887006
# Train Epoch: 17: train loss : 0.41595984	 train accuracy : 0.80916306	 val accuracy : 0.60028860	 test accuracy : 0.61016949
# Train Epoch: 18: train loss : 0.38532178	 train accuracy : 0.82251082	 val accuracy : 0.57720058	 test accuracy : 0.61016949
# Train Epoch: 19: train loss : 0.36295900	 train accuracy : 0.84632035	 val accuracy : 0.58730159	 test accuracy : 0.60451977
# Train Epoch: 20: train loss : 0.33274085	 train accuracy : 0.86075036	 val accuracy : 0.58730159	 test accuracy : 0.59322034
# Train Epoch: 21: train loss : 0.30355241	 train accuracy : 0.88131313	 val accuracy : 0.60317460	 test accuracy : 0.56497175
# Train Epoch: 22: train loss : 0.27576237	 train accuracy : 0.88636364	 val accuracy : 0.61038961	 test accuracy : 0.56497175
# Train Epoch: 23: train loss : 0.24595670	 train accuracy : 0.90331890	 val accuracy : 0.60750361	 test accuracy : 0.58192090
# Train Epoch: 24: train loss : 0.22148918	 train accuracy : 0.91594517	 val accuracy : 0.60028860	 test accuracy : 0.59887006
# Train Epoch: 25: train loss : 0.20214016	 train accuracy : 0.93001443	 val accuracy : 0.58585859	 test accuracy : 0.60451977
# Train Epoch: 26: train loss : 0.17598464	 train accuracy : 0.93470418	 val accuracy : 0.60173160	 test accuracy : 0.59887006
# Train Epoch: 27: train loss : 0.15450340	 train accuracy : 0.94588745	 val accuracy : 0.61183261	 test accuracy : 0.59887006
# Save models
# Train Epoch: 28: train loss : 0.13405245	 train accuracy : 0.95851371	 val accuracy : 0.61616162	 test accuracy : 0.58192090
# Train Epoch: 29: train loss : 0.12024806	 train accuracy : 0.95959596	 val accuracy : 0.60894661	 test accuracy : 0.57627119
# Train Epoch: 30: train loss : 0.10498631	 train accuracy : 0.96572872	 val accuracy : 0.59595960	 test accuracy : 0.57062147
# Train Epoch: 31: train loss : 0.08378020	 train accuracy : 0.97582973	 val accuracy : 0.59451659	 test accuracy : 0.58192090
# Train Epoch: 32: train loss : 0.07270006	 train accuracy : 0.97907648	 val accuracy : 0.58441558	 test accuracy : 0.57062147
# Train Epoch: 33: train loss : 0.06163230	 train accuracy : 0.98051948	 val accuracy : 0.58297258	 test accuracy : 0.56497175
# Train Epoch: 34: train loss : 0.05336759	 train accuracy : 0.98520924	 val accuracy : 0.58441558	 test accuracy : 0.58192090
# Train Epoch: 35: train loss : 0.04687027	 train accuracy : 0.98881674	 val accuracy : 0.58297258	 test accuracy : 0.61016949
# Train Epoch: 36: train loss : 0.04176781	 train accuracy : 0.98953824	 val accuracy : 0.58441558	 test accuracy : 0.59887006
# Train Epoch: 37: train loss : 0.03606828	 train accuracy : 0.98989899	 val accuracy : 0.58730159	 test accuracy : 0.61581921
# Train Epoch: 38: train loss : 0.02927298	 train accuracy : 0.99242424	 val accuracy : 0.59018759	 test accuracy : 0.60451977
# Train Epoch: 39: train loss : 0.03285446	 train accuracy : 0.98917749	 val accuracy : 0.59595960	 test accuracy : 0.60451977
# Train Epoch: 40: train loss : 0.01991325	 train accuracy : 0.99494949	 val accuracy : 0.59884560	 test accuracy : 0.61016949
# Train Epoch: 41: train loss : 0.02163146	 train accuracy : 0.99567100	 val accuracy : 0.61038961	 test accuracy : 0.62146893
# Train Epoch: 42: train loss : 0.01862049	 train accuracy : 0.99422799	 val accuracy : 0.60317460	 test accuracy : 0.58757062
# Train Epoch: 43: train loss : 0.01450277	 train accuracy : 0.99639250	 val accuracy : 0.60028860	 test accuracy : 0.57627119
# Train Epoch: 44: train loss : 0.01508915	 train accuracy : 0.99675325	 val accuracy : 0.59740260	 test accuracy : 0.59322034
# Train Epoch: 45: train loss : 0.01404362	 train accuracy : 0.99711400	 val accuracy : 0.59163059	 test accuracy : 0.61581921
# Train Epoch: 46: train loss : 0.01593198	 train accuracy : 0.99386724	 val accuracy : 0.59307359	 test accuracy : 0.60451977
# Train Epoch: 47: train loss : 0.01087190	 train accuracy : 0.99675325	 val accuracy : 0.59018759	 test accuracy : 0.59887006
# Train Epoch: 48: train loss : 0.01118135	 train accuracy : 0.99747475	 val accuracy : 0.58874459	 test accuracy : 0.59887006
# Train Epoch: 49: train loss : 0.01280542	 train accuracy : 0.99531025	 val accuracy : 0.59163059	 test accuracy : 0.59322034
# Train Epoch: 50: train loss : 0.00949229	 train accuracy : 0.99675325	 val accuracy : 0.59595960	 test accuracy : 0.59322034
# Train Epoch: 51: train loss : 0.00616584	 train accuracy : 0.99855700	 val accuracy : 0.58874459	 test accuracy : 0.59322034
# Train Epoch: 52: train loss : 0.00733599	 train accuracy : 0.99855700	 val accuracy : 0.58585859	 test accuracy : 0.58757062
# Train Epoch: 53: train loss : 0.01039825	 train accuracy : 0.99639250	 val accuracy : 0.59018759	 test accuracy : 0.58757062
# Train Epoch: 54: train loss : 0.00989912	 train accuracy : 0.99711400	 val accuracy : 0.59018759	 test accuracy : 0.59322034
# Train Epoch: 55: train loss : 0.00741489	 train accuracy : 0.99711400	 val accuracy : 0.59018759	 test accuracy : 0.57627119
# Train Epoch: 56: train loss : 0.00680415	 train accuracy : 0.99819625	 val accuracy : 0.58585859	 test accuracy : 0.57062147
# Train Epoch: 57: train loss : 0.00631244	 train accuracy : 0.99783550	 val accuracy : 0.59163059	 test accuracy : 0.58757062
# Train Epoch: 58: train loss : 0.00771687	 train accuracy : 0.99747475	 val accuracy : 0.59451659	 test accuracy : 0.59322034
# Train Epoch: 59: train loss : 0.00781495	 train accuracy : 0.99783550	 val accuracy : 0.59595960	 test accuracy : 0.60451977
# Train Epoch: 60: train loss : 0.00499523	 train accuracy : 0.99891775	 val accuracy : 0.60028860	 test accuracy : 0.59887006
# Train Epoch: 61: train loss : 0.00552520	 train accuracy : 0.99927850	 val accuracy : 0.59884560	 test accuracy : 0.58757062
# Train Epoch: 62: train loss : 0.00727173	 train accuracy : 0.99783550	 val accuracy : 0.60894661	 test accuracy : 0.58192090
# Train Epoch: 63: train loss : 0.00650663	 train accuracy : 0.99855700	 val accuracy : 0.60317460	 test accuracy : 0.57627119
# Train Epoch: 64: train loss : 0.00515870	 train accuracy : 0.99927850	 val accuracy : 0.60750361	 test accuracy : 0.57062147
# Train Epoch: 65: train loss : 0.00687842	 train accuracy : 0.99711400	 val accuracy : 0.60606061	 test accuracy : 0.57627119
# Train Epoch: 66: train loss : 0.00767940	 train accuracy : 0.99819625	 val accuracy : 0.60606061	 test accuracy : 0.57062147
# Train Epoch: 67: train loss : 0.00485096	 train accuracy : 0.99855700	 val accuracy : 0.60317460	 test accuracy : 0.55932203
# Train Epoch: 68: train loss : 0.00524283	 train accuracy : 0.99891775	 val accuracy : 0.60461760	 test accuracy : 0.58192090
# Train Epoch: 69: train loss : 0.00399170	 train accuracy : 0.99891775	 val accuracy : 0.59595960	 test accuracy : 0.55367232
# Train Epoch: 70: train loss : 0.00574871	 train accuracy : 0.99891775	 val accuracy : 0.59163059	 test accuracy : 0.55932203
# Train Epoch: 71: train loss : 0.00928183	 train accuracy : 0.99711400	 val accuracy : 0.59307359	 test accuracy : 0.55367232
# Train Epoch: 72: train loss : 0.00644149	 train accuracy : 0.99819625	 val accuracy : 0.58874459	 test accuracy : 0.56497175
# Train Epoch: 73: train loss : 0.00703953	 train accuracy : 0.99675325	 val accuracy : 0.59307359	 test accuracy : 0.57062147
# Train Epoch: 74: train loss : 0.00541385	 train accuracy : 0.99819625	 val accuracy : 0.60317460	 test accuracy : 0.57627119
# Train Epoch: 75: train loss : 0.00408850	 train accuracy : 0.99855700	 val accuracy : 0.60461760	 test accuracy : 0.57627119
# Train Epoch: 76: train loss : 0.00378323	 train accuracy : 0.99927850	 val accuracy : 0.59884560	 test accuracy : 0.57627119
# Train Epoch: 77: train loss : 0.00529563	 train accuracy : 0.99819625	 val accuracy : 0.60028860	 test accuracy : 0.58757062
# Train Epoch: 78: train loss : 0.00416531	 train accuracy : 0.99891775	 val accuracy : 0.60317460	 test accuracy : 0.58192090
# Train Epoch: 79: train loss : 0.00813217	 train accuracy : 0.99639250	 val accuracy : 0.60461760	 test accuracy : 0.57062147
# Train Epoch: 80: train loss : 0.00610236	 train accuracy : 0.99819625	 val accuracy : 0.60606061	 test accuracy : 0.57627119
# Train Epoch: 81: train loss : 0.00422284	 train accuracy : 0.99927850	 val accuracy : 0.60606061	 test accuracy : 0.57062147
# Train Epoch: 82: train loss : 0.00420205	 train accuracy : 0.99819625	 val accuracy : 0.60317460	 test accuracy : 0.56497175
# Train Epoch: 83: train loss : 0.00446598	 train accuracy : 0.99891775	 val accuracy : 0.61327561	 test accuracy : 0.58192090
# Train Epoch: 84: train loss : 0.00475725	 train accuracy : 0.99855700	 val accuracy : 0.61038961	 test accuracy : 0.57627119
# Train Epoch: 85: train loss : 0.00472810	 train accuracy : 0.99819625	 val accuracy : 0.60606061	 test accuracy : 0.58757062
# Train Epoch: 86: train loss : 0.00424506	 train accuracy : 0.99855700	 val accuracy : 0.59884560	 test accuracy : 0.59887006
# Train Epoch: 87: train loss : 0.00445459	 train accuracy : 0.99783550	 val accuracy : 0.59595960	 test accuracy : 0.60451977
# Train Epoch: 88: train loss : 0.00418396	 train accuracy : 0.99855700	 val accuracy : 0.59595960	 test accuracy : 0.60451977
# Train Epoch: 89: train loss : 0.00704344	 train accuracy : 0.99747475	 val accuracy : 0.60894661	 test accuracy : 0.59322034
# Train Epoch: 90: train loss : 0.00566896	 train accuracy : 0.99819625	 val accuracy : 0.61183261	 test accuracy : 0.59322034
# Train Epoch: 91: train loss : 0.00597975	 train accuracy : 0.99891775	 val accuracy : 0.59884560	 test accuracy : 0.57062147
# Train Epoch: 92: train loss : 0.00378773	 train accuracy : 0.99819625	 val accuracy : 0.60173160	 test accuracy : 0.57062147
# Train Epoch: 93: train loss : 0.00393805	 train accuracy : 0.99927850	 val accuracy : 0.60606061	 test accuracy : 0.58192090
# Train Epoch: 94: train loss : 0.00588825	 train accuracy : 0.99819625	 val accuracy : 0.60461760	 test accuracy : 0.60451977
# Train Epoch: 95: train loss : 0.00619602	 train accuracy : 0.99855700	 val accuracy : 0.59595960	 test accuracy : 0.59887006
# Train Epoch: 96: train loss : 0.00507521	 train accuracy : 0.99783550	 val accuracy : 0.58874459	 test accuracy : 0.59887006
# Train Epoch: 97: train loss : 0.00729113	 train accuracy : 0.99747475	 val accuracy : 0.58152958	 test accuracy : 0.61016949
# Train Epoch: 98: train loss : 0.00828918	 train accuracy : 0.99747475	 val accuracy : 0.58297258	 test accuracy : 0.60451977
# Train Epoch: 99: train loss : 0.00382730	 train accuracy : 0.99891775	 val accuracy : 0.58874459	 test accuracy : 0.59322034
# Train Epoch: 100: train loss : 0.00522314	 train accuracy : 0.99819625	 val accuracy : 0.58874459	 test accuracy : 0.58757062
# Train Epoch: 101: train loss : 0.00579504	 train accuracy : 0.99891775	 val accuracy : 0.59740260	 test accuracy : 0.58757062
# Train Epoch: 102: train loss : 0.00718928	 train accuracy : 0.99819625	 val accuracy : 0.60028860	 test accuracy : 0.58757062
# Train Epoch: 103: train loss : 0.00672240	 train accuracy : 0.99747475	 val accuracy : 0.60750361	 test accuracy : 0.59322034
# Train Epoch: 104: train loss : 0.00661478	 train accuracy : 0.99747475	 val accuracy : 0.60028860	 test accuracy : 0.61581921
# Train Epoch: 105: train loss : 0.00753066	 train accuracy : 0.99711400	 val accuracy : 0.59740260	 test accuracy : 0.59887006
# Train Epoch: 106: train loss : 0.00611063	 train accuracy : 0.99855700	 val accuracy : 0.60461760	 test accuracy : 0.59322034
# Train Epoch: 107: train loss : 0.00541835	 train accuracy : 0.99891775	 val accuracy : 0.60317460	 test accuracy : 0.57627119
# Train Epoch: 108: train loss : 0.00726535	 train accuracy : 0.99711400	 val accuracy : 0.59884560	 test accuracy : 0.58757062
# Train Epoch: 109: train loss : 0.00770896	 train accuracy : 0.99783550	 val accuracy : 0.60750361	 test accuracy : 0.57627119
# Train Epoch: 110: train loss : 0.01132919	 train accuracy : 0.99675325	 val accuracy : 0.61327561	 test accuracy : 0.56497175
# Train Epoch: 111: train loss : 0.00407719	 train accuracy : 0.99891775	 val accuracy : 0.60461760	 test accuracy : 0.57062147
# Train Epoch: 112: train loss : 0.00470270	 train accuracy : 0.99855700	 val accuracy : 0.60028860	 test accuracy : 0.58192090
# Train Epoch: 113: train loss : 0.00763481	 train accuracy : 0.99567100	 val accuracy : 0.60317460	 test accuracy : 0.58757062
# Train Epoch: 114: train loss : 0.00832392	 train accuracy : 0.99783550	 val accuracy : 0.60461760	 test accuracy : 0.58757062
# Train Epoch: 115: train loss : 0.00504160	 train accuracy : 0.99819625	 val accuracy : 0.60173160	 test accuracy : 0.58757062
# Train Epoch: 116: train loss : 0.00376027	 train accuracy : 0.99927850	 val accuracy : 0.59451659	 test accuracy : 0.60451977
# Train Epoch: 117: train loss : 0.00255426	 train accuracy : 0.99963925	 val accuracy : 0.59595960	 test accuracy : 0.61016949
# Train Epoch: 118: train loss : 0.00399841	 train accuracy : 0.99891775	 val accuracy : 0.59884560	 test accuracy : 0.61016949
# Train Epoch: 119: train loss : 0.00276952	 train accuracy : 0.99927850	 val accuracy : 0.59595960	 test accuracy : 0.60451977
# Train Epoch: 120: train loss : 0.00672744	 train accuracy : 0.99711400	 val accuracy : 0.59884560	 test accuracy : 0.61016949
# Train Epoch: 121: train loss : 0.00615415	 train accuracy : 0.99891775	 val accuracy : 0.59740260	 test accuracy : 0.61016949
# Train Epoch: 122: train loss : 0.00397054	 train accuracy : 0.99855700	 val accuracy : 0.59884560	 test accuracy : 0.60451977
# Train Epoch: 123: train loss : 0.00296932	 train accuracy : 0.99963925	 val accuracy : 0.59740260	 test accuracy : 0.59887006
# Train Epoch: 124: train loss : 0.00808592	 train accuracy : 0.99711400	 val accuracy : 0.59595960	 test accuracy : 0.59322034
# Train Epoch: 125: train loss : 0.00488637	 train accuracy : 0.99927850	 val accuracy : 0.60028860	 test accuracy : 0.59322034
# Train Epoch: 126: train loss : 0.00351720	 train accuracy : 0.99891775	 val accuracy : 0.59163059	 test accuracy : 0.59322034
# Train Epoch: 127: train loss : 0.00574533	 train accuracy : 0.99783550	 val accuracy : 0.58874459	 test accuracy : 0.58192090
# Train Epoch: 128: train loss : 0.00294893	 train accuracy : 0.99963925	 val accuracy : 0.59163059	 test accuracy : 0.56497175
# Train Epoch: 129: train loss : 0.00526139	 train accuracy : 0.99819625	 val accuracy : 0.59307359	 test accuracy : 0.58192090
# Train Epoch: 130: train loss : 0.00694662	 train accuracy : 0.99711400	 val accuracy : 0.60317460	 test accuracy : 0.58192090
# Train Epoch: 131: train loss : 0.00382779	 train accuracy : 0.99819625	 val accuracy : 0.59740260	 test accuracy : 0.59887006
# Train Epoch: 132: train loss : 0.00272842	 train accuracy : 0.99927850	 val accuracy : 0.60317460	 test accuracy : 0.61016949
# Train Epoch: 133: train loss : 0.00736562	 train accuracy : 0.99783550	 val accuracy : 0.60461760	 test accuracy : 0.61016949
# Train Epoch: 134: train loss : 0.00407700	 train accuracy : 0.99819625	 val accuracy : 0.60317460	 test accuracy : 0.61016949
# Train Epoch: 135: train loss : 0.00382207	 train accuracy : 0.99855700	 val accuracy : 0.60173160	 test accuracy : 0.60451977
# Train Epoch: 136: train loss : 0.00447739	 train accuracy : 0.99819625	 val accuracy : 0.58874459	 test accuracy : 0.58757062
# Train Epoch: 137: train loss : 0.00286272	 train accuracy : 0.99891775	 val accuracy : 0.58441558	 test accuracy : 0.58192090
# Train Epoch: 138: train loss : 0.00321413	 train accuracy : 0.99927850	 val accuracy : 0.58152958	 test accuracy : 0.59887006
# Train Epoch: 139: train loss : 0.00678386	 train accuracy : 0.99747475	 val accuracy : 0.57864358	 test accuracy : 0.59322034
# Train Epoch: 140: train loss : 0.00291964	 train accuracy : 0.99963925	 val accuracy : 0.58874459	 test accuracy : 0.58757062
# Train Epoch: 141: train loss : 0.00659434	 train accuracy : 0.99819625	 val accuracy : 0.58585859	 test accuracy : 0.59887006
# Train Epoch: 142: train loss : 0.00291601	 train accuracy : 0.99891775	 val accuracy : 0.58585859	 test accuracy : 0.58757062
# Train Epoch: 143: train loss : 0.00674383	 train accuracy : 0.99783550	 val accuracy : 0.58874459	 test accuracy : 0.59887006
# Train Epoch: 144: train loss : 0.00645646	 train accuracy : 0.99783550	 val accuracy : 0.59307359	 test accuracy : 0.59322034
# Train Epoch: 145: train loss : 0.00398569	 train accuracy : 0.99891775	 val accuracy : 0.58585859	 test accuracy : 0.58192090
# Train Epoch: 146: train loss : 0.00436484	 train accuracy : 0.99927850	 val accuracy : 0.58441558	 test accuracy : 0.59322034
# Train Epoch: 147: train loss : 0.00576936	 train accuracy : 0.99783550	 val accuracy : 0.58441558	 test accuracy : 0.61016949
# Train Epoch: 148: train loss : 0.00525191	 train accuracy : 0.99783550	 val accuracy : 0.59451659	 test accuracy : 0.62146893
# Train Epoch: 149: train loss : 0.00495148	 train accuracy : 0.99855700	 val accuracy : 0.60173160	 test accuracy : 0.61581921
# Train Epoch: 150: train loss : 0.00285011	 train accuracy : 0.99927850	 val accuracy : 0.61038961	 test accuracy : 0.61016949
# Train Epoch: 151: train loss : 0.00457212	 train accuracy : 0.99855700	 val accuracy : 0.60894661	 test accuracy : 0.61016949
# Train Epoch: 152: train loss : 0.00330411	 train accuracy : 0.99927850	 val accuracy : 0.60894661	 test accuracy : 0.60451977
# Train Epoch: 153: train loss : 0.00327888	 train accuracy : 0.99927850	 val accuracy : 0.61183261	 test accuracy : 0.61016949
# Train Epoch: 154: train loss : 0.00588850	 train accuracy : 0.99783550	 val accuracy : 0.59884560	 test accuracy : 0.58192090
# Train Epoch: 155: train loss : 0.00348671	 train accuracy : 0.99855700	 val accuracy : 0.59595960	 test accuracy : 0.56497175
# Train Epoch: 156: train loss : 0.00444549	 train accuracy : 0.99855700	 val accuracy : 0.58152958	 test accuracy : 0.57062147
# Train Epoch: 157: train loss : 0.00980662	 train accuracy : 0.99711400	 val accuracy : 0.59595960	 test accuracy : 0.57627119
# Train Epoch: 158: train loss : 0.00517907	 train accuracy : 0.99783550	 val accuracy : 0.60317460	 test accuracy : 0.59887006
# Train Epoch: 159: train loss : 0.00603128	 train accuracy : 0.99783550	 val accuracy : 0.60894661	 test accuracy : 0.59322034
# Train Epoch: 160: train loss : 0.00540118	 train accuracy : 0.99819625	 val accuracy : 0.61327561	 test accuracy : 0.57062147
# Train Epoch: 161: train loss : 0.00242935	 train accuracy : 0.99927850	 val accuracy : 0.61183261	 test accuracy : 0.58192090
# Train Epoch: 162: train loss : 0.00690604	 train accuracy : 0.99783550	 val accuracy : 0.61327561	 test accuracy : 0.57627119
# Train Epoch: 163: train loss : 0.00507321	 train accuracy : 0.99855700	 val accuracy : 0.60894661	 test accuracy : 0.58757062
# Train Epoch: 164: train loss : 0.00355947	 train accuracy : 0.99891775	 val accuracy : 0.60606061	 test accuracy : 0.60451977
# Train Epoch: 165: train loss : 0.00541637	 train accuracy : 0.99855700	 val accuracy : 0.59163059	 test accuracy : 0.58757062
# Train Epoch: 166: train loss : 0.00535787	 train accuracy : 0.99855700	 val accuracy : 0.59163059	 test accuracy : 0.57062147
# Train Epoch: 167: train loss : 0.00443067	 train accuracy : 0.99855700	 val accuracy : 0.59451659	 test accuracy : 0.57627119
# Train Epoch: 168: train loss : 0.00359691	 train accuracy : 0.99891775	 val accuracy : 0.59307359	 test accuracy : 0.58757062
# Train Epoch: 169: train loss : 0.00406671	 train accuracy : 0.99855700	 val accuracy : 0.60750361	 test accuracy : 0.58757062
# Train Epoch: 170: train loss : 0.00490236	 train accuracy : 0.99855700	 val accuracy : 0.60606061	 test accuracy : 0.58192090
# Train Epoch: 171: train loss : 0.00423113	 train accuracy : 0.99855700	 val accuracy : 0.60894661	 test accuracy : 0.58192090
# ...
# Train Epoch: 78: train loss : 0.00479800	 train accuracy : 0.99928876	 val accuracy : 0.62588905	 test accuracy : 0.60479042
# Train Epoch: 79: train loss : 0.00839090	 train accuracy : 0.99822191	 val accuracy : 0.61308677	 test accuracy : 0.58682635
# Train Epoch: 80: train loss : 0.00500803	 train accuracy : 0.99857752	 val accuracy : 0.61024182	 test accuracy : 0.60479042
# Train Epoch: 81: train loss : 0.01095057	 train accuracy : 0.99644381	 val accuracy : 0.61593172	 test accuracy : 0.59880240
# Train Epoch: 82: train loss : 0.00332278	 train accuracy : 0.99928876	 val accuracy : 0.61593172	 test accuracy : 0.59880240
# Train Epoch: 83: train loss : 0.00513912	 train accuracy : 0.99893314	 val accuracy : 0.61735420	 test accuracy : 0.60479042
# Train Epoch: 84: train loss : 0.00576856	 train accuracy : 0.99893314	 val accuracy : 0.61450925	 test accuracy : 0.62275449
# Train Epoch: 85: train loss : 0.00409421	 train accuracy : 0.99893314	 val accuracy : 0.61166430	 test accuracy : 0.64071856
# Train Epoch: 86: train loss : 0.00510191	 train accuracy : 0.99893314	 val accuracy : 0.61735420	 test accuracy : 0.63473054
# Train Epoch: 87: train loss : 0.00623390	 train accuracy : 0.99786629	 val accuracy : 0.60597440	 test accuracy : 0.64071856
# Train Epoch: 88: train loss : 0.00515723	 train accuracy : 0.99857752	 val accuracy : 0.61024182	 test accuracy : 0.62275449
# Train Epoch: 89: train loss : 0.00453401	 train accuracy : 0.99857752	 val accuracy : 0.61877667	 test accuracy : 0.62874251
# Train Epoch: 90: train loss : 0.00706842	 train accuracy : 0.99822191	 val accuracy : 0.62162162	 test accuracy : 0.62874251
# Train Epoch: 91: train loss : 0.00426905	 train accuracy : 0.99857752	 val accuracy : 0.61877667	 test accuracy : 0.62874251
# Train Epoch: 92: train loss : 0.00406537	 train accuracy : 0.99857752	 val accuracy : 0.61166430	 test accuracy : 0.62275449
# Train Epoch: 93: train loss : 0.00602098	 train accuracy : 0.99751067	 val accuracy : 0.61735420	 test accuracy : 0.63473054
# Train Epoch: 94: train loss : 0.00472304	 train accuracy : 0.99857752	 val accuracy : 0.62019915	 test accuracy : 0.64071856
# Train Epoch: 95: train loss : 0.00336307	 train accuracy : 0.99928876	 val accuracy : 0.62019915	 test accuracy : 0.65269461
# Train Epoch: 96: train loss : 0.00271009	 train accuracy : 0.99928876	 val accuracy : 0.61877667	 test accuracy : 0.65269461
# Train Epoch: 97: train loss : 0.00452397	 train accuracy : 0.99822191	 val accuracy : 0.62304410	 test accuracy : 0.65269461
# Train Epoch: 98: train loss : 0.00410864	 train accuracy : 0.99893314	 val accuracy : 0.62162162	 test accuracy : 0.65269461
# Train Epoch: 99: train loss : 0.00278990	 train accuracy : 0.99928876	 val accuracy : 0.62019915	 test accuracy : 0.66467066
# Train Epoch: 100: train loss : 0.00382880	 train accuracy : 0.99893314	 val accuracy : 0.61593172	 test accuracy : 0.67065868
# Train Epoch: 101: train loss : 0.00312842	 train accuracy : 0.99928876	 val accuracy : 0.61166430	 test accuracy : 0.66467066
# Train Epoch: 102: train loss : 0.00497081	 train accuracy : 0.99822191	 val accuracy : 0.61877667	 test accuracy : 0.65868263
# Train Epoch: 103: train loss : 0.00296832	 train accuracy : 0.99964438	 val accuracy : 0.61450925	 test accuracy : 0.65269461
# Train Epoch: 104: train loss : 0.00220118	 train accuracy : 0.99964438	 val accuracy : 0.61735420	 test accuracy : 0.64670659
# Train Epoch: 105: train loss : 0.00708970	 train accuracy : 0.99893314	 val accuracy : 0.62162162	 test accuracy : 0.65868263
# Train Epoch: 106: train loss : 0.00621426	 train accuracy : 0.99857752	 val accuracy : 0.61735420	 test accuracy : 0.63473054
# Train Epoch: 107: train loss : 0.00581492	 train accuracy : 0.99822191	 val accuracy : 0.60739687	 test accuracy : 0.61077844
# Train Epoch: 108: train loss : 0.00470908	 train accuracy : 0.99822191	 val accuracy : 0.61024182	 test accuracy : 0.61676647
# Train Epoch: 109: train loss : 0.00537832	 train accuracy : 0.99893314	 val accuracy : 0.61166430	 test accuracy : 0.60479042
# Train Epoch: 110: train loss : 0.00520120	 train accuracy : 0.99786629	 val accuracy : 0.60597440	 test accuracy : 0.61676647
# Train Epoch: 111: train loss : 0.00580568	 train accuracy : 0.99751067	 val accuracy : 0.60739687	 test accuracy : 0.62275449
# Train Epoch: 112: train loss : 0.00290608	 train accuracy : 0.99928876	 val accuracy : 0.60739687	 test accuracy : 0.62275449
# Train Epoch: 113: train loss : 0.00558582	 train accuracy : 0.99857752	 val accuracy : 0.60455192	 test accuracy : 0.62275449
# Train Epoch: 114: train loss : 0.00371895	 train accuracy : 0.99964438	 val accuracy : 0.60455192	 test accuracy : 0.62275449
# Train Epoch: 115: train loss : 0.00322215	 train accuracy : 0.99893314	 val accuracy : 0.60881935	 test accuracy : 0.63473054
# Train Epoch: 116: train loss : 0.00372207	 train accuracy : 0.99786629	 val accuracy : 0.60739687	 test accuracy : 0.62874251
# Train Epoch: 117: train loss : 0.00224730	 train accuracy : 0.99964438	 val accuracy : 0.61024182	 test accuracy : 0.62874251
# Train Epoch: 118: train loss : 0.00407610	 train accuracy : 0.99893314	 val accuracy : 0.60881935	 test accuracy : 0.63473054
# Train Epoch: 119: train loss : 0.00369216	 train accuracy : 0.99928876	 val accuracy : 0.60455192	 test accuracy : 0.65269461
# Train Epoch: 120: train loss : 0.00332374	 train accuracy : 0.99928876	 val accuracy : 0.60739687	 test accuracy : 0.66467066
# Train Epoch: 121: train loss : 0.00349833	 train accuracy : 0.99928876	 val accuracy : 0.61308677	 test accuracy : 0.65868263
# Train Epoch: 122: train loss : 0.00233587	 train accuracy : 0.99964438	 val accuracy : 0.61450925	 test accuracy : 0.64670659
# Train Epoch: 123: train loss : 0.00502248	 train accuracy : 0.99786629	 val accuracy : 0.61024182	 test accuracy : 0.64071856
# Train Epoch: 124: train loss : 0.00228862	 train accuracy : 0.99964438	 val accuracy : 0.60170697	 test accuracy : 0.64071856
# Train Epoch: 125: train loss : 0.00320503	 train accuracy : 0.99928876	 val accuracy : 0.60170697	 test accuracy : 0.64071856
# Train Epoch: 126: train loss : 0.00365309	 train accuracy : 0.99893314	 val accuracy : 0.60739687	 test accuracy : 0.62874251
# Train Epoch: 127: train loss : 0.00190139	 train accuracy : 0.99964438	 val accuracy : 0.61308677	 test accuracy : 0.62275449
# Train Epoch: 128: train loss : 0.00365312	 train accuracy : 0.99928876	 val accuracy : 0.61166430	 test accuracy : 0.64071856
# Train Epoch: 129: train loss : 0.00550953	 train accuracy : 0.99751067	 val accuracy : 0.60312945	 test accuracy : 0.63473054
# Train Epoch: 130: train loss : 0.00358489	 train accuracy : 0.99928876	 val accuracy : 0.60455192	 test accuracy : 0.64071856
# Train Epoch: 131: train loss : 0.00189180	 train accuracy : 0.99928876	 val accuracy : 0.61593172	 test accuracy : 0.62275449
# Train Epoch: 132: train loss : 0.00363690	 train accuracy : 0.99893314	 val accuracy : 0.61024182	 test accuracy : 0.62874251
# Train Epoch: 133: train loss : 0.00287259	 train accuracy : 0.99964438	 val accuracy : 0.60597440	 test accuracy : 0.62275449
# Train Epoch: 134: train loss : 0.00519358	 train accuracy : 0.99822191	 val accuracy : 0.60312945	 test accuracy : 0.62275449
# Train Epoch: 135: train loss : 0.00427738	 train accuracy : 0.99822191	 val accuracy : 0.61166430	 test accuracy : 0.62275449
# Train Epoch: 136: train loss : 0.00253223	 train accuracy : 0.99964438	 val accuracy : 0.60455192	 test accuracy : 0.61077844
# Train Epoch: 137: train loss : 0.00537065	 train accuracy : 0.99786629	 val accuracy : 0.59601707	 test accuracy : 0.60479042
# Train Epoch: 138: train loss : 0.00585966	 train accuracy : 0.99786629	 val accuracy : 0.59317212	 test accuracy : 0.60479042
# Train Epoch: 139: train loss : 0.00778649	 train accuracy : 0.99715505	 val accuracy : 0.59317212	 test accuracy : 0.61676647
# Train Epoch: 140: train loss : 0.00305604	 train accuracy : 0.99857752	 val accuracy : 0.60028450	 test accuracy : 0.61077844
# Train Epoch: 141: train loss : 0.00311521	 train accuracy : 0.99857752	 val accuracy : 0.61166430	 test accuracy : 0.62275449
# Train Epoch: 142: train loss : 0.00511146	 train accuracy : 0.99786629	 val accuracy : 0.61308677	 test accuracy : 0.62874251
# Train Epoch: 143: train loss : 0.00358836	 train accuracy : 0.99928876	 val accuracy : 0.60455192	 test accuracy : 0.62275449
# Train Epoch: 144: train loss : 0.00436048	 train accuracy : 0.99822191	 val accuracy : 0.60170697	 test accuracy : 0.62874251
# Train Epoch: 145: train loss : 0.00318496	 train accuracy : 0.99893314	 val accuracy : 0.61024182	 test accuracy : 0.62275449
# Train Epoch: 146: train loss : 0.00388776	 train accuracy : 0.99822191	 val accuracy : 0.62019915	 test accuracy : 0.61676647
# Train Epoch: 147: train loss : 0.00282276	 train accuracy : 0.99893314	 val accuracy : 0.62019915	 test accuracy : 0.61676647
# Train Epoch: 148: train loss : 0.00351684	 train accuracy : 0.99857752	 val accuracy : 0.61735420	 test accuracy : 0.62874251
# Train Epoch: 149: train loss : 0.00290135	 train accuracy : 0.99928876	 val accuracy : 0.61308677	 test accuracy : 0.63473054
# Train Epoch: 150: train loss : 0.00164056	 train accuracy : 1.00000000	 val accuracy : 0.61308677	 test accuracy : 0.64071856
# Train Epoch: 151: train loss : 0.00279710	 train accuracy : 0.99928876	 val accuracy : 0.60881935	 test accuracy : 0.65868263
# Train Epoch: 152: train loss : 0.00621014	 train accuracy : 0.99822191	 val accuracy : 0.61024182	 test accuracy : 0.65269461
# Train Epoch: 153: train loss : 0.00209964	 train accuracy : 1.00000000	 val accuracy : 0.60881935	 test accuracy : 0.64670659
# Train Epoch: 154: train loss : 0.00344328	 train accuracy : 0.99964438	 val accuracy : 0.60597440	 test accuracy : 0.64670659
# Train Epoch: 155: train loss : 0.00320908	 train accuracy : 0.99893314	 val accuracy : 0.60881935	 test accuracy : 0.64670659
# Train Epoch: 156: train loss : 0.00543188	 train accuracy : 0.99786629	 val accuracy : 0.60028450	 test accuracy : 0.62275449
# Train Epoch: 157: train loss : 0.00331756	 train accuracy : 0.99893314	 val accuracy : 0.60455192	 test accuracy : 0.62275449
# Train Epoch: 158: train loss : 0.00448088	 train accuracy : 0.99893314	 val accuracy : 0.60312945	 test accuracy : 0.62874251
# Train Epoch: 159: train loss : 0.00180696	 train accuracy : 0.99964438	 val accuracy : 0.60455192	 test accuracy : 0.62275449
# Train Epoch: 160: train loss : 0.00605603	 train accuracy : 0.99715505	 val accuracy : 0.60312945	 test accuracy : 0.61676647
# Train Epoch: 161: train loss : 0.00174534	 train accuracy : 1.00000000	 val accuracy : 0.60597440	 test accuracy : 0.61077844
# Train Epoch: 162: train loss : 0.00345912	 train accuracy : 0.99893314	 val accuracy : 0.60597440	 test accuracy : 0.60479042
# Train Epoch: 163: train loss : 0.01365082	 train accuracy : 0.99679943	 val accuracy : 0.60170697	 test accuracy : 0.61676647
# Train Epoch: 164: train loss : 0.00218341	 train accuracy : 0.99928876	 val accuracy : 0.59743954	 test accuracy : 0.63473054
# Train Epoch: 165: train loss : 0.00356483	 train accuracy : 0.99822191	 val accuracy : 0.59174964	 test accuracy : 0.63473054
# Train Epoch: 166: train loss : 0.00474468	 train accuracy : 0.99893314	 val accuracy : 0.59032717	 test accuracy : 0.64670659
# Train Epoch: 167: train loss : 0.00347722	 train accuracy : 0.99893314	 val accuracy : 0.59743954	 test accuracy : 0.64670659
# Train Epoch: 168: train loss : 0.00373469	 train accuracy : 0.99893314	 val accuracy : 0.60739687	 test accuracy : 0.64071856
# Train Epoch: 169: train loss : 0.00727276	 train accuracy : 0.99857752	 val accuracy : 0.60881935	 test accuracy : 0.64071856
# Train Epoch: 170: train loss : 0.00373126	 train accuracy : 0.99857752	 val accuracy : 0.61877667	 test accuracy : 0.61077844
# Train Epoch: 171: train loss : 0.00295205	 train accuracy : 0.99928876	 val accuracy : 0.61877667	 test accuracy : 0.61077844
# Train Epoch: 172: train loss : 0.00387763	 train accuracy : 0.99893314	 val accuracy : 0.61308677	 test accuracy : 0.61676647
# Train Epoch: 173: train loss : 0.00174509	 train accuracy : 1.00000000	 val accuracy : 0.61166430	 test accuracy : 0.63473054
# Train Epoch: 174: train loss : 0.00364618	 train accuracy : 0.99928876	 val accuracy : 0.60455192	 test accuracy : 0.62275449
# Train Epoch: 175: train loss : 0.00560548	 train accuracy : 0.99751067	 val accuracy : 0.59601707	 test accuracy : 0.63473054
# Train Epoch: 176: train loss : 0.00349567	 train accuracy : 0.99857752	 val accuracy : 0.60597440	 test accuracy : 0.62874251
# Train Epoch: 177: train loss : 0.00249920	 train accuracy : 0.99928876	 val accuracy : 0.60597440	 test accuracy : 0.62874251
# Train Epoch: 178: train loss : 0.00831961	 train accuracy : 0.99857752	 val accuracy : 0.61024182	 test accuracy : 0.63473054
# Train Epoch: 179: train loss : 0.00707927	 train accuracy : 0.99822191	 val accuracy : 0.61024182	 test accuracy : 0.62874251
# Train Epoch: 180: train loss : 0.00331474	 train accuracy : 0.99893314	 val accuracy : 0.60170697	 test accuracy : 0.64071856
# Train Epoch: 181: train loss : 0.00289515	 train accuracy : 0.99928876	 val accuracy : 0.61308677	 test accuracy : 0.64071856
# Train Epoch: 182: train loss : 0.00632180	 train accuracy : 0.99857752	 val accuracy : 0.61024182	 test accuracy : 0.63473054
# Train Epoch: 183: train loss : 0.00535192	 train accuracy : 0.99822191	 val accuracy : 0.61877667	 test accuracy : 0.62874251
# Save models
# Train Epoch: 184: train loss : 0.00198706	 train accuracy : 0.99964438	 val accuracy : 0.62873400	 test accuracy : 0.62874251
# Train Epoch: 185: train loss : 0.00356877	 train accuracy : 0.99822191	 val accuracy : 0.62446657	 test accuracy : 0.61676647
# Train Epoch: 186: train loss : 0.00452841	 train accuracy : 0.99893314	 val accuracy : 0.62019915	 test accuracy : 0.62275449
# Train Epoch: 187: train loss : 0.00446897	 train accuracy : 0.99893314	 val accuracy : 0.61450925	 test accuracy : 0.62874251
# Train Epoch: 188: train loss : 0.00233944	 train accuracy : 0.99928876	 val accuracy : 0.60597440	 test accuracy : 0.62874251
# Train Epoch: 189: train loss : 0.00354906	 train accuracy : 0.99928876	 val accuracy : 0.60312945	 test accuracy : 0.64071856
# Train Epoch: 190: train loss : 0.00559154	 train accuracy : 0.99751067	 val accuracy : 0.60170697	 test accuracy : 0.64071856
# Train Epoch: 191: train loss : 0.00380651	 train accuracy : 0.99928876	 val accuracy : 0.60455192	 test accuracy : 0.64071856
# Train Epoch: 192: train loss : 0.00315854	 train accuracy : 0.99893314	 val accuracy : 0.61024182	 test accuracy : 0.64071856
# Train Epoch: 193: train loss : 0.00345786	 train accuracy : 0.99893314	 val accuracy : 0.60312945	 test accuracy : 0.65269461
# Train Epoch: 194: train loss : 0.00621683	 train accuracy : 0.99822191	 val accuracy : 0.61024182	 test accuracy : 0.62874251
# Train Epoch: 195: train loss : 0.00683841	 train accuracy : 0.99715505	 val accuracy : 0.60312945	 test accuracy : 0.65269461
# Train Epoch: 196: train loss : 0.00254664	 train accuracy : 0.99928876	 val accuracy : 0.59743954	 test accuracy : 0.62874251
# Train Epoch: 197: train loss : 0.00305724	 train accuracy : 0.99893314	 val accuracy : 0.59174964	 test accuracy : 0.62874251
# Train Epoch: 198: train loss : 0.00985350	 train accuracy : 0.99679943	 val accuracy : 0.59032717	 test accuracy : 0.64071856
# Train Epoch: 199: train loss : 0.00619767	 train accuracy : 0.99786629	 val accuracy : 0.58890469	 test accuracy : 0.65269461
# Train Epoch: 200: train loss : 0.00581196	 train accuracy : 0.99822191	 val accuracy : 0.60312945	 test accuracy : 0.64670659
# In ensemble  5
# The best validaiton accuracy is:  0.6287339971550497
# Happened at epoch:  184
# The corresponding test accuracy 0.6287425149700598
# The corresponding test AUC is:  0.6604347826086955
# The Max voting test accuracy is:  0.6045977011494252
# The test AUC is:  0.6473105881477781
