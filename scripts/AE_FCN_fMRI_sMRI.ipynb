# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/ABIDE/")
# Out:
# Mounted at /content/drive

# %%
# load ComBat algorithm
# !python /content/drive/MyDrive/ABIDE/neuralCombat.py 
import sys
sys.path.append('/content/drive/MyDrive/ABIDE/')

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from neuralCombat import *
# from neuralCombat.py import neuralCombat
import pandas as pd
from sklearn import svm
import joblib
import openpyxl
from openpyxl import load_workbook
import os
import scipy.io as scio
import argparse
import numpy as np
import time
import torch
import torch.utils.data
import torch.nn as nn
import torch.optim as optim
from torch.utils.data.dataset import Dataset
from torch.autograd import Variable
from torchvision import datasets, transforms
from torchvision.utils import make_grid , save_image
import torchvision.utils as vutils
from os.path import join
from os import listdir
from torch.utils.data.dataloader import DataLoader
from torch.utils.data import DataLoader
from collections import OrderedDict
import nibabel as nib
import matplotlib.pyplot as plt
import cv2 as cv
from os import path
import shutil
import scipy.stats
import scipy.ndimage
import random
import torch.nn.init as init
import torch.nn.functional as F
import sys
import math
from functools import reduce
import operator
from scipy.interpolate import interp1d
from torch.optim import lr_scheduler
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import RidgeClassifier
from sklearn.feature_selection import RFE

def feature_selection_fMRI(matrix, labels, train_ind, fnum):
    """
        matrix       : feature matrix (num_subjects x num_features)
        labels       : ground truth labels (num_subjects x 1)
        train_ind    : indices of the training samples
        fnum         : size of the feature vector after feature selection 

    return:
        x_data      : feature matrix of lower dimension (num_subjects x fnum)
    """

    estimator = RidgeClassifier()
    selector = RFE(estimator, n_features_to_select=fnum, step=100, verbose=1)

    featureX = matrix[train_ind, :]
    featureY = labels[train_ind]
    selector = selector.fit(featureX, featureY.ravel())

    return selector
def feature_selection_sMRI(matrix, labels, train_ind, fnum):
    """
        matrix       : feature matrix (num_subjects x num_features)
        labels       : ground truth labels (num_subjects x 1)
        train_ind    : indices of the training samples
        fnum         : size of the feature vector after feature selection 

    return:
        x_data      : feature matrix of lower dimension (num_subjects x fnum)
    """

    estimator = RidgeClassifier()
    selector = RFE(estimator, n_features_to_select=fnum, step=10, verbose=1)

    featureX = matrix[train_ind, :]
    featureY = labels[train_ind]
    selector = selector.fit(featureX, featureY.ravel())

    return selector

def get_index(lst=None, item=''):
	return [i for i in range(len(lst)) if lst[i] == item]

def flatten_one(length, img):
	'''
	  In some situations, the dimension on z-axis of images are smaller than
	  the dimension of z-axis of patches, this function will be used to pad
	'''

	one_line = np.zeros((1, int(length)))
	position = 0
	for i in range(img.shape[0]):  # column
		for j in range(i + 1, img.shape[1]):  # row
			one_line[0, position] = img[j, i]
			position = position + 1
	return one_line


def get_ids(num_subjects=None,dir_path=''):
	"""
	return:
		subject_IDs    : list of all subject IDs
	"""
	subject_IDs = np.genfromtxt(os.path.join(dir_path, 'subject_IDs.txt'), dtype=str)

	if num_subjects is not None:
		subject_IDs = subject_IDs[:num_subjects]

	return subject_IDs

def save_model(net,path, name_net):

  # This fucntion is used to save a specific model

    path_net =  path + '/' + name_net + '.pth'
    torch.save(net.cpu().state_dict(), path_net)
    net.cuda()

def load_model(net, path, name_net):

  # This function is used to load a specific model we saved before

    path_net =  path + '/' + name_net + '.pth'
    net.load_state_dict(torch.load(path_net))

    return net

def initialize():
  set_seed


def set_seed(seed=0):
  random.seed(seed)
  np.random.seed(seed)
  torch.manual_seed(seed)
  torch.cuda.manual_seed(seed)
  torch.cuda.manual_seed_all(seed)
  torch.backends.cudnn.deterministic = True
  torch.backends.cudnn.benchmark = False

# initialize()

# %%
########################################### Load Data ###############################################
#####################################################################################################
#####################################################################################################
fMRI_atlas = 'CC200'  # AAL or CC200
combat_fMRI = True    # True or False
combat_sMRI = True

if combat_sMRI == False:
  save_combat_sMRI = '/without_ComBat/'
else:
  save_combat_sMRI = '/with_ComBat/'

# fMRI path
save_path = '/content/drive/MyDrive/ABIDE/save_models/CC200_sMRI/'+ save_combat_sMRI
root_path_fMRI = '/content/dataset'
if os.path.exists(root_path_fMRI):
  shutil.rmtree(root_path_fMRI) 
shutil.copytree('/content/drive/MyDrive/ABIDE/' + fMRI_atlas + '/original/', root_path_fMRI) 
label_dir = '/content/drive/MyDrive/ABIDE/phenotypic_image_quality'

# sMRI path
localDir = '/content/sMRI_dataset/'
if os.path.exists(localDir):
  shutil.rmtree(localDir) 
os.makedirs(localDir)
# !unzip '/content/drive/MyDrive/ABIDE/freesurfer_stats.zip' -d '/content/sMRI_dataset'
localDir = localDir + 'freesurfer_stats/'


k_fold = 5
new_number_features_fMRI = 5000
new_number_features_sMRI = 1435
new_number_features_combine = 6000
number_samples = 871
useless_samples = ['51334']
if fMRI_atlas == 'AAL':
  image_size = [116, 116]
else:
  image_size = [200, 200]
scaler = True


age_name = 'ages.mat'
gender_name = 'genders.mat'
label_name = 'ABIDE_label_871.mat'
label = scio.loadmat(os.path.join(label_dir, label_name))
label = label['label'][0]
labels = np.zeros(number_samples - len(useless_samples))
site_name = 'sites.mat'
site = scio.loadmat(os.path.join(label_dir, site_name))
all_sites = site['sites']
for i in range(len(all_sites)):
	site = all_sites[i]
	all_sites[i] = site.replace(' ', '')
unique_sites = np.unique(all_sites)
sites = []
unique_sites = list(unique_sites)

gender = scio.loadmat(os.path.join(label_dir, gender_name))
gender = gender['genders']
genders = np.zeros((number_samples - len(useless_samples), 1))

age = scio.loadmat(os.path.join(label_dir, age_name))
age = age['ages']
ages = np.zeros((number_samples - len(useless_samples), 1))

subject_IDs = get_ids(number_samples,dir_path=label_dir)
subject_IDs = subject_IDs.tolist()
length = image_size[0] * (image_size[1]-1) / 2
fMRI_images = np.zeros((number_samples - len(useless_samples), int(length)))

position = 0
print('constructing fMRI features')
for i in range(number_samples):
  subject_name = subject_IDs[i]
  if subject_name in useless_samples:
    subject_index = get_index(lst=subject_IDs, item=subject_name)
    print('The index for sample ' + subject_name + ' is : ', subject_index)
  else:
    image_name = subject_name + '.mat'
    subject_index = get_index(lst=subject_IDs, item=subject_name)
    image = scio.loadmat(os.path.join(root_path_fMRI, image_name))
    img = image['connectivity']

    idx = np.triu_indices_from(img, 1)
    fMRI_images[position, :] = img[idx]
    sites.append(all_sites[subject_index[0]])
    labels[position] = label[subject_index[0]]
    genders[position] = int(gender[subject_index[0]]) + 1
    ages[position] = float(age[subject_index[0]].replace(' ', ''))
    position = position + 1

if scaler == True:
	fMRI_images = StandardScaler().fit_transform(fMRI_images)
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51096/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51097/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51098/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51099/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51100/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51101/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51102/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51103/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51104/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51105/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51106/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51107/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51109/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51110/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51111/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51112/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51113/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51114/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51116/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51117/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51118/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51122/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51123/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51124/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51126/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51127/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51128/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51129/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51130/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51131/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.w-g.pct.stats
# ...
#   inflating: /content/sMRI_dataset/freesurfer_stats/51576/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51576/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51576/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51576/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51576/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51577/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51578/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51579/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51580/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51582/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51583/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51584/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51585/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51606/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51607/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/wmparc.stats
# constructing fMRI features
# The index for sample 51334 is :  [799]

# %%
############################################### Load sMRI ###############################################################
############################################### Load sMRI ###############################################################
############################################### Load sMRI ###############################################################
############################################### Load Desikan_Killiany_features
left = 'lh.aparc.stats'
right = 'rh.aparc.stats'
number_roi = 68
feature_list = ['NumVert', 'SurfArea', 'GrayVol', 'ThickAvg', 'ThickStd', 'MeanCurv', 'GausCurv', 'FoldInd', 'CurvInd']
names = ['StructName', 'NumVert', 'SurfArea', 'GrayVol', 'ThickAvg', 'ThickStd', 'MeanCurv', 'GausCurv', 'FoldInd', 'CurvInd']
skiprows= list(range(0,61))
Desikan_Killiany_features = np.zeros((number_samples - len(useless_samples), number_roi * len(feature_list)))


position = 0
print('constructing Desikan-Killiany Atlas features')
for i in range(number_samples):
  subject_name = subject_IDs[i]
  if subject_name in useless_samples:
    subject_index = get_index(lst=subject_IDs, item=subject_name)
    print('The index for sample ' + subject_name + ' is : ', subject_index)
  else:
    table_left = pd.read_table(localDir + subject_name + '/' + left, sep='\s+', names=names,
						  skiprows=skiprows)
    table_right = pd.read_table(localDir + subject_name + '/' + right, sep='\s+', names=names,
						  skiprows=skiprows)

    for j in range(len(feature_list)):
      feature_name = feature_list[j]
      left_features = table_left[feature_name].values.tolist()
      right_features = table_right[feature_name].values.tolist()
      all_features = left_features + right_features
      if len(all_features) != number_roi:
       print('The sample ' + subject_name + ' has mistake!')
      all_features = np.array(all_features)
      Desikan_Killiany_features[position, j*number_roi : (j+1)*number_roi] = all_features
    position = position + 1

if scaler == True:
	for i in range(len(feature_list)):
		Desikan_Killiany_features[:, i * number_roi: (i+1) * number_roi] = StandardScaler().fit_transform(Desikan_Killiany_features[:, i * number_roi: (i+1) * number_roi])

print('finished')

############################################### Load aseg features
print('constructing aseg features')
number_roi_aseg = 45
aseg = 'aseg.stats'
feature_list_aseg = ['Number of Voxels', 'Volume', 'Intensity normMean', 'Itensity normStdDev', 'Intensity normMin', 'Intensity normMax', 'Intensity normRange']
names_aseg = ['ColHeader Index', 'Segmentation Id ', 'Number of Voxels', 'Volume', 'Structure Name', 'Intensity normMean', 'Itensity normStdDev', 'Intensity normMin', 'Intensity normMax', 'Intensity normRange']
skiprows_aseg= list(range(0,79))
aseg_features = np.zeros((number_samples - len(useless_samples), number_roi_aseg * len(feature_list_aseg)))

position = 0
for i in range(number_samples):
	subject_name = subject_IDs[i]
	if subject_name in useless_samples:
		subject_index = get_index(lst=subject_IDs, item=subject_name)
		print('The index for sample ' + subject_name + ' is : ', subject_index)
	else:
		table_left = pd.read_table(localDir + subject_name + '/' + aseg, sep='\s+', names=names_aseg,
						  skiprows=skiprows_aseg)
		for j in range(len(feature_list_aseg)):
			feature_name = feature_list_aseg[j]
			left_features = table_left[feature_name].values.tolist()
			if len(left_features) != number_roi_aseg:
				print('The sample ' + subject_name + ' has mistake!')
			all_features = np.array(left_features)
			aseg_features[position, j*number_roi_aseg : (j+1)*number_roi_aseg] = all_features
		position = position + 1

if scaler == True:
	for i in range(len(feature_list_aseg)):
		aseg_features[:, i * number_roi_aseg: (i+1) * number_roi_aseg] = StandardScaler().fit_transform(aseg_features[:, i * number_roi_aseg: (i+1) * number_roi_aseg])
print('finished')

############################################### Load wmparc features
number_roi_wmparc = 70
wmparc = 'wmparc.stats'
feature_list_wmparc = ['Number of Voxels', 'Volume', 'Intensity normMean', 'Itensity normStdDev', 'Intensity normMin', 'Intensity normMax', 'Intensity normRange']
names_wmparc = ['ColHeader Index', 'Segmentation Id ', 'Number of Voxels', 'Volume', 'Structure Name', 'Intensity normMean', 'Itensity normStdDev', 'Intensity normMin', 'Intensity normMax', 'Intensity normRange']
skiprows_wmparc= list(range(0,65))
wmparc_features = np.zeros((number_samples - len(useless_samples), number_roi_wmparc * len(feature_list_wmparc)))

print('constructing wmparc features')
position = 0
for i in range(number_samples):
	subject_name = subject_IDs[i]
	if subject_name in useless_samples:
		subject_index = get_index(lst=subject_IDs, item=subject_name)
		print('The index for sample ' + subject_name + ' is : ', subject_index)
	else:
		table_left = pd.read_table(localDir + subject_name + '/' + wmparc, sep='\s+', names = names_wmparc,
						  skiprows=skiprows_wmparc)
		for j in range(len(feature_list_wmparc)):
			feature_name = feature_list_wmparc[j]
			left_features = table_left[feature_name].values.tolist()
			if len(left_features) != number_roi_wmparc:
				print('The sample ' + subject_name + ' has mistake!')
			all_features = np.array(left_features)
			wmparc_features[position, j*number_roi_wmparc : (j+1)*number_roi_wmparc] = all_features
		position = position + 1
if scaler == True:
	for i in range(len(feature_list_wmparc)):
		wmparc_features[:, i * number_roi_wmparc: (i+1) * number_roi_wmparc] = StandardScaler().fit_transform(wmparc_features[:, i * number_roi_wmparc: (i+1) * number_roi_wmparc])
print('finished')

############################################### concatenation
sMRI_features = np.concatenate((Desikan_Killiany_features, aseg_features, wmparc_features),axis = 1)
# Out:
# constructing Desikan-Killiany Atlas features
# The index for sample 51334 is :  [799]
# finished
# constructing aseg features
# The index for sample 51334 is :  [799]
# finished
# constructing wmparc features
# The index for sample 51334 is :  [799]
# finished

# %%
print(sMRI_features.shape)
print(fMRI_images.shape)
print(sMRI_features)
print(fMRI_images)
plt.matshow(sMRI_features, vmin=-4, vmax=4)
plt.show()
# Out:
# (870, 1417)
# (870, 19900)
# [[-0.26379633 -0.36585841  0.05890851 ... -1.11697067 -0.75921467
#   -1.26821845]
#  [ 0.06295102 -0.10354483  0.33562979 ... -1.05248729 -0.25577202
#   -0.43539667]
#  [ 0.42528471  0.95491346 -0.04689668 ... -0.60110366 -0.12991135
#   -0.22719123]
#  ...
#  [-0.3026178  -0.9917294  -0.14781855 ... -0.98800391  0.24767064
#    1.36905051]
#  [-1.29903544 -0.89508755 -1.63560233 ...  0.68856387  1.69506827
#    0.67503236]
#  [ 0.02412955  0.81225169 -0.29594582 ...  0.68856387 -0.19284168
#    0.46682692]]
# [[ 1.88061923  1.93466056  0.63599984 ...  1.46885436  1.98724053
#    1.1636311 ]
#  [ 0.66500812 -0.06661812 -0.205227   ... -0.2077196   1.01585943
#   -0.42020151]
#  [ 0.10988633  1.25041509  0.03347263 ...  0.58907048  0.07775594
#   -0.27915372]
#  ...
#  [-1.36387375 -0.51655671 -0.33001366 ... -0.03915398 -0.87802826
#   -1.38083403]
#  [-1.53608071 -1.77684322 -0.2103792  ...  0.22321413 -0.14141626
#   -0.94863806]
#  [-0.10758455  0.20114007  1.34416595 ... -0.14711034  1.47870214
#   -0.14221066]]

# %%
############################################### Combat ###############################################################
############################################### Combat ###############################################################
############################################### Combat ###############################################################

batch = []
for i in range(len(sites)):
	batch.append(get_index(lst=unique_sites, item=sites[i])[0]+1)

combat_labels = []
combat_genders = []
combat_ages = []
for i in range(len(labels)):
	combat_labels.append(labels[i] + 1)
	combat_genders.append(genders[i])
	combat_ages.append(ages[i])
 
if combat_fMRI == True:
	print('The ComBat for fMRI')
	new_all_samples_feature = fMRI_images.T
	covars = {}
	covars['batch'] = batch
	covars['labels'] = combat_labels
	covars['genders'] = combat_genders
	covars['ages'] = combat_ages
	covars = pd.DataFrame(covars)

	# To specify names of the variables that are categorical:
	categorical_cols = ['labels', 'genders']
	# To specify the name of the variable that encodes for the scanner/batch covariate:
	batch_col = 'batch'
	continuous_cols = ['ages']
	# Harmonization step:
	new_all_samples_feature = neuroCombat(dat=new_all_samples_feature,
											covars=covars,
											batch_col=batch_col,
											categorical_cols=categorical_cols,
											continuous_cols=continuous_cols)["data"]
	fMRI_images = new_all_samples_feature.T

if combat_sMRI == True:
	print('The ComBat for sMRI')
	new_all_samples_feature = sMRI_features.T
	covars = {}
	covars['batch'] = batch
	covars['labels'] = combat_labels
	covars['genders'] = combat_genders
	covars['ages'] = combat_ages
	covars = pd.DataFrame(covars)

	# To specify names of the variables that are categorical:
	categorical_cols = ['labels', 'genders']
	# To specify the name of the variable that encodes for the scanner/batch covariate:
	batch_col = 'batch'
	continuous_cols = ['ages']
	# Harmonization step:
	new_all_samples_feature = neuroCombat(dat=new_all_samples_feature,
											covars=covars,
											batch_col=batch_col,
											categorical_cols=categorical_cols,
											continuous_cols=continuous_cols)["data"]
	sMRI_features = new_all_samples_feature.T
# Out:
# The ComBat for fMRI
# [neuroCombat] Creating design matrix
# [neuroCombat] Standardizing data across features
# [neuroCombat] Fitting L/S model and finding priors
# [neuroCombat] Finding parametric adjustments
# [neuroCombat] Final adjustment of data
# The ComBat for sMRI
# [neuroCombat] Creating design matrix
# [neuroCombat] Standardizing data across features
# [neuroCombat] Fitting L/S model and finding priors
# [neuroCombat] Finding parametric adjustments
# [neuroCombat] Final adjustment of data
# /content/drive/MyDrive/ABIDE/neuralCombat.py:325: RuntimeWarning: divide by zero encountered in true_divide
#   change = max((abs(g_new - g_old) / g_old).max(), (abs(d_new - d_old) / d_old).max())

# %%
print(sMRI_features.shape)
print(fMRI_images.shape)
print(sMRI_features)
print(fMRI_images)
plt.matshow(sMRI_features, vmin=-4, vmax=4)
plt.show()
# Out:
# (870, 1417)
# (870, 19900)
# [[-0.39239928 -0.55216102  0.1374198  ... -0.37205478 -0.07062745
#   -0.64134877]
#  [-0.07774417 -0.29267612  0.37513052 ... -0.27523294  0.60302642
#    0.33544345]
#  [ 0.2476013   0.74743091 -0.03192999 ...  0.36514416  0.7587449
#    0.58261208]
#  ...
#  [-0.70463588 -1.49906787 -0.13151063 ... -0.58585031 -0.45536805
#    0.95004168]
#  [-1.33177367 -0.97515466 -1.30232848 ...  0.19861977  1.48030952
#    0.27982554]
#  [-0.13026378  0.6961938  -0.02895118 ...  0.21603334 -0.47497158
#    0.04782907]]
# [[ 1.31969574  1.29609272  0.16548012 ...  1.1264416   1.40539022
#    0.89244625]
#  [ 0.1978668  -0.56846397 -0.64249501 ... -0.49195432  0.53999082
#   -0.51186112]
#  [-0.31230063  0.64071419 -0.4209943  ...  0.28124017 -0.31134127
#   -0.38226791]
#  ...
#  [-1.66106482 -0.70338647 -0.75717584 ...  0.07807565 -0.91287903
#   -1.53599873]
#  [-1.66776798 -1.80027394 -0.20547798 ...  0.20826832 -0.11814347
#   -1.202585  ]
#  [-0.21670001  0.0388709   1.28034576 ... -0.15455976  1.52893364
#   -0.33087638]]

# %%
############################################### phenotypic ###############################################################
############################################### phenotypic ###############################################################
############################################### phenotypic ###############################################################
ages_name = 'ages.mat'
ages = scio.loadmat(os.path.join(label_dir, ages_name))
ages = ages['ages']

gender_name = 'genders.mat'
genders = scio.loadmat(os.path.join(label_dir, gender_name))
genders = genders['genders']

FIQ_name = 'FIQS.mat'
FIQS = scio.loadmat(os.path.join(label_dir, FIQ_name))
FIQS = FIQS['FIQS']

NUM_name = 'NUM.mat'
NUM = scio.loadmat(os.path.join(label_dir, NUM_name))
NUMS = NUM['NUM']

PEC_name = 'PEC.mat'
PEC = scio.loadmat(os.path.join(label_dir, PEC_name))
PECS = PEC['PEC']

RAT_name = 'RAT.mat'
RAT = scio.loadmat(os.path.join(label_dir, RAT_name))
RATS = RAT['RAT']

age = np.zeros((number_samples - len(useless_samples), 1))
gender = np.zeros((number_samples - len(useless_samples), 1))
FIQ = np.zeros((number_samples - len(useless_samples), 1))
NUM = np.zeros((number_samples - len(useless_samples), 1))
PEC = np.zeros((number_samples - len(useless_samples), 1))
RAT = np.zeros((number_samples - len(useless_samples), 1))

position = 0
print('constructing phenotypic features')
for i in range(number_samples):
	subject_name = subject_IDs[i]
	if subject_name in useless_samples:
		subject_index = get_index(lst=subject_IDs, item=subject_name)
		print('The index for sample ' + subject_name + ' is : ', subject_index)
	else:
		subject_index = get_index(lst=subject_IDs, item=subject_name)
		age[position] = float(ages[subject_index[0]].replace(' ', ''))
		gender[position] = int(genders[subject_index[0]]) + 1
		FIQ[position] = int(FIQS[subject_index[0]])
		NUM[position] = float(NUMS[subject_index[0]])
		PEC[position] = float(PECS[subject_index[0]])
		RAT[position] = int(RATS[subject_index[0]])
		position = position + 1
FIQ[FIQ == -9999] = 108

if scaler == True:

  age[:,0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(age[:,0], axis = 1)))
  FIQ[:, 0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(FIQ[:, 0], axis = 1)))
  NUM[:, 0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(NUM[:, 0], axis = 1)))
  PEC[:, 0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(PEC[:, 0], axis = 1)))

# age, gender, FIQ, NUM, PEC, RAT
for i in range(3):
	sMRI_features = np.concatenate((sMRI_features, age, gender, FIQ, NUM, PEC, RAT),axis = 1)
# Out:
# constructing phenotypic features
# The index for sample 51334 is :  [799]

# %%
dist_train = {}
dist_validation = {}
dist_test = {}
for i in range(k_fold):
	dist_train[str(i + 1)] = []
	dist_validation[str(i + 1)] = []
	dist_test[str(i + 1)] = []

for each_site in unique_sites:
	index_site = get_index(sites, each_site)
	label = np.zeros((len(index_site)))
	for i in range(len(index_site)):
		index = index_site[i]
		label[i] = int(labels[int(index)])
	########################################### StratifiedKFold ####################################################
	sfolder = StratifiedKFold(n_splits=k_fold,random_state=0,shuffle=True)
	group = 0
	for train, validation in sfolder.split(index_site,label):
		for i in train:
			dist_train[str(group + 1)].append(index_site[i])
			name = 0
		for j in validation:
			dist_validation[str(group + 1)].append(index_site[j])
			name = 0
		group = group+1

	group = 0
	for train, validation in sfolder.split(index_site,label):
		if group == 0:
			for j in validation:
				dist_test[str(group + k_fold)].append(index_site[j])
				dist_train[str(group + k_fold)].remove(index_site[j])
		else:
			for j in validation:
				dist_test[str(group)].append(index_site[j])
				dist_train[str(group)].remove(index_site[j])
		group = group+1

# %%
import torch.nn as nn
############################################### AUTO model ###############################################################
############################################### AUTO model ###############################################################
############################################### AUTO model ###############################################################
class Stacked_autoencoder(nn.Module):
	def __init__(self, in_c, hid_1, hid_2, hid_3, out, dropout_rate):

		super(Stacked_autoencoder, self).__init__()
		self.linear_1 = nn.Linear(in_features=in_c, out_features=hid_1)
		self.linear_2 = nn.Linear(in_features=hid_1, out_features=hid_2)
		self.linear_3 = nn.Linear(in_features=hid_2, out_features=hid_3)
		self.linear_4 = nn.Linear(in_features=hid_3, out_features=out)
		self.relu = nn.ReLU(inplace=True)
		self.dropout = nn.Dropout(dropout_rate)

	def forward(self, data):

		input_data = torch.flatten(data, start_dim=1, end_dim=-1)
		lin1 = self.relu(self.dropout(self.linear_1(input_data)))
		lin2 = self.relu(self.linear_2(lin1))
		lin3 = self.relu(self.linear_3(lin2))
		lin4 = self.relu(self.linear_4(lin3))

		return lin4

class MLP(nn.Module):
	def __init__(self, in_c, hid_1, hid_2, out, dropout_rate):

		super(MLP, self).__init__()
		self.linear_1 = nn.Linear(in_features=in_c, out_features=hid_1)
		self.linear_2 = nn.Linear(in_features=hid_1, out_features=hid_2)
		self.linear_3 = nn.Linear(in_features=hid_2, out_features=out)
		self.relu = nn.ReLU(inplace=True)
		self.dropout = nn.Dropout(dropout_rate)

	def forward(self, data):

		lin1 = self.relu(self.linear_1(data))
		lin2 = self.dropout(self.relu(self.linear_2(lin1)))
		lin3 = self.linear_3(lin2)

		return lin3


class Auto_encoder_MLP(nn.Module):
	def __init__(self, in_c, auto_1, auto_2, auto_3, MLP_1, MLP_2, MLP_out, dropout_rate):

		super(Auto_encoder_MLP, self).__init__()
		self.auto_encoder = Stacked_autoencoder(in_c, auto_1, auto_2, auto_3, in_c, dropout_rate)
		self.MLP = MLP(in_c, MLP_1, MLP_2, MLP_out, dropout_rate)
		self.softmax = nn.LogSoftmax(dim=1)

	def forward(self, data):

		auto_output = self.auto_encoder(data)
		MLP_out = self.MLP(auto_output)
		out = self.softmax(MLP_out)

		return out, auto_output

# %%
AUTO_labels = np.zeros((number_samples - len(useless_samples), 2))
for i in range(len(labels)):
    if labels[i] == 1:
        AUTO_labels[i,0] = 1
    else:
        AUTO_labels[i,1] = 1

data = {}
for fold in range(1, k_fold+1):

  data[str(fold)] = []
  selector_fMRI = feature_selection_fMRI(fMRI_images, labels, dist_train[str(fold)], new_number_features_fMRI)
  selector_sMRI = feature_selection_sMRI(sMRI_features, labels, dist_train[str(fold)], new_number_features_sMRI)

  new_fMRI_data = selector_fMRI.transform(fMRI_images)
  new_sMRI_data = selector_sMRI.transform(sMRI_features)
  ################################################# combine ##########################################
  sMRI_fMRI_combine = np.concatenate((new_sMRI_data, new_fMRI_data), axis = 1)
  selector_combine = feature_selection_fMRI(sMRI_fMRI_combine, labels, dist_train[str(fold)], new_number_features_combine)
  fold_data = selector_combine.transform(sMRI_fMRI_combine)

  data[str(fold)].append(fold_data)
  data[str(fold)].append(AUTO_labels)
# Out:
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 6435 features.
# Fitting estimator with 6335 features.
# Fitting estimator with 6235 features.
# Fitting estimator with 6135 features.
# Fitting estimator with 6035 features.
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 6435 features.
# Fitting estimator with 6335 features.
# Fitting estimator with 6235 features.
# Fitting estimator with 6135 features.
# Fitting estimator with 6035 features.
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 6435 features.
# Fitting estimator with 6335 features.
# Fitting estimator with 6235 features.
# Fitting estimator with 6135 features.
# Fitting estimator with 6035 features.
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 6435 features.
# Fitting estimator with 6335 features.
# Fitting estimator with 6235 features.
# Fitting estimator with 6135 features.
# Fitting estimator with 6035 features.
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 6435 features.
# Fitting estimator with 6335 features.
# Fitting estimator with 6235 features.
# Fitting estimator with 6135 features.
# Fitting estimator with 6035 features.

# %%
############################################### Train, validaiton, test pipelines ###############################################################
############################################### Train, validaiton, test pipelines ###############################################################
############################################### Train, validaiton, test pipelines ###############################################################
def train_AUTO(args, model, all_data, fold_train_index, fold_validation_index, fold_test_index, scheduler):

    model.train()
    loss_function=torch.nn.MSELoss()

    data = torch.from_numpy(all_data[0])
    data = Variable(data, requires_grad=True)
    data = data.float()

    target = torch.from_numpy(all_data[1])
    target = target.float().long()


    if args.cuda:
        data, target = data.cuda(), target.cuda()
    
    data_train = data[fold_train_index,:] 
    target = target[fold_train_index, :]
    scheduler.zero_grad()
    out,out_auto = model(data_train)

    cross_loss = torch.nn.functional.nll_loss(out, torch.max(target, 1)[1])
    data2 = torch.squeeze(data_train)
    MSE_loss = loss_function(out_auto,data2)
    total_loss = cross_loss + MSE_loss
    total_loss.backward()
    scheduler.step()

    out = torch.max(out, 1)[1]
    target = torch.max(target, 1)[1]
    target = target.cpu().numpy()
    out = out.cpu().numpy()

    ############################## validation and test ################################################################################
    val_target, val_out, val_loss = validation_AUTO(args, model, all_data, fold_validation_index)
    test_target, test_out, test_out_prob, test_loss = test_AUTO(args, model, all_data, fold_test_index)

    return model, target, out, total_loss.item(), val_target, val_out,val_loss, test_target, test_out, test_out_prob, test_loss

    
def validation_AUTO(args, model,all_data,  fold_validation_index):

    model.eval()
    loss_function=torch.nn.MSELoss()
    data = torch.from_numpy(all_data[0])
    data = Variable(data, requires_grad=False)
    data = data.float()

    target = torch.from_numpy(all_data[1])
    target = target.float().long()


    if args.cuda:
        data, target = data.cuda(), target.cuda()


    data_val = data[fold_validation_index,:] 
    target = target[fold_validation_index, :]
    out,out_auto = model(data_val)

    cross_loss = torch.nn.functional.nll_loss(out, torch.max(target, 1)[1])
    data2 = torch.squeeze(data_val)
    MSE_loss = loss_function(out_auto,data2)
    total_loss = cross_loss + MSE_loss

    out = torch.max(out, 1)[1]
    target = torch.max(target, 1)[1]
    target = target.cpu().numpy()
    out = out.cpu().numpy()

    return target, out, total_loss.item()


def test_AUTO(args, model, all_data,  fold_test_index):

    model.eval()
    loss_function=torch.nn.MSELoss()

    data = torch.from_numpy(all_data[0])
    data = Variable(data, requires_grad=False)
    data = data.float()

    target = torch.from_numpy(all_data[1])
    target = target.float().long()


    if args.cuda:
        data, target = data.cuda(), target.cuda()
    
    data_test = data[fold_test_index,:] 
    target = target[fold_test_index, :]
    out,out_auto = model(data_test)

    cross_loss = torch.nn.functional.nll_loss(out, torch.max(target, 1)[1])
    data2 = torch.squeeze(data_test)
    MSE_loss = loss_function(out_auto,data2)
    total_loss = cross_loss + MSE_loss

    out_prob = torch.exp(out)
    out = torch.max(out, 1)[1]
    target = torch.max(target, 1)[1]
    target = target.cpu().numpy()
    out = out.cpu().numpy()
    out_prob = out_prob.cpu().detach().numpy()

    return target, out, out_prob, total_loss.item()

# %%
########################################### Training setting ################################################
########################################### Training setting ################################################
########################################### Training setting ################################################
parser = argparse.ArgumentParser()
parser.add_argument('--ngpu', type=int, default=1)
parser.add_argument('--nEpochs', type=int, default=200)
parser.add_argument('--no-cuda', action='store_true')
parser.add_argument('--seed', type=int, default=1)
parser.add_argument('--lr', type=str, default=8e-4)
# I define three kinds of optimizer, adam sgd and rmsprop, but adam performs the best
parser.add_argument('--opt', type=str, default='adam')
parser.add_argument('--auto_in', type=int, default=new_number_features_combine)
parser.add_argument('--auto_hid_1', type=int, default=300)
parser.add_argument('--auto_hid_2', type=int, default=150)
parser.add_argument('--auto_hid_3', type=int, default=300)
parser.add_argument('--MLP_1', type=int, default=300)
parser.add_argument('--MLP_2', type=int, default=16)
parser.add_argument('--MLP_out', type=int, default=2)
parser.add_argument('--dropout_rate', type=int, default=0.5)


args, unknown = parser.parse_known_args()
args.cuda = not args.no_cuda and torch.cuda.is_available()
torch.manual_seed(args.seed)
if args.cuda:
    torch.cuda.manual_seed(args.seed)
    
gpu_ids = range(args.ngpu)
train = train_AUTO

# %%
########################################### Training ################################################
########################################### Training ################################################
########################################### Training ################################################
for fold in range(1, k_fold+1):
  model = Auto_encoder_MLP(in_c=args.auto_in, auto_1=args.auto_hid_1, auto_2=args.auto_hid_2, auto_3=args.auto_hid_3, MLP_1=args.MLP_1, MLP_2=args.MLP_2, MLP_out=args.MLP_out, dropout_rate=args.dropout_rate)
  print('  + Number of params: {}'.format(
    sum([p.data.nelement() for p in model.parameters()])))
  model = nn.parallel.DataParallel(model, device_ids=gpu_ids)
  if args.cuda:
    model = model.cuda()
  optimizer = optim.Adam(model.parameters(), lr = args.lr)

  best_validation_accuracy = 0
  Train_accuracy_list =[]
  Train_loss_list = []
  Val_accuracy_list =[]
  Val_loss_list = []
  Test_accuracy_list =[]
  Test_loss_list = []

  for epoch in range(1, args.nEpochs + 1):

    model, train_target, train_out, train_loss, val_target, val_out, val_loss, test_target, test_out, test_prob, test_loss = train(args, model, data[str(fold)], dist_train[str(fold)], dist_validation[str(fold)], dist_test[str(fold)], optimizer)

    train_accuracy = metrics.accuracy_score(train_target, train_out)
    val_accuracy = metrics.accuracy_score(val_target, val_out)
    test_accuracy = metrics.accuracy_score(test_target, test_out)
    Train_accuracy_list.append(train_accuracy)
    Val_accuracy_list.append(val_accuracy)
    Test_accuracy_list.append(test_accuracy)
    Train_loss_list.append(train_loss)
    Val_loss_list.append(val_loss)
    Test_loss_list.append(test_loss)

    if val_accuracy >=best_validation_accuracy:
      best_epoch = epoch
      best_validation_accuracy = val_accuracy
      corresponding_val_out = val_out
      corresponding_test_accuracy = test_accuracy
      corresponding_test_out = test_out
      corresponding_test_prob = test_prob

      print('Save models')
      save_model(model, save_path, 'AUTO_'+str(fold))

    print('Train Epoch: ' + str(epoch) + ': train loss : {:.8f}\t train accuracy : {:.8f}\t val accuracy : {:.8f}\t test accuracy : {:.8f}\t'.format(
      train_loss, train_accuracy, val_accuracy, test_accuracy))
  
  if fold == 1:
    all_fold_val_label = val_target
    all_fold_val_out = corresponding_val_out
    all_fold_test_label = test_target
    all_fold_test_out = corresponding_test_out
    all_fold_test_prob = corresponding_test_prob
  else:
    all_fold_val_label = np.concatenate((all_fold_val_label, val_target),axis = 0)
    all_fold_val_out = np.concatenate((all_fold_val_out, corresponding_val_out),axis = 0)
    all_fold_test_label = np.concatenate((all_fold_test_label, test_target),axis = 0)
    all_fold_test_out = np.concatenate((all_fold_test_out, corresponding_test_out),axis = 0)
    all_fold_test_prob = np.concatenate((all_fold_test_prob, corresponding_test_prob),axis = 0)

  x_axis = list(range(1, len(Train_accuracy_list)+1))
  plt.figure(figsize=(10,6))
  plt.plot(x_axis, Train_loss_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_loss_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_loss_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()

  plt.figure(figsize=(10,6))
  plt.plot(x_axis, Train_accuracy_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_accuracy_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_accuracy_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()


  test_fpr, test_tpr, te_thresholds = roc_curve(test_target, corresponding_test_prob[:,1],pos_label=1)
  test_auc = auc(test_fpr, test_tpr)
  print('\n')
  print('In fold ',str(fold))
  print('The best validaiton accuracy is: ',best_validation_accuracy)
  print('Happened at epoch: ',best_epoch)
  print('The corresponding test accuracy', corresponding_test_accuracy)
  print('The corresponding test AUC is: ',test_auc)
  print('\n')


  plt.grid()
  plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
  plt.plot([0,1],[0,1],'g--')
  plt.legend()
  plt.xlabel("False Positive Rate")
  plt.ylabel("True Positive Rate")
  plt.title("Test AUC(ROC curve)")
  plt.grid(color='black', linestyle='-', linewidth=0.5)
  plt.show()

print('Finish 5-fold training')
# Out:
#   + Number of params: 5501900
# Save models
# Train Epoch: 1: train loss : 1.58202267	 train accuracy : 0.45401174	 val accuracy : 0.52747253	 test accuracy : 0.51977401
# Train Epoch: 2: train loss : 1.56771731	 train accuracy : 0.54598826	 val accuracy : 0.47252747	 test accuracy : 0.48022599
# Train Epoch: 3: train loss : 1.55299568	 train accuracy : 0.45792564	 val accuracy : 0.47252747	 test accuracy : 0.48022599
# Train Epoch: 4: train loss : 1.54436350	 train accuracy : 0.46771037	 val accuracy : 0.49450549	 test accuracy : 0.49152542
# Train Epoch: 5: train loss : 1.53703344	 train accuracy : 0.48336595	 val accuracy : 0.50000000	 test accuracy : 0.53672316
# Train Epoch: 6: train loss : 1.52535963	 train accuracy : 0.54990215	 val accuracy : 0.51098901	 test accuracy : 0.51977401
# Save models
# Train Epoch: 7: train loss : 1.51839614	 train accuracy : 0.53620352	 val accuracy : 0.62087912	 test accuracy : 0.66101695
# Train Epoch: 8: train loss : 1.50500703	 train accuracy : 0.52250489	 val accuracy : 0.60439560	 test accuracy : 0.62146893
# Train Epoch: 9: train loss : 1.50370061	 train accuracy : 0.49706458	 val accuracy : 0.59340659	 test accuracy : 0.63841808
# Train Epoch: 10: train loss : 1.48575377	 train accuracy : 0.56555773	 val accuracy : 0.56593407	 test accuracy : 0.57627119
# Train Epoch: 11: train loss : 1.47398853	 train accuracy : 0.52837573	 val accuracy : 0.58241758	 test accuracy : 0.56497175
# Train Epoch: 12: train loss : 1.45756412	 train accuracy : 0.57534247	 val accuracy : 0.56593407	 test accuracy : 0.57627119
# Train Epoch: 13: train loss : 1.44541049	 train accuracy : 0.57925636	 val accuracy : 0.58241758	 test accuracy : 0.57062147
# Train Epoch: 14: train loss : 1.41300631	 train accuracy : 0.69471624	 val accuracy : 0.58791209	 test accuracy : 0.57627119
# Train Epoch: 15: train loss : 1.38190103	 train accuracy : 0.76125245	 val accuracy : 0.59340659	 test accuracy : 0.62711864
# Save models
# Train Epoch: 16: train loss : 1.35708189	 train accuracy : 0.75342466	 val accuracy : 0.62637363	 test accuracy : 0.61581921
# Save models
# Train Epoch: 17: train loss : 1.32596946	 train accuracy : 0.81409002	 val accuracy : 0.67582418	 test accuracy : 0.64406780
# Train Epoch: 18: train loss : 1.28208017	 train accuracy : 0.92954990	 val accuracy : 0.67032967	 test accuracy : 0.67796610
# Train Epoch: 19: train loss : 1.24240685	 train accuracy : 0.90606654	 val accuracy : 0.65934066	 test accuracy : 0.63276836
# Train Epoch: 20: train loss : 1.22251868	 train accuracy : 0.95694716	 val accuracy : 0.66483516	 test accuracy : 0.61581921
# Save models
# Train Epoch: 21: train loss : 1.19551790	 train accuracy : 0.97847358	 val accuracy : 0.73076923	 test accuracy : 0.70056497
# Train Epoch: 22: train loss : 1.17895937	 train accuracy : 0.95107632	 val accuracy : 0.71428571	 test accuracy : 0.70621469
# Train Epoch: 23: train loss : 1.18572879	 train accuracy : 0.94911937	 val accuracy : 0.68131868	 test accuracy : 0.64971751
# Train Epoch: 24: train loss : 1.15711582	 train accuracy : 0.98825832	 val accuracy : 0.68131868	 test accuracy : 0.63841808
# Train Epoch: 25: train loss : 1.15868211	 train accuracy : 0.97260274	 val accuracy : 0.71978022	 test accuracy : 0.68926554
# Train Epoch: 26: train loss : 1.13391721	 train accuracy : 0.98043053	 val accuracy : 0.71428571	 test accuracy : 0.71186441
# Train Epoch: 27: train loss : 1.14080048	 train accuracy : 0.96868885	 val accuracy : 0.70879121	 test accuracy : 0.68361582
# Train Epoch: 28: train loss : 1.13163698	 train accuracy : 0.99804305	 val accuracy : 0.69230769	 test accuracy : 0.66666667
# Train Epoch: 29: train loss : 1.13928854	 train accuracy : 0.98434442	 val accuracy : 0.70329670	 test accuracy : 0.67796610
# Train Epoch: 30: train loss : 1.12520552	 train accuracy : 0.98434442	 val accuracy : 0.69780220	 test accuracy : 0.70056497
# Train Epoch: 31: train loss : 1.14562297	 train accuracy : 0.94129159	 val accuracy : 0.72527473	 test accuracy : 0.69491525
# Train Epoch: 32: train loss : 1.11243343	 train accuracy : 0.99804305	 val accuracy : 0.70879121	 test accuracy : 0.65536723
# Train Epoch: 33: train loss : 1.11798286	 train accuracy : 0.98825832	 val accuracy : 0.70329670	 test accuracy : 0.64406780
# Train Epoch: 34: train loss : 1.12192202	 train accuracy : 0.98434442	 val accuracy : 0.70329670	 test accuracy : 0.67231638
# Train Epoch: 35: train loss : 1.10097945	 train accuracy : 0.99021526	 val accuracy : 0.70329670	 test accuracy : 0.68926554
# Train Epoch: 36: train loss : 1.10658789	 train accuracy : 0.98630137	 val accuracy : 0.69780220	 test accuracy : 0.67796610
# Train Epoch: 37: train loss : 1.09382749	 train accuracy : 0.99608611	 val accuracy : 0.69230769	 test accuracy : 0.67796610
# Train Epoch: 38: train loss : 1.10071778	 train accuracy : 0.98825832	 val accuracy : 0.70329670	 test accuracy : 0.66666667
# Train Epoch: 39: train loss : 1.10251260	 train accuracy : 0.99412916	 val accuracy : 0.70879121	 test accuracy : 0.65536723
# Train Epoch: 40: train loss : 1.10128117	 train accuracy : 0.98825832	 val accuracy : 0.72527473	 test accuracy : 0.70056497
# Train Epoch: 41: train loss : 1.08525574	 train accuracy : 0.99804305	 val accuracy : 0.69780220	 test accuracy : 0.71186441
# Train Epoch: 42: train loss : 1.08577919	 train accuracy : 0.99412916	 val accuracy : 0.71428571	 test accuracy : 0.68361582
# Train Epoch: 43: train loss : 1.09409082	 train accuracy : 0.98434442	 val accuracy : 0.70329670	 test accuracy : 0.67796610
# Train Epoch: 44: train loss : 1.08309412	 train accuracy : 0.99412916	 val accuracy : 0.70329670	 test accuracy : 0.66666667
# Train Epoch: 45: train loss : 1.08651805	 train accuracy : 0.99217221	 val accuracy : 0.71428571	 test accuracy : 0.67231638
# Train Epoch: 46: train loss : 1.07735157	 train accuracy : 1.00000000	 val accuracy : 0.70879121	 test accuracy : 0.70621469
# Train Epoch: 47: train loss : 1.08025956	 train accuracy : 0.99412916	 val accuracy : 0.71978022	 test accuracy : 0.71186441
# Train Epoch: 48: train loss : 1.07438779	 train accuracy : 0.99217221	 val accuracy : 0.72527473	 test accuracy : 0.75141243
# Train Epoch: 49: train loss : 1.07985306	 train accuracy : 0.99217221	 val accuracy : 0.71428571	 test accuracy : 0.70621469
# Save models
# Train Epoch: 50: train loss : 1.07451451	 train accuracy : 0.98825832	 val accuracy : 0.74175824	 test accuracy : 0.69491525
# Train Epoch: 51: train loss : 1.07543659	 train accuracy : 0.99412916	 val accuracy : 0.72527473	 test accuracy : 0.67231638
# Train Epoch: 52: train loss : 1.07888484	 train accuracy : 0.99412916	 val accuracy : 0.73076923	 test accuracy : 0.71186441
# Train Epoch: 53: train loss : 1.07584381	 train accuracy : 0.99608611	 val accuracy : 0.72527473	 test accuracy : 0.74011299
# Train Epoch: 54: train loss : 1.07940757	 train accuracy : 0.98825832	 val accuracy : 0.72527473	 test accuracy : 0.74011299
# Train Epoch: 55: train loss : 1.06691456	 train accuracy : 0.99804305	 val accuracy : 0.72527473	 test accuracy : 0.68361582
# Train Epoch: 56: train loss : 1.08104944	 train accuracy : 0.98630137	 val accuracy : 0.72527473	 test accuracy : 0.69491525
# Train Epoch: 57: train loss : 1.07372820	 train accuracy : 0.99804305	 val accuracy : 0.73626374	 test accuracy : 0.72881356
# Train Epoch: 58: train loss : 1.06696916	 train accuracy : 0.99608611	 val accuracy : 0.71428571	 test accuracy : 0.72881356
# Train Epoch: 59: train loss : 1.06667721	 train accuracy : 0.99412916	 val accuracy : 0.71978022	 test accuracy : 0.73446328
# Train Epoch: 60: train loss : 1.06360602	 train accuracy : 0.99412916	 val accuracy : 0.71428571	 test accuracy : 0.72881356
# Train Epoch: 61: train loss : 1.06834114	 train accuracy : 0.99217221	 val accuracy : 0.71428571	 test accuracy : 0.72316384
# Train Epoch: 62: train loss : 1.06343281	 train accuracy : 0.99804305	 val accuracy : 0.71428571	 test accuracy : 0.72316384
# Train Epoch: 63: train loss : 1.06271160	 train accuracy : 0.99608611	 val accuracy : 0.71978022	 test accuracy : 0.71751412
# Train Epoch: 64: train loss : 1.06209087	 train accuracy : 0.99608611	 val accuracy : 0.72527473	 test accuracy : 0.69491525
# Train Epoch: 65: train loss : 1.06687844	 train accuracy : 0.99412916	 val accuracy : 0.71428571	 test accuracy : 0.68926554
# Train Epoch: 66: train loss : 1.06884420	 train accuracy : 0.99021526	 val accuracy : 0.71978022	 test accuracy : 0.71751412
# Train Epoch: 67: train loss : 1.05872130	 train accuracy : 0.99608611	 val accuracy : 0.71978022	 test accuracy : 0.72881356
# Train Epoch: 68: train loss : 1.06844509	 train accuracy : 0.98630137	 val accuracy : 0.71428571	 test accuracy : 0.71751412
# Train Epoch: 69: train loss : 1.05720782	 train accuracy : 1.00000000	 val accuracy : 0.70329670	 test accuracy : 0.70056497
# Train Epoch: 70: train loss : 1.05867159	 train accuracy : 0.99217221	 val accuracy : 0.73076923	 test accuracy : 0.68926554
# Train Epoch: 71: train loss : 1.05478907	 train accuracy : 0.99608611	 val accuracy : 0.71978022	 test accuracy : 0.67796610
# Train Epoch: 72: train loss : 1.05530632	 train accuracy : 0.99608611	 val accuracy : 0.72527473	 test accuracy : 0.66666667
# Train Epoch: 73: train loss : 1.05791914	 train accuracy : 0.99412916	 val accuracy : 0.72527473	 test accuracy : 0.68361582
# Train Epoch: 74: train loss : 1.05293667	 train accuracy : 0.99608611	 val accuracy : 0.70879121	 test accuracy : 0.70056497
# Save models
# Train Epoch: 75: train loss : 1.05469000	 train accuracy : 0.99608611	 val accuracy : 0.74175824	 test accuracy : 0.70621469
# Train Epoch: 76: train loss : 1.05502510	 train accuracy : 0.99217221	 val accuracy : 0.71978022	 test accuracy : 0.68926554
# Train Epoch: 77: train loss : 1.05290854	 train accuracy : 0.99804305	 val accuracy : 0.70879121	 test accuracy : 0.68926554
# Train Epoch: 78: train loss : 1.05297995	 train accuracy : 0.99412916	 val accuracy : 0.70879121	 test accuracy : 0.67231638
# Train Epoch: 79: train loss : 1.04873323	 train accuracy : 0.99608611	 val accuracy : 0.70329670	 test accuracy : 0.67231638
# Train Epoch: 80: train loss : 1.05407643	 train accuracy : 0.99412916	 val accuracy : 0.69780220	 test accuracy : 0.68361582
# Train Epoch: 81: train loss : 1.04471469	 train accuracy : 1.00000000	 val accuracy : 0.71428571	 test accuracy : 0.71186441
# Train Epoch: 82: train loss : 1.04928005	 train accuracy : 0.99412916	 val accuracy : 0.71978022	 test accuracy : 0.68361582
# Train Epoch: 83: train loss : 1.04404533	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.66101695
# Train Epoch: 84: train loss : 1.05364144	 train accuracy : 0.99217221	 val accuracy : 0.70879121	 test accuracy : 0.67231638
# Train Epoch: 85: train loss : 1.05092573	 train accuracy : 0.99608611	 val accuracy : 0.70329670	 test accuracy : 0.70056497
# Train Epoch: 86: train loss : 1.04529142	 train accuracy : 0.99608611	 val accuracy : 0.68681319	 test accuracy : 0.71186441
# Train Epoch: 87: train loss : 1.04814470	 train accuracy : 0.99608611	 val accuracy : 0.68681319	 test accuracy : 0.70621469
# Train Epoch: 88: train loss : 1.04744112	 train accuracy : 0.99608611	 val accuracy : 0.69230769	 test accuracy : 0.67231638
# Train Epoch: 89: train loss : 1.04390681	 train accuracy : 0.99804305	 val accuracy : 0.69780220	 test accuracy : 0.66101695
# Train Epoch: 90: train loss : 1.05413973	 train accuracy : 0.99608611	 val accuracy : 0.69780220	 test accuracy : 0.66666667
# Train Epoch: 91: train loss : 1.05386841	 train accuracy : 0.98825832	 val accuracy : 0.69780220	 test accuracy : 0.68926554
# Train Epoch: 92: train loss : 1.04123747	 train accuracy : 0.99804305	 val accuracy : 0.70879121	 test accuracy : 0.70056497
# Train Epoch: 93: train loss : 1.04077947	 train accuracy : 0.99804305	 val accuracy : 0.69780220	 test accuracy : 0.71186441
# Train Epoch: 94: train loss : 1.04084206	 train accuracy : 0.99804305	 val accuracy : 0.69780220	 test accuracy : 0.70621469
# Train Epoch: 95: train loss : 1.04051960	 train accuracy : 0.99804305	 val accuracy : 0.68681319	 test accuracy : 0.70621469
# Train Epoch: 96: train loss : 1.04193294	 train accuracy : 0.99217221	 val accuracy : 0.68131868	 test accuracy : 0.66101695
# Train Epoch: 97: train loss : 1.03989851	 train accuracy : 0.99021526	 val accuracy : 0.68131868	 test accuracy : 0.63841808
# Train Epoch: 98: train loss : 1.04487705	 train accuracy : 0.99217221	 val accuracy : 0.68681319	 test accuracy : 0.66101695
# Train Epoch: 99: train loss : 1.04516673	 train accuracy : 0.98825832	 val accuracy : 0.70879121	 test accuracy : 0.70621469
# Train Epoch: 100: train loss : 1.03604424	 train accuracy : 0.99804305	 val accuracy : 0.71978022	 test accuracy : 0.74011299
# Train Epoch: 101: train loss : 1.03560340	 train accuracy : 0.99804305	 val accuracy : 0.72527473	 test accuracy : 0.72316384
# Train Epoch: 102: train loss : 1.04239511	 train accuracy : 0.99021526	 val accuracy : 0.72527473	 test accuracy : 0.71751412
# Train Epoch: 103: train loss : 1.04389334	 train accuracy : 0.99021526	 val accuracy : 0.70879121	 test accuracy : 0.70621469
# Train Epoch: 104: train loss : 1.03228045	 train accuracy : 1.00000000	 val accuracy : 0.70879121	 test accuracy : 0.68361582
# Train Epoch: 105: train loss : 1.03545749	 train accuracy : 0.99412916	 val accuracy : 0.68681319	 test accuracy : 0.64406780
# Train Epoch: 106: train loss : 1.03216207	 train accuracy : 0.99804305	 val accuracy : 0.68681319	 test accuracy : 0.64406780
# Train Epoch: 107: train loss : 1.04633594	 train accuracy : 0.99412916	 val accuracy : 0.67582418	 test accuracy : 0.67231638
# Train Epoch: 108: train loss : 1.03043866	 train accuracy : 0.99804305	 val accuracy : 0.68681319	 test accuracy : 0.67796610
# Train Epoch: 109: train loss : 1.03139031	 train accuracy : 0.99608611	 val accuracy : 0.70329670	 test accuracy : 0.72881356
# Train Epoch: 110: train loss : 1.02723682	 train accuracy : 0.99804305	 val accuracy : 0.73076923	 test accuracy : 0.72881356
# Train Epoch: 111: train loss : 1.04953694	 train accuracy : 0.98434442	 val accuracy : 0.73626374	 test accuracy : 0.67796610
# Train Epoch: 112: train loss : 1.03003013	 train accuracy : 0.99608611	 val accuracy : 0.73076923	 test accuracy : 0.64971751
# Train Epoch: 113: train loss : 1.02998888	 train accuracy : 1.00000000	 val accuracy : 0.70879121	 test accuracy : 0.66666667
# Train Epoch: 114: train loss : 1.04610884	 train accuracy : 0.98238748	 val accuracy : 0.69780220	 test accuracy : 0.68361582
# Train Epoch: 115: train loss : 1.03352165	 train accuracy : 0.99412916	 val accuracy : 0.70329670	 test accuracy : 0.68926554
# Train Epoch: 116: train loss : 1.02745974	 train accuracy : 0.99804305	 val accuracy : 0.71428571	 test accuracy : 0.68361582
# Train Epoch: 117: train loss : 1.02997160	 train accuracy : 0.99412916	 val accuracy : 0.68681319	 test accuracy : 0.69491525
# Train Epoch: 118: train loss : 1.02969444	 train accuracy : 0.99608611	 val accuracy : 0.69230769	 test accuracy : 0.70056497
# Train Epoch: 119: train loss : 1.07232571	 train accuracy : 0.99021526	 val accuracy : 0.66483516	 test accuracy : 0.65536723
# Train Epoch: 120: train loss : 1.02335179	 train accuracy : 1.00000000	 val accuracy : 0.63736264	 test accuracy : 0.63276836
# Train Epoch: 121: train loss : 1.10040140	 train accuracy : 0.93737769	 val accuracy : 0.67032967	 test accuracy : 0.63841808
# Train Epoch: 122: train loss : 1.09088814	 train accuracy : 0.93150685	 val accuracy : 0.67582418	 test accuracy : 0.66666667
# Train Epoch: 123: train loss : 1.07228506	 train accuracy : 0.95499022	 val accuracy : 0.68681319	 test accuracy : 0.67231638
# Train Epoch: 124: train loss : 1.04481375	 train accuracy : 0.98825832	 val accuracy : 0.72527473	 test accuracy : 0.70621469
# Train Epoch: 125: train loss : 1.04117775	 train accuracy : 0.99412916	 val accuracy : 0.70879121	 test accuracy : 0.70621469
# Train Epoch: 126: train loss : 1.05341661	 train accuracy : 0.98825832	 val accuracy : 0.72527473	 test accuracy : 0.68926554
# Train Epoch: 127: train loss : 1.03127015	 train accuracy : 0.99804305	 val accuracy : 0.71978022	 test accuracy : 0.67231638
# Train Epoch: 128: train loss : 1.04168487	 train accuracy : 0.99217221	 val accuracy : 0.70329670	 test accuracy : 0.61016949
# Train Epoch: 129: train loss : 1.05333066	 train accuracy : 0.97455969	 val accuracy : 0.71428571	 test accuracy : 0.61581921
# Train Epoch: 130: train loss : 1.04269207	 train accuracy : 0.98238748	 val accuracy : 0.70879121	 test accuracy : 0.64406780
# Train Epoch: 131: train loss : 1.04010892	 train accuracy : 0.98434442	 val accuracy : 0.73076923	 test accuracy : 0.68926554
# Train Epoch: 132: train loss : 1.13528490	 train accuracy : 0.98434442	 val accuracy : 0.71978022	 test accuracy : 0.66101695
# Train Epoch: 133: train loss : 1.03380549	 train accuracy : 0.99412916	 val accuracy : 0.72527473	 test accuracy : 0.64971751
# Train Epoch: 134: train loss : 1.05455995	 train accuracy : 0.96868885	 val accuracy : 0.70879121	 test accuracy : 0.64406780
# Train Epoch: 135: train loss : 1.06774211	 train accuracy : 0.96477495	 val accuracy : 0.70879121	 test accuracy : 0.63841808
# Train Epoch: 136: train loss : 1.05763268	 train accuracy : 0.97064579	 val accuracy : 0.73626374	 test accuracy : 0.66101695
# Train Epoch: 137: train loss : 1.03075576	 train accuracy : 0.99412916	 val accuracy : 0.71428571	 test accuracy : 0.68926554
# Train Epoch: 138: train loss : 1.03684568	 train accuracy : 0.99217221	 val accuracy : 0.71978022	 test accuracy : 0.68361582
# Train Epoch: 139: train loss : 1.03445697	 train accuracy : 0.99021526	 val accuracy : 0.71978022	 test accuracy : 0.67231638
# Train Epoch: 140: train loss : 1.02566755	 train accuracy : 0.99412916	 val accuracy : 0.70879121	 test accuracy : 0.67796610
# Train Epoch: 141: train loss : 1.02704835	 train accuracy : 0.99412916	 val accuracy : 0.69230769	 test accuracy : 0.66101695
# Train Epoch: 142: train loss : 1.02620733	 train accuracy : 0.99217221	 val accuracy : 0.69780220	 test accuracy : 0.65536723
# Train Epoch: 143: train loss : 1.02441597	 train accuracy : 0.99021526	 val accuracy : 0.70879121	 test accuracy : 0.65536723
# Train Epoch: 144: train loss : 1.02191556	 train accuracy : 0.99412916	 val accuracy : 0.71428571	 test accuracy : 0.66666667
# Train Epoch: 145: train loss : 1.02114880	 train accuracy : 0.99412916	 val accuracy : 0.71978022	 test accuracy : 0.67796610
# Train Epoch: 146: train loss : 1.02359080	 train accuracy : 0.99217221	 val accuracy : 0.73626374	 test accuracy : 0.67231638
# Save models
# Train Epoch: 147: train loss : 1.02272654	 train accuracy : 0.99217221	 val accuracy : 0.74175824	 test accuracy : 0.67231638
# Train Epoch: 148: train loss : 1.02026820	 train accuracy : 0.99217221	 val accuracy : 0.72527473	 test accuracy : 0.67796610
# Train Epoch: 149: train loss : 1.04972649	 train accuracy : 0.99021526	 val accuracy : 0.70329670	 test accuracy : 0.67231638
# Train Epoch: 150: train loss : 1.01646590	 train accuracy : 0.99608611	 val accuracy : 0.69780220	 test accuracy : 0.65536723
# Train Epoch: 151: train loss : 1.02616310	 train accuracy : 0.98630137	 val accuracy : 0.69780220	 test accuracy : 0.64406780
# Train Epoch: 152: train loss : 1.02635336	 train accuracy : 0.98043053	 val accuracy : 0.73076923	 test accuracy : 0.68361582
# Train Epoch: 153: train loss : 1.01807749	 train accuracy : 0.99217221	 val accuracy : 0.72527473	 test accuracy : 0.67231638
# Train Epoch: 154: train loss : 1.01662028	 train accuracy : 0.99412916	 val accuracy : 0.71978022	 test accuracy : 0.69491525
# Train Epoch: 155: train loss : 1.01090002	 train accuracy : 0.99217221	 val accuracy : 0.72527473	 test accuracy : 0.70056497
# Train Epoch: 156: train loss : 1.01686990	 train accuracy : 0.99021526	 val accuracy : 0.73626374	 test accuracy : 0.69491525
# Train Epoch: 157: train loss : 1.00905979	 train accuracy : 0.99608611	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 158: train loss : 1.01185906	 train accuracy : 0.99412916	 val accuracy : 0.71978022	 test accuracy : 0.67796610
# Train Epoch: 159: train loss : 1.01369321	 train accuracy : 0.99217221	 val accuracy : 0.72527473	 test accuracy : 0.67231638
# Train Epoch: 160: train loss : 1.01189506	 train accuracy : 0.99217221	 val accuracy : 0.72527473	 test accuracy : 0.66666667
# Train Epoch: 161: train loss : 1.00879323	 train accuracy : 0.99412916	 val accuracy : 0.72527473	 test accuracy : 0.67796610
# Train Epoch: 162: train loss : 1.00241733	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.68361582
# Train Epoch: 163: train loss : 1.00349844	 train accuracy : 0.99804305	 val accuracy : 0.73626374	 test accuracy : 0.69491525
# Train Epoch: 164: train loss : 1.00295305	 train accuracy : 0.99804305	 val accuracy : 0.73076923	 test accuracy : 0.69491525
# Train Epoch: 165: train loss : 1.00319374	 train accuracy : 0.99608611	 val accuracy : 0.72527473	 test accuracy : 0.69491525
# Train Epoch: 166: train loss : 1.00377655	 train accuracy : 0.99412916	 val accuracy : 0.71978022	 test accuracy : 0.70056497
# Train Epoch: 167: train loss : 1.00328183	 train accuracy : 0.99412916	 val accuracy : 0.72527473	 test accuracy : 0.70056497
# Train Epoch: 168: train loss : 0.99857819	 train accuracy : 0.99608611	 val accuracy : 0.71978022	 test accuracy : 0.69491525
# Train Epoch: 169: train loss : 1.00817275	 train accuracy : 0.99804305	 val accuracy : 0.72527473	 test accuracy : 0.69491525
# Train Epoch: 170: train loss : 0.99752223	 train accuracy : 0.99804305	 val accuracy : 0.73626374	 test accuracy : 0.68926554
# Train Epoch: 171: train loss : 0.99693847	 train accuracy : 0.99804305	 val accuracy : 0.73626374	 test accuracy : 0.69491525
# Train Epoch: 172: train loss : 0.99404079	 train accuracy : 1.00000000	 val accuracy : 0.73626374	 test accuracy : 0.69491525
# Train Epoch: 173: train loss : 0.99613649	 train accuracy : 0.99608611	 val accuracy : 0.73626374	 test accuracy : 0.69491525
# Save models
# Train Epoch: 174: train loss : 0.99532092	 train accuracy : 0.99412916	 val accuracy : 0.74725275	 test accuracy : 0.69491525
# Save models
# Train Epoch: 175: train loss : 0.99499393	 train accuracy : 0.99804305	 val accuracy : 0.74725275	 test accuracy : 0.70056497
# Train Epoch: 176: train loss : 0.99411321	 train accuracy : 0.99608611	 val accuracy : 0.74175824	 test accuracy : 0.70056497
# Train Epoch: 177: train loss : 0.99194205	 train accuracy : 0.99804305	 val accuracy : 0.73626374	 test accuracy : 0.71186441
# Train Epoch: 178: train loss : 0.99268603	 train accuracy : 0.99608611	 val accuracy : 0.73626374	 test accuracy : 0.71751412
# Train Epoch: 179: train loss : 0.98910296	 train accuracy : 0.99804305	 val accuracy : 0.73076923	 test accuracy : 0.71186441
# Train Epoch: 180: train loss : 0.98987937	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.71186441
# Train Epoch: 181: train loss : 0.98813105	 train accuracy : 0.99804305	 val accuracy : 0.74175824	 test accuracy : 0.70621469
# Train Epoch: 182: train loss : 0.98586106	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.70621469
# Train Epoch: 183: train loss : 0.98783058	 train accuracy : 0.99804305	 val accuracy : 0.73076923	 test accuracy : 0.70056497
# Train Epoch: 184: train loss : 0.98706794	 train accuracy : 0.99608611	 val accuracy : 0.73076923	 test accuracy : 0.70056497
# Train Epoch: 185: train loss : 0.98343718	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.70056497
# Train Epoch: 186: train loss : 0.98464316	 train accuracy : 0.99804305	 val accuracy : 0.71428571	 test accuracy : 0.70056497
# Train Epoch: 187: train loss : 0.98188502	 train accuracy : 0.99804305	 val accuracy : 0.70329670	 test accuracy : 0.70056497
# Train Epoch: 188: train loss : 0.98409778	 train accuracy : 0.99608611	 val accuracy : 0.71428571	 test accuracy : 0.70621469
# Train Epoch: 189: train loss : 0.98295105	 train accuracy : 0.99804305	 val accuracy : 0.73626374	 test accuracy : 0.70056497
# Save models
# Train Epoch: 190: train loss : 0.98442638	 train accuracy : 0.99608611	 val accuracy : 0.75274725	 test accuracy : 0.70621469
# Train Epoch: 191: train loss : 0.98047173	 train accuracy : 0.99804305	 val accuracy : 0.73626374	 test accuracy : 0.70056497
# Train Epoch: 192: train loss : 0.97948503	 train accuracy : 0.99804305	 val accuracy : 0.74725275	 test accuracy : 0.71186441
# Train Epoch: 193: train loss : 0.97834158	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.71186441
# Train Epoch: 194: train loss : 0.97601640	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.71751412
# Save models
# Train Epoch: 195: train loss : 0.97857702	 train accuracy : 0.99804305	 val accuracy : 0.75274725	 test accuracy : 0.71751412
# Save models
# Train Epoch: 196: train loss : 0.98118275	 train accuracy : 0.99412916	 val accuracy : 0.75274725	 test accuracy : 0.71186441
# Save models
# Train Epoch: 197: train loss : 0.97629213	 train accuracy : 0.99804305	 val accuracy : 0.75274725	 test accuracy : 0.71751412
# Train Epoch: 198: train loss : 0.97716498	 train accuracy : 0.99608611	 val accuracy : 0.73626374	 test accuracy : 0.72316384
# Train Epoch: 199: train loss : 0.97573036	 train accuracy : 0.99804305	 val accuracy : 0.73076923	 test accuracy : 0.72316384
# Train Epoch: 200: train loss : 0.97472662	 train accuracy : 0.99804305	 val accuracy : 0.72527473	 test accuracy : 0.72316384
# In fold  1
# The best validaiton accuracy is:  0.7527472527472527
# Happened at epoch:  197
# The corresponding test accuracy 0.7175141242937854
# The corresponding test AUC is:  0.743925831202046
#   + Number of params: 5501900
# Save models
# Train Epoch: 1: train loss : 1.56912947	 train accuracy : 0.45664740	 val accuracy : 0.51412429	 test accuracy : 0.47701149
# Save models
# Train Epoch: 2: train loss : 1.54373074	 train accuracy : 0.46628131	 val accuracy : 0.55932203	 test accuracy : 0.48275862
# Train Epoch: 3: train loss : 1.52764761	 train accuracy : 0.51830443	 val accuracy : 0.54802260	 test accuracy : 0.48275862
# Train Epoch: 4: train loss : 1.52776504	 train accuracy : 0.52601156	 val accuracy : 0.53107345	 test accuracy : 0.46551724
# Save models
# Train Epoch: 5: train loss : 1.52006745	 train accuracy : 0.50674374	 val accuracy : 0.59322034	 test accuracy : 0.50000000
# Train Epoch: 6: train loss : 1.51220870	 train accuracy : 0.53949904	 val accuracy : 0.58757062	 test accuracy : 0.51724138
# Save models
# Train Epoch: 7: train loss : 1.50071371	 train accuracy : 0.55105973	 val accuracy : 0.60451977	 test accuracy : 0.52873563
# Save models
# Train Epoch: 8: train loss : 1.47368193	 train accuracy : 0.64354528	 val accuracy : 0.64406780	 test accuracy : 0.52298851
# Train Epoch: 9: train loss : 1.47577441	 train accuracy : 0.69749518	 val accuracy : 0.62711864	 test accuracy : 0.60919540
# Train Epoch: 10: train loss : 1.43128133	 train accuracy : 0.79383430	 val accuracy : 0.60451977	 test accuracy : 0.62068966
# Save models
# Train Epoch: 11: train loss : 1.39173853	 train accuracy : 0.81117534	 val accuracy : 0.64971751	 test accuracy : 0.63218391
# Train Epoch: 12: train loss : 1.35636020	 train accuracy : 0.79190751	 val accuracy : 0.63276836	 test accuracy : 0.66666667
# Train Epoch: 13: train loss : 1.28905749	 train accuracy : 0.82273603	 val accuracy : 0.62711864	 test accuracy : 0.67816092
# Save models
# Train Epoch: 14: train loss : 1.26606834	 train accuracy : 0.89017341	 val accuracy : 0.64971751	 test accuracy : 0.71264368
# Train Epoch: 15: train loss : 1.23223531	 train accuracy : 0.92678227	 val accuracy : 0.64406780	 test accuracy : 0.68390805
# Save models
# Train Epoch: 16: train loss : 1.19174922	 train accuracy : 0.95183044	 val accuracy : 0.66666667	 test accuracy : 0.70689655
# Save models
# Train Epoch: 17: train loss : 1.15504146	 train accuracy : 0.96339114	 val accuracy : 0.67796610	 test accuracy : 0.70689655
# Save models
# Train Epoch: 18: train loss : 1.12938190	 train accuracy : 0.97880539	 val accuracy : 0.67796610	 test accuracy : 0.71264368
# Save models
# Train Epoch: 19: train loss : 1.09911847	 train accuracy : 0.98265896	 val accuracy : 0.69491525	 test accuracy : 0.68965517
# Train Epoch: 20: train loss : 1.07394099	 train accuracy : 0.98843931	 val accuracy : 0.67796610	 test accuracy : 0.66666667
# Train Epoch: 21: train loss : 1.06881082	 train accuracy : 0.98458574	 val accuracy : 0.68926554	 test accuracy : 0.72413793
# Train Epoch: 22: train loss : 1.05730867	 train accuracy : 0.97880539	 val accuracy : 0.67231638	 test accuracy : 0.70689655
# Save models
# Train Epoch: 23: train loss : 1.01519501	 train accuracy : 0.99229287	 val accuracy : 0.70621469	 test accuracy : 0.71264368
# Train Epoch: 24: train loss : 0.98627776	 train accuracy : 0.98843931	 val accuracy : 0.67796610	 test accuracy : 0.67816092
# Train Epoch: 25: train loss : 0.97972816	 train accuracy : 0.99807322	 val accuracy : 0.67231638	 test accuracy : 0.66666667
# Train Epoch: 26: train loss : 0.96512157	 train accuracy : 0.98458574	 val accuracy : 0.66101695	 test accuracy : 0.69540230
# Train Epoch: 27: train loss : 0.95394069	 train accuracy : 0.99421965	 val accuracy : 0.60451977	 test accuracy : 0.69540230
# Train Epoch: 28: train loss : 0.96183318	 train accuracy : 0.98073218	 val accuracy : 0.66666667	 test accuracy : 0.68390805
# Train Epoch: 29: train loss : 0.95229226	 train accuracy : 0.99229287	 val accuracy : 0.66666667	 test accuracy : 0.63218391
# Train Epoch: 30: train loss : 0.95190752	 train accuracy : 0.99421965	 val accuracy : 0.66101695	 test accuracy : 0.63793103
# Train Epoch: 31: train loss : 0.96058851	 train accuracy : 0.98843931	 val accuracy : 0.65536723	 test accuracy : 0.64942529
# Train Epoch: 32: train loss : 0.96425259	 train accuracy : 0.97880539	 val accuracy : 0.68361582	 test accuracy : 0.65517241
# Train Epoch: 33: train loss : 0.93309170	 train accuracy : 0.99036609	 val accuracy : 0.67231638	 test accuracy : 0.68390805
# Train Epoch: 34: train loss : 0.97161764	 train accuracy : 0.98843931	 val accuracy : 0.67231638	 test accuracy : 0.69540230
# Train Epoch: 35: train loss : 0.92515880	 train accuracy : 0.99421965	 val accuracy : 0.68361582	 test accuracy : 0.70689655
# Train Epoch: 36: train loss : 0.91349828	 train accuracy : 0.99421965	 val accuracy : 0.68361582	 test accuracy : 0.73563218
# Train Epoch: 37: train loss : 0.89280504	 train accuracy : 1.00000000	 val accuracy : 0.66666667	 test accuracy : 0.72988506
# Train Epoch: 38: train loss : 0.91069597	 train accuracy : 0.99421965	 val accuracy : 0.67796610	 test accuracy : 0.71839080
# Train Epoch: 39: train loss : 0.91668022	 train accuracy : 0.99036609	 val accuracy : 0.69491525	 test accuracy : 0.67816092
# Train Epoch: 40: train loss : 0.92724001	 train accuracy : 0.98458574	 val accuracy : 0.68361582	 test accuracy : 0.74137931
# Train Epoch: 41: train loss : 0.88972837	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.72988506
# Train Epoch: 42: train loss : 0.93066198	 train accuracy : 0.98651252	 val accuracy : 0.70056497	 test accuracy : 0.71264368
# Train Epoch: 43: train loss : 0.91926306	 train accuracy : 0.99229287	 val accuracy : 0.68361582	 test accuracy : 0.69540230
# Train Epoch: 44: train loss : 0.89340687	 train accuracy : 0.99229287	 val accuracy : 0.70056497	 test accuracy : 0.72988506
# Train Epoch: 45: train loss : 0.88113195	 train accuracy : 0.99614644	 val accuracy : 0.68926554	 test accuracy : 0.76436782
# Train Epoch: 46: train loss : 0.91448307	 train accuracy : 0.98651252	 val accuracy : 0.68926554	 test accuracy : 0.72413793
# Train Epoch: 47: train loss : 0.96830577	 train accuracy : 0.98458574	 val accuracy : 0.68926554	 test accuracy : 0.71264368
# Train Epoch: 48: train loss : 0.94135725	 train accuracy : 0.97495183	 val accuracy : 0.69491525	 test accuracy : 0.69540230
# Train Epoch: 49: train loss : 1.01655805	 train accuracy : 0.98458574	 val accuracy : 0.68926554	 test accuracy : 0.68965517
# Train Epoch: 50: train loss : 1.08834195	 train accuracy : 0.96339114	 val accuracy : 0.67796610	 test accuracy : 0.74137931
# Train Epoch: 51: train loss : 0.90003020	 train accuracy : 0.99036609	 val accuracy : 0.68926554	 test accuracy : 0.70689655
# Train Epoch: 52: train loss : 0.96718246	 train accuracy : 0.98073218	 val accuracy : 0.67231638	 test accuracy : 0.65517241
# Train Epoch: 53: train loss : 1.15598440	 train accuracy : 0.93834297	 val accuracy : 0.65536723	 test accuracy : 0.64367816
# Train Epoch: 54: train loss : 0.95872062	 train accuracy : 0.98073218	 val accuracy : 0.64971751	 test accuracy : 0.66091954
# Train Epoch: 55: train loss : 0.92878455	 train accuracy : 0.98843931	 val accuracy : 0.67231638	 test accuracy : 0.67241379
# Train Epoch: 56: train loss : 0.92876279	 train accuracy : 0.99614644	 val accuracy : 0.66101695	 test accuracy : 0.64942529
# Train Epoch: 57: train loss : 0.99826264	 train accuracy : 0.98265896	 val accuracy : 0.67231638	 test accuracy : 0.65517241
# Train Epoch: 58: train loss : 0.97467947	 train accuracy : 0.98265896	 val accuracy : 0.66666667	 test accuracy : 0.67241379
# Train Epoch: 59: train loss : 0.91080630	 train accuracy : 0.99421965	 val accuracy : 0.65536723	 test accuracy : 0.66666667
# Train Epoch: 60: train loss : 0.90466392	 train accuracy : 0.99421965	 val accuracy : 0.66101695	 test accuracy : 0.65517241
# Train Epoch: 61: train loss : 0.91881627	 train accuracy : 0.99421965	 val accuracy : 0.65536723	 test accuracy : 0.64367816
# Train Epoch: 62: train loss : 0.88465375	 train accuracy : 1.00000000	 val accuracy : 0.65536723	 test accuracy : 0.64942529
# Train Epoch: 63: train loss : 0.88637179	 train accuracy : 1.00000000	 val accuracy : 0.66101695	 test accuracy : 0.64367816
# Train Epoch: 64: train loss : 0.88488913	 train accuracy : 0.99229287	 val accuracy : 0.67231638	 test accuracy : 0.66091954
# Train Epoch: 65: train loss : 0.89495099	 train accuracy : 0.99807322	 val accuracy : 0.67231638	 test accuracy : 0.68390805
# Train Epoch: 66: train loss : 0.87609011	 train accuracy : 0.99614644	 val accuracy : 0.66101695	 test accuracy : 0.71839080
# Train Epoch: 67: train loss : 0.88629067	 train accuracy : 0.99807322	 val accuracy : 0.64971751	 test accuracy : 0.70689655
# Train Epoch: 68: train loss : 0.87951267	 train accuracy : 0.99807322	 val accuracy : 0.66101695	 test accuracy : 0.70114943
# Train Epoch: 69: train loss : 0.89595705	 train accuracy : 0.99229287	 val accuracy : 0.67231638	 test accuracy : 0.67241379
# Train Epoch: 70: train loss : 0.89349312	 train accuracy : 0.99036609	 val accuracy : 0.67231638	 test accuracy : 0.63793103
# Train Epoch: 71: train loss : 0.88876915	 train accuracy : 0.99421965	 val accuracy : 0.66101695	 test accuracy : 0.63793103
# Train Epoch: 72: train loss : 0.86690056	 train accuracy : 0.99421965	 val accuracy : 0.66101695	 test accuracy : 0.63218391
# Train Epoch: 73: train loss : 0.88560450	 train accuracy : 0.98651252	 val accuracy : 0.66101695	 test accuracy : 0.65517241
# Train Epoch: 74: train loss : 0.87935680	 train accuracy : 0.99807322	 val accuracy : 0.66666667	 test accuracy : 0.67816092
# Train Epoch: 75: train loss : 0.85910916	 train accuracy : 0.99807322	 val accuracy : 0.67231638	 test accuracy : 0.68390805
# Train Epoch: 76: train loss : 0.87891942	 train accuracy : 0.99036609	 val accuracy : 0.64971751	 test accuracy : 0.67816092
# Train Epoch: 77: train loss : 0.86465549	 train accuracy : 1.00000000	 val accuracy : 0.64971751	 test accuracy : 0.68390805
# Train Epoch: 78: train loss : 0.86428177	 train accuracy : 0.99807322	 val accuracy : 0.66101695	 test accuracy : 0.67241379
# Train Epoch: 79: train loss : 0.86852974	 train accuracy : 0.99229287	 val accuracy : 0.65536723	 test accuracy : 0.66666667
# Train Epoch: 80: train loss : 0.86401886	 train accuracy : 1.00000000	 val accuracy : 0.66101695	 test accuracy : 0.67241379
# Train Epoch: 81: train loss : 0.86629772	 train accuracy : 0.99614644	 val accuracy : 0.66666667	 test accuracy : 0.67816092
# Train Epoch: 82: train loss : 0.85916054	 train accuracy : 0.99614644	 val accuracy : 0.66666667	 test accuracy : 0.67241379
# Train Epoch: 83: train loss : 0.86146921	 train accuracy : 1.00000000	 val accuracy : 0.66666667	 test accuracy : 0.66666667
# Train Epoch: 84: train loss : 0.85867923	 train accuracy : 0.99229287	 val accuracy : 0.66666667	 test accuracy : 0.67816092
# Train Epoch: 85: train loss : 0.87037051	 train accuracy : 0.99229287	 val accuracy : 0.66666667	 test accuracy : 0.68965517
# Train Epoch: 86: train loss : 0.85114086	 train accuracy : 0.99614644	 val accuracy : 0.66666667	 test accuracy : 0.68965517
# Train Epoch: 87: train loss : 0.85603648	 train accuracy : 0.99614644	 val accuracy : 0.65536723	 test accuracy : 0.68965517
# Train Epoch: 88: train loss : 0.85552919	 train accuracy : 0.99614644	 val accuracy : 0.66101695	 test accuracy : 0.67241379
# Train Epoch: 89: train loss : 0.86125469	 train accuracy : 1.00000000	 val accuracy : 0.64971751	 test accuracy : 0.68965517
# Train Epoch: 90: train loss : 0.83887076	 train accuracy : 0.99807322	 val accuracy : 0.64971751	 test accuracy : 0.70114943
# Train Epoch: 91: train loss : 0.85496104	 train accuracy : 0.99421965	 val accuracy : 0.64406780	 test accuracy : 0.69540230
# Train Epoch: 92: train loss : 0.84634823	 train accuracy : 0.99807322	 val accuracy : 0.65536723	 test accuracy : 0.69540230
# Train Epoch: 93: train loss : 0.85155696	 train accuracy : 0.99807322	 val accuracy : 0.67231638	 test accuracy : 0.67816092
# Train Epoch: 94: train loss : 0.85841048	 train accuracy : 0.99614644	 val accuracy : 0.66666667	 test accuracy : 0.66666667
# Train Epoch: 95: train loss : 0.83986866	 train accuracy : 1.00000000	 val accuracy : 0.65536723	 test accuracy : 0.67241379
# Train Epoch: 96: train loss : 0.83841896	 train accuracy : 0.99614644	 val accuracy : 0.65536723	 test accuracy : 0.67241379
# Train Epoch: 97: train loss : 0.84950042	 train accuracy : 0.99036609	 val accuracy : 0.65536723	 test accuracy : 0.66666667
# Train Epoch: 98: train loss : 0.84333187	 train accuracy : 0.99421965	 val accuracy : 0.64406780	 test accuracy : 0.66666667
# Train Epoch: 99: train loss : 0.84870803	 train accuracy : 0.99614644	 val accuracy : 0.66101695	 test accuracy : 0.67241379
# Train Epoch: 100: train loss : 0.84515399	 train accuracy : 0.99614644	 val accuracy : 0.66101695	 test accuracy : 0.70114943
# Train Epoch: 101: train loss : 0.85101682	 train accuracy : 0.99614644	 val accuracy : 0.66101695	 test accuracy : 0.69540230
# Train Epoch: 102: train loss : 0.85763252	 train accuracy : 0.99807322	 val accuracy : 0.66666667	 test accuracy : 0.68390805
# Train Epoch: 103: train loss : 0.87086284	 train accuracy : 0.99421965	 val accuracy : 0.66101695	 test accuracy : 0.68390805
# Train Epoch: 104: train loss : 0.85565144	 train accuracy : 0.99229287	 val accuracy : 0.66666667	 test accuracy : 0.68965517
# Train Epoch: 105: train loss : 0.86097813	 train accuracy : 0.99807322	 val accuracy : 0.64971751	 test accuracy : 0.70689655
# Train Epoch: 106: train loss : 0.83933640	 train accuracy : 1.00000000	 val accuracy : 0.66101695	 test accuracy : 0.67816092
# Train Epoch: 107: train loss : 0.84516907	 train accuracy : 0.99614644	 val accuracy : 0.64971751	 test accuracy : 0.66666667
# Train Epoch: 108: train loss : 0.84389496	 train accuracy : 0.99807322	 val accuracy : 0.67231638	 test accuracy : 0.65517241
# Train Epoch: 109: train loss : 0.84813070	 train accuracy : 0.99807322	 val accuracy : 0.66666667	 test accuracy : 0.66091954
# Train Epoch: 110: train loss : 0.86127919	 train accuracy : 0.99421965	 val accuracy : 0.66666667	 test accuracy : 0.66091954
# Train Epoch: 111: train loss : 0.85094708	 train accuracy : 0.99807322	 val accuracy : 0.66666667	 test accuracy : 0.66091954
# Train Epoch: 112: train loss : 0.85498130	 train accuracy : 0.99421965	 val accuracy : 0.66101695	 test accuracy : 0.68390805
# Train Epoch: 113: train loss : 0.83399916	 train accuracy : 1.00000000	 val accuracy : 0.66666667	 test accuracy : 0.71264368
# Train Epoch: 114: train loss : 0.84404361	 train accuracy : 0.99614644	 val accuracy : 0.66101695	 test accuracy : 0.70689655
# Train Epoch: 115: train loss : 0.84169352	 train accuracy : 0.99807322	 val accuracy : 0.66101695	 test accuracy : 0.71839080
# Train Epoch: 116: train loss : 0.83931339	 train accuracy : 1.00000000	 val accuracy : 0.66666667	 test accuracy : 0.71839080
# Train Epoch: 117: train loss : 0.84313387	 train accuracy : 1.00000000	 val accuracy : 0.66666667	 test accuracy : 0.70689655
# Train Epoch: 118: train loss : 0.84188110	 train accuracy : 1.00000000	 val accuracy : 0.66666667	 test accuracy : 0.70114943
# Train Epoch: 119: train loss : 0.84018815	 train accuracy : 0.99229287	 val accuracy : 0.66101695	 test accuracy : 0.70114943
# Train Epoch: 120: train loss : 0.83996850	 train accuracy : 0.99807322	 val accuracy : 0.66101695	 test accuracy : 0.71264368
# Train Epoch: 121: train loss : 0.83756673	 train accuracy : 0.99807322	 val accuracy : 0.66666667	 test accuracy : 0.71839080
# Train Epoch: 122: train loss : 0.82702166	 train accuracy : 1.00000000	 val accuracy : 0.66666667	 test accuracy : 0.71839080
# Train Epoch: 123: train loss : 0.83960247	 train accuracy : 0.99614644	 val accuracy : 0.67796610	 test accuracy : 0.72413793
# Train Epoch: 124: train loss : 0.81741828	 train accuracy : 1.00000000	 val accuracy : 0.66101695	 test accuracy : 0.72413793
# Train Epoch: 125: train loss : 0.83704388	 train accuracy : 0.99614644	 val accuracy : 0.67231638	 test accuracy : 0.70689655
# Train Epoch: 126: train loss : 0.83335602	 train accuracy : 0.99807322	 val accuracy : 0.67796610	 test accuracy : 0.68965517
# Train Epoch: 127: train loss : 0.83593011	 train accuracy : 0.99807322	 val accuracy : 0.67796610	 test accuracy : 0.68390805
# Train Epoch: 128: train loss : 0.82879978	 train accuracy : 0.99807322	 val accuracy : 0.67231638	 test accuracy : 0.67816092
# Train Epoch: 129: train loss : 0.84997284	 train accuracy : 0.99036609	 val accuracy : 0.66101695	 test accuracy : 0.71839080
# Train Epoch: 130: train loss : 0.83703750	 train accuracy : 0.99614644	 val accuracy : 0.65536723	 test accuracy : 0.72413793
# Train Epoch: 131: train loss : 0.84226578	 train accuracy : 0.99614644	 val accuracy : 0.65536723	 test accuracy : 0.71264368
# Train Epoch: 132: train loss : 0.81420040	 train accuracy : 1.00000000	 val accuracy : 0.66666667	 test accuracy : 0.70689655
# Train Epoch: 133: train loss : 0.83935249	 train accuracy : 1.00000000	 val accuracy : 0.66101695	 test accuracy : 0.69540230
# Train Epoch: 134: train loss : 0.85444391	 train accuracy : 0.99036609	 val accuracy : 0.66101695	 test accuracy : 0.70689655
# Train Epoch: 135: train loss : 0.83474696	 train accuracy : 0.99421965	 val accuracy : 0.64406780	 test accuracy : 0.71264368
# Train Epoch: 136: train loss : 0.83278674	 train accuracy : 0.99807322	 val accuracy : 0.65536723	 test accuracy : 0.70114943
# Train Epoch: 137: train loss : 0.82153159	 train accuracy : 0.99614644	 val accuracy : 0.64406780	 test accuracy : 0.69540230
# Train Epoch: 138: train loss : 0.83219850	 train accuracy : 0.99807322	 val accuracy : 0.64971751	 test accuracy : 0.67816092
# Train Epoch: 139: train loss : 0.83595109	 train accuracy : 0.99807322	 val accuracy : 0.67796610	 test accuracy : 0.66666667
# Train Epoch: 140: train loss : 0.82567054	 train accuracy : 0.99614644	 val accuracy : 0.67796610	 test accuracy : 0.64942529
# Train Epoch: 141: train loss : 0.84096545	 train accuracy : 0.99614644	 val accuracy : 0.66666667	 test accuracy : 0.65517241
# Train Epoch: 142: train loss : 0.84130132	 train accuracy : 0.99421965	 val accuracy : 0.67231638	 test accuracy : 0.65517241
# Train Epoch: 143: train loss : 0.83472133	 train accuracy : 0.99421965	 val accuracy : 0.63276836	 test accuracy : 0.67241379
# Train Epoch: 144: train loss : 0.82944775	 train accuracy : 1.00000000	 val accuracy : 0.63276836	 test accuracy : 0.66666667
# Train Epoch: 145: train loss : 0.83400065	 train accuracy : 0.99614644	 val accuracy : 0.62711864	 test accuracy : 0.68390805
# Train Epoch: 146: train loss : 0.82871097	 train accuracy : 1.00000000	 val accuracy : 0.63841808	 test accuracy : 0.68390805
# Train Epoch: 147: train loss : 0.82952523	 train accuracy : 0.99614644	 val accuracy : 0.63841808	 test accuracy : 0.70114943
# Train Epoch: 148: train loss : 0.85251462	 train accuracy : 0.99807322	 val accuracy : 0.65536723	 test accuracy : 0.70689655
# Train Epoch: 149: train loss : 0.84378910	 train accuracy : 1.00000000	 val accuracy : 0.66101695	 test accuracy : 0.70114943
# Train Epoch: 150: train loss : 0.83355117	 train accuracy : 0.99807322	 val accuracy : 0.67796610	 test accuracy : 0.69540230
# Train Epoch: 151: train loss : 0.83292413	 train accuracy : 0.99807322	 val accuracy : 0.67796610	 test accuracy : 0.70114943
# Train Epoch: 152: train loss : 0.82951063	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.69540230
# Train Epoch: 153: train loss : 0.82588577	 train accuracy : 1.00000000	 val accuracy : 0.67231638	 test accuracy : 0.70114943
# Train Epoch: 154: train loss : 0.83386070	 train accuracy : 0.99614644	 val accuracy : 0.66666667	 test accuracy : 0.70114943
# Train Epoch: 155: train loss : 0.82349980	 train accuracy : 0.99421965	 val accuracy : 0.67231638	 test accuracy : 0.70689655
# Train Epoch: 156: train loss : 0.81735212	 train accuracy : 1.00000000	 val accuracy : 0.66666667	 test accuracy : 0.70114943
# Train Epoch: 157: train loss : 0.84041071	 train accuracy : 0.99807322	 val accuracy : 0.67231638	 test accuracy : 0.70689655
# Train Epoch: 158: train loss : 0.82200456	 train accuracy : 0.99807322	 val accuracy : 0.64971751	 test accuracy : 0.69540230
# Train Epoch: 159: train loss : 0.82396615	 train accuracy : 1.00000000	 val accuracy : 0.63841808	 test accuracy : 0.70114943
# Train Epoch: 160: train loss : 0.82269657	 train accuracy : 1.00000000	 val accuracy : 0.63841808	 test accuracy : 0.68390805
# Train Epoch: 161: train loss : 0.82717919	 train accuracy : 0.99807322	 val accuracy : 0.66101695	 test accuracy : 0.68390805
# Train Epoch: 162: train loss : 0.81850696	 train accuracy : 0.99807322	 val accuracy : 0.65536723	 test accuracy : 0.68390805
# Train Epoch: 163: train loss : 0.82587701	 train accuracy : 0.99807322	 val accuracy : 0.65536723	 test accuracy : 0.67816092
# Train Epoch: 164: train loss : 0.82567531	 train accuracy : 1.00000000	 val accuracy : 0.66101695	 test accuracy : 0.68390805
# Train Epoch: 165: train loss : 0.82390451	 train accuracy : 0.99807322	 val accuracy : 0.67796610	 test accuracy : 0.70114943
# Train Epoch: 166: train loss : 0.82342517	 train accuracy : 1.00000000	 val accuracy : 0.68361582	 test accuracy : 0.71839080
# Train Epoch: 167: train loss : 0.81158400	 train accuracy : 0.99807322	 val accuracy : 0.68361582	 test accuracy : 0.70689655
# Train Epoch: 168: train loss : 0.81638044	 train accuracy : 0.99807322	 val accuracy : 0.67796610	 test accuracy : 0.71264368
# Train Epoch: 169: train loss : 0.82565123	 train accuracy : 0.99229287	 val accuracy : 0.67796610	 test accuracy : 0.70689655
# Train Epoch: 170: train loss : 0.81975281	 train accuracy : 0.99421965	 val accuracy : 0.67796610	 test accuracy : 0.70689655
# Train Epoch: 171: train loss : 0.81669849	 train accuracy : 0.99614644	 val accuracy : 0.67796610	 test accuracy : 0.70689655
# Train Epoch: 172: train loss : 0.81577283	 train accuracy : 1.00000000	 val accuracy : 0.67231638	 test accuracy : 0.71839080
# Train Epoch: 173: train loss : 0.81018776	 train accuracy : 1.00000000	 val accuracy : 0.66666667	 test accuracy : 0.72413793
# Train Epoch: 174: train loss : 0.81697196	 train accuracy : 0.99614644	 val accuracy : 0.66666667	 test accuracy : 0.71264368
# Train Epoch: 175: train loss : 0.81558615	 train accuracy : 1.00000000	 val accuracy : 0.67231638	 test accuracy : 0.70689655
# ...
# Train Epoch: 79: train loss : 0.87809098	 train accuracy : 0.99616123	 val accuracy : 0.69461078	 test accuracy : 0.70329670
# Train Epoch: 80: train loss : 0.88403577	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.69230769
# Train Epoch: 81: train loss : 0.87128705	 train accuracy : 0.99616123	 val accuracy : 0.68263473	 test accuracy : 0.68681319
# Train Epoch: 82: train loss : 0.87896496	 train accuracy : 1.00000000	 val accuracy : 0.67065868	 test accuracy : 0.69230769
# Train Epoch: 83: train loss : 0.87919366	 train accuracy : 0.99424184	 val accuracy : 0.67065868	 test accuracy : 0.70329670
# Train Epoch: 84: train loss : 0.86285889	 train accuracy : 0.99808061	 val accuracy : 0.68862275	 test accuracy : 0.69230769
# Train Epoch: 85: train loss : 0.86352116	 train accuracy : 0.99616123	 val accuracy : 0.68862275	 test accuracy : 0.69230769
# Train Epoch: 86: train loss : 0.85951233	 train accuracy : 0.99808061	 val accuracy : 0.68862275	 test accuracy : 0.69780220
# Train Epoch: 87: train loss : 0.85217601	 train accuracy : 1.00000000	 val accuracy : 0.66467066	 test accuracy : 0.71428571
# Train Epoch: 88: train loss : 0.83824211	 train accuracy : 1.00000000	 val accuracy : 0.67065868	 test accuracy : 0.71428571
# Train Epoch: 89: train loss : 0.83948195	 train accuracy : 1.00000000	 val accuracy : 0.66467066	 test accuracy : 0.71978022
# Train Epoch: 90: train loss : 0.82799602	 train accuracy : 0.99808061	 val accuracy : 0.66467066	 test accuracy : 0.71428571
# Train Epoch: 91: train loss : 0.84532541	 train accuracy : 0.99808061	 val accuracy : 0.66467066	 test accuracy : 0.70879121
# Train Epoch: 92: train loss : 0.84124404	 train accuracy : 0.99616123	 val accuracy : 0.65868263	 test accuracy : 0.71428571
# Train Epoch: 93: train loss : 0.83534324	 train accuracy : 0.99424184	 val accuracy : 0.67664671	 test accuracy : 0.71428571
# Train Epoch: 94: train loss : 0.82390964	 train accuracy : 1.00000000	 val accuracy : 0.67065868	 test accuracy : 0.71428571
# Train Epoch: 95: train loss : 0.82354826	 train accuracy : 0.99808061	 val accuracy : 0.67065868	 test accuracy : 0.70879121
# Train Epoch: 96: train loss : 0.85482210	 train accuracy : 0.99040307	 val accuracy : 0.67664671	 test accuracy : 0.70329670
# Train Epoch: 97: train loss : 0.82998860	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.69230769
# Train Epoch: 98: train loss : 0.82787144	 train accuracy : 0.99616123	 val accuracy : 0.69461078	 test accuracy : 0.69230769
# Train Epoch: 99: train loss : 0.82938588	 train accuracy : 0.99040307	 val accuracy : 0.67664671	 test accuracy : 0.69230769
# Train Epoch: 100: train loss : 0.82587248	 train accuracy : 0.99616123	 val accuracy : 0.68862275	 test accuracy : 0.68131868
# Train Epoch: 101: train loss : 0.82398200	 train accuracy : 0.99808061	 val accuracy : 0.68862275	 test accuracy : 0.67582418
# Train Epoch: 102: train loss : 0.82115656	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.68131868
# Train Epoch: 103: train loss : 0.82163846	 train accuracy : 0.99232246	 val accuracy : 0.67664671	 test accuracy : 0.68681319
# Train Epoch: 104: train loss : 0.81371891	 train accuracy : 1.00000000	 val accuracy : 0.67065868	 test accuracy : 0.69780220
# Train Epoch: 105: train loss : 0.82865018	 train accuracy : 0.99808061	 val accuracy : 0.67065868	 test accuracy : 0.69780220
# Train Epoch: 106: train loss : 0.82462358	 train accuracy : 0.99808061	 val accuracy : 0.67065868	 test accuracy : 0.69230769
# Train Epoch: 107: train loss : 0.83201456	 train accuracy : 0.99616123	 val accuracy : 0.67664671	 test accuracy : 0.68681319
# Train Epoch: 108: train loss : 0.81935972	 train accuracy : 0.99808061	 val accuracy : 0.67664671	 test accuracy : 0.68681319
# Train Epoch: 109: train loss : 0.81729394	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.69230769
# Train Epoch: 110: train loss : 0.81288040	 train accuracy : 0.99616123	 val accuracy : 0.67065868	 test accuracy : 0.69230769
# Train Epoch: 111: train loss : 0.81591284	 train accuracy : 1.00000000	 val accuracy : 0.67065868	 test accuracy : 0.68681319
# Train Epoch: 112: train loss : 0.81204456	 train accuracy : 0.99808061	 val accuracy : 0.66467066	 test accuracy : 0.68681319
# Train Epoch: 113: train loss : 0.81165719	 train accuracy : 0.99616123	 val accuracy : 0.66467066	 test accuracy : 0.69780220
# Train Epoch: 114: train loss : 0.81554896	 train accuracy : 0.99616123	 val accuracy : 0.66467066	 test accuracy : 0.70329670
# Train Epoch: 115: train loss : 0.81629354	 train accuracy : 1.00000000	 val accuracy : 0.66467066	 test accuracy : 0.69780220
# Train Epoch: 116: train loss : 0.81169814	 train accuracy : 0.99808061	 val accuracy : 0.66467066	 test accuracy : 0.69780220
# Train Epoch: 117: train loss : 0.81568152	 train accuracy : 1.00000000	 val accuracy : 0.67065868	 test accuracy : 0.69780220
# Train Epoch: 118: train loss : 0.80577821	 train accuracy : 0.99616123	 val accuracy : 0.67065868	 test accuracy : 0.69780220
# Train Epoch: 119: train loss : 0.80815023	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.69780220
# Train Epoch: 120: train loss : 0.80413145	 train accuracy : 0.99616123	 val accuracy : 0.68263473	 test accuracy : 0.69780220
# Train Epoch: 121: train loss : 0.80638570	 train accuracy : 0.99808061	 val accuracy : 0.68862275	 test accuracy : 0.69780220
# Train Epoch: 122: train loss : 0.80968660	 train accuracy : 0.99616123	 val accuracy : 0.68862275	 test accuracy : 0.69780220
# Train Epoch: 123: train loss : 0.80913091	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.70329670
# Train Epoch: 124: train loss : 0.81180459	 train accuracy : 0.99424184	 val accuracy : 0.69461078	 test accuracy : 0.70329670
# Train Epoch: 125: train loss : 0.81340355	 train accuracy : 0.99616123	 val accuracy : 0.69461078	 test accuracy : 0.69780220
# Train Epoch: 126: train loss : 0.81484568	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.69780220
# Train Epoch: 127: train loss : 0.79724008	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.69780220
# Train Epoch: 128: train loss : 0.79669780	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.69780220
# Save models
# Train Epoch: 129: train loss : 0.79844445	 train accuracy : 1.00000000	 val accuracy : 0.70658683	 test accuracy : 0.69780220
# Save models
# Train Epoch: 130: train loss : 0.80129391	 train accuracy : 0.99808061	 val accuracy : 0.70658683	 test accuracy : 0.69780220
# Train Epoch: 131: train loss : 0.80264127	 train accuracy : 0.99616123	 val accuracy : 0.68862275	 test accuracy : 0.69780220
# Train Epoch: 132: train loss : 0.79495281	 train accuracy : 0.99808061	 val accuracy : 0.68862275	 test accuracy : 0.69780220
# Train Epoch: 133: train loss : 0.80013013	 train accuracy : 0.99808061	 val accuracy : 0.69461078	 test accuracy : 0.69780220
# Train Epoch: 134: train loss : 0.80189908	 train accuracy : 0.99616123	 val accuracy : 0.69461078	 test accuracy : 0.69230769
# Train Epoch: 135: train loss : 0.79460943	 train accuracy : 0.99808061	 val accuracy : 0.69461078	 test accuracy : 0.69230769
# Train Epoch: 136: train loss : 0.80440611	 train accuracy : 0.99808061	 val accuracy : 0.69461078	 test accuracy : 0.69780220
# Train Epoch: 137: train loss : 0.79637110	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.69780220
# Train Epoch: 138: train loss : 0.79884881	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.69780220
# Train Epoch: 139: train loss : 0.79266322	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.69780220
# Train Epoch: 140: train loss : 0.80038595	 train accuracy : 0.99616123	 val accuracy : 0.68862275	 test accuracy : 0.70329670
# Train Epoch: 141: train loss : 0.79697174	 train accuracy : 0.99808061	 val accuracy : 0.68263473	 test accuracy : 0.70329670
# Train Epoch: 142: train loss : 0.78732640	 train accuracy : 0.99616123	 val accuracy : 0.68263473	 test accuracy : 0.70879121
# Train Epoch: 143: train loss : 0.79747677	 train accuracy : 0.99808061	 val accuracy : 0.68263473	 test accuracy : 0.70879121
# Train Epoch: 144: train loss : 0.79735041	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.71428571
# Train Epoch: 145: train loss : 0.80471539	 train accuracy : 0.99808061	 val accuracy : 0.70059880	 test accuracy : 0.70329670
# Save models
# Train Epoch: 146: train loss : 0.80157578	 train accuracy : 0.99808061	 val accuracy : 0.70658683	 test accuracy : 0.70329670
# Train Epoch: 147: train loss : 0.78407252	 train accuracy : 0.99616123	 val accuracy : 0.69461078	 test accuracy : 0.70329670
# Train Epoch: 148: train loss : 0.80158836	 train accuracy : 0.99424184	 val accuracy : 0.68862275	 test accuracy : 0.69780220
# Train Epoch: 149: train loss : 0.78758609	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.68681319
# Save models
# Train Epoch: 150: train loss : 0.78791445	 train accuracy : 0.99808061	 val accuracy : 0.70658683	 test accuracy : 0.68681319
# Train Epoch: 151: train loss : 0.78881437	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.68131868
# Train Epoch: 152: train loss : 0.79170769	 train accuracy : 0.99808061	 val accuracy : 0.68263473	 test accuracy : 0.69230769
# Train Epoch: 153: train loss : 0.78885943	 train accuracy : 0.99808061	 val accuracy : 0.69461078	 test accuracy : 0.68681319
# Train Epoch: 154: train loss : 0.79635221	 train accuracy : 0.99616123	 val accuracy : 0.68263473	 test accuracy : 0.70329670
# Train Epoch: 155: train loss : 0.79794896	 train accuracy : 0.99424184	 val accuracy : 0.68263473	 test accuracy : 0.69780220
# Train Epoch: 156: train loss : 0.80243462	 train accuracy : 0.98848369	 val accuracy : 0.68862275	 test accuracy : 0.69780220
# Train Epoch: 157: train loss : 0.79100883	 train accuracy : 0.99808061	 val accuracy : 0.69461078	 test accuracy : 0.69780220
# Save models
# Train Epoch: 158: train loss : 0.77900165	 train accuracy : 1.00000000	 val accuracy : 0.70658683	 test accuracy : 0.69230769
# Train Epoch: 159: train loss : 0.78338194	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.68681319
# Train Epoch: 160: train loss : 0.78684825	 train accuracy : 0.99616123	 val accuracy : 0.69461078	 test accuracy : 0.69230769
# Train Epoch: 161: train loss : 0.78334659	 train accuracy : 0.99808061	 val accuracy : 0.70059880	 test accuracy : 0.69230769
# Save models
# Train Epoch: 162: train loss : 0.78222460	 train accuracy : 1.00000000	 val accuracy : 0.71257485	 test accuracy : 0.69230769
# Train Epoch: 163: train loss : 0.78986788	 train accuracy : 0.99808061	 val accuracy : 0.70658683	 test accuracy : 0.69230769
# Train Epoch: 164: train loss : 0.77955556	 train accuracy : 0.99616123	 val accuracy : 0.70658683	 test accuracy : 0.69230769
# Save models
# Train Epoch: 165: train loss : 0.77701807	 train accuracy : 0.99808061	 val accuracy : 0.71257485	 test accuracy : 0.69230769
# Save models
# Train Epoch: 166: train loss : 0.79042023	 train accuracy : 1.00000000	 val accuracy : 0.71257485	 test accuracy : 0.69230769
# Train Epoch: 167: train loss : 0.77992988	 train accuracy : 0.99616123	 val accuracy : 0.70658683	 test accuracy : 0.69230769
# Train Epoch: 168: train loss : 0.78539485	 train accuracy : 0.99424184	 val accuracy : 0.70658683	 test accuracy : 0.69230769
# Save models
# Train Epoch: 169: train loss : 0.78574646	 train accuracy : 1.00000000	 val accuracy : 0.71257485	 test accuracy : 0.69230769
# Save models
# Train Epoch: 170: train loss : 0.79271251	 train accuracy : 1.00000000	 val accuracy : 0.71257485	 test accuracy : 0.69230769
# Save models
# Train Epoch: 171: train loss : 0.78533638	 train accuracy : 1.00000000	 val accuracy : 0.71257485	 test accuracy : 0.69230769
# Save models
# Train Epoch: 172: train loss : 0.77952772	 train accuracy : 1.00000000	 val accuracy : 0.71257485	 test accuracy : 0.68681319
# Save models
# Train Epoch: 173: train loss : 0.77495289	 train accuracy : 1.00000000	 val accuracy : 0.71257485	 test accuracy : 0.68681319
# Save models
# Train Epoch: 174: train loss : 0.77747190	 train accuracy : 0.99808061	 val accuracy : 0.71257485	 test accuracy : 0.68681319
# Save models
# Train Epoch: 175: train loss : 0.78137028	 train accuracy : 0.99808061	 val accuracy : 0.71856287	 test accuracy : 0.68131868
# Save models
# Train Epoch: 176: train loss : 0.77851778	 train accuracy : 0.99808061	 val accuracy : 0.71856287	 test accuracy : 0.68131868
# Train Epoch: 177: train loss : 0.76857942	 train accuracy : 1.00000000	 val accuracy : 0.71257485	 test accuracy : 0.68131868
# Save models
# Train Epoch: 178: train loss : 0.76326817	 train accuracy : 1.00000000	 val accuracy : 0.71856287	 test accuracy : 0.68131868
# Train Epoch: 179: train loss : 0.76661539	 train accuracy : 1.00000000	 val accuracy : 0.71257485	 test accuracy : 0.68131868
# Train Epoch: 180: train loss : 0.79557985	 train accuracy : 0.99616123	 val accuracy : 0.69461078	 test accuracy : 0.68131868
# Train Epoch: 181: train loss : 0.78863138	 train accuracy : 0.99616123	 val accuracy : 0.68263473	 test accuracy : 0.69780220
# Train Epoch: 182: train loss : 0.77632296	 train accuracy : 0.99808061	 val accuracy : 0.69461078	 test accuracy : 0.68681319
# Train Epoch: 183: train loss : 0.77341592	 train accuracy : 0.99616123	 val accuracy : 0.68862275	 test accuracy : 0.69780220
# Train Epoch: 184: train loss : 0.77006674	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.70329670
# Train Epoch: 185: train loss : 0.77088535	 train accuracy : 0.99616123	 val accuracy : 0.68263473	 test accuracy : 0.69230769
# Train Epoch: 186: train loss : 0.76690805	 train accuracy : 1.00000000	 val accuracy : 0.67065868	 test accuracy : 0.68681319
# Train Epoch: 187: train loss : 0.77045590	 train accuracy : 0.99616123	 val accuracy : 0.67065868	 test accuracy : 0.68131868
# Train Epoch: 188: train loss : 0.77222180	 train accuracy : 0.99616123	 val accuracy : 0.67664671	 test accuracy : 0.68681319
# Train Epoch: 189: train loss : 0.75558841	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.68681319
# Train Epoch: 190: train loss : 0.76327920	 train accuracy : 0.99616123	 val accuracy : 0.68862275	 test accuracy : 0.67582418
# Train Epoch: 191: train loss : 0.76230693	 train accuracy : 0.99808061	 val accuracy : 0.68263473	 test accuracy : 0.68681319
# Train Epoch: 192: train loss : 0.76401597	 train accuracy : 0.99808061	 val accuracy : 0.68862275	 test accuracy : 0.68131868
# Train Epoch: 193: train loss : 0.75917786	 train accuracy : 1.00000000	 val accuracy : 0.70658683	 test accuracy : 0.67582418
# Train Epoch: 194: train loss : 0.76285958	 train accuracy : 0.99808061	 val accuracy : 0.70059880	 test accuracy : 0.67582418
# Train Epoch: 195: train loss : 0.76365632	 train accuracy : 0.99424184	 val accuracy : 0.68862275	 test accuracy : 0.68131868
# Train Epoch: 196: train loss : 0.76596802	 train accuracy : 0.99808061	 val accuracy : 0.70658683	 test accuracy : 0.68131868
# Train Epoch: 197: train loss : 0.75931823	 train accuracy : 0.99808061	 val accuracy : 0.70059880	 test accuracy : 0.69780220
# Train Epoch: 198: train loss : 0.76055038	 train accuracy : 0.99808061	 val accuracy : 0.69461078	 test accuracy : 0.71428571
# Train Epoch: 199: train loss : 0.76041001	 train accuracy : 0.99424184	 val accuracy : 0.70658683	 test accuracy : 0.74175824
# Train Epoch: 200: train loss : 0.76343232	 train accuracy : 0.99616123	 val accuracy : 0.70059880	 test accuracy : 0.73076923
# In fold  5
# The best validaiton accuracy is:  0.718562874251497
# Happened at epoch:  178
# The corresponding test accuracy 0.6813186813186813
# The corresponding test AUC is:  0.7421875
# Finish 5-fold training

# %%
val_accuracy = metrics.accuracy_score(all_fold_val_label, all_fold_val_out)
test_accuracy = metrics.accuracy_score(all_fold_test_label, all_fold_test_out)
test_fpr, test_tpr, te_thresholds = roc_curve(all_fold_test_label, all_fold_test_prob[:,1],pos_label=1)
test_auc = auc(test_fpr, test_tpr)
print('The best validation accuracy is ',val_accuracy)
print('The corresponding test accuracy is ',test_accuracy)
print('The corresponding test AUC is: ',test_auc)
plt.grid()
plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
plt.plot([0,1],[0,1],'g--')
plt.legend()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Test AUC(ROC curve)")
plt.grid(color='black', linestyle='-', linewidth=0.5)
plt.show()
# Out:
# The best validation accuracy is  0.725287356321839
# The corresponding test accuracy is  0.6908045977011494
# The corresponding test AUC is:  0.7071455518302241

# %%
torch.cuda.empty_cache()
torch.manual_seed(args.seed)
if args.cuda:
    torch.cuda.manual_seed(args.seed)
############################################### Max voting ###############################################################
############################################### Max voting ###############################################################
############################################### Max voting ###############################################################
dist_ensemble_val_label = {}
dist_ensemble_val_result = {}
dist_ensemble_test_label = {}
dist_ensemble_test_result = {}
dist_ensemble_test_prob = {}

for ensemble_fold in range(5):
  print('Ensemble ',ensemble_fold+1)
  save_ensemble_models_path = save_path + 'Max_voting/AUTO/'
  dist_train = {}
  dist_validation = {}
  dist_test = {}
  for i in range(k_fold):
    dist_train[str(i + 1)] = []
    dist_validation[str(i + 1)] = []
    dist_test[str(i + 1)] = []
  test_name = {}
  for i in range(len(unique_sites)):
    test_name[unique_sites[i]] = []
  for each_site in unique_sites:
    index_site = get_index(sites, each_site)
    label = np.zeros((len(index_site)))
    for i in range(len(index_site)):
      index = index_site[i]
      label[i] = int(labels[int(index)])
    test_name_list = test_name[each_site]
    ########################################### StratifiedKFold ####################################################
    sfolder = StratifiedKFold(n_splits=k_fold,random_state=0,shuffle=True)
    group = 0
    for train, validation in sfolder.split(index_site,label):
      if group == ensemble_fold:
        for j in validation:
          name = index_site[j]
          dist_test['1'].append(name)
          dist_test['2'].append(name)
          dist_test['3'].append(name)
          dist_test['4'].append(name)
          dist_test['5'].append(name)
          test_name_list.append(name)
      group = group + 1
    test_name[each_site] = test_name_list

  for each_site in unique_sites:
    if ensemble_fold == 0:

      index_site = get_index(sites, each_site)
      label = np.zeros((len(index_site)))
      for i in range(len(index_site)):
        index = index_site[i]
        label[i] = int(labels[int(index)])
      test_name_list = test_name[each_site]
      index_site_new = []
      label_new = np.zeros((len(index_site) - len(test_name_list)))
      position = 0
      for x in range(len(index_site)):
        sample_name = index_site[x]
        if sample_name in test_name_list:
          c=0
        else:
          index_site_new.append(sample_name)
          label_new[position] = label[x]
          position = position + 1
      if each_site == 'CMU':  # ONLY 4 AUTISM SAMPLES AND 4 TD SAMPLES, CAN NOT BE DEVIDED INTO 5 GROUPS
        group_autism_val = []
        group_autism_train = []
        group_TD_val = []
        group_TD_train = []
        autism_validation_number = len(label_new[label_new ==1])/4
        TD_validation_number = len(label_new[label_new ==0]) / 4
        for j in range(len(label_new)):
          if label_new[j] == 1:
            if len(group_autism_val)<autism_validation_number:
              group_autism_val.append(index_site_new[j])
            else:
              group_autism_train.append(index_site_new[j])
          else:
            if len(group_TD_val)<TD_validation_number:
              group_TD_val.append(index_site_new[j])
            else:
              group_TD_train.append(index_site_new[j])

        dist_validation['1'] = dist_validation['1'] + group_autism_val + group_TD_val
        dist_validation['2'] = dist_validation['2'] + group_autism_val + group_TD_val
        dist_validation['3'] = dist_validation['3'] + group_autism_val + group_TD_val
        dist_validation['4'] = dist_validation['4'] + group_autism_val + group_TD_val
        dist_validation['5'] = dist_validation['5'] + group_autism_val + group_TD_val
        dist_train['1'] = dist_train['1'] + group_autism_train + group_TD_train
        dist_train['2'] = dist_train['2'] + group_autism_train + group_TD_train
        dist_train['3'] = dist_train['3'] + group_autism_train + group_TD_train
        dist_train['4'] = dist_train['4'] + group_autism_train + group_TD_train
        dist_train['5'] = dist_train['5'] + group_autism_train + group_TD_train
      else:
        ########################################### StratifiedKFold ####################################################
        sfolder = StratifiedKFold(n_splits=k_fold, random_state=0, shuffle=True)
        group = 0
        for train, validation in sfolder.split(index_site_new, label_new):

          for i in train:
            name = index_site_new[i]
            dist_train[str(group + 1)].append(name)
          for j in validation:
            name = index_site_new[j]
            dist_validation[str(group + 1)].append(name)
          group = group + 1
    else:

      index_site = get_index(sites, each_site)
      label = np.zeros((len(index_site)))
      for i in range(len(index_site)):
        index = index_site[i]
        label[i] = int(labels[int(index)])
      test_name_list = test_name[each_site]
      index_site_new = []
      label_new = np.zeros((len(index_site) - len(test_name_list)))
      position = 0
      for x in range(len(index_site)):
        sample_name = index_site[x]
        if sample_name in test_name_list:
          c=0
        else:
          index_site_new.append(sample_name)
          label_new[position] = label[x]
          position = position + 1
      ########################################### StratifiedKFold ####################################################
      sfolder = StratifiedKFold(n_splits=k_fold,random_state=0,shuffle=True)
      group = 0
      for train, validation in sfolder.split(index_site_new,label_new):

        for i in train:
          name = index_site_new[i]
          dist_train[str(group + 1)].append(name)
        for j in validation:
          name = index_site_new[j]
          dist_validation[str(group + 1)].append(name)
        group = group+1
  
  
  data = {}
  for fold in range(1, k_fold+1):
    data[str(fold)] = []
    ################################################# feature selection #########################################################
    selector_fMRI = feature_selection_fMRI(fMRI_images, labels, dist_train[str(fold)], new_number_features_fMRI)
    selector_sMRI = feature_selection_sMRI(sMRI_features, labels, dist_train[str(fold)], new_number_features_sMRI)

    new_fMRI_data = selector_fMRI.transform(fMRI_images)
    new_sMRI_data = selector_sMRI.transform(sMRI_features)
    ################################################# combine ##########################################
    sMRI_fMRI_combine = np.concatenate((new_sMRI_data, new_fMRI_data), axis = 1)
    selector_combine = feature_selection_fMRI(sMRI_fMRI_combine, labels, dist_train[str(fold)], new_number_features_combine)
    fold_data = selector_combine.transform(sMRI_fMRI_combine)

    data[str(fold)].append(fold_data)
    data[str(fold)].append(AUTO_labels)

  ############################################### Train ###############################################################
  ############################################### Train ###############################################################
  ############################################### Train ###############################################################

  model_1 = Auto_encoder_MLP(in_c=args.auto_in, auto_1=args.auto_hid_1, auto_2=args.auto_hid_2, auto_3=args.auto_hid_3, MLP_1=args.MLP_1, MLP_2=args.MLP_2, MLP_out=args.MLP_out, dropout_rate=args.dropout_rate)
  model_2 = Auto_encoder_MLP(in_c=args.auto_in, auto_1=args.auto_hid_1, auto_2=args.auto_hid_2, auto_3=args.auto_hid_3, MLP_1=args.MLP_1, MLP_2=args.MLP_2, MLP_out=args.MLP_out, dropout_rate=args.dropout_rate)
  model_3 = Auto_encoder_MLP(in_c=args.auto_in, auto_1=args.auto_hid_1, auto_2=args.auto_hid_2, auto_3=args.auto_hid_3, MLP_1=args.MLP_1, MLP_2=args.MLP_2, MLP_out=args.MLP_out, dropout_rate=args.dropout_rate)
  model_4 = Auto_encoder_MLP(in_c=args.auto_in, auto_1=args.auto_hid_1, auto_2=args.auto_hid_2, auto_3=args.auto_hid_3, MLP_1=args.MLP_1, MLP_2=args.MLP_2, MLP_out=args.MLP_out, dropout_rate=args.dropout_rate)
  model_5 = Auto_encoder_MLP(in_c=args.auto_in, auto_1=args.auto_hid_1, auto_2=args.auto_hid_2, auto_3=args.auto_hid_3, MLP_1=args.MLP_1, MLP_2=args.MLP_2, MLP_out=args.MLP_out, dropout_rate=args.dropout_rate)

  gpu_ids = range(args.ngpu)
  model_1 = nn.parallel.DataParallel(model_1, device_ids=gpu_ids)
  model_2 = nn.parallel.DataParallel(model_2, device_ids=gpu_ids)
  model_3 = nn.parallel.DataParallel(model_3, device_ids=gpu_ids)
  model_4 = nn.parallel.DataParallel(model_4, device_ids=gpu_ids)
  model_5 = nn.parallel.DataParallel(model_5, device_ids=gpu_ids)
  train = train_AUTO

  print('  + Number of params: {}'.format(
      sum([p.data.nelement() for p in model_1.parameters()])))
  if args.cuda:
      model_1 = model_1.cuda()
      model_2 = model_2.cuda()
      model_3 = model_3.cuda()
      model_4 = model_4.cuda()
      model_5 = model_5.cuda()

  optimizer_1 = optim.Adam(model_1.parameters(), lr = args.lr)
  optimizer_2 = optim.Adam(model_2.parameters(), lr = args.lr)
  optimizer_3 = optim.Adam(model_3.parameters(), lr = args.lr)
  optimizer_4 = optim.Adam(model_4.parameters(), lr = args.lr)
  optimizer_5 = optim.Adam(model_5.parameters(), lr = args.lr)

  Train_accuracy_list =[]
  Train_loss_list = []
  Val_accuracy_list =[]
  Val_loss_list = []
  Test_accuracy_list =[]
  Test_loss_list = []
  best_validation_accuracy = 0

  for epoch in range(1, args.nEpochs + 1):


    model_1, train_target_1, train_out_1, train_loss_1, val_target_1, val_out_1, val_loss_1, test_target_1, test_out_1, test_prob_1, test_loss_1 = train(args, model_1, data['1'], dist_train['1'], dist_validation['1'], dist_test['1'], optimizer_1)
    model_2, train_target_2, train_out_2, train_loss_2, val_target_2, val_out_2, val_loss_2, test_target_2, test_out_2, test_prob_2, test_loss_2 = train(args, model_2, data['2'], dist_train['2'], dist_validation['2'], dist_test['2'], optimizer_2)
    model_3, train_target_3, train_out_3, train_loss_3, val_target_3, val_out_3, val_loss_3, test_target_3, test_out_3, test_prob_3, test_loss_3 = train(args, model_3, data['3'], dist_train['3'], dist_validation['3'], dist_test['3'], optimizer_3)
    model_4, train_target_4, train_out_4, train_loss_4, val_target_4, val_out_4, val_loss_4, test_target_4, test_out_4, test_prob_4, test_loss_4 = train(args, model_4, data['4'], dist_train['4'], dist_validation['4'], dist_test['4'], optimizer_4)
    model_5, train_target_5, train_out_5, train_loss_5, val_target_5, val_out_5, val_loss_5, test_target_5, test_out_5, test_prob_5, test_loss_5 = train(args, model_5, data['5'], dist_train['5'], dist_validation['5'], dist_test['5'], optimizer_5)

    train_target_all = np.concatenate((train_target_1, train_target_2, train_target_3, train_target_4, train_target_5),axis = 0)
    train_out_all = np.concatenate((train_out_1, train_out_2, train_out_3, train_out_4, train_out_5),axis = 0)
    train_loss = (train_loss_1 + train_loss_2 + train_loss_3 + train_loss_4 + train_loss_5)/5
    val_target_all = np.concatenate((val_target_1, val_target_2, val_target_3, val_target_4, val_target_5),axis = 0)
    val_out_all = np.concatenate((val_out_1, val_out_2, val_out_3, val_out_4, val_out_5),axis = 0)
    val_loss = (val_loss_1 + val_loss_2 + val_loss_3 + val_loss_4 + val_loss_5)/5
    test_target_all = test_target_1 # test_target_1 = test_target_2 = test_target_3 = test_target_4 = test_target_5
    test_out_all = test_out_1 + test_out_2 + test_out_3 + test_out_4 + test_out_5
    test_prob_all = (test_prob_1 + test_prob_2 + test_prob_3 + test_prob_4 + test_prob_5)/5
    test_loss = (test_loss_1 + test_loss_2 + test_loss_3 + test_loss_4 + test_loss_5)/5

    test_results_binary = np.zeros_like((test_out_all))
    test_results_binary[test_out_all<2.5] = 0
    test_results_binary[test_out_all>=2.5] = 1

    train_accuracy = metrics.accuracy_score(train_target_all, train_out_all)
    val_accuracy = metrics.accuracy_score(val_target_all, val_out_all)
    test_accuracy = metrics.accuracy_score(test_target_all, test_results_binary)
    Train_accuracy_list.append(train_accuracy)
    Val_accuracy_list.append(val_accuracy)
    Test_accuracy_list.append(test_accuracy)
    Train_loss_list.append(train_loss)
    Val_loss_list.append(val_loss)
    Test_loss_list.append(test_loss)

    if val_accuracy >=best_validation_accuracy:
      best_epoch = epoch
      best_validation_accuracy = val_accuracy
      corresponding_test_accuracy = test_accuracy
      corresponding_test_prob = test_prob_all
      corresponding_test_labels = test_target_all
      corresponding_test_out = test_results_binary
      print('Save models')

      save_model(model_1, save_ensemble_models_path, 'AUTO_ensemble' + str(ensemble_fold) + '_1')
      save_model(model_2, save_ensemble_models_path, 'AUTO_ensemble' + str(ensemble_fold) + '_2')
      save_model(model_3, save_ensemble_models_path, 'AUTO_ensemble' + str(ensemble_fold) + '_3')
      save_model(model_4, save_ensemble_models_path, 'AUTO_ensemble' + str(ensemble_fold) + '_4')
      save_model(model_5, save_ensemble_models_path, 'AUTO_ensemble' + str(ensemble_fold) + '_5')

    print('Train Epoch: ' + str(epoch) + ': train loss : {:.8f}\t train accuracy : {:.8f}\t val accuracy : {:.8f}\t test accuracy : {:.8f}\t'.format(
      train_loss, train_accuracy, val_accuracy, test_accuracy))

  x_axis = list(range(1, len(Train_accuracy_list)+1))
  plt.figure(figsize=(15,10))
  plt.plot(x_axis, Train_loss_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_loss_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_loss_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()

  plt.figure(figsize=(15,10))
  plt.plot(x_axis, Train_accuracy_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_accuracy_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_accuracy_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()
 
  test_fpr, test_tpr, te_thresholds = roc_curve(corresponding_test_labels, corresponding_test_prob[:,1],pos_label=1)
  test_auc = auc(test_fpr, test_tpr)
  print('\n')
  print('In ensemble ',ensemble_fold+1)
  print('The best validaiton accuracy is: ',best_validation_accuracy)
  print('Happened at epoch: ',best_epoch)
  print('The corresponding test accuracy', corresponding_test_accuracy)
  print('The corresponding test AUC is: ',test_auc)
  print('\n')


  plt.grid()
  plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
  plt.plot([0,1],[0,1],'g--')
  plt.legend()
  plt.xlabel("False Positive Rate")
  plt.ylabel("True Positive Rate")
  plt.title("Test AUC(ROC curve)")
  plt.grid(color='black', linestyle='-', linewidth=0.5)
  plt.show()


  dist_ensemble_test_label[str(ensemble_fold+1)] = corresponding_test_labels
  dist_ensemble_test_result[str(ensemble_fold+1)] = corresponding_test_out
  dist_ensemble_test_prob[str(ensemble_fold+1)] = corresponding_test_prob
  print('\n')

  torch.cuda.empty_cache()

test_labels_concat = np.concatenate((dist_ensemble_test_label['1'], dist_ensemble_test_label['2'],  dist_ensemble_test_label['3'], dist_ensemble_test_label['4'], dist_ensemble_test_label['5']),axis = 0)
test_results_concat = np.concatenate((dist_ensemble_test_result['1'], dist_ensemble_test_result['2'],  dist_ensemble_test_result['3'], dist_ensemble_test_result['4'], dist_ensemble_test_result['5']),axis = 0)
test_probs_concat = np.concatenate((dist_ensemble_test_prob['1'], dist_ensemble_test_prob['2'],  dist_ensemble_test_prob['3'], dist_ensemble_test_prob['4'], dist_ensemble_test_prob['5']),axis = 0)

test_accuracy = metrics.accuracy_score(test_labels_concat, test_results_concat)
test_fpr, test_tpr, te_thresholds = roc_curve(test_labels_concat, test_probs_concat[:,1],pos_label=1)
test_auc = auc(test_fpr, test_tpr)
print('The Max voting test accuracy is: ',test_accuracy)
print('The test AUC is: ',test_auc)

print('\n')
print('\n')
plt.grid()
plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
plt.plot([0,1],[0,1],'g--')
plt.legend()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Test AUC(ROC curve)")
plt.grid(color='black', linestyle='-', linewidth=0.5)
plt.show()
# Out:
# Ensemble  1
# Fitting estimator with 19900 features.
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 6435 features.
# Fitting estimator with 6335 features.
# Fitting estimator with 6235 features.
# Fitting estimator with 6135 features.
# Fitting estimator with 6035 features.
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 6435 features.
# Fitting estimator with 6335 features.
# Fitting estimator with 6235 features.
# Fitting estimator with 6135 features.
# Fitting estimator with 6035 features.
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 6435 features.
# Fitting estimator with 6335 features.
# Fitting estimator with 6235 features.
# Fitting estimator with 6135 features.
# Fitting estimator with 6035 features.
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 6435 features.
# Fitting estimator with 6335 features.
# Fitting estimator with 6235 features.
# Fitting estimator with 6135 features.
# Fitting estimator with 6035 features.
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 6435 features.
# Fitting estimator with 6335 features.
# Fitting estimator with 6235 features.
# Fitting estimator with 6135 features.
# Fitting estimator with 6035 features.
#   + Number of params: 5501900
# Save models
# Train Epoch: 1: train loss : 1.58323953	 train accuracy : 0.47345455	 val accuracy : 0.51449275	 test accuracy : 0.49450549
# Train Epoch: 2: train loss : 1.55424860	 train accuracy : 0.49345455	 val accuracy : 0.50869565	 test accuracy : 0.48901099
# Train Epoch: 3: train loss : 1.55236015	 train accuracy : 0.50618182	 val accuracy : 0.50289855	 test accuracy : 0.50000000
# Train Epoch: 4: train loss : 1.53659220	 train accuracy : 0.50000000	 val accuracy : 0.51014493	 test accuracy : 0.48901099
# Train Epoch: 5: train loss : 1.52768722	 train accuracy : 0.51309091	 val accuracy : 0.51014493	 test accuracy : 0.50000000
# Train Epoch: 6: train loss : 1.52448740	 train accuracy : 0.52909091	 val accuracy : 0.50000000	 test accuracy : 0.53296703
# Save models
# Train Epoch: 7: train loss : 1.51465483	 train accuracy : 0.55854545	 val accuracy : 0.53478261	 test accuracy : 0.53296703
# Save models
# Train Epoch: 8: train loss : 1.49701140	 train accuracy : 0.60727273	 val accuracy : 0.57391304	 test accuracy : 0.64285714
# Save models
# Train Epoch: 9: train loss : 1.48106320	 train accuracy : 0.62836364	 val accuracy : 0.61014493	 test accuracy : 0.68681319
# Save models
# Train Epoch: 10: train loss : 1.45006249	 train accuracy : 0.67309091	 val accuracy : 0.61304348	 test accuracy : 0.67582418
# Save models
# Train Epoch: 11: train loss : 1.42378781	 train accuracy : 0.71672727	 val accuracy : 0.62028986	 test accuracy : 0.63186813
# Save models
# Train Epoch: 12: train loss : 1.39213555	 train accuracy : 0.74472727	 val accuracy : 0.63913043	 test accuracy : 0.64285714
# Train Epoch: 13: train loss : 1.36992254	 train accuracy : 0.75054545	 val accuracy : 0.63043478	 test accuracy : 0.64835165
# Train Epoch: 14: train loss : 1.32644775	 train accuracy : 0.79054545	 val accuracy : 0.61884058	 test accuracy : 0.65384615
# Save models
# Train Epoch: 15: train loss : 1.31164136	 train accuracy : 0.79345455	 val accuracy : 0.64492754	 test accuracy : 0.69230769
# Save models
# Train Epoch: 16: train loss : 1.27492738	 train accuracy : 0.83890909	 val accuracy : 0.64637681	 test accuracy : 0.70879121
# Train Epoch: 17: train loss : 1.25525687	 train accuracy : 0.85018182	 val accuracy : 0.62753623	 test accuracy : 0.72527473
# Train Epoch: 18: train loss : 1.23313661	 train accuracy : 0.86109091	 val accuracy : 0.62608696	 test accuracy : 0.72527473
# Train Epoch: 19: train loss : 1.22580786	 train accuracy : 0.86763636	 val accuracy : 0.62608696	 test accuracy : 0.74725275
# Train Epoch: 20: train loss : 1.20082493	 train accuracy : 0.86763636	 val accuracy : 0.63623188	 test accuracy : 0.71428571
# Train Epoch: 21: train loss : 1.18282263	 train accuracy : 0.87309091	 val accuracy : 0.62463768	 test accuracy : 0.71978022
# Train Epoch: 22: train loss : 1.20163128	 train accuracy : 0.85890909	 val accuracy : 0.62753623	 test accuracy : 0.69780220
# Train Epoch: 23: train loss : 1.17180455	 train accuracy : 0.86836364	 val accuracy : 0.64347826	 test accuracy : 0.71978022
# Save models
# Train Epoch: 24: train loss : 1.16482112	 train accuracy : 0.87090909	 val accuracy : 0.65797101	 test accuracy : 0.71978022
# Train Epoch: 25: train loss : 1.13824242	 train accuracy : 0.87854545	 val accuracy : 0.62753623	 test accuracy : 0.74175824
# Train Epoch: 26: train loss : 1.14902203	 train accuracy : 0.86545455	 val accuracy : 0.63043478	 test accuracy : 0.72527473
# Train Epoch: 27: train loss : 1.13181204	 train accuracy : 0.87309091	 val accuracy : 0.63768116	 test accuracy : 0.71978022
# Train Epoch: 28: train loss : 1.13075204	 train accuracy : 0.87818182	 val accuracy : 0.65072464	 test accuracy : 0.70879121
# Train Epoch: 29: train loss : 1.12485731	 train accuracy : 0.87527273	 val accuracy : 0.64927536	 test accuracy : 0.71978022
# Train Epoch: 30: train loss : 1.12701906	 train accuracy : 0.87418182	 val accuracy : 0.64782609	 test accuracy : 0.73626374
# Train Epoch: 31: train loss : 1.10346910	 train accuracy : 0.88036364	 val accuracy : 0.64202899	 test accuracy : 0.72527473
# Train Epoch: 32: train loss : 1.11591797	 train accuracy : 0.87309091	 val accuracy : 0.65507246	 test accuracy : 0.71428571
# Save models
# Train Epoch: 33: train loss : 1.08799633	 train accuracy : 0.87927273	 val accuracy : 0.66231884	 test accuracy : 0.70329670
# Train Epoch: 34: train loss : 1.09231431	 train accuracy : 0.87854545	 val accuracy : 0.65652174	 test accuracy : 0.70879121
# Train Epoch: 35: train loss : 1.08574865	 train accuracy : 0.87818182	 val accuracy : 0.65652174	 test accuracy : 0.72527473
# Train Epoch: 36: train loss : 1.08487422	 train accuracy : 0.87745455	 val accuracy : 0.64927536	 test accuracy : 0.74175824
# Train Epoch: 37: train loss : 1.07675962	 train accuracy : 0.87927273	 val accuracy : 0.63913043	 test accuracy : 0.74175824
# Train Epoch: 38: train loss : 1.08888425	 train accuracy : 0.87163636	 val accuracy : 0.65072464	 test accuracy : 0.73076923
# Train Epoch: 39: train loss : 1.07200800	 train accuracy : 0.87927273	 val accuracy : 0.64927536	 test accuracy : 0.71428571
# Train Epoch: 40: train loss : 1.06803790	 train accuracy : 0.87963636	 val accuracy : 0.64347826	 test accuracy : 0.71428571
# Train Epoch: 41: train loss : 1.10578614	 train accuracy : 0.87490909	 val accuracy : 0.65362319	 test accuracy : 0.73626374
# Train Epoch: 42: train loss : 1.05397358	 train accuracy : 0.88218182	 val accuracy : 0.64347826	 test accuracy : 0.74725275
# Train Epoch: 43: train loss : 1.10532483	 train accuracy : 0.87018182	 val accuracy : 0.63768116	 test accuracy : 0.73076923
# Train Epoch: 44: train loss : 1.05873443	 train accuracy : 0.87890909	 val accuracy : 0.64782609	 test accuracy : 0.73626374
# Train Epoch: 45: train loss : 1.05880128	 train accuracy : 0.87963636	 val accuracy : 0.64347826	 test accuracy : 0.72527473
# Train Epoch: 46: train loss : 1.06046553	 train accuracy : 0.87927273	 val accuracy : 0.65217391	 test accuracy : 0.73076923
# Train Epoch: 47: train loss : 1.04843299	 train accuracy : 0.87272727	 val accuracy : 0.64927536	 test accuracy : 0.73626374
# Train Epoch: 48: train loss : 1.03717830	 train accuracy : 0.88145455	 val accuracy : 0.65797101	 test accuracy : 0.71428571
# Train Epoch: 49: train loss : 1.03978785	 train accuracy : 0.88145455	 val accuracy : 0.65217391	 test accuracy : 0.71428571
# Train Epoch: 50: train loss : 1.01832489	 train accuracy : 0.88509091	 val accuracy : 0.64057971	 test accuracy : 0.74175824
# Train Epoch: 51: train loss : 1.02681065	 train accuracy : 0.89054545	 val accuracy : 0.64637681	 test accuracy : 0.73076923
# Train Epoch: 52: train loss : 1.01317112	 train accuracy : 0.89745455	 val accuracy : 0.64347826	 test accuracy : 0.74175824
# Train Epoch: 53: train loss : 1.02953542	 train accuracy : 0.89600000	 val accuracy : 0.65797101	 test accuracy : 0.74725275
# Train Epoch: 54: train loss : 1.01504254	 train accuracy : 0.90145455	 val accuracy : 0.65217391	 test accuracy : 0.74175824
# Train Epoch: 55: train loss : 1.00333377	 train accuracy : 0.91018182	 val accuracy : 0.65942029	 test accuracy : 0.73076923
# Save models
# Train Epoch: 56: train loss : 1.02237209	 train accuracy : 0.90981818	 val accuracy : 0.66231884	 test accuracy : 0.71428571
# Train Epoch: 57: train loss : 1.00210053	 train accuracy : 0.92327273	 val accuracy : 0.65072464	 test accuracy : 0.74175824
# Train Epoch: 58: train loss : 1.01489667	 train accuracy : 0.92145455	 val accuracy : 0.65217391	 test accuracy : 0.73626374
# Train Epoch: 59: train loss : 0.98690525	 train accuracy : 0.93709091	 val accuracy : 0.65797101	 test accuracy : 0.74175824
# Train Epoch: 60: train loss : 0.97219868	 train accuracy : 0.94727273	 val accuracy : 0.65217391	 test accuracy : 0.75824176
# Train Epoch: 61: train loss : 0.95237244	 train accuracy : 0.95236364	 val accuracy : 0.65362319	 test accuracy : 0.75274725
# Train Epoch: 62: train loss : 0.99019244	 train accuracy : 0.96000000	 val accuracy : 0.65217391	 test accuracy : 0.73076923
# Train Epoch: 63: train loss : 0.97140028	 train accuracy : 0.94909091	 val accuracy : 0.63623188	 test accuracy : 0.70329670
# Train Epoch: 64: train loss : 0.97362844	 train accuracy : 0.94654545	 val accuracy : 0.64057971	 test accuracy : 0.70329670
# Train Epoch: 65: train loss : 0.96419425	 train accuracy : 0.95709091	 val accuracy : 0.64492754	 test accuracy : 0.75824176
# Train Epoch: 66: train loss : 0.94726002	 train accuracy : 0.96109091	 val accuracy : 0.64347826	 test accuracy : 0.75824176
# Train Epoch: 67: train loss : 0.96069779	 train accuracy : 0.96290909	 val accuracy : 0.64202899	 test accuracy : 0.71978022
# Train Epoch: 68: train loss : 0.94373271	 train accuracy : 0.96327273	 val accuracy : 0.64637681	 test accuracy : 0.76373626
# Train Epoch: 69: train loss : 0.95615865	 train accuracy : 0.96509091	 val accuracy : 0.64927536	 test accuracy : 0.76923077
# Train Epoch: 70: train loss : 0.93617108	 train accuracy : 0.96836364	 val accuracy : 0.65072464	 test accuracy : 0.73626374
# Train Epoch: 71: train loss : 0.92628518	 train accuracy : 0.96472727	 val accuracy : 0.66086957	 test accuracy : 0.74175824
# Save models
# Train Epoch: 72: train loss : 0.95156076	 train accuracy : 0.95854545	 val accuracy : 0.66521739	 test accuracy : 0.74725275
# Save models
# Train Epoch: 73: train loss : 0.93920506	 train accuracy : 0.96327273	 val accuracy : 0.67101449	 test accuracy : 0.72527473
# Train Epoch: 74: train loss : 0.91505475	 train accuracy : 0.97127273	 val accuracy : 0.65797101	 test accuracy : 0.74725275
# Train Epoch: 75: train loss : 0.91356945	 train accuracy : 0.97418182	 val accuracy : 0.64637681	 test accuracy : 0.75274725
# Train Epoch: 76: train loss : 0.93053402	 train accuracy : 0.96872727	 val accuracy : 0.64492754	 test accuracy : 0.75274725
# Train Epoch: 77: train loss : 0.91353142	 train accuracy : 0.97490909	 val accuracy : 0.65217391	 test accuracy : 0.75274725
# Train Epoch: 78: train loss : 0.90770202	 train accuracy : 0.97527273	 val accuracy : 0.65362319	 test accuracy : 0.76373626
# Train Epoch: 79: train loss : 0.90397567	 train accuracy : 0.97745455	 val accuracy : 0.65507246	 test accuracy : 0.74725275
# Train Epoch: 80: train loss : 0.89880602	 train accuracy : 0.97672727	 val accuracy : 0.65362319	 test accuracy : 0.73076923
# Train Epoch: 81: train loss : 0.89751484	 train accuracy : 0.97781818	 val accuracy : 0.64637681	 test accuracy : 0.73626374
# Train Epoch: 82: train loss : 0.89444897	 train accuracy : 0.97890909	 val accuracy : 0.66666667	 test accuracy : 0.73076923
# Train Epoch: 83: train loss : 0.90304575	 train accuracy : 0.97781818	 val accuracy : 0.66811594	 test accuracy : 0.72527473
# Train Epoch: 84: train loss : 0.89347929	 train accuracy : 0.97490909	 val accuracy : 0.65362319	 test accuracy : 0.75274725
# Train Epoch: 85: train loss : 0.89237889	 train accuracy : 0.97781818	 val accuracy : 0.65507246	 test accuracy : 0.74725275
# Train Epoch: 86: train loss : 0.88272781	 train accuracy : 0.98254545	 val accuracy : 0.65942029	 test accuracy : 0.73076923
# Train Epoch: 87: train loss : 0.88579983	 train accuracy : 0.97781818	 val accuracy : 0.65217391	 test accuracy : 0.74175824
# Train Epoch: 88: train loss : 0.88569975	 train accuracy : 0.97854545	 val accuracy : 0.65217391	 test accuracy : 0.74725275
# Train Epoch: 89: train loss : 0.88774987	 train accuracy : 0.97927273	 val accuracy : 0.65652174	 test accuracy : 0.74725275
# Train Epoch: 90: train loss : 0.87949661	 train accuracy : 0.98072727	 val accuracy : 0.64927536	 test accuracy : 0.74725275
# Train Epoch: 91: train loss : 0.88286947	 train accuracy : 0.98145455	 val accuracy : 0.66521739	 test accuracy : 0.74725275
# Train Epoch: 92: train loss : 0.87254438	 train accuracy : 0.98181818	 val accuracy : 0.65942029	 test accuracy : 0.74175824
# Train Epoch: 93: train loss : 0.88896282	 train accuracy : 0.97781818	 val accuracy : 0.66086957	 test accuracy : 0.73076923
# Train Epoch: 94: train loss : 0.87436165	 train accuracy : 0.98400000	 val accuracy : 0.66376812	 test accuracy : 0.75274725
# Train Epoch: 95: train loss : 0.88305063	 train accuracy : 0.97781818	 val accuracy : 0.66376812	 test accuracy : 0.73076923
# Train Epoch: 96: train loss : 0.87562296	 train accuracy : 0.98036364	 val accuracy : 0.65507246	 test accuracy : 0.73626374
# Train Epoch: 97: train loss : 0.86299183	 train accuracy : 0.98327273	 val accuracy : 0.65217391	 test accuracy : 0.72527473
# Train Epoch: 98: train loss : 0.87665718	 train accuracy : 0.97490909	 val accuracy : 0.64782609	 test accuracy : 0.72527473
# Train Epoch: 99: train loss : 0.86542608	 train accuracy : 0.98254545	 val accuracy : 0.63623188	 test accuracy : 0.72527473
# Train Epoch: 100: train loss : 0.87592008	 train accuracy : 0.97818182	 val accuracy : 0.63333333	 test accuracy : 0.73076923
# Train Epoch: 101: train loss : 0.87135366	 train accuracy : 0.98145455	 val accuracy : 0.64637681	 test accuracy : 0.74175824
# Train Epoch: 102: train loss : 0.86411574	 train accuracy : 0.98436364	 val accuracy : 0.65072464	 test accuracy : 0.73076923
# Train Epoch: 103: train loss : 0.86969047	 train accuracy : 0.98327273	 val accuracy : 0.65942029	 test accuracy : 0.74725275
# Train Epoch: 104: train loss : 0.86496744	 train accuracy : 0.97818182	 val accuracy : 0.66086957	 test accuracy : 0.74175824
# Train Epoch: 105: train loss : 0.86037159	 train accuracy : 0.98545455	 val accuracy : 0.65507246	 test accuracy : 0.73626374
# Train Epoch: 106: train loss : 0.87164872	 train accuracy : 0.98290909	 val accuracy : 0.65072464	 test accuracy : 0.74725275
# Train Epoch: 107: train loss : 0.86286891	 train accuracy : 0.98400000	 val accuracy : 0.65217391	 test accuracy : 0.74175824
# Train Epoch: 108: train loss : 0.87151898	 train accuracy : 0.97890909	 val accuracy : 0.63768116	 test accuracy : 0.71978022
# Train Epoch: 109: train loss : 0.86756239	 train accuracy : 0.97890909	 val accuracy : 0.64637681	 test accuracy : 0.71978022
# Train Epoch: 110: train loss : 0.86332352	 train accuracy : 0.97709091	 val accuracy : 0.63478261	 test accuracy : 0.72527473
# Train Epoch: 111: train loss : 0.86437676	 train accuracy : 0.97963636	 val accuracy : 0.63768116	 test accuracy : 0.74175824
# Train Epoch: 112: train loss : 0.85428362	 train accuracy : 0.98472727	 val accuracy : 0.63913043	 test accuracy : 0.73626374
# Train Epoch: 113: train loss : 0.86930915	 train accuracy : 0.97854545	 val accuracy : 0.64782609	 test accuracy : 0.73076923
# Train Epoch: 114: train loss : 0.85185478	 train accuracy : 0.98400000	 val accuracy : 0.64492754	 test accuracy : 0.74725275
# Train Epoch: 115: train loss : 0.88919936	 train accuracy : 0.97127273	 val accuracy : 0.66231884	 test accuracy : 0.74175824
# Train Epoch: 116: train loss : 0.86256424	 train accuracy : 0.98145455	 val accuracy : 0.65362319	 test accuracy : 0.75824176
# Train Epoch: 117: train loss : 0.86875479	 train accuracy : 0.98218182	 val accuracy : 0.65217391	 test accuracy : 0.76373626
# Train Epoch: 118: train loss : 0.87209839	 train accuracy : 0.97709091	 val accuracy : 0.65217391	 test accuracy : 0.76373626
# Train Epoch: 119: train loss : 0.86251549	 train accuracy : 0.98036364	 val accuracy : 0.64347826	 test accuracy : 0.74725275
# Train Epoch: 120: train loss : 0.88581092	 train accuracy : 0.97018182	 val accuracy : 0.64347826	 test accuracy : 0.75274725
# Train Epoch: 121: train loss : 0.85942069	 train accuracy : 0.97963636	 val accuracy : 0.65072464	 test accuracy : 0.76373626
# Train Epoch: 122: train loss : 0.86867945	 train accuracy : 0.97781818	 val accuracy : 0.65362319	 test accuracy : 0.74175824
# Train Epoch: 123: train loss : 0.87629869	 train accuracy : 0.97890909	 val accuracy : 0.65797101	 test accuracy : 0.74725275
# Train Epoch: 124: train loss : 0.85928568	 train accuracy : 0.98109091	 val accuracy : 0.66086957	 test accuracy : 0.74725275
# Train Epoch: 125: train loss : 0.86223609	 train accuracy : 0.98072727	 val accuracy : 0.66231884	 test accuracy : 0.75274725
# Train Epoch: 126: train loss : 0.86292790	 train accuracy : 0.98036364	 val accuracy : 0.66376812	 test accuracy : 0.75274725
# Train Epoch: 127: train loss : 0.86928701	 train accuracy : 0.98181818	 val accuracy : 0.66811594	 test accuracy : 0.75824176
# Train Epoch: 128: train loss : 0.85961587	 train accuracy : 0.97963636	 val accuracy : 0.66231884	 test accuracy : 0.75274725
# Train Epoch: 129: train loss : 0.86149358	 train accuracy : 0.97927273	 val accuracy : 0.65797101	 test accuracy : 0.74175824
# Train Epoch: 130: train loss : 0.86145219	 train accuracy : 0.97527273	 val accuracy : 0.64637681	 test accuracy : 0.73076923
# Train Epoch: 131: train loss : 0.85668300	 train accuracy : 0.97963636	 val accuracy : 0.64782609	 test accuracy : 0.71978022
# Train Epoch: 132: train loss : 0.86166871	 train accuracy : 0.97418182	 val accuracy : 0.64927536	 test accuracy : 0.73076923
# Train Epoch: 133: train loss : 0.85498115	 train accuracy : 0.98254545	 val accuracy : 0.66231884	 test accuracy : 0.73626374
# Save models
# Train Epoch: 134: train loss : 0.85656523	 train accuracy : 0.98036364	 val accuracy : 0.67391304	 test accuracy : 0.75274725
# Train Epoch: 135: train loss : 0.85502906	 train accuracy : 0.98000000	 val accuracy : 0.66521739	 test accuracy : 0.75274725
# Train Epoch: 136: train loss : 0.86272037	 train accuracy : 0.97781818	 val accuracy : 0.66956522	 test accuracy : 0.73626374
# Train Epoch: 137: train loss : 0.84472370	 train accuracy : 0.98472727	 val accuracy : 0.66666667	 test accuracy : 0.74725275
# Train Epoch: 138: train loss : 0.85276530	 train accuracy : 0.98218182	 val accuracy : 0.66521739	 test accuracy : 0.74725275
# Train Epoch: 139: train loss : 0.84676106	 train accuracy : 0.98400000	 val accuracy : 0.65942029	 test accuracy : 0.74175824
# Train Epoch: 140: train loss : 0.85247670	 train accuracy : 0.98327273	 val accuracy : 0.67246377	 test accuracy : 0.74725275
# Train Epoch: 141: train loss : 0.85222927	 train accuracy : 0.98145455	 val accuracy : 0.66376812	 test accuracy : 0.74175824
# ...
# Train Epoch: 78: train loss : 0.91743557	 train accuracy : 0.95554765	 val accuracy : 0.68705548	 test accuracy : 0.68862275
# Train Epoch: 79: train loss : 0.91459174	 train accuracy : 0.95697013	 val accuracy : 0.69274538	 test accuracy : 0.70658683
# Train Epoch: 80: train loss : 0.90928921	 train accuracy : 0.96052632	 val accuracy : 0.70697013	 test accuracy : 0.70658683
# Train Epoch: 81: train loss : 0.89370214	 train accuracy : 0.96728307	 val accuracy : 0.69559033	 test accuracy : 0.68862275
# Train Epoch: 82: train loss : 0.89336481	 train accuracy : 0.96834993	 val accuracy : 0.69274538	 test accuracy : 0.67664671
# Train Epoch: 83: train loss : 0.90110404	 train accuracy : 0.96728307	 val accuracy : 0.69274538	 test accuracy : 0.67664671
# Train Epoch: 84: train loss : 0.91361221	 train accuracy : 0.96159317	 val accuracy : 0.68705548	 test accuracy : 0.68263473
# Train Epoch: 85: train loss : 0.89642714	 train accuracy : 0.96372688	 val accuracy : 0.70128023	 test accuracy : 0.68862275
# Train Epoch: 86: train loss : 0.89083440	 train accuracy : 0.96657183	 val accuracy : 0.69559033	 test accuracy : 0.67664671
# Train Epoch: 87: train loss : 0.90278521	 train accuracy : 0.96052632	 val accuracy : 0.69559033	 test accuracy : 0.68862275
# Train Epoch: 88: train loss : 0.90288402	 train accuracy : 0.96479374	 val accuracy : 0.69701280	 test accuracy : 0.70059880
# Train Epoch: 89: train loss : 0.89439552	 train accuracy : 0.96443812	 val accuracy : 0.70981508	 test accuracy : 0.71257485
# Train Epoch: 90: train loss : 0.88976793	 train accuracy : 0.96230441	 val accuracy : 0.71408250	 test accuracy : 0.70059880
# Train Epoch: 91: train loss : 0.88167053	 train accuracy : 0.97297297	 val accuracy : 0.70839260	 test accuracy : 0.68263473
# Train Epoch: 92: train loss : 0.88728179	 train accuracy : 0.96337127	 val accuracy : 0.70697013	 test accuracy : 0.65868263
# Train Epoch: 93: train loss : 0.89383931	 train accuracy : 0.96301565	 val accuracy : 0.71408250	 test accuracy : 0.70658683
# Save models
# Train Epoch: 94: train loss : 0.88225188	 train accuracy : 0.96692745	 val accuracy : 0.71834993	 test accuracy : 0.71257485
# Train Epoch: 95: train loss : 0.86581694	 train accuracy : 0.97439545	 val accuracy : 0.71692745	 test accuracy : 0.71856287
# Train Epoch: 96: train loss : 0.87019395	 train accuracy : 0.97190612	 val accuracy : 0.71408250	 test accuracy : 0.73053892
# Train Epoch: 97: train loss : 0.87437903	 train accuracy : 0.96692745	 val accuracy : 0.70697013	 test accuracy : 0.72455090
# Train Epoch: 98: train loss : 0.87854968	 train accuracy : 0.96586060	 val accuracy : 0.70839260	 test accuracy : 0.73053892
# Train Epoch: 99: train loss : 0.87466273	 train accuracy : 0.96550498	 val accuracy : 0.70412518	 test accuracy : 0.72455090
# Train Epoch: 100: train loss : 0.86829008	 train accuracy : 0.96337127	 val accuracy : 0.70412518	 test accuracy : 0.71257485
# Train Epoch: 101: train loss : 0.86761224	 train accuracy : 0.96586060	 val accuracy : 0.69559033	 test accuracy : 0.70059880
# Train Epoch: 102: train loss : 0.86115634	 train accuracy : 0.96870555	 val accuracy : 0.69416785	 test accuracy : 0.70658683
# Train Epoch: 103: train loss : 0.86291803	 train accuracy : 0.96692745	 val accuracy : 0.69132290	 test accuracy : 0.70059880
# Train Epoch: 104: train loss : 0.85960282	 train accuracy : 0.97190612	 val accuracy : 0.69559033	 test accuracy : 0.70059880
# Train Epoch: 105: train loss : 0.86586308	 train accuracy : 0.96728307	 val accuracy : 0.69843528	 test accuracy : 0.70658683
# Train Epoch: 106: train loss : 0.85897410	 train accuracy : 0.96977240	 val accuracy : 0.69701280	 test accuracy : 0.70059880
# Train Epoch: 107: train loss : 0.85324281	 train accuracy : 0.97190612	 val accuracy : 0.69701280	 test accuracy : 0.71856287
# Train Epoch: 108: train loss : 0.85620310	 train accuracy : 0.97048364	 val accuracy : 0.69274538	 test accuracy : 0.70658683
# Train Epoch: 109: train loss : 0.85900646	 train accuracy : 0.96906117	 val accuracy : 0.68990043	 test accuracy : 0.70658683
# Train Epoch: 110: train loss : 0.88190937	 train accuracy : 0.96194879	 val accuracy : 0.69985775	 test accuracy : 0.71257485
# Train Epoch: 111: train loss : 0.85051489	 train accuracy : 0.96799431	 val accuracy : 0.70270270	 test accuracy : 0.71257485
# Train Epoch: 112: train loss : 0.86322638	 train accuracy : 0.96763869	 val accuracy : 0.68705548	 test accuracy : 0.71856287
# Train Epoch: 113: train loss : 0.87418336	 train accuracy : 0.96550498	 val accuracy : 0.69701280	 test accuracy : 0.70059880
# Train Epoch: 114: train loss : 0.85155302	 train accuracy : 0.97083926	 val accuracy : 0.70128023	 test accuracy : 0.71257485
# Train Epoch: 115: train loss : 0.85097684	 train accuracy : 0.96870555	 val accuracy : 0.69985775	 test accuracy : 0.71257485
# Train Epoch: 116: train loss : 0.84906703	 train accuracy : 0.97261735	 val accuracy : 0.69701280	 test accuracy : 0.73053892
# Train Epoch: 117: train loss : 0.85683386	 train accuracy : 0.97083926	 val accuracy : 0.69843528	 test accuracy : 0.73053892
# Train Epoch: 118: train loss : 0.87317433	 train accuracy : 0.96052632	 val accuracy : 0.69701280	 test accuracy : 0.71856287
# Train Epoch: 119: train loss : 0.84798137	 train accuracy : 0.97759602	 val accuracy : 0.69274538	 test accuracy : 0.70658683
# Train Epoch: 120: train loss : 0.84843639	 train accuracy : 0.97901849	 val accuracy : 0.68705548	 test accuracy : 0.70059880
# Train Epoch: 121: train loss : 0.87187768	 train accuracy : 0.97226174	 val accuracy : 0.68563300	 test accuracy : 0.70059880
# Train Epoch: 122: train loss : 0.86022961	 train accuracy : 0.97724040	 val accuracy : 0.69701280	 test accuracy : 0.69461078
# Train Epoch: 123: train loss : 0.85310470	 train accuracy : 0.97724040	 val accuracy : 0.70697013	 test accuracy : 0.71257485
# Train Epoch: 124: train loss : 0.84765925	 train accuracy : 0.98293030	 val accuracy : 0.71123755	 test accuracy : 0.72455090
# Train Epoch: 125: train loss : 0.84117546	 train accuracy : 0.98044097	 val accuracy : 0.70412518	 test accuracy : 0.73053892
# Train Epoch: 126: train loss : 0.84715701	 train accuracy : 0.97652916	 val accuracy : 0.70128023	 test accuracy : 0.73652695
# Train Epoch: 127: train loss : 0.85244375	 train accuracy : 0.97297297	 val accuracy : 0.69985775	 test accuracy : 0.71257485
# Train Epoch: 128: train loss : 0.85675406	 train accuracy : 0.97510669	 val accuracy : 0.70554765	 test accuracy : 0.70658683
# Train Epoch: 129: train loss : 0.85157571	 train accuracy : 0.97759602	 val accuracy : 0.70554765	 test accuracy : 0.70059880
# Train Epoch: 130: train loss : 0.84144976	 train accuracy : 0.97795164	 val accuracy : 0.70839260	 test accuracy : 0.70658683
# Train Epoch: 131: train loss : 0.85369393	 train accuracy : 0.97652916	 val accuracy : 0.70839260	 test accuracy : 0.70658683
# Train Epoch: 132: train loss : 0.83835696	 train accuracy : 0.98221906	 val accuracy : 0.70554765	 test accuracy : 0.70658683
# Train Epoch: 133: train loss : 0.83648565	 train accuracy : 0.98150782	 val accuracy : 0.70697013	 test accuracy : 0.71257485
# Train Epoch: 134: train loss : 0.84219892	 train accuracy : 0.98079659	 val accuracy : 0.70981508	 test accuracy : 0.71856287
# Train Epoch: 135: train loss : 0.85145932	 train accuracy : 0.97759602	 val accuracy : 0.70697013	 test accuracy : 0.71856287
# Train Epoch: 136: train loss : 0.83693581	 train accuracy : 0.98186344	 val accuracy : 0.71123755	 test accuracy : 0.71257485
# Train Epoch: 137: train loss : 0.83870553	 train accuracy : 0.97830725	 val accuracy : 0.71123755	 test accuracy : 0.70658683
# Train Epoch: 138: train loss : 0.83874536	 train accuracy : 0.98079659	 val accuracy : 0.69843528	 test accuracy : 0.71257485
# Train Epoch: 139: train loss : 0.83992071	 train accuracy : 0.97901849	 val accuracy : 0.69843528	 test accuracy : 0.72455090
# Train Epoch: 140: train loss : 0.83902378	 train accuracy : 0.97724040	 val accuracy : 0.70270270	 test accuracy : 0.71257485
# Train Epoch: 141: train loss : 0.84226513	 train accuracy : 0.97759602	 val accuracy : 0.70412518	 test accuracy : 0.71257485
# Train Epoch: 142: train loss : 0.83119235	 train accuracy : 0.98399716	 val accuracy : 0.70412518	 test accuracy : 0.70658683
# Train Epoch: 143: train loss : 0.83884543	 train accuracy : 0.97937411	 val accuracy : 0.70412518	 test accuracy : 0.71257485
# Train Epoch: 144: train loss : 0.82774433	 train accuracy : 0.98257468	 val accuracy : 0.70128023	 test accuracy : 0.70059880
# Train Epoch: 145: train loss : 0.83629889	 train accuracy : 0.97688478	 val accuracy : 0.70270270	 test accuracy : 0.70059880
# Train Epoch: 146: train loss : 0.83424773	 train accuracy : 0.97866287	 val accuracy : 0.70128023	 test accuracy : 0.70658683
# Train Epoch: 147: train loss : 0.83493403	 train accuracy : 0.97795164	 val accuracy : 0.70412518	 test accuracy : 0.71257485
# Train Epoch: 148: train loss : 0.83550402	 train accuracy : 0.97937411	 val accuracy : 0.69985775	 test accuracy : 0.71257485
# Train Epoch: 149: train loss : 0.83411336	 train accuracy : 0.98044097	 val accuracy : 0.69843528	 test accuracy : 0.71257485
# Train Epoch: 150: train loss : 0.83679624	 train accuracy : 0.97403983	 val accuracy : 0.69985775	 test accuracy : 0.71856287
# Train Epoch: 151: train loss : 0.83867363	 train accuracy : 0.97937411	 val accuracy : 0.69843528	 test accuracy : 0.70658683
# Train Epoch: 152: train loss : 0.83451231	 train accuracy : 0.98044097	 val accuracy : 0.70270270	 test accuracy : 0.70658683
# Train Epoch: 153: train loss : 0.83880956	 train accuracy : 0.97759602	 val accuracy : 0.69985775	 test accuracy : 0.70658683
# Train Epoch: 154: train loss : 0.83764579	 train accuracy : 0.97937411	 val accuracy : 0.69701280	 test accuracy : 0.70059880
# Train Epoch: 155: train loss : 0.82898767	 train accuracy : 0.98257468	 val accuracy : 0.70270270	 test accuracy : 0.70059880
# Train Epoch: 156: train loss : 0.83628949	 train accuracy : 0.97510669	 val accuracy : 0.70412518	 test accuracy : 0.70059880
# Train Epoch: 157: train loss : 0.83566744	 train accuracy : 0.97475107	 val accuracy : 0.70554765	 test accuracy : 0.69461078
# Train Epoch: 158: train loss : 0.83823315	 train accuracy : 0.97724040	 val accuracy : 0.70554765	 test accuracy : 0.69461078
# Train Epoch: 159: train loss : 0.83553971	 train accuracy : 0.97617354	 val accuracy : 0.70412518	 test accuracy : 0.68862275
# Train Epoch: 160: train loss : 0.83190651	 train accuracy : 0.97688478	 val accuracy : 0.69701280	 test accuracy : 0.68862275
# Train Epoch: 161: train loss : 0.83058542	 train accuracy : 0.97937411	 val accuracy : 0.69274538	 test accuracy : 0.71257485
# Train Epoch: 162: train loss : 0.83538821	 train accuracy : 0.97510669	 val accuracy : 0.70412518	 test accuracy : 0.69461078
# Train Epoch: 163: train loss : 0.82401136	 train accuracy : 0.98186344	 val accuracy : 0.70270270	 test accuracy : 0.70059880
# Train Epoch: 164: train loss : 0.83141576	 train accuracy : 0.97972973	 val accuracy : 0.69843528	 test accuracy : 0.69461078
# Train Epoch: 165: train loss : 0.83401495	 train accuracy : 0.97617354	 val accuracy : 0.70270270	 test accuracy : 0.69461078
# Train Epoch: 166: train loss : 0.83031510	 train accuracy : 0.97652916	 val accuracy : 0.70839260	 test accuracy : 0.70059880
# Train Epoch: 167: train loss : 0.82485690	 train accuracy : 0.98186344	 val accuracy : 0.70697013	 test accuracy : 0.69461078
# Train Epoch: 168: train loss : 0.82622190	 train accuracy : 0.97972973	 val accuracy : 0.69843528	 test accuracy : 0.68862275
# Train Epoch: 169: train loss : 0.82998056	 train accuracy : 0.97866287	 val accuracy : 0.69843528	 test accuracy : 0.68862275
# Train Epoch: 170: train loss : 0.83213975	 train accuracy : 0.97795164	 val accuracy : 0.70128023	 test accuracy : 0.69461078
# Train Epoch: 171: train loss : 0.82655684	 train accuracy : 0.97581792	 val accuracy : 0.69843528	 test accuracy : 0.68862275
# Train Epoch: 172: train loss : 0.82462702	 train accuracy : 0.97901849	 val accuracy : 0.69843528	 test accuracy : 0.68862275
# Train Epoch: 173: train loss : 0.83050693	 train accuracy : 0.97652916	 val accuracy : 0.69274538	 test accuracy : 0.70059880
# Train Epoch: 174: train loss : 0.82751385	 train accuracy : 0.97724040	 val accuracy : 0.69132290	 test accuracy : 0.68862275
# Train Epoch: 175: train loss : 0.82058227	 train accuracy : 0.98115220	 val accuracy : 0.69416785	 test accuracy : 0.68263473
# Train Epoch: 176: train loss : 0.82686858	 train accuracy : 0.97759602	 val accuracy : 0.69559033	 test accuracy : 0.68263473
# Train Epoch: 177: train loss : 0.81959515	 train accuracy : 0.98257468	 val accuracy : 0.69559033	 test accuracy : 0.68263473
# Train Epoch: 178: train loss : 0.82209935	 train accuracy : 0.98008535	 val accuracy : 0.69274538	 test accuracy : 0.68862275
# Train Epoch: 179: train loss : 0.82083719	 train accuracy : 0.98257468	 val accuracy : 0.69559033	 test accuracy : 0.69461078
# Train Epoch: 180: train loss : 0.82138481	 train accuracy : 0.97688478	 val accuracy : 0.69701280	 test accuracy : 0.71257485
# Train Epoch: 181: train loss : 0.81459026	 train accuracy : 0.98257468	 val accuracy : 0.70270270	 test accuracy : 0.71257485
# Train Epoch: 182: train loss : 0.82037703	 train accuracy : 0.97795164	 val accuracy : 0.70270270	 test accuracy : 0.71257485
# Train Epoch: 183: train loss : 0.82057314	 train accuracy : 0.97688478	 val accuracy : 0.70270270	 test accuracy : 0.70658683
# Train Epoch: 184: train loss : 0.81807215	 train accuracy : 0.98008535	 val accuracy : 0.70839260	 test accuracy : 0.70658683
# Train Epoch: 185: train loss : 0.81566179	 train accuracy : 0.97901849	 val accuracy : 0.70554765	 test accuracy : 0.71856287
# Train Epoch: 186: train loss : 0.82047713	 train accuracy : 0.97546230	 val accuracy : 0.70412518	 test accuracy : 0.71856287
# Train Epoch: 187: train loss : 0.81928083	 train accuracy : 0.97724040	 val accuracy : 0.70697013	 test accuracy : 0.71856287
# Train Epoch: 188: train loss : 0.81475899	 train accuracy : 0.98186344	 val accuracy : 0.70412518	 test accuracy : 0.71856287
# Train Epoch: 189: train loss : 0.81572248	 train accuracy : 0.97759602	 val accuracy : 0.70554765	 test accuracy : 0.71257485
# Train Epoch: 190: train loss : 0.81580315	 train accuracy : 0.97830725	 val accuracy : 0.70839260	 test accuracy : 0.71257485
# Train Epoch: 191: train loss : 0.82186033	 train accuracy : 0.97759602	 val accuracy : 0.70697013	 test accuracy : 0.71257485
# Train Epoch: 192: train loss : 0.81262933	 train accuracy : 0.98079659	 val accuracy : 0.70697013	 test accuracy : 0.70059880
# Train Epoch: 193: train loss : 0.80888318	 train accuracy : 0.98186344	 val accuracy : 0.70128023	 test accuracy : 0.70059880
# Train Epoch: 194: train loss : 0.81013517	 train accuracy : 0.98115220	 val accuracy : 0.70128023	 test accuracy : 0.70059880
# Train Epoch: 195: train loss : 0.80898764	 train accuracy : 0.98257468	 val accuracy : 0.70270270	 test accuracy : 0.70059880
# Train Epoch: 196: train loss : 0.82273058	 train accuracy : 0.97439545	 val accuracy : 0.70554765	 test accuracy : 0.69461078
# Train Epoch: 197: train loss : 0.81186020	 train accuracy : 0.97937411	 val accuracy : 0.70412518	 test accuracy : 0.68263473
# Train Epoch: 198: train loss : 0.81293977	 train accuracy : 0.98150782	 val accuracy : 0.70128023	 test accuracy : 0.68263473
# Train Epoch: 199: train loss : 0.81366968	 train accuracy : 0.97795164	 val accuracy : 0.70128023	 test accuracy : 0.70059880
# Train Epoch: 200: train loss : 0.80952857	 train accuracy : 0.98293030	 val accuracy : 0.69985775	 test accuracy : 0.69461078
# In ensemble  5
# The best validaiton accuracy is:  0.7183499288762447
# Happened at epoch:  94
# The corresponding test accuracy 0.7125748502994012
# The corresponding test AUC is:  0.7695652173913043
# The Max voting test accuracy is:  0.7080459770114943
# The test AUC is:  0.7691218431357962
