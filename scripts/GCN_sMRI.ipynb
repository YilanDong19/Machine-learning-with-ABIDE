# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/ABIDE/")
# Out:
# Mounted at /content/drive

# %%
# !pip install torch==1.11.0 torchvision==0.12.0 torchaudio==0.11.0
# !pip install --no-index torch-scatter -f https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# !pip install --no-index torch-sparse -f https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# !pip install --no-index torch-cluster -f https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# !pip install --no-index torch-spline-conv -f https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# !pip install torch-geometric
import torch
print(torch.__version__)  
print(torch.version.cuda)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch==1.11.0
#   Downloading torch-1.11.0-cp38-cp38-manylinux1_x86_64.whl (750.6 MB)
#      |████████████████████████████████| 750.6 MB 17 kB/s
# Collecting torchvision==0.12.0
#   Downloading torchvision-0.12.0-cp38-cp38-manylinux1_x86_64.whl (21.0 MB)
#      |████████████████████████████████| 21.0 MB 1.3 MB/s
# Collecting torchaudio==0.11.0
#   Downloading torchaudio-0.11.0-cp38-cp38-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 56.0 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch==1.11.0) (4.1.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision==0.12.0) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torchvision==0.12.0) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torchvision==0.12.0) (1.21.6)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision==0.12.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision==0.12.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision==0.12.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision==0.12.0) (2022.9.24)
# Installing collected packages: torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.1+cu113
#     Uninstalling torchvision-0.13.1+cu113:
#       Successfully uninstalled torchvision-0.13.1+cu113
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 0.12.1+cu113
#     Uninstalling torchaudio-0.12.1+cu113:
#       Successfully uninstalled torchaudio-0.12.1+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.13.1 requires torch==1.12.1, but you have torch 1.11.0 which is incompatible.
# Successfully installed torch-1.11.0 torchaudio-0.11.0 torchvision-0.12.0
# Looking in links: https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# Collecting torch-scatter
#   Downloading https://data.pyg.org/whl/torch-1.11.0%2Bcu102/torch_scatter-2.0.9-cp38-cp38-linux_x86_64.whl (8.0 MB)
#      |████████████████████████████████| 8.0 MB 2.7 MB/s
# Installing collected packages: torch-scatter
# Successfully installed torch-scatter-2.0.9
# Looking in links: https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# Collecting torch-sparse
#   Downloading https://data.pyg.org/whl/torch-1.11.0%2Bcu102/torch_sparse-0.6.15-cp38-cp38-linux_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 31.1 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from torch-sparse) (1.7.3)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /usr/local/lib/python3.8/dist-packages (from scipy->torch-sparse) (1.21.6)
# Installing collected packages: torch-sparse
# Successfully installed torch-sparse-0.6.15
# Looking in links: https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# Collecting torch-cluster
#   Downloading https://data.pyg.org/whl/torch-1.11.0%2Bcu102/torch_cluster-1.6.0-cp38-cp38-linux_x86_64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 33.2 MB/s
# Installing collected packages: torch-cluster
# Successfully installed torch-cluster-1.6.0
# Looking in links: https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# Collecting torch-spline-conv
#   Downloading https://data.pyg.org/whl/torch-1.11.0%2Bcu102/torch_spline_conv-1.2.1-cp38-cp38-linux_x86_64.whl (672 kB)
#      |████████████████████████████████| 672 kB 36.3 MB/s
# Installing collected packages: torch-spline-conv
# Successfully installed torch-spline-conv-1.2.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch-geometric
#   Downloading torch_geometric-2.2.0.tar.gz (564 kB)
#      |████████████████████████████████| 564 kB 18.8 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from torch-geometric) (4.64.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torch-geometric) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from torch-geometric) (1.7.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from torch-geometric) (2.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torch-geometric) (2.23.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.8/dist-packages (from torch-geometric) (3.0.9)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from torch-geometric) (1.0.2)
# Collecting psutil>=5.8.0
#   Downloading psutil-5.9.4-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
#      |████████████████████████████████| 280 kB 63.9 MB/s
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->torch-geometric) (2.0.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torch-geometric) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->torch-geometric) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->torch-geometric) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torch-geometric) (2022.9.24)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->torch-geometric) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->torch-geometric) (1.2.0)
# Building wheels for collected packages: torch-geometric
#   Building wheel for torch-geometric (setup.py) ... done
#   Created wheel for torch-geometric: filename=torch_geometric-2.2.0-py3-none-any.whl size=773302 sha256=da2358b0a339dcc2edc7bb8bc933f06c73a223bdaedbc9803cbf73c6b3ff6dfd
#   Stored in directory: /root/.cache/pip/wheels/59/a3/20/198928106d3169865ae73afcbd3d3d1796cf6b429b55c65378
# Successfully built torch-geometric
# Installing collected packages: psutil, torch-geometric
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
# Successfully installed psutil-5.9.4 torch-geometric-2.2.0
# 1.11.0+cu102
# 10.2

# %%
# load ComBat algorithm
# !python /content/drive/MyDrive/ABIDE/neuralCombat.py 
import sys
sys.path.append('/content/drive/MyDrive/ABIDE/')

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from neuralCombat import *
# from neuralCombat.py import neuralCombat
import pandas as pd
from sklearn import svm
import joblib
import openpyxl
from openpyxl import load_workbook
import os
import scipy.io as scio
import argparse
import numpy as np
import time
import torch
import torch.utils.data
import torch.nn as nn
import torch.optim as optim
from torch.utils.data.dataset import Dataset
from torch.autograd import Variable
from torchvision import datasets, transforms
from torchvision.utils import make_grid , save_image
import torchvision.utils as vutils
from os.path import join
from os import listdir
from torch.utils.data.dataloader import DataLoader
from torch.utils.data import DataLoader
from collections import OrderedDict
import nibabel as nib
import matplotlib.pyplot as plt
import cv2 as cv
from os import path
import shutil
import scipy.stats
import scipy.ndimage
import random
import torch.nn.init as init
import torch.nn.functional as F
import sys
import math
from functools import reduce
import operator
from scipy.interpolate import interp1d
from torch.optim import lr_scheduler
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import RidgeClassifier
from sklearn.feature_selection import RFE

def feature_selection(matrix, labels, train_ind, fnum):
    """
        matrix       : feature matrix (num_subjects x num_features)
        labels       : ground truth labels (num_subjects x 1)
        train_ind    : indices of the training samples
        fnum         : size of the feature vector after feature selection 

    return:
        x_data      : feature matrix of lower dimension (num_subjects x fnum)
    """

    estimator = RidgeClassifier()
    selector = RFE(estimator, n_features_to_select=fnum, step=100, verbose=1)

    featureX = matrix[train_ind, :]
    featureY = labels[train_ind]
    selector = selector.fit(featureX, featureY.ravel())

    return selector

def get_index(lst=None, item=''):
	return [i for i in range(len(lst)) if lst[i] == item]

def flatten_one(length, img):
	'''
	  In some situations, the dimension on z-axis of images are smaller than
	  the dimension of z-axis of patches, this function will be used to pad
	'''

	one_line = np.zeros((1, int(length)))
	position = 0
	for i in range(img.shape[0]):  # column
		for j in range(i + 1, img.shape[1]):  # row
			one_line[0, position] = img[j, i]
			position = position + 1
	return one_line


def get_ids(num_subjects=None,dir_path=''):
	"""
	return:
		subject_IDs    : list of all subject IDs
	"""
	subject_IDs = np.genfromtxt(os.path.join(dir_path, 'subject_IDs.txt'), dtype=str)

	if num_subjects is not None:
		subject_IDs = subject_IDs[:num_subjects]

	return subject_IDs

def save_model(net,path, name_net):

  # This fucntion is used to save a specific model

    path_net =  path + '/' + name_net + '.pth'
    torch.save(net.cpu().state_dict(), path_net)
    net.cuda()

def load_model(net, path, name_net):

  # This function is used to load a specific model we saved before

    path_net =  path + '/' + name_net + '.pth'
    net.load_state_dict(torch.load(path_net))

    return net

# %%
########################################### Load Data ###############################################
#####################################################################################################
#####################################################################################################
combat = True    # True or False


if combat == False:
  save_combat = '/without_ComBat/'
else:
  save_combat = '/with_ComBat/'

save_path = '/content/drive/MyDrive/ABIDE/save_models/sMRI' + save_combat
localDir = '/content/sMRI_dataset/'
if os.path.exists(localDir):
  shutil.rmtree(localDir) 
# shutil.copy('/content/drive/MyDrive/ABIDE/freesurfer_stats.7z', localDir)
os.makedirs(localDir)
# !unzip '/content/drive/MyDrive/ABIDE/freesurfer_stats.zip' -d '/content/sMRI_dataset'

label_dir = '/content/drive/MyDrive/ABIDE/phenotypic_image_quality'
localDir = localDir + 'freesurfer_stats/'

k_fold = 5
new_number_features = 1435
number_samples = 871
useless_samples = ['51334']
scaler = True

age_name = 'ages.mat'
gender_name = 'genders.mat'
label_name = 'ABIDE_label_871.mat'
label = scio.loadmat(os.path.join(label_dir, label_name))
label = label['label'][0]
labels = np.zeros(number_samples - len(useless_samples))
site_name = 'sites.mat'
site = scio.loadmat(os.path.join(label_dir, site_name))
all_sites = site['sites']
for i in range(len(all_sites)):
	site = all_sites[i]
	all_sites[i] = site.replace(' ', '')
unique_sites = np.unique(all_sites)
sites = []
unique_sites = list(unique_sites)

gender = scio.loadmat(os.path.join(label_dir, gender_name))
gender = gender['genders']
genders = np.zeros((number_samples - len(useless_samples), 1))

age = scio.loadmat(os.path.join(label_dir, age_name))
age = age['ages']
ages = np.zeros((number_samples - len(useless_samples), 1))

subject_IDs = get_ids(number_samples,dir_path=label_dir)
subject_IDs = subject_IDs.tolist()

position = 0
for i in range(number_samples):
  subject_name = subject_IDs[i]
  if subject_name in useless_samples:
    subject_index = get_index(lst=subject_IDs, item=subject_name)
    print('The index for sample ' + subject_name + ' is : ', subject_index)
  else:
    image_name = subject_name + '.mat'
    subject_index = get_index(lst=subject_IDs, item=subject_name)
    sites.append(all_sites[subject_index[0]])
    labels[position] = label[subject_index[0]]
    genders[position] = int(gender[subject_index[0]]) + 1
    ages[position] = float(age[subject_index[0]].replace(' ', ''))
    position = position + 1
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51095/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51096/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51096/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51097/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51097/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51098/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51098/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51099/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51099/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51100/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51100/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51101/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51101/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51102/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51102/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51103/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51103/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51104/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51104/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51105/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51105/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51106/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51106/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51107/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51107/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51109/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51109/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51110/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51110/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51111/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51111/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51112/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51112/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51113/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51113/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51114/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51114/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51116/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51116/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51117/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51117/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51118/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51118/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51122/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51122/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51123/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51123/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51124/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51124/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51126/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51126/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51127/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51127/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51128/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51128/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51129/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51129/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51130/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51130/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51131/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51131/rh.curv.stats
# ...
#   inflating: /content/sMRI_dataset/freesurfer_stats/51576/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51576/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51576/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51576/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51576/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51577/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51577/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51578/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51578/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51579/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51579/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51580/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51580/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51582/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51582/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51583/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51583/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51584/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51584/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51585/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51585/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51606/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51606/wmparc.stats
#    creating: /content/sMRI_dataset/freesurfer_stats/51607/
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/aseg.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/brainvol.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/lh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.aparc.a2009s.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.aparc.DKTatlas.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.aparc.pial.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.aparc.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.BA_exvivo.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.BA_exvivo.thresh.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.curv.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/rh.w-g.pct.stats
#   inflating: /content/sMRI_dataset/freesurfer_stats/51607/wmparc.stats
# The index for sample 51334 is :  [799]

# %%
############################################### Load sMRI ###############################################################
############################################### Load sMRI ###############################################################
############################################### Load sMRI ###############################################################
############################################### Load Desikan_Killiany_features
left = 'lh.aparc.stats'
right = 'rh.aparc.stats'
number_roi = 68
feature_list = ['NumVert', 'SurfArea', 'GrayVol', 'ThickAvg', 'ThickStd', 'MeanCurv', 'GausCurv', 'FoldInd', 'CurvInd']
names = ['StructName', 'NumVert', 'SurfArea', 'GrayVol', 'ThickAvg', 'ThickStd', 'MeanCurv', 'GausCurv', 'FoldInd', 'CurvInd']
skiprows= list(range(0,61))
Desikan_Killiany_features = np.zeros((number_samples - len(useless_samples), number_roi * len(feature_list)))


position = 0
print('constructing Desikan-Killiany Atlas features')
for i in range(number_samples):
  subject_name = subject_IDs[i]
  if subject_name in useless_samples:
    subject_index = get_index(lst=subject_IDs, item=subject_name)
    print('The index for sample ' + subject_name + ' is : ', subject_index)
  else:
    table_left = pd.read_table(localDir + subject_name + '/' + left, sep='\s+', names=names,
						  skiprows=skiprows)
    table_right = pd.read_table(localDir + subject_name + '/' + right, sep='\s+', names=names,
						  skiprows=skiprows)

    for j in range(len(feature_list)):
      feature_name = feature_list[j]
      left_features = table_left[feature_name].values.tolist()
      right_features = table_right[feature_name].values.tolist()
      all_features = left_features + right_features
      if len(all_features) != number_roi:
       print('The sample ' + subject_name + ' has mistake!')
      all_features = np.array(all_features)
      Desikan_Killiany_features[position, j*number_roi : (j+1)*number_roi] = all_features
    position = position + 1

if scaler == True:
	for i in range(len(feature_list)):
		Desikan_Killiany_features[:, i * number_roi: (i+1) * number_roi] = StandardScaler().fit_transform(Desikan_Killiany_features[:, i * number_roi: (i+1) * number_roi])

print('finished')

############################################### Load aseg features
print('constructing aseg features')
number_roi_aseg = 45
aseg = 'aseg.stats'
feature_list_aseg = ['Number of Voxels', 'Volume', 'Intensity normMean', 'Itensity normStdDev', 'Intensity normMin', 'Intensity normMax', 'Intensity normRange']
names_aseg = ['ColHeader Index', 'Segmentation Id ', 'Number of Voxels', 'Volume', 'Structure Name', 'Intensity normMean', 'Itensity normStdDev', 'Intensity normMin', 'Intensity normMax', 'Intensity normRange']
skiprows_aseg= list(range(0,79))
aseg_features = np.zeros((number_samples - len(useless_samples), number_roi_aseg * len(feature_list_aseg)))

position = 0
for i in range(number_samples):
	subject_name = subject_IDs[i]
	if subject_name in useless_samples:
		subject_index = get_index(lst=subject_IDs, item=subject_name)
		print('The index for sample ' + subject_name + ' is : ', subject_index)
	else:
		table_left = pd.read_table(localDir + subject_name + '/' + aseg, sep='\s+', names=names_aseg,
						  skiprows=skiprows_aseg)
		for j in range(len(feature_list_aseg)):
			feature_name = feature_list_aseg[j]
			left_features = table_left[feature_name].values.tolist()
			if len(left_features) != number_roi_aseg:
				print('The sample ' + subject_name + ' has mistake!')
			all_features = np.array(left_features)
			aseg_features[position, j*number_roi_aseg : (j+1)*number_roi_aseg] = all_features
		position = position + 1

if scaler == True:
	for i in range(len(feature_list_aseg)):
		aseg_features[:, i * number_roi_aseg: (i+1) * number_roi_aseg] = StandardScaler().fit_transform(aseg_features[:, i * number_roi_aseg: (i+1) * number_roi_aseg])
print('finished')

############################################### Load wmparc features
number_roi_wmparc = 70
wmparc = 'wmparc.stats'
feature_list_wmparc = ['Number of Voxels', 'Volume', 'Intensity normMean', 'Itensity normStdDev', 'Intensity normMin', 'Intensity normMax', 'Intensity normRange']
names_wmparc = ['ColHeader Index', 'Segmentation Id ', 'Number of Voxels', 'Volume', 'Structure Name', 'Intensity normMean', 'Itensity normStdDev', 'Intensity normMin', 'Intensity normMax', 'Intensity normRange']
skiprows_wmparc= list(range(0,65))
wmparc_features = np.zeros((number_samples - len(useless_samples), number_roi_wmparc * len(feature_list_wmparc)))

print('constructing wmparc features')
position = 0
for i in range(number_samples):
	subject_name = subject_IDs[i]
	if subject_name in useless_samples:
		subject_index = get_index(lst=subject_IDs, item=subject_name)
		print('The index for sample ' + subject_name + ' is : ', subject_index)
	else:
		table_left = pd.read_table(localDir + subject_name + '/' + wmparc, sep='\s+', names = names_wmparc,
						  skiprows=skiprows_wmparc)
		for j in range(len(feature_list_wmparc)):
			feature_name = feature_list_wmparc[j]
			left_features = table_left[feature_name].values.tolist()
			if len(left_features) != number_roi_wmparc:
				print('The sample ' + subject_name + ' has mistake!')
			all_features = np.array(left_features)
			wmparc_features[position, j*number_roi_wmparc : (j+1)*number_roi_wmparc] = all_features
		position = position + 1
if scaler == True:
	for i in range(len(feature_list_wmparc)):
		wmparc_features[:, i * number_roi_wmparc: (i+1) * number_roi_wmparc] = StandardScaler().fit_transform(wmparc_features[:, i * number_roi_wmparc: (i+1) * number_roi_wmparc])
print('finished')

############################################### concatenation
sMRI_features = np.concatenate((Desikan_Killiany_features, aseg_features, wmparc_features),axis = 1)
# Out:
# constructing Desikan-Killiany Atlas features
# The index for sample 51334 is :  [799]
# finished
# constructing aseg features
# The index for sample 51334 is :  [799]
# finished
# constructing wmparc features
# The index for sample 51334 is :  [799]
# finished

# %%
############################################### Combat ###############################################################
############################################### Combat ###############################################################
############################################### Combat ###############################################################
if combat == True:
	batch = []
	for i in range(len(sites)):
		batch.append(get_index(lst=unique_sites, item=sites[i])[0]+1)

	combat_labels = []
	combat_genders = []
	combat_ages = []
	for i in range(len(labels)):
		combat_labels.append(labels[i] + 1)
		combat_genders.append(genders[i])
		combat_ages.append(ages[i])

	new_all_samples_feature = sMRI_features.T
	covars = {}
	covars['batch'] = batch
	covars['labels'] = combat_labels
	covars['genders'] = combat_genders
	covars['ages'] = combat_ages
	covars = pd.DataFrame(covars)

	# To specify names of the variables that are categorical:
	categorical_cols = ['labels', 'genders']
	# To specify the name of the variable that encodes for the scanner/batch covariate:
	batch_col = 'batch'
	continuous_cols = ['ages']
	# Harmonization step:
	new_all_samples_feature = neuroCombat(dat=new_all_samples_feature,
										  covars=covars,
										  batch_col=batch_col,
										  categorical_cols=categorical_cols,
											continuous_cols=continuous_cols)["data"]
	sMRI_features = new_all_samples_feature.T
# Out:
# [neuroCombat] Creating design matrix
# [neuroCombat] Standardizing data across features
# [neuroCombat] Fitting L/S model and finding priors
# [neuroCombat] Finding parametric adjustments
# [neuroCombat] Final adjustment of data
# /content/drive/MyDrive/ABIDE/neuralCombat.py:325: RuntimeWarning: divide by zero encountered in true_divide
#   change = max((abs(g_new - g_old) / g_old).max(), (abs(d_new - d_old) / d_old).max())

# %%
plt.matshow(sMRI_features, vmin=-4, vmax=4)
plt.show()

# %%
############################################### phenotypic ###############################################################
############################################### phenotypic ###############################################################
############################################### phenotypic ###############################################################
ages_name = 'ages.mat'
ages = scio.loadmat(os.path.join(label_dir, ages_name))
ages = ages['ages']

gender_name = 'genders.mat'
genders = scio.loadmat(os.path.join(label_dir, gender_name))
genders = genders['genders']

FIQ_name = 'FIQS.mat'
FIQS = scio.loadmat(os.path.join(label_dir, FIQ_name))
FIQS = FIQS['FIQS']

NUM_name = 'NUM.mat'
NUM = scio.loadmat(os.path.join(label_dir, NUM_name))
NUMS = NUM['NUM']

PEC_name = 'PEC.mat'
PEC = scio.loadmat(os.path.join(label_dir, PEC_name))
PECS = PEC['PEC']

RAT_name = 'RAT.mat'
RAT = scio.loadmat(os.path.join(label_dir, RAT_name))
RATS = RAT['RAT']

age = np.zeros((number_samples - len(useless_samples), 1))
gender = np.zeros((number_samples - len(useless_samples), 1))
FIQ = np.zeros((number_samples - len(useless_samples), 1))
NUM = np.zeros((number_samples - len(useless_samples), 1))
PEC = np.zeros((number_samples - len(useless_samples), 1))
RAT = np.zeros((number_samples - len(useless_samples), 1))

position = 0
print('constructing phenotypic features')
for i in range(number_samples):
	subject_name = subject_IDs[i]
	if subject_name in useless_samples:
		subject_index = get_index(lst=subject_IDs, item=subject_name)
		print('The index for sample ' + subject_name + ' is : ', subject_index)
	else:
		subject_index = get_index(lst=subject_IDs, item=subject_name)
		age[position] = float(ages[subject_index[0]].replace(' ', ''))
		gender[position] = int(genders[subject_index[0]]) + 1
		FIQ[position] = int(FIQS[subject_index[0]])
		NUM[position] = float(NUMS[subject_index[0]])
		PEC[position] = float(PECS[subject_index[0]])
		RAT[position] = int(RATS[subject_index[0]])
		position = position + 1
FIQ[FIQ == -9999] = 108

if scaler == True:

  age[:,0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(age[:,0], axis = 1)))
  FIQ[:, 0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(FIQ[:, 0], axis = 1)))
  NUM[:, 0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(NUM[:, 0], axis = 1)))
  PEC[:, 0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(PEC[:, 0], axis = 1)))

# age, gender, FIQ, NUM, PEC, RAT
for i in range(3):
	sMRI_features = np.concatenate((sMRI_features, age, gender, FIQ, NUM, PEC, RAT),axis = 1)
# Out:
# constructing phenotypic features
# The index for sample 51334 is :  [799]

# %%
dist_train = {}
dist_validation = {}
dist_test = {}
for i in range(k_fold):
	dist_train[str(i + 1)] = []
	dist_validation[str(i + 1)] = []
	dist_test[str(i + 1)] = []

for each_site in unique_sites:
	index_site = get_index(sites, each_site)
	label = np.zeros((len(index_site)))
	for i in range(len(index_site)):
		index = index_site[i]
		label[i] = int(labels[int(index)])
	########################################### StratifiedKFold ####################################################
	sfolder = StratifiedKFold(n_splits=k_fold,random_state=0,shuffle=True)
	group = 0
	for train, validation in sfolder.split(index_site,label):
		for i in train:
			dist_train[str(group + 1)].append(index_site[i])
			name = 0
		for j in validation:
			dist_validation[str(group + 1)].append(index_site[j])
			name = 0
		group = group+1

	group = 0
	for train, validation in sfolder.split(index_site,label):
		if group == 0:
			for j in validation:
				dist_test[str(group + k_fold)].append(index_site[j])
				dist_train[str(group + k_fold)].remove(index_site[j])
		else:
			for j in validation:
				dist_test[str(group)].append(index_site[j])
				dist_train[str(group)].remove(index_site[j])
		group = group+1

# %%
import torch.nn as nn
import torch_geometric as tg

############################################### GCN model ###############################################################
############################################### GCN model ###############################################################
############################################### GCN model ###############################################################
class GCN(nn.Module):
    def __init__(self, in_c, hid_c, out_c, K, dropout_rate, normalize=True):
        """
        :param in_c: int, number of input channels.
        :param hid_c: int, number of hidden channels.
        :param out_c: int, number of output channels.
        :param K:
        """
        super(GCN, self).__init__()
        self.normalize = normalize

        self.conv1 = tg.nn.ChebConv(in_c, hid_c, K, normalization='sym', bias=True)
        self.conv2 = tg.nn.ChebConv(hid_c, hid_c, K, normalization='sym', bias=True)
        self.conv3 = tg.nn.ChebConv(hid_c, out_c, K, normalization='sym', bias=True)
        self.relu = nn.ReLU(inplace=True)
        self.dropout = nn.Dropout(dropout_rate)
        self.softmax = nn.LogSoftmax(dim=1)


    def forward(self, data, edge_index, edgenet_input):

        edge_weight = torch.squeeze(edgenet_input)
        # data = self.dropout(data)
        h = self.relu(self.dropout(self.conv1(data, edge_index, edge_weight)))
        h = self.relu(self.dropout(self.conv2(h, edge_index, edge_weight)))
        h = self.conv3(h, edge_index, edge_weight)

        return self.softmax(h)

# %%
############################################### Population graph ###############################################################
############################################### Population graph ###############################################################
############################################### Population graph ###############################################################
def get_subject_score(subject_list,l, path, all_subject_list):

    name = l + '.mat'
    file = scio.loadmat(os.path.join(path, name))
    file = file[l]
    label_dict = {}
    for i in subject_list:
        sample_index = get_index(lst=all_subject_list, item=i)
        value = file[sample_index[0]]
        if l == 'genders':
            label_dict[i] = int(value)
        elif l == 'ages':
            label_dict[i] = float(value)
        elif l == 'FIQS':
            label_dict[i] = float(value)
        elif l == 'NUM':
            label_dict[i] = int(value)
        elif l == 'PEC':
            label_dict[i] = float(value)
        elif l == 'RAT':
            label_dict[i] = int(value)
        elif l == 'sites':
            label_dict[i] = value.replace(' ', '')
        else:
            label_dict[i] = value
    return label_dict

def create_graph_from_scores(scores, subject_list, path, all_subject_list):
    """
        scores       : list of phenotypic information to be used to construct the affinity graph
        subject_list : list of subject IDs
    return:
        graph        : adjacency matrix of the population graph (num_subjects x num_subjects)
    """

    num_nodes = len(subject_list)
    graph = np.zeros((num_nodes, num_nodes))

    for l in scores:
        label_dict = get_subject_score(subject_list, l, path, all_subject_list)

        # quantitative phenotypic scores
        if l in ['ages']:
            for k in range(num_nodes):
                for j in range(k + 1, num_nodes):
                    try:
                        val = abs(float(label_dict[subject_list[k]]) - float(label_dict[subject_list[j]]))
                        if val < 2:
                            graph[k, j] += 1
                            graph[j, k] += 1
                    except ValueError:  # missing label
                        pass
        elif l in ['FIQ']:
            for k in range(num_nodes):
                for j in range(k + 1, num_nodes):
                    try:
                        val = abs(float(label_dict[subject_list[k]]) - float(label_dict[subject_list[j]]))
                        if val < 10:
                            graph[k, j] += 1
                            graph[j, k] += 1
                    except ValueError:  # missing label
                        pass

        else:
            for k in range(num_nodes):
                for j in range(k + 1, num_nodes):
                    if label_dict[subject_list[k]] == label_dict[subject_list[j]]:
                        graph[k, j] += 1
                        graph[j, k] += 1

    return graph

GCN_labels = np.zeros((number_samples - len(useless_samples), 2))
for i in range(len(labels)):
    if labels[i] == 1:
        GCN_labels[i,0] = 1
    else:
        GCN_labels[i,1] = 1


all_subject_IDs = get_ids(number_samples,dir_path=label_dir)
all_subject_IDs = all_subject_IDs.tolist()
for i in useless_samples:
    subject_IDs.remove(i)

graph = create_graph_from_scores(['sites'], subject_IDs, label_dir,all_subject_IDs)

# %%
data = {}
for fold in range(1, k_fold+1):
  data[str(fold)] = []
  selector = feature_selection(sMRI_features, labels, dist_train[str(fold)], new_number_features)
  fold_data = selector.transform(sMRI_features)

  n = fold_data.shape[0]
  num_edge = n * n
  edge_index = np.zeros([2, num_edge], dtype=np.int64)
  edgenet_input = np.zeros([num_edge, 1], dtype=np.float32) 
  aff_score = np.zeros(num_edge, dtype=np.float32)
  flatten_ind = 0

  for i in range(n): 
    for j in range(n):
      edge_index[:, flatten_ind] = [i, j]
      edgenet_input[flatten_ind] = graph[i,j]
      aff_score[flatten_ind] = graph[i,j]
      flatten_ind += 1


  keep_ind = np.where(aff_score > 0.99)[0]
  edge_index = edge_index[:, keep_ind]
  edgenet_input = edgenet_input[keep_ind]

  data[str(fold)].append(fold_data)
  data[str(fold)].append(GCN_labels)
  data[str(fold)].append(edge_index)
  data[str(fold)].append(edgenet_input)

# %%
############################################### Train, validaiton, test pipelines ###############################################################
############################################### Train, validaiton, test pipelines ###############################################################
############################################### Train, validaiton, test pipelines ###############################################################
def train_GCN(args, model, all_data, fold_train_index, fold_validation_index, fold_test_index, scheduler):

    model.train()
    data = torch.from_numpy(all_data[0])
    data = Variable(data, requires_grad=True)
    data = data.float()

    target = torch.from_numpy(all_data[1])
    target = target.float().long()

    edge_index = torch.from_numpy(all_data[2])
    edge_index = Variable(edge_index, requires_grad=False)

    edgenet_input = torch.from_numpy(all_data[3])
    edgenet_input = Variable(edgenet_input, requires_grad=True)
    edgenet_input = edgenet_input.float()
    if args.cuda:
        data, target, edge_index, edgenet_input = data.cuda(), target.cuda(), edge_index.cuda(), edgenet_input.cuda()

    scheduler.zero_grad()
    out = model(data, edge_index, edgenet_input)
    out = out[fold_train_index,:]  
    target = target[fold_train_index, :]

    cross_loss = torch.nn.functional.nll_loss(out, torch.max(target, 1)[1]) # only train set will be included
    out = torch.max(out, 1)[1]
    target = torch.max(target, 1)[1]
    target = target.cpu().numpy()
    out = out.cpu().numpy()
    cross_loss.backward()
    scheduler.step()

    ############################## validation and test ################################################################################
    val_target, val_out, val_loss = validation_GCN(args, model, all_data, fold_validation_index)
    test_target, test_out, test_out_prob, test_loss = test_GCN(args, model, all_data, fold_test_index)

    return model, target, out, cross_loss.item(), val_target, val_out,val_loss, test_target, test_out, test_out_prob, test_loss

    
def validation_GCN(args, model,all_data,  fold_validation_index):

    model.eval()
    data = torch.from_numpy(all_data[0])
    data = Variable(data, requires_grad=False)
    data = data.float()

    target = torch.from_numpy(all_data[1])
    target = target.float().long()

    edge_index = torch.from_numpy(all_data[2])
    edge_index = Variable(edge_index, requires_grad=False)

    edgenet_input = torch.from_numpy(all_data[3])
    edgenet_input = Variable(edgenet_input, requires_grad=False)
    edgenet_input = edgenet_input.float()

    if args.cuda:
        data, target, edge_index, edgenet_input = data.cuda(), target.cuda(), edge_index.cuda(), edgenet_input.cuda()

    out = model(data, edge_index, edgenet_input)
    out = out[fold_validation_index, :]
    target = target[fold_validation_index, :]
    cross_loss = torch.nn.functional.nll_loss(out, torch.max(target, 1)[1])

    out = torch.max(out, 1)[1]
    target = torch.max(target, 1)[1]
    target = target.cpu().numpy()
    out = out.cpu().numpy()

    return target, out, cross_loss.item()


def test_GCN(args, model, all_data,  fold_test_index):

    model.eval()

    data = torch.from_numpy(all_data[0])
    data = Variable(data, requires_grad=False)
    data = data.float()

    target = torch.from_numpy(all_data[1])
    target = target.float().long()

    edge_index = torch.from_numpy(all_data[2])
    edge_index = Variable(edge_index, requires_grad=False)

    edgenet_input = torch.from_numpy(all_data[3])
    edgenet_input = Variable(edgenet_input, requires_grad=False)
    edgenet_input = edgenet_input.float()

    if args.cuda:
        data, target, edge_index, edgenet_input = data.cuda(), target.cuda(), edge_index.cuda(), edgenet_input.cuda()

    out = model(data, edge_index, edgenet_input)
    out = out[fold_test_index, :]
    target = target[fold_test_index, :]
    cross_loss = torch.nn.functional.nll_loss(out, torch.max(target, 1)[1])

    out_prob = torch.exp(out)
    out = torch.max(out, 1)[1]
    target = torch.max(target, 1)[1]
    target = target.cpu().numpy()
    out = out.cpu().numpy()
    out_prob = out_prob.cpu().detach().numpy()

    return target, out, out_prob, cross_loss.item()

# %%
########################################### Training setting ################################################
########################################### Training setting ################################################
########################################### Training setting ################################################

parser = argparse.ArgumentParser()
parser.add_argument('--ngpu', type=int, default=1)
parser.add_argument('--nEpochs', type=int, default=200)
parser.add_argument('--start-epoch', default=0, type=int, metavar='N',
                    help='manual epoch number (useful on restarts)')
parser.add_argument('--weight-decay', '--wd', default=1e-8, type=float,
                    metavar='W', help='weight decay (default: 1e-8)')
parser.add_argument('--no-cuda', action='store_true')
parser.add_argument('--opt', type=str, default='adam')
parser.add_argument('--lr', type=str, default=8e-4)
parser.add_argument('--seed', type=int, default=1)
parser.add_argument('--cheby_order_K', type=int, default=2)
parser.add_argument('--input_dimension', type=int, default=new_number_features)
parser.add_argument('--hidden_dimension', type=int, default=128)
parser.add_argument('--output_dimension', type=int, default=2)
parser.add_argument('--dropout_rate', type=int, default=0.3)
#
args, unknown = parser.parse_known_args()
args.cuda = not args.no_cuda and torch.cuda.is_available()
torch.manual_seed(args.seed)
if args.cuda:
    torch.cuda.manual_seed(args.seed)
    
gpu_ids = range(args.ngpu)
train = train_GCN

# %%
########################################### Training ################################################
########################################### Training ################################################
########################################### Training ################################################
for fold in range(1, k_fold+1):
  model = GCN(in_c=args.input_dimension, hid_c=args.hidden_dimension, out_c=args.output_dimension, K=args.cheby_order_K, dropout_rate=args.dropout_rate)
  print('  + Number of params: {}'.format(
    sum([p.data.nelement() for p in model.parameters()])))
  model = nn.parallel.DataParallel(model, device_ids=gpu_ids)
  if args.cuda:
    model = model.cuda()
  optimizer = optim.Adam(model.parameters(), lr = args.lr)

  best_validation_accuracy = 0
  Train_accuracy_list =[]
  Train_loss_list = []
  Val_accuracy_list =[]
  Val_loss_list = []
  Test_accuracy_list =[]
  Test_loss_list = []

  for epoch in range(1, args.nEpochs + 1):

    model, train_target, train_out, train_loss, val_target, val_out, val_loss, test_target, test_out, test_prob, test_loss = train(args, model, data[str(fold)], dist_train[str(fold)], dist_validation[str(fold)], dist_test[str(fold)], optimizer)

    train_accuracy = metrics.accuracy_score(train_target, train_out)
    val_accuracy = metrics.accuracy_score(val_target, val_out)
    test_accuracy = metrics.accuracy_score(test_target, test_out)
    Train_accuracy_list.append(train_accuracy)
    Val_accuracy_list.append(val_accuracy)
    Test_accuracy_list.append(test_accuracy)
    Train_loss_list.append(train_loss)
    Val_loss_list.append(val_loss)
    Test_loss_list.append(test_loss)

    if val_accuracy >=best_validation_accuracy:
      best_epoch = epoch
      best_validation_accuracy = val_accuracy
      corresponding_val_out = val_out
      corresponding_test_accuracy = test_accuracy
      corresponding_test_out = test_out
      corresponding_test_prob = test_prob

      print('Save models')
      save_model(model, save_path, 'GCN_'+str(fold))

    print('Train Epoch: ' + str(epoch) + ': train loss : {:.8f}\t train accuracy : {:.8f}\t val accuracy : {:.8f}\t test accuracy : {:.8f}\t'.format(
      train_loss, train_accuracy, val_accuracy, test_accuracy))
  
  if fold == 1:
    all_fold_val_label = val_target
    all_fold_val_out = corresponding_val_out
    all_fold_test_label = test_target
    all_fold_test_out = corresponding_test_out
    all_fold_test_prob = corresponding_test_prob
  else:
    all_fold_val_label = np.concatenate((all_fold_val_label, val_target),axis = 0)
    all_fold_val_out = np.concatenate((all_fold_val_out, corresponding_val_out),axis = 0)
    all_fold_test_label = np.concatenate((all_fold_test_label, test_target),axis = 0)
    all_fold_test_out = np.concatenate((all_fold_test_out, corresponding_test_out),axis = 0)
    all_fold_test_prob = np.concatenate((all_fold_test_prob, corresponding_test_prob),axis = 0)

  x_axis = list(range(1, len(Train_accuracy_list)+1))
  plt.figure(figsize=(10,6))
  plt.plot(x_axis, Train_loss_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_loss_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_loss_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()

  plt.figure(figsize=(10,6))
  plt.plot(x_axis, Train_accuracy_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_accuracy_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_accuracy_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()


  test_fpr, test_tpr, te_thresholds = roc_curve(test_target, corresponding_test_prob[:,1],pos_label=1)
  test_auc = auc(test_fpr, test_tpr)
  print('\n')
  print('In fold ',str(fold))
  print('The best validaiton accuracy is: ',best_validation_accuracy)
  print('Happened at epoch: ',best_epoch)
  print('The corresponding test accuracy', corresponding_test_accuracy)
  print('The corresponding test AUC is: ',test_auc)
  print('\n')


  plt.grid()
  plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
  plt.plot([0,1],[0,1],'g--')
  plt.legend()
  plt.xlabel("False Positive Rate")
  plt.ylabel("True Positive Rate")
  plt.title("Test AUC(ROC curve)")
  plt.grid(color='black', linestyle='-', linewidth=0.5)
  plt.show()

print('Finish 5-fold training')
# Out:
#   + Number of params: 400898
# Save models
# Train Epoch: 1: train loss : 0.90176755	 train accuracy : 0.49510763	 val accuracy : 0.56593407	 test accuracy : 0.53107345
# Save models
# Train Epoch: 2: train loss : 0.86427742	 train accuracy : 0.60273973	 val accuracy : 0.58241758	 test accuracy : 0.54237288
# Train Epoch: 3: train loss : 0.70960426	 train accuracy : 0.61448141	 val accuracy : 0.53296703	 test accuracy : 0.58757062
# Train Epoch: 4: train loss : 0.70152760	 train accuracy : 0.63796477	 val accuracy : 0.52197802	 test accuracy : 0.55367232
# Train Epoch: 5: train loss : 0.63515115	 train accuracy : 0.69275930	 val accuracy : 0.54945055	 test accuracy : 0.58192090
# Train Epoch: 6: train loss : 0.57828844	 train accuracy : 0.71624266	 val accuracy : 0.57142857	 test accuracy : 0.58192090
# Train Epoch: 7: train loss : 0.54350680	 train accuracy : 0.72798434	 val accuracy : 0.57692308	 test accuracy : 0.59322034
# Train Epoch: 8: train loss : 0.49621695	 train accuracy : 0.76320939	 val accuracy : 0.57692308	 test accuracy : 0.61581921
# Train Epoch: 9: train loss : 0.47841039	 train accuracy : 0.78864971	 val accuracy : 0.57692308	 test accuracy : 0.59887006
# Save models
# Train Epoch: 10: train loss : 0.43139082	 train accuracy : 0.80234834	 val accuracy : 0.58241758	 test accuracy : 0.56497175
# Save models
# Train Epoch: 11: train loss : 0.39872465	 train accuracy : 0.83170254	 val accuracy : 0.60439560	 test accuracy : 0.63276836
# Save models
# Train Epoch: 12: train loss : 0.36216068	 train accuracy : 0.83757339	 val accuracy : 0.60439560	 test accuracy : 0.59322034
# Train Epoch: 13: train loss : 0.41450942	 train accuracy : 0.81213307	 val accuracy : 0.59340659	 test accuracy : 0.58757062
# Save models
# Train Epoch: 14: train loss : 0.36495578	 train accuracy : 0.85909980	 val accuracy : 0.60439560	 test accuracy : 0.59887006
# Save models
# Train Epoch: 15: train loss : 0.34902406	 train accuracy : 0.86301370	 val accuracy : 0.60989011	 test accuracy : 0.57627119
# Save models
# Train Epoch: 16: train loss : 0.30575550	 train accuracy : 0.88062622	 val accuracy : 0.60989011	 test accuracy : 0.56497175
# Save models
# Train Epoch: 17: train loss : 0.29437616	 train accuracy : 0.90019569	 val accuracy : 0.60989011	 test accuracy : 0.57062147
# Save models
# Train Epoch: 18: train loss : 0.27086186	 train accuracy : 0.92954990	 val accuracy : 0.60989011	 test accuracy : 0.58192090
# Save models
# Train Epoch: 19: train loss : 0.26998717	 train accuracy : 0.90606654	 val accuracy : 0.60989011	 test accuracy : 0.57062147
# Train Epoch: 20: train loss : 0.24717192	 train accuracy : 0.91585127	 val accuracy : 0.59890110	 test accuracy : 0.57627119
# Train Epoch: 21: train loss : 0.22442774	 train accuracy : 0.91976517	 val accuracy : 0.59890110	 test accuracy : 0.59887006
# Save models
# Train Epoch: 22: train loss : 0.19275992	 train accuracy : 0.95303327	 val accuracy : 0.61538462	 test accuracy : 0.58192090
# Train Epoch: 23: train loss : 0.19263995	 train accuracy : 0.93542074	 val accuracy : 0.60989011	 test accuracy : 0.58192090
# Train Epoch: 24: train loss : 0.17496231	 train accuracy : 0.94911937	 val accuracy : 0.60989011	 test accuracy : 0.57627119
# Train Epoch: 25: train loss : 0.18723422	 train accuracy : 0.94129159	 val accuracy : 0.60989011	 test accuracy : 0.57627119
# Save models
# Train Epoch: 26: train loss : 0.13750643	 train accuracy : 0.97064579	 val accuracy : 0.62087912	 test accuracy : 0.58192090
# Save models
# Train Epoch: 27: train loss : 0.15685837	 train accuracy : 0.95303327	 val accuracy : 0.62087912	 test accuracy : 0.59887006
# Train Epoch: 28: train loss : 0.12892294	 train accuracy : 0.97064579	 val accuracy : 0.61538462	 test accuracy : 0.59887006
# Train Epoch: 29: train loss : 0.12010641	 train accuracy : 0.96673190	 val accuracy : 0.61538462	 test accuracy : 0.59887006
# Train Epoch: 30: train loss : 0.12115212	 train accuracy : 0.97064579	 val accuracy : 0.60989011	 test accuracy : 0.59887006
# Save models
# Train Epoch: 31: train loss : 0.09340668	 train accuracy : 0.98043053	 val accuracy : 0.62087912	 test accuracy : 0.59887006
# Train Epoch: 32: train loss : 0.10031990	 train accuracy : 0.98630137	 val accuracy : 0.61538462	 test accuracy : 0.59887006
# Train Epoch: 33: train loss : 0.07875573	 train accuracy : 0.98434442	 val accuracy : 0.61538462	 test accuracy : 0.59887006
# Save models
# Train Epoch: 34: train loss : 0.07260442	 train accuracy : 0.98434442	 val accuracy : 0.62087912	 test accuracy : 0.59887006
# Train Epoch: 35: train loss : 0.06960298	 train accuracy : 0.98630137	 val accuracy : 0.60989011	 test accuracy : 0.59887006
# Save models
# Train Epoch: 36: train loss : 0.07838871	 train accuracy : 0.97651663	 val accuracy : 0.62087912	 test accuracy : 0.59887006
# Train Epoch: 37: train loss : 0.05700571	 train accuracy : 0.99412916	 val accuracy : 0.60439560	 test accuracy : 0.59887006
# Train Epoch: 38: train loss : 0.04737720	 train accuracy : 0.99608611	 val accuracy : 0.60439560	 test accuracy : 0.58192090
# Train Epoch: 39: train loss : 0.04911635	 train accuracy : 0.99412916	 val accuracy : 0.59890110	 test accuracy : 0.58757062
# Train Epoch: 40: train loss : 0.04899534	 train accuracy : 0.99021526	 val accuracy : 0.59890110	 test accuracy : 0.57062147
# Train Epoch: 41: train loss : 0.04508991	 train accuracy : 0.98825832	 val accuracy : 0.61538462	 test accuracy : 0.57627119
# Train Epoch: 42: train loss : 0.03746350	 train accuracy : 0.99608611	 val accuracy : 0.61538462	 test accuracy : 0.58192090
# Train Epoch: 43: train loss : 0.04040580	 train accuracy : 0.99412916	 val accuracy : 0.61538462	 test accuracy : 0.58757062
# Train Epoch: 44: train loss : 0.03339067	 train accuracy : 0.99608611	 val accuracy : 0.61538462	 test accuracy : 0.58192090
# Save models
# Train Epoch: 45: train loss : 0.03292733	 train accuracy : 0.99804305	 val accuracy : 0.62087912	 test accuracy : 0.58757062
# Train Epoch: 46: train loss : 0.03147901	 train accuracy : 0.99412916	 val accuracy : 0.61538462	 test accuracy : 0.58757062
# Train Epoch: 47: train loss : 0.02984364	 train accuracy : 0.99412916	 val accuracy : 0.60439560	 test accuracy : 0.58757062
# Train Epoch: 48: train loss : 0.03078257	 train accuracy : 0.99608611	 val accuracy : 0.60989011	 test accuracy : 0.59322034
# Train Epoch: 49: train loss : 0.01957280	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.58757062
# Train Epoch: 50: train loss : 0.02560684	 train accuracy : 0.99608611	 val accuracy : 0.61538462	 test accuracy : 0.58757062
# Train Epoch: 51: train loss : 0.01737513	 train accuracy : 0.99804305	 val accuracy : 0.61538462	 test accuracy : 0.58757062
# Train Epoch: 52: train loss : 0.02680692	 train accuracy : 0.99608611	 val accuracy : 0.61538462	 test accuracy : 0.58757062
# Save models
# Train Epoch: 53: train loss : 0.01425258	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.58757062
# Save models
# Train Epoch: 54: train loss : 0.01582716	 train accuracy : 0.99804305	 val accuracy : 0.62637363	 test accuracy : 0.58192090
# Save models
# Train Epoch: 55: train loss : 0.01693483	 train accuracy : 0.99804305	 val accuracy : 0.62637363	 test accuracy : 0.58757062
# Save models
# Train Epoch: 56: train loss : 0.01555812	 train accuracy : 0.99804305	 val accuracy : 0.62637363	 test accuracy : 0.58192090
# Save models
# Train Epoch: 57: train loss : 0.01806642	 train accuracy : 0.99804305	 val accuracy : 0.62637363	 test accuracy : 0.58192090
# Save models
# Train Epoch: 58: train loss : 0.01652840	 train accuracy : 0.99804305	 val accuracy : 0.62637363	 test accuracy : 0.58192090
# Save models
# Train Epoch: 59: train loss : 0.01678290	 train accuracy : 0.99804305	 val accuracy : 0.62637363	 test accuracy : 0.58192090
# Train Epoch: 60: train loss : 0.01457366	 train accuracy : 0.99804305	 val accuracy : 0.61538462	 test accuracy : 0.58757062
# Train Epoch: 61: train loss : 0.01115719	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.58757062
# Train Epoch: 62: train loss : 0.01614938	 train accuracy : 0.99608611	 val accuracy : 0.60989011	 test accuracy : 0.58192090
# Train Epoch: 63: train loss : 0.01272964	 train accuracy : 0.99804305	 val accuracy : 0.60989011	 test accuracy : 0.58192090
# Train Epoch: 64: train loss : 0.01333501	 train accuracy : 0.99608611	 val accuracy : 0.60989011	 test accuracy : 0.58192090
# Train Epoch: 65: train loss : 0.01034554	 train accuracy : 0.99804305	 val accuracy : 0.60989011	 test accuracy : 0.58192090
# Train Epoch: 66: train loss : 0.00908702	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.58757062
# Train Epoch: 67: train loss : 0.01054500	 train accuracy : 0.99804305	 val accuracy : 0.60439560	 test accuracy : 0.57627119
# Train Epoch: 68: train loss : 0.00924373	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.57627119
# Train Epoch: 69: train loss : 0.00813880	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.57627119
# Train Epoch: 70: train loss : 0.00945617	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.57627119
# Train Epoch: 71: train loss : 0.00845017	 train accuracy : 0.99804305	 val accuracy : 0.60989011	 test accuracy : 0.57062147
# Train Epoch: 72: train loss : 0.00869313	 train accuracy : 0.99608611	 val accuracy : 0.60989011	 test accuracy : 0.57062147
# Train Epoch: 73: train loss : 0.01079286	 train accuracy : 0.99804305	 val accuracy : 0.61538462	 test accuracy : 0.57062147
# Train Epoch: 74: train loss : 0.00743874	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.56497175
# Train Epoch: 75: train loss : 0.00753564	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.55932203
# Save models
# Train Epoch: 76: train loss : 0.01074210	 train accuracy : 0.99804305	 val accuracy : 0.62637363	 test accuracy : 0.55367232
# Train Epoch: 77: train loss : 0.00638893	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.55367232
# Train Epoch: 78: train loss : 0.00513355	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.56497175
# Train Epoch: 79: train loss : 0.00544185	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.56497175
# Train Epoch: 80: train loss : 0.00542317	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.56497175
# Save models
# Train Epoch: 81: train loss : 0.00787469	 train accuracy : 0.99804305	 val accuracy : 0.62637363	 test accuracy : 0.56497175
# Save models
# Train Epoch: 82: train loss : 0.00682697	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.55932203
# Save models
# Train Epoch: 83: train loss : 0.00523822	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.55932203
# Train Epoch: 84: train loss : 0.00507122	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.57062147
# Train Epoch: 85: train loss : 0.00802838	 train accuracy : 0.99804305	 val accuracy : 0.61538462	 test accuracy : 0.58192090
# Train Epoch: 86: train loss : 0.00962026	 train accuracy : 0.99804305	 val accuracy : 0.61538462	 test accuracy : 0.58192090
# Train Epoch: 87: train loss : 0.00477208	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.57627119
# Save models
# Train Epoch: 88: train loss : 0.00522430	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.57627119
# Save models
# Train Epoch: 89: train loss : 0.00491583	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.57627119
# Save models
# Train Epoch: 90: train loss : 0.00409385	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.57627119
# Train Epoch: 91: train loss : 0.00500210	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.57627119
# Train Epoch: 92: train loss : 0.00473987	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.57627119
# Train Epoch: 93: train loss : 0.00415496	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.57627119
# Train Epoch: 94: train loss : 0.00277706	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.57627119
# Train Epoch: 95: train loss : 0.00661933	 train accuracy : 0.99804305	 val accuracy : 0.62087912	 test accuracy : 0.57627119
# Train Epoch: 96: train loss : 0.00311293	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.57627119
# Train Epoch: 97: train loss : 0.00320087	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.57627119
# Train Epoch: 98: train loss : 0.00324140	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.57627119
# Train Epoch: 99: train loss : 0.00379204	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.57062147
# Train Epoch: 100: train loss : 0.00327150	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.57062147
# Train Epoch: 101: train loss : 0.00492780	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.57062147
# Train Epoch: 102: train loss : 0.00269850	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.57062147
# Train Epoch: 103: train loss : 0.00374226	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.57062147
# Train Epoch: 104: train loss : 0.00248774	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.57062147
# Train Epoch: 105: train loss : 0.00276177	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.57062147
# Train Epoch: 106: train loss : 0.00250778	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.56497175
# Train Epoch: 107: train loss : 0.00346161	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.57062147
# Train Epoch: 108: train loss : 0.00188135	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.57062147
# Train Epoch: 109: train loss : 0.00335722	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.57062147
# Train Epoch: 110: train loss : 0.00344299	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.56497175
# Train Epoch: 111: train loss : 0.00303107	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.56497175
# Train Epoch: 112: train loss : 0.00322340	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.56497175
# Train Epoch: 113: train loss : 0.00177765	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.56497175
# Train Epoch: 114: train loss : 0.00344543	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.56497175
# Train Epoch: 115: train loss : 0.00285629	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.56497175
# Train Epoch: 116: train loss : 0.00326494	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.56497175
# Train Epoch: 117: train loss : 0.00141032	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.56497175
# Train Epoch: 118: train loss : 0.00372860	 train accuracy : 0.99804305	 val accuracy : 0.61538462	 test accuracy : 0.56497175
# Train Epoch: 119: train loss : 0.00357308	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.56497175
# Train Epoch: 120: train loss : 0.00306958	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.56497175
# Train Epoch: 121: train loss : 0.00457403	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.56497175
# Train Epoch: 122: train loss : 0.00156702	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.55932203
# Train Epoch: 123: train loss : 0.00467966	 train accuracy : 0.99804305	 val accuracy : 0.62087912	 test accuracy : 0.55932203
# Train Epoch: 124: train loss : 0.00251069	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.55932203
# Train Epoch: 125: train loss : 0.00208693	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.55932203
# Train Epoch: 126: train loss : 0.00221948	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.55932203
# Train Epoch: 127: train loss : 0.00382621	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.56497175
# Train Epoch: 128: train loss : 0.00219408	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.56497175
# Save models
# Train Epoch: 129: train loss : 0.00245490	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.56497175
# Save models
# Train Epoch: 130: train loss : 0.00256127	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.56497175
# Save models
# Train Epoch: 131: train loss : 0.00458029	 train accuracy : 0.99804305	 val accuracy : 0.62637363	 test accuracy : 0.57062147
# Save models
# Train Epoch: 132: train loss : 0.00130818	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.56497175
# Save models
# Train Epoch: 133: train loss : 0.00101623	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.56497175
# Save models
# Train Epoch: 134: train loss : 0.00227867	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.56497175
# Save models
# Train Epoch: 135: train loss : 0.00187109	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.56497175
# Save models
# Train Epoch: 136: train loss : 0.00196196	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.56497175
# Save models
# Train Epoch: 137: train loss : 0.00133222	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.56497175
# Save models
# Train Epoch: 138: train loss : 0.00268855	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.56497175
# Save models
# Train Epoch: 139: train loss : 0.00174571	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.55932203
# Train Epoch: 140: train loss : 0.00184068	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.55932203
# Train Epoch: 141: train loss : 0.00174837	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.55932203
# Train Epoch: 142: train loss : 0.00109766	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.55932203
# Train Epoch: 143: train loss : 0.00302570	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.55932203
# Save models
# Train Epoch: 144: train loss : 0.00096163	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.56497175
# Save models
# Train Epoch: 145: train loss : 0.00096584	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.57062147
# Save models
# Train Epoch: 146: train loss : 0.00233269	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.57062147
# Train Epoch: 147: train loss : 0.00140453	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.57062147
# Train Epoch: 148: train loss : 0.00189384	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.57062147
# Train Epoch: 149: train loss : 0.00167545	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.57062147
# Train Epoch: 150: train loss : 0.00094188	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.57062147
# Train Epoch: 151: train loss : 0.00245425	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.57062147
# Train Epoch: 152: train loss : 0.00236945	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.57062147
# Train Epoch: 153: train loss : 0.00117765	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.57062147
# Train Epoch: 154: train loss : 0.00161502	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.57062147
# Train Epoch: 155: train loss : 0.00276238	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.57062147
# Train Epoch: 156: train loss : 0.00083555	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.57062147
# Train Epoch: 157: train loss : 0.00424158	 train accuracy : 0.99804305	 val accuracy : 0.60989011	 test accuracy : 0.57062147
# Train Epoch: 158: train loss : 0.00098979	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.57062147
# Train Epoch: 159: train loss : 0.00303958	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.57062147
# Save models
# Train Epoch: 160: train loss : 0.00208532	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.57062147
# Save models
# Train Epoch: 161: train loss : 0.00173429	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.57627119
# Save models
# Train Epoch: 162: train loss : 0.00104950	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.57627119
# Save models
# Train Epoch: 163: train loss : 0.00138567	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.57062147
# Train Epoch: 164: train loss : 0.00047910	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.57062147
# Train Epoch: 165: train loss : 0.00137873	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.56497175
# Train Epoch: 166: train loss : 0.00095980	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.57062147
# Train Epoch: 167: train loss : 0.00110892	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.57062147
# Train Epoch: 168: train loss : 0.00121823	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.57062147
# Train Epoch: 169: train loss : 0.00141216	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.56497175
# Train Epoch: 170: train loss : 0.00100526	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.56497175
# Train Epoch: 171: train loss : 0.00356305	 train accuracy : 0.99804305	 val accuracy : 0.62087912	 test accuracy : 0.56497175
# Save models
# Train Epoch: 172: train loss : 0.00151165	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.56497175
# Save models
# Train Epoch: 173: train loss : 0.00234691	 train accuracy : 1.00000000	 val accuracy : 0.62637363	 test accuracy : 0.56497175
# Train Epoch: 174: train loss : 0.00122892	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.56497175
# Train Epoch: 175: train loss : 0.00128089	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.56497175
# Train Epoch: 176: train loss : 0.00113575	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.55932203
# Train Epoch: 177: train loss : 0.00085370	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.55932203
# Train Epoch: 178: train loss : 0.00186557	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.56497175
# Train Epoch: 179: train loss : 0.00174720	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.56497175
# Train Epoch: 180: train loss : 0.00202162	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.56497175
# Train Epoch: 181: train loss : 0.00157390	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.56497175
# Train Epoch: 182: train loss : 0.00214417	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.56497175
# Train Epoch: 183: train loss : 0.00139395	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.55932203
# Train Epoch: 184: train loss : 0.00073210	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.55932203
# Train Epoch: 185: train loss : 0.00369954	 train accuracy : 0.99804305	 val accuracy : 0.62087912	 test accuracy : 0.55932203
# Train Epoch: 186: train loss : 0.00237489	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.55932203
# Train Epoch: 187: train loss : 0.00099504	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.55932203
# Train Epoch: 188: train loss : 0.00091804	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.56497175
# Train Epoch: 189: train loss : 0.00068212	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.56497175
# Train Epoch: 190: train loss : 0.00179810	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.56497175
# Train Epoch: 191: train loss : 0.00119620	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.57062147
# Train Epoch: 192: train loss : 0.00474601	 train accuracy : 0.99804305	 val accuracy : 0.60989011	 test accuracy : 0.57627119
# Train Epoch: 193: train loss : 0.00331358	 train accuracy : 0.99804305	 val accuracy : 0.60439560	 test accuracy : 0.57627119
# Train Epoch: 194: train loss : 0.00190048	 train accuracy : 1.00000000	 val accuracy : 0.60439560	 test accuracy : 0.57627119
# Train Epoch: 195: train loss : 0.00410508	 train accuracy : 0.99804305	 val accuracy : 0.60989011	 test accuracy : 0.57627119
# Train Epoch: 196: train loss : 0.00201244	 train accuracy : 1.00000000	 val accuracy : 0.60989011	 test accuracy : 0.57627119
# Train Epoch: 197: train loss : 0.00152239	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.57627119
# Train Epoch: 198: train loss : 0.00098925	 train accuracy : 1.00000000	 val accuracy : 0.61538462	 test accuracy : 0.57627119
# Train Epoch: 199: train loss : 0.00115895	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.57627119
# Train Epoch: 200: train loss : 0.00078324	 train accuracy : 1.00000000	 val accuracy : 0.62087912	 test accuracy : 0.57627119
# In fold  1
# The best validaiton accuracy is:  0.6263736263736264
# Happened at epoch:  173
# The corresponding test accuracy 0.5649717514124294
# The corresponding test AUC is:  0.6516624040920715
#   + Number of params: 400898
# Save models
# Train Epoch: 1: train loss : 1.54003155	 train accuracy : 0.54527938	 val accuracy : 0.56497175	 test accuracy : 0.60344828
# Train Epoch: 2: train loss : 0.82243651	 train accuracy : 0.53757225	 val accuracy : 0.49717514	 test accuracy : 0.48850575
# Train Epoch: 3: train loss : 0.96081924	 train accuracy : 0.51252408	 val accuracy : 0.48587571	 test accuracy : 0.50000000
# Train Epoch: 4: train loss : 0.97471923	 train accuracy : 0.53179191	 val accuracy : 0.53107345	 test accuracy : 0.56896552
# Save models
# Train Epoch: 5: train loss : 0.78726149	 train accuracy : 0.60886320	 val accuracy : 0.58757062	 test accuracy : 0.66091954
# Save models
# Train Epoch: 6: train loss : 0.66160280	 train accuracy : 0.66473988	 val accuracy : 0.62711864	 test accuracy : 0.61494253
# Train Epoch: 7: train loss : 0.66852677	 train accuracy : 0.68208092	 val accuracy : 0.58757062	 test accuracy : 0.61494253
# Train Epoch: 8: train loss : 0.64381874	 train accuracy : 0.69942197	 val accuracy : 0.57062147	 test accuracy : 0.60344828
# Train Epoch: 9: train loss : 0.59681123	 train accuracy : 0.71868979	 val accuracy : 0.57627119	 test accuracy : 0.62643678
# Train Epoch: 10: train loss : 0.52407914	 train accuracy : 0.72254335	 val accuracy : 0.55932203	 test accuracy : 0.62643678
# Train Epoch: 11: train loss : 0.47622287	 train accuracy : 0.77263969	 val accuracy : 0.56497175	 test accuracy : 0.63218391
# Train Epoch: 12: train loss : 0.45287833	 train accuracy : 0.78420039	 val accuracy : 0.57062147	 test accuracy : 0.62068966
# Train Epoch: 13: train loss : 0.45869964	 train accuracy : 0.79383430	 val accuracy : 0.57627119	 test accuracy : 0.63793103
# Train Epoch: 14: train loss : 0.45714062	 train accuracy : 0.78805395	 val accuracy : 0.56497175	 test accuracy : 0.63793103
# Train Epoch: 15: train loss : 0.44862181	 train accuracy : 0.80732177	 val accuracy : 0.58192090	 test accuracy : 0.62643678
# Train Epoch: 16: train loss : 0.39143768	 train accuracy : 0.82851638	 val accuracy : 0.59322034	 test accuracy : 0.62643678
# Train Epoch: 17: train loss : 0.33948496	 train accuracy : 0.85549133	 val accuracy : 0.58757062	 test accuracy : 0.62643678
# Train Epoch: 18: train loss : 0.34639490	 train accuracy : 0.84778420	 val accuracy : 0.57627119	 test accuracy : 0.62068966
# Train Epoch: 19: train loss : 0.35817099	 train accuracy : 0.84200385	 val accuracy : 0.57062147	 test accuracy : 0.62643678
# Train Epoch: 20: train loss : 0.29490712	 train accuracy : 0.88053950	 val accuracy : 0.57062147	 test accuracy : 0.63793103
# Train Epoch: 21: train loss : 0.30805004	 train accuracy : 0.86512524	 val accuracy : 0.57627119	 test accuracy : 0.64367816
# Train Epoch: 22: train loss : 0.28603509	 train accuracy : 0.88246628	 val accuracy : 0.57627119	 test accuracy : 0.66091954
# Train Epoch: 23: train loss : 0.28589085	 train accuracy : 0.87668593	 val accuracy : 0.58757062	 test accuracy : 0.67241379
# Train Epoch: 24: train loss : 0.23520912	 train accuracy : 0.91907514	 val accuracy : 0.60451977	 test accuracy : 0.64367816
# Save models
# Train Epoch: 25: train loss : 0.22469026	 train accuracy : 0.93834297	 val accuracy : 0.63276836	 test accuracy : 0.64367816
# Save models
# Train Epoch: 26: train loss : 0.21616413	 train accuracy : 0.92100193	 val accuracy : 0.63276836	 test accuracy : 0.66666667
# Train Epoch: 27: train loss : 0.21416007	 train accuracy : 0.94026975	 val accuracy : 0.62711864	 test accuracy : 0.63793103
# Train Epoch: 28: train loss : 0.20622392	 train accuracy : 0.93641618	 val accuracy : 0.62711864	 test accuracy : 0.64367816
# Train Epoch: 29: train loss : 0.20710120	 train accuracy : 0.92678227	 val accuracy : 0.62711864	 test accuracy : 0.64942529
# Train Epoch: 30: train loss : 0.20829137	 train accuracy : 0.92292871	 val accuracy : 0.62711864	 test accuracy : 0.63218391
# Save models
# Train Epoch: 31: train loss : 0.15957262	 train accuracy : 0.96146435	 val accuracy : 0.63276836	 test accuracy : 0.64367816
# Save models
# Train Epoch: 32: train loss : 0.15559700	 train accuracy : 0.96146435	 val accuracy : 0.63276836	 test accuracy : 0.68390805
# Train Epoch: 33: train loss : 0.13446681	 train accuracy : 0.97109827	 val accuracy : 0.62146893	 test accuracy : 0.68965517
# Train Epoch: 34: train loss : 0.14101875	 train accuracy : 0.96531792	 val accuracy : 0.59887006	 test accuracy : 0.68965517
# Train Epoch: 35: train loss : 0.14588884	 train accuracy : 0.95953757	 val accuracy : 0.59887006	 test accuracy : 0.68965517
# Train Epoch: 36: train loss : 0.11762448	 train accuracy : 0.97302505	 val accuracy : 0.58757062	 test accuracy : 0.67241379
# Train Epoch: 37: train loss : 0.10768200	 train accuracy : 0.97495183	 val accuracy : 0.57627119	 test accuracy : 0.65517241
# Train Epoch: 38: train loss : 0.11595737	 train accuracy : 0.97687861	 val accuracy : 0.57627119	 test accuracy : 0.66091954
# Train Epoch: 39: train loss : 0.11148562	 train accuracy : 0.96724470	 val accuracy : 0.58757062	 test accuracy : 0.66091954
# Train Epoch: 40: train loss : 0.09859117	 train accuracy : 0.98073218	 val accuracy : 0.59322034	 test accuracy : 0.67241379
# Train Epoch: 41: train loss : 0.09006729	 train accuracy : 0.98265896	 val accuracy : 0.58757062	 test accuracy : 0.67241379
# Train Epoch: 42: train loss : 0.08076930	 train accuracy : 0.98651252	 val accuracy : 0.59887006	 test accuracy : 0.65517241
# Train Epoch: 43: train loss : 0.07857499	 train accuracy : 0.97880539	 val accuracy : 0.59887006	 test accuracy : 0.65517241
# Train Epoch: 44: train loss : 0.07233528	 train accuracy : 0.99036609	 val accuracy : 0.59322034	 test accuracy : 0.66091954
# Train Epoch: 45: train loss : 0.07048001	 train accuracy : 0.98651252	 val accuracy : 0.59887006	 test accuracy : 0.66666667
# Train Epoch: 46: train loss : 0.05714877	 train accuracy : 0.98843931	 val accuracy : 0.59322034	 test accuracy : 0.66091954
# Train Epoch: 47: train loss : 0.06301972	 train accuracy : 0.99229287	 val accuracy : 0.58757062	 test accuracy : 0.65517241
# Train Epoch: 48: train loss : 0.06453721	 train accuracy : 0.99229287	 val accuracy : 0.58192090	 test accuracy : 0.66666667
# Train Epoch: 49: train loss : 0.05827034	 train accuracy : 0.98843931	 val accuracy : 0.57627119	 test accuracy : 0.67241379
# Train Epoch: 50: train loss : 0.05819734	 train accuracy : 0.98843931	 val accuracy : 0.58192090	 test accuracy : 0.66666667
# Train Epoch: 51: train loss : 0.05302265	 train accuracy : 0.99421965	 val accuracy : 0.57062147	 test accuracy : 0.66091954
# Train Epoch: 52: train loss : 0.04106884	 train accuracy : 0.99807322	 val accuracy : 0.57062147	 test accuracy : 0.66091954
# Train Epoch: 53: train loss : 0.03054825	 train accuracy : 1.00000000	 val accuracy : 0.58757062	 test accuracy : 0.64942529
# Train Epoch: 54: train loss : 0.04448216	 train accuracy : 0.99614644	 val accuracy : 0.58192090	 test accuracy : 0.64942529
# Train Epoch: 55: train loss : 0.04283730	 train accuracy : 0.99036609	 val accuracy : 0.58192090	 test accuracy : 0.64942529
# Train Epoch: 56: train loss : 0.03322662	 train accuracy : 1.00000000	 val accuracy : 0.58192090	 test accuracy : 0.64942529
# Train Epoch: 57: train loss : 0.02957283	 train accuracy : 0.99807322	 val accuracy : 0.58192090	 test accuracy : 0.65517241
# Train Epoch: 58: train loss : 0.03250429	 train accuracy : 0.99807322	 val accuracy : 0.57627119	 test accuracy : 0.65517241
# Train Epoch: 59: train loss : 0.03088205	 train accuracy : 0.99614644	 val accuracy : 0.57627119	 test accuracy : 0.64942529
# Train Epoch: 60: train loss : 0.02927377	 train accuracy : 0.99807322	 val accuracy : 0.57062147	 test accuracy : 0.64942529
# Train Epoch: 61: train loss : 0.02839961	 train accuracy : 0.99807322	 val accuracy : 0.58192090	 test accuracy : 0.65517241
# Train Epoch: 62: train loss : 0.03028188	 train accuracy : 0.99807322	 val accuracy : 0.58192090	 test accuracy : 0.66666667
# Train Epoch: 63: train loss : 0.02609660	 train accuracy : 1.00000000	 val accuracy : 0.57627119	 test accuracy : 0.67241379
# Train Epoch: 64: train loss : 0.02626146	 train accuracy : 0.99421965	 val accuracy : 0.56497175	 test accuracy : 0.66091954
# Train Epoch: 65: train loss : 0.02054870	 train accuracy : 0.99807322	 val accuracy : 0.57627119	 test accuracy : 0.66666667
# Train Epoch: 66: train loss : 0.02252271	 train accuracy : 0.99614644	 val accuracy : 0.56497175	 test accuracy : 0.66091954
# Train Epoch: 67: train loss : 0.02705318	 train accuracy : 0.99421965	 val accuracy : 0.57062147	 test accuracy : 0.66091954
# Train Epoch: 68: train loss : 0.02112015	 train accuracy : 0.99807322	 val accuracy : 0.57627119	 test accuracy : 0.65517241
# Train Epoch: 69: train loss : 0.02187229	 train accuracy : 0.99614644	 val accuracy : 0.57062147	 test accuracy : 0.64942529
# Train Epoch: 70: train loss : 0.01585654	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.64942529
# Train Epoch: 71: train loss : 0.02193600	 train accuracy : 0.99614644	 val accuracy : 0.57062147	 test accuracy : 0.65517241
# Train Epoch: 72: train loss : 0.02171941	 train accuracy : 0.99807322	 val accuracy : 0.57627119	 test accuracy : 0.65517241
# Train Epoch: 73: train loss : 0.01482471	 train accuracy : 1.00000000	 val accuracy : 0.58192090	 test accuracy : 0.66091954
# Train Epoch: 74: train loss : 0.01386645	 train accuracy : 1.00000000	 val accuracy : 0.58192090	 test accuracy : 0.66666667
# Train Epoch: 75: train loss : 0.01714707	 train accuracy : 1.00000000	 val accuracy : 0.57062147	 test accuracy : 0.67241379
# Train Epoch: 76: train loss : 0.01514626	 train accuracy : 1.00000000	 val accuracy : 0.57062147	 test accuracy : 0.67241379
# Train Epoch: 77: train loss : 0.02073956	 train accuracy : 0.99421965	 val accuracy : 0.57062147	 test accuracy : 0.66666667
# Train Epoch: 78: train loss : 0.01058086	 train accuracy : 1.00000000	 val accuracy : 0.57062147	 test accuracy : 0.66666667
# Train Epoch: 79: train loss : 0.01395243	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.66091954
# Train Epoch: 80: train loss : 0.01580786	 train accuracy : 0.99614644	 val accuracy : 0.56497175	 test accuracy : 0.66091954
# Train Epoch: 81: train loss : 0.00906274	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.64942529
# Train Epoch: 82: train loss : 0.01439940	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.64942529
# Train Epoch: 83: train loss : 0.01558188	 train accuracy : 0.99807322	 val accuracy : 0.56497175	 test accuracy : 0.64367816
# Train Epoch: 84: train loss : 0.01143885	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.64367816
# Train Epoch: 85: train loss : 0.01067892	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.64942529
# Train Epoch: 86: train loss : 0.01304702	 train accuracy : 0.99807322	 val accuracy : 0.56497175	 test accuracy : 0.64942529
# Train Epoch: 87: train loss : 0.01272885	 train accuracy : 0.99807322	 val accuracy : 0.56497175	 test accuracy : 0.64942529
# Train Epoch: 88: train loss : 0.00992974	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.64367816
# Train Epoch: 89: train loss : 0.00924734	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.64367816
# Train Epoch: 90: train loss : 0.01153231	 train accuracy : 0.99614644	 val accuracy : 0.56497175	 test accuracy : 0.64367816
# Train Epoch: 91: train loss : 0.01100487	 train accuracy : 0.99807322	 val accuracy : 0.56497175	 test accuracy : 0.65517241
# Train Epoch: 92: train loss : 0.00899574	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.64942529
# Train Epoch: 93: train loss : 0.01042495	 train accuracy : 0.99614644	 val accuracy : 0.57062147	 test accuracy : 0.64942529
# Train Epoch: 94: train loss : 0.01038711	 train accuracy : 0.99807322	 val accuracy : 0.57062147	 test accuracy : 0.64942529
# Train Epoch: 95: train loss : 0.00707659	 train accuracy : 1.00000000	 val accuracy : 0.57627119	 test accuracy : 0.64942529
# Train Epoch: 96: train loss : 0.00978484	 train accuracy : 1.00000000	 val accuracy : 0.57627119	 test accuracy : 0.64942529
# Train Epoch: 97: train loss : 0.00764793	 train accuracy : 1.00000000	 val accuracy : 0.57627119	 test accuracy : 0.65517241
# Train Epoch: 98: train loss : 0.01133263	 train accuracy : 0.99807322	 val accuracy : 0.57062147	 test accuracy : 0.64942529
# Train Epoch: 99: train loss : 0.01031607	 train accuracy : 0.99807322	 val accuracy : 0.57062147	 test accuracy : 0.64942529
# Train Epoch: 100: train loss : 0.00736161	 train accuracy : 1.00000000	 val accuracy : 0.57062147	 test accuracy : 0.64942529
# Train Epoch: 101: train loss : 0.00885553	 train accuracy : 0.99807322	 val accuracy : 0.56497175	 test accuracy : 0.64367816
# Train Epoch: 102: train loss : 0.00632180	 train accuracy : 1.00000000	 val accuracy : 0.57062147	 test accuracy : 0.64367816
# Train Epoch: 103: train loss : 0.01139402	 train accuracy : 0.99614644	 val accuracy : 0.56497175	 test accuracy : 0.64942529
# Train Epoch: 104: train loss : 0.00786574	 train accuracy : 0.99807322	 val accuracy : 0.57062147	 test accuracy : 0.65517241
# Train Epoch: 105: train loss : 0.00849307	 train accuracy : 0.99807322	 val accuracy : 0.57627119	 test accuracy : 0.65517241
# Train Epoch: 106: train loss : 0.00677529	 train accuracy : 1.00000000	 val accuracy : 0.57627119	 test accuracy : 0.65517241
# Train Epoch: 107: train loss : 0.00667633	 train accuracy : 0.99807322	 val accuracy : 0.56497175	 test accuracy : 0.64367816
# Train Epoch: 108: train loss : 0.00683822	 train accuracy : 0.99807322	 val accuracy : 0.56497175	 test accuracy : 0.64942529
# Train Epoch: 109: train loss : 0.00548016	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.64942529
# Train Epoch: 110: train loss : 0.00462621	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.64942529
# Train Epoch: 111: train loss : 0.00829619	 train accuracy : 0.99807322	 val accuracy : 0.55932203	 test accuracy : 0.64942529
# Train Epoch: 112: train loss : 0.00666271	 train accuracy : 0.99807322	 val accuracy : 0.55367232	 test accuracy : 0.66091954
# Train Epoch: 113: train loss : 0.01095360	 train accuracy : 0.99807322	 val accuracy : 0.55367232	 test accuracy : 0.65517241
# Train Epoch: 114: train loss : 0.00435714	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.66091954
# Train Epoch: 115: train loss : 0.00693060	 train accuracy : 1.00000000	 val accuracy : 0.54802260	 test accuracy : 0.66666667
# Train Epoch: 116: train loss : 0.00886857	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.65517241
# Train Epoch: 117: train loss : 0.01607466	 train accuracy : 0.99807322	 val accuracy : 0.55367232	 test accuracy : 0.64942529
# Train Epoch: 118: train loss : 0.00609807	 train accuracy : 0.99807322	 val accuracy : 0.54802260	 test accuracy : 0.64942529
# Train Epoch: 119: train loss : 0.00716270	 train accuracy : 1.00000000	 val accuracy : 0.54237288	 test accuracy : 0.64942529
# Train Epoch: 120: train loss : 0.00575732	 train accuracy : 0.99807322	 val accuracy : 0.54802260	 test accuracy : 0.64367816
# Train Epoch: 121: train loss : 0.00347428	 train accuracy : 1.00000000	 val accuracy : 0.54802260	 test accuracy : 0.63793103
# Train Epoch: 122: train loss : 0.00587858	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.63793103
# Train Epoch: 123: train loss : 0.00689556	 train accuracy : 0.99807322	 val accuracy : 0.55367232	 test accuracy : 0.63218391
# Train Epoch: 124: train loss : 0.00737303	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.63793103
# Train Epoch: 125: train loss : 0.00586236	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.63218391
# Train Epoch: 126: train loss : 0.00548983	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.63218391
# Train Epoch: 127: train loss : 0.00409524	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.63218391
# Train Epoch: 128: train loss : 0.00372679	 train accuracy : 1.00000000	 val accuracy : 0.54802260	 test accuracy : 0.63218391
# Train Epoch: 129: train loss : 0.00381859	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.63218391
# Train Epoch: 130: train loss : 0.00455707	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.63218391
# Train Epoch: 131: train loss : 0.00419536	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.63218391
# Train Epoch: 132: train loss : 0.00366117	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.62643678
# Train Epoch: 133: train loss : 0.00448930	 train accuracy : 0.99807322	 val accuracy : 0.56497175	 test accuracy : 0.62643678
# Train Epoch: 134: train loss : 0.00512279	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.62643678
# Train Epoch: 135: train loss : 0.00259984	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.62643678
# Train Epoch: 136: train loss : 0.00370313	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.62643678
# Train Epoch: 137: train loss : 0.00277269	 train accuracy : 1.00000000	 val accuracy : 0.57062147	 test accuracy : 0.62643678
# Train Epoch: 138: train loss : 0.00566210	 train accuracy : 1.00000000	 val accuracy : 0.57062147	 test accuracy : 0.62643678
# Train Epoch: 139: train loss : 0.00349578	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.62643678
# Train Epoch: 140: train loss : 0.00542956	 train accuracy : 0.99807322	 val accuracy : 0.56497175	 test accuracy : 0.62643678
# Train Epoch: 141: train loss : 0.00329971	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.62643678
# Train Epoch: 142: train loss : 0.00444633	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.62643678
# Train Epoch: 143: train loss : 0.00243335	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.62643678
# Train Epoch: 144: train loss : 0.00262232	 train accuracy : 1.00000000	 val accuracy : 0.57062147	 test accuracy : 0.62643678
# Train Epoch: 145: train loss : 0.00199479	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.63218391
# Train Epoch: 146: train loss : 0.00343504	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.63793103
# Train Epoch: 147: train loss : 0.00344546	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.63793103
# Train Epoch: 148: train loss : 0.00440629	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.63793103
# Train Epoch: 149: train loss : 0.00421055	 train accuracy : 0.99807322	 val accuracy : 0.56497175	 test accuracy : 0.63793103
# Train Epoch: 150: train loss : 0.00869298	 train accuracy : 0.99807322	 val accuracy : 0.55932203	 test accuracy : 0.63793103
# Train Epoch: 151: train loss : 0.00458516	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.63793103
# Train Epoch: 152: train loss : 0.00322735	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.63793103
# Train Epoch: 153: train loss : 0.00276124	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.64367816
# Train Epoch: 154: train loss : 0.00294233	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.63793103
# Train Epoch: 155: train loss : 0.00584029	 train accuracy : 0.99807322	 val accuracy : 0.55367232	 test accuracy : 0.63793103
# Train Epoch: 156: train loss : 0.00263589	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.63793103
# Train Epoch: 157: train loss : 0.00207783	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.63793103
# Train Epoch: 158: train loss : 0.00286570	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.63793103
# Train Epoch: 159: train loss : 0.00315693	 train accuracy : 1.00000000	 val accuracy : 0.55367232	 test accuracy : 0.63793103
# Train Epoch: 160: train loss : 0.00317852	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.63793103
# Train Epoch: 161: train loss : 0.00335811	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.63793103
# Train Epoch: 162: train loss : 0.00307494	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.63793103
# Train Epoch: 163: train loss : 0.00288257	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.63793103
# Train Epoch: 164: train loss : 0.00178834	 train accuracy : 1.00000000	 val accuracy : 0.55932203	 test accuracy : 0.63793103
# Train Epoch: 165: train loss : 0.00403163	 train accuracy : 0.99807322	 val accuracy : 0.56497175	 test accuracy : 0.63793103
# Train Epoch: 166: train loss : 0.00262272	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.64367816
# Train Epoch: 167: train loss : 0.00341108	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.64367816
# Train Epoch: 168: train loss : 0.00267920	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.63793103
# Train Epoch: 169: train loss : 0.00202593	 train accuracy : 1.00000000	 val accuracy : 0.56497175	 test accuracy : 0.63218391
# Train Epoch: 170: train loss : 0.00554440	 train accuracy : 0.99807322	 val accuracy : 0.55367232	 test accuracy : 0.64367816
# Train Epoch: 171: train loss : 0.00297023	 train accuracy : 1.00000000	 val accuracy : 0.54237288	 test accuracy : 0.64942529
# Train Epoch: 172: train loss : 0.00362070	 train accuracy : 1.00000000	 val accuracy : 0.54802260	 test accuracy : 0.65517241
# ...
# Train Epoch: 77: train loss : 0.00675797	 train accuracy : 0.99808061	 val accuracy : 0.54491018	 test accuracy : 0.56043956
# Train Epoch: 78: train loss : 0.00691814	 train accuracy : 0.99808061	 val accuracy : 0.54491018	 test accuracy : 0.55494505
# Train Epoch: 79: train loss : 0.00429133	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.55494505
# Train Epoch: 80: train loss : 0.00542078	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.55494505
# Train Epoch: 81: train loss : 0.00571719	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.55494505
# Train Epoch: 82: train loss : 0.00647262	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.55494505
# Train Epoch: 83: train loss : 0.00779042	 train accuracy : 0.99808061	 val accuracy : 0.54491018	 test accuracy : 0.55494505
# Train Epoch: 84: train loss : 0.00637201	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.56043956
# Train Epoch: 85: train loss : 0.00502434	 train accuracy : 1.00000000	 val accuracy : 0.55089820	 test accuracy : 0.56043956
# Train Epoch: 86: train loss : 0.00598960	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.56593407
# Train Epoch: 87: train loss : 0.00606753	 train accuracy : 0.99808061	 val accuracy : 0.55089820	 test accuracy : 0.57142857
# Train Epoch: 88: train loss : 0.00374682	 train accuracy : 1.00000000	 val accuracy : 0.55089820	 test accuracy : 0.57142857
# Train Epoch: 89: train loss : 0.00495056	 train accuracy : 1.00000000	 val accuracy : 0.55089820	 test accuracy : 0.57142857
# Train Epoch: 90: train loss : 0.00525696	 train accuracy : 1.00000000	 val accuracy : 0.55089820	 test accuracy : 0.57142857
# Train Epoch: 91: train loss : 0.00492044	 train accuracy : 1.00000000	 val accuracy : 0.55688623	 test accuracy : 0.57142857
# Train Epoch: 92: train loss : 0.00582186	 train accuracy : 0.99808061	 val accuracy : 0.55688623	 test accuracy : 0.57142857
# Train Epoch: 93: train loss : 0.00528287	 train accuracy : 0.99808061	 val accuracy : 0.55688623	 test accuracy : 0.56593407
# Train Epoch: 94: train loss : 0.00363653	 train accuracy : 1.00000000	 val accuracy : 0.55089820	 test accuracy : 0.57142857
# Train Epoch: 95: train loss : 0.00430096	 train accuracy : 1.00000000	 val accuracy : 0.55688623	 test accuracy : 0.57692308
# Train Epoch: 96: train loss : 0.00521344	 train accuracy : 1.00000000	 val accuracy : 0.55089820	 test accuracy : 0.57692308
# Train Epoch: 97: train loss : 0.00592349	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.57692308
# Train Epoch: 98: train loss : 0.00312174	 train accuracy : 1.00000000	 val accuracy : 0.53293413	 test accuracy : 0.57692308
# Train Epoch: 99: train loss : 0.00537382	 train accuracy : 1.00000000	 val accuracy : 0.52694611	 test accuracy : 0.57692308
# Train Epoch: 100: train loss : 0.00608733	 train accuracy : 1.00000000	 val accuracy : 0.53293413	 test accuracy : 0.58241758
# Train Epoch: 101: train loss : 0.00467118	 train accuracy : 1.00000000	 val accuracy : 0.53293413	 test accuracy : 0.58241758
# Train Epoch: 102: train loss : 0.00358490	 train accuracy : 1.00000000	 val accuracy : 0.53293413	 test accuracy : 0.58241758
# Train Epoch: 103: train loss : 0.00227655	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.58241758
# Train Epoch: 104: train loss : 0.00401880	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.58241758
# Train Epoch: 105: train loss : 0.00149815	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.58241758
# Train Epoch: 106: train loss : 0.00251568	 train accuracy : 1.00000000	 val accuracy : 0.55089820	 test accuracy : 0.58241758
# Train Epoch: 107: train loss : 0.00427203	 train accuracy : 1.00000000	 val accuracy : 0.55089820	 test accuracy : 0.58241758
# Train Epoch: 108: train loss : 0.00291305	 train accuracy : 1.00000000	 val accuracy : 0.55089820	 test accuracy : 0.57692308
# Train Epoch: 109: train loss : 0.00265240	 train accuracy : 1.00000000	 val accuracy : 0.55089820	 test accuracy : 0.57692308
# Train Epoch: 110: train loss : 0.00382441	 train accuracy : 1.00000000	 val accuracy : 0.55089820	 test accuracy : 0.57692308
# Train Epoch: 111: train loss : 0.00751069	 train accuracy : 0.99808061	 val accuracy : 0.55089820	 test accuracy : 0.57692308
# Train Epoch: 112: train loss : 0.00281881	 train accuracy : 1.00000000	 val accuracy : 0.55089820	 test accuracy : 0.58241758
# Train Epoch: 113: train loss : 0.00356436	 train accuracy : 1.00000000	 val accuracy : 0.55089820	 test accuracy : 0.58241758
# Train Epoch: 114: train loss : 0.00238664	 train accuracy : 1.00000000	 val accuracy : 0.55089820	 test accuracy : 0.58241758
# Train Epoch: 115: train loss : 0.00208761	 train accuracy : 1.00000000	 val accuracy : 0.55089820	 test accuracy : 0.58241758
# Train Epoch: 116: train loss : 0.00251133	 train accuracy : 1.00000000	 val accuracy : 0.55089820	 test accuracy : 0.57692308
# Train Epoch: 117: train loss : 0.00261789	 train accuracy : 1.00000000	 val accuracy : 0.55688623	 test accuracy : 0.58241758
# Train Epoch: 118: train loss : 0.00315283	 train accuracy : 1.00000000	 val accuracy : 0.55688623	 test accuracy : 0.58241758
# Train Epoch: 119: train loss : 0.00501708	 train accuracy : 0.99808061	 val accuracy : 0.55089820	 test accuracy : 0.58241758
# Train Epoch: 120: train loss : 0.00403566	 train accuracy : 0.99808061	 val accuracy : 0.54491018	 test accuracy : 0.58241758
# Train Epoch: 121: train loss : 0.00293786	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.57692308
# Train Epoch: 122: train loss : 0.00321846	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.57692308
# Train Epoch: 123: train loss : 0.00449217	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.56593407
# Train Epoch: 124: train loss : 0.00276473	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.56593407
# Train Epoch: 125: train loss : 0.00226964	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.56593407
# Train Epoch: 126: train loss : 0.00326520	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.56043956
# Train Epoch: 127: train loss : 0.00390210	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.56043956
# Train Epoch: 128: train loss : 0.00375455	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.57142857
# Train Epoch: 129: train loss : 0.00166603	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.57692308
# Train Epoch: 130: train loss : 0.00271531	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.58791209
# Train Epoch: 131: train loss : 0.00434084	 train accuracy : 0.99808061	 val accuracy : 0.54491018	 test accuracy : 0.58791209
# Train Epoch: 132: train loss : 0.00149703	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.58791209
# Train Epoch: 133: train loss : 0.00172052	 train accuracy : 1.00000000	 val accuracy : 0.55089820	 test accuracy : 0.58791209
# Train Epoch: 134: train loss : 0.00185594	 train accuracy : 1.00000000	 val accuracy : 0.55089820	 test accuracy : 0.58791209
# Train Epoch: 135: train loss : 0.00312953	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.58791209
# Train Epoch: 136: train loss : 0.00144801	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.59340659
# Train Epoch: 137: train loss : 0.00372126	 train accuracy : 0.99808061	 val accuracy : 0.54491018	 test accuracy : 0.58791209
# Train Epoch: 138: train loss : 0.00168609	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.58791209
# Train Epoch: 139: train loss : 0.00261843	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.58791209
# Train Epoch: 140: train loss : 0.00183131	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.57692308
# Train Epoch: 141: train loss : 0.00263885	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.57692308
# Train Epoch: 142: train loss : 0.00301035	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.57692308
# Train Epoch: 143: train loss : 0.00381394	 train accuracy : 0.99808061	 val accuracy : 0.54491018	 test accuracy : 0.58241758
# Train Epoch: 144: train loss : 0.00160421	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.58791209
# Train Epoch: 145: train loss : 0.00191658	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.58791209
# Train Epoch: 146: train loss : 0.00152040	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.58791209
# Train Epoch: 147: train loss : 0.00196394	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.58791209
# Train Epoch: 148: train loss : 0.00210441	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.58791209
# Train Epoch: 149: train loss : 0.00199003	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.58791209
# Train Epoch: 150: train loss : 0.00182636	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.58791209
# Train Epoch: 151: train loss : 0.00216962	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.58791209
# Train Epoch: 152: train loss : 0.00170738	 train accuracy : 1.00000000	 val accuracy : 0.53293413	 test accuracy : 0.58791209
# Train Epoch: 153: train loss : 0.00205630	 train accuracy : 1.00000000	 val accuracy : 0.53293413	 test accuracy : 0.59340659
# Train Epoch: 154: train loss : 0.00332682	 train accuracy : 0.99808061	 val accuracy : 0.53293413	 test accuracy : 0.59340659
# Train Epoch: 155: train loss : 0.00389685	 train accuracy : 1.00000000	 val accuracy : 0.53293413	 test accuracy : 0.59890110
# Train Epoch: 156: train loss : 0.00299223	 train accuracy : 0.99808061	 val accuracy : 0.53293413	 test accuracy : 0.59340659
# Train Epoch: 157: train loss : 0.00072335	 train accuracy : 1.00000000	 val accuracy : 0.53293413	 test accuracy : 0.59340659
# Train Epoch: 158: train loss : 0.00297405	 train accuracy : 1.00000000	 val accuracy : 0.53293413	 test accuracy : 0.59340659
# Train Epoch: 159: train loss : 0.00077118	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.58791209
# Train Epoch: 160: train loss : 0.00097445	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.58791209
# Train Epoch: 161: train loss : 0.00144638	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.58791209
# Train Epoch: 162: train loss : 0.00166513	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.58791209
# Train Epoch: 163: train loss : 0.00120852	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.58791209
# Train Epoch: 164: train loss : 0.00240881	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.58241758
# Train Epoch: 165: train loss : 0.00150272	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.58241758
# Train Epoch: 166: train loss : 0.00375125	 train accuracy : 0.99808061	 val accuracy : 0.54491018	 test accuracy : 0.58241758
# Train Epoch: 167: train loss : 0.00302403	 train accuracy : 0.99808061	 val accuracy : 0.54491018	 test accuracy : 0.58791209
# Train Epoch: 168: train loss : 0.00095502	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.59340659
# Train Epoch: 169: train loss : 0.00061403	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.59340659
# Train Epoch: 170: train loss : 0.00113817	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.59340659
# Train Epoch: 171: train loss : 0.00235466	 train accuracy : 1.00000000	 val accuracy : 0.53293413	 test accuracy : 0.59340659
# Train Epoch: 172: train loss : 0.00161055	 train accuracy : 1.00000000	 val accuracy : 0.53293413	 test accuracy : 0.59340659
# Train Epoch: 173: train loss : 0.00259828	 train accuracy : 1.00000000	 val accuracy : 0.53293413	 test accuracy : 0.60439560
# Train Epoch: 174: train loss : 0.00103749	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.60439560
# Train Epoch: 175: train loss : 0.00103235	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.60439560
# Train Epoch: 176: train loss : 0.00213286	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.60439560
# Train Epoch: 177: train loss : 0.00116374	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.60439560
# Train Epoch: 178: train loss : 0.00133053	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.60439560
# Train Epoch: 179: train loss : 0.00147307	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.59890110
# Train Epoch: 180: train loss : 0.00108344	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.59890110
# Train Epoch: 181: train loss : 0.00091904	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.60439560
# Train Epoch: 182: train loss : 0.00083477	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.60439560
# Train Epoch: 183: train loss : 0.00165818	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.59340659
# Train Epoch: 184: train loss : 0.00091016	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.59340659
# Train Epoch: 185: train loss : 0.00091556	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.58791209
# Train Epoch: 186: train loss : 0.00123957	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.58791209
# Train Epoch: 187: train loss : 0.00077014	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.58241758
# Train Epoch: 188: train loss : 0.00104868	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.58241758
# Train Epoch: 189: train loss : 0.00102281	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.58241758
# Train Epoch: 190: train loss : 0.00054616	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.58241758
# Train Epoch: 191: train loss : 0.00112050	 train accuracy : 1.00000000	 val accuracy : 0.54491018	 test accuracy : 0.58241758
# Train Epoch: 192: train loss : 0.00108722	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.58241758
# Train Epoch: 193: train loss : 0.00100619	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.58241758
# Train Epoch: 194: train loss : 0.00091414	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.58241758
# Train Epoch: 195: train loss : 0.00081012	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.58241758
# Train Epoch: 196: train loss : 0.00078881	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.58241758
# Train Epoch: 197: train loss : 0.00141095	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.58791209
# Train Epoch: 198: train loss : 0.00093559	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.58791209
# Train Epoch: 199: train loss : 0.00149072	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.59340659
# Train Epoch: 200: train loss : 0.00079827	 train accuracy : 1.00000000	 val accuracy : 0.53892216	 test accuracy : 0.59890110
# In fold  5
# The best validaiton accuracy is:  0.6227544910179641
# Happened at epoch:  7
# The corresponding test accuracy 0.5769230769230769
# The corresponding test AUC is:  0.5857558139534883
# Finish 5-fold training

# %%
val_accuracy = metrics.accuracy_score(all_fold_val_label, all_fold_val_out)
test_accuracy = metrics.accuracy_score(all_fold_test_label, all_fold_test_out)
test_fpr, test_tpr, te_thresholds = roc_curve(all_fold_test_label, all_fold_test_prob[:,1],pos_label=1)
test_auc = auc(test_fpr, test_tpr)
print('The best validation accuracy is ',val_accuracy)
print('The corresponding test accuracy is ',test_accuracy)
print('The corresponding test AUC is: ',test_auc)
plt.grid()
plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
plt.plot([0,1],[0,1],'g--')
plt.legend()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Test AUC(ROC curve)")
plt.grid(color='black', linestyle='-', linewidth=0.5)
plt.show()
# Out:
# The best validation accuracy is  0.6436781609195402
# The corresponding test accuracy is  0.6218390804597701
# The corresponding test AUC is:  0.6473344987539917

# %%
torch.cuda.empty_cache()
torch.manual_seed(args.seed)
if args.cuda:
    torch.cuda.manual_seed(args.seed)
############################################### Max voting ###############################################################
############################################### Max voting ###############################################################
############################################### Max voting ###############################################################
dist_ensemble_val_label = {}
dist_ensemble_val_result = {}
dist_ensemble_test_label = {}
dist_ensemble_test_result = {}
dist_ensemble_test_prob = {}

for ensemble_fold in range(5):
  print('Ensemble ',ensemble_fold+1)
  save_ensemble_models_path = save_path + 'Max_voting/GCN/'
  dist_train = {}
  dist_validation = {}
  dist_test = {}
  for i in range(k_fold):
    dist_train[str(i + 1)] = []
    dist_validation[str(i + 1)] = []
    dist_test[str(i + 1)] = []
  test_name = {}
  for i in range(len(unique_sites)):
    test_name[unique_sites[i]] = []
  for each_site in unique_sites:
    index_site = get_index(sites, each_site)
    label = np.zeros((len(index_site)))
    for i in range(len(index_site)):
      index = index_site[i]
      label[i] = int(labels[int(index)])
    test_name_list = test_name[each_site]
    ########################################### StratifiedKFold ####################################################
    sfolder = StratifiedKFold(n_splits=k_fold,random_state=0,shuffle=True)
    group = 0
    for train, validation in sfolder.split(index_site,label):
      if group == ensemble_fold:
        for j in validation:
          name = index_site[j]
          dist_test['1'].append(name)
          dist_test['2'].append(name)
          dist_test['3'].append(name)
          dist_test['4'].append(name)
          dist_test['5'].append(name)
          test_name_list.append(name)
      group = group + 1
    test_name[each_site] = test_name_list

  for each_site in unique_sites:
    if ensemble_fold == 0:

      index_site = get_index(sites, each_site)
      label = np.zeros((len(index_site)))
      for i in range(len(index_site)):
        index = index_site[i]
        label[i] = int(labels[int(index)])
      test_name_list = test_name[each_site]
      index_site_new = []
      label_new = np.zeros((len(index_site) - len(test_name_list)))
      position = 0
      for x in range(len(index_site)):
        sample_name = index_site[x]
        if sample_name in test_name_list:
          c=0
        else:
          index_site_new.append(sample_name)
          label_new[position] = label[x]
          position = position + 1
      if each_site == 'CMU':  # ONLY 4 AUTISM SAMPLES AND 4 TD SAMPLES, CAN NOT BE DEVIDED INTO 5 GROUPS
        group_autism_val = []
        group_autism_train = []
        group_TD_val = []
        group_TD_train = []
        autism_validation_number = len(label_new[label_new ==1])/4
        TD_validation_number = len(label_new[label_new ==0]) / 4
        for j in range(len(label_new)):
          if label_new[j] == 1:
            if len(group_autism_val)<autism_validation_number:
              group_autism_val.append(index_site_new[j])
            else:
              group_autism_train.append(index_site_new[j])
          else:
            if len(group_TD_val)<TD_validation_number:
              group_TD_val.append(index_site_new[j])
            else:
              group_TD_train.append(index_site_new[j])

        dist_validation['1'] = dist_validation['1'] + group_autism_val + group_TD_val
        dist_validation['2'] = dist_validation['2'] + group_autism_val + group_TD_val
        dist_validation['3'] = dist_validation['3'] + group_autism_val + group_TD_val
        dist_validation['4'] = dist_validation['4'] + group_autism_val + group_TD_val
        dist_validation['5'] = dist_validation['5'] + group_autism_val + group_TD_val
        dist_train['1'] = dist_train['1'] + group_autism_train + group_TD_train
        dist_train['2'] = dist_train['2'] + group_autism_train + group_TD_train
        dist_train['3'] = dist_train['3'] + group_autism_train + group_TD_train
        dist_train['4'] = dist_train['4'] + group_autism_train + group_TD_train
        dist_train['5'] = dist_train['5'] + group_autism_train + group_TD_train
      else:
        ########################################### StratifiedKFold ####################################################
        sfolder = StratifiedKFold(n_splits=k_fold, random_state=0, shuffle=True)
        group = 0
        for train, validation in sfolder.split(index_site_new, label_new):

          for i in train:
            name = index_site_new[i]
            dist_train[str(group + 1)].append(name)
          for j in validation:
            name = index_site_new[j]
            dist_validation[str(group + 1)].append(name)
          group = group + 1
    else:

      index_site = get_index(sites, each_site)
      label = np.zeros((len(index_site)))
      for i in range(len(index_site)):
        index = index_site[i]
        label[i] = int(labels[int(index)])
      test_name_list = test_name[each_site]
      index_site_new = []
      label_new = np.zeros((len(index_site) - len(test_name_list)))
      position = 0
      for x in range(len(index_site)):
        sample_name = index_site[x]
        if sample_name in test_name_list:
          c=0
        else:
          index_site_new.append(sample_name)
          label_new[position] = label[x]
          position = position + 1
      ########################################### StratifiedKFold ####################################################
      sfolder = StratifiedKFold(n_splits=k_fold,random_state=0,shuffle=True)
      group = 0
      for train, validation in sfolder.split(index_site_new,label_new):

        for i in train:
          name = index_site_new[i]
          dist_train[str(group + 1)].append(name)
        for j in validation:
          name = index_site_new[j]
          dist_validation[str(group + 1)].append(name)
        group = group+1
  
  
  data = {}
  for fold in range(1, k_fold+1):
    data[str(fold)] = []
    selector = feature_selection(sMRI_features, labels, dist_train[str(fold)], new_number_features)
    fold_data = selector.transform(sMRI_features)

    n = fold_data.shape[0]
    num_edge = n * n
    edge_index = np.zeros([2, num_edge], dtype=np.int64)
    edgenet_input = np.zeros([num_edge, 1], dtype=np.float32) 
    aff_score = np.zeros(num_edge, dtype=np.float32)
    flatten_ind = 0

    for i in range(n): 
      for j in range(n):
        edge_index[:, flatten_ind] = [i, j]
        edgenet_input[flatten_ind] = graph[i,j]
        aff_score[flatten_ind] = graph[i,j]
        flatten_ind += 1


    keep_ind = np.where(aff_score > 0.99)[0]
    edge_index = edge_index[:, keep_ind]
    edgenet_input = edgenet_input[keep_ind]

    data[str(fold)].append(fold_data)
    data[str(fold)].append(GCN_labels)
    data[str(fold)].append(edge_index)
    data[str(fold)].append(edgenet_input)




  ############################################### Train ###############################################################
  ############################################### Train ###############################################################
  ############################################### Train ###############################################################

  model_1 = GCN(in_c=args.input_dimension, hid_c=args.hidden_dimension, out_c=args.output_dimension, K=args.cheby_order_K, dropout_rate=args.dropout_rate)
  model_2 = GCN(in_c=args.input_dimension, hid_c=args.hidden_dimension, out_c=args.output_dimension, K=args.cheby_order_K, dropout_rate=args.dropout_rate)
  model_3 = GCN(in_c=args.input_dimension, hid_c=args.hidden_dimension, out_c=args.output_dimension, K=args.cheby_order_K, dropout_rate=args.dropout_rate)
  model_4 = GCN(in_c=args.input_dimension, hid_c=args.hidden_dimension, out_c=args.output_dimension, K=args.cheby_order_K, dropout_rate=args.dropout_rate)
  model_5 = GCN(in_c=args.input_dimension, hid_c=args.hidden_dimension, out_c=args.output_dimension, K=args.cheby_order_K, dropout_rate=args.dropout_rate)

  gpu_ids = range(args.ngpu)
  model_1 = nn.parallel.DataParallel(model_1, device_ids=gpu_ids)
  model_2 = nn.parallel.DataParallel(model_2, device_ids=gpu_ids)
  model_3 = nn.parallel.DataParallel(model_3, device_ids=gpu_ids)
  model_4 = nn.parallel.DataParallel(model_4, device_ids=gpu_ids)
  model_5 = nn.parallel.DataParallel(model_5, device_ids=gpu_ids)
  train = train_GCN

  print('  + Number of params: {}'.format(
      sum([p.data.nelement() for p in model_1.parameters()])))
  if args.cuda:
      model_1 = model_1.cuda()
      model_2 = model_2.cuda()
      model_3 = model_3.cuda()
      model_4 = model_4.cuda()
      model_5 = model_5.cuda()

  optimizer_1 = optim.Adam(model_1.parameters(), lr = args.lr, weight_decay=0.1)
  optimizer_2 = optim.Adam(model_2.parameters(), lr = args.lr, weight_decay=0.1)
  optimizer_3 = optim.Adam(model_3.parameters(), lr = args.lr, weight_decay=0.1)
  optimizer_4 = optim.Adam(model_4.parameters(), lr = args.lr, weight_decay=0.1)
  optimizer_5 = optim.Adam(model_5.parameters(), lr = args.lr, weight_decay=0.1)

  Train_accuracy_list =[]
  Train_loss_list = []
  Val_accuracy_list =[]
  Val_loss_list = []
  Test_accuracy_list =[]
  Test_loss_list = []
  best_validation_accuracy = 0

  for epoch in range(1, args.nEpochs + 1):


    model_1, train_target_1, train_out_1, train_loss_1, val_target_1, val_out_1, val_loss_1, test_target_1, test_out_1, test_prob_1, test_loss_1 = train(args, model_1, data['1'], dist_train['1'], dist_validation['1'], dist_test['1'], optimizer_1)
    model_2, train_target_2, train_out_2, train_loss_2, val_target_2, val_out_2, val_loss_2, test_target_2, test_out_2, test_prob_2, test_loss_2 = train(args, model_2, data['2'], dist_train['2'], dist_validation['2'], dist_test['2'], optimizer_2)
    model_3, train_target_3, train_out_3, train_loss_3, val_target_3, val_out_3, val_loss_3, test_target_3, test_out_3, test_prob_3, test_loss_3 = train(args, model_3, data['3'], dist_train['3'], dist_validation['3'], dist_test['3'], optimizer_3)
    model_4, train_target_4, train_out_4, train_loss_4, val_target_4, val_out_4, val_loss_4, test_target_4, test_out_4, test_prob_4, test_loss_4 = train(args, model_4, data['4'], dist_train['4'], dist_validation['4'], dist_test['4'], optimizer_4)
    model_5, train_target_5, train_out_5, train_loss_5, val_target_5, val_out_5, val_loss_5, test_target_5, test_out_5, test_prob_5, test_loss_5 = train(args, model_5, data['5'], dist_train['5'], dist_validation['5'], dist_test['5'], optimizer_5)

    train_target_all = np.concatenate((train_target_1, train_target_2, train_target_3, train_target_4, train_target_5),axis = 0)
    train_out_all = np.concatenate((train_out_1, train_out_2, train_out_3, train_out_4, train_out_5),axis = 0)
    train_loss = (train_loss_1 + train_loss_2 + train_loss_3 + train_loss_4 + train_loss_5)/5
    val_target_all = np.concatenate((val_target_1, val_target_2, val_target_3, val_target_4, val_target_5),axis = 0)
    val_out_all = np.concatenate((val_out_1, val_out_2, val_out_3, val_out_4, val_out_5),axis = 0)
    val_loss = (val_loss_1 + val_loss_2 + val_loss_3 + val_loss_4 + val_loss_5)/5
    test_target_all = test_target_1 # test_target_1 = test_target_2 = test_target_3 = test_target_4 = test_target_5
    test_out_all = test_out_1 + test_out_2 + test_out_3 + test_out_4 + test_out_5
    test_prob_all = (test_prob_1 + test_prob_2 + test_prob_3 + test_prob_4 + test_prob_5)/5
    test_loss = (test_loss_1 + test_loss_2 + test_loss_3 + test_loss_4 + test_loss_5)/5

    test_results_binary = np.zeros_like((test_out_all))
    test_results_binary[test_out_all<2.5] = 0
    test_results_binary[test_out_all>=2.5] = 1

    train_accuracy = metrics.accuracy_score(train_target_all, train_out_all)
    val_accuracy = metrics.accuracy_score(val_target_all, val_out_all)
    test_accuracy = metrics.accuracy_score(test_target_all, test_results_binary)
    Train_accuracy_list.append(train_accuracy)
    Val_accuracy_list.append(val_accuracy)
    Test_accuracy_list.append(test_accuracy)
    Train_loss_list.append(train_loss)
    Val_loss_list.append(val_loss)
    Test_loss_list.append(test_loss)

    if val_accuracy >=best_validation_accuracy:
      best_epoch = epoch
      best_validation_accuracy = val_accuracy
      corresponding_test_accuracy = test_accuracy
      corresponding_test_prob = test_prob_all
      corresponding_test_labels = test_target_all
      corresponding_test_out = test_results_binary
      print('Save models')

      save_model(model_1, save_ensemble_models_path, 'GCN_ensemble' + str(ensemble_fold) + '_1')
      save_model(model_2, save_ensemble_models_path, 'GCN_ensemble' + str(ensemble_fold) + '_2')
      save_model(model_3, save_ensemble_models_path, 'GCN_ensemble' + str(ensemble_fold) + '_3')
      save_model(model_4, save_ensemble_models_path, 'GCN_ensemble' + str(ensemble_fold) + '_4')
      save_model(model_5, save_ensemble_models_path, 'GCN_ensemble' + str(ensemble_fold) + '_5')

    print('Train Epoch: ' + str(epoch) + ': train loss : {:.8f}\t train accuracy : {:.8f}\t val accuracy : {:.8f}\t test accuracy : {:.8f}\t'.format(
      train_loss, train_accuracy, val_accuracy, test_accuracy))

  x_axis = list(range(1, len(Train_accuracy_list)+1))
  plt.figure(figsize=(15,10))
  plt.plot(x_axis, Train_loss_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_loss_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_loss_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()

  plt.figure(figsize=(15,10))
  plt.plot(x_axis, Train_accuracy_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_accuracy_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_accuracy_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()
 
  test_fpr, test_tpr, te_thresholds = roc_curve(corresponding_test_labels, corresponding_test_prob[:,1],pos_label=1)
  test_auc = auc(test_fpr, test_tpr)
  print('\n')
  print('In ensemble ',ensemble_fold+1)
  print('The best validaiton accuracy is: ',best_validation_accuracy)
  print('Happened at epoch: ',best_epoch)
  print('The corresponding test accuracy', corresponding_test_accuracy)
  print('The corresponding test AUC is: ',test_auc)
  print('\n')


  plt.grid()
  plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
  plt.plot([0,1],[0,1],'g--')
  plt.legend()
  plt.xlabel("False Positive Rate")
  plt.ylabel("True Positive Rate")
  plt.title("Test AUC(ROC curve)")
  plt.grid(color='black', linestyle='-', linewidth=0.5)
  plt.show()


  dist_ensemble_test_label[str(ensemble_fold+1)] = corresponding_test_labels
  dist_ensemble_test_result[str(ensemble_fold+1)] = corresponding_test_out
  dist_ensemble_test_prob[str(ensemble_fold+1)] = corresponding_test_prob
  print('\n')

  torch.cuda.empty_cache()

test_labels_concat = np.concatenate((dist_ensemble_test_label['1'], dist_ensemble_test_label['2'],  dist_ensemble_test_label['3'], dist_ensemble_test_label['4'], dist_ensemble_test_label['5']),axis = 0)
test_results_concat = np.concatenate((dist_ensemble_test_result['1'], dist_ensemble_test_result['2'],  dist_ensemble_test_result['3'], dist_ensemble_test_result['4'], dist_ensemble_test_result['5']),axis = 0)
test_probs_concat = np.concatenate((dist_ensemble_test_prob['1'], dist_ensemble_test_prob['2'],  dist_ensemble_test_prob['3'], dist_ensemble_test_prob['4'], dist_ensemble_test_prob['5']),axis = 0)

test_accuracy = metrics.accuracy_score(test_labels_concat, test_results_concat)
test_fpr, test_tpr, te_thresholds = roc_curve(test_labels_concat, test_probs_concat[:,1],pos_label=1)
test_auc = auc(test_fpr, test_tpr)
print('The Max voting test accuracy is: ',test_accuracy)
print('The test AUC is: ',test_auc)

print('\n')
print('\n')
plt.grid()
plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
plt.plot([0,1],[0,1],'g--')
plt.legend()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Test AUC(ROC curve)")
plt.grid(color='black', linestyle='-', linewidth=0.5)
plt.show()
# Out:
# Ensemble  1
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
#   + Number of params: 400898
# Save models
# Train Epoch: 1: train loss : 1.13549043	 train accuracy : 0.50981818	 val accuracy : 0.53188406	 test accuracy : 0.53846154
# Train Epoch: 2: train loss : 0.86873875	 train accuracy : 0.52400000	 val accuracy : 0.51884058	 test accuracy : 0.54395604
# Save models
# Train Epoch: 3: train loss : 0.82243730	 train accuracy : 0.56363636	 val accuracy : 0.53333333	 test accuracy : 0.56043956
# Save models
# Train Epoch: 4: train loss : 0.79459965	 train accuracy : 0.57963636	 val accuracy : 0.55072464	 test accuracy : 0.58241758
# Save models
# Train Epoch: 5: train loss : 0.72483320	 train accuracy : 0.60400000	 val accuracy : 0.56666667	 test accuracy : 0.58791209
# Save models
# Train Epoch: 6: train loss : 0.65501144	 train accuracy : 0.65200000	 val accuracy : 0.58405797	 test accuracy : 0.57142857
# Save models
# Train Epoch: 7: train loss : 0.64714198	 train accuracy : 0.64618182	 val accuracy : 0.60289855	 test accuracy : 0.62087912
# Train Epoch: 8: train loss : 0.62035873	 train accuracy : 0.67018182	 val accuracy : 0.59130435	 test accuracy : 0.61538462
# Train Epoch: 9: train loss : 0.58777233	 train accuracy : 0.69600000	 val accuracy : 0.58695652	 test accuracy : 0.60989011
# Train Epoch: 10: train loss : 0.57422535	 train accuracy : 0.69490909	 val accuracy : 0.58695652	 test accuracy : 0.62087912
# Train Epoch: 11: train loss : 0.56196308	 train accuracy : 0.71527273	 val accuracy : 0.59565217	 test accuracy : 0.62637363
# Train Epoch: 12: train loss : 0.53770092	 train accuracy : 0.73672727	 val accuracy : 0.60144928	 test accuracy : 0.67032967
# Save models
# Train Epoch: 13: train loss : 0.52440981	 train accuracy : 0.73200000	 val accuracy : 0.60579710	 test accuracy : 0.64285714
# Save models
# Train Epoch: 14: train loss : 0.50331190	 train accuracy : 0.76036364	 val accuracy : 0.60869565	 test accuracy : 0.63736264
# Save models
# Train Epoch: 15: train loss : 0.49272326	 train accuracy : 0.76800000	 val accuracy : 0.61594203	 test accuracy : 0.62087912
# Save models
# Train Epoch: 16: train loss : 0.48673932	 train accuracy : 0.77345455	 val accuracy : 0.61739130	 test accuracy : 0.61538462
# Train Epoch: 17: train loss : 0.46979836	 train accuracy : 0.79600000	 val accuracy : 0.61014493	 test accuracy : 0.60989011
# Train Epoch: 18: train loss : 0.47231758	 train accuracy : 0.79272727	 val accuracy : 0.60289855	 test accuracy : 0.62087912
# Train Epoch: 19: train loss : 0.45844145	 train accuracy : 0.80436364	 val accuracy : 0.60724638	 test accuracy : 0.63736264
# Train Epoch: 20: train loss : 0.44514030	 train accuracy : 0.81309091	 val accuracy : 0.60869565	 test accuracy : 0.59340659
# Save models
# Train Epoch: 21: train loss : 0.44537748	 train accuracy : 0.81345455	 val accuracy : 0.61884058	 test accuracy : 0.59890110
# Save models
# Train Epoch: 22: train loss : 0.43363183	 train accuracy : 0.82363636	 val accuracy : 0.62318841	 test accuracy : 0.60989011
# Save models
# Train Epoch: 23: train loss : 0.42252302	 train accuracy : 0.84290909	 val accuracy : 0.62608696	 test accuracy : 0.59340659
# Train Epoch: 24: train loss : 0.41286443	 train accuracy : 0.85381818	 val accuracy : 0.62173913	 test accuracy : 0.59340659
# Save models
# Train Epoch: 25: train loss : 0.41011326	 train accuracy : 0.84872727	 val accuracy : 0.62753623	 test accuracy : 0.60439560
# Train Epoch: 26: train loss : 0.39832949	 train accuracy : 0.86545455	 val accuracy : 0.62028986	 test accuracy : 0.60989011
# Train Epoch: 27: train loss : 0.38802398	 train accuracy : 0.87381818	 val accuracy : 0.62028986	 test accuracy : 0.62087912
# Train Epoch: 28: train loss : 0.38369052	 train accuracy : 0.87818182	 val accuracy : 0.62463768	 test accuracy : 0.61538462
# Save models
# Train Epoch: 29: train loss : 0.37695192	 train accuracy : 0.87854545	 val accuracy : 0.63333333	 test accuracy : 0.60989011
# Train Epoch: 30: train loss : 0.37006481	 train accuracy : 0.89236364	 val accuracy : 0.63188406	 test accuracy : 0.61538462
# Save models
# Train Epoch: 31: train loss : 0.35706089	 train accuracy : 0.90690909	 val accuracy : 0.64057971	 test accuracy : 0.61538462
# Save models
# Train Epoch: 32: train loss : 0.35774445	 train accuracy : 0.90254545	 val accuracy : 0.64347826	 test accuracy : 0.60989011
# Train Epoch: 33: train loss : 0.35724344	 train accuracy : 0.90145455	 val accuracy : 0.63768116	 test accuracy : 0.60989011
# Train Epoch: 34: train loss : 0.34781544	 train accuracy : 0.90800000	 val accuracy : 0.63188406	 test accuracy : 0.60989011
# Train Epoch: 35: train loss : 0.33518625	 train accuracy : 0.92581818	 val accuracy : 0.63188406	 test accuracy : 0.60439560
# Train Epoch: 36: train loss : 0.32615961	 train accuracy : 0.92254545	 val accuracy : 0.63623188	 test accuracy : 0.61538462
# Train Epoch: 37: train loss : 0.32866177	 train accuracy : 0.92327273	 val accuracy : 0.62318841	 test accuracy : 0.61538462
# Train Epoch: 38: train loss : 0.31770609	 train accuracy : 0.92472727	 val accuracy : 0.61884058	 test accuracy : 0.60989011
# Train Epoch: 39: train loss : 0.31421579	 train accuracy : 0.93163636	 val accuracy : 0.62173913	 test accuracy : 0.60439560
# Train Epoch: 40: train loss : 0.30531086	 train accuracy : 0.93563636	 val accuracy : 0.62608696	 test accuracy : 0.60439560
# Train Epoch: 41: train loss : 0.30041344	 train accuracy : 0.93890909	 val accuracy : 0.62173913	 test accuracy : 0.60989011
# Train Epoch: 42: train loss : 0.29193100	 train accuracy : 0.94436364	 val accuracy : 0.62463768	 test accuracy : 0.61538462
# Train Epoch: 43: train loss : 0.28969582	 train accuracy : 0.94400000	 val accuracy : 0.62318841	 test accuracy : 0.62087912
# Train Epoch: 44: train loss : 0.28334544	 train accuracy : 0.94545455	 val accuracy : 0.62463768	 test accuracy : 0.60989011
# Train Epoch: 45: train loss : 0.27582412	 train accuracy : 0.95309091	 val accuracy : 0.62753623	 test accuracy : 0.60989011
# Train Epoch: 46: train loss : 0.27509118	 train accuracy : 0.95418182	 val accuracy : 0.62608696	 test accuracy : 0.61538462
# Train Epoch: 47: train loss : 0.26782937	 train accuracy : 0.95963636	 val accuracy : 0.62173913	 test accuracy : 0.62637363
# Train Epoch: 48: train loss : 0.25215714	 train accuracy : 0.96545455	 val accuracy : 0.62173913	 test accuracy : 0.62637363
# Train Epoch: 49: train loss : 0.25136988	 train accuracy : 0.97163636	 val accuracy : 0.61594203	 test accuracy : 0.63186813
# Train Epoch: 50: train loss : 0.25041392	 train accuracy : 0.96581818	 val accuracy : 0.61884058	 test accuracy : 0.62637363
# Train Epoch: 51: train loss : 0.24058609	 train accuracy : 0.96509091	 val accuracy : 0.62028986	 test accuracy : 0.61538462
# Train Epoch: 52: train loss : 0.23526026	 train accuracy : 0.96872727	 val accuracy : 0.61739130	 test accuracy : 0.60989011
# Train Epoch: 53: train loss : 0.23393052	 train accuracy : 0.97563636	 val accuracy : 0.61449275	 test accuracy : 0.59340659
# Train Epoch: 54: train loss : 0.22779849	 train accuracy : 0.97418182	 val accuracy : 0.61014493	 test accuracy : 0.59890110
# Train Epoch: 55: train loss : 0.22354545	 train accuracy : 0.97600000	 val accuracy : 0.61594203	 test accuracy : 0.62087912
# Train Epoch: 56: train loss : 0.22198807	 train accuracy : 0.97563636	 val accuracy : 0.62028986	 test accuracy : 0.64285714
# Train Epoch: 57: train loss : 0.21122038	 train accuracy : 0.98436364	 val accuracy : 0.61739130	 test accuracy : 0.63186813
# Train Epoch: 58: train loss : 0.21103752	 train accuracy : 0.97600000	 val accuracy : 0.61594203	 test accuracy : 0.63186813
# Train Epoch: 59: train loss : 0.20447428	 train accuracy : 0.98000000	 val accuracy : 0.61884058	 test accuracy : 0.62637363
# Train Epoch: 60: train loss : 0.20079717	 train accuracy : 0.98290909	 val accuracy : 0.61884058	 test accuracy : 0.63186813
# Train Epoch: 61: train loss : 0.19348065	 train accuracy : 0.98509091	 val accuracy : 0.61014493	 test accuracy : 0.63186813
# Train Epoch: 62: train loss : 0.19377602	 train accuracy : 0.98472727	 val accuracy : 0.61739130	 test accuracy : 0.62637363
# Train Epoch: 63: train loss : 0.18881813	 train accuracy : 0.98727273	 val accuracy : 0.61884058	 test accuracy : 0.62637363
# Train Epoch: 64: train loss : 0.18535029	 train accuracy : 0.98800000	 val accuracy : 0.62028986	 test accuracy : 0.63186813
# Train Epoch: 65: train loss : 0.17899043	 train accuracy : 0.99163636	 val accuracy : 0.61739130	 test accuracy : 0.63736264
# Train Epoch: 66: train loss : 0.17730231	 train accuracy : 0.98472727	 val accuracy : 0.61594203	 test accuracy : 0.61538462
# Train Epoch: 67: train loss : 0.16844862	 train accuracy : 0.99054545	 val accuracy : 0.61594203	 test accuracy : 0.62087912
# Train Epoch: 68: train loss : 0.17285033	 train accuracy : 0.98909091	 val accuracy : 0.61884058	 test accuracy : 0.63736264
# Train Epoch: 69: train loss : 0.16827452	 train accuracy : 0.98981818	 val accuracy : 0.61014493	 test accuracy : 0.64285714
# Train Epoch: 70: train loss : 0.16428425	 train accuracy : 0.99272727	 val accuracy : 0.61594203	 test accuracy : 0.63736264
# Train Epoch: 71: train loss : 0.16036450	 train accuracy : 0.99090909	 val accuracy : 0.61304348	 test accuracy : 0.64285714
# Train Epoch: 72: train loss : 0.15951228	 train accuracy : 0.99381818	 val accuracy : 0.61594203	 test accuracy : 0.64285714
# Train Epoch: 73: train loss : 0.16042455	 train accuracy : 0.99090909	 val accuracy : 0.61304348	 test accuracy : 0.64285714
# Train Epoch: 74: train loss : 0.15282340	 train accuracy : 0.99345455	 val accuracy : 0.61449275	 test accuracy : 0.65934066
# Train Epoch: 75: train loss : 0.15232070	 train accuracy : 0.99490909	 val accuracy : 0.61449275	 test accuracy : 0.64835165
# Train Epoch: 76: train loss : 0.14951648	 train accuracy : 0.99309091	 val accuracy : 0.61304348	 test accuracy : 0.63736264
# Train Epoch: 77: train loss : 0.14798319	 train accuracy : 0.99636364	 val accuracy : 0.61449275	 test accuracy : 0.62087912
# Train Epoch: 78: train loss : 0.14888383	 train accuracy : 0.99600000	 val accuracy : 0.61594203	 test accuracy : 0.63736264
# Train Epoch: 79: train loss : 0.14488918	 train accuracy : 0.99527273	 val accuracy : 0.61304348	 test accuracy : 0.64835165
# Train Epoch: 80: train loss : 0.14329447	 train accuracy : 0.99636364	 val accuracy : 0.60869565	 test accuracy : 0.64285714
# Train Epoch: 81: train loss : 0.14163924	 train accuracy : 0.99745455	 val accuracy : 0.61159420	 test accuracy : 0.63186813
# Train Epoch: 82: train loss : 0.14056786	 train accuracy : 0.99854545	 val accuracy : 0.60869565	 test accuracy : 0.63186813
# Train Epoch: 83: train loss : 0.14092073	 train accuracy : 0.99563636	 val accuracy : 0.60869565	 test accuracy : 0.62087912
# Train Epoch: 84: train loss : 0.13876848	 train accuracy : 0.99636364	 val accuracy : 0.61304348	 test accuracy : 0.62637363
# Train Epoch: 85: train loss : 0.13578382	 train accuracy : 0.99527273	 val accuracy : 0.61594203	 test accuracy : 0.61538462
# Train Epoch: 86: train loss : 0.13763654	 train accuracy : 0.99600000	 val accuracy : 0.61159420	 test accuracy : 0.62637363
# Train Epoch: 87: train loss : 0.13425417	 train accuracy : 0.99709091	 val accuracy : 0.60869565	 test accuracy : 0.62637363
# Train Epoch: 88: train loss : 0.13328258	 train accuracy : 0.99600000	 val accuracy : 0.61014493	 test accuracy : 0.62637363
# Train Epoch: 89: train loss : 0.13085963	 train accuracy : 0.99854545	 val accuracy : 0.60724638	 test accuracy : 0.63186813
# Train Epoch: 90: train loss : 0.13038965	 train accuracy : 0.99818182	 val accuracy : 0.61304348	 test accuracy : 0.64835165
# Train Epoch: 91: train loss : 0.13085299	 train accuracy : 0.99818182	 val accuracy : 0.62028986	 test accuracy : 0.63736264
# Train Epoch: 92: train loss : 0.13029954	 train accuracy : 0.99745455	 val accuracy : 0.61449275	 test accuracy : 0.63186813
# Train Epoch: 93: train loss : 0.12756961	 train accuracy : 0.99927273	 val accuracy : 0.60434783	 test accuracy : 0.62637363
# Train Epoch: 94: train loss : 0.12616686	 train accuracy : 0.99890909	 val accuracy : 0.60144928	 test accuracy : 0.61538462
# Train Epoch: 95: train loss : 0.12676309	 train accuracy : 0.99636364	 val accuracy : 0.60579710	 test accuracy : 0.62087912
# Train Epoch: 96: train loss : 0.12671208	 train accuracy : 0.99781818	 val accuracy : 0.61304348	 test accuracy : 0.63736264
# Train Epoch: 97: train loss : 0.12769483	 train accuracy : 0.99854545	 val accuracy : 0.60434783	 test accuracy : 0.63736264
# Train Epoch: 98: train loss : 0.12375070	 train accuracy : 0.99854545	 val accuracy : 0.60869565	 test accuracy : 0.64285714
# Train Epoch: 99: train loss : 0.12333322	 train accuracy : 0.99709091	 val accuracy : 0.60434783	 test accuracy : 0.60989011
# Train Epoch: 100: train loss : 0.12288823	 train accuracy : 0.99745455	 val accuracy : 0.60144928	 test accuracy : 0.60989011
# Train Epoch: 101: train loss : 0.12113035	 train accuracy : 0.99781818	 val accuracy : 0.61449275	 test accuracy : 0.62087912
# Train Epoch: 102: train loss : 0.11967319	 train accuracy : 0.99745455	 val accuracy : 0.60579710	 test accuracy : 0.62087912
# Train Epoch: 103: train loss : 0.12480890	 train accuracy : 0.99781818	 val accuracy : 0.60724638	 test accuracy : 0.61538462
# Train Epoch: 104: train loss : 0.12189675	 train accuracy : 0.99709091	 val accuracy : 0.61014493	 test accuracy : 0.63736264
# Train Epoch: 105: train loss : 0.11906354	 train accuracy : 0.99890909	 val accuracy : 0.61014493	 test accuracy : 0.62087912
# Train Epoch: 106: train loss : 0.11873854	 train accuracy : 0.99781818	 val accuracy : 0.61014493	 test accuracy : 0.62087912
# Train Epoch: 107: train loss : 0.11720312	 train accuracy : 0.99745455	 val accuracy : 0.61159420	 test accuracy : 0.60989011
# Train Epoch: 108: train loss : 0.11911817	 train accuracy : 0.99854545	 val accuracy : 0.61304348	 test accuracy : 0.61538462
# Train Epoch: 109: train loss : 0.11911515	 train accuracy : 0.99818182	 val accuracy : 0.61594203	 test accuracy : 0.61538462
# Train Epoch: 110: train loss : 0.11729778	 train accuracy : 0.99927273	 val accuracy : 0.60869565	 test accuracy : 0.61538462
# Train Epoch: 111: train loss : 0.11878644	 train accuracy : 0.99818182	 val accuracy : 0.60869565	 test accuracy : 0.60989011
# Train Epoch: 112: train loss : 0.11645918	 train accuracy : 0.99890909	 val accuracy : 0.60724638	 test accuracy : 0.60439560
# Train Epoch: 113: train loss : 0.11673428	 train accuracy : 0.99672727	 val accuracy : 0.61304348	 test accuracy : 0.63186813
# Train Epoch: 114: train loss : 0.11346519	 train accuracy : 0.99854545	 val accuracy : 0.60869565	 test accuracy : 0.60989011
# Train Epoch: 115: train loss : 0.11794886	 train accuracy : 0.99818182	 val accuracy : 0.60000000	 test accuracy : 0.60989011
# Train Epoch: 116: train loss : 0.11659798	 train accuracy : 0.99818182	 val accuracy : 0.60289855	 test accuracy : 0.60439560
# Train Epoch: 117: train loss : 0.11471071	 train accuracy : 0.99927273	 val accuracy : 0.61014493	 test accuracy : 0.61538462
# Train Epoch: 118: train loss : 0.11528458	 train accuracy : 0.99781818	 val accuracy : 0.61304348	 test accuracy : 0.61538462
# Train Epoch: 119: train loss : 0.11464088	 train accuracy : 0.99709091	 val accuracy : 0.61304348	 test accuracy : 0.63736264
# Train Epoch: 120: train loss : 0.11157860	 train accuracy : 1.00000000	 val accuracy : 0.60724638	 test accuracy : 0.63186813
# Train Epoch: 121: train loss : 0.11372434	 train accuracy : 0.99890909	 val accuracy : 0.60579710	 test accuracy : 0.59890110
# Train Epoch: 122: train loss : 0.11445460	 train accuracy : 0.99854545	 val accuracy : 0.60000000	 test accuracy : 0.60989011
# Train Epoch: 123: train loss : 0.11220023	 train accuracy : 0.99927273	 val accuracy : 0.60434783	 test accuracy : 0.61538462
# Train Epoch: 124: train loss : 0.11102318	 train accuracy : 0.99890909	 val accuracy : 0.60724638	 test accuracy : 0.61538462
# Train Epoch: 125: train loss : 0.11187039	 train accuracy : 0.99854545	 val accuracy : 0.61594203	 test accuracy : 0.63186813
# Train Epoch: 126: train loss : 0.10928817	 train accuracy : 0.99890909	 val accuracy : 0.60144928	 test accuracy : 0.63186813
# Train Epoch: 127: train loss : 0.11171553	 train accuracy : 0.99854545	 val accuracy : 0.60144928	 test accuracy : 0.60989011
# Train Epoch: 128: train loss : 0.11292295	 train accuracy : 0.99818182	 val accuracy : 0.60000000	 test accuracy : 0.60439560
# Train Epoch: 129: train loss : 0.10992796	 train accuracy : 0.99890909	 val accuracy : 0.60724638	 test accuracy : 0.60989011
# Train Epoch: 130: train loss : 0.11009212	 train accuracy : 0.99890909	 val accuracy : 0.60434783	 test accuracy : 0.61538462
# Train Epoch: 131: train loss : 0.10967951	 train accuracy : 0.99818182	 val accuracy : 0.60289855	 test accuracy : 0.62087912
# Train Epoch: 132: train loss : 0.11070862	 train accuracy : 0.99890909	 val accuracy : 0.60289855	 test accuracy : 0.61538462
# Train Epoch: 133: train loss : 0.11005601	 train accuracy : 0.99854545	 val accuracy : 0.60144928	 test accuracy : 0.59340659
# Train Epoch: 134: train loss : 0.10884903	 train accuracy : 0.99890909	 val accuracy : 0.60144928	 test accuracy : 0.60439560
# Train Epoch: 135: train loss : 0.10870479	 train accuracy : 0.99890909	 val accuracy : 0.59855072	 test accuracy : 0.61538462
# Train Epoch: 136: train loss : 0.11049534	 train accuracy : 0.99927273	 val accuracy : 0.60144928	 test accuracy : 0.62087912
# Train Epoch: 137: train loss : 0.10881355	 train accuracy : 0.99854545	 val accuracy : 0.60144928	 test accuracy : 0.62637363
# Train Epoch: 138: train loss : 0.10532103	 train accuracy : 0.99818182	 val accuracy : 0.60000000	 test accuracy : 0.60989011
# Train Epoch: 139: train loss : 0.10871364	 train accuracy : 0.99818182	 val accuracy : 0.60144928	 test accuracy : 0.60989011
# Train Epoch: 140: train loss : 0.10729445	 train accuracy : 0.99927273	 val accuracy : 0.60434783	 test accuracy : 0.61538462
# Train Epoch: 141: train loss : 0.10738241	 train accuracy : 1.00000000	 val accuracy : 0.60144928	 test accuracy : 0.62087912
# Train Epoch: 142: train loss : 0.10534227	 train accuracy : 0.99854545	 val accuracy : 0.60579710	 test accuracy : 0.62637363
# Train Epoch: 143: train loss : 0.10772324	 train accuracy : 0.99890909	 val accuracy : 0.60434783	 test accuracy : 0.62087912
# Train Epoch: 144: train loss : 0.11011496	 train accuracy : 0.99854545	 val accuracy : 0.60579710	 test accuracy : 0.61538462
# Train Epoch: 145: train loss : 0.10795272	 train accuracy : 0.99854545	 val accuracy : 0.60000000	 test accuracy : 0.60989011
# Train Epoch: 146: train loss : 0.10932302	 train accuracy : 0.99927273	 val accuracy : 0.60144928	 test accuracy : 0.62087912
# Train Epoch: 147: train loss : 0.10774965	 train accuracy : 0.99818182	 val accuracy : 0.59855072	 test accuracy : 0.62087912
# Train Epoch: 148: train loss : 0.10689110	 train accuracy : 0.99890909	 val accuracy : 0.60434783	 test accuracy : 0.62637363
# Train Epoch: 149: train loss : 0.10802290	 train accuracy : 0.99927273	 val accuracy : 0.60579710	 test accuracy : 0.61538462
# Train Epoch: 150: train loss : 0.10673846	 train accuracy : 0.99818182	 val accuracy : 0.60579710	 test accuracy : 0.62087912
# Train Epoch: 151: train loss : 0.10477480	 train accuracy : 0.99927273	 val accuracy : 0.59855072	 test accuracy : 0.61538462
# Train Epoch: 152: train loss : 0.10768707	 train accuracy : 0.99854545	 val accuracy : 0.60289855	 test accuracy : 0.61538462
# Train Epoch: 153: train loss : 0.10637525	 train accuracy : 0.99854545	 val accuracy : 0.60579710	 test accuracy : 0.62087912
# Train Epoch: 154: train loss : 0.10493179	 train accuracy : 1.00000000	 val accuracy : 0.60579710	 test accuracy : 0.62087912
# Train Epoch: 155: train loss : 0.10642552	 train accuracy : 0.99854545	 val accuracy : 0.60434783	 test accuracy : 0.61538462
# Train Epoch: 156: train loss : 0.10484261	 train accuracy : 0.99963636	 val accuracy : 0.59130435	 test accuracy : 0.59340659
# Train Epoch: 157: train loss : 0.10500774	 train accuracy : 0.99818182	 val accuracy : 0.59565217	 test accuracy : 0.60989011
# Train Epoch: 158: train loss : 0.10617207	 train accuracy : 0.99927273	 val accuracy : 0.61014493	 test accuracy : 0.62087912
# Train Epoch: 159: train loss : 0.10485475	 train accuracy : 0.99963636	 val accuracy : 0.60434783	 test accuracy : 0.63186813
# Train Epoch: 160: train loss : 0.10438539	 train accuracy : 0.99854545	 val accuracy : 0.60434783	 test accuracy : 0.62087912
# Train Epoch: 161: train loss : 0.10554604	 train accuracy : 0.99927273	 val accuracy : 0.59710145	 test accuracy : 0.62087912
# Train Epoch: 162: train loss : 0.10527288	 train accuracy : 0.99890909	 val accuracy : 0.60000000	 test accuracy : 0.62637363
# Train Epoch: 163: train loss : 0.10604959	 train accuracy : 0.99963636	 val accuracy : 0.60000000	 test accuracy : 0.61538462
# Train Epoch: 164: train loss : 0.10279233	 train accuracy : 0.99890909	 val accuracy : 0.59855072	 test accuracy : 0.61538462
# Train Epoch: 165: train loss : 0.10283860	 train accuracy : 0.99963636	 val accuracy : 0.59565217	 test accuracy : 0.59890110
# Train Epoch: 166: train loss : 0.10393315	 train accuracy : 0.99963636	 val accuracy : 0.59710145	 test accuracy : 0.59890110
# Train Epoch: 167: train loss : 0.10603534	 train accuracy : 0.99854545	 val accuracy : 0.59275362	 test accuracy : 0.60439560
# Train Epoch: 168: train loss : 0.10430207	 train accuracy : 0.99890909	 val accuracy : 0.60289855	 test accuracy : 0.60439560
# Train Epoch: 169: train loss : 0.10646522	 train accuracy : 0.99890909	 val accuracy : 0.60144928	 test accuracy : 0.61538462
# Train Epoch: 170: train loss : 0.10404946	 train accuracy : 0.99854545	 val accuracy : 0.59565217	 test accuracy : 0.61538462
# Train Epoch: 171: train loss : 0.10426274	 train accuracy : 0.99927273	 val accuracy : 0.60144928	 test accuracy : 0.62637363
# Train Epoch: 172: train loss : 0.10231885	 train accuracy : 0.99963636	 val accuracy : 0.61449275	 test accuracy : 0.61538462
# Train Epoch: 173: train loss : 0.10399097	 train accuracy : 0.99927273	 val accuracy : 0.61449275	 test accuracy : 0.62087912
# Train Epoch: 174: train loss : 0.10478142	 train accuracy : 0.99854545	 val accuracy : 0.60579710	 test accuracy : 0.62087912
# Train Epoch: 175: train loss : 0.10286766	 train accuracy : 0.99963636	 val accuracy : 0.60434783	 test accuracy : 0.62087912
# Train Epoch: 176: train loss : 0.10515956	 train accuracy : 1.00000000	 val accuracy : 0.60289855	 test accuracy : 0.62087912
# Train Epoch: 177: train loss : 0.10256121	 train accuracy : 1.00000000	 val accuracy : 0.59855072	 test accuracy : 0.63736264
# Train Epoch: 178: train loss : 0.10357944	 train accuracy : 0.99927273	 val accuracy : 0.60434783	 test accuracy : 0.61538462
# Train Epoch: 179: train loss : 0.10378711	 train accuracy : 0.99890909	 val accuracy : 0.59275362	 test accuracy : 0.60989011
# Train Epoch: 180: train loss : 0.10321354	 train accuracy : 0.99927273	 val accuracy : 0.60434783	 test accuracy : 0.60439560
# Train Epoch: 181: train loss : 0.10184917	 train accuracy : 0.99890909	 val accuracy : 0.60724638	 test accuracy : 0.60989011
# Train Epoch: 182: train loss : 0.10144026	 train accuracy : 0.99890909	 val accuracy : 0.60724638	 test accuracy : 0.61538462
# Train Epoch: 183: train loss : 0.10104616	 train accuracy : 1.00000000	 val accuracy : 0.60289855	 test accuracy : 0.62087912
# Train Epoch: 184: train loss : 0.10252550	 train accuracy : 0.99890909	 val accuracy : 0.58695652	 test accuracy : 0.60989011
# Train Epoch: 185: train loss : 0.10194727	 train accuracy : 0.99890909	 val accuracy : 0.58985507	 test accuracy : 0.61538462
# Train Epoch: 186: train loss : 0.10200548	 train accuracy : 1.00000000	 val accuracy : 0.59710145	 test accuracy : 0.61538462
# Train Epoch: 187: train loss : 0.10370353	 train accuracy : 0.99818182	 val accuracy : 0.59130435	 test accuracy : 0.61538462
# Train Epoch: 188: train loss : 0.10111919	 train accuracy : 0.99890909	 val accuracy : 0.59855072	 test accuracy : 0.60439560
# Train Epoch: 189: train loss : 0.10218711	 train accuracy : 1.00000000	 val accuracy : 0.60144928	 test accuracy : 0.61538462
# Train Epoch: 190: train loss : 0.10174648	 train accuracy : 0.99890909	 val accuracy : 0.60289855	 test accuracy : 0.60439560
# Train Epoch: 191: train loss : 0.10102748	 train accuracy : 0.99927273	 val accuracy : 0.60289855	 test accuracy : 0.60439560
# Train Epoch: 192: train loss : 0.09995651	 train accuracy : 0.99927273	 val accuracy : 0.59710145	 test accuracy : 0.61538462
# Train Epoch: 193: train loss : 0.10222950	 train accuracy : 0.99927273	 val accuracy : 0.60579710	 test accuracy : 0.61538462
# Train Epoch: 194: train loss : 0.10118507	 train accuracy : 0.99927273	 val accuracy : 0.60579710	 test accuracy : 0.62087912
# Train Epoch: 195: train loss : 0.10052322	 train accuracy : 0.99890909	 val accuracy : 0.60724638	 test accuracy : 0.60439560
# Train Epoch: 196: train loss : 0.10245306	 train accuracy : 0.99963636	 val accuracy : 0.61159420	 test accuracy : 0.59340659
# Train Epoch: 197: train loss : 0.10116008	 train accuracy : 0.99963636	 val accuracy : 0.60579710	 test accuracy : 0.60989011
# Train Epoch: 198: train loss : 0.10187960	 train accuracy : 0.99818182	 val accuracy : 0.60724638	 test accuracy : 0.62087912
# Train Epoch: 199: train loss : 0.10244754	 train accuracy : 0.99890909	 val accuracy : 0.60579710	 test accuracy : 0.60439560
# Train Epoch: 200: train loss : 0.09983671	 train accuracy : 0.99854545	 val accuracy : 0.60289855	 test accuracy : 0.60989011
# In ensemble  1
# The best validaiton accuracy is:  0.6434782608695652
# Happened at epoch:  32
# The corresponding test accuracy 0.6098901098901099
# The corresponding test AUC is:  0.6859253875968992
# Ensemble  2
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
#   + Number of params: 400898
# Save models
# Train Epoch: 1: train loss : 1.16134436	 train accuracy : 0.47691198	 val accuracy : 0.50937951	 test accuracy : 0.55367232
# Save models
# Train Epoch: 2: train loss : 0.86701107	 train accuracy : 0.54112554	 val accuracy : 0.53102453	 test accuracy : 0.54237288
# Save models
# Train Epoch: 3: train loss : 0.85160495	 train accuracy : 0.58549784	 val accuracy : 0.56854257	 test accuracy : 0.53107345
# Save models
# Train Epoch: 4: train loss : 0.79670227	 train accuracy : 0.58189033	 val accuracy : 0.56998557	 test accuracy : 0.53107345
# Save models
# Train Epoch: 5: train loss : 0.73119701	 train accuracy : 0.62914863	 val accuracy : 0.57720058	 test accuracy : 0.54802260
# Save models
# Train Epoch: 6: train loss : 0.68944046	 train accuracy : 0.63961039	 val accuracy : 0.58730159	 test accuracy : 0.56497175
# Save models
# Train Epoch: 7: train loss : 0.65135995	 train accuracy : 0.64898990	 val accuracy : 0.59740260	 test accuracy : 0.56497175
# Save models
# Train Epoch: 8: train loss : 0.62945606	 train accuracy : 0.66522367	 val accuracy : 0.61327561	 test accuracy : 0.54237288
# Train Epoch: 9: train loss : 0.59367980	 train accuracy : 0.68145743	 val accuracy : 0.60461760	 test accuracy : 0.57627119
# Train Epoch: 10: train loss : 0.60028514	 train accuracy : 0.68217893	 val accuracy : 0.61183261	 test accuracy : 0.57062147
# Train Epoch: 11: train loss : 0.55723059	 train accuracy : 0.71103896	 val accuracy : 0.61183261	 test accuracy : 0.59322034
# Train Epoch: 12: train loss : 0.53654953	 train accuracy : 0.72005772	 val accuracy : 0.61183261	 test accuracy : 0.59887006
# Save models
# Train Epoch: 13: train loss : 0.50635257	 train accuracy : 0.76406926	 val accuracy : 0.61760462	 test accuracy : 0.59322034
# Train Epoch: 14: train loss : 0.51140395	 train accuracy : 0.74675325	 val accuracy : 0.60750361	 test accuracy : 0.59887006
# Train Epoch: 15: train loss : 0.48908799	 train accuracy : 0.77453102	 val accuracy : 0.60461760	 test accuracy : 0.61016949
# Train Epoch: 16: train loss : 0.47758645	 train accuracy : 0.78318903	 val accuracy : 0.60606061	 test accuracy : 0.61016949
# Train Epoch: 17: train loss : 0.47506825	 train accuracy : 0.78030303	 val accuracy : 0.59307359	 test accuracy : 0.58192090
# Train Epoch: 18: train loss : 0.45165976	 train accuracy : 0.80988456	 val accuracy : 0.58585859	 test accuracy : 0.59322034
# Train Epoch: 19: train loss : 0.45256954	 train accuracy : 0.80663781	 val accuracy : 0.59163059	 test accuracy : 0.58757062
# Train Epoch: 20: train loss : 0.44589813	 train accuracy : 0.81385281	 val accuracy : 0.60173160	 test accuracy : 0.58192090
# Train Epoch: 21: train loss : 0.43475206	 train accuracy : 0.83008658	 val accuracy : 0.61616162	 test accuracy : 0.57062147
# Train Epoch: 22: train loss : 0.41874319	 train accuracy : 0.84523810	 val accuracy : 0.61616162	 test accuracy : 0.56497175
# Save models
# Train Epoch: 23: train loss : 0.40562691	 train accuracy : 0.85678211	 val accuracy : 0.61760462	 test accuracy : 0.58757062
# Save models
# Train Epoch: 24: train loss : 0.41275302	 train accuracy : 0.85533911	 val accuracy : 0.62914863	 test accuracy : 0.59887006
# Train Epoch: 25: train loss : 0.39759407	 train accuracy : 0.85894661	 val accuracy : 0.62770563	 test accuracy : 0.61016949
# Train Epoch: 26: train loss : 0.38931658	 train accuracy : 0.86399711	 val accuracy : 0.62337662	 test accuracy : 0.61016949
# Save models
# Train Epoch: 27: train loss : 0.37619580	 train accuracy : 0.87337662	 val accuracy : 0.62914863	 test accuracy : 0.59322034
# Save models
# Train Epoch: 28: train loss : 0.38396612	 train accuracy : 0.86904762	 val accuracy : 0.63203463	 test accuracy : 0.58192090
# Save models
# Train Epoch: 29: train loss : 0.37003080	 train accuracy : 0.88059163	 val accuracy : 0.63347763	 test accuracy : 0.59322034
# Save models
# Train Epoch: 30: train loss : 0.36971219	 train accuracy : 0.88131313	 val accuracy : 0.63492063	 test accuracy : 0.59887006
# Save models
# Train Epoch: 31: train loss : 0.35690405	 train accuracy : 0.89430014	 val accuracy : 0.63492063	 test accuracy : 0.60451977
# Train Epoch: 32: train loss : 0.35769271	 train accuracy : 0.90079365	 val accuracy : 0.62770563	 test accuracy : 0.61016949
# Train Epoch: 33: train loss : 0.34470420	 train accuracy : 0.90151515	 val accuracy : 0.63203463	 test accuracy : 0.59887006
# Save models
# Train Epoch: 34: train loss : 0.34507449	 train accuracy : 0.90548341	 val accuracy : 0.63780664	 test accuracy : 0.59887006
# Train Epoch: 35: train loss : 0.33014353	 train accuracy : 0.92388167	 val accuracy : 0.63636364	 test accuracy : 0.60451977
# Train Epoch: 36: train loss : 0.32850845	 train accuracy : 0.92099567	 val accuracy : 0.63492063	 test accuracy : 0.61016949
# Train Epoch: 37: train loss : 0.32506837	 train accuracy : 0.91919192	 val accuracy : 0.63347763	 test accuracy : 0.61581921
# Save models
# Train Epoch: 38: train loss : 0.30963103	 train accuracy : 0.93867244	 val accuracy : 0.64213564	 test accuracy : 0.61581921
# Train Epoch: 39: train loss : 0.31020159	 train accuracy : 0.93109668	 val accuracy : 0.64069264	 test accuracy : 0.61581921
# Train Epoch: 40: train loss : 0.30597905	 train accuracy : 0.93253968	 val accuracy : 0.63924964	 test accuracy : 0.60451977
# Train Epoch: 41: train loss : 0.29894373	 train accuracy : 0.94011544	 val accuracy : 0.63492063	 test accuracy : 0.59322034
# Train Epoch: 42: train loss : 0.29063021	 train accuracy : 0.94119769	 val accuracy : 0.64069264	 test accuracy : 0.59887006
# Train Epoch: 43: train loss : 0.28802426	 train accuracy : 0.94408369	 val accuracy : 0.63924964	 test accuracy : 0.61016949
# Train Epoch: 44: train loss : 0.28226708	 train accuracy : 0.94949495	 val accuracy : 0.63059163	 test accuracy : 0.61016949
# Train Epoch: 45: train loss : 0.28002849	 train accuracy : 0.94913420	 val accuracy : 0.62770563	 test accuracy : 0.60451977
# Train Epoch: 46: train loss : 0.27152226	 train accuracy : 0.95238095	 val accuracy : 0.63059163	 test accuracy : 0.59887006
# Train Epoch: 47: train loss : 0.26889218	 train accuracy : 0.95779221	 val accuracy : 0.62914863	 test accuracy : 0.60451977
# Train Epoch: 48: train loss : 0.26147586	 train accuracy : 0.95707071	 val accuracy : 0.62049062	 test accuracy : 0.58757062
# Train Epoch: 49: train loss : 0.25898002	 train accuracy : 0.95959596	 val accuracy : 0.63203463	 test accuracy : 0.58192090
# Train Epoch: 50: train loss : 0.25385231	 train accuracy : 0.95851371	 val accuracy : 0.63347763	 test accuracy : 0.59322034
# Train Epoch: 51: train loss : 0.24732585	 train accuracy : 0.96645022	 val accuracy : 0.63059163	 test accuracy : 0.59322034
# Train Epoch: 52: train loss : 0.24200806	 train accuracy : 0.97150072	 val accuracy : 0.62049062	 test accuracy : 0.59322034
# Train Epoch: 53: train loss : 0.23520267	 train accuracy : 0.97113997	 val accuracy : 0.62049062	 test accuracy : 0.58192090
# Train Epoch: 54: train loss : 0.23578624	 train accuracy : 0.96897547	 val accuracy : 0.61471861	 test accuracy : 0.60451977
# Train Epoch: 55: train loss : 0.22617152	 train accuracy : 0.97546898	 val accuracy : 0.62193362	 test accuracy : 0.61016949
# Train Epoch: 56: train loss : 0.22256662	 train accuracy : 0.97655123	 val accuracy : 0.62049062	 test accuracy : 0.60451977
# Train Epoch: 57: train loss : 0.22025123	 train accuracy : 0.97979798	 val accuracy : 0.62049062	 test accuracy : 0.59887006
# Train Epoch: 58: train loss : 0.21343121	 train accuracy : 0.98124098	 val accuracy : 0.62626263	 test accuracy : 0.59322034
# Train Epoch: 59: train loss : 0.20384910	 train accuracy : 0.98520924	 val accuracy : 0.63059163	 test accuracy : 0.59322034
# Train Epoch: 60: train loss : 0.20584313	 train accuracy : 0.98340548	 val accuracy : 0.62770563	 test accuracy : 0.58757062
# Train Epoch: 61: train loss : 0.19605857	 train accuracy : 0.98412698	 val accuracy : 0.62626263	 test accuracy : 0.59322034
# Train Epoch: 62: train loss : 0.19605289	 train accuracy : 0.98593074	 val accuracy : 0.62337662	 test accuracy : 0.59887006
# Train Epoch: 63: train loss : 0.19499161	 train accuracy : 0.98376623	 val accuracy : 0.61904762	 test accuracy : 0.59322034
# Train Epoch: 64: train loss : 0.19018393	 train accuracy : 0.98881674	 val accuracy : 0.62193362	 test accuracy : 0.58192090
# Train Epoch: 65: train loss : 0.18448476	 train accuracy : 0.98809524	 val accuracy : 0.62193362	 test accuracy : 0.58757062
# Train Epoch: 66: train loss : 0.18269902	 train accuracy : 0.98520924	 val accuracy : 0.62481962	 test accuracy : 0.59322034
# Train Epoch: 67: train loss : 0.17974868	 train accuracy : 0.98556999	 val accuracy : 0.62337662	 test accuracy : 0.58192090
# Train Epoch: 68: train loss : 0.17492795	 train accuracy : 0.99170274	 val accuracy : 0.61760462	 test accuracy : 0.58192090
# Train Epoch: 69: train loss : 0.17594058	 train accuracy : 0.98881674	 val accuracy : 0.61904762	 test accuracy : 0.57627119
# Train Epoch: 70: train loss : 0.16751451	 train accuracy : 0.99350649	 val accuracy : 0.61471861	 test accuracy : 0.58192090
# Train Epoch: 71: train loss : 0.16745371	 train accuracy : 0.99242424	 val accuracy : 0.61183261	 test accuracy : 0.57062147
# Train Epoch: 72: train loss : 0.16241644	 train accuracy : 0.99206349	 val accuracy : 0.61904762	 test accuracy : 0.58192090
# Train Epoch: 73: train loss : 0.16003242	 train accuracy : 0.99531025	 val accuracy : 0.61760462	 test accuracy : 0.57062147
# Train Epoch: 74: train loss : 0.16109601	 train accuracy : 0.99386724	 val accuracy : 0.61760462	 test accuracy : 0.57062147
# Train Epoch: 75: train loss : 0.15670501	 train accuracy : 0.99386724	 val accuracy : 0.61760462	 test accuracy : 0.57062147
# Train Epoch: 76: train loss : 0.15347731	 train accuracy : 0.99603175	 val accuracy : 0.61760462	 test accuracy : 0.57062147
# Train Epoch: 77: train loss : 0.15269368	 train accuracy : 0.99350649	 val accuracy : 0.61760462	 test accuracy : 0.57627119
# Train Epoch: 78: train loss : 0.15062311	 train accuracy : 0.99350649	 val accuracy : 0.61760462	 test accuracy : 0.58757062
# Train Epoch: 79: train loss : 0.14779482	 train accuracy : 0.99458874	 val accuracy : 0.61471861	 test accuracy : 0.57627119
# Train Epoch: 80: train loss : 0.14884162	 train accuracy : 0.99278499	 val accuracy : 0.61471861	 test accuracy : 0.56497175
# Train Epoch: 81: train loss : 0.14600714	 train accuracy : 0.99639250	 val accuracy : 0.61616162	 test accuracy : 0.58192090
# Train Epoch: 82: train loss : 0.14256862	 train accuracy : 0.99567100	 val accuracy : 0.61327561	 test accuracy : 0.57627119
# Train Epoch: 83: train loss : 0.14290208	 train accuracy : 0.99531025	 val accuracy : 0.61038961	 test accuracy : 0.56497175
# Train Epoch: 84: train loss : 0.14205860	 train accuracy : 0.99747475	 val accuracy : 0.60606061	 test accuracy : 0.57062147
# Train Epoch: 85: train loss : 0.13722110	 train accuracy : 0.99675325	 val accuracy : 0.61327561	 test accuracy : 0.57062147
# Train Epoch: 86: train loss : 0.14168572	 train accuracy : 0.99639250	 val accuracy : 0.61471861	 test accuracy : 0.57062147
# Train Epoch: 87: train loss : 0.13783626	 train accuracy : 0.99639250	 val accuracy : 0.61471861	 test accuracy : 0.58192090
# Train Epoch: 88: train loss : 0.13302079	 train accuracy : 0.99747475	 val accuracy : 0.61327561	 test accuracy : 0.57062147
# Train Epoch: 89: train loss : 0.13510161	 train accuracy : 0.99458874	 val accuracy : 0.61327561	 test accuracy : 0.57627119
# Train Epoch: 90: train loss : 0.13741615	 train accuracy : 0.99711400	 val accuracy : 0.61760462	 test accuracy : 0.57627119
# Train Epoch: 91: train loss : 0.13160530	 train accuracy : 0.99675325	 val accuracy : 0.61471861	 test accuracy : 0.57062147
# Train Epoch: 92: train loss : 0.13112282	 train accuracy : 0.99603175	 val accuracy : 0.61327561	 test accuracy : 0.57062147
# Train Epoch: 93: train loss : 0.12933905	 train accuracy : 0.99711400	 val accuracy : 0.61471861	 test accuracy : 0.57627119
# Train Epoch: 94: train loss : 0.12949843	 train accuracy : 0.99783550	 val accuracy : 0.60894661	 test accuracy : 0.58757062
# Train Epoch: 95: train loss : 0.12988467	 train accuracy : 0.99783550	 val accuracy : 0.60317460	 test accuracy : 0.58757062
# Train Epoch: 96: train loss : 0.13070617	 train accuracy : 0.99747475	 val accuracy : 0.60173160	 test accuracy : 0.58757062
# Train Epoch: 97: train loss : 0.12167358	 train accuracy : 0.99819625	 val accuracy : 0.60317460	 test accuracy : 0.59322034
# Train Epoch: 98: train loss : 0.12599777	 train accuracy : 0.99891775	 val accuracy : 0.61038961	 test accuracy : 0.59887006
# Train Epoch: 99: train loss : 0.12770545	 train accuracy : 0.99927850	 val accuracy : 0.61183261	 test accuracy : 0.59322034
# Train Epoch: 100: train loss : 0.12251061	 train accuracy : 0.99819625	 val accuracy : 0.60894661	 test accuracy : 0.58757062
# Train Epoch: 101: train loss : 0.12509877	 train accuracy : 0.99855700	 val accuracy : 0.61038961	 test accuracy : 0.58757062
# Train Epoch: 102: train loss : 0.12254407	 train accuracy : 0.99855700	 val accuracy : 0.60606061	 test accuracy : 0.59322034
# Train Epoch: 103: train loss : 0.12520078	 train accuracy : 0.99675325	 val accuracy : 0.60606061	 test accuracy : 0.59887006
# Train Epoch: 104: train loss : 0.12361749	 train accuracy : 0.99819625	 val accuracy : 0.61183261	 test accuracy : 0.59887006
# Train Epoch: 105: train loss : 0.12149428	 train accuracy : 0.99747475	 val accuracy : 0.61327561	 test accuracy : 0.59322034
# Train Epoch: 106: train loss : 0.12074699	 train accuracy : 0.99819625	 val accuracy : 0.61616162	 test accuracy : 0.60451977
# Train Epoch: 107: train loss : 0.12265780	 train accuracy : 0.99783550	 val accuracy : 0.61471861	 test accuracy : 0.59887006
# Train Epoch: 108: train loss : 0.11939113	 train accuracy : 0.99927850	 val accuracy : 0.61183261	 test accuracy : 0.58192090
# Train Epoch: 109: train loss : 0.11859866	 train accuracy : 0.99927850	 val accuracy : 0.60317460	 test accuracy : 0.58757062
# Train Epoch: 110: train loss : 0.11715347	 train accuracy : 0.99855700	 val accuracy : 0.60894661	 test accuracy : 0.58757062
# Train Epoch: 111: train loss : 0.11949338	 train accuracy : 0.99819625	 val accuracy : 0.61327561	 test accuracy : 0.59322034
# Train Epoch: 112: train loss : 0.11879369	 train accuracy : 0.99891775	 val accuracy : 0.61616162	 test accuracy : 0.58757062
# Train Epoch: 113: train loss : 0.11833157	 train accuracy : 0.99855700	 val accuracy : 0.61904762	 test accuracy : 0.58757062
# Train Epoch: 114: train loss : 0.11905689	 train accuracy : 0.99855700	 val accuracy : 0.61471861	 test accuracy : 0.59887006
# Train Epoch: 115: train loss : 0.11722521	 train accuracy : 0.99891775	 val accuracy : 0.61327561	 test accuracy : 0.58757062
# Train Epoch: 116: train loss : 0.11498013	 train accuracy : 0.99855700	 val accuracy : 0.61616162	 test accuracy : 0.58757062
# Train Epoch: 117: train loss : 0.11783762	 train accuracy : 0.99855700	 val accuracy : 0.61760462	 test accuracy : 0.58757062
# Train Epoch: 118: train loss : 0.11552023	 train accuracy : 0.99963925	 val accuracy : 0.61760462	 test accuracy : 0.57627119
# Train Epoch: 119: train loss : 0.11463058	 train accuracy : 0.99855700	 val accuracy : 0.61327561	 test accuracy : 0.58192090
# Train Epoch: 120: train loss : 0.11650762	 train accuracy : 0.99783550	 val accuracy : 0.60606061	 test accuracy : 0.58192090
# Train Epoch: 121: train loss : 0.11339954	 train accuracy : 0.99855700	 val accuracy : 0.60894661	 test accuracy : 0.58757062
# Train Epoch: 122: train loss : 0.11395788	 train accuracy : 0.99927850	 val accuracy : 0.61327561	 test accuracy : 0.57627119
# Train Epoch: 123: train loss : 0.11320389	 train accuracy : 0.99891775	 val accuracy : 0.61616162	 test accuracy : 0.57062147
# Train Epoch: 124: train loss : 0.11354672	 train accuracy : 0.99963925	 val accuracy : 0.61616162	 test accuracy : 0.58192090
# Train Epoch: 125: train loss : 0.11203624	 train accuracy : 0.99927850	 val accuracy : 0.60750361	 test accuracy : 0.58757062
# Train Epoch: 126: train loss : 0.11067619	 train accuracy : 1.00000000	 val accuracy : 0.60173160	 test accuracy : 0.58757062
# Train Epoch: 127: train loss : 0.11368597	 train accuracy : 0.99855700	 val accuracy : 0.60317460	 test accuracy : 0.58757062
# Train Epoch: 128: train loss : 0.11004776	 train accuracy : 0.99891775	 val accuracy : 0.60317460	 test accuracy : 0.59322034
# Train Epoch: 129: train loss : 0.11139279	 train accuracy : 0.99855700	 val accuracy : 0.60750361	 test accuracy : 0.58757062
# Train Epoch: 130: train loss : 0.11137685	 train accuracy : 0.99855700	 val accuracy : 0.61038961	 test accuracy : 0.58757062
# Train Epoch: 131: train loss : 0.11161460	 train accuracy : 0.99927850	 val accuracy : 0.61038961	 test accuracy : 0.57627119
# Train Epoch: 132: train loss : 0.11190964	 train accuracy : 0.99963925	 val accuracy : 0.60317460	 test accuracy : 0.58757062
# Train Epoch: 133: train loss : 0.11020673	 train accuracy : 0.99963925	 val accuracy : 0.60461760	 test accuracy : 0.58757062
# Train Epoch: 134: train loss : 0.10885648	 train accuracy : 0.99927850	 val accuracy : 0.60028860	 test accuracy : 0.58757062
# Train Epoch: 135: train loss : 0.10899759	 train accuracy : 0.99927850	 val accuracy : 0.60173160	 test accuracy : 0.59322034
# Train Epoch: 136: train loss : 0.11039657	 train accuracy : 0.99891775	 val accuracy : 0.60173160	 test accuracy : 0.58757062
# Train Epoch: 137: train loss : 0.10608969	 train accuracy : 0.99927850	 val accuracy : 0.60461760	 test accuracy : 0.58192090
# Train Epoch: 138: train loss : 0.10770517	 train accuracy : 0.99891775	 val accuracy : 0.61183261	 test accuracy : 0.57627119
# Train Epoch: 139: train loss : 0.11029651	 train accuracy : 0.99855700	 val accuracy : 0.60894661	 test accuracy : 0.58192090
# Train Epoch: 140: train loss : 0.10811768	 train accuracy : 0.99927850	 val accuracy : 0.59884560	 test accuracy : 0.59322034
# Train Epoch: 141: train loss : 0.10764931	 train accuracy : 0.99819625	 val accuracy : 0.59740260	 test accuracy : 0.59322034
# Train Epoch: 142: train loss : 0.10883500	 train accuracy : 0.99891775	 val accuracy : 0.60028860	 test accuracy : 0.59322034
# Train Epoch: 143: train loss : 0.10519701	 train accuracy : 0.99927850	 val accuracy : 0.60173160	 test accuracy : 0.58757062
# Train Epoch: 144: train loss : 0.10495857	 train accuracy : 0.99891775	 val accuracy : 0.60750361	 test accuracy : 0.59887006
# Train Epoch: 145: train loss : 0.10634801	 train accuracy : 0.99891775	 val accuracy : 0.61038961	 test accuracy : 0.59322034
# Train Epoch: 146: train loss : 0.10688684	 train accuracy : 0.99963925	 val accuracy : 0.61327561	 test accuracy : 0.59322034
# Train Epoch: 147: train loss : 0.10748338	 train accuracy : 1.00000000	 val accuracy : 0.61038961	 test accuracy : 0.59887006
# Train Epoch: 148: train loss : 0.10842707	 train accuracy : 0.99963925	 val accuracy : 0.60894661	 test accuracy : 0.58757062
# Train Epoch: 149: train loss : 0.10625729	 train accuracy : 0.99927850	 val accuracy : 0.60461760	 test accuracy : 0.57062147
# Train Epoch: 150: train loss : 0.10515957	 train accuracy : 0.99963925	 val accuracy : 0.60028860	 test accuracy : 0.57062147
# Train Epoch: 151: train loss : 0.10337219	 train accuracy : 0.99927850	 val accuracy : 0.60461760	 test accuracy : 0.58192090
# Train Epoch: 152: train loss : 0.10494327	 train accuracy : 0.99855700	 val accuracy : 0.60173160	 test accuracy : 0.57062147
# Train Epoch: 153: train loss : 0.10892989	 train accuracy : 0.99963925	 val accuracy : 0.60317460	 test accuracy : 0.59322034
# Train Epoch: 154: train loss : 0.10745046	 train accuracy : 0.99855700	 val accuracy : 0.61616162	 test accuracy : 0.58757062
# Train Epoch: 155: train loss : 0.10704234	 train accuracy : 0.99855700	 val accuracy : 0.60894661	 test accuracy : 0.58192090
# Train Epoch: 156: train loss : 0.10441085	 train accuracy : 0.99963925	 val accuracy : 0.60461760	 test accuracy : 0.57627119
# Train Epoch: 157: train loss : 0.10526876	 train accuracy : 0.99927850	 val accuracy : 0.61038961	 test accuracy : 0.58192090
# Train Epoch: 158: train loss : 0.10516283	 train accuracy : 0.99855700	 val accuracy : 0.62049062	 test accuracy : 0.57627119
# Train Epoch: 159: train loss : 0.10384116	 train accuracy : 0.99963925	 val accuracy : 0.62049062	 test accuracy : 0.58192090
# Train Epoch: 160: train loss : 0.10462758	 train accuracy : 0.99927850	 val accuracy : 0.61038961	 test accuracy : 0.58757062
# Train Epoch: 161: train loss : 0.10452487	 train accuracy : 0.99927850	 val accuracy : 0.60894661	 test accuracy : 0.58192090
# Train Epoch: 162: train loss : 0.10619336	 train accuracy : 0.99927850	 val accuracy : 0.61471861	 test accuracy : 0.58192090
# Train Epoch: 163: train loss : 0.10460370	 train accuracy : 0.99927850	 val accuracy : 0.61327561	 test accuracy : 0.58757062
# Train Epoch: 164: train loss : 0.10178156	 train accuracy : 1.00000000	 val accuracy : 0.61471861	 test accuracy : 0.59322034
# Train Epoch: 165: train loss : 0.10555537	 train accuracy : 0.99855700	 val accuracy : 0.61616162	 test accuracy : 0.58757062
# Train Epoch: 166: train loss : 0.10657878	 train accuracy : 0.99891775	 val accuracy : 0.60461760	 test accuracy : 0.58757062
# Train Epoch: 167: train loss : 0.10484588	 train accuracy : 0.99927850	 val accuracy : 0.60894661	 test accuracy : 0.59322034
# Train Epoch: 168: train loss : 0.10421271	 train accuracy : 0.99927850	 val accuracy : 0.60461760	 test accuracy : 0.59887006
# Train Epoch: 169: train loss : 0.10467400	 train accuracy : 0.99963925	 val accuracy : 0.61327561	 test accuracy : 0.59322034
# ...
# Train Epoch: 78: train loss : 0.16366411	 train accuracy : 0.99324324	 val accuracy : 0.61735420	 test accuracy : 0.66467066
# Train Epoch: 79: train loss : 0.15907342	 train accuracy : 0.99288762	 val accuracy : 0.61735420	 test accuracy : 0.67065868
# Save models
# Train Epoch: 80: train loss : 0.15762496	 train accuracy : 0.99395448	 val accuracy : 0.62162162	 test accuracy : 0.67664671
# Save models
# Train Epoch: 81: train loss : 0.15710293	 train accuracy : 0.99253201	 val accuracy : 0.62162162	 test accuracy : 0.67664671
# Save models
# Train Epoch: 82: train loss : 0.15449221	 train accuracy : 0.99359886	 val accuracy : 0.62588905	 test accuracy : 0.67664671
# Train Epoch: 83: train loss : 0.15193008	 train accuracy : 0.99359886	 val accuracy : 0.62304410	 test accuracy : 0.67065868
# Train Epoch: 84: train loss : 0.15135970	 train accuracy : 0.99324324	 val accuracy : 0.62446657	 test accuracy : 0.67065868
# Train Epoch: 85: train loss : 0.15102754	 train accuracy : 0.99502134	 val accuracy : 0.62446657	 test accuracy : 0.67664671
# Train Epoch: 86: train loss : 0.14567830	 train accuracy : 0.99573257	 val accuracy : 0.62446657	 test accuracy : 0.67065868
# Train Epoch: 87: train loss : 0.14745862	 train accuracy : 0.99644381	 val accuracy : 0.62162162	 test accuracy : 0.65269461
# Train Epoch: 88: train loss : 0.14560226	 train accuracy : 0.99679943	 val accuracy : 0.62304410	 test accuracy : 0.65269461
# Train Epoch: 89: train loss : 0.14237856	 train accuracy : 0.99679943	 val accuracy : 0.62304410	 test accuracy : 0.66467066
# Train Epoch: 90: train loss : 0.14371866	 train accuracy : 0.99466572	 val accuracy : 0.62446657	 test accuracy : 0.67664671
# Train Epoch: 91: train loss : 0.14005731	 train accuracy : 0.99751067	 val accuracy : 0.62304410	 test accuracy : 0.66467066
# Train Epoch: 92: train loss : 0.14091965	 train accuracy : 0.99715505	 val accuracy : 0.62446657	 test accuracy : 0.67065868
# Train Epoch: 93: train loss : 0.13687156	 train accuracy : 0.99679943	 val accuracy : 0.62446657	 test accuracy : 0.67065868
# Save models
# Train Epoch: 94: train loss : 0.13752872	 train accuracy : 0.99537696	 val accuracy : 0.62588905	 test accuracy : 0.66467066
# Train Epoch: 95: train loss : 0.13643175	 train accuracy : 0.99715505	 val accuracy : 0.62304410	 test accuracy : 0.65269461
# Train Epoch: 96: train loss : 0.13361990	 train accuracy : 0.99786629	 val accuracy : 0.62162162	 test accuracy : 0.65269461
# Train Epoch: 97: train loss : 0.13454086	 train accuracy : 0.99786629	 val accuracy : 0.62162162	 test accuracy : 0.66467066
# Train Epoch: 98: train loss : 0.13442404	 train accuracy : 0.99679943	 val accuracy : 0.62446657	 test accuracy : 0.65269461
# Train Epoch: 99: train loss : 0.13166232	 train accuracy : 0.99644381	 val accuracy : 0.61735420	 test accuracy : 0.64670659
# Train Epoch: 100: train loss : 0.12719170	 train accuracy : 0.99857752	 val accuracy : 0.61735420	 test accuracy : 0.65269461
# Train Epoch: 101: train loss : 0.13156510	 train accuracy : 0.99786629	 val accuracy : 0.61308677	 test accuracy : 0.65868263
# Train Epoch: 102: train loss : 0.12848523	 train accuracy : 0.99822191	 val accuracy : 0.61166430	 test accuracy : 0.65269461
# Train Epoch: 103: train loss : 0.12994855	 train accuracy : 0.99715505	 val accuracy : 0.62019915	 test accuracy : 0.64071856
# Train Epoch: 104: train loss : 0.12744917	 train accuracy : 0.99822191	 val accuracy : 0.62304410	 test accuracy : 0.64071856
# Train Epoch: 105: train loss : 0.12660722	 train accuracy : 0.99715505	 val accuracy : 0.61735420	 test accuracy : 0.64071856
# Train Epoch: 106: train loss : 0.12742693	 train accuracy : 0.99715505	 val accuracy : 0.61166430	 test accuracy : 0.65269461
# Train Epoch: 107: train loss : 0.12780385	 train accuracy : 0.99857752	 val accuracy : 0.61735420	 test accuracy : 0.65269461
# Train Epoch: 108: train loss : 0.12567520	 train accuracy : 0.99822191	 val accuracy : 0.62019915	 test accuracy : 0.64670659
# Train Epoch: 109: train loss : 0.12461308	 train accuracy : 0.99822191	 val accuracy : 0.62019915	 test accuracy : 0.63473054
# Train Epoch: 110: train loss : 0.12476246	 train accuracy : 0.99857752	 val accuracy : 0.62162162	 test accuracy : 0.65269461
# Train Epoch: 111: train loss : 0.12295438	 train accuracy : 0.99822191	 val accuracy : 0.61735420	 test accuracy : 0.65269461
# Train Epoch: 112: train loss : 0.12076197	 train accuracy : 0.99928876	 val accuracy : 0.61877667	 test accuracy : 0.64670659
# Train Epoch: 113: train loss : 0.12328580	 train accuracy : 0.99786629	 val accuracy : 0.62019915	 test accuracy : 0.62874251
# Train Epoch: 114: train loss : 0.12344036	 train accuracy : 0.99786629	 val accuracy : 0.62162162	 test accuracy : 0.63473054
# Train Epoch: 115: train loss : 0.12187824	 train accuracy : 0.99893314	 val accuracy : 0.62304410	 test accuracy : 0.64670659
# Save models
# Train Epoch: 116: train loss : 0.12242181	 train accuracy : 0.99857752	 val accuracy : 0.62588905	 test accuracy : 0.65269461
# Train Epoch: 117: train loss : 0.12079151	 train accuracy : 0.99822191	 val accuracy : 0.62304410	 test accuracy : 0.64670659
# Train Epoch: 118: train loss : 0.11996921	 train accuracy : 0.99822191	 val accuracy : 0.62162162	 test accuracy : 0.66467066
# Train Epoch: 119: train loss : 0.11891798	 train accuracy : 0.99928876	 val accuracy : 0.62162162	 test accuracy : 0.65868263
# Train Epoch: 120: train loss : 0.11688661	 train accuracy : 0.99822191	 val accuracy : 0.61877667	 test accuracy : 0.65868263
# Train Epoch: 121: train loss : 0.11736878	 train accuracy : 0.99857752	 val accuracy : 0.62162162	 test accuracy : 0.64071856
# Train Epoch: 122: train loss : 0.11894244	 train accuracy : 0.99786629	 val accuracy : 0.62019915	 test accuracy : 0.64670659
# Train Epoch: 123: train loss : 0.11852365	 train accuracy : 0.99964438	 val accuracy : 0.61593172	 test accuracy : 0.65269461
# Train Epoch: 124: train loss : 0.11617150	 train accuracy : 0.99822191	 val accuracy : 0.61735420	 test accuracy : 0.66467066
# Train Epoch: 125: train loss : 0.11674224	 train accuracy : 0.99822191	 val accuracy : 0.61593172	 test accuracy : 0.65868263
# Train Epoch: 126: train loss : 0.11653403	 train accuracy : 0.99822191	 val accuracy : 0.62019915	 test accuracy : 0.64670659
# Train Epoch: 127: train loss : 0.11868708	 train accuracy : 0.99964438	 val accuracy : 0.61593172	 test accuracy : 0.64071856
# Train Epoch: 128: train loss : 0.11468894	 train accuracy : 0.99964438	 val accuracy : 0.62019915	 test accuracy : 0.64071856
# Train Epoch: 129: train loss : 0.11507533	 train accuracy : 0.99786629	 val accuracy : 0.61735420	 test accuracy : 0.64071856
# Train Epoch: 130: train loss : 0.11447717	 train accuracy : 0.99644381	 val accuracy : 0.61877667	 test accuracy : 0.64071856
# Train Epoch: 131: train loss : 0.11207183	 train accuracy : 0.99893314	 val accuracy : 0.61877667	 test accuracy : 0.64670659
# Train Epoch: 132: train loss : 0.11310900	 train accuracy : 0.99786629	 val accuracy : 0.61735420	 test accuracy : 0.65868263
# Train Epoch: 133: train loss : 0.11680707	 train accuracy : 0.99893314	 val accuracy : 0.62446657	 test accuracy : 0.65269461
# Train Epoch: 134: train loss : 0.11291232	 train accuracy : 0.99822191	 val accuracy : 0.62304410	 test accuracy : 0.64071856
# Train Epoch: 135: train loss : 0.10973423	 train accuracy : 0.99964438	 val accuracy : 0.62019915	 test accuracy : 0.62874251
# Train Epoch: 136: train loss : 0.11635659	 train accuracy : 0.99679943	 val accuracy : 0.62162162	 test accuracy : 0.64071856
# Train Epoch: 137: train loss : 0.11367247	 train accuracy : 0.99857752	 val accuracy : 0.62019915	 test accuracy : 0.64670659
# Train Epoch: 138: train loss : 0.11408681	 train accuracy : 0.99822191	 val accuracy : 0.61735420	 test accuracy : 0.65269461
# Train Epoch: 139: train loss : 0.11156230	 train accuracy : 0.99857752	 val accuracy : 0.61877667	 test accuracy : 0.64071856
# Train Epoch: 140: train loss : 0.11428263	 train accuracy : 0.99644381	 val accuracy : 0.62019915	 test accuracy : 0.61676647
# Save models
# Train Epoch: 141: train loss : 0.11094536	 train accuracy : 0.99857752	 val accuracy : 0.62588905	 test accuracy : 0.62874251
# Train Epoch: 142: train loss : 0.11203292	 train accuracy : 0.99822191	 val accuracy : 0.61877667	 test accuracy : 0.63473054
# Train Epoch: 143: train loss : 0.10890521	 train accuracy : 1.00000000	 val accuracy : 0.60881935	 test accuracy : 0.64670659
# Train Epoch: 144: train loss : 0.11091838	 train accuracy : 0.99822191	 val accuracy : 0.61450925	 test accuracy : 0.65269461
# Train Epoch: 145: train loss : 0.11300660	 train accuracy : 0.99751067	 val accuracy : 0.62019915	 test accuracy : 0.64071856
# Train Epoch: 146: train loss : 0.10975128	 train accuracy : 0.99857752	 val accuracy : 0.62446657	 test accuracy : 0.64071856
# Train Epoch: 147: train loss : 0.11120506	 train accuracy : 0.99786629	 val accuracy : 0.61166430	 test accuracy : 0.64071856
# Train Epoch: 148: train loss : 0.11156808	 train accuracy : 0.99893314	 val accuracy : 0.61877667	 test accuracy : 0.64071856
# Train Epoch: 149: train loss : 0.11055787	 train accuracy : 0.99893314	 val accuracy : 0.61308677	 test accuracy : 0.62874251
# Train Epoch: 150: train loss : 0.11042857	 train accuracy : 0.99964438	 val accuracy : 0.61450925	 test accuracy : 0.63473054
# Train Epoch: 151: train loss : 0.10879594	 train accuracy : 0.99857752	 val accuracy : 0.61593172	 test accuracy : 0.62275449
# Train Epoch: 152: train loss : 0.11037354	 train accuracy : 0.99964438	 val accuracy : 0.61735420	 test accuracy : 0.62874251
# Train Epoch: 153: train loss : 0.11028603	 train accuracy : 0.99893314	 val accuracy : 0.62162162	 test accuracy : 0.61077844
# Save models
# Train Epoch: 154: train loss : 0.10860230	 train accuracy : 0.99893314	 val accuracy : 0.62588905	 test accuracy : 0.63473054
# Train Epoch: 155: train loss : 0.10796378	 train accuracy : 0.99893314	 val accuracy : 0.62019915	 test accuracy : 0.62874251
# Train Epoch: 156: train loss : 0.10733652	 train accuracy : 0.99857752	 val accuracy : 0.61877667	 test accuracy : 0.62275449
# Train Epoch: 157: train loss : 0.10586157	 train accuracy : 0.99857752	 val accuracy : 0.61877667	 test accuracy : 0.62874251
# Train Epoch: 158: train loss : 0.10586657	 train accuracy : 0.99893314	 val accuracy : 0.62446657	 test accuracy : 0.64071856
# Train Epoch: 159: train loss : 0.10908156	 train accuracy : 0.99928876	 val accuracy : 0.61877667	 test accuracy : 0.64071856
# Train Epoch: 160: train loss : 0.10977246	 train accuracy : 0.99964438	 val accuracy : 0.61735420	 test accuracy : 0.62874251
# Train Epoch: 161: train loss : 0.10899537	 train accuracy : 0.99822191	 val accuracy : 0.61308677	 test accuracy : 0.63473054
# Train Epoch: 162: train loss : 0.10886250	 train accuracy : 0.99857752	 val accuracy : 0.61593172	 test accuracy : 0.62874251
# Train Epoch: 163: train loss : 0.10832584	 train accuracy : 0.99893314	 val accuracy : 0.61877667	 test accuracy : 0.63473054
# Train Epoch: 164: train loss : 0.10848433	 train accuracy : 0.99964438	 val accuracy : 0.61877667	 test accuracy : 0.64670659
# Train Epoch: 165: train loss : 0.10727766	 train accuracy : 0.99893314	 val accuracy : 0.61593172	 test accuracy : 0.64071856
# Train Epoch: 166: train loss : 0.10655811	 train accuracy : 1.00000000	 val accuracy : 0.61593172	 test accuracy : 0.63473054
# Train Epoch: 167: train loss : 0.10495728	 train accuracy : 0.99928876	 val accuracy : 0.61877667	 test accuracy : 0.64071856
# Train Epoch: 168: train loss : 0.10929406	 train accuracy : 0.99964438	 val accuracy : 0.62019915	 test accuracy : 0.64071856
# Train Epoch: 169: train loss : 0.10692021	 train accuracy : 0.99964438	 val accuracy : 0.61308677	 test accuracy : 0.64071856
# Train Epoch: 170: train loss : 0.10589397	 train accuracy : 0.99857752	 val accuracy : 0.61593172	 test accuracy : 0.64071856
# Train Epoch: 171: train loss : 0.10611738	 train accuracy : 0.99822191	 val accuracy : 0.61308677	 test accuracy : 0.64071856
# Train Epoch: 172: train loss : 0.10663183	 train accuracy : 0.99964438	 val accuracy : 0.61593172	 test accuracy : 0.63473054
# Train Epoch: 173: train loss : 0.10769915	 train accuracy : 0.99893314	 val accuracy : 0.61308677	 test accuracy : 0.63473054
# Train Epoch: 174: train loss : 0.10552284	 train accuracy : 0.99893314	 val accuracy : 0.61166430	 test accuracy : 0.61676647
# Train Epoch: 175: train loss : 0.10775268	 train accuracy : 0.99964438	 val accuracy : 0.61877667	 test accuracy : 0.61676647
# Train Epoch: 176: train loss : 0.10611520	 train accuracy : 0.99893314	 val accuracy : 0.62162162	 test accuracy : 0.62874251
# Train Epoch: 177: train loss : 0.10529781	 train accuracy : 0.99857752	 val accuracy : 0.61735420	 test accuracy : 0.63473054
# Train Epoch: 178: train loss : 0.10604300	 train accuracy : 0.99964438	 val accuracy : 0.62019915	 test accuracy : 0.62874251
# Train Epoch: 179: train loss : 0.10546032	 train accuracy : 0.99786629	 val accuracy : 0.61450925	 test accuracy : 0.61077844
# Train Epoch: 180: train loss : 0.10691453	 train accuracy : 0.99857752	 val accuracy : 0.61735420	 test accuracy : 0.61077844
# Train Epoch: 181: train loss : 0.10453825	 train accuracy : 0.99964438	 val accuracy : 0.62446657	 test accuracy : 0.63473054
# Train Epoch: 182: train loss : 0.10528538	 train accuracy : 0.99893314	 val accuracy : 0.62162162	 test accuracy : 0.64071856
# Train Epoch: 183: train loss : 0.10295996	 train accuracy : 0.99928876	 val accuracy : 0.61877667	 test accuracy : 0.61676647
# Train Epoch: 184: train loss : 0.10479352	 train accuracy : 0.99964438	 val accuracy : 0.61877667	 test accuracy : 0.61676647
# Train Epoch: 185: train loss : 0.10557086	 train accuracy : 0.99857752	 val accuracy : 0.61877667	 test accuracy : 0.61676647
# Train Epoch: 186: train loss : 0.10356167	 train accuracy : 0.99857752	 val accuracy : 0.61450925	 test accuracy : 0.62275449
# Train Epoch: 187: train loss : 0.10371111	 train accuracy : 0.99928876	 val accuracy : 0.61877667	 test accuracy : 0.64071856
# Train Epoch: 188: train loss : 0.10345445	 train accuracy : 0.99928876	 val accuracy : 0.61308677	 test accuracy : 0.62874251
# Train Epoch: 189: train loss : 0.10286552	 train accuracy : 0.99928876	 val accuracy : 0.62019915	 test accuracy : 0.61676647
# Train Epoch: 190: train loss : 0.10512826	 train accuracy : 0.99893314	 val accuracy : 0.62019915	 test accuracy : 0.63473054
# Train Epoch: 191: train loss : 0.10539567	 train accuracy : 0.99928876	 val accuracy : 0.62304410	 test accuracy : 0.64071856
# Train Epoch: 192: train loss : 0.10468795	 train accuracy : 0.99893314	 val accuracy : 0.62304410	 test accuracy : 0.64670659
# Train Epoch: 193: train loss : 0.10350045	 train accuracy : 0.99928876	 val accuracy : 0.62019915	 test accuracy : 0.62275449
# Train Epoch: 194: train loss : 0.10347560	 train accuracy : 0.99893314	 val accuracy : 0.61166430	 test accuracy : 0.62275449
# Train Epoch: 195: train loss : 0.10361440	 train accuracy : 0.99822191	 val accuracy : 0.62019915	 test accuracy : 0.62275449
# Train Epoch: 196: train loss : 0.10247504	 train accuracy : 0.99928876	 val accuracy : 0.61308677	 test accuracy : 0.64071856
# Train Epoch: 197: train loss : 0.10408507	 train accuracy : 0.99928876	 val accuracy : 0.60881935	 test accuracy : 0.62874251
# Train Epoch: 198: train loss : 0.10432391	 train accuracy : 0.99928876	 val accuracy : 0.61735420	 test accuracy : 0.61077844
# Train Epoch: 199: train loss : 0.10158705	 train accuracy : 0.99964438	 val accuracy : 0.62019915	 test accuracy : 0.61676647
# Train Epoch: 200: train loss : 0.10509826	 train accuracy : 0.99786629	 val accuracy : 0.62162162	 test accuracy : 0.62874251
# In ensemble  5
# The best validaiton accuracy is:  0.6258890469416786
# Happened at epoch:  154
# The corresponding test accuracy 0.6347305389221557
# The corresponding test AUC is:  0.6605797101449276
# The Max voting test accuracy is:  0.6298850574712643
# The test AUC is:  0.680230179435816
