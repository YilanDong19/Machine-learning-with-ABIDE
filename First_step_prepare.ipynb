# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install nilearn
# Out:
# Collecting nilearn
#   Downloading nilearn-0.10.3-py3-none-any.whl (10.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 21.0 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from nilearn) (1.3.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nilearn) (4.9.4)
# Requirement already satisfied: nibabel>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from nilearn) (4.0.2)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from nilearn) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from nilearn) (23.2)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from nilearn) (1.5.3)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.10/dist-packages (from nilearn) (2.31.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from nilearn) (1.2.2)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from nilearn) (1.11.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nibabel>=4.0.0->nilearn) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->nilearn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->nilearn) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->nilearn) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->nilearn) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->nilearn) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->nilearn) (2024.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->nilearn) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->nilearn) (1.16.0)
# Installing collected packages: nilearn
# Successfully installed nilearn-0.10.3

# %%
import sys
import os
sys.path.append('/content/drive/MyDrive/')
main_path = '/content/drive/MyDrive/ABIDE'
if not os.path.exists(main_path):
  os.makedirs(main_path)

# %%
# download subject_IDs.txt
phenotypic_path = main_path + '/phenotypic_image_quality'
if not os.path.exists(phenotypic_path):
  os.makedirs(phenotypic_path)
# !gdown 1PTO7x0ja5kMKP1t1LhoFd04VDSK1DYIA --output /content/drive/MyDrive/ABIDE/phenotypic_image_quality/
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1PTO7x0ja5kMKP1t1LhoFd04VDSK1DYIA
# To: /content/drive/MyDrive/ABIDE/phenotypic_image_quality/subject_IDs.txt
# 100% 5.23k/5.23k [00:00<00:00, 16.8MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1W-fAQxR1jFrmZmPxxRRCaWYmTYM08yDy
# From (redirected): https://drive.google.com/uc?id=1W-fAQxR1jFrmZmPxxRRCaWYmTYM08yDy&confirm=t&uuid=24eecd43-cb77-4cb7-8c0a-a2d5b9f662d2
# To: /content/drive/MyDrive/ABIDE/neuralCombat.py
# 100% 16.7k/16.7k [00:00<00:00, 51.7MB/s]

# %%
# Prepare AAL data

from nilearn import datasets
from nilearn import connectome
import scipy.io as sio
import numpy as np
import shutil

def get_ids(data_folder,num_subjects=None):
    """
    return:
        subject_IDs    : list of all subject IDs
    """
    subject_IDs = np.genfromtxt(os.path.join(data_folder, 'subject_IDs.txt'), dtype=str)
    if num_subjects is not None:
        subject_IDs = subject_IDs[:num_subjects]
    return subject_IDs

def fetch_filenames(data_folder,subject_IDs, file_type):
    """
        subject_list : list of short subject IDs in string format
        file_type    : must be one of the available file types
    returns:
        filenames    : list of filetypes (same length as subject_list)
    """
    import glob
    # Specify file mappings for the possible file types
    filemapping = {'func_preproc': '_func_preproc.nii.gz',
                   'rois_aal': '_rois_aal.1D'}
    # The list to be filled
    filenames = []
    # Fill list with requested file paths
    for i in range(len(subject_IDs)):
        os.chdir(data_folder)
        try:
            filenames.append(glob.glob('*' + subject_IDs[i] + filemapping[file_type])[0])
        except IndexError:
            # Return N/A if subject ID is not found
            filenames.append('N/A')
    return filenames

def get_timeseries(data_folder,subject_list, atlas_name):
    """
        subject_list : list of short subject IDs in string format
        atlas_name   : the atlas based on which the timeseries are generated e.g. aal, cc200

    returns:
        time_series  : list of timeseries arrays, each of shape (timepoints x regions)
    """
    timeseries = []
    for i in range(len(subject_list)):
        subject_folder = os.path.join(data_folder, subject_list[i])
        ro_file = [f for f in os.listdir(subject_folder) if f.endswith('_rois_' + atlas_name + '.1D')]
        print(ro_file[0])
        fl = os.path.join(subject_folder, ro_file[0])
        print("Reading timeseries file %s" %fl)
        timeseries.append(np.loadtxt(fl, skiprows=0))
    return timeseries

def subject_connectivity(timeseries, subject, atlas_name, kind, save_path, save=True):
    """
        timeseries   : timeseries table for subject (timepoints x regions)
        subject      : the subject ID
        atlas_name   : name of the parcellation atlas used
        kind         : the kind of connectivity to be used, e.g. lasso, partial correlation, correlation
        save         : save the connectivity matrix to a file
        save_path    : specify path to save the matrix if different from subject folder

    returns:
        connectivity : connectivity matrix (regions x regions)
    """

    print("Estimating %s matrix for subject %s" % (kind, subject))

    if kind in ['tangent', 'partial correlation', 'correlation']:
        conn_measure = connectome.ConnectivityMeasure(kind=kind)
        connectivity = conn_measure.fit_transform([timeseries])[0]

    if save:
        subject_file = os.path.join(save_path, subject + '.mat')
        sio.savemat(subject_file, {'connectivity': connectivity})

    return connectivity



AAL_path = main_path + '/AAL/original/'
data_folder = AAL_path + 'ABIDE_pcp/cpac/filt_noglobal'
if not os.path.exists(AAL_path):
  os.makedirs(AAL_path)
pipeline = 'cpac'
num_subjects = 871  # Number of subjects
files = ['rois_aal']
filemapping = {'func_preproc': 'func_preproc.nii.gz',
               'rois_aal': 'rois_aal.1D'}

abide = datasets.fetch_abide_pcp(data_dir=AAL_path, n_subjects=num_subjects, pipeline=pipeline,
                 band_pass_filtering=True, global_signal_regression=False, derivatives=files)


subject_IDs = get_ids(phenotypic_path,num_subjects)
subject_IDs = subject_IDs.tolist()

for s, fname in zip(subject_IDs, fetch_filenames(data_folder, subject_IDs, files[0])):
    subject_folder = os.path.join(data_folder, s)
    if not os.path.exists(subject_folder):
        os.mkdir(subject_folder)

    # Get the base filename for each subject
    base = fname.split(files[0])[0]

    # Move each subject file to the subject folder
    for fl in files:
        if not os.path.exists(os.path.join(subject_folder, base + filemapping[fl])):
            shutil.move(base + filemapping[fl], subject_folder)

time_series = get_timeseries(data_folder,subject_IDs, 'aal')

# Compute and save connectivity matrices
for i in range(len(subject_IDs)):
    subject_connectivity(time_series[i], subject_IDs[i], 'aal', 'correlation',AAL_path)
# Out:
# Added README.md to /content/drive/MyDrive/ABIDE/AAL/original/
#
#
# Dataset created in /content/drive/MyDrive/ABIDE/AAL/original/ABIDE_pcp
#
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Phenotypic_V1_0b_preprocessed1.csv ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050003_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050004_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050005_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050006_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050007_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050008_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050010_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050011_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050012_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050013_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050014_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050015_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050016_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050020_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050022_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050023_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050024_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050025_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050026_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050027_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050028_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050030_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050031_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050032_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050033_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050034_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050035_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050036_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050037_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050038_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050039_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050040_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050041_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050042_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050043_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050044_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050045_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050046_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050047_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050048_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050049_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050050_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050051_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050052_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050053_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050054_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050056_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050057_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050059_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Pitt_0050060_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Olin_0050102_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Olin_0050103_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Olin_0050104_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Olin_0050105_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Olin_0050106_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Olin_0050107_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Olin_0050109_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Olin_0050111_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Olin_0050112_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Olin_0050113_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Olin_0050114_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Olin_0050115_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Olin_0050116_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Olin_0050117_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Olin_0050118_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Olin_0050119_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Olin_0050121_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Olin_0050123_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Olin_0050124_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Olin_0050125_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Olin_0050127_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Olin_0050128_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Olin_0050129_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Olin_0050130_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Olin_0050131_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Olin_0050132_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Olin_0050134_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Olin_0050135_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/OHSU_0050142_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/OHSU_0050143_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/OHSU_0050144_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/OHSU_0050145_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/OHSU_0050146_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/OHSU_0050147_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/OHSU_0050148_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/OHSU_0050149_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/OHSU_0050150_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/OHSU_0050152_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/OHSU_0050153_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/OHSU_0050156_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/OHSU_0050157_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/OHSU_0050158_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/OHSU_0050159_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/OHSU_0050160_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/OHSU_0050161_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/OHSU_0050162_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/OHSU_0050163_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/OHSU_0050164_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/OHSU_0050167_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/OHSU_0050168_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/OHSU_0050169_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/OHSU_0050170_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/OHSU_0050171_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/SDSU_0050182_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/SDSU_0050183_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/SDSU_0050184_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/SDSU_0050186_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/SDSU_0050187_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/SDSU_0050188_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/SDSU_0050189_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/SDSU_0050190_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/SDSU_0050193_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/SDSU_0050194_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/SDSU_0050195_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/SDSU_0050196_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/SDSU_0050198_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/SDSU_0050199_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/SDSU_0050200_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/SDSU_0050201_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/SDSU_0050202_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/SDSU_0050203_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/SDSU_0050204_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/SDSU_0050205_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/SDSU_0050206_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/SDSU_0050208_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/SDSU_0050210_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/SDSU_0050213_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/SDSU_0050214_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/SDSU_0050215_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/SDSU_0050217_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050232_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050233_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050234_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050236_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050237_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050239_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050240_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050241_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050243_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050245_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050247_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050248_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050249_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050250_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050251_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050252_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050253_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050254_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050255_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050257_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050259_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050260_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050261_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050262_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050263_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050264_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050265_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050266_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050267_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050268_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050269_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050270_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/Trinity_0050271_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050272_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050273_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050274_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050275_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050276_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050278_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050282_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050284_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050285_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050287_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050289_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050290_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050291_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050292_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050293_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050294_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050295_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050297_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050298_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050300_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050301_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050302_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050304_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050308_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050310_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050312_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050314_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050315_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050318_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050319_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050320_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050321_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050324_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050325_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050327_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050329_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050330_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050331_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050332_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050333_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050334_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050335_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050336_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050337_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050338_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050339_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050340_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050341_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050342_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050343_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050344_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050345_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050346_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050347_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050348_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050349_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050350_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050351_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050352_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050353_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050354_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050355_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050356_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050357_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050358_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050359_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050360_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050361_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050362_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050363_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050364_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050365_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050366_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050367_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050368_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050369_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050370_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050372_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050373_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050374_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050375_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050376_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050377_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050379_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050380_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_1_0050381_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_2_0050382_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_2_0050383_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_2_0050385_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_2_0050386_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_2_0050387_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_2_0050388_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_2_0050390_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_2_0050391_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_2_0050397_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_2_0050399_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_2_0050402_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_2_0050403_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_2_0050404_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_aal/UM_2_0050405_rois_aal.1D ...
#  ...done. (1 seconds, 0 min)
# ...
# Estimating correlation matrix for subject 51007
# Estimating correlation matrix for subject 51008
# Estimating correlation matrix for subject 51009
# Estimating correlation matrix for subject 51010
# Estimating correlation matrix for subject 51011
# Estimating correlation matrix for subject 51012
# Estimating correlation matrix for subject 51013
# Estimating correlation matrix for subject 51014
# Estimating correlation matrix for subject 51015
# Estimating correlation matrix for subject 51016
# Estimating correlation matrix for subject 51017
# Estimating correlation matrix for subject 51018
# Estimating correlation matrix for subject 51019
# Estimating correlation matrix for subject 51020
# Estimating correlation matrix for subject 51021
# Estimating correlation matrix for subject 51023
# Estimating correlation matrix for subject 51024
# Estimating correlation matrix for subject 51025
# Estimating correlation matrix for subject 51026
# Estimating correlation matrix for subject 51027
# Estimating correlation matrix for subject 51028
# Estimating correlation matrix for subject 51029
# Estimating correlation matrix for subject 51030
# Estimating correlation matrix for subject 51032
# Estimating correlation matrix for subject 51033
# Estimating correlation matrix for subject 51034
# Estimating correlation matrix for subject 51035
# Estimating correlation matrix for subject 51036
# Estimating correlation matrix for subject 51038
# Estimating correlation matrix for subject 51039
# Estimating correlation matrix for subject 51040
# Estimating correlation matrix for subject 51041
# Estimating correlation matrix for subject 51042
# Estimating correlation matrix for subject 51044
# Estimating correlation matrix for subject 51045
# Estimating correlation matrix for subject 51046
# Estimating correlation matrix for subject 51047
# Estimating correlation matrix for subject 51048
# Estimating correlation matrix for subject 51049
# Estimating correlation matrix for subject 51050
# Estimating correlation matrix for subject 51051
# Estimating correlation matrix for subject 51052
# Estimating correlation matrix for subject 51053
# Estimating correlation matrix for subject 51054
# Estimating correlation matrix for subject 51055
# Estimating correlation matrix for subject 51056
# Estimating correlation matrix for subject 51057
# Estimating correlation matrix for subject 51058
# Estimating correlation matrix for subject 51059
# Estimating correlation matrix for subject 51060
# Estimating correlation matrix for subject 51061
# Estimating correlation matrix for subject 51062
# Estimating correlation matrix for subject 51063
# Estimating correlation matrix for subject 51064
# Estimating correlation matrix for subject 51065
# Estimating correlation matrix for subject 51066
# Estimating correlation matrix for subject 51067
# Estimating correlation matrix for subject 51068
# Estimating correlation matrix for subject 51069
# Estimating correlation matrix for subject 51070
# Estimating correlation matrix for subject 51072
# Estimating correlation matrix for subject 51073
# Estimating correlation matrix for subject 51074
# Estimating correlation matrix for subject 51075
# Estimating correlation matrix for subject 51076
# Estimating correlation matrix for subject 51077
# Estimating correlation matrix for subject 51078
# Estimating correlation matrix for subject 51079
# Estimating correlation matrix for subject 51080
# Estimating correlation matrix for subject 51081
# Estimating correlation matrix for subject 51082
# Estimating correlation matrix for subject 51083
# Estimating correlation matrix for subject 51084
# Estimating correlation matrix for subject 51085
# Estimating correlation matrix for subject 51086
# Estimating correlation matrix for subject 51087
# Estimating correlation matrix for subject 51088
# Estimating correlation matrix for subject 51089
# Estimating correlation matrix for subject 51090
# Estimating correlation matrix for subject 51091
# Estimating correlation matrix for subject 51093
# Estimating correlation matrix for subject 51094
# Estimating correlation matrix for subject 51095
# Estimating correlation matrix for subject 51096
# Estimating correlation matrix for subject 51097
# Estimating correlation matrix for subject 51098
# Estimating correlation matrix for subject 51099
# Estimating correlation matrix for subject 51100
# Estimating correlation matrix for subject 51101
# Estimating correlation matrix for subject 51102
# Estimating correlation matrix for subject 51103
# Estimating correlation matrix for subject 51104
# Estimating correlation matrix for subject 51105
# Estimating correlation matrix for subject 51106
# Estimating correlation matrix for subject 51107
# Estimating correlation matrix for subject 51109
# Estimating correlation matrix for subject 51110
# Estimating correlation matrix for subject 51111
# Estimating correlation matrix for subject 51112
# Estimating correlation matrix for subject 51113
# Estimating correlation matrix for subject 51114
# Estimating correlation matrix for subject 51116
# Estimating correlation matrix for subject 51117
# Estimating correlation matrix for subject 51118
# Estimating correlation matrix for subject 51122
# Estimating correlation matrix for subject 51123
# Estimating correlation matrix for subject 51124
# Estimating correlation matrix for subject 51126
# Estimating correlation matrix for subject 51127
# Estimating correlation matrix for subject 51128
# Estimating correlation matrix for subject 51129
# Estimating correlation matrix for subject 51130
# Estimating correlation matrix for subject 51131
# Estimating correlation matrix for subject 51132
# Estimating correlation matrix for subject 51133
# Estimating correlation matrix for subject 51134
# Estimating correlation matrix for subject 51135
# Estimating correlation matrix for subject 51136
# Estimating correlation matrix for subject 51137
# Estimating correlation matrix for subject 51138
# Estimating correlation matrix for subject 51139
# Estimating correlation matrix for subject 51140
# Estimating correlation matrix for subject 51141
# Estimating correlation matrix for subject 51142
# Estimating correlation matrix for subject 51146
# Estimating correlation matrix for subject 51147
# Estimating correlation matrix for subject 51148
# Estimating correlation matrix for subject 51149
# Estimating correlation matrix for subject 51150
# Estimating correlation matrix for subject 51151
# Estimating correlation matrix for subject 51152
# Estimating correlation matrix for subject 51153
# Estimating correlation matrix for subject 51154
# Estimating correlation matrix for subject 51155
# Estimating correlation matrix for subject 51156
# Estimating correlation matrix for subject 51159
# Estimating correlation matrix for subject 51161
# Estimating correlation matrix for subject 51162
# Estimating correlation matrix for subject 51163
# Estimating correlation matrix for subject 51164
# Estimating correlation matrix for subject 51168
# Estimating correlation matrix for subject 51169
# Estimating correlation matrix for subject 51170
# Estimating correlation matrix for subject 51171
# Estimating correlation matrix for subject 51173
# Estimating correlation matrix for subject 51177
# Estimating correlation matrix for subject 51178
# Estimating correlation matrix for subject 51179
# Estimating correlation matrix for subject 51180
# Estimating correlation matrix for subject 51181
# Estimating correlation matrix for subject 51182
# Estimating correlation matrix for subject 51183
# Estimating correlation matrix for subject 51184
# Estimating correlation matrix for subject 51185
# Estimating correlation matrix for subject 51187
# Estimating correlation matrix for subject 51188
# Estimating correlation matrix for subject 51189
# Estimating correlation matrix for subject 51192
# Estimating correlation matrix for subject 51194
# Estimating correlation matrix for subject 51197
# Estimating correlation matrix for subject 51198
# Estimating correlation matrix for subject 51201
# Estimating correlation matrix for subject 51202
# Estimating correlation matrix for subject 51203
# Estimating correlation matrix for subject 51204
# Estimating correlation matrix for subject 51205
# Estimating correlation matrix for subject 51206
# Estimating correlation matrix for subject 51207
# Estimating correlation matrix for subject 51208
# Estimating correlation matrix for subject 51210
# Estimating correlation matrix for subject 51211
# Estimating correlation matrix for subject 51212
# Estimating correlation matrix for subject 51214
# Estimating correlation matrix for subject 51215
# Estimating correlation matrix for subject 51216
# Estimating correlation matrix for subject 51217
# Estimating correlation matrix for subject 51218
# Estimating correlation matrix for subject 51219
# Estimating correlation matrix for subject 51220
# Estimating correlation matrix for subject 51221
# Estimating correlation matrix for subject 51222
# Estimating correlation matrix for subject 51223
# Estimating correlation matrix for subject 51224
# Estimating correlation matrix for subject 51225
# Estimating correlation matrix for subject 51226
# Estimating correlation matrix for subject 51228
# Estimating correlation matrix for subject 51229
# Estimating correlation matrix for subject 51230
# Estimating correlation matrix for subject 51231
# Estimating correlation matrix for subject 51234
# Estimating correlation matrix for subject 51235
# Estimating correlation matrix for subject 51236
# Estimating correlation matrix for subject 51237
# Estimating correlation matrix for subject 51239
# Estimating correlation matrix for subject 51240
# Estimating correlation matrix for subject 51241
# Estimating correlation matrix for subject 51248
# Estimating correlation matrix for subject 51249
# Estimating correlation matrix for subject 51250
# Estimating correlation matrix for subject 51251
# Estimating correlation matrix for subject 51252
# Estimating correlation matrix for subject 51253
# Estimating correlation matrix for subject 51254
# Estimating correlation matrix for subject 51255
# Estimating correlation matrix for subject 51256
# Estimating correlation matrix for subject 51257
# Estimating correlation matrix for subject 51260
# Estimating correlation matrix for subject 51261
# Estimating correlation matrix for subject 51262
# Estimating correlation matrix for subject 51264
# Estimating correlation matrix for subject 51265
# Estimating correlation matrix for subject 51266
# Estimating correlation matrix for subject 51267
# Estimating correlation matrix for subject 51268
# Estimating correlation matrix for subject 51269
# Estimating correlation matrix for subject 51271
# Estimating correlation matrix for subject 51272
# Estimating correlation matrix for subject 51273
# Estimating correlation matrix for subject 51275
# Estimating correlation matrix for subject 51276
# Estimating correlation matrix for subject 51277
# Estimating correlation matrix for subject 51278
# Estimating correlation matrix for subject 51279
# Estimating correlation matrix for subject 51280
# Estimating correlation matrix for subject 51281
# Estimating correlation matrix for subject 51291
# Estimating correlation matrix for subject 51292
# Estimating correlation matrix for subject 51293
# Estimating correlation matrix for subject 51294
# Estimating correlation matrix for subject 51295
# Estimating correlation matrix for subject 51297
# Estimating correlation matrix for subject 51298
# Estimating correlation matrix for subject 51299
# Estimating correlation matrix for subject 51300
# Estimating correlation matrix for subject 51301
# Estimating correlation matrix for subject 51302
# Estimating correlation matrix for subject 51303
# Estimating correlation matrix for subject 51304
# Estimating correlation matrix for subject 51305
# Estimating correlation matrix for subject 51306
# Estimating correlation matrix for subject 51307
# Estimating correlation matrix for subject 51308
# Estimating correlation matrix for subject 51309
# Estimating correlation matrix for subject 51311
# Estimating correlation matrix for subject 51313
# Estimating correlation matrix for subject 51315
# Estimating correlation matrix for subject 51318
# Estimating correlation matrix for subject 51319
# Estimating correlation matrix for subject 51320
# Estimating correlation matrix for subject 51321
# Estimating correlation matrix for subject 51322
# Estimating correlation matrix for subject 51323
# Estimating correlation matrix for subject 51325
# Estimating correlation matrix for subject 51326
# Estimating correlation matrix for subject 51327
# Estimating correlation matrix for subject 51328
# Estimating correlation matrix for subject 51329
# Estimating correlation matrix for subject 51330
# Estimating correlation matrix for subject 51331
# Estimating correlation matrix for subject 51332
# Estimating correlation matrix for subject 51333
# Estimating correlation matrix for subject 51334
# Estimating correlation matrix for subject 51335
# Estimating correlation matrix for subject 51336
# Estimating correlation matrix for subject 51338
# Estimating correlation matrix for subject 51339
# Estimating correlation matrix for subject 51340
# Estimating correlation matrix for subject 51341
# Estimating correlation matrix for subject 51342
# Estimating correlation matrix for subject 51343
# Estimating correlation matrix for subject 51344
# Estimating correlation matrix for subject 51345
# Estimating correlation matrix for subject 51346
# Estimating correlation matrix for subject 51347
# Estimating correlation matrix for subject 51349
# Estimating correlation matrix for subject 51350
# Estimating correlation matrix for subject 51351
# Estimating correlation matrix for subject 51354
# Estimating correlation matrix for subject 51356
# Estimating correlation matrix for subject 51357
# Estimating correlation matrix for subject 51359
# Estimating correlation matrix for subject 51360
# Estimating correlation matrix for subject 51361
# Estimating correlation matrix for subject 51362
# Estimating correlation matrix for subject 51363
# Estimating correlation matrix for subject 51364
# Estimating correlation matrix for subject 51365
# Estimating correlation matrix for subject 51369
# Estimating correlation matrix for subject 51370
# Estimating correlation matrix for subject 51373
# Estimating correlation matrix for subject 51461
# Estimating correlation matrix for subject 51463
# Estimating correlation matrix for subject 51464
# Estimating correlation matrix for subject 51465
# Estimating correlation matrix for subject 51473
# Estimating correlation matrix for subject 51477
# Estimating correlation matrix for subject 51479
# Estimating correlation matrix for subject 51480
# Estimating correlation matrix for subject 51481
# Estimating correlation matrix for subject 51482
# Estimating correlation matrix for subject 51484
# Estimating correlation matrix for subject 51487
# Estimating correlation matrix for subject 51488
# Estimating correlation matrix for subject 51491
# Estimating correlation matrix for subject 51493
# Estimating correlation matrix for subject 51556
# Estimating correlation matrix for subject 51557
# Estimating correlation matrix for subject 51558
# Estimating correlation matrix for subject 51559
# Estimating correlation matrix for subject 51560
# Estimating correlation matrix for subject 51562
# Estimating correlation matrix for subject 51563
# Estimating correlation matrix for subject 51564
# Estimating correlation matrix for subject 51565
# Estimating correlation matrix for subject 51566
# Estimating correlation matrix for subject 51567
# Estimating correlation matrix for subject 51568
# Estimating correlation matrix for subject 51569
# Estimating correlation matrix for subject 51570
# Estimating correlation matrix for subject 51572
# Estimating correlation matrix for subject 51573
# Estimating correlation matrix for subject 51574
# Estimating correlation matrix for subject 51576
# Estimating correlation matrix for subject 51577
# Estimating correlation matrix for subject 51578
# Estimating correlation matrix for subject 51579
# Estimating correlation matrix for subject 51580
# Estimating correlation matrix for subject 51582
# Estimating correlation matrix for subject 51583
# Estimating correlation matrix for subject 51584
# Estimating correlation matrix for subject 51585
# Estimating correlation matrix for subject 51606
# Estimating correlation matrix for subject 51607

# %%
################### download labels, collection sites, age, gender, FIQS .mat files #################################
import csv


phenotype = os.path.join(AAL_path, 'ABIDE_pcp/Phenotypic_V1_0b_preprocessed1.csv')

def get_subject_score(phenotype,subject_list, score):
    scores_dict = {}

    with open(phenotype) as csv_file:
        reader = csv.DictReader(csv_file)
        for row in reader:
            if row['SUB_ID'] in subject_list:
                scores_dict[row['SUB_ID']] = row[score]

    return scores_dict

ages_dist = get_subject_score(phenotype, subject_IDs, score='AGE_AT_SCAN')
genders_dist = get_subject_score(phenotype, subject_IDs, score='SEX')
labels_dist = get_subject_score(phenotype, subject_IDs, score='DX_GROUP')
sites_dist = get_subject_score(phenotype, subject_IDs, score='SITE_ID')
FIQS_dist = get_subject_score(phenotype, subject_IDs, score='FIQ')
NUM_dist = get_subject_score(phenotype, subject_IDs, score='func_num_fd')
PEC_dist = get_subject_score(phenotype, subject_IDs, score='func_perc_fd')
RAT_dist = get_subject_score(phenotype, subject_IDs, score='qc_anat_rater_2')
ages = list(ages_dist.values())
genders = list(genders_dist.values())
labels = list(labels_dist.values())
sites = list(sites_dist.values())
FIQS_all = list(FIQS_dist.values())
NUM_all = list(NUM_dist.values())
PEC_all = list(PEC_dist.values())
RAT_all = list(RAT_dist.values())

labels_array = np.zeros((2,num_subjects))
NUM = np.zeros([num_subjects, 1], dtype=np.int)
PEC = np.zeros([num_subjects, 1], dtype=np.float)
RAT = np.zeros([num_subjects, 1], dtype=np.int)
FIQS = np.zeros([num_subjects, 1], dtype=np.float)


for i in range(num_subjects):

    NUM[i] = NUM_all[i]
    PEC[i] = PEC_all[i]

    if FIQS_all[i] == '':
        FIQS[i] = -9999
    else:
        FIQS[i] = FIQS_all[i]

    if labels[i] == '1':
        labels_array[0, i] = 1
    else:
        labels_array[1, i] = 1

    if RAT_all[i] == 'OK':
        RAT[i]=1
    elif RAT_all[i] == 'maybe':
        RAT[i]=2
    elif RAT_all[i] == 'fail':
        RAT[i]=3

sio.savemat(os.path.join(phenotypic_path, 'ages.mat'), {'ages': ages})
sio.savemat(os.path.join(phenotypic_path, 'genders.mat'), {'genders': genders})
sio.savemat(os.path.join(phenotypic_path, 'sites.mat'), {'sites': sites})
sio.savemat(os.path.join(phenotypic_path, 'FIQS.mat'), {'FIQS': FIQS})
sio.savemat(os.path.join(phenotypic_path, 'NUM.mat'), {'NUM': NUM})
sio.savemat(os.path.join(phenotypic_path, 'PEC.mat'), {'PEC': PEC})
sio.savemat(os.path.join(phenotypic_path, 'RAT.mat'), {'RAT': RAT})
sio.savemat(os.path.join(phenotypic_path, 'ABIDE_label_871.mat'), {'label': labels_array})
# Out:
# <ipython-input-6-ed7fd764f3bb>:36: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   NUM = np.zeros([num_subjects, 1], dtype=np.int)
# <ipython-input-6-ed7fd764f3bb>:37: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   PEC = np.zeros([num_subjects, 1], dtype=np.float)
# <ipython-input-6-ed7fd764f3bb>:38: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   RAT = np.zeros([num_subjects, 1], dtype=np.int)
# <ipython-input-6-ed7fd764f3bb>:39: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   FIQS = np.zeros([num_subjects, 1], dtype=np.float)

# %%
labels_array = np.zeros((2,num_subjects))
# !pwd
os.chdir("/content/drive/MyDrive/ABIDE/AAL/original/")
# !pwd
# !rm -rf ABIDE_pcp
# Out:
# /content/drive/MyDrive/ABIDE/AAL/original/ABIDE_pcp/cpac/filt_noglobal
# /content/drive/MyDrive/ABIDE/AAL/original

# %%
# Prepare CC200 data

from nilearn import datasets
from nilearn import connectome
import scipy.io as sio
import numpy as np
import shutil

def get_ids(data_folder,num_subjects=None):
    """
    return:
        subject_IDs    : list of all subject IDs
    """
    subject_IDs = np.genfromtxt(os.path.join(data_folder, 'subject_IDs.txt'), dtype=str)
    if num_subjects is not None:
        subject_IDs = subject_IDs[:num_subjects]
    return subject_IDs

def fetch_filenames(data_folder,subject_IDs, file_type):
    """
        subject_list : list of short subject IDs in string format
        file_type    : must be one of the available file types
    returns:
        filenames    : list of filetypes (same length as subject_list)
    """
    import glob
    # Specify file mappings for the possible file types
    filemapping = {'func_preproc': '_func_preproc.nii.gz',
                   'rois_cc200': '_rois_cc200.1D'}
    # The list to be filled
    filenames = []
    # Fill list with requested file paths
    for i in range(len(subject_IDs)):
        os.chdir(data_folder)
        try:
            filenames.append(glob.glob('*' + subject_IDs[i] + filemapping[file_type])[0])
        except IndexError:
            # Return N/A if subject ID is not found
            filenames.append('N/A')
    return filenames

def get_timeseries(data_folder,subject_list, atlas_name):
    """
        subject_list : list of short subject IDs in string format
        atlas_name   : the atlas based on which the timeseries are generated e.g. aal, cc200

    returns:
        time_series  : list of timeseries arrays, each of shape (timepoints x regions)
    """
    timeseries = []
    for i in range(len(subject_list)):
        subject_folder = os.path.join(data_folder, subject_list[i])
        ro_file = [f for f in os.listdir(subject_folder) if f.endswith('_rois_' + atlas_name + '.1D')]
        print(ro_file[0])
        fl = os.path.join(subject_folder, ro_file[0])
        print("Reading timeseries file %s" %fl)
        timeseries.append(np.loadtxt(fl, skiprows=0))
    return timeseries

def subject_connectivity(timeseries, subject, atlas_name, kind, save_path, save=True):
    """
        timeseries   : timeseries table for subject (timepoints x regions)
        subject      : the subject ID
        atlas_name   : name of the parcellation atlas used
        kind         : the kind of connectivity to be used, e.g. lasso, partial correlation, correlation
        save         : save the connectivity matrix to a file
        save_path    : specify path to save the matrix if different from subject folder

    returns:
        connectivity : connectivity matrix (regions x regions)
    """

    print("Estimating %s matrix for subject %s" % (kind, subject))

    if kind in ['tangent', 'partial correlation', 'correlation']:
        conn_measure = connectome.ConnectivityMeasure(kind=kind)
        connectivity = conn_measure.fit_transform([timeseries])[0]

    if save:
        subject_file = os.path.join(save_path, subject + '.mat')
        sio.savemat(subject_file, {'connectivity': connectivity})

    return connectivity



CC200_path = main_path + '/CC200/original/'
data_folder = CC200_path + 'ABIDE_pcp/cpac/filt_noglobal'
if not os.path.exists(CC200_path):
  os.makedirs(CC200_path)
pipeline = 'cpac'
num_subjects = 871  # Number of subjects
files = ['rois_cc200']
filemapping = {'func_preproc': 'func_preproc.nii.gz',
               'rois_cc200': 'rois_cc200.1D'}

abide = datasets.fetch_abide_pcp(data_dir=CC200_path, n_subjects=num_subjects, pipeline=pipeline,
                 band_pass_filtering=True, global_signal_regression=False, derivatives=files)


subject_IDs = get_ids(phenotypic_path,num_subjects)
subject_IDs = subject_IDs.tolist()

for s, fname in zip(subject_IDs, fetch_filenames(data_folder, subject_IDs, files[0])):
    subject_folder = os.path.join(data_folder, s)
    if not os.path.exists(subject_folder):
        os.mkdir(subject_folder)

    # Get the base filename for each subject
    base = fname.split(files[0])[0]

    # Move each subject file to the subject folder
    for fl in files:
        if not os.path.exists(os.path.join(subject_folder, base + filemapping[fl])):
            shutil.move(base + filemapping[fl], subject_folder)

time_series = get_timeseries(data_folder,subject_IDs, 'cc200')

# Compute and save connectivity matrices
for i in range(len(subject_IDs)):
    subject_connectivity(time_series[i], subject_IDs[i], 'cc200', 'correlation',CC200_path)
# Out:
# Added README.md to /content/drive/MyDrive/ABIDE/CC200/original/
#
#
# Dataset created in /content/drive/MyDrive/ABIDE/CC200/original/ABIDE_pcp
#
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Phenotypic_V1_0b_preprocessed1.csv ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050003_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050004_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050005_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050006_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050007_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050008_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050010_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050011_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050012_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050013_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050014_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050015_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050016_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050020_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050022_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050023_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050024_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050025_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050026_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050027_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050028_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050030_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050031_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050032_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050033_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050034_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050035_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050036_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050037_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050038_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050039_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050040_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050041_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050042_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050043_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050044_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050045_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050046_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050047_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050048_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050049_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050050_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050051_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050052_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050053_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050054_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050056_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050057_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050059_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Pitt_0050060_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Olin_0050102_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Olin_0050103_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Olin_0050104_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Olin_0050105_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Olin_0050106_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Olin_0050107_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Olin_0050109_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Olin_0050111_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Olin_0050112_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Olin_0050113_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Olin_0050114_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Olin_0050115_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Olin_0050116_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Olin_0050117_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Olin_0050118_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Olin_0050119_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Olin_0050121_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Olin_0050123_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Olin_0050124_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Olin_0050125_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Olin_0050127_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Olin_0050128_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Olin_0050129_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Olin_0050130_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Olin_0050131_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Olin_0050132_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Olin_0050134_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Olin_0050135_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/OHSU_0050142_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/OHSU_0050143_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/OHSU_0050144_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/OHSU_0050145_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/OHSU_0050146_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/OHSU_0050147_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/OHSU_0050148_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/OHSU_0050149_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/OHSU_0050150_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/OHSU_0050152_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/OHSU_0050153_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/OHSU_0050156_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/OHSU_0050157_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/OHSU_0050158_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/OHSU_0050159_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/OHSU_0050160_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/OHSU_0050161_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/OHSU_0050162_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/OHSU_0050163_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/OHSU_0050164_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/OHSU_0050167_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/OHSU_0050168_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/OHSU_0050169_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/OHSU_0050170_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/OHSU_0050171_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/SDSU_0050182_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/SDSU_0050183_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/SDSU_0050184_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/SDSU_0050186_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/SDSU_0050187_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/SDSU_0050188_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/SDSU_0050189_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/SDSU_0050190_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/SDSU_0050193_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/SDSU_0050194_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/SDSU_0050195_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/SDSU_0050196_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/SDSU_0050198_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/SDSU_0050199_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/SDSU_0050200_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/SDSU_0050201_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/SDSU_0050202_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/SDSU_0050203_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/SDSU_0050204_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/SDSU_0050205_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/SDSU_0050206_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/SDSU_0050208_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/SDSU_0050210_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/SDSU_0050213_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/SDSU_0050214_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/SDSU_0050215_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/SDSU_0050217_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050232_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050233_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050234_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050236_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050237_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050239_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050240_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050241_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050243_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050245_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050247_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050248_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050249_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050250_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050251_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050252_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050253_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050254_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050255_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050257_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050259_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050260_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050261_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050262_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050263_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050264_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050265_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050266_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050267_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050268_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050269_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050270_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/Trinity_0050271_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050272_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050273_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050274_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050275_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050276_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050278_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050282_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050284_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050285_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050287_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050289_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050290_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050291_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050292_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050293_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050294_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050295_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050297_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050298_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050300_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050301_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050302_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050304_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050308_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050310_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050312_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050314_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050315_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050318_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050319_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050320_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050321_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050324_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050325_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050327_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050329_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050330_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050331_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050332_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050333_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050334_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050335_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050336_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050337_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050338_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050339_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050340_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050341_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050342_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050343_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050344_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050345_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050346_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050347_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050348_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050349_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050350_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050351_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050352_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050353_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050354_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050355_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050356_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050357_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050358_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050359_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050360_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050361_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050362_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050363_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050364_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050365_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050366_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050367_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050368_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050369_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050370_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050372_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050373_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050374_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050375_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050376_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050377_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050379_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050380_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_1_0050381_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_2_0050382_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_2_0050383_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_2_0050385_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_2_0050386_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_2_0050387_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_2_0050388_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_2_0050390_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_noglobal/rois_cc200/UM_2_0050391_rois_cc200.1D ...
#  ...done. (1 seconds, 0 min)
# ...
# Estimating correlation matrix for subject 51007
# Estimating correlation matrix for subject 51008
# Estimating correlation matrix for subject 51009
# Estimating correlation matrix for subject 51010
# Estimating correlation matrix for subject 51011
# Estimating correlation matrix for subject 51012
# Estimating correlation matrix for subject 51013
# Estimating correlation matrix for subject 51014
# Estimating correlation matrix for subject 51015
# Estimating correlation matrix for subject 51016
# Estimating correlation matrix for subject 51017
# Estimating correlation matrix for subject 51018
# Estimating correlation matrix for subject 51019
# Estimating correlation matrix for subject 51020
# Estimating correlation matrix for subject 51021
# Estimating correlation matrix for subject 51023
# Estimating correlation matrix for subject 51024
# Estimating correlation matrix for subject 51025
# Estimating correlation matrix for subject 51026
# Estimating correlation matrix for subject 51027
# Estimating correlation matrix for subject 51028
# Estimating correlation matrix for subject 51029
# Estimating correlation matrix for subject 51030
# Estimating correlation matrix for subject 51032
# Estimating correlation matrix for subject 51033
# Estimating correlation matrix for subject 51034
# Estimating correlation matrix for subject 51035
# Estimating correlation matrix for subject 51036
# Estimating correlation matrix for subject 51038
# Estimating correlation matrix for subject 51039
# Estimating correlation matrix for subject 51040
# Estimating correlation matrix for subject 51041
# Estimating correlation matrix for subject 51042
# Estimating correlation matrix for subject 51044
# Estimating correlation matrix for subject 51045
# Estimating correlation matrix for subject 51046
# Estimating correlation matrix for subject 51047
# Estimating correlation matrix for subject 51048
# Estimating correlation matrix for subject 51049
# Estimating correlation matrix for subject 51050
# Estimating correlation matrix for subject 51051
# Estimating correlation matrix for subject 51052
# Estimating correlation matrix for subject 51053
# Estimating correlation matrix for subject 51054
# Estimating correlation matrix for subject 51055
# Estimating correlation matrix for subject 51056
# Estimating correlation matrix for subject 51057
# Estimating correlation matrix for subject 51058
# Estimating correlation matrix for subject 51059
# Estimating correlation matrix for subject 51060
# Estimating correlation matrix for subject 51061
# Estimating correlation matrix for subject 51062
# Estimating correlation matrix for subject 51063
# Estimating correlation matrix for subject 51064
# Estimating correlation matrix for subject 51065
# Estimating correlation matrix for subject 51066
# Estimating correlation matrix for subject 51067
# Estimating correlation matrix for subject 51068
# Estimating correlation matrix for subject 51069
# Estimating correlation matrix for subject 51070
# Estimating correlation matrix for subject 51072
# Estimating correlation matrix for subject 51073
# Estimating correlation matrix for subject 51074
# Estimating correlation matrix for subject 51075
# Estimating correlation matrix for subject 51076
# Estimating correlation matrix for subject 51077
# Estimating correlation matrix for subject 51078
# Estimating correlation matrix for subject 51079
# Estimating correlation matrix for subject 51080
# Estimating correlation matrix for subject 51081
# Estimating correlation matrix for subject 51082
# Estimating correlation matrix for subject 51083
# Estimating correlation matrix for subject 51084
# Estimating correlation matrix for subject 51085
# Estimating correlation matrix for subject 51086
# Estimating correlation matrix for subject 51087
# Estimating correlation matrix for subject 51088
# Estimating correlation matrix for subject 51089
# Estimating correlation matrix for subject 51090
# Estimating correlation matrix for subject 51091
# Estimating correlation matrix for subject 51093
# Estimating correlation matrix for subject 51094
# Estimating correlation matrix for subject 51095
# Estimating correlation matrix for subject 51096
# Estimating correlation matrix for subject 51097
# Estimating correlation matrix for subject 51098
# Estimating correlation matrix for subject 51099
# Estimating correlation matrix for subject 51100
# Estimating correlation matrix for subject 51101
# Estimating correlation matrix for subject 51102
# Estimating correlation matrix for subject 51103
# Estimating correlation matrix for subject 51104
# Estimating correlation matrix for subject 51105
# Estimating correlation matrix for subject 51106
# Estimating correlation matrix for subject 51107
# Estimating correlation matrix for subject 51109
# Estimating correlation matrix for subject 51110
# Estimating correlation matrix for subject 51111
# Estimating correlation matrix for subject 51112
# Estimating correlation matrix for subject 51113
# Estimating correlation matrix for subject 51114
# Estimating correlation matrix for subject 51116
# Estimating correlation matrix for subject 51117
# Estimating correlation matrix for subject 51118
# Estimating correlation matrix for subject 51122
# Estimating correlation matrix for subject 51123
# Estimating correlation matrix for subject 51124
# Estimating correlation matrix for subject 51126
# Estimating correlation matrix for subject 51127
# Estimating correlation matrix for subject 51128
# Estimating correlation matrix for subject 51129
# Estimating correlation matrix for subject 51130
# Estimating correlation matrix for subject 51131
# Estimating correlation matrix for subject 51132
# Estimating correlation matrix for subject 51133
# Estimating correlation matrix for subject 51134
# Estimating correlation matrix for subject 51135
# Estimating correlation matrix for subject 51136
# Estimating correlation matrix for subject 51137
# Estimating correlation matrix for subject 51138
# Estimating correlation matrix for subject 51139
# Estimating correlation matrix for subject 51140
# Estimating correlation matrix for subject 51141
# Estimating correlation matrix for subject 51142
# Estimating correlation matrix for subject 51146
# Estimating correlation matrix for subject 51147
# Estimating correlation matrix for subject 51148
# Estimating correlation matrix for subject 51149
# Estimating correlation matrix for subject 51150
# Estimating correlation matrix for subject 51151
# Estimating correlation matrix for subject 51152
# Estimating correlation matrix for subject 51153
# Estimating correlation matrix for subject 51154
# Estimating correlation matrix for subject 51155
# Estimating correlation matrix for subject 51156
# Estimating correlation matrix for subject 51159
# Estimating correlation matrix for subject 51161
# Estimating correlation matrix for subject 51162
# Estimating correlation matrix for subject 51163
# Estimating correlation matrix for subject 51164
# Estimating correlation matrix for subject 51168
# Estimating correlation matrix for subject 51169
# Estimating correlation matrix for subject 51170
# Estimating correlation matrix for subject 51171
# Estimating correlation matrix for subject 51173
# Estimating correlation matrix for subject 51177
# Estimating correlation matrix for subject 51178
# Estimating correlation matrix for subject 51179
# Estimating correlation matrix for subject 51180
# Estimating correlation matrix for subject 51181
# Estimating correlation matrix for subject 51182
# Estimating correlation matrix for subject 51183
# Estimating correlation matrix for subject 51184
# Estimating correlation matrix for subject 51185
# Estimating correlation matrix for subject 51187
# Estimating correlation matrix for subject 51188
# Estimating correlation matrix for subject 51189
# Estimating correlation matrix for subject 51192
# Estimating correlation matrix for subject 51194
# Estimating correlation matrix for subject 51197
# Estimating correlation matrix for subject 51198
# Estimating correlation matrix for subject 51201
# Estimating correlation matrix for subject 51202
# Estimating correlation matrix for subject 51203
# Estimating correlation matrix for subject 51204
# Estimating correlation matrix for subject 51205
# Estimating correlation matrix for subject 51206
# Estimating correlation matrix for subject 51207
# Estimating correlation matrix for subject 51208
# Estimating correlation matrix for subject 51210
# Estimating correlation matrix for subject 51211
# Estimating correlation matrix for subject 51212
# Estimating correlation matrix for subject 51214
# Estimating correlation matrix for subject 51215
# Estimating correlation matrix for subject 51216
# Estimating correlation matrix for subject 51217
# Estimating correlation matrix for subject 51218
# Estimating correlation matrix for subject 51219
# Estimating correlation matrix for subject 51220
# Estimating correlation matrix for subject 51221
# Estimating correlation matrix for subject 51222
# Estimating correlation matrix for subject 51223
# Estimating correlation matrix for subject 51224
# Estimating correlation matrix for subject 51225
# Estimating correlation matrix for subject 51226
# Estimating correlation matrix for subject 51228
# Estimating correlation matrix for subject 51229
# Estimating correlation matrix for subject 51230
# Estimating correlation matrix for subject 51231
# Estimating correlation matrix for subject 51234
# Estimating correlation matrix for subject 51235
# Estimating correlation matrix for subject 51236
# Estimating correlation matrix for subject 51237
# Estimating correlation matrix for subject 51239
# Estimating correlation matrix for subject 51240
# Estimating correlation matrix for subject 51241
# Estimating correlation matrix for subject 51248
# Estimating correlation matrix for subject 51249
# Estimating correlation matrix for subject 51250
# Estimating correlation matrix for subject 51251
# Estimating correlation matrix for subject 51252
# Estimating correlation matrix for subject 51253
# Estimating correlation matrix for subject 51254
# Estimating correlation matrix for subject 51255
# Estimating correlation matrix for subject 51256
# Estimating correlation matrix for subject 51257
# Estimating correlation matrix for subject 51260
# Estimating correlation matrix for subject 51261
# Estimating correlation matrix for subject 51262
# Estimating correlation matrix for subject 51264
# Estimating correlation matrix for subject 51265
# Estimating correlation matrix for subject 51266
# Estimating correlation matrix for subject 51267
# Estimating correlation matrix for subject 51268
# Estimating correlation matrix for subject 51269
# Estimating correlation matrix for subject 51271
# Estimating correlation matrix for subject 51272
# Estimating correlation matrix for subject 51273
# Estimating correlation matrix for subject 51275
# Estimating correlation matrix for subject 51276
# Estimating correlation matrix for subject 51277
# Estimating correlation matrix for subject 51278
# Estimating correlation matrix for subject 51279
# Estimating correlation matrix for subject 51280
# Estimating correlation matrix for subject 51281
# Estimating correlation matrix for subject 51291
# Estimating correlation matrix for subject 51292
# Estimating correlation matrix for subject 51293
# Estimating correlation matrix for subject 51294
# Estimating correlation matrix for subject 51295
# Estimating correlation matrix for subject 51297
# Estimating correlation matrix for subject 51298
# Estimating correlation matrix for subject 51299
# Estimating correlation matrix for subject 51300
# Estimating correlation matrix for subject 51301
# Estimating correlation matrix for subject 51302
# Estimating correlation matrix for subject 51303
# Estimating correlation matrix for subject 51304
# Estimating correlation matrix for subject 51305
# Estimating correlation matrix for subject 51306
# Estimating correlation matrix for subject 51307
# Estimating correlation matrix for subject 51308
# Estimating correlation matrix for subject 51309
# Estimating correlation matrix for subject 51311
# Estimating correlation matrix for subject 51313
# Estimating correlation matrix for subject 51315
# Estimating correlation matrix for subject 51318
# Estimating correlation matrix for subject 51319
# Estimating correlation matrix for subject 51320
# Estimating correlation matrix for subject 51321
# Estimating correlation matrix for subject 51322
# Estimating correlation matrix for subject 51323
# Estimating correlation matrix for subject 51325
# Estimating correlation matrix for subject 51326
# Estimating correlation matrix for subject 51327
# Estimating correlation matrix for subject 51328
# Estimating correlation matrix for subject 51329
# Estimating correlation matrix for subject 51330
# Estimating correlation matrix for subject 51331
# Estimating correlation matrix for subject 51332
# Estimating correlation matrix for subject 51333
# Estimating correlation matrix for subject 51334
# Estimating correlation matrix for subject 51335
# Estimating correlation matrix for subject 51336
# Estimating correlation matrix for subject 51338
# Estimating correlation matrix for subject 51339
# Estimating correlation matrix for subject 51340
# Estimating correlation matrix for subject 51341
# Estimating correlation matrix for subject 51342
# Estimating correlation matrix for subject 51343
# Estimating correlation matrix for subject 51344
# Estimating correlation matrix for subject 51345
# Estimating correlation matrix for subject 51346
# Estimating correlation matrix for subject 51347
# Estimating correlation matrix for subject 51349
# Estimating correlation matrix for subject 51350
# Estimating correlation matrix for subject 51351
# Estimating correlation matrix for subject 51354
# Estimating correlation matrix for subject 51356
# Estimating correlation matrix for subject 51357
# Estimating correlation matrix for subject 51359
# Estimating correlation matrix for subject 51360
# Estimating correlation matrix for subject 51361
# Estimating correlation matrix for subject 51362
# Estimating correlation matrix for subject 51363
# Estimating correlation matrix for subject 51364
# Estimating correlation matrix for subject 51365
# Estimating correlation matrix for subject 51369
# Estimating correlation matrix for subject 51370
# Estimating correlation matrix for subject 51373
# Estimating correlation matrix for subject 51461
# Estimating correlation matrix for subject 51463
# Estimating correlation matrix for subject 51464
# Estimating correlation matrix for subject 51465
# Estimating correlation matrix for subject 51473
# Estimating correlation matrix for subject 51477
# Estimating correlation matrix for subject 51479
# Estimating correlation matrix for subject 51480
# Estimating correlation matrix for subject 51481
# Estimating correlation matrix for subject 51482
# Estimating correlation matrix for subject 51484
# Estimating correlation matrix for subject 51487
# Estimating correlation matrix for subject 51488
# Estimating correlation matrix for subject 51491
# Estimating correlation matrix for subject 51493
# Estimating correlation matrix for subject 51556
# Estimating correlation matrix for subject 51557
# Estimating correlation matrix for subject 51558
# Estimating correlation matrix for subject 51559
# Estimating correlation matrix for subject 51560
# Estimating correlation matrix for subject 51562
# Estimating correlation matrix for subject 51563
# Estimating correlation matrix for subject 51564
# Estimating correlation matrix for subject 51565
# Estimating correlation matrix for subject 51566
# Estimating correlation matrix for subject 51567
# Estimating correlation matrix for subject 51568
# Estimating correlation matrix for subject 51569
# Estimating correlation matrix for subject 51570
# Estimating correlation matrix for subject 51572
# Estimating correlation matrix for subject 51573
# Estimating correlation matrix for subject 51574
# Estimating correlation matrix for subject 51576
# Estimating correlation matrix for subject 51577
# Estimating correlation matrix for subject 51578
# Estimating correlation matrix for subject 51579
# Estimating correlation matrix for subject 51580
# Estimating correlation matrix for subject 51582
# Estimating correlation matrix for subject 51583
# Estimating correlation matrix for subject 51584
# Estimating correlation matrix for subject 51585
# Estimating correlation matrix for subject 51606
# Estimating correlation matrix for subject 51607

# %%
# !pwd
os.chdir("/content/drive/MyDrive/ABIDE/CC200/original/")
# !pwd
# !rm -rf ABIDE_pcp
# Out:
# /content/drive/MyDrive/ABIDE/CC200/original/ABIDE_pcp/cpac/filt_noglobal
# /content/drive/MyDrive/ABIDE/CC200/original

# %%
# download sMRI data
# !gdown 1E18xuQ-BbspSuuFIhJ2AiI4RsPKwqTCy --output /content/drive/MyDrive/ABIDE/
# Out:
# Failed to retrieve file url:
#
# 	Too many users have viewed or downloaded this file recently. Please
# 	try accessing the file again later. If the file you are trying to
# 	access is particularly large or is shared with many people, it may
# 	take up to 24 hours to be able to view or download the file. If you
# 	still can't access a file after 24 hours, contact your domain
# 	administrator.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=1E18xuQ-BbspSuuFIhJ2AiI4RsPKwqTCy
#
# but Gdown can't. Please check connections and permissions.

# %%
# mkdir paths

save_model_path = main_path + '/save_models'
if not os.path.exists(save_model_path):
  os.makedirs(save_model_path)

foldernames = ['AAL','CC200','sMRI','CC200_sMRI']
modelnames = ['SVM','FCN','AUTO','GCN','EV_GCN']

for i in range(len(foldernames)):
  features_path = save_model_path + '/' + foldernames[i]
  with_phe_path = features_path + '/with_phe'
  without_phe_path = features_path + '/without_phe'
  with_phe_maxvoting_path = with_phe_path + '/Max_voting'
  without_phe_maxvoting_path = without_phe_path + '/Max_voting'
  if not os.path.exists(features_path):
    os.makedirs(features_path)
  if not os.path.exists(with_phe_path):
    os.makedirs(with_phe_path)
  if not os.path.exists(without_phe_path):
    os.makedirs(without_phe_path)
  if not os.path.exists(with_phe_maxvoting_path):
    os.makedirs(with_phe_maxvoting_path)
  if not os.path.exists(without_phe_maxvoting_path):
    os.makedirs(without_phe_maxvoting_path)

  for j in range(len(modelnames)):
    with_path = with_phe_maxvoting_path + '/' + modelnames[j]
    without_path = without_phe_maxvoting_path + '/' + modelnames[j]
    if not os.path.exists(with_path):
      os.makedirs(with_path)
    if not os.path.exists(without_path):
      os.makedirs(without_path)

# %%
# download scripts

# SVM sMRI
# !gdown 1KkbELF5C7f7ixfd8MX0Js2iZYmuwC39I --output /content/drive/MyDrive/ABIDE/
# SVM fMRI
# !gdown 1Exv0Iaf7ck3GZqV0w0wQtrt8DMm9UC8m --output /content/drive/MyDrive/ABIDE/
# SVM fMRI + sMRI
# !gdown 1EwNFEIVt9r13VsIZHE_pkYqH-W4o5L5b --output /content/drive/MyDrive/ABIDE/


# FCN sMRI
# !gdown 1l9WbbvbjjBwkKcxcKuOpZgbOKPVp9xyi --output /content/drive/MyDrive/ABIDE/
# FCN fMRI
# !gdown 1ErvYuiaE1-FKufYSXxQUun_oGIHLtE62 --output /content/drive/MyDrive/ABIDE/
# FCN fMRI + sMRI
# !gdown 1EqfmbvBH0FM7eekX1hKQGPAIjBncnx7f --output /content/drive/MyDrive/ABIDE/


# AE-FCN sMRI
# !gdown 124-aRCCH688eUGt47hb8etVPvyl-_Ks3 --output /content/drive/MyDrive/ABIDE/
# AE-FCN fMRI
# !gdown 1EjKBAcrIr1Z0kb6IBX-QgLZ5Ta80hxsj --output /content/drive/MyDrive/ABIDE/
# AE-FCN fMRI + sMRI
# !gdown 1NRxhSfZHwu-4ORbbfslMYdLjjRi_4UgO --output /content/drive/MyDrive/ABIDE/


# GCN sMRI
# !gdown 1n0p7PDnlfDwf2B37gR2GVdI3RbZ5t4lH --output /content/drive/MyDrive/ABIDE/
# GCN fMRI
# !gdown 1_xfM7R9ycPGfkIX7pcF6_Xf7JxkJ7sHV --output /content/drive/MyDrive/ABIDE/
# GCN fMRI + sMRI
# !gdown 1VbNa5fiF4O2d6ubxaafT1JTMSZ6Dn8Sh --output /content/drive/MyDrive/ABIDE/


# EVGCN sMRI
# !gdown 1HzANmGKuCmyRSSm-qYWRAdQnbMv7xPFu --output /content/drive/MyDrive/ABIDE/
# EVGCN fMRI
# !gdown 1EAwLDriSk9K_Nm9-CHxSWCqVMiKMmiUO --output /content/drive/MyDrive/ABIDE/
# EVGCN fMRI + sMRI
# !gdown 1O_NCJ6WvnDQre-Gf-qTaLqs4YS8dYHkU --output /content/drive/MyDrive/ABIDE/


# EMMA sMRI
# !gdown 12sp57Ooyr2pqLzDitvijg9ZQl3ddBnUc --output /content/drive/MyDrive/ABIDE/
# EMMA fMRI
# !gdown 1E4r6Vzh8sNPd8iUPs3Oa5VdV4F8omGfM --output /content/drive/MyDrive/ABIDE/
# EMMA fMRI + sMRI
# !gdown 1E3nH1bLPdbhSjBjw5aVr6ULZ0oNW95iG --output /content/drive/MyDrive/ABIDE/
# Out:
# Failed to retrieve file url:
#
# 	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=1KkbELF5C7f7ixfd8MX0Js2iZYmuwC39I
#
# but Gdown can't. Please check connections and permissions.
# Failed to retrieve file url:
#
# 	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=1Exv0Iaf7ck3GZqV0w0wQtrt8DMm9UC8m
#
# but Gdown can't. Please check connections and permissions.
# Failed to retrieve file url:
#
# 	Too many users have viewed or downloaded this file recently. Please
# 	try accessing the file again later. If the file you are trying to
# 	access is particularly large or is shared with many people, it may
# 	take up to 24 hours to be able to view or download the file. If you
# 	still can't access a file after 24 hours, contact your domain
# 	administrator.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=1EwNFEIVt9r13VsIZHE_pkYqH-W4o5L5b
#
# but Gdown can't. Please check connections and permissions.
# Downloading...
# From: https://drive.google.com/uc?id=1l9WbbvbjjBwkKcxcKuOpZgbOKPVp9xyi
# To: /content/drive/MyDrive/ABIDE/FCN_sMRI.ipynb
# 100% 2.62M/2.62M [00:00<00:00, 18.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1ErvYuiaE1-FKufYSXxQUun_oGIHLtE62
# To: /content/drive/MyDrive/ABIDE/FCN_fMRI.ipynb
# 100% 2.37M/2.37M [00:00<00:00, 17.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1EqfmbvBH0FM7eekX1hKQGPAIjBncnx7f
# To: /content/drive/MyDrive/ABIDE/FCN_fMRI_sMRI.ipynb
# 100% 2.79M/2.79M [00:00<00:00, 18.6MB/s]
# Failed to retrieve file url:
#
# 	Too many users have viewed or downloaded this file recently. Please
# 	try accessing the file again later. If the file you are trying to
# 	access is particularly large or is shared with many people, it may
# 	take up to 24 hours to be able to view or download the file. If you
# 	still can't access a file after 24 hours, contact your domain
# 	administrator.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=124-aRCCH688eUGt47hb8etVPvyl-_Ks3
#
# but Gdown can't. Please check connections and permissions.
# Downloading...
# From: https://drive.google.com/uc?id=1EjKBAcrIr1Z0kb6IBX-QgLZ5Ta80hxsj
# To: /content/drive/MyDrive/ABIDE/AE_FCN_fMRI.ipynb
# 100% 3.22M/3.22M [00:00<00:00, 20.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1NRxhSfZHwu-4ORbbfslMYdLjjRi_4UgO
# To: /content/drive/MyDrive/ABIDE/AE_FCN_fMRI_sMRI.ipynb
# 100% 3.55M/3.55M [00:00<00:00, 22.7MB/s]
# Failed to retrieve file url:
#
# 	Too many users have viewed or downloaded this file recently. Please
# 	try accessing the file again later. If the file you are trying to
# 	access is particularly large or is shared with many people, it may
# 	take up to 24 hours to be able to view or download the file. If you
# 	still can't access a file after 24 hours, contact your domain
# 	administrator.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=1n0p7PDnlfDwf2B37gR2GVdI3RbZ5t4lH
#
# but Gdown can't. Please check connections and permissions.
# Failed to retrieve file url:
#
# 	Too many users have viewed or downloaded this file recently. Please
# 	try accessing the file again later. If the file you are trying to
# 	access is particularly large or is shared with many people, it may
# 	take up to 24 hours to be able to view or download the file. If you
# 	still can't access a file after 24 hours, contact your domain
# 	administrator.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=1_xfM7R9ycPGfkIX7pcF6_Xf7JxkJ7sHV
#
# but Gdown can't. Please check connections and permissions.
# Failed to retrieve file url:
#
# 	Too many users have viewed or downloaded this file recently. Please
# 	try accessing the file again later. If the file you are trying to
# 	access is particularly large or is shared with many people, it may
# 	take up to 24 hours to be able to view or download the file. If you
# 	still can't access a file after 24 hours, contact your domain
# 	administrator.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=1VbNa5fiF4O2d6ubxaafT1JTMSZ6Dn8Sh
#
# but Gdown can't. Please check connections and permissions.
# Downloading...
# From: https://drive.google.com/uc?id=1HzANmGKuCmyRSSm-qYWRAdQnbMv7xPFu
# To: /content/drive/MyDrive/ABIDE/EV_GCN_sMRI.ipynb
# 100% 3.20M/3.20M [00:00<00:00, 20.7MB/s]
# Failed to retrieve file url:
#
# 	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=1EAwLDriSk9K_Nm9-CHxSWCqVMiKMmiUO
#
# but Gdown can't. Please check connections and permissions.
# Downloading...
# From: https://drive.google.com/uc?id=1O_NCJ6WvnDQre-Gf-qTaLqs4YS8dYHkU
# To: /content/drive/MyDrive/ABIDE/EV_GCN_fMRI_sMRI.ipynb
# 100% 2.76M/2.76M [00:00<00:00, 18.5MB/s]
# Failed to retrieve file url:
#
# 	Too many users have viewed or downloaded this file recently. Please
# 	try accessing the file again later. If the file you are trying to
# 	access is particularly large or is shared with many people, it may
# 	take up to 24 hours to be able to view or download the file. If you
# 	still can't access a file after 24 hours, contact your domain
# 	administrator.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=12sp57Ooyr2pqLzDitvijg9ZQl3ddBnUc
#
# but Gdown can't. Please check connections and permissions.
# Downloading...
# From: https://drive.google.com/uc?id=1E4r6Vzh8sNPd8iUPs3Oa5VdV4F8omGfM
# To: /content/drive/MyDrive/ABIDE/EMMA_fMRI.ipynb
# 100% 182k/182k [00:00<00:00, 3.66MB/s]
# Failed to retrieve file url:
#
# 	Too many users have viewed or downloaded this file recently. Please
# 	try accessing the file again later. If the file you are trying to
# 	access is particularly large or is shared with many people, it may
# 	take up to 24 hours to be able to view or download the file. If you
# 	still can't access a file after 24 hours, contact your domain
# 	administrator.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=1E3nH1bLPdbhSjBjw5aVr6ULZ0oNW95iG
#
# but Gdown can't. Please check connections and permissions.
